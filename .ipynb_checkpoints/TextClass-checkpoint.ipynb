# %% [markdown]
# # TextClass (inkl. für mehrere Werte)

# %%
import xml.etree.ElementTree as ET

# XML-Datei laden und Wurzel abrufen
root_node = ET.parse('gesamt_märchen.xml').getroot()

# Namespace definieren
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}
filter_ident = ""  # Kann auf "" gesetzt werden, um keinen Filter anzuwenden
unique_schema_set = set()

# Durchlaufen des XML-Baums
for corp in root_node.findall(".//tei:teiCorpus", NS):
    if ("tg" in corp.attrib.get("n", "") or "xtk" in corp.attrib.get("n", "")):
        for ganze in corp.findall(".//tei:TEI", NS):
            language = ganze.find(".//tei:teiHeader//tei:langUsage/tei:language", NS)
            # Bedingung für Sprache: anwenden, wenn filter_ident definiert ist, oder überspringen
            if language is not None and (not filter_ident or language.attrib.get('ident') == filter_ident):
                for text in ganze.findall(".//tei:text", NS):
                    if "" in text.attrib['{http://www.w3.org/XML/1998/namespace}id']:  
                        for segm in text.findall(".//tei:seg", NS):
                            tn = segm.attrib.get('{www.dglab.uni-jena.de/vmf/a}ana', '')
                            if "" in tn:  # Sicherstellen, dass `tn` das gesuchte Muster enthält
                                chisch = text.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                                if chisch:
                                    unique_schema_set.add(chisch)

# Ergebnisse in Datei schreiben
with open("TextClass.txt", 'w', encoding='utf-8') as f:
    f.write(str(sorted(unique_schema_set)))

# %%
import ast
import xml.etree.ElementTree as ET

def setze_variable_aus_datei(dateiname: str, variablenname: str):
    try:
        with open(dateiname, "r", encoding="utf-8") as datei:
            inhalt = datei.read().strip()
        wert = ast.literal_eval(inhalt)
        globals()[variablenname] = wert
        return wert
    except Exception as e:
        print(f"Fehler beim Einlesen und Setzen der Variable: {e}")
        return None

# 1. Mehrere `chisch`-Werte definieren
chisch = setze_variable_aus_datei("TextClass.txt", "chisch")

# Überprüfen, ob die Variable korrekt gesetzt wurde
print(chisch)
# Out:
# ['cc_agx_rus_54', 'cc_agx_rus_55', 'cc_agx_rus_56ß', 'cc_agx_rus_57', 'cc_ani_rus_10', 'cc_ani_rus_11', 'cc_ani_rus_12ß', 'cc_ani_rus_13', 'cc_ani_rus_14', 'cc_ani_rus_15', 'cc_ani_rus_16', 'cc_ani_rus_17', 'cc_ani_rus_8', 'cc_ani_rus_9', 'cc_aqc_rus_19', 'cc_aqc_rus_20', 'cc_aqc_rus_21', 'cc_aqc_rus_22', 'cc_aqc_rus_23', 'cc_aqc_rus_24', 'cc_aqc_rus_25', 'cc_aqc_rus_26', 'cc_aqc_rus_27', 'cc_aqc_rus_28', 'cc_aqc_rus_29', 'cc_aqc_rus_30', 'cc_aqc_rus_31', 'cc_aqc_rus_32', 'cc_aqc_rus_33', 'cc_ava_ava_204', 'cc_ava_ava_205', 'cc_ava_ava_206', 'cc_ava_ava_207', 'cc_ava_ava_208', 'cc_ava_ava_209', 'cc_ava_ava_210', 'cc_ava_ava_211', 'cc_ava_ava_212', 'cc_ava_ava_213', 'cc_ava_ava_214', 'cc_ava_deu_204', 'cc_ava_deu_205', 'cc_ava_deu_206', 'cc_ava_deu_207', 'cc_ava_deu_208', 'cc_ava_deu_209', 'cc_ava_deu_210', 'cc_ava_deu_211', 'cc_ava_deu_212', 'cc_ava_deu_213', 'cc_ava_rus_214', 'cc_ddo_ddo_95', 'cc_ddo_ddo_96', 'cc_ddo_ddo_97', 'cc_ddo_ddo_98', 'cc_ddo_ddo_99', 'cc_ddo_kat_95', 'cc_ddo_kat_96', 'cc_ddo_kat_97', 'cc_ddo_kat_98', 'cc_ddo_kat_99', 'cc_ddo_rus_95', 'cc_ddo_rus_98', 'cc_ddo_rus_99', 'cc_huz_huz_1', 'cc_huz_huz_2', 'cc_huz_rus_1', 'cc_huz_rus_2', 'cc_kap_kap_1', 'cc_kap_kap_2', 'cc_kap_kat_1', 'cc_kap_rus_1', 'cc_kap_rus_2', 'cc_sva_kat_1', 'cc_sva_sva_1', 'cc_tab_rus_45', 'cc_tab_rus_46', 'cc_tab_rus_47', 'cc_tab_rus_48', 'cc_tab_rus_49', 'cc_tab_rus_50', 'cc_xmf_kat_1', 'cc_xmf_kat_2', 'cc_xmf_kat_3', 'cc_xmf_kat_4', 'cc_xmf_kat_5', 'cc_xmf_xmf_1', 'cc_xmf_xmf_2', 'cc_xmf_xmf_3', 'cc_xmf_xmf_4', 'cc_xmf_xmf_5', 'zyx_cc_agx_rus_35ß', 'zyx_cc_agx_rus_36ß', 'zyx_cc_ddo_rus_13', 'zyx_cc_ddo_rus_15ß', 'zyx_cc_ddo_rus_18ß', 'zyx_cc_ddo_rus_26ß', 'zyx_cc_ddo_rus_33ß', 'zyx_cc_ddo_rus_34ß', 'zyx_cc_ddo_rus_47ß', 'zyx_cc_ddo_rus_48ß', 'zyx_cc_ddo_rus_49ß', 'zyx_cc_ddo_rus_4ß', 'zyx_cc_ddo_rus_55ß', 'zyx_cc_ddo_rus_59ß', 'zyx_cc_ddo_rus_5ß', 'zyx_cc_ddo_rus_60ß', 'zyx_cc_ddo_rus_61ß', 'zyx_cc_ddo_rus_72ß', 'zyx_cc_ddo_rus_76ß', 'zyx_cc_ddo_rus_77', 'zyx_cc_ddo_rus_87ß', 'zyx_cc_ddo_rus_90ß', 'zyx_cc_ddo_rus_94ß', 'zyx_cc_kva_rus_13ß', 'zyx_cr_agx_rus_10ß', 'zyx_cr_agx_rus_11ß', 'zyx_cr_agx_rus_12', 'zyx_cr_agx_rus_13', 'zyx_cr_agx_rus_14ß', 'zyx_cr_agx_rus_15', 'zyx_cr_agx_rus_16', 'zyx_cr_agx_rus_17', 'zyx_cr_agx_rus_18', 'zyx_cr_agx_rus_19', 'zyx_cr_agx_rus_1ß', 'zyx_cr_agx_rus_20', 'zyx_cr_agx_rus_21', 'zyx_cr_agx_rus_22ß', 'zyx_cr_agx_rus_23', 'zyx_cr_agx_rus_24', 'zyx_cr_agx_rus_25', 'zyx_cr_agx_rus_26', 'zyx_cr_agx_rus_27', 'zyx_cr_agx_rus_28', 'zyx_cr_agx_rus_29ß', 'zyx_cr_agx_rus_2ß', 'zyx_cr_agx_rus_3', 'zyx_cr_agx_rus_30ß', 'zyx_cr_agx_rus_31', 'zyx_cr_agx_rus_32', 'zyx_cr_agx_rus_33', 'zyx_cr_agx_rus_34', 'zyx_cr_agx_rus_37', 'zyx_cr_agx_rus_38', 'zyx_cr_agx_rus_39ß', 'zyx_cr_agx_rus_4', 'zyx_cr_agx_rus_40', 'zyx_cr_agx_rus_41', 'zyx_cr_agx_rus_42', 'zyx_cr_agx_rus_43', 'zyx_cr_agx_rus_44', 'zyx_cr_agx_rus_45', 'zyx_cr_agx_rus_46', 'zyx_cr_agx_rus_47ß', 'zyx_cr_agx_rus_48', 'zyx_cr_agx_rus_49', 'zyx_cr_agx_rus_5', 'zyx_cr_agx_rus_50', 'zyx_cr_agx_rus_51', 'zyx_cr_agx_rus_52', 'zyx_cr_agx_rus_53ß', 'zyx_cr_agx_rus_6', 'zyx_cr_agx_rus_7', 'zyx_cr_agx_rus_8ß', 'zyx_cr_agx_rus_9', 'zyx_cr_ani_rus_1', 'zyx_cr_ani_rus_2', 'zyx_cr_ani_rus_3', 'zyx_cr_ani_rus_4', 'zyx_cr_ani_rus_5', 'zyx_cr_ani_rus_6', 'zyx_cr_ani_rus_7', 'zyx_cr_aqc_rus_1', 'zyx_cr_aqc_rus_10', 'zyx_cr_aqc_rus_11', 'zyx_cr_aqc_rus_12', 'zyx_cr_aqc_rus_13', 'zyx_cr_aqc_rus_14', 'zyx_cr_aqc_rus_15', 'zyx_cr_aqc_rus_16', 'zyx_cr_aqc_rus_17ß', 'zyx_cr_aqc_rus_18ß', 'zyx_cr_aqc_rus_2', 'zyx_cr_aqc_rus_3', 'zyx_cr_aqc_rus_4', 'zyx_cr_aqc_rus_5ß', 'zyx_cr_aqc_rus_6ß', 'zyx_cr_aqc_rus_7', 'zyx_cr_aqc_rus_8', 'zyx_cr_aqc_rus_9', 'zyx_cr_ava_rus_1', 'zyx_cr_ava_rus_10', 'zyx_cr_ava_rus_100', 'zyx_cr_ava_rus_101', 'zyx_cr_ava_rus_102', 'zyx_cr_ava_rus_103', 'zyx_cr_ava_rus_104ß', 'zyx_cr_ava_rus_105', 'zyx_cr_ava_rus_106ß', 'zyx_cr_ava_rus_107', 'zyx_cr_ava_rus_108', 'zyx_cr_ava_rus_109', 'zyx_cr_ava_rus_110ß', 'zyx_cr_ava_rus_112ß', 'zyx_cr_ava_rus_113ß', 'zyx_cr_ ...

# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET

# Modul zur Speicherung in einer zentralen Textdatei
def speichere_gesamt_ergebnisse(dateiname, daten):
    """
    Speichert die Gesamtergebnisse in eine Textdatei.
    
    :param dateiname: Name der Textdatei
    :param daten: Ergebnisse in Form eines Dictionaries {chisch: [Daten]}
    """
    with open(dateiname, 'w', encoding='utf-8') as f:
        for ch, ergebnisse in daten.items():
            f.write(f"\n{ch}:\n")
            for zeile in ergebnisse:
                f.write(f"{zeile}\n")

# Mehrere `chisch`-Werte definieren
chisch = setze_variable_aus_datei("TextClass.txt", "chisch")
# chisch = ['zyx_cr_lbe_rus_43'] # 1.1. Alternativ: Einen chisch-Wert eingeben

root_node = ET.parse('gesamt_märchen.xml').getroot()

# Speichern der Märchendaten für jedes `chisch`
maerchen_daten = {ch: "" for ch in chisch}

# 2. Schleife für jeden `chisch`-Wert in der Liste
for ch in chisch:
    for ganze in root_node.findall(".//{http://www.tei-c.org/ns/1.0}text"):
        if ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id') == ch:
            for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
                for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
                    for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}seg"):
                        try:
                            # Extrahieren der relevanten Attribute
                            labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
                            labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N')
                            labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N')
                            labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N')
                            labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N')
                            labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N')
                            labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N')
                            labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N')
                            labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N')
                            labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N')
                            labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N')
                            labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N')
                            quelle = ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']                            
                            if labela.startswith('a'):
                                # Speichern der Märchendaten in der entsprechenden `chisch`-Liste
                                maerchen_daten[ch] += f"{quelle},{labela},{labelb1},{labelc1},{labelb2},{labelc2},{labelb3},{labelc3},{labelb4},{labelc4},{labelb5},{labelc5},{labeld},{inhalt},0\n"
                        except KeyError as e:
                            print(f"Fehlendes Attribut: {e}")

# 3. Ausgabestruktur für jeden `chisch`-Wert erstellen
gesamt_ergebnisse = {}

# Erstellen der CSV-Dateien und Verarbeiten der Daten
unique_values_per_ch = {}
result_data_per_ch = {}
for ch in chisch:
    # CSV-Datei erstellen
    with open(f"text_{ch}.csv", 'w', encoding='utf-8') as f:
        f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar\n')
        f.write(maerchen_daten[ch])

    # Index-Strings erstellen
    abcd_data = []
    df = pd.read_csv(f"text_{ch}.csv", encoding='utf-8')

    for index, row in df.iterrows():
        quelle = row['quelle']
        labela = row['labela']
        for i in range(1, 6):
            labelb = row[f'labelb{i}']
            labelc = row[f'labelc{i}']
            labeld = row['labeld']
            inhalt = row['inhalt']
            abcd_data.append(f"{labela}:{labelb}:{labelc}:{labeld}")

    # Filterung der Daten
    filtered_data = [line for line in abcd_data if ':N:' not in line]

    # Extrahieren einzigartiger Werte vor dem ersten ':'
    unique_values = set(line.split(':')[0] for line in filtered_data)
    unique_values_per_ch[ch] = unique_values
    result_data_per_ch[ch] = filtered_data

    # Speichern der gefilterten Daten in der Gesamt-Ausgabeliste
    gesamt_ergebnisse[ch] = filtered_data

# Zählen der `chisch`-Werte mit und ohne Ergebnisse
chisch_mit_ergebnissen = [ch for ch, ergebnisse in gesamt_ergebnisse.items() if ergebnisse]
chisch_ohne_ergebnisse = [ch for ch, ergebnisse in gesamt_ergebnisse.items() if not ergebnisse]

print(f"Anzahl der chisch-Werte mit Ergebnissen: {len(chisch_mit_ergebnissen)}")
print(f"Anzahl der chisch-Werte ohne Ergebnisse: {len(chisch_ohne_ergebnisse)}")

# Parsen der `fk/vmf_a.xsd`-Datei und Überprüfen von Werten mit Leerzeichen
fk_tree = ET.parse('kf/vmf_a.xsd').getroot()
enum_elements = fk_tree.findall(".//{http://www.w3.org/2001/XMLSchema}enumeration")
enum_values_with_spaces = {enum.attrib['value'] for enum in enum_elements if ' ' in enum.attrib['value']}

# Ausgabe der Ergebnisse
for ch, unique_values in unique_values_per_ch.items():
    print(f"\n\n{ch}")
    print("-----------------")
    matching_values = [
    value for value in enum_values_with_spaces 
    if any(value.split(' ')[0] == uval for uval in unique_values)
]
    print(*matching_values, sep='\n')
    print("-----------------")

    # Ergebnisse mit Werten anzeigen
    if ch in result_data_per_ch:
        #print("Gefilterte Ergebnisse:")
        for result in result_data_per_ch[ch]:
            print(result)

# Speichern in einer Textdatei
speichere_gesamt_ergebnisse("TextClassaLaufende.txt", gesamt_ergebnisse)

# Löschen der erstellten CSV-Dateien
for ch in chisch:
    try:
        os.remove(f"text_{ch}.csv")  # Löschen der CSV-Datei
    except FileNotFoundError:
        print(f"Datei text_{ch}.csv wurde nicht gefunden und konnte nicht gelöscht werden.")
    except Exception as e:
        print(f"Fehler beim Löschen der Datei text_{ch}.csv: {e}")
# Out:
# Anzahl der chisch-Werte mit Ergebnissen: 372
# Anzahl der chisch-Werte ohne Ergebnisse: 735
#
#
# cc_agx_rus_54
# -----------------
#
# -----------------
#
#
# cc_agx_rus_55
# -----------------
#
# -----------------
#
#
# cc_agx_rus_56ß
# -----------------
# a654 Die behenden Brüder
# -----------------
# a654:F:SELTENEN_Gegenstand_besorgen:rHP
# a654:H:Fernseher_als_ZAUBERMITTEL_erhalten:rHD
# a654:H:WAFFE_ZAUBERMITTEL_erhalten:rHD
# a654:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD
# a654:F:Um_eine_Frau_werben:rHD_rHP
# a654:F:Eine_ENTFÜHRUNG_beheben:N
# a654:F:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD
# a654:H:VORHERSAGE_des_Aufenthaltsortes:rHD
# a654:F:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:N
# a654:H:Komplikationsfreier_Flug:N
# a654:H:Eine_ENTFÜHRUNG_beheben:N
# a654:F:Dilemma_lösen:N
#
#
# cc_agx_rus_57
# -----------------
#
# -----------------
#
#
# cc_ani_rus_10
# -----------------
#
# -----------------
#
#
# cc_ani_rus_11
# -----------------
# anh384 Мупла Насреддин и дети
# -----------------
# anh384:#:#:#
# anh384:#:#:#
#
#
# cc_ani_rus_12ß
# -----------------
# a654 Die behenden Brüder
# -----------------
# a654:F:Eine_Heiratsabsicht_kundtun:rHD_rHH
# a654:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rHH_rZM
# a654:H:Elixier_als_ZAUBERMITTEL_erhalten:rHD_rHH_rZM
# a654:H:Fernseher_als_ZAUBERMITTEL_erhalten:rHD_rHH_rZM
# a654:F:Streit_schlichten:rHD_rST
# a654:H:Streit_schlichten:rHD_rST
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM
# a654:F:WIEDERBELEBEN:rHD_rZM
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM
# a654:H:Komplikationsfreier_Flug:rHD_rZM
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rPP
# a654:H:WIEDERBELEBEN:rHD_rZM_rPP
# a654:F:Dilemma_lösen:rHD
# a654:F:Dilemma_lösen:rHD_fST
# a654:h:Dilemma_lösen:rHD_fST
#
#
# cc_ani_rus_13
# -----------------
#
# -----------------
#
#
# cc_ani_rus_14
# -----------------
#
# -----------------
#
#
# cc_ani_rus_15
# -----------------
#
# -----------------
#
#
# cc_ani_rus_16
# -----------------
# a1592B Topf hat ein Kind
# -----------------
# a1592B:f:#:zs_zt
# a1592B:h:#:zs_zt
# a1592B:f:#:zs_zt
# a1592B:h:#:zs_zt
# a1592B:f:#:zs_zt
# a1592B:h:#:zs_zt
#
#
# cc_ani_rus_17
# -----------------
#
# -----------------
#
#
# cc_ani_rus_8
# -----------------
# anh395 Эта мера — одна треть мана
# -----------------
# anh395:f:#:zs
# anh395:h:#:zsa
# anh395:f:#:zs_zt
# anh395:h:#:zs_zt
#
#
# cc_ani_rus_9
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_19
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_20
# -----------------
# a1592B Topf hat ein Kind
# -----------------
# a1592B:#:#:#
# a1592B:#:#:#
#
#
# cc_aqc_rus_21
# -----------------
# anh577 Возьми и себе
# -----------------
# anh577:#:#:#
# anh577:#:#:#
# anh577:#:#:#
#
#
# cc_aqc_rus_22
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_23
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_24
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_25
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_26
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_27
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_28
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_29
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_30
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_31
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_32
# -----------------
#
# -----------------
#
#
# cc_aqc_rus_33
# -----------------
#
# -----------------
#
#
# cc_ava_ava_204
# -----------------
#
# -----------------
#
#
# cc_ava_ava_205
# -----------------
#
# -----------------
#
#
# cc_ava_ava_206
# -----------------
#
# -----------------
#
#
# cc_ava_ava_207
# -----------------
#
# -----------------
#
#
# cc_ava_ava_208
# -----------------
#
# -----------------
#
#
# cc_ava_ava_209
# -----------------
#
# -----------------
#
#
# cc_ava_ava_210
# -----------------
#
# -----------------
#
#
# cc_ava_ava_211
# -----------------
#
# -----------------
#
#
# cc_ava_ava_212
# -----------------
#
# -----------------
#
#
# cc_ava_ava_213
# -----------------
#
# -----------------
#
#
# cc_ava_ava_214
# -----------------
#
# -----------------
#
#
# cc_ava_deu_204
# -----------------
#
# -----------------
#
#
# cc_ava_deu_205
# -----------------
#
# -----------------
#
#
# cc_ava_deu_206
# -----------------
#
# -----------------
#
#
# cc_ava_deu_207
# -----------------
#
# -----------------
#
#
# cc_ava_deu_208
# -----------------
#
# -----------------
#
#
# cc_ava_deu_209
# -----------------
#
# -----------------
#
#
# cc_ava_deu_210
# -----------------
#
# -----------------
#
#
# cc_ava_deu_211
# -----------------
#
# -----------------
#
#
# cc_ava_deu_212
# -----------------
#
# -----------------
#
#
# cc_ava_deu_213
# -----------------
#
# -----------------
#
#
# cc_ava_rus_214
# -----------------
# anh789 Первый инжир
# -----------------
# anh789:f:#:zs_zt
# anh789:h:#:zs
# anh789:f:#:zs_zt
# anh789:h:#:zs_zt
#
#
# cc_ddo_ddo_95
# -----------------
#
# -----------------
#
#
# cc_ddo_ddo_96
# -----------------
#
# -----------------
#
#
# cc_ddo_ddo_97
# -----------------
#
# -----------------
#
#
# cc_ddo_ddo_98
# -----------------
#
# -----------------
#
#
# cc_ddo_ddo_99
# -----------------
#
# -----------------
#
#
# cc_ddo_kat_95
# -----------------
# a313 Magische Flucht
# a327 Die Kinder und der Unhold
# -----------------
# a327:h:KONTAKT_abbrechen:rHD_rHH
# a327:HF:MISSETAT_beheben:rHD_rST
# a327:H:FLUCHT_vorbereiten:rHD_rST
# a313:Hh:FLUCHT:rHD_rZM_rAN
# a313:h:VERFOLGUNG:rHD_rZM_rAN
# a313:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a313:H:VERFOLGUNG_entkommen:rHD_rZM_rAN
# a313:Hh:FLUCHT:rHD_rAN
# a313:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rAN
# a313:H:VERFOLGUNG_entkommen:rHD_rAN
# a313:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_rAN
# a313:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN
# a327:H:KONTAKT_wiederherstellen:rHD_rHH
#
#
# cc_ddo_kat_96
# -----------------
#
# -----------------
#
#
# cc_ddo_kat_97
# -----------------
#
# -----------------
#
#
# cc_ddo_kat_98
# -----------------
#
# -----------------
#
#
# cc_ddo_kat_99
# -----------------
#
# -----------------
#
#
# cc_ddo_rus_95
# -----------------
#
# -----------------
#
#
# cc_ddo_rus_98
# -----------------
#
# -----------------
#
#
# cc_ddo_rus_99
# -----------------
#
# -----------------
#
#
# cc_huz_huz_1
# -----------------
#
# -----------------
#
#
# cc_huz_huz_2
# -----------------
#
# -----------------
#
#
# cc_huz_rus_1
# -----------------
#
# -----------------
#
#
# cc_huz_rus_2
# -----------------
#
# -----------------
#
#
# cc_kap_kap_1
# -----------------
#
# -----------------
#
#
# cc_kap_kap_2
# -----------------
#
# -----------------
#
#
# cc_kap_kat_1
# -----------------
#
# -----------------
#
#
# cc_kap_rus_1
# -----------------
#
# -----------------
#
#
# cc_kap_rus_2
# -----------------
#
# -----------------
#
#
# cc_sva_kat_1
# -----------------
#
# -----------------
#
#
# cc_sva_sva_1
# -----------------
#
# -----------------
#
#
# cc_tab_rus_45
# -----------------
#
# -----------------
#
#
# cc_tab_rus_46
# -----------------
#
# -----------------
#
#
# cc_tab_rus_47
# -----------------
#
# -----------------
#
#
# cc_tab_rus_48
# -----------------
#
# -----------------
#
#
# cc_tab_rus_49
# -----------------
#
# -----------------
#
#
# cc_tab_rus_50
# -----------------
#
# -----------------
#
#
# cc_xmf_kat_1
# -----------------
#
# -----------------
#
#
# cc_xmf_kat_2
# -----------------
#
# -----------------
#
#
# cc_xmf_kat_3
# -----------------
#
# -----------------
#
#
# cc_xmf_kat_4
# -----------------
# a514 Geschlechtswechsel
# -----------------
# a514:h:Fehlende_männliche_oder_weibliche_NACHKOMMEN:rHH
# a514:F:Um_einen_Auftrag_werben:rHH_fHD
# a514:H:IDENTITÄT_ändern:rHH_fHD
# a514:F:IDENTITÄT_beweisen:rHH_fHD
# a514:h:IDENTITÄT_beweisen:rHH_fHD
# a514:h:Den_Vorgang_deuten:rHH_fHD
# a514:F:Um_einen_Auftrag_werben:rHH_fHD
# a514:h:IDENTITÄT_beweisen:rHH_fHD
# a514:F:Um_einen_Auftrag_werben:rHD_rHH
# a514:F:IDENTITÄT_beweisen:rHD_rHH
# a514:H:IDENTITÄT_beweisen:rHD_rHH
# a514:HF:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rHH
# a514:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rHP
# a514:F:IDENTITÄT_beweisen:rHD_rHP
# a514:h:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP
# a514:F:Liebe_wird_ausgelöst:rHD_rPP
# a514:HF:Richtiges_erlangen:rHD_rPP
# a514:H:Richtiges_erlangen:rHD_rHP
# a514:HF:REITTIER_erfassen:rHD_rHF_rPP
# a514:H:REITTIER_erfassen:rHD_rHF_rPP
# a514:HF:IDENTITÄT_beweisen:rHD_rHF_rPP
# a514:h:VERTRAG_abschließen_oder_verkünden:rHD_fHP
# a514:f:Zu_Beauftragungen_anregen:fHP_fPP
# a514:hf:TIERKÖRPERTEIL_besorgen:fHP_fPP
# a514:f:TIERKÖRPERTEIL_besorgen:rHD_fHP
# a514:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a514:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a514:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_fHP
# a514:HF:TIERKÖRPERTEIL_erfassen:rHD_rHF
# a514:H:TIERKÖRPERTEIL_erfassen:rHD_rHF
# a514:H:TIERKÖRPERTEIL_besorgen:rHD_fPP
# a514:f:Zu_Beauftragungen_anregen:fHP_fPP
# a514:hf:MUSIKINSTRUMENT_besorgen:fHP_fPP
# a514:f:MUSIKINSTRUMENT_besorgen:rHD_fHP
# a514:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a514:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a514:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_fHP
# a514:F:Eine_Bedrohung_VORTÄUSCHEN:rHD_rHF_rBZ
# a514:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_rBZ
# a514:H:MUSIKINSTRUMENT_erfassen:rHD_rHF_rBZ
# a514:H:MUSIKINSTRUMENT_besorgen:rHD_rZO_rPP
# a514:f:Zu_Beauftragungen_anregen:fHP_fPP
# a514:hf:GEHEIMNIS_AUFKLÄREN:fHP_fPP
# a514:f:GEHEIMNIS_AUFKLÄREN:rHD_fHP
# a514:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a514:HF:Zuschnappendes_Hindernis_überwinden:rHD_rHF
# a514:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a514:Hh:Zuschnappendes_Hindernis_überwinden:rHD_rHF
# a514:HF:Angebot_GEOPFERT_ZU_WERDEN:rHD_rHF
# a514:F:VERSTEINERUNG_beheben:rHD_rRE
# a514:H:ERZÄHLEN_beginnen:rHD_rRE
# a514:h:VERLUST_von_Tieren_Früchten_Ernte_usw:rRE
# a514:H:IDENTITÄT_ändern:rRE
# a514:H:Heimlich_beobachten:rRE_rAN
# a514:h:GEHEIME_LIEBESBEZIEHUNG:rRE_rAN
# a514:h:Der_Wechsel_der_IDENTITÄT_eingestehen:rRE_rAN
# a514:h:VERSTEINERUNG:rRE_rAN
# a514:H:ERZÄHLEN_beenden:rRE_rAN
# a514:H:Verstecken_als_Rettung:rHD_rRE_rAN
# a514:H:Wiedergutmachung_erpressen:rHD_rRE_rAN
# a514:H:VERSTEINERUNG_beheben:rHD_rRE_rAN
# a514:H:Geschlechtsumwandlung_erzielen:rHD_rRE_rAN
# a514:H:Bestrafung:rHD_rRE_rAN
# a514:F:Angebot_KÖNIG_ZU_WERDEN:rHD_rRE
# a514:h:KONTAKT_abbrechen:rHD_rRE
# a514:H:KONTAKT_wiederherstellen:rHD_rPP
# a514:H:Heiraten:rHD_rPP
# a514:H:GEHEIMNIS_AUFKLÄREN:rHD_fHP
# a514:F:Angebot_KÖNIG_ZU_WERDEN:rHD_fHP
# a514:h:Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen:rHD_fHP
# a514:H:KONTAKT_wiederherstellen:rHD_rRE
# a514:H:Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen:rHD_rRE
#
#
# cc_xmf_kat_5
# -----------------
#
# -----------------
#
#
# cc_xmf_xmf_1
# -----------------
#
# -----------------
#
#
# cc_xmf_xmf_2
# -----------------
#
# -----------------
#
#
# cc_xmf_xmf_3
# -----------------
#
# -----------------
#
#
# cc_xmf_xmf_4
# -----------------
#
# -----------------
#
#
# cc_xmf_xmf_5
# -----------------
#
# -----------------
#
#
# zyx_cc_agx_rus_35ß
# -----------------
# a1543 Keinen Pfennig weniger
# -----------------
# a1543:F:PROVOKATION:zs
# a1543:H:Der_PROVOKATION_nachgehen:zt
# a1543:H:Eine_numinose_Einmischung_VORTÄUSCHEN:zt
# a1543:H:Dem_VORTÄUSCHEN_nachgehen:zs_zt
# a1543:H:Behauptung_der_ABSURDITÄT:zs_zt
# a1543:f:Den_Vorgang_deuten:zs_zt
# a1543:h:Das_VORTÄUSCHEN_eingestehen:zs_zt
# a1543:f:Gerechte_Rückgabe_fordern:zs_zt
# a1543:H:Eine_löst_andere_ABSURDITÄT_aus:zs_zt
# a1543:F:Streit_schlichten:zs_zt_zv
# a1543:h:Den_Vorgang_deuten:zs_zt_zv
# a1543:H:ABSURDITÄT_glaubhaft_zu_halten_VORTÄUSCHEN:zs_zt_zv
# a1543:H:Behauptung_der_ABSURDITÄT:zs_zt_zv
# a1543:H:Beglaubigen_der_Behauptung_der_ABSURDITÄT:zs_zt_zv
#
#
# zyx_cc_agx_rus_36ß
# -----------------
# anh531 При дневном свете не знаешь дороги
# -----------------
# anh531:F:Sonstiges_verkaufen:zs_zt
# anh531:h:Handeln_als_ABSURDITÄT:zs
# anh531:h:Sachschaden_anrichten:zs
# anh531:H:Schlußfolgerung_als_ABSURDITÄT:zs
# anh531:f:Den_Vorgang_deuten:zs_zsa
# anh531:H:ABSURDITÄT_glaubhaft_zu_halten_VORTÄUSCHEN:zs_zsa
#
#
# zyx_cc_ddo_rus_13
# -----------------
# a516 Der treue Johannes
# aU ATU Typ: unklar welcher
# -----------------
# aU:h:VERTREIBUNG:rHH_fHH
# aU:H:Notwendiges_auf_wunderbare_Weise_besorgen:rHD_rHH
# aU:H:Goldhaariges_Kind_zur_Welt_bringen:rHD_rHH
# a516:h:Die_FERNLIEBE_wird_ausgelöst:N
# a516:F:Auf_Hilfsquelle_zurückgreifen:rHF_rHP
# a516:F:Krisenursachen_ergründen:rHF_rHP
# a516:H:Gespräche_belauschen:rHF_rPP
# a516:H:Enthüllung_der_Wahrheit_durch_das_subtile_Mittel:rHF_rPP
# a516:H:Krisenursachen_ergründen:rHF_rPP
# a516:H:Den_Vorgang_deuten:rHF_rHP
# aU:F:Um_eine_Frau_werben:rHH_rHP
# aU:H:FERNLIEBE_beheben:rHH_rHP
# aU:H:Heiraten:N
#
#
# zyx_cc_ddo_rus_15ß
# -----------------
# a976 Die vornehmste Handlung
# a655 Die scharfsinnigen Brüder
# -----------------
# a655:F:Die_Erbschaft_teilen:zs_zsa
# a655:h:Tod_von_Angehörigen:zs_zsa
# a655:h:VERLUST des Schatzes:zs
# a655:F:VERLUSTursache_beheben:zs
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs
# a655:h:VERLUST_von_Tieren_Früchten_Ernte_usw:zs_zt
# a655:F:VORHERSAGE_erforderlich:zs_zt
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zt
# a655:h:Der_VORHERSAGE_nachgehen:zs_zt
# a655:F:VERLUSTursache_beheben:zs_zt
# a655:F:EINLADUNG:zv_zva
# a655:F:Gespräche_belauschen:zv_zva
# a655:hf:VORHERSAGE_subtiles_Geschmak:zs_zva
# a655:HF:VORHERSAGE_subtile_Identität:zs_zva
# a655:HF:Information_aus_zweiter_Hand:zv_zva
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zv_zva
# a655:HF:VORHERSAGE_subtile_Identität:zv_zva
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zv_zva
# a655:HF:VORHERSAGE_subtiles_Geschmak:zv_zva
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zv_zva
# a655:HF:VORHERSAGE_subtiles_Geschmak:zv_zva
# a655:F:Streit_schlichten:zt_zv
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:H:Streit_schlichten:zt_zv
# a655:H:VERLUSTursache_beheben:zt_zv
# a976:F:VORHERSAGE_erforderlich:zs_zv
# a976:F:VERLUSTursache_beheben:zs_zv
# a976:F:Rätsel_lösen:zs_zv
# a976:F:ERZÄHLEN_beginnen:zs_zv
# a655:H:ERZÄHLEN_beenden:zs_zv
# a655:Hh:Rätsel_lösen:zs_zv
# a655:H:VERLUSTursache_beheben:zs_zv
# a655:H:Streit_schlichten:zs_zv
#
#
# zyx_cc_ddo_rus_18ß
# -----------------
# a545B Der gestiefelte Kater
# -----------------
# a545B:F:VERTRAG_abschließen_oder_verkünden:rHD_rHF
# a545B:F:GEGENLEISTUNG_für_die_LEISTUNG:rHD_rHF
# a545B:F:Um_eine_Frau_werben:rHF_rHP
# a545B:HF:Information_aus_zweiter_Hand:rHF_rHP
# a545B:F:EINLADUNG:rHF_rHP
# a545B:Hh:Einer_EINLADUNG_nachgehen:rHD_rHF
# a545B:F:Verlust_VORTÄUSCHEN:rHD_rHF
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP
# a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHF_rHP
# a545B:H:REITTIER_erhalten:rHF_rHP
# a545B:H:Heiraten:rHD_rHF
#
#
# zyx_cc_ddo_rus_26ß
# -----------------
# a982 Die vorgetäuschte Erbschaft
# a301 Die drei geraubten Prinzesinnen
# a300 Der Drachentöter
# -----------------
# a982:f:Reiche_Erbschaft_VORTÄUSCHEN:rHH
# a982:h:Tod_von_Angehörigen:rHH
# a982:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fHD
# a982:F:Erträumen:rHD_rHH_fHD
# a982:F:Wache_halten:rHD_rHH_fHD
# a982:Hh:Wache_halten:fHD
# a982:H:Wache_halten:rHD_rST
# a982:H:Wegweisung_erpressen:rHD_rST
# a982:Hh:Wache_halten:rHD_rST
# a982:H:Wegweisung_erpressen:rHD_rST
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Zweikampf:rHD_rAN
# a300:f:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_rAN
# a300:f:VERGIFTUNG:rHD_rAN
# a300:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fZM
# a300:H:VERGIFTUNG_beheben:rHD_fZM
# a300:H:Menschliche_OPFERGABE_beheben:rHD_rPP
# a300:h:KONTAKT_abbrechen:rHD_rPP
# a300:F:NEUGIER_ausgelöst:rVB_rHP
# a300:HF:Information_aus_zweiter_Hand:rVB_rHP
# a300:H:Der_NEUGIER_nachgehen:rVB_rHP
# a300:F:EINLADUNG:rVB_rHP
# a300:f:Heldentat_VORTÄUSCHEN:rHD_rHP_fHD
# a300:H:Einer_EINLADUNG_nachgehen:rHD_rHP_fHD
# a300:F:IDENTITÄT_beweisen:rHD_rHP_fHD
# a300:H:IDENTITÄT_beweisen:rHD_rHP_fHD
# a300:H:KONTAKT_wiederherstellen:rHD_rHP_fHD
# a300:F:Heiraten:rHD_rHP
# a300:h:Heiraten:rHD_rHP
# a300:H:Um_GEGENLEISTUNG_bitten:rHD_rHP
# a300:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rHP
# a300:h:Den_ALTERNATIVEN_nachgehen:rHD_rZM
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:MASSENBEDROHUNG_beheben:rHD_rVB
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Sorge_um_Schutzbedürftige:rHD_rST
# a300:F:Angebot_KÖNIG_ZU_WERDEN:rHD_rHP
# a300:h:Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen:rHD_rHP
# a300:F:Um_GEGENLEISTUNG_bitten:rHD_rHP
# a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP
# a300:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a300:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHP
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a300:H:Sorge_um_Mitleidsbedürftige:rHD_rHF
# a300:H:Eine_BEHINDERUNG_beheben:rHD_rHF
# a301:H:Krisenursachen_ergründen:rHD_rPP
# a301:F:Eine_ENTFÜHRUNG_beheben:rHD_rPP
# a301:HF:ABRATEN_von_der_Mission:rHD_rPP
# a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a301:H:Mut_zeigen:rHD_rAN
# a301:HF:Zweikampf:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:H:Auf_dem_Heimweg:N
# a301:F:Angebot_KÖNIG_ZU_WERDEN:N
# a301:h:Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen:N
#
#
# zyx_cc_ddo_rus_33ß
# -----------------
# a56A Fuchs und Vogeljunge
# -----------------
# a56A:#:#:#
# a56A:#:#:#
# a56A:#:#:#
# a56A:#:#:#
#
#
# zyx_cc_ddo_rus_34ß
# -----------------
# a313 Magische Flucht
# a327 Die Kinder und der Unhold
# -----------------
# a327:h:KONTAKT_abbrechen:rHD_rHH
# a327:H:AUSRÜSTUNG_als_ZAUBERMITTEL_erhalten:rHD_rHH
# a327:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD
# a327:Hh:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD
# a327:HF:KANNIBALISMUS_beheben:rHD_rST
# a327:HF:FLUCHT_vorbereiten:rHD_rST
# a313:H:FLUCHT:rHD_rAN
# a313:h:VERFOLGUNG:rHD_rAN
# a313:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rAN
# a313:H:VERFOLGUNG_entkommen:rHD_rAN
# a313:H:KANNIBALISMUS_beheben:rHD_rAN
# a327:H:KONTAKT_wiederherstellen:rHD_rHH
#
#
# zyx_cc_ddo_rus_47ß
# -----------------
# a327B Daeumling und Menschenfresser
# a328 Corvetto
# -----------------
# a327B:f:VERTRAG_abschließen_oder_verkünden:rHD_rAN
# a327B:f:Gastfreundlichkeit_VORTÄUSCHEN:rHD_rAN
# a327B:f:VERTRAG_abschließen_oder_verkünden:rHD_rAN
# a327B:F:Um_eine_Frau_werben:rHD_rAN
# a327B:F:Auf_dem_VERTRAG_bestehen:rHD_rAN
# a327B:f:KANNIBALISMUS:N
# a327B:F:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:N
# a327B:h:MISSETAT_wie_Kannibalismus:rHD_rAN
# a327B:F:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN
# a327B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN
# a327B:F:IDENTITÄT_ändern:rHD
# a327B:F:Schlaf_VORTÄUSCHEN:rHD_rAN
# a327B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN
# a327B:H:Personenschaden_anrichten:rHD_rAN
# a327B:f:Auftrag_zum_Kochen:rHD_rAN
# a327B:H:Auftrag_zum_Kochen:rHD_rAN
# a327B:H:Jemanden_in_Kannibalismus_verwickeln:rHD_rAN
# a327B:Hh:FLUCHT:rHD_fHD
# a328:F:Um_eine_Frau_werben:rHD_rHP
# a328:h:VERTRAG_abschließen_oder_verkünden:rHD_rHP
# a328:f:SELTENEN_Gegenstand_besorgen:rHD_rHP
# a328:H:IDENTITÄT_ändern:rHD
# a328:F:Rebellion_des_Zielobjektes_VORTÄUSCHEN:rHD_rZO_rAN
# a328:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rZO_rAN
# a328:H:SELTENEN_Gegenstand_erfassen:rHD_rZO_rAN
# a328:H:SELTENEN_Gegenstand_besorgen:rHD_rHP
# a328:f:NUTZTIER_besorgen:rHD_rHP
# a328:F:Rebellion_des_Zielobjektes_VORTÄUSCHEN:rHD_rZO_rAN
# a328:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rZO_rAN
# a328:H:NUTZTIER_erfassen:rHD_rZO_rAN
# a328:H:NUTZTIER_besorgen:rHD_rHP
# a328:f:UNGEHEUER_herbeiholen:rHD_rHP
# a328:H:IDENTITÄT_ändern:rHD
# a328:H:Geänderte_IDENTITÄT_VORTÄUSCHEN:rHD_rBZ
# a328:F:Truhe_herstellen:rHD_rBZ
# a328:F:Testnotwendigkeit_VORTÄUSCHEN:rHD_rBZ
# a328:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rBZ
# a328:H:UNGEHEUER_erfassen:rHD_rBZ
# a328:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rBZ
# a328:H:UNGEHEUER_herbeiholen:rHD_rBZ_rHP
# a328:h:VERSCHLINGEN:rHD_rBZ_rHP
# a328:h:VERFOLGUNG:rHD_rBZ
# a328:H:TÖTUNG:rHD_rBZ
# a328:H:VERFOLGUNG_entkommen:rHD_rBZ
# a328:H:VERSCHLINGEN_beheben:rHD_rHP_rPP
# a328:H:Heiraten:rHD_rHP_rPP
#
#
# zyx_cc_ddo_rus_48ß
# -----------------
# a301 Die drei geraubten Prinzesinnen
# -----------------
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rAN_fHD
# a301:h:Der_PROVOKATION_nachgehen:rAN_fHD
# a301:h:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Den_Vorgang_deuten:rHD_fHD
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rAN_fHD
# a301:h:Der_PROVOKATION_nachgehen:rAN_fHD
# a301:h:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Den_Vorgang_deuten:rHD_fHD
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rHD_rAN
# a301:H:Der_PROVOKATION_nachgehen:rHD_rAN
# a301:H:Den_Vorgang_deuten:rHD_fVB
# a301:H:Wegweisung_erpressen:rHD_fVB
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:HF:ABRATEN_von_der_Mission:rHD_rPP
# a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a301:H:Eine_ENTFÜHRUNG_beheben:rHD_rAN
# a301:H:Heiraten:rHD_rAN
# a301:H:Ende:rHD_rAN
#
#
# zyx_cc_ddo_rus_49ß
# -----------------
# a327 Die Kinder und der Unhold
# a327B Daeumling und Menschenfresser
# -----------------
# a327B:h:VERLUST_von_Tieren_Früchten_Ernte_usw:rVB_rAN
# a327B:f:Gastfreundlichkeit_VORTÄUSCHEN:rHD_rAN_fHD
# a327B:Hh:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN_fHD
# a327B:f:KANNIBALISMUS:rHD_rAN_fHD
# a327B:F:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN
# a327B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN
# a327B:f:KANNIBALISMUS:rHD_rAN
# a327B:F:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN
# a327B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN
# a327B:F:IDENTITÄT_ändern:rHD_fHD
# a327B:H:Personenschaden_anrichten:rHD_rAN
# a327B:f:Auftrag_zum_Kochen:rHD
# a327B:H:Auftrag_zum_Kochen:rHD
# a327B:F:Jemanden_in_Kannibalismus_verwickeln:rHD_fHD
# a327B:H:FLUCHT:rHD_fHD
# a327B:h:VERFOLGUNG:rHD_fHD
# a327B:H:VERFOLGUNG_entkommen:rHD_fHD
# a327:F:SELTENEN_Gegenstand_besorgen:N
# a327:F:Rebellion_des_Zielobjektes_VORTÄUSCHEN:N
# a327:H:Dem_VORTÄUSCHEN_nachgehen:N
# a327:H:SELTENEN_Gegenstand_erfassen:N
# a327:H:FLUCHT:rHD_rAN
# a327:f:VERFOLGUNG:rHD_rAN
# a327:H:VERFOLGUNG_entkommen:rHD_rAN
# a327:F:UNGEHEUER_herbeiholen:rHD
# a327:H:IDENTITÄT_ändern:rHD
# a327:F:Geänderte_IDENTITÄT_VORTÄUSCHEN:rHD_rAN
# a327:F:Truhe_herstellen:rHD_rAN
# a327:F:Testnotwendigkeit_VORTÄUSCHEN:rHD_rAN
# a327:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN
# a327:H:UNGEHEUER_erfassen:rHD_rAN
# a327:H:UNGEHEUER_herbeiholen:rHD
# a327:H:TÖTUNG:rHD
# a327:H:VERLUSTursache_beheben:rVB
#
#
# zyx_cc_ddo_rus_4ß
# -----------------
# a301 Die drei geraubten Prinzesinnen
# -----------------
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rAN_fHD
# a301:h:Der_PROVOKATION_nachgehen:rAN_fHD
# a301:h:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Den_Vorgang_deuten:rHD_fHD
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rAN_fHD
# a301:h:Der_PROVOKATION_nachgehen:rAN_fHD
# a301:h:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Den_Vorgang_deuten:rHD_fHD
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:h:PROVOKATION:rHD_fVB
# a301:H:Der_PROVOKATION_nachgehen:rHD_fVB
# a301:H:Wegweisung_erpressen:rHD_rAN
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:HF:ABRATEN_von_der_Mission:rHD_rPP
# a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:H:Heiraten:rHD_rAN
# a301:H:Eine_ENTFÜHRUNG_beheben:rHD_rAN
# a301:H:Heiraten:rHD_rAN
# a301:H:Ende:rHD_rAN
#
#
# zyx_cc_ddo_rus_55ß
# -----------------
# a650A Starker Hans
# a300 Der Drachentöter
# -----------------
# a650A:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHH_fHH
# a650A:h:Eine_ENTFÜHRUNG:rHH_fHH
# a650A:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHH
# a650A:H:Zur_Welt_kommen:rHD_rHH
# a300:h:WASSERMANGEL:rAN
# a300:h:Eine_OPFERGABE_verlangen:rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
#
#
# zyx_cc_ddo_rus_59ß
# -----------------
# a537 Der Flug auf dem dankbaren Adler
# a327A Haensel und Gretel
# -----------------
# a537:F:Sorge_um_Pflegebedürftige:rHD_rHF
# a537:H:Sorge_um_Pflegebedürftige:rHD_rHF
# a537:F:GEGENLEISTUNG_für_die_LEISTUNG:rHD_rHF
# a537:H:Sorge_um_Pflegebedürftige:rHD_rHF
# a537:Hh:Angst_mit_Angst_vergelten:rHD_rHF
# a537:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHF
# a537:HF:Richtiges_erlangen:rHD_rHF
# a537:H:Vermittlung:rHF_rST
# a537:F:Richtiges_erlangen:rHD_rST
# a537:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST
# a537:hf:TABU_Behälter_nicht_öffnen:rHD_rST
# a537:h:TABU_nachgehen:rHD
# a537:F:Folgen_eines_TABUbruches_rückgängig_machen:rHD_fHF
# a537:Hh:VERSPRECHEN_im_Austausch_für_Hilfe:rHD_fHF
# a537:H:Folgen_eines_TABUbruches_rückgängig_machen:rHD_fHF
# a327A:f:Ein_VERSPRECHEN_halten:rHD_fHF
# a327A:F:Um_einen_Auftrag_werben:rHD_rHD
# a327A:h:KONTAKT_abbrechen:rHD_rHD
# a327A:HF:Unwissenheit_VORTÄUSCHEN:rHD_rST
# a327A:f:SONSTIGE_AUFGABE_erledigen:rHD_fHF
# a327A:F:Unwissenheit_VORTÄUSCHEN:rHD_fHF
# a327A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fHF
# a327A:H:TÖTUNG:rHD_fHF
# a537:H:KONTAKT_wiederherstellen:rHD_rHD
#
#
# zyx_cc_ddo_rus_5ß
# -----------------
# a976 Die vornehmste Handlung
# a655 Die scharfsinnigen Brüder
# -----------------
# a655:F:Die_Erbschaft_teilen:zs_zsa
# a655:h:Tod_von_Angehörigen:zs_zsa
# a655:h:VERLUST des Schatzes:zs
# a655:F:VERLUSTursache_beheben:zs
# a655:HF:VORHERSAGE_subtile_Eigenschaft:N
# a655:h:VERLUST_von_Tieren_Früchten_Ernte_usw:zs_zt
# a655:F:VORHERSAGE_erforderlich:zs_zt
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zt
# a655:h:Der_VORHERSAGE_nachgehen:zs_zt
# a655:F:VERLUSTursache_beheben:zs_zt
# a655:F:EINLADUNG:zva
# a655:H:Einer_EINLADUNG_nachgehen:zva
# a655:H:Gespräche_belauschen:zva
# a655:HF:VORHERSAGE_subtile_Identität:zs
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs
# a655:HF:VORHERSAGE_subtiles_Geschmak:N
# a655:HF:Information_aus_zweiter_Hand:zv_zva
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zv_zva
# a655:HF:VORHERSAGE_subtile_Identität:zv_zva
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zv_zva
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zv_zva
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zv_zva
# a655:HF:VORHERSAGE_subtiles_Geschmak:zv_zva
# a655:F:Streit_schlichten:zt_zv
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:H:Streit_schlichten:zt_zv
# a655:H:VERLUSTursache_beheben:zt_zv
# a976:F:VORHERSAGE_erforderlich:zs_zv
# a976:F:Streit_schlichten:zs_zv
# a976:F:Rätsel_lösen:zs_zv
# a976:F:ERZÄHLEN_beginnen:zs_zv
# a655:H:ERZÄHLEN_beenden:zs_zv
# a655:Hh:Rätsel_lösen:zs_zv
# a655:H:Streit_schlichten:zs_zv
# a655:H:VERLUSTursache_beheben:zs_zv
#
#
# zyx_cc_ddo_rus_60ß
# -----------------
# a303 Die zwei Brueder
# a327A Haensel und Gretel
# -----------------
# a303:h:Kinderlosigkeit:rHH
# a303:Hh:VERSPRECHEN_im_Austausch_für_Hilfe:rHH_rZM_fST
# a303:H:Magische_EMPFÄNGNISmittel_erhalten:rHH_rZM_fST
# a303:H:Zur_Welt_kommen:rHD
# a303:f:Ein_VERSPRECHEN_halten:rHH_fST
# a303:F:Um_einen_Auftrag_werben:rHD_rHH
# a303:h:KONTAKT_abbrechen:rHD_rHH
# a303:F:Um_einen_Auftrag_werben:rHD_rHH
# a303:h:KONTAKT_abbrechen:rHD_rHH
# a303:F:MARKIERUNGEN_anbringen:rHD_rHD
# a303:h:KONTAKT_abbrechen:rHD_rHD
# a327A:HF:Unwissenheit_VORTÄUSCHEN:rHD_rST
# a327A:Hh:Unterkommen:N
# a327A:H:Unwissenheit_VORTÄUSCHEN:N
# a327A:H:Dem_VORTÄUSCHEN_nachgehen:N
# a327A:H:TÖTUNG:N
# a303:H:Die_SCHÖNE_erfassen:rHD_rPP
# a303:H:Krisenursachen_ergründen:rHD_rPP
# a303:H:KONTAKT_abbrechen:rHD_rPP
# a303:F:MARKIERUNGEN_anbringen:rHD_rPP
# a303:f:WETTKAMPF:rHD_rAN
# a303:h:WETTKAMPF:rHD_rAN
# a303:h:VERSCHLINGEN:rHD_rAN
# a303:H:MARKIERUNGEN_erkennen:rHD_rHD
# a303:H:Wegweisung_erhalten:rHD_rPP
# a303:f:WETTKAMPF:rHD_rAN
# a303:H:WETTKAMPF:rHD_rAN
# a303:H:VERSCHLINGEN_beheben:rHD_rHD_rAN
# a303:H:Ende:N
#
#
# zyx_cc_ddo_rus_61ß
# -----------------
# a545B Der gestiefelte Kater
# -----------------
# a545B:H:Hilfeversprechen_erhalten:rHD_rHF
# a545B:F:Verlust_VORTÄUSCHEN:rHD_rHF
# a545B:F:Um_eine_Frau_werben:rHD_rHF
# a545B:F:Auftrag_zum_VOTÄUSCHEN:rHF_fST
# a545B:H:TÖTUNG:rHF_fST
# a545B:H:Fremdes_Gut_einziehen:rHF_fST
# a545B:H:Heiraten:rHF_fST
# a545B:F:VERTRAG_abschließen_oder_verkünden:rHD_rHF
# a545B:F:GEGENLEISTUNG_für_die_LEISTUNG:rHD_rHF
# a545B:f:Vertrauen_beweisen:rHD_rHF
# a545B:f:Tod_VORTÄUSCHEN:rHD_rHF
# a545B:h:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF
# a545B:h:Vertrauen_beweisen:rHD_rHF
# a545B:H:Das_VORTÄUSCHEN_eingestehen:rHF_rPP
# a545B:f:Eine_Enttäuschung_ausgelöst:rHF_rPP
# a545B:h:Wiedergutmachung_erpressen:rHD_rHF
# a545B:h:Auf_dem_VERTRAG_bestehen:rHD_rHF
# a545B:H:GEGENLEISTUNG_für_die_LEISTUNG:rHD_rHF
# a545B:f:Vertrauen_beweisen:rHD_rHF
# a545B:f:Tod_VORTÄUSCHEN:rHD_rHF
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF
# a545B:H:VERTRAGsbedingungen_erfüllen:rHD_rHF
#
#
# zyx_cc_ddo_rus_72ß
# -----------------
# a550 Vogel Pferd und Koenigstochter
# a530 Prinzessin auf dem Glasberg
# a300 Der Drachentöter
# -----------------
# a530:F:Wache_halten:rHH
# a530:h:Tod_von_Angehörigen:rHH
# a530:h:Wache_halten:fHD
# a530:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a530:F:Reitkünste_zeigen:rHP
# a530:h:Reitkünste_zeigen:fHD
# a530:h:RESPEKTLOSIGKEIT:rHD_fHD
# a530:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a530:H:REITTIER_erhalten:rHD_rHF
# a530:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Reitkünste_zeigen:rHD_rHF
# a530:H:Die_SCHÖNE_erfassen:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:F:NEUGIER_ausgelöst:rHD_fHD
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Reitkünste_zeigen:rHD_rHF
# a530:H:Die_SCHÖNE_erfassen:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:F:NEUGIER_ausgelöst:rHD_fHD
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Reitkünste_zeigen:rHD_rHF
# a530:H:Die_SCHÖNE_erfassen:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Den_Vorgang_deuten:rHD_fHD
# a530:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_fHD
# a530:Hh:Beuteteilen:rHD_fHD
# a550:f:MISSETAT_planen:rHD_fHD
# a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:h:Zweikampf:rHD_rAN
# a300:h:VERSCHLINGEN:rHD_rAN
# a300:H:VERSCHLINGEN_beheben:rHD_rAN
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
# a300:H:NEUGIER_ausgelöst:rVB
# a300:HF:Information_aus_zweiter_Hand:rVB
# a300:F:EINLADUNG:rHD_rVB
# a300:H:Einer_EINLADUNG_nachgehen:rHD_rVB
# a300:F:Um_GEGENLEISTUNG_bitten:rHD_rVB
# a300:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rHF
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a530:H:Ende:rHD_rVB
#
#
# zyx_cc_ddo_rus_76ß
# -----------------
# a516 Der treue Johannes
# a312D Erbsensohn
# a563 Tischleindeckdich
# -----------------
# a312D:h:VERLOCKUNG:rRE_rAN
# a312D:h:Der_VERLOCKUNG_nachgehen:rRE_rAN
# a312D:h:FREIHEITSBERAUBUNG:rRE_rAN
# a312D:H:Zur_Welt_kommen:rHD
# a312D:F:PROVOKATION:rHD_rVB
# a312D:H:Der_PROVOKATION_nachgehen:rHD_rVB
# a312D:F:NEUGIER_ausgelöst:rHD_rVB
# a312D:H:Der_NEUGIER_nachgehen:rHD_rHH
# a312D:H:Krisenursachen_ergründen:rHD_rHH
# a312D:F:FREIHEITSBERAUBUNG_beheben:rHD_rHH
# a563:h:SCHLAF:rHD_rST
# a563:H:SCHLAF_unterbrechen:rHD_rST
# a563:H:PROVIANTPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST
# a312D:F:Ungewollte_Verlobung_akzeptieren:rHD_rST
# a312D:H:Ungewollte_Verlobung_akzeptieren:rHD_rST
# a312D:HF:Richtiges_erlangen:rHD_rHF
# a312D:hf:TABU_Türe_nicht_öffnen_dürfen:rHD_rST
# a516:HF:Richtiges_erlangen:rHD_rHF
# a516:F:Richtiges_erlangen:rHD_rST
# a516:h:TABU_nachgehen:rHD_rST
# a516:h:Die_FERNLIEBE_wird_ausgelöst:rHD_rPP
# a516:F:Richtiges_erlangen:rHD_rST
# a516:H:TREUEN_HELFER_erhalten:rHD_rHF
# a516:H:Die_Änderung_der_EXISTENZFORM:rHD_rHF
# a516:H:REITTIER_erhalten:rHD_rHF
# a516:HF:SELTENEN_Gegenstand_erfassen:rHD_rHF
# a516:H:SELTENEN_Gegenstand_erfassen:rHD_rHF
# a516:F:Um_eine_Frau_werben:rHD_rHP
# a516:F:VERTRAG_abschließen_oder_verkünden:rHD_rHP
# a516:F:Gegen_ein_Tier_kämpfen:rHD_rHP
# a516:HF:Gegen_ein_Tier_kämpfen:rHD_rHF
# a516:H:Gegen_ein_Tier_kämpfen:rHF_fHF
# a516:F:Tiere_gegeneinander_kämpfen_lassen:rHD_rHP
# a516:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a516:HF:Tiere_gegeneinander_kämpfen_lassen:rHD_rHF
# a516:H:Tiere_gegeneinander_kämpfen_lassen:rHF_fHF
# a516:F:WETTLAUF:rHD_rHP
# a516:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a516:HF:WETTKAMPF:rHD_rHF
# a516:H:WETTKAMPF:rHD_fHF
# a516:H:VERTRAGsbedingungen_erfüllen:rHD_rHP
# a516:H:Heiraten:rHD_rHP
#
#
# zyx_cc_ddo_rus_77
# -----------------
#
# -----------------
#
#
# zyx_cc_ddo_rus_87ß
# -----------------
# a531 Sohn des Jaegers/Ferdinand der treue...
# a329 Versteckwette
# -----------------
# a531:hf:TABU_Tier_nicht_töten:rHD_rHH
# a531:h:TABU_nachgehen:rHD_rZM
# a531:Ff:VOGEL_erfassen:rHD_rZM
# a531:f:NEUGIER_ausgelöst:rHD_rVB
# a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHH
# a531:f:Zu_Beauftragungen_anregen:rVB_rAN
# a531:hf:VOGEL_herbeiholen:rVB_rAN
# a531:f:VOGEL_herbeiholen:rHD_rVB
# a531:HF:Information_aus_zweiter_Hand:rHD_rVB
# a531:Hh:VOGEL_herbeiholen:rHD_rZO_rAN
# a531:f:Zu_Beauftragungen_anregen:rVB_rAN
# a531:hf:VOGEL_herbeiholen:rVB_rAN
# a531:f:VOGEL_herbeiholen:rHD_rVB
# a531:HF:Information_aus_zweiter_Hand:rHD_rVB
# a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHH
# a531:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH
# a531:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rAN
# a531:F:Auf_Hilfsquelle_zurückgreifen:N
# a531:HF:VOGEL_erfassen:N
# a531:H:VOGEL_erfassen:rHD_rZO_rAN
# a531:H:VOGEL_herbeiholen:rHD_rZO_rAN
# a531:f:Zu_Beauftragungen_anregen:rVB_rAN
# a531:hf:Die_SCHÖNE_herbeiholen:rVB_rAN
# a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN
# a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHH
# a531:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH
# a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHH
# a531:HF:Stifter_oder_Helfer_gewinnen:rHD_rHH
# a329:F:Sorge_um_Hilfsbedürftige:rHD_rHF
# a329:H:Sorge_um_Hilfsbedürftige:rHD_rHF
# a329:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a329:F:Sorge_um_Hilfsbedürftige:rHD_rHF
# a329:H:Sorge_um_Hilfsbedürftige:rHD_rHF
# a329:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a329:F:Sorge_um_Freikaufsbedürftige:rHD_rHF
# a329:H:Sorge_um_Freikaufsbedürftige:rHD_rHF
# a329:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a329:F:Sorge_um_Freikaufsbedürftige:rHD_rHF
# a329:H:Sorge_um_Freikaufsbedürftige:rHD_rHF
# a329:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a329:F:Um_eine_Frau_werben:rHD_rBZ_rZO
# a329:f:VERTRAG_abschließen_oder_verkünden:rHD_rBZ_rZO
# a329:f:VERSTECKWETTE:rHD_rBZ_rZO
# a329:Hh:VERSTECKWETTE_in_Angriff_nehmen:rHD_rHF
# a329:h:VERSTECKWETTE:rHD_rHP_rPP
# a329:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a329:Hh:VERSTECKWETTE_in_Angriff_nehmen:rHD_rHF
# a329:h:VERSTECKWETTE:rHD_rHP_rPP
# a329:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a329:Hh:VERSTECKWETTE_in_Angriff_nehmen:rHD_rHF
# a329:h:VERSTECKWETTE:rHD_rHP_rPP
# a329:F:Letzte_Gelegenheit_nützen:rHD_rHP_rPP
# a329:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a329:H:VERSTECKWETTE_in_Angriff_nehmen:rHD_rHF
# a329:H:VERSTECKWETTE:rHD_rHP_rPP
# a329:H:VERTRAGsbedingungen_erfüllen:rHD_rPP
# a329:H:Die_SCHÖNE_erfassen:rHD_rPP
# a329:H:Heiraten:rHD_rPP
#
#
# zyx_cc_ddo_rus_90ß
# -----------------
# a563 Tischleindeckdich
# -----------------
# a563:F:HUNGERSNOT_beheben:rHD_rHH
# a563:H:HUNGERSNOT_beheben:rHD_rHH
# a563:F:HUNGERSNOT_beheben:rHD_rHH
# a563:F:Die_potenzielle_Beute_begnadigen:rHD_rST_rZM
# a563:H:Die_potenzielle_Beute_begnadigen:rHD_rST_rZM
# a563:H:PROVIANTPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:HF:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHH_rZM
# a563:H:HUNGERSNOT_beheben:rHD_rHH_rZM
# a563:h:Ausplaudern:rHH_rAN
# a563:h:GIER_und_NEID_ausgelöst:rHD_rZM_rAN
# a563:h:Den_GIER_und_NEID_nachgehen:rHD_rZM_rAN
# a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_rZM_rAN
# a563:h:HUNGERSNOT:rHH_rAN
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM
# a563:H:Einen_gold_oder_GELDPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHH_rZM
# a563:H:HUNGERSNOT_beheben:rHD_rHH_rZM
# a563:h:GIER_und_NEID_ausgelöst:rHD_rZM_rAN
# a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_rZM_rAN
# a563:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHH_fZM
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM
# a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:HF:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a563:H:ANEIGNEN_beheben:rHD_rZM_rAN
# a563:H:Ende:rHD_rHH
#
#
# zyx_cc_ddo_rus_94ß
# -----------------
# a530 Prinzessin auf dem Glasberg
# -----------------
# a530:F:Wache_halten:rHH
# a530:h:Tod_von_Angehörigen:rHH
# a530:h:Wache_halten:fHD
# a530:h:SCHLAF:fHD
# a530:H:Wache_halten:rHD_rHF
# a530:H:REITTIER_erfassen:rHD_rHF
# a530:H:REITTIER_erhalten:rHD_rHF
# a530:h:Den_Vorgang_deuten:fHD
# a530:h:Wache_halten:fHD
# a530:h:SCHLAF:fHD
# a530:H:Wache_halten:rHD_rHF
# a530:H:REITTIER_erfassen:rHD_rHF
# a530:H:REITTIER_erhalten:rHD_rHF
# a530:h:Den_Vorgang_deuten:fHD
# a530:H:Wache_halten:rHD_rHF
# a530:H:REITTIER_erfassen:rHD_rHF
# a530:H:REITTIER_erhalten:rHD_rHF
# a530:Hh:Den_Vorgang_deuten:rHD_rHF
# a530:F:Reitkünste_zeigen:rHP
# a530:F:Um_einen_Auftrag_werben:rHD_fHD
# a530:h:RESPEKTLOSIGKEIT:rHD_fHD
# a530:H:Reitkünste_zeigen:rHD_rHF_rPP
# a530:H:Die_SCHÖNE_erfassen:rHD_rHF_rPP
# a530:F:NEUGIER_ausgelöst:rHD_fHD
# a530:h:Den_Vorgang_deuten:rHD_fHD
# a530:F:Reitkünste_zeigen:rHP
# a530:F:Um_einen_Auftrag_werben:rHD_fHD
# a530:h:RESPEKTLOSIGKEIT:rHD_fHD
# a530:H:Reitkünste_zeigen:rHD_rHF_rPP
# a530:H:Die_SCHÖNE_erfassen:rHD_rHF_rPP
# a530:F:NEUGIER_ausgelöst:rHD_fHD
# a530:h:Den_Vorgang_deuten:rHD_fHD
# a530:F:Reitkünste_zeigen:rHP
# a530:h:RESPEKTLOSIGKEIT:rHD_fHD
# a530:H:Reitkünste_zeigen:rHD_rHF_rPP
# a530:H:Die_SCHÖNE_erfassen:rHD_rHF_rPP
# a530:F:NEUGIER_ausgelöst:rHD_fHD
# a530:h:Den_Vorgang_deuten:rHD_fHD
# a530:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_fHD
# a530:H:Die_SCHÖNE_herbeiholen:rHD_fHD
# a530:H:Beuteteilen:rHD_fHD
#
#
# zyx_cc_kva_rus_13ß
# -----------------
# a563 Tischleindeckdich
# -----------------
# a563:h:HUNGERSNOT:rHD_rHH
# a563:F:Die_potenzielle_Beute_begnadigen:rHD_rST_rZM
# a563:H:Die_potenzielle_Beute_begnadigen:rHD_rST_rZM
# a563:H:Einen_gold_oder_GELDPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:HF:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rST_rZM
# a563:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_fZM
# a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_fZM
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM
# a563:Hh:Den_Vorgang_deuten:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH_rZM
# a563:H:HUNGERSNOT_beheben:rHD_rHH_rZM
# a563:f:EINLADUNG:rVB_rAN
# a563:h:Information_aus_zweiter_Hand:rVB_rAN
# a563:h:Einer_EINLADUNG_nachgehen:rHD_rZM_rAN
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a563:h:GIER_und_NEID_ausgelöst:rHD_rZM_rAN
# a563:h:Den_GIER_und_NEID_nachgehen:rHD_rZM_rAN
# a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_rZM_rAN
# a563:h:HUNGERSNOT:rHD
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM
# a563:H:Den_Vorgang_deuten:rHD_rST_rZM
# a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:HF:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a563:H:ANEIGNEN_beheben:rHD_rZM_rAN
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a563:H:ANEIGNEN_beheben:rHD_rZM_rAN
#
#
# zyx_cr_agx_rus_10ß
# -----------------
# a1543 Keinen Pfennig weniger
# -----------------
# a1543:F:PROVOKATION:zs
# a1543:H:Der_PROVOKATION_nachgehen:zt
# a1543:h:Eine_numinose_Einmischung_VORTÄUSCHEN:zs_zt
# a1543:H:Dem_VORTÄUSCHEN_nachgehen:zs_zt
# a1543:H:ABSURDITÄT_glaubhaft_zu_halten_VORTÄUSCHEN:zs_zt
#
#
# zyx_cr_agx_rus_11ß
# -----------------
# anh531 При дневном свете не знаешь дороги
# -----------------
# anh531:F:Sonstiges_verkaufen:zs_zsa
# anh531:h:Handeln_als_ABSURDITÄT:zs
# anh531:h:Sachschaden_anrichten:zs
# anh531:H:Schlußfolgerung_als_ABSURDITÄT:zs
# anh531:f:Den_Vorgang_deuten:zs_zsa
# anh531:H:ABSURDITÄT_glaubhaft_zu_halten_VORTÄUSCHEN:zs_zsa
#
#
# zyx_cr_agx_rus_12
# -----------------
# aTMJ2672 Zwei Streitende stehlen seine Decke
# -----------------
# aTMJ2672:#:#:#
# aTMJ2672:#:#:#
# aTMJ2672:#:#:#
#
#
# zyx_cr_agx_rus_13
# -----------------
# anh395 Эта мера — одна треть мана
# -----------------
# anh395:#:#:#
# anh395:#:#:#
# anh395:#:#:#
# anh395:#:#:#
#
#
# zyx_cr_agx_rus_14ß
# -----------------
# a8 Schönheitskur
# a38 Einklemmen unholder Wesen
# a56B The Fox as Schoolarmaster
# -----------------
# a56B:#:#:#
# a56B:#:#:#
# a56B:#:#:#
# a56B:#:#:#
# a8:#:#:#
# a38:#:#:#
#
#
# zyx_cr_agx_rus_15
# -----------------
# anh921 Наказанный судья
# -----------------
# anh921:#:#:#
# anh921:#:#:#
# anh921:#:#:#
# anh921:#:#:#
#
#
# zyx_cr_agx_rus_16
# -----------------
# anh483 Мулла Насреддин и сельчане
# -----------------
# anh483:#:#:#
# anh483:#:#:#
#
#
# zyx_cr_agx_rus_17
# -----------------
# anh395 Эта мера — одна треть мана
# -----------------
# anh395:#:#:#
# anh395:#:#:#
# anh395:#:#:#
# anh395:#:#:#
#
#
# zyx_cr_agx_rus_18
# -----------------
# a1640 Tapferes Schneiderlein
# -----------------
# a1640:#:#:#
# a1640:#:#:#
# a1640:#:#:#
# a1640:#:#:#
#
#
# zyx_cr_agx_rus_19
# -----------------
# anh483 Мулла Насреддин и сельчане
# -----------------
# anh483:#:#:#
# anh483:#:#:#
# anh483:#:#:#
# anh483:#:#:#
# anh483:h:#:#
#
#
# zyx_cr_agx_rus_1ß
# -----------------
# aE2 Epos: Rostam (Schāhnāme)
# -----------------
# aE2:H:Wunderbare_EMPFÄNGNIS:rHH
# aE2:Hh:Kaiserschnitt:rHD_rHH_rHF
# aE2:H:Zur_Welt_kommen:rHD_rHH_rHF
# aE2:F:UNGEHEUER_herbeiholen:rHH_fAN
# aE2:h:MASSENBEDROHUNG:rHD_rAN
# aE2:H:Zweikampf:rHD_rAN
# aE2:H:MASSENBEDROHUNG_beheben:rHD_rHH_rVB
# aE2:F:Um_einen_Auftrag_werben:rHD_rHH
# aE2:F:PROVOKATION:rHD_rVB
# aE2:H:Der_PROVOKATION_nachgehen:rHD_rVB
# aE2:F:Krisenursachen_ergründen:rHD_rHH
# aE2:F:Rache_nehmen:rHD_rHH
# aE2:F:Um_einen_Auftrag_werben:rHD_rHH
# aE2:H:Die_Beschaffung_der_AUSRÜSTUNG:rHH_rST
# aE2:#:#:#
# aE2:HF:PFÖRTNER_täuschen:rHD_rVB
# aE2:H:PFÖRTNER_entkommen:rHD
# aE2:H:Schrecken_ausgelöst:rHD
# aE2:#:#:#
# aE2:H:Zweikampf:N
# aE2:H:Rache_nehmen:N
# aE2:F:MASSENBEDROHUNG_beheben:rHH_fAN
# aE2:F:MASSENBEDROHUNG_beheben:rHD_rHH
# aE2:HF:Information_aus_zweiter_Hand:rHD_rHH
# aE2:H:Heimlich_beobachten:rHD
# aE2:h:MASSENBEDROHUNG:rHD
# aE2:#:#:#
# aE2:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_fAN
# aE2:H:REITTIER_erfassen:rHD_fAN
# aE2:H:REITTIER_besorgen:rHD_fAN
#
#
# zyx_cr_agx_rus_20
# -----------------
# anh344 Чтобы самого не украли
# -----------------
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
#
#
# zyx_cr_agx_rus_21
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_22ß
# -----------------
# a930 Uriasbrief
# -----------------
# a930:f:VORHERSAGE_ungewünschte_Heiraten:rST_fHP
# a930:h:Der_VORHERSAGE_nachgehen:rHD_rHH_fHP
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP
# a930:h:TÖTUNG:rHD_rHH_fHP
# a930:h:Aussetzung:rHD_rHH_fHP
# a930:H:Adoption:rHD_rST
# a930:H:Begegnung:rHD_rST_fHP
# a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST_fHP
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rST_fHP
# a930:f:BOTSCHAFTEN_versenden:rHD_rST_fHP
# a930:H:SCHLAF:rHD_rPP
# a930:F:Liebe_wird_ausgelöst:rHD_rPP
# a930:H:BOTSCHAFTEN_verfälschen:rHD_rPP
# a930:H:Heiraten:rHD_rHP_rPP
# a930:H:Die_VORHERSAGE_tritt_ein:rHD_rHP_rPP
#
#
# zyx_cr_agx_rus_23
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_24
# -----------------
# anh344 Чтобы самого не украли
# -----------------
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
#
#
# zyx_cr_agx_rus_25
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_26
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_27
# -----------------
# a1592B Topf hat ein Kind
# -----------------
# a1592B:#:#:#
# a1592B:#:#:#
#
#
# zyx_cr_agx_rus_28
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_29ß
# -----------------
# a545B Der gestiefelte Kater
# -----------------
# a545B:F:Sorge_um_Hungernde_oder_Durstige:rHD_rHF
# a545B:H:Sorge_um_Hungernde_oder_Durstige:rHD_rHF
# a545B:H:Hilfeversprechen_erhalten:rHD_rHF
# a545B:F:Reichtum_VORTÄUSCHEN:rHF_rHP
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP
# a545B:F:Reichtum_VORTÄUSCHEN:rHF_rHP
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP
# a545B:F:Um_eine_Frau_werben:rHF_rHP
# a545B:HF:Information_aus_zweiter_Hand:rHF_rHP
# a545B:F:EINLADUNG:rHF_rHP
# a545B:H:Einer_EINLADUNG_nachgehen:rHD_rHF
# a545B:F:Verlust_VORTÄUSCHEN:rHF_rHP
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP
# a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF
# a545B:H:REITTIER_erhalten:rHD_rHF
# a545B:H:Heiraten:rHD_rHF_rPP
# a545B:H:Auf_dem_Heimweg:rHD_rHF_rPP
# a545B:F:Eine_Bedrohung_VORTÄUSCHEN:rHF_fST
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_fST
# a545B:H:VERTREIBUNG:rHF_fST
# a545B:H:Fremdes_Gut_einziehen:rHD_rHF_rPP
# a545B:f:Tod_VORTÄUSCHEN:rHD_rHF
# a545B:Ff:Vertrauen_beweisen:rHD_rHF
# a545B:h:Dem_VORTÄUSCHEN_nachgehen:rHD_rPP
# a545B:h:Vertrauen_beweisen:rHD_rPP
# a545B:H:Das_VORTÄUSCHEN_eingestehen:rHF_fST
# a545B:hf:Wiedergutmachung_erpressen:rHF_fST
# a545B:f:Wiedergutmachung_erpressen:rHD_rHF_fST
# a545B:F:Eine_Bedrohung_VORTÄUSCHEN:rHD_rHF_fST
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_fST
# a545B:H:Wiedergutmachung_erpressen:rHD_rHF_fST
#
#
# zyx_cr_agx_rus_2ß
# -----------------
# a301 Die drei geraubten Prinzesinnen
# a300 Der Drachentöter
# -----------------
# a301:F:Auftrag_zum_Kochen:fHD
# a301:f:PROVOKATION:rST_fHD
# a301:h:Der_PROVOKATION_nachgehen:rST_fHD
# a301:h:Auftrag_zum_Kochen:fHD
# a301:h:Den_Vorgang_deuten:fHD
# a301:F:Auftrag_zum_Kochen:rHD
# a301:f:PROVOKATION:rHD_rST
# a301:H:Der_PROVOKATION_nachgehen:rHD_rST
# a301:H:Hilfeversprechen_erhalten:rHD_rST
# a300:F:WASSERMANGEL_beheben:rHD_rHF
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rHF
# a300:H:WAFFE_ZAUBERMITTEL_erhalten:rHD_rHF
# a300:HF:ABRATEN_von_der_Mission:rHD_rVB
# a300:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rVB
# a300:H:Mut_zeigen:rHD_rPP
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rHD_rVB
# a300:F:MARKIERUNGEN_anbringen:rHD_rAN
# a300:F:MARKIERUNGEN_anbringen:rHD_rPP
# a300:h:KONTAKT_abbrechen:rHD_rPP
# a300:H:Den_Vorgang_deuten:rHD_fHD
# a300:h:GIER_und_NEID_ausgelöst:rHD_fHD
# a300:h:SCHLAF:rHD_fHD
# a300:f:MISSETAT_planen:rHD_fHD
# a300:h:MISSETAT_wie_Entmachtung:rHD_fHD
# a300:h:MISSETAT_wie_Aneignung:rHD_fHD
# a300:f:Heldentat_VORTÄUSCHEN:rVB_fHD
# a300:H:Dem_VORTÄUSCHEN_nachgehen:rPP_fHD
# a300:F:MISSETAT_beheben:rHD_rHF
# a300:F:Krisenursachen_ergründen:rHD_rHF
# a300:H:KONTAKT_wiederherstellen:rHD_rHP_rPP
# a300:H:MARKIERUNGEN_vorlegen:rHD_rHP_rPP
# a300:H:MARKIERUNGEN_erkennen:rHD_rHP_rPP
# a300:H:Held_erkennen:rHF_rHP_fHD
# a300:H:Bestrafung:rHF_rHP_fHD
# a300:f:Heiraten:rHD_rPP
#
#
# zyx_cr_agx_rus_3
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_30ß
# -----------------
# a56A Fuchs und Vogeljunge
# -----------------
# a56A:#:#:#
# a56A:#:#:#
# a56A:#:#:#
# a56A:#:#:#
#
#
# zyx_cr_agx_rus_31
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_32
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_33
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_34
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_37
# -----------------
# aTMJ2672 Zwei Streitende stehlen seine Decke
# -----------------
# aTMJ2672:#:#:#
# aTMJ2672:#:#:#
# aTMJ2672:#:#:#
#
#
# zyx_cr_agx_rus_38
# -----------------
# anh395 Эта мера — одна треть мана
# -----------------
# anh395:#:#:#
# anh395:#:#:#
# anh395:#:#:#
# anh395:#:#:N
#
#
# zyx_cr_agx_rus_39ß
# -----------------
# a8 Schönheitskur
# a38 Einklemmen unholder Wesen
# a56B The Fox as Schoolarmaster
# -----------------
# a56B:#:#:#
# a56B:#:#:#
# a56B:#:#:#
# a56B:#:#:#
# a8:#:#:#
# a38:#:#:#
#
#
# zyx_cr_agx_rus_4
# -----------------
# a329 Versteckwette
# -----------------
# a329:h:Tod_von_Angehörigen:rHD
# a329:F:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a329:H:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a329:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a329:F:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a329:H:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a329:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a329:F:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a329:H:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a329:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a329:F:VERSTECKWETTE:rHD_rVB
# a329:f:VERTRAG_abschließen_oder_verkünden:rHD_rPP
# a329:h:VERSTECKWETTE:rHD_rHF
# a329:h:VERSTECKWETTE:rHD_rPP
# a329:h:VERSTECKWETTE:rHD_rHF
# a329:h:VERSTECKWETTE:rHD_rPP
# a329:H:VERSTECKWETTE:rHD_rHF
# a329:H:VERSTECKWETTE:rHD_rPP
# a329:H:Heiraten:rHD_rPP
#
#
# zyx_cr_agx_rus_40
# -----------------
# anh921 Наказанный судья
# -----------------
# anh921:#:#:#
#
#
# zyx_cr_agx_rus_41
# -----------------
# anh483 Мулла Насреддин и сельчане
# -----------------
# anh483:#:#:#
# anh483:#:#:#
# anh483:#:#:#
# anh483:#:#:#
# anh483:#:#:#
# anh483:#:#:#
#
#
# zyx_cr_agx_rus_42
# -----------------
# anh395 Эта мера — одна треть мана
# -----------------
# anh395:#:#:#
# anh395:#:#:#
# anh395:#:#:#
# anh395:#:#:#
#
#
# zyx_cr_agx_rus_43
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_44
# -----------------
# anh483 Мулла Насреддин и сельчане
# -----------------
# anh483:#:#:#
# anh483:#:#:#
# anh483:#:#:#
# anh483:#:#:#
# anh483:#:#:#
#
#
# zyx_cr_agx_rus_45
# -----------------
# anh344 Чтобы самого не украли
# -----------------
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
# anh344:#:#:#
#
#
# zyx_cr_agx_rus_46
# -----------------
#
# -----------------
#
#
# zyx_cr_agx_rus_47ß
# -----------------
# a930 Uriasbrief
# -----------------
# a930:f:VORHERSAGE_ungewünschte_Heiraten:rST_fHP
# a930:h:Der_VORHERSAGE_nachgehen:rHD_rHH_fHP
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP
# a930:h:TÖTUNG:rHD_rHH_fHP
# a930:h:Aussetzung:rHD_rHH_fHP
# a930:H:Adoption:rHD_rST
# a930:H:Begegnung:rHD_rST_fHP
# ...
# aE2:#:#:#
# aE2:#:#:#
# aE2:#:#:#
# aE2:#:#:#
# aE2:#:#:#
# aE2:#:#:#
# aE2:#:#:#
# aE2:#:#:#
#
#
# zyx_cr_ttt_rus_2
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_20
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_21
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_22
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_23ß
# -----------------
# a881A Frau in Männerkleidung
# -----------------
# a881A:H:Verlobung_wird_arrangiert:rHH_rHH
# a881A:h:Tod_von_Angehörigen:rHH
# a881A:H:Hochzeit_verschieben:rHH
# a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_rAN
# a881A:f:Ungewollte_Verlobung_akzeptieren:rHH_rAN
# a881A:h:Ungewollte_Verlobung_akzeptieren:rHH_rAN
# a881A:f:Ungewollte_Verlobung_akzeptieren:rHH_rAN
# a881A:h:Ungewollte_Verlobung_akzeptieren:rHH_rAN
# a881A:h:Ungewollte_Verlobung_akzeptieren:rHD_rHH
# a881A:H:FLUCHT_vorbereiten:rHD_rPP
# a881A:F:Krankheit_VORTÄUSCHEN:rHD_rAN
# a881A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN
# a881A:Hh:FLUCHT:rHD_rPP
# a881A:H:IDENTITÄT_ändern:rHD_rPP
# a881A:Hh:KONTAKT_abbrechen:rHD_rPP_fPP
# a881A:h:Eine_ENTFÜHRUNG:rHD_fPP
# a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP
# a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP
# a881A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fPP
# a881A:H:FLUCHT:rHD
# a881A:h:SCHLAF:rHD
# a881A:h:Überrascht_werden_oder_geraten:rHD_fPP
# a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP
# a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP
# a881A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fPP
# a881A:Hh:FLUCHT:rHD_fHF
# a881A:h:Überrascht_werden_oder_geraten:rHD_fPP
# a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP
# a881A:H:Zum_Schlafen_bringen:rHD_fPP
# a881A:H:IDENTITÄT_ändern:rHD_fPP
# a881A:F:MARKIERUNGEN_anbringen:rHD_fPP
# a881A:F:An_Königswahl_teilnehmen:rHD
# a881A:H:An_Königswahl_teilnehmen:rHD
# a881A:F:Intensive_ERKUNDUNGSAKTION:rHD_fPP
# a881A:#:#:#
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rAN
# a881A:H:Zusammenbringen_aller_Handlungsträger:rAN
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rPP
# a881A:H:Zusammenbringen_aller_Handlungsträger:rPP
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:fPP
# a881A:H:Zusammenbringen_aller_Handlungsträger:fPP
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:fPP
# a881A:H:Zusammenbringen_aller_Handlungsträger:fPP
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:fPP
# a881A:H:Zusammenbringen_aller_Handlungsträger:fPP
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rAN
# a881A:F:ERZÄHLEN_beginnen:rHD_rAN
# a881A:H:ERZÄHLEN_beenden:rHD_rAN
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rPP
# a881A:F:ERZÄHLEN_beginnen:rHD_rPP
# a881A:H:ERZÄHLEN_beenden:rHD_rPP
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fPP
# a881A:F:ERZÄHLEN_beginnen:rHD_fPP
# a881A:H:ERZÄHLEN_beenden:rHD_fPP
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fPP
# a881A:F:ERZÄHLEN_beginnen:rHD_fPP
# a881A:H:ERZÄHLEN_beenden:rHD_fPP
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fPP
# a881A:F:ERZÄHLEN_beginnen:rHD_fPP
# a881A:H:ERZÄHLEN_beenden:rHD_fPP
# a881A:H:Bestrafung:rHD_rAN
# a881A:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP
# a881A:H:Familienzusammenführung:rHD_rPP
# a881A:F:Angebot_KÖNIG_ZU_WERDEN:N
# a881A:H:Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen:N
# a881A:H:Ende:N
#
#
# zyx_cr_ttt_rus_24
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_25
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_26
# -----------------
# a507 Die Braut des Ungeheuers
# -----------------
# a507:hf:TABU_Land_nicht_betreten:N
# a507:h:TABU_nachgehen:N
# a507:F:Liebe_wird_ausgelöst:N
# a507:Hh:KONTAKT_abbrechen:N
# a507:F:Krisenursachen_ergründen:rHD_rHF
# a507:F:KONTAKT_wiederherstellen:N
# a507:F:Um_eine_Frau_werben:N
# a507:h:BEHINDERUNG_durch_einen_Fluch:N
# a507:H:Tarnung_gewährendes_ZAUBERMITTEL_erhalten:N
# a507:H:Komplikationsfreier_Flug:N
# a507:F:Heimlich_beobachten:N
# a507:F:NEUGIER_ausgelöst:N
# a507:H:Komplikationsfreier_Flug:N
# a507:F:Heimlich_beobachten:N
# a507:H:Komplikationsfreier_Flug:N
# a507:F:NEUGIER_ausgelöst:N
# a507:H:Komplikationsfreier_Flug:N
# a507:H:Mut_zeigen:N
# a507:H:Richtiges_auswählen:N
# a507:H:Ende:N
#
#
# zyx_cr_ttt_rus_27
# -----------------
# a471 Brücke zur anderen Welt
# -----------------
# a471:h:Tod_von_Angehörigen:N
# a471:f:Jenseitswanderung_unternehmen:N
# a471:h:Jenseitswanderung_unternehmen:N
# a471:h:Jenseitswanderung_unternehmen:N
# a471:F:Um_einen_Auftrag_werben:N
# a471:F:Auf_Hilfsquelle_zurückgreifen:N
# a471:HF:Wegweisung_erhalten:N
# a471:F:Lösung_für_den_FÄHRMANN_deuten:N
# a471:F:Folge_von_Betrügerei_deuten:N
# a471:F:Folge_von_Betrügerei_deuten:N
# a471:F:Ursache_des_unstillbaren_Hungers_deuten:N
# a471:F:Ursache_des_unstillbaren_Dursts_deuten:N
# a471:F:Folge_von_Arbeitsscheu_deuten:N
# a471:F:Folge_von_Arbeitsscheu_deuten:N
# a471:H:Jenseitswanderung_unternehmen:N
# a471:H:Lösung_für_den_FÄHRMANN_deuten:N
# a471:H:Folge_von_Betrügerei_deuten:N
# a471:H:Folge_von_Betrügerei_deuten:N
# a471:H:Ursache_des_unstillbaren_Hungers_deuten:N
# a471:H:Ursache_des_unstillbaren_Dursts_deuten:N
# a471:H:Folge_von_Arbeitsscheu_deuten:N
# a471:H:Universellen_ZAUBERMITTEL_erhalten:N
# a471:H:Bestrafung:N
# a471:H:Ende:N
#
#
# zyx_cr_ttt_rus_28
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_29ß
# -----------------
# a563 Tischleindeckdich
# -----------------
# a563:F:HUNGERSNOT_beheben:rHD_rVB_fVB
# a563:H:Sich_sonstige_Dinge_ANEIGNEN:rHD_rVB_fVB
# a563:h:VERLUST_von_Tieren_Früchten_Ernte_usw:rST_fHF
# a563:h:Überrascht_werden_oder_geraten:rHD_rST
# a563:f:Ungewollte_Verlobung_akzeptieren:rHD_rST
# a563:HF:Information_aus_zweiter_Hand:rHD_fVB
# a563:h:Ungewollte_Verlobung_akzeptieren:rHD_fVB
# a563:HF:Information_aus_zweiter_Hand:rHD_rVB
# a563:H:Ungewollte_Verlobung_akzeptieren:rHD_rVB
# a563:h:HUNGERSNOT:rHD_fVB
# a563:h:KONTAKT_abbrechen:rHD_fVB
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rVB
# a563:H:PROVIANTPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rZM
# a563:H:KONTAKT_wiederherstellen:rHD_fVB
# a563:f:EINLADUNG:rHD_fVB
# a563:HF:Information_aus_zweiter_Hand:rAN_fVB
# a563:h:Einer_EINLADUNG_nachgehen:rAN_fVB
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a563:h:GIER_und_NEID_ausgelöst:rHD_rZM_rAN
# a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_rZM_rAN
# a563:h:HUNGERSNOT:rHD_fVB
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM
# a563:H:Einen_gold_oder_GELDPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_fVB
# a563:H:HUNGERSNOT_beheben:rHD_rZM_fVB
# a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_rZM_rAN
# a563:h:HUNGERSNOT:rHD_fVB
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM
# a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a563:H:ANEIGNEN_beheben:rHD_rZM_rAN
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a563:H:ANEIGNEN_beheben:rHD_rZM_rAN
# a563:H:HUNGERSNOT_beheben:rHD_rZM_fVB
# a563:H:Ende:rHD_rZM_fVB
#
#
# zyx_cr_ttt_rus_3
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_30
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_31
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_32
# -----------------
# a706 Mädchen ohne Hände
# -----------------
# a706:h:Kinderlosigkeit:rHH
# a706:F:Magische_EMPFÄNGNISmittel_suchen:rHH
# a706:Hh:VERSPRECHEN_im_Austausch_für_Hilfe:rHH_rZM_fST
# a706:H:Magische_EMPFÄNGNISmittel_erhalten:rHH_rZM_fST
# a706:H:Wunderbare_EMPFÄNGNIS:rHH_rZM
# a706:H:Zur_Welt_kommen:rHH
# a706:h:Tod_von_Angehörigen:rHH
# a706:H:Zur_Welt_kommen:rHD
# a706:h:Tod_von_Angehörigen:rHH
# a706:h:Sich_auf_Eindringlinge_einlassen:rHD_fHH
# a706:h:Verlobung_wird_arrangiert:rHD_rHH_fHH
# a706:h:Heiraten:rHD_rHH_fHH
# a706:h:VERLEUMDUNG_bei_Schädigung:rHD_rHH_fHH
# a706:H:VERLEUMDUNG_beheben:rHD_rHH_fHH
# a706:h:VERLEUMDUNG_bei_Schädigung:rHD_rHH_fHH
# a706:H:VERLEUMDUNG_beheben:rHD_rHH_fHH
# a706:h:VERLEUMDUNG_bei_Schädigung:rHD_rHH_fHH
# a706:H:VERLEUMDUNG_beheben:rHD_rHH_fHH
# a706:h:KINDERMORD_nachgehen:rHD_rHH_fHH
# a706:h:VERLEUMDUNG_bei_Kindstötung:rHD_rHH_fHH
# a706:h:BEHINDERUNG_durch_Verstümmelung:rHD_rHH
# a706:h:VERTREIBUNG:rHD_rHH
# a706:H:Überrascht_werden_oder_geraten:rHD_rPP
# a706:F:Liebe_wird_ausgelöst:rHD_rPP
# a706:F:Heiraten:rHD_rPP
# a706:Hh:KONTAKT_abbrechen:rHD_rPP
# a706:H:BOTSCHAFTEN_versenden:rVB_rHP
# a706:h:SCHLAF:rVB_fHH
# a706:h:BOTSCHAFTEN_verfälschen:rVB_fHH
# a706:H:BOTSCHAFTEN_versenden:rVB_rPP
# a706:h:SCHLAF:rVB_fHH
# a706:h:BOTSCHAFTEN_verfälschen:rVB_fHH
# a706:h:VERTREIBUNG:rHD_rHP
# a706:F:Sorge_um_Hilfsbedürftige:N
# a706:H:Sorge_um_Hilfsbedürftige:N
# a706:H:Eine_BEHINDERUNG_beheben:N
# a706:H:Sich_niederlassen:rHD
# a706:H:Intensive_ERKUNDUNGSAKTION:rHD_rST
# a706:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST
# a706:H:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST
# a706:H:Zusammenbringen_aller_Handlungsträger:rHD_rHH_rPP
# a706:H:Den_Vorgang_deuten:rHD_rHH_rPP
# a706:H:VERLEUMDUNG_beheben:rHD_rHH_rPP
# a706:H:Bestrafung:rHH_fHH
# a706:H:Familienzusammenführung:rHD_rPP
#
#
# zyx_cr_ttt_rus_33
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_34
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_35
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_36
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_37
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_38
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_39
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_4
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_40
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_41
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_42
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_43
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_44
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_45
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_46
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_47
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_48
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_49
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_5
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_50
# -----------------
# a922 Kaiser und Abt
# -----------------
# a922:f:VERTRAG_abschließen_oder_verkünden:zs_zv
# a922:f:Rätsel_lösen:zs_zv
# a922:H:Rätsel_lösen:zs_zv
# a922:H:VERTRAGsbedingungen_erfüllen:zs_zv
# a922:h:FREIHEITSBERAUBUNG:zs_zv_zva
# a922:f:VERTRAG_abschließen_oder_verkünden:zt_zv
# a922:f:Rätsel_lösen:zt_zv
# a922:h:Rätsel_lösen:zt_zv
# a922:h:FREIHEITSBERAUBUNG:zt_zv
# a922:f:VERTRAG_abschließen_oder_verkünden:zt_zv
# a922:f:Rätsel_lösen:zt_zv
# a922:h:Rätsel_lösen:zt_zv
# a922:h:FREIHEITSBERAUBUNG:zt_zv
# a922:f:VERTRAG_abschließen_oder_verkünden:zt_zv
# a922:f:Rätsel_lösen:zt_zv
# a922:h:Rätsel_lösen:zt_zv
# a922:h:FREIHEITSBERAUBUNG:zt_zv
# a922:F:Auf_Hilfsquelle_zurückgreifen:zs_zt
# a922:F:GEGENLEISTUNG_für_die_LEISTUNG:zs_zt
# a922:F:LEISTUNG_für_die_GEGENLEISTUNG:zs_zt_zta
# a922:HF:Rätsel_lösen:zs_zt_zta
# a922:H:Rätsel_lösen:zt_zv
# a922:H:Ende:zs_zv
#
#
# zyx_cr_ttt_rus_51
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_52
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_53ß
# -----------------
# a930 Uriasbrief
# -----------------
# a930:H:Unterkommen:rHH_rVB_fHP
# a930:H:Zur_Welt_kommen:rHD_rVB_fHP
# a930:f:VORHERSAGE_ungewünschte_Heiraten:rHD_rVB_fHP
# a930:h:Der_VORHERSAGE_nachgehen:rHD_rHH_fHP
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP
# a930:h:Adoption:rHD_rHH_fHP
# a930:h:Aussetzung:rHD_rVB_fHP
# a930:H:Überrascht_werden_oder_geraten:rHD_rST
# a930:H:Adoption:rHD_rST
# a930:H:Begegnung:rHD_rVB_fHP
# a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST_fHP
# a930:h:Der_VORHERSAGE_nachgehen:rHD_rST_fHP
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rST_fHP
# a930:h:Adoption:rHD_rST_fHP
# a930:h:Aussetzung:rHD_rVB_fHP
# a930:H:Überrascht_werden_oder_geraten:rHD_rST
# a930:H:Adoption:rHD_rST
# a930:F:Um_einen_Auftrag_werben:rHD_rST
# a930:h:KONTAKT_abbrechen:rHD_rST
# a930:H:Begegnung:rHD_rVB_fHP
# a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rVB_fHP
# a930:h:Der_VORHERSAGE_nachgehen:rHD_rVB_fHP
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rVB_fHP
# a930:f:BOTSCHAFTEN_versenden:rHD_fHP
# a930:H:SCHLAF:rHD
# a930:F:Liebe_wird_ausgelöst:rHD_rPP
# a930:H:BOTSCHAFTEN_verfälschen:rHD_rPP
# a930:H:Heiraten:rHD_rHP_rPP
# a930:HF:VERFOLGUNG_entkommen:rHD_rPP
# a930:h:VERFOLGUNG:rVB_fHP
# a930:H:VERFOLGUNG_entkommen:rHD_fHP
# a930:H:Die_VORHERSAGE_tritt_ein:rHD_fHP
#
#
# zyx_cr_ttt_rus_54
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_55
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_56
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_57
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_58
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_59
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_60
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_61
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_62
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_63ß
# -----------------
# a545B Der gestiefelte Kater
# -----------------
# a545B:F:Den_Einbrecher_begnadigen:rHD_rHF
# a545B:H:Den_Einbrecher_begnadigen:rHD_rHF
# a545B:H:Hilfeversprechen_erhalten:rHD_rHF
# a545B:F:NEUGIER_ausgelöst:rHF_rHP
# a545B:F:Um_eine_Frau_werben:rHF_rHP
# a545B:HF:Information_aus_zweiter_Hand:rHF_rHP
# a545B:H:Der_NEUGIER_nachgehen:rHF_rHP
# a545B:HF:Reichtum_VORTÄUSCHEN:rHD_rHF
# a545B:F:SONSTIGE_AUFGABE_erledigen:rHD_rHF
# a545B:H:SONSTIGE_AUFGABE_in_Angriff_nehmen:rHD_rHH
# a545B:H:SONSTIGE_AUFGABE_erledigen:rHD_rHH
# a545B:F:Reichtum_VORTÄUSCHEN:rHD_rHH
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHH
# a545B:F:NEUGIER_ausgelöst:rHD_rHH
# a545B:H:Der_NEUGIER_nachgehen:rHD_rHF_rHP
# a545B:F:EINLADUNG:rHD_rHF_rHP
# a545B:Hh:Einer_EINLADUNG_nachgehen:rHD_rHF
# a545B:F:LEISTUNG_für_die_GEGENLEISTUNG:rHF_fST
# a545B:H:GEGENLEISTUNG_für_die_LEISTUNG:rHF_fST
# a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHF_fST
# a545B:f:Zum_STAUNEN_bringen:rHF_rHP
# a545B:h:Dem_STAUNEN_nachgehen:rHF_rHP
# a545B:F:Unzufriedenheit_VORTÄUSCHEN:rHF_rHP
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP
# a545B:F:Eine_Bedrohung_VORTÄUSCHEN:rHF_fST
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_fST
# a545B:H:TÖTUNG:rHF_fST
# a545B:H:Fremdes_Gut_einziehen:rHD_rHF_rPP
# a545B:H:Heiraten:rHD_rHF_rPP
# a545B:H:Ende:N
#
#
# zyx_cr_ttt_rus_6ß
# -----------------
# a976 Die vornehmste Handlung
# a655 Die scharfsinnigen Brüder
# -----------------
# a655:Ff:Priorisierung_VORTÄUSCHEN:zs_zsa
# a655:Ff:Priorisierung_VORTÄUSCHEN:zs_zsa
# a655:Hh:Dem_VORTÄUSCHEN_nachgehen:zs
# a655:h:Tod_von_Angehörigen:zs_zsa
# a655:h:MISSETAT_wie_Aneignung:zs_zsa
# a655:h:VERLUST des Schatzes:zs
# a655:F:VERLUSTursache_beheben:zs
# a655:h:VERLUST_von_Tieren_Früchten_Ernte_usw:zs_zt
# a655:F:VORHERSAGE_erforderlich:zs_zt
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:h:Der_VORHERSAGE_nachgehen:zt_zv
# a655:F:Streit_schlichten:zt_zv
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zv
# a655:H:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zv
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zv
# a655:H:VERLUSTursache_beheben:zt_zv
# a655:H:Streit_schlichten:zt_zv
# a655:F:EINLADUNG:zs_zv
# a655:H:Einer_EINLADUNG_nachgehen:zs_zv
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zv
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zv
# a655:HF:VORHERSAGE_subtile_Identität:zs_zv
# a655:H:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zv_zva
# a655:HF:VORHERSAGE_subtiles_Geschmak:zv_zva
# a655:H:Der_VORHERSAGE_nachgehen:zs_zsa
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zsa
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zsa
# a655:HF:Der_VORHERSAGE_nachgehen:zs_zv
# a655:H:Die_VORHERSAGE_tritt_ein:zv_zva
# a655:HF:VORHERSAGE_subtile_Identität:zv_zva
# a655:F:Auf_Hilfsquelle_zurückgreifen:zv_zva
# a655:F:VERLUST des Schatzes:zs_zva
# a655:F:VORHERSAGE_erforderlich:zs_zva
# a976:F:Rätsel_lösen:zva
# a976:F:ERZÄHLEN_beginnen:zva
# a655:H:ERZÄHLEN_beenden:zs_zva
# a655:Hh:Rätsel_lösen:zs_zva
# a655:H:VERLUSTursache_beheben:zs_zva
# a655:H:Streit_schlichten:zs_zva
#
#
# zyx_cr_ttt_rus_7
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_8
# -----------------
#
# -----------------
#
#
# zyx_cr_ttt_rus_9
# -----------------
#
# -----------------
