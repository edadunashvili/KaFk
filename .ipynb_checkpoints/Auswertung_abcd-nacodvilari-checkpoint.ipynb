# %% [markdown]
# #  Auswertung - abcd

# %% [markdown]
# ### README
#
# Der Code visualisiert die Verkettung von 4-Tupel-Elemente (a=Typnummer, b = Sinn und Zweck der Handlung, c = die Handlung, d = die handlungstragende Figur bzw. Figuren).
#
# Anpassbare Zeilen:
#
# (#1) Die Index des in Betracht bezogenen Typs kann durch die Variable 'mZahl' angepasst werden.
#
# (#2) Durch die Variable 'mWert' wird ein Motiv als Anhaltpunkt in der visualisierten Motivkette bestimmt. Dieser Wert wird aus der generierten Liste (#149) entnommen, nachdem als die Variable 'mZahl' (#1) bestimmt und der Code ausgeführt ist.
#
# (#3) Die Variable 'häufigkeit' bestimmt die Häufigkeit des Auftretens der Verbindung zwischen den Motiven.
#
# (#6) Pfad zu der Inputdatei.
#
# (#9) Der Attributwert bestimmt die Herkunft der zu analysierenden Textgruppe (des Repertoires). Die Filter können mit den 'or' und 'and' Operatoren ergänzt werden, z. B.:
#
# if ('deu' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
#
#     or 'ita' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']):

# %%
mZahl = "a550"  #1 Typnummer eingeben

mWert = "a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH"  #2 Ein konkretes Markupelement eingeben

haeufigkeit = 2  #3 Eine ganze Zahl eingeben = Häufigkeit eines Markupelements in den ausgewerteten Daten3


def graph_update():
    graph.update(alle_aeste("a531", df))
    graph.update(alle_aeste("", df))
    graph.update(alle_aeste("", df))

# %%
maerchen = ""  #25 Eine leere Zeichenkette, in der Daten für Märchen gesammelt werden.
import xml.etree.ElementTree as ET  #26 Importieren der ElementTree-Bibliothek zum Parsen von XML.
root_node = ET.parse('gesamt_märchen.xml').getroot()  #27 Parsen der XML-Datei und Zugriff auf das Wurzelelement.
never_saved = True  #28 Ein boolean-Wert, der angibt, ob Daten bereits gespeichert wurden oder nicht.
#29 Iteration durch jedes 'text'-Element in der XML-Datei.
for corp in root_node.findall (".//{http://www.tei-c.org/ns/1.0}teiCorpus"):
    if "rus" in corp.attrib["n"]:
        for ganze in corp.findall(".//{http://www.tei-c.org/ns/1.0}text"):
            #30 Überprüfung, ob das Attribut 'deu' in der 'id'-Eigenschaft des 'text'-Elements vorhanden ist.
            if ('zyx_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']):
                #31 Iteration durch jeden Absatz im 'body' des 'text'-Elements.
                for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
                    for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
                        #32 Iteration durch jede 'seg'-Phrase im Absatz.
                        for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}seg"):
                            #33 Extrahieren von Labels und Inhalten aus den Attributen und dem Text der Phrase.
                            labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
                            labelb1 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b1}ana']
                            labelb2 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b2}ana']
                            labelb3 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b3}ana']
                            labelb4 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b4}ana']
                            labelb5 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b5}ana']
                            labelc1 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c1}ana']
                            labelc2 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c2}ana']
                            labelc3 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c3}ana']
                            labelc4 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c4}ana']
                            labelc5 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c5}ana']
                            labeld = phrase.attrib['{www.dglab.uni-jena.de/vmf/d}ana']
                            #34 Die Quelle wird aus dem Attribut 'id' der 'ganze'-Schleife extrahiert.
                            quelle = ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
                            #35 Der Inhalt wird in Kleinbuchstaben umgewandelt und formatiert.
                            inhalt = (phrase.text.lower().strip().replace('|','').replace(':','').replace("ä","ae")
                                      .replace("ü","ue").replace("ö","oe").replace("ß","ss").replace(",","")
                                      .replace("«","").replace("»","").replace(".","").replace('=',' ').replace(";","")
                                      .replace('"',"").replace("?","").replace("!","").replace("á","a").replace(",","")
                                      .replace("\t"," ").replace("'","").replace("‹","").replace("›","").replace("-"," ")
                                      .replace("'('","").replace("')'","").replace('>','').replace("    "," ")
                                      .replace("   "," ").replace("  "," ").replace('–','').replace('—','').replace('<','')
                                      .replace("Â", "A").replace("ø", "oe").replace('“','').replace('„','').replace('(','')
                                      .replace(')','').replace('*','').replace("\n","\n")
                                      .replace("'''",""))
                            #36 Überprüfung, ob labela mit 'a' beginnt und nicht gleich 'N' ist.
                            if labela.startswith('a') and labela != 'N':
                                    #37 Konstruktion des Datensatzes für das Märchen und Anhängen an die 'maerchen'-Zeichenkette.
                                    maerchen += (quelle+','+labela+','+labelb1+','+labelc1+','+labelb2+','+labelc2+','+
                                                 labelb3+','+labelc3+','+labelb4+','+labelc4+','+labelb5+','+labelc5+','+
                                                 labeld+','+inhalt+',0'+'\n')                       
with open("text.csv", 'w', encoding='utf-8') as f:
     #38 Schreiben der Kopfzeile in die CSV-Datei.
    f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar')
    f.write('\n')
    #39 Schreiben der gesammelten Daten in die CSV-Datei.
    f.write(maerchen)

# %%
#19 leere Zeichenketten, in der Daten für abcd1-5 gesammelt werden.
abcd1 = ""
abcd2 = ""
abcd3 = ""
abcd4 = ""
abcd5 = ""

import csv
import pandas as pd
from collections import Counter

#20 Einlesen der CSV-Datei in ein DataFrame.
df = pd.read_csv('text.csv', encoding='utf-8')

#21 Hinzufügen von Daten an abcd1, abcd2, abcd3, abcd4 und abcd5.
abcd1 += df.quelle+','+df.labela+':'+df.labelb1+':'+df.labelc1+':'+df.labeld+','+df.inhalt+',0'
abcd2 += df.quelle+','+df.labela+':'+df.labelb2+':'+df.labelc2+':'+df.labeld+','+df.inhalt+',0'
abcd3 += df.quelle+','+df.labela+':'+df.labelb3+':'+df.labelc3+':'+df.labeld+','+df.inhalt+',0'
abcd4 += df.quelle+','+df.labela+':'+df.labelb4+':'+df.labelc4+':'+df.labeld+','+df.inhalt+',0'
abcd5 += df.quelle+','+df.labela+':'+df.labelb5+':'+df.labelc5+':'+df.labeld+','+df.inhalt+',0'

#22 Zusammenstellen der Daten aus abcd1 bis abcd5
recorded = (abcd1 + '\n' + abcd2 + '\n' + abcd3 + '\n' + abcd4 + '\n' + abcd5 + '\n')

#23 Schreiben der aufgezeichneten Daten in eine CSV-Datei
with open("text_aw.csv", 'w', encoding='utf-8') as w:
    w.write('quelle,index_string,inhalt,index_binar\n')
    w.write('000:ballast,ballast,ballast,0\n')  #24 Schreiben einer Platzhalterzeile
    w.write("".join(recorded))  #25 Schreiben der aufgezeichneten Daten
    

mom = []  #26 Eine leere Liste zum Speichern der Daten

#27 Lesen der CSV-Datei und Filtern von Zeilen mit ':N:' in der zweiten Spalte
with open('text_aw.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    for line in reader:
        if ':N:' not in line[1]:  #28 Wenn ':N:' nicht in der zweiten Spalte enthalten ist
            mom.append(line)  #29 Die Zeile der Liste mom hinzufügen
            
#30 Schreiben der gefilterten Daten in eine Textdatei.
with open('text_ax.txt', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(mom)  #26 Schreiben der Liste in die Datei
    
#31 Lesen der Textdatei und Formatieren der Daten
with open('text_ax.txt', 'r', encoding='utf-8') as file:
    filedata = file.read()
filedata = (filedata.replace(']","[', "\n").replace('"[', '').replace(']"', '').replace(" '", "")
            .replace("'", ""))

#32 Schreiben der formatierten Daten in eine CSV-Datei
with open('text_ay.csv', 'w', encoding='utf-8') as file:
    file.write(filedata)

# %%
import csv
from collections import defaultdict

# Pfad zur CSV-Datei
csv_datei = 'text_ay.csv'

# Datenstruktur zum Speichern der Häufigkeit der Kombinationen
kombinationen = defaultdict(int)

# Die CSV-Datei lesen und die Häufigkeit der Kombinationen zählen
with open(csv_datei, mode='r', newline='', encoding='utf-8') as file:
    reader = csv.DictReader(file)
    rows = list(reader)

    for row in rows:
        kombination = (row['quelle'], row['index_string'])
        kombinationen[kombination] += 1

# Die Häufigkeit der Kombinationen erneut initialisieren, um Bearbeitungen durchzuführen
kombinationen = defaultdict(int)

# Die CSV-Datei bearbeiten, wobei nur wiederholte Kombinationen ein 'x' erhalten
for row in rows:
    kombination = (row['quelle'], row['index_string'])
    kombinationen[kombination] += 1
    if kombinationen[kombination] > 1:
        row['index_string'] += '_x'

# Die bearbeitete CSV-Datei unter demselben Namen speichern
with open(csv_datei, mode='w', newline='', encoding='utf-8') as file:
    writer = csv.DictWriter(file, fieldnames=rows[0].keys())
    writer.writeheader()
    writer.writerows(rows)

print(f"Die Datei {csv_datei} wurde erfolgreich bearbeitet und gespeichert.")
# Out:
# Die Datei text_ay.csv wurde erfolgreich bearbeitet und gespeichert.

# %%
# import csv
# from collections import defaultdict

# # Pfad zur CSV-Datei
# csv_datei = 'text_ay.csv'

# # Datenstruktur zum Speichern der Häufigkeit der Kombinationen
# kombinationen = defaultdict(int)

# # Die CSV-Datei lesen und die Häufigkeit der Kombinationen zählen
# with open(csv_datei, mode='r', newline='', encoding='utf-8') as file:
#     reader = csv.DictReader(file)
#     rows = list(reader)

#     for row in rows:
#         kombination = (row['quelle'], row['index_string'])
#         kombinationen[kombination] += 1

# # Die Häufigkeit der Kombinationen erneut initialisieren, um Bearbeitungen durchzuführen
# kombinationen = defaultdict(int)

# # Die CSV-Datei bearbeiten, wobei nur wiederholte Kombinationen ein 'x' erhalten
# for row in rows:
#     kombination = (row['quelle'], row['index_string'])
#     kombinationen[kombination] += 1
#     if kombinationen[kombination] > 1:
#         row['index_string'] += '_x'

# # Die bearbeitete CSV-Datei unter demselben Namen speichern
# with open(csv_datei, mode='w', newline='', encoding='utf-8') as file:
#     writer = csv.DictWriter(file, fieldnames=rows[0].keys())
#     writer.writeheader()
#     writer.writerows(rows)

# print(f"Die Datei {csv_datei} wurde erfolgreich bearbeitet und gespeichert.")

# %%
# import csv
# from collections import defaultdict, deque

# # Pfad zur CSV-Datei
# csv_datei = 'text_ay.csv'

# # Datenstruktur zum Speichern der letzten Vorkommen jeder Kombination
# letzte_vorkommen = defaultdict(deque)

# # Die CSV-Datei lesen und die Häufigkeit der Kombinationen zählen
# with open(csv_datei, mode='r', newline='', encoding='utf-8') as file:
#     reader = csv.DictReader(file)
#     rows = list(reader)

# # Variable für die Bearbeitung
# kombinationen_mit_x = set()

# # Die CSV-Datei bearbeiten, wobei nur wiederholte Kombinationen ein 'x' erhalten
# for i, row in enumerate(rows):
#     kombination = (row['quelle'], row['index_string'])

#     # Wenn diese Kombination bereits früher vorkam, prüfen, ob es eine echte Wiederholung ist
#     if kombination in letzte_vorkommen and letzte_vorkommen[kombination]:
#         letzte_position = letzte_vorkommen[kombination][-1]
#         # Überprüfen, ob es zwischen den zwei Vorkommen unterschiedliche Kombinationen gibt
#         if any(
#             (rows[j]['quelle'], rows[j]['index_string']) != kombination 
#             for j in range(letzte_position + 3, i)
#         ):
#             row['index_string'] += '_x'
#             kombinationen_mit_x.add(kombination)

#     # Aktuelle Position der Kombination speichern
#     letzte_vorkommen[kombination].append(i)

# # Die bearbeitete CSV-Datei unter demselben Namen speichern
# with open(csv_datei, mode='w', newline='', encoding='utf-8') as file:
#     writer = csv.DictWriter(file, fieldnames=rows[0].keys())
#     writer.writeheader()
#     writer.writerows(rows)

# print(f"Die Datei {csv_datei} wurde erfolgreich bearbeitet und gespeichert.")

# %%
# import csv
# from collections import defaultdict, deque

# # Pfad zur CSV-Datei
# csv_datei = 'text_ay.csv'

# # Datenstruktur zum Speichern der letzten Vorkommen jeder Kombination und der Wiederholungszähler
# letzte_vorkommen = defaultdict(deque)
# wiederholungen = defaultdict(int)

# # Die CSV-Datei lesen
# with open(csv_datei, mode='r', newline='', encoding='utf-8') as file:
#     reader = csv.DictReader(file)
#     rows = list(reader)

# # Die CSV-Datei bearbeiten, wobei der Vorkommenszähler zur Anzahl der '_x' führt
# for i, row in enumerate(rows):
#     kombination = (row['quelle'], row['index_string'])
    
#     # Zähler für diese Kombination erhöhen
#     wiederholungen[kombination] += 1

#     # Wenn diese Kombination bereits früher vorkam, prüfen, ob es eine echte Wiederholung ist
#     if kombination in letzte_vorkommen and letzte_vorkommen[kombination]:
#         letzte_position = letzte_vorkommen[kombination][-1]
#         # Überprüfen, ob es zwischen den zwei Vorkommen unterschiedliche Kombinationen gibt
#         if any(
#             (rows[j]['quelle'], rows[j]['index_string']) != kombination 
#             for j in range(letzte_position + le_po, i)
#         ):
#             # Füge so viele '_x' hinzu, wie das wievielte Vorkommen es ist
#             row['index_string'] +='_' +'x' * (wiederholungen[kombination]-1)
    
#     # Aktuelle Position der Kombination speichern
#     letzte_vorkommen[kombination].append(i)

# # Die bearbeitete CSV-Datei unter demselben Namen speichern
# with open(csv_datei, mode='w', newline='', encoding='utf-8') as file:
#     writer = csv.DictWriter(file, fieldnames=rows[0].keys())
#     writer.writeheader()
#     writer.writerows(rows)

# print(f"Die Datei {csv_datei} wurde erfolgreich bearbeitet und gespeichert.")

# %%
from collections import Counter 

df = pd.read_csv('text_ay.csv', encoding='utf-8')  #33 Einlesen der Daten aus einer CSV-Datei in ein DataFrame

#34 Eine Funktion zur Formatierung der Markupelemente eines Märchens
def ep_format(ep_full):
    return (ep_full.split(':'))[0]

#35 Eine Funktion zur Formatierung des Typs eines Märchens.
def ep_name_format(ep_full):
    sublist = (ep_full)
    name = ""
    for strg in sublist:
        name += strg
    return name

#36 Eine Funktion zum Vergleich von Quellen in einem DataFrame.
def quellenvergleich(df, i1, i2):
    return df.quelle[i1] == df.quelle[i2]

#37 Eine Funktion zur Analyse von Abschnitten eines Märchens.
def ast(gesep, df):
    ep_tree = {}  #38 Ein leeres Dictionary zur Speicherung der Analyseergebnisse.
    a_liste = []  #39 Eine leere Liste zur Speicherung von Startabschnitten.
    z_liste = []  #40 Eine leere Liste zur Speicherung von Endabschnitten.
    df_len = len(df.index_string)  #36 Die Anzahl der Zeilen im DataFrame.
    for i, ep in enumerate(df.index_string):  #41 Iteration durch die 'Index-String' des DataFrames.
        if gesep == ep:  #42 Wenn der aktuelle Abschnitt dem gesuchten Abschnitt entspricht.
            if (i > 0) and (quellenvergleich(df, i, i - 1)):  #43 Wenn es einen vorherigen Abschnitt gibt und die Quellen übereinstimmen.
                a = df.index_string[i - 1]  #44 Der vorherige Abschnitt wird als Startabschnitt betrachtet.
            else:
                a = 'Anf-' + ep_name_format(gesep)  #45 Ansonsten wird ein neuer Startabschnitt erstellt.
            if (i < df_len - 1):  #46 Wenn es einen nächsten Abschnitt gibt.
                if not (quellenvergleich(df, i, i + 1)):  #47 Wenn die Quellen des nächsten Abschnitts unterschiedlich sind.
                    z = 'End-' + ep_name_format(gesep)  #48 Der aktuelle Abschnitt wird als Endabschnitt betrachtet.
                else:
                    z = df.index_string[i + 1]  #49 Ansonsten wird der nächste Abschnitt als Endabschnitt betrachtet.
            else:
                z = 'End-' + ep_name_format(gesep)  #50 Wenn es keinen nächsten Abschnitt gibt, wird ein neuer Endabschnitt erstellt.
            a_liste.append(a)  #51 Startabschnitt wird der Liste hinzugefügt.
            z_liste.append(z)  #52 Endabschnitt wird der Liste hinzugefügt.
    return {gesep: [Counter(a_liste), Counter(z_liste)]}  #53 Rückgabe der Analyseergebnisse als Dictionary.

# %%
def alle_aeste(gesep, df):
    episoden_baeume = {}  #54 Ein leeres Dictionary zur Speicherung der Analyseergebnisse.
    ep_list = []  #55 Eine leere Liste zur Speicherung von Episoden.
    for ep_full in df.index_string:  #56 Iteration durch die 'Index-String' des DataFrames.
        ep = ep_format(ep_full)  #57 Formatierung der Episode.
        if gesep == ep:  #58 Wenn die gesuchte Episode gefunden wird.
            ep_list.append(ep_full)  #59 Die Episode wird zur Liste hinzugefügt.
    for ep in set(ep_list):  #60 Iteration durch jede einzigartige Episode in der Liste.
        episoden_baeume.update(ast(ep, df))  #61 Die Analyseergebnisse für jede Episode werden dem Dictionary hinzugefügt.
    return episoden_baeume  #62 Rückgabe des Dictionary mit den Analyseergebnissen.

# %%
def key_val_printer(d):
    for k, v in d.items():
        print(v, k, sep=':')
def baum_printer(baeume: dict, baum: str):
    key_val_printer(baeume[baum][0])
    print(65*'-')
    print(sum(baeume[baum][0].values()),':', baum)
    print(65*'-')
    key_val_printer(baeume[baum][1]) 
def wald_printer(wald: dict):
    for baum in (wald.keys()): # for baum in sorted(wald.keys():
        baum_printer (wald, baum)
        print(65*'=')

# %%
#63 Die Variable 'graph' wird mit den Analyseergebnissen für die Episode 'mZahl' initialisiert.
graph = alle_aeste(mZahl, df)
graph_update()
wald_printer(graph)
# Out:
# 1:a550:HF:VOGEL_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:h:FREIHEITSBERAUBUNG:rHD_rBZ
# -----------------------------------------------------------------
# 1:a550:f:REITTIER_besorgen:rHD_rBZ
# =================================================================
# 1:a550:F:HOCHZEIT_verschieben:rHH_rBZ_fHD
# -----------------------------------------------------------------
# 1 : a550:F:PARALYSIERUNG_beheben:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1:a550:F:Bestrafung_erfolgt:rHD_fHD
# =================================================================
# 3:a550:F:Wache_halten:rHD_rZM
# -----------------------------------------------------------------
# 3 : a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM
# -----------------------------------------------------------------
# 1:a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rHH
# 1:a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rHH_fHD
# 1:a550:f:NEUGIER_auslösen:rHD_fHD
# =================================================================
# 1:a550:f:VOGEL_herbeiholen:fHD
# -----------------------------------------------------------------
# 1 : a550:F:VOGEL_herbeiholen:fHD_x
# -----------------------------------------------------------------
# 1:a550:f:VOGEL_herbeiholen:fHD_x
# =================================================================
# 1:a550:H:Ortswechsel_durchführen:rHD_rHF
# 1:a550:f:Die_SCHÖNE_herbeiholen:rHD_rBZ
# -----------------------------------------------------------------
# 2 : a550:HF:Die_SCHÖNE_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1:a550:F:Die_SCHÖNE_erfassen:rHD_rZO
# 1:a550:H:Ortswechsel_durchführen:rHD_rHF_x
# =================================================================
# 2:a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# 1:a550:H:Ortswechsel_durchführen:rHD_rHF
# -----------------------------------------------------------------
# 3 : a550:HF:VOGEL_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1:a550:F:VOGEL_erfassen:rHD_rZO
# 1:a550:h:FREIHEITSBERAUBUNG:rHD_rBZ
# 1:a550:f:TABU_Sonstiges:rHD_rHF
# =================================================================
# 2:a550:HF:REITTIER_erfassen:rST_rVB
# -----------------------------------------------------------------
# 2 : a550:H:Handlungsanweisungen_aus_zweiter_Hand:rST_rVB
# -----------------------------------------------------------------
# 1:a550:H:REITTIER_erfassen:rHD_rZO
# 1:a550:F:REITTIER_erfassen:rHD_rZO
# =================================================================
# 1:a550:F:VOGEL_herbeiholen:fHD_x
# -----------------------------------------------------------------
# 1 : a550:f:VOGEL_herbeiholen:fHD_x
# -----------------------------------------------------------------
# 1:a550:F:Gutes_Benehmen:rHD_rST
# =================================================================
# 1:a550:h:MISSETAT_planen:fHD
# -----------------------------------------------------------------
# 1 : a550:h:MISSETAT_wie_Behinderung:rHD_fHD_fPP
# -----------------------------------------------------------------
# 1:a550:h:MISSETAT_wie_Aneignung:rHD_fHD_fPP
# =================================================================
# 5:a550:F:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB
# -----------------------------------------------------------------
# 5 : a550:HF:REITTIER_erfassen:rST_rVB
# -----------------------------------------------------------------
# 2:a550:H:Handlungsanweisungen_aus_zweiter_Hand:rST_rVB
# 3:a550:H:Handlungsanweisungen_aus_zweiter_Hand:rHD_rVB
# =================================================================
# 2:a550:f:Wache_halten:fHD_x
# 1:a550:H:Um_einen_Auftrag_werben:rHD_rHH
# -----------------------------------------------------------------
# 3 : a550:F:Wache_halten:rHD_rZM
# -----------------------------------------------------------------
# 3:a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM
# =================================================================
# 3:a550:f:Wache_halten:fHD
# -----------------------------------------------------------------
# 3 : a550:F:Wache_halten:fHD_x
# -----------------------------------------------------------------
# 3:a550:f:Wache_halten:fHD_x
# =================================================================
# 1:a550:H:Gutes_Benehmen:rHD_rST
# -----------------------------------------------------------------
# 1 : a550:HF:REITTIER_besorgen:rHD_rST
# -----------------------------------------------------------------
# 1:a550:F:REITTIER_erhalten:rHD_rHF
# =================================================================
# 1:a550:f:TABU_Sonstiges:rHD_rHF_x
# -----------------------------------------------------------------
# 1 : a550:F:REITTIER_erfassen:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1:a550:h:TABU_nachgehen:rHD_rBZ_rZO_x
# =================================================================
# 1:a550:h:FREIHEITSBERAUBUNG:rHD_rBZ
# 1:a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 2 : a550:f:REITTIER_besorgen:rHD_rBZ
# -----------------------------------------------------------------
# 1:a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_x
# 1:a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# =================================================================
# 1:a550:F:Gutes_Benehmen:rHD_rST
# -----------------------------------------------------------------
# 1 : a550:H:Gutes_Benehmen:rHD_rST
# -----------------------------------------------------------------
# 1:a550:HF:REITTIER_besorgen:rHD_rST
# =================================================================
# 1:a550:H:Auf_dem_Heimweg:rHD_rHF_fPP
# 1:a550:F:Eine_BEHINDERUNG_beheben:rHD_rHF
# -----------------------------------------------------------------
# 2 : a550:F:ZWANGSEHE_Drohung_beheben:rHD_rVB
# -----------------------------------------------------------------
# 1:a550:H:NEUGIER_auslösen:rHD_rVB
# 1:a550:F:IDENTITÄT_ändern:rHD_rVB
# =================================================================
# 1:a550:H:Zweikampf:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1 : a550:h:Zweikampf:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1:a550:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rBZ_rZO
# =================================================================
# 1:a550:F:IDENTITÄT_ändern:rHD_rVB
# -----------------------------------------------------------------
# 1 : a550:f:Held_erkennen:rHD_rZO_fHD
# -----------------------------------------------------------------
# 1:a550:F:Held_erkennen:rHD_rZO_fHD
# =================================================================
# 2:a550:f:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD
# -----------------------------------------------------------------
# 2 : a550:F:HOCHZEIT_verschieben:rHH_rZO_fHD
# -----------------------------------------------------------------
# 2:a550:F:PARALYSIERUNG_beheben:rZO_rZO
# =================================================================
# 1:a550:f:Held_erkennen:rHD_rZO_fHD
# -----------------------------------------------------------------
# 1 : a550:F:Held_erkennen:rHD_rZO_fHD
# -----------------------------------------------------------------
# 1:a550:F:Bestrafung_erfolgt:rHD_rZO_fHD
# =================================================================
# 1:Anf-a550:F:REITTIER_besorgen:rHH
# -----------------------------------------------------------------
# 1 : a550:F:REITTIER_besorgen:rHH
# -----------------------------------------------------------------
# 1:a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD
# =================================================================
# 3:Anf-a550:F:REITTIER_besorgen:rHD_rHH_fHD
# -----------------------------------------------------------------
# 3 : a550:F:REITTIER_besorgen:rHD_rHH_fHD
# -----------------------------------------------------------------
# 3:a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD
# =================================================================
# 1:a550:H:Den_Vorgang_deuten:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1 : a550:H:Dem_VERLUST_entgegentreten:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1:a550:h:KONTAKT_abbrechen:rHD_fHD
# =================================================================
# 1:a550:F:ZWANGSEHE_Drohung_beheben:rHD_rVB
# -----------------------------------------------------------------
# 1 : a550:H:NEUGIER_auslösen:rHD_rVB
# -----------------------------------------------------------------
# 1:a550:H:Einer_Einladung_folgen:rHD_rHF
# =================================================================
# 2:a550:F:Bestrafung_erfolgt:rHD_fHD
# -----------------------------------------------------------------
# 2 : a550:F:Heiraten:rHD_rZO
# -----------------------------------------------------------------
# 2:End-a550:F:Heiraten:rHD_rZO
# =================================================================
# 1:a550:F:Ortswechsel_durchführen:rHD_rBZ
# -----------------------------------------------------------------
# 1 : a550:f:TODESAUFTRAG:rBZ_fHF
# -----------------------------------------------------------------
# 1:a550:unklar:#:fHD_fST
# =================================================================
# 1:a550:f:Wache_halten:fHD_x
# -----------------------------------------------------------------
# 1 : a550:H:Um_einen_Auftrag_werben:rHD_rHH
# -----------------------------------------------------------------
# 1:a550:F:Wache_halten:rHD_rZM
# =================================================================
# 1:a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1 : a550:F:REITTIER_besorgen:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1:a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ_x
# =================================================================
# 1:a550:h:Wache_halten:fHD
# -----------------------------------------------------------------
# 1 : a550:h:Sandwich:fHD
# -----------------------------------------------------------------
# 1:a550:Hh:Wache_halten:rHD_rAN
# =================================================================
# 3:a550:HF:REITTIER_erfassen:rST_rVB
# -----------------------------------------------------------------
# 3 : a550:H:Handlungsanweisungen_aus_zweiter_Hand:rHD_rVB
# -----------------------------------------------------------------
# 3:a550:H:REITTIER_erfassen:rHD_rZO
# =================================================================
# 1:a550:H:Ortswechsel_durchführen:rHD_rHF_x
# -----------------------------------------------------------------
# 1 : a550:H:Zweikampf:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1:a550:h:Zweikampf:rHD_rBZ_rZO
# =================================================================
# 1:a550:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1 : a550:F:Krisenursachen_ergründen:rHD_rZO
# -----------------------------------------------------------------
# 1:a550:f:Abtretung_der_Schönen_stehet_bevor:rHD_rZO
# =================================================================
# 1:a550:H:Einer_Einladung_folgen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:H:Bestrafung_erfolgt:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1:a550:H:Held_erkennen:rHD_rHH_fHD
# =================================================================
# 3:Anf-a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# -----------------------------------------------------------------
# 3 : a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# -----------------------------------------------------------------
# 1:a550:F:Wache_halten:fHD
# 2:a550:F:Wache_halten:rHD_rHH_fHD
# =================================================================
# 1:a550:HF:VOGEL_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:F:VOGEL_erfassen:rHD_rZO
# -----------------------------------------------------------------
# 1:End-a550:F:VOGEL_erfassen:rHD_rZO
# =================================================================
# 1:a550:f:ZWANGSEHE_Drohung_beheben:rHD_fHD
# -----------------------------------------------------------------
# 1 : a550:H:ZWANGSEHE_Drohung_beheben:rHD_fHD
# -----------------------------------------------------------------
# 1:a550:H:Bestrafung_erfolgt:rHD_fHD
# =================================================================
# 1:a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM
# -----------------------------------------------------------------
# 1 : a550:f:NEUGIER_auslösen:rHD_fHD
# -----------------------------------------------------------------
# 1:a550:H:Um_einen_Auftrag_werben:rHH_fHD
# =================================================================
# 1:a550:f:NEUGIER_auslösen:rHD_fHD
# -----------------------------------------------------------------
# 1 : a550:H:Um_einen_Auftrag_werben:rHH_fHD
# -----------------------------------------------------------------
# 1:a550:f:KONTAKT_abbrechen:fHD
# =================================================================
# 1:a554:f:TABU_Sonstiges:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:Hh:VOGEL_erfassen:rHD_rZO
# -----------------------------------------------------------------
# 1:a550:h:TABU_nachgehen:rHD_rZO
# =================================================================
# 2:a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# -----------------------------------------------------------------
# 2 : a550:F:Wache_halten:rHD_rHH_fHD
# -----------------------------------------------------------------
# 2:a550:F:Wache_halten:fHD
# =================================================================
# 2:a550:F:PARALYSIERUNG_beheben:rBZ_rZO
# -----------------------------------------------------------------
# 2 : a550:F:Bestrafung_erfolgt:rHD_rBZ_fHD
# -----------------------------------------------------------------
# 2:a550:F:Heiraten:rHD_rBZ_fHD
# =================================================================
# 1:a550:h:Sandwich:fHD
# -----------------------------------------------------------------
# 1 : a550:Hh:Wache_halten:rHD_rAN
# -----------------------------------------------------------------
# 1:a550:H:Wegweisung_erpressen:rHD_rAN
# =================================================================
# 3:a550:F:Wache_halten:fHD
# -----------------------------------------------------------------
# 3 : a550:f:Wache_halten:fHD
# -----------------------------------------------------------------
# 3:a550:F:Wache_halten:fHD_x
# =================================================================
# 1:a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1 : a550:F:Die_SCHÖNE_herbeiholen:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1:a550:F:Auf_dem_Heimweg:rHD_rHF_rZO
# =================================================================
# 8:a550:h:MISSETAT_planen:rHD_fHD
# 1:a530:H:Ende:N
# -----------------------------------------------------------------
# 9 : a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# -----------------------------------------------------------------
# 4:a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD
# 2:a550:f:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD
# 1:a550:f:Heldentat_VORTÄUSCHEN:rHH_rBZ_fHD
# 1:a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# 1:a550:F:PARALYSIERUNG_beheben:rHD_rZO
# =================================================================
# 1:a550:H:Bestrafung_erfolgt:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1 : a550:H:Held_erkennen:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1:a550:H:Heiraten:rHD_fPP
# =================================================================
# 1:a550:H:Handlungsanweisungen_aus_zweiter_Hand:rST_rVB
# 3:a550:H:Handlungsanweisungen_aus_zweiter_Hand:rHD_rVB
# -----------------------------------------------------------------
# 4 : a550:H:REITTIER_erfassen:rHD_rZO
# -----------------------------------------------------------------
# 3:a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM_rZO
# 1:a531:Hh:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM_rZO
# =================================================================
# 1:a550:f:KRANKHEIT:rHH_rZO
# -----------------------------------------------------------------
# 1 : a550:F:VOGEL_herbeiholen:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1:a550:F:VOGEL_herbeiholen:fHD
# =================================================================
# 1:a550:F:REITTIER_besorgen:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1 : a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ_x
# -----------------------------------------------------------------
# 1:a550:F:VOGEL_herbeiholen:rHD_rHF_rBZ
# =================================================================
# 1:a550:Hh:VOGEL_erfassen:rHD_rZO
# -----------------------------------------------------------------
# 1 : a550:h:TABU_nachgehen:rHD_rZO
# -----------------------------------------------------------------
# 1:a550:h:KONTAKT_abbrechen:rHD_rZO
# =================================================================
# 1:a550:f:REITTIER_besorgen:rHD_rBZ
# 1:a550:f:Die_SCHÖNE_herbeiholen:rHD_rZO
# -----------------------------------------------------------------
# 2 : a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_x
# -----------------------------------------------------------------
# 1:a550:HF:REITTIER_erfassen:rHD_rHF
# 1:a550:H:Ortswechsel_durchführen:rHD_rHF
# =================================================================
# 2:a531:f:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# 1:a531:f:Sich_einem_magischen_Eingriff_unterziehen:rAN
# 1:a550:F:Sorge_um_Freikaufsbedürftige:rHD_rVB
# 1:a550:F:REITTIER_erfassen:rHD_rZO
# 1:a550:F:Auf_dem_Heimweg:rHD_rHF_rZO
# -----------------------------------------------------------------
# 6 : a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# -----------------------------------------------------------------
# 4:a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD_x
# 1:a550:h:MISSETAT_planen:fHD
# 1:a550:h:MISSETAT_planen:rHD_fHD
# =================================================================
# 4:a550:h:Den_ALTERNATIVEN_nachgehen:rHD_fHD
# 1:a550:F:Ortswechsel_durchführen:rHD
# -----------------------------------------------------------------
# 5 : a550:F:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB
# -----------------------------------------------------------------
# 5:a550:HF:REITTIER_erfassen:rST_rVB
# =================================================================
# 1:a550:H:Sorge_um_Freikaufsbedürftige:rHD_fHD_fPP
# 1:a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# -----------------------------------------------------------------
# 2 : a550:h:MISSETAT_planen:fHD
# -----------------------------------------------------------------
# 1:a550:h:MISSETAT_wie_Behinderung:rHD_fHD_fPP
# 1:a550:h:MISSETAT_wie_Behinderung:fHD
# =================================================================
# 1:a550:H:KONTAKT_wiederherstellen:rHD_fHD_fPP
# -----------------------------------------------------------------
# 1 : a550:H:Sorge_um_Freikaufsbedürftige:rHD_fHD_fPP
# -----------------------------------------------------------------
# 1:a550:h:MISSETAT_planen:fHD
# =================================================================
# 1:a550:f:TODESAUFTRAG:rBZ_fHF
# -----------------------------------------------------------------
# 1 : a550:unklar:#:fHD_fST
# -----------------------------------------------------------------
# 1:a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# =================================================================
# 2:a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD
# -----------------------------------------------------------------
# 2 : a550:F:PARALYSIERUNG_beheben:rBZ_rZO
# -----------------------------------------------------------------
# 2:a550:F:Bestrafung_erfolgt:rHD_rBZ_fHD
# =================================================================
# 2:a550:F:Bestrafung_erfolgt:rHD_rBZ_fHD
# -----------------------------------------------------------------
# 2 : a550:F:Heiraten:rHD_rBZ_fHD
# -----------------------------------------------------------------
# 2:End-a550:F:Heiraten:rHD_rBZ_fHD
# =================================================================
# 1:a550:F:VOGEL_herbeiholen:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1 : a550:F:VOGEL_herbeiholen:fHD
# -----------------------------------------------------------------
# 1:a550:f:VOGEL_herbeiholen:fHD
# =================================================================
# 1:a550:h:MISSETAT_planen:fHD
# -----------------------------------------------------------------
# 1 : a550:h:MISSETAT_wie_Behinderung:fHD
# -----------------------------------------------------------------
# 1:a550:F:Eine_BEHINDERUNG_beheben:rHD_rHF
# =================================================================
# 1:a550:f:Abtretung_der_Schönen_stehet_bevor:rHD_rZO
# -----------------------------------------------------------------
# 1 : a550:HF:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rZO
# -----------------------------------------------------------------
# 1:a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ
# =================================================================
# 1:a550:F:REITTIER_erfassen:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1 : a550:h:TABU_nachgehen:rHD_rBZ_rZO_x
# -----------------------------------------------------------------
# 1:a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO_x
# =================================================================
# 1:a550:Hh:REITTIER_erfassen:rHD_rBZ_rZO
# 1:a550:H:VOGEL_erfassen:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 2 : a550:h:TABU_nachgehen:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 2:a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO
# =================================================================
# 1:a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM
# -----------------------------------------------------------------
# 1 : a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1:a554:F:Sorge_um_Hungernde_oder_Durstige:rHD_rHF
# =================================================================
# 1:a550:HF:Die_SCHÖNE_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:F:Die_SCHÖNE_erfassen:rHD_rZO
# -----------------------------------------------------------------
# 1:a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ
# =================================================================
# 1:a550:F:VOGEL_herbeiholen:fHD
# -----------------------------------------------------------------
# 1 : a550:f:VOGEL_herbeiholen:fHD
# -----------------------------------------------------------------
# 1:a550:F:VOGEL_herbeiholen:fHD_x
# =================================================================
# 1:a550:h:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# -----------------------------------------------------------------
# 1 : a550:F:Wache_halten:rHH
# -----------------------------------------------------------------
# 1:a550:h:Wache_halten:fHD
# =================================================================
# 1:a550:F:ZWANGSEHE_Drohung_beheben:rHD_rVB
# -----------------------------------------------------------------
# 1 : a550:F:IDENTITÄT_ändern:rHD_rVB
# -----------------------------------------------------------------
# 1:a550:f:Held_erkennen:rHD_rZO_fHD
# =================================================================
# 1:a550:f:Heldentat_VORTÄUSCHEN:rHH_rBZ_fHD
# -----------------------------------------------------------------
# 1 : a550:F:HOCHZEIT_verschieben:rHH_rBZ_fHD
# -----------------------------------------------------------------
# 1:a550:F:PARALYSIERUNG_beheben:rHD_rBZ_rZO
# =================================================================
# 7:a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD
# -----------------------------------------------------------------
# 7 : a550:h:Den_ALTERNATIVEN_nachgehen:rHD_fHD
# -----------------------------------------------------------------
# 4:a550:F:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB
# 1:a550:F:Ortswechsel_durchführen:rHD
# 1:a554:H:TREUEN_HELFER_erhalten:rHD_rHF
# 1:a550:F:REITTIER_erfassen:rHD_rZO
# =================================================================
# 2:a550:F:HOCHZEIT_verschieben:rHH_rZO_fHD
# 1:a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD
# -----------------------------------------------------------------
# 3 : a550:F:PARALYSIERUNG_beheben:rZO_rZO
# -----------------------------------------------------------------
# 2:a550:F:Bestrafung_erfolgt:rHD_fHD
# 1:a550:F:Heiraten:N
# =================================================================
# 1:a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_x
# 1:a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# -----------------------------------------------------------------
# 2 : a550:HF:REITTIER_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1:a550:f:TABU_Sonstiges:rHD_rHF
# 1:a550:f:TABU_Sonstiges:rHD_rHF_x
# =================================================================
# 1:a550:f:TABU_Sonstiges:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:H:VOGEL_erfassen:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1:a550:h:TABU_nachgehen:rHD_rBZ_rZO
# =================================================================
# 1:a550:F:REITTIER_erhalten:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:F:Ortswechsel_durchführen:rHD_rBZ
# -----------------------------------------------------------------
# 1:a550:f:TODESAUFTRAG:rBZ_fHF
# =================================================================
# 1:a550:F:VOGEL_herbeiholen:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1 : a550:F:Sorge_um_Freikaufsbedürftige:rHD_rVB
# -----------------------------------------------------------------
# 1:a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# =================================================================
# 1:a550:H:Um_einen_Auftrag_werben:rHH_fHD_x
# -----------------------------------------------------------------
# 1 : a550:f:KONTAKT_abbrechen:fHD_x
# -----------------------------------------------------------------
# 1:a550:H:Um_einen_Auftrag_werben:rHD_rHH_x
# =================================================================
# 1:a550:h:Den_ALTERNATIVEN_nachgehen:rHD_fHD
# -----------------------------------------------------------------
# 1 : a550:F:Ortswechsel_durchführen:rHD
# -----------------------------------------------------------------
# 1:a550:F:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB
# =================================================================
# 2:a550:h:TABU_nachgehen:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 2 : a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1:a550:f:Die_SCHÖNE_herbeiholen:rHD_rZO
# 1:a550:f:REITTIER_besorgen:rHD_rBZ
# =================================================================
# 1:a550:F:IDENTITÄT_ändern:rHD_fHD
# -----------------------------------------------------------------
# 1 : a550:f:ZWANGSEHE_Drohung_beheben:rHD_fHD
# -----------------------------------------------------------------
# 1:a550:H:ZWANGSEHE_Drohung_beheben:rHD_fHD
# =================================================================
# 1:a300:F:Eine_BEHINDERUNG_beheben:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:F:IDENTITÄT_ändern:rHD_fHD
# -----------------------------------------------------------------
# 1:a550:f:ZWANGSEHE_Drohung_beheben:rHD_fHD
# =================================================================
# 1:a550:unklar:#:fHD_fST
# 1:a550:h:KONTAKT_abbrechen:rHD_rZO
# 1:a550:f:REITTIER_besorgen:rHD_rBZ
# -----------------------------------------------------------------
# 3 : a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# -----------------------------------------------------------------
# 2:a550:HF:VOGEL_erfassen:rHD_rHF
# 1:a550:HF:REITTIER_erfassen:rHD_rHF
# =================================================================
# 1:a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD
# -----------------------------------------------------------------
# 1 : a550:F:Schicksalsbestimmender_Weisung_folgen:rHD
# -----------------------------------------------------------------
# 1:a554:F:Den_Einbrecher_begnadigen:rHD_rHF
# =================================================================
# 1:a550:H:Dem_VERLUST_entgegentreten:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1 : a550:h:KONTAKT_abbrechen:rHD_fHD
# -----------------------------------------------------------------
# 1:a300A:H:Ortswechsel_durchführen:rHD_fPP
# =================================================================
# 1:a550:F:Bestrafung_erfolgt:rHD_fHD
# 1:a550:F:PARALYSIERUNG_beheben:rZO_rZO
# -----------------------------------------------------------------
# 2 : a550:F:Heiraten:N
# -----------------------------------------------------------------
# 2:End-a550:F:Heiraten:N
# =================================================================
# 1:a550:Hh:Wache_halten:rHD_rAN
# -----------------------------------------------------------------
# 1 : a550:H:Wegweisung_erpressen:rHD_rAN
# -----------------------------------------------------------------
# 1:a550:H:Den_Vorgang_deuten:rHD_rHH_fHD
# =================================================================
# 1:a550:H:NEUGIER_auslösen:rHD_rVB
# -----------------------------------------------------------------
# 1 : a550:H:Einer_Einladung_folgen:rHD_rHF
# -----------------------------------------------------------------
# 1:a550:H:Bestrafung_erfolgt:rHD_rHH_fHD
# =================================================================
# 1:a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM
# -----------------------------------------------------------------
# 1 : a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rHH
# -----------------------------------------------------------------
# 1:a554:F:Sorge_um_Hungernde_oder_Durstige:rHD_rST
# =================================================================
# 1:a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# -----------------------------------------------------------------
# 1 : a550:f:Heldentat_VORTÄUSCHEN:rHH_rBZ_fHD
# -----------------------------------------------------------------
# 1:a550:F:HOCHZEIT_verschieben:rHH_rBZ_fHD
# =================================================================
# 1:a550:h:MISSETAT_wie_Aneignung:rHD_fHD_fPP
# -----------------------------------------------------------------
# 1 : a550:h:SCHWEIGEPFLICHT_verhängen:rHD_fHD_fPP
# -----------------------------------------------------------------
# 1:a519:H:Mit_einer_anderen_behinderten_Person_einen_Bund_schließen:rHD_rHF
# =================================================================
# 1:a550:HF:Die_SCHÖNE_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:H:Ortswechsel_durchführen:rHD_rHF_x
# -----------------------------------------------------------------
# 1:a550:H:Zweikampf:rHD_rBZ_rZO
# =================================================================
# 1:a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ_x
# -----------------------------------------------------------------
# 1 : a550:F:VOGEL_herbeiholen:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1:a550:F:Sorge_um_Freikaufsbedürftige:rHD_rVB
# =================================================================
# 1:a550:F:Die_SCHÖNE_erfassen:rHD_rZO
# 1:a550:HF:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rZO
# -----------------------------------------------------------------
# 2 : a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1:a550:F:REITTIER_besorgen:rHD_rHF_rBZ
# 1:a550:F:Die_SCHÖNE_herbeiholen:rHD_rHF_rBZ
# =================================================================
# 1:a550:F:Krisenursachen_ergründen:rHD_rZO
# -----------------------------------------------------------------
# 1 : a550:f:Abtretung_der_Schönen_stehet_bevor:rHD_rZO
# -----------------------------------------------------------------
# 1:a550:HF:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rZO
# =================================================================
# 1:a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO_x
# -----------------------------------------------------------------
# 1 : a550:f:Die_SCHÖNE_herbeiholen:rHD_rBZ
# -----------------------------------------------------------------
# 1:a550:HF:Die_SCHÖNE_erfassen:rHD_rHF
# =================================================================
# 3:a550:F:Wache_halten:fHD_x
# -----------------------------------------------------------------
# 3 : a550:f:Wache_halten:fHD_x
# -----------------------------------------------------------------
# 2:a550:F:Wache_halten:rHD_rZM
# 1:a550:H:Um_einen_Auftrag_werben:rHD_rHH
# =================================================================
# 1:a531:Hh:FEHLENDEN_Gegenstand_erfassen:rHD_rBZ_rZO
# 1:a531:H:FEHLENDEN_Gegenstand_erfassen:rHD_rBZ_rZO
# 4:a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD_x
# 1:a530:H:Held_erkennen:rHD_fHD
# 1:a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# -----------------------------------------------------------------
# 8 : a550:h:MISSETAT_planen:rHD_fHD
# -----------------------------------------------------------------
# 8:a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# =================================================================
# 1:a550:h:MISSETAT_wie_Behinderung:fHD
# -----------------------------------------------------------------
# 1 : a550:F:Eine_BEHINDERUNG_beheben:rHD_rHF
# -----------------------------------------------------------------
# 1:a550:F:ZWANGSEHE_Drohung_beheben:rHD_rVB
# =================================================================
# 1:a550:F:Die_SCHÖNE_herbeiholen:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1 : a550:F:Auf_dem_Heimweg:rHD_rHF_rZO
# -----------------------------------------------------------------
# 1:a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# =================================================================
# 1:a550:H:ZWANGSEHE_Drohung_beheben:rHD_fHD
# -----------------------------------------------------------------
# 1 : a550:H:Bestrafung_erfolgt:rHD_fHD
# -----------------------------------------------------------------
# 1:End-a550:H:Bestrafung_erfolgt:rHD_fHD
# =================================================================
# 1:a550:H:Held_erkennen:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1 : a550:H:Heiraten:rHD_fPP
# -----------------------------------------------------------------
# 1:a550:H:Ende:rHD_fPP
# =================================================================
# 1:a550:F:REITTIER_erhalten:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rZO
# -----------------------------------------------------------------
# 1:End-a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rZO
# =================================================================
# 1:a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# 2:a550:F:Wache_halten:rHD_rHH_fHD
# -----------------------------------------------------------------
# 3 : a550:F:Wache_halten:fHD
# -----------------------------------------------------------------
# 3:a550:f:Wache_halten:fHD
# =================================================================
# 1:a550:H:Wegweisung_erpressen:rHD_rAN
# -----------------------------------------------------------------
# 1 : a550:H:Den_Vorgang_deuten:rHD_rHH_fHD
# -----------------------------------------------------------------
# 1:a550:H:Dem_VERLUST_entgegentreten:rHD_rHH_fHD
# =================================================================
# 2:a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# -----------------------------------------------------------------
# 2 : a550:f:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD
# -----------------------------------------------------------------
# 2:a550:F:HOCHZEIT_verschieben:rHH_rZO_fHD
# =================================================================
# 1:a550:H:Handlungsanweisungen_aus_zweiter_Hand:rST_rVB
# 1:a550:h:Den_ALTERNATIVEN_nachgehen:rHD_fHD
# -----------------------------------------------------------------
# 2 : a550:F:REITTIER_erfassen:rHD_rZO
# -----------------------------------------------------------------
# 1:a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM_rZO
# 1:a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# =================================================================
# 4:a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# -----------------------------------------------------------------
# 4 : a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD
# -----------------------------------------------------------------
# 2:a550:F:PARALYSIERUNG_beheben:rBZ_rZO
# 1:a550:F:PARALYSIERUNG_beheben:rZO_rZO
# 1:a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rPP
# =================================================================
# 4:a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# -----------------------------------------------------------------
# 4 : a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD_x
# -----------------------------------------------------------------
# 4:a550:h:MISSETAT_planen:rHD_fHD
# =================================================================
# 1:a550:F:Bestrafung_erfolgt:rHD_fHD
# -----------------------------------------------------------------
# 1 : a550:F:Heiraten:rHD_rPP
# -----------------------------------------------------------------
# 1:End-a550:F:Heiraten:rHD_rPP
# =================================================================
# 1:a300A:H:Zweikampf:rHD_rAN_x
# -----------------------------------------------------------------
# 1 : a550:H:KONTAKT_wiederherstellen:rHD_fHD_fPP
# -----------------------------------------------------------------
# 1:a550:H:Sorge_um_Freikaufsbedürftige:rHD_fHD_fPP
# =================================================================
# 1:a550:f:KONTAKT_abbrechen:fHD
# -----------------------------------------------------------------
# 1 : a550:H:Um_einen_Auftrag_werben:rHH_fHD_x
# -----------------------------------------------------------------
# 1:a550:f:KONTAKT_abbrechen:fHD_x
# =================================================================
# 1:a550:H:Heiraten:rHD_fPP
# -----------------------------------------------------------------
# 1 : a550:H:Ende:rHD_fPP
# -----------------------------------------------------------------
# 1:End-a550:H:Ende:rHD_fPP
# =================================================================
# 1:a550:F:Held_erkennen:rHD_rZO_fHD
# -----------------------------------------------------------------
# 1 : a550:F:Bestrafung_erfolgt:rHD_rZO_fHD
# -----------------------------------------------------------------
# 1:End-a550:F:Bestrafung_erfolgt:rHD_rZO_fHD
# =================================================================
# 1:Anf-a550:f:KRANKHEIT:rHH_rZO
# -----------------------------------------------------------------
# 1 : a550:f:KRANKHEIT:rHH_rZO
# -----------------------------------------------------------------
# 1:a550:F:VOGEL_herbeiholen:rHD_rHH_fHD
# =================================================================
# 1:a550:HF:REITTIER_besorgen:rHD_rST
# 1:a554:HF:REITTIER_besorgen:rHD_rST
# -----------------------------------------------------------------
# 2 : a550:F:REITTIER_erhalten:rHD_rHF
# -----------------------------------------------------------------
# 1:a550:F:Ortswechsel_durchführen:rHD_rBZ
# 1:a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rZO
# =================================================================
# 1:a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1 : a550:f:Die_SCHÖNE_herbeiholen:rHD_rZO
# -----------------------------------------------------------------
# 1:a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_x
# =================================================================
# 1:Anf-a550:h:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# -----------------------------------------------------------------
# 1 : a550:h:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# -----------------------------------------------------------------
# 1:a550:F:Wache_halten:rHH
# =================================================================
# 1:a550:H:Um_einen_Auftrag_werben:rHH_fHD
# -----------------------------------------------------------------
# 1 : a550:f:KONTAKT_abbrechen:fHD
# -----------------------------------------------------------------
# 1:a550:H:Um_einen_Auftrag_werben:rHH_fHD_x
# =================================================================
# 1:a550:f:VOGEL_herbeiholen:fHD_x
# -----------------------------------------------------------------
# 1 : a550:F:Gutes_Benehmen:rHD_rST
# -----------------------------------------------------------------
# 1:a550:H:Gutes_Benehmen:rHD_rST
# =================================================================
# 1:a550:f:TABU_Sonstiges:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:Hh:REITTIER_erfassen:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1:a550:h:TABU_nachgehen:rHD_rBZ_rZO
# =================================================================
# 1:a550:H:Um_einen_Auftrag_werben:rHD_rHH_x
# -----------------------------------------------------------------
# 1 : a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD
# -----------------------------------------------------------------
# 1:a550:F:Schicksalsbestimmender_Weisung_folgen:rHD
# =================================================================
# 1:a550:h:Zweikampf:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1 : a550:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1:a550:F:Krisenursachen_ergründen:rHD_rZO
# =================================================================
# 2:Anf-a550:f:REITTIER_besorgen:rHD_rHH_fHD
# -----------------------------------------------------------------
# 2 : a550:f:REITTIER_besorgen:rHD_rHH_fHD
# -----------------------------------------------------------------
# 2:a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD
# =================================================================
# 1:a550:F:Wache_halten:rHH
# -----------------------------------------------------------------
# 1 : a550:h:Wache_halten:fHD
# -----------------------------------------------------------------
# 1:a550:h:Sandwich:fHD
# =================================================================
# 1:a550:f:KONTAKT_abbrechen:fHD_x
# -----------------------------------------------------------------
# 1 : a550:H:Um_einen_Auftrag_werben:rHD_rHH_x
# -----------------------------------------------------------------
# 1:a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD
# =================================================================
# 1:a550:h:MISSETAT_wie_Behinderung:rHD_fHD_fPP
# -----------------------------------------------------------------
# 1 : a550:h:MISSETAT_wie_Aneignung:rHD_fHD_fPP
# -----------------------------------------------------------------
# 1:a550:h:SCHWEIGEPFLICHT_verhängen:rHD_fHD_fPP
# =================================================================
# 1:a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_x
# 1:a554:F:Einen_Begleiter_gewinnen:rHD_rHF
# -----------------------------------------------------------------
# 2 : a550:H:Ortswechsel_durchführen:rHD_rHF
# -----------------------------------------------------------------
# 1:a550:HF:Die_SCHÖNE_erfassen:rHD_rHF
# 1:a550:HF:VOGEL_erfassen:rHD_rHF
# =================================================================
# 1:a550:h:TABU_nachgehen:rHD_rBZ_rZO_x
# -----------------------------------------------------------------
# 1 : a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO_x
# -----------------------------------------------------------------
# 1:a550:f:Die_SCHÖNE_herbeiholen:rHD_rBZ
# =================================================================
# 1:a550:HF:REITTIER_erfassen:rHD_rHF
# 1:a550:HF:VOGEL_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 2 : a550:f:TABU_Sonstiges:rHD_rHF
# -----------------------------------------------------------------
# 1:a550:Hh:REITTIER_erfassen:rHD_rBZ_rZO
# 1:a550:H:VOGEL_erfassen:rHD_rBZ_rZO
# =================================================================
# 1:a550:HF:REITTIER_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a550:f:TABU_Sonstiges:rHD_rHF_x
# -----------------------------------------------------------------
# 1:a550:F:REITTIER_erfassen:rHD_rBZ_rZO
# =================================================================
# 1:a550:F:PARALYSIERUNG_beheben:rHD_rZO
# -----------------------------------------------------------------
# 1 : a550:F:ZWANGSEHE_Drohung_beheben:rHD_fHD
# -----------------------------------------------------------------
# 1:a550:F:Bestrafung_erfolgt:rHD_fHD
# =================================================================
# 1:a519:H:Eine_BEHINDERUNG_beheben:rHD_rHF_rAN_x
# -----------------------------------------------------------------
# 1 : a550:H:Auf_dem_Heimweg:rHD_rHF_fPP
# -----------------------------------------------------------------
# 1:a550:F:ZWANGSEHE_Drohung_beheben:rHD_rVB
# =================================================================
# 2:a550:F:PARALYSIERUNG_beheben:rZO_rZO
# 1:a550:F:PARALYSIERUNG_beheben:rHD_rBZ_rZO
# 1:a550:F:ZWANGSEHE_Drohung_beheben:rHD_fHD
# -----------------------------------------------------------------
# 4 : a550:F:Bestrafung_erfolgt:rHD_fHD
# -----------------------------------------------------------------
# 2:a550:F:Heiraten:rHD_rZO
# 1:a550:F:Heiraten:N
# 1:a550:F:Heiraten:rHD_rPP
# =================================================================
# 1:a550:h:TABU_nachgehen:rHD_rZO
# -----------------------------------------------------------------
# 1 : a550:h:KONTAKT_abbrechen:rHD_rZO
# -----------------------------------------------------------------
# 1:a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# =================================================================
# 1:a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# -----------------------------------------------------------------
# 1 : a550:F:PARALYSIERUNG_beheben:rHD_rZO
# -----------------------------------------------------------------
# 1:a550:F:ZWANGSEHE_Drohung_beheben:rHD_fHD
# =================================================================
# 3:a550:F:REITTIER_besorgen:rHD_rHH_fHD
# 2:a550:f:REITTIER_besorgen:rHD_rHH_fHD
# 1:a554:F:Sorge_um_Hungernde_oder_Durstige:rHD_rHF
# 1:a550:F:REITTIER_besorgen:rHH
# -----------------------------------------------------------------
# 7 : a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD
# -----------------------------------------------------------------
# 7:a550:h:Den_ALTERNATIVEN_nachgehen:rHD_fHD
# =================================================================
# 1:a531:F:Mitleidsgefühl_auslösen:rHD_rHF_x
# -----------------------------------------------------------------
# 1 : a531:H:Komplikationsfreier_Flug:rHD_rHF
# -----------------------------------------------------------------
# 1:a531:HF:SELTENEN_Gegenstand_erfassen:rHD_rHF
# =================================================================
# 1:a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH
# 1:a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST
# -----------------------------------------------------------------
# 2 : a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rAN
# -----------------------------------------------------------------
# 1:a531:H:Auf_Hilfsquelle_zurückgreifen:N
# 1:a531:H:TIERKÖRPERTEIL_erfassen:rHD
# =================================================================
# 1:a551:F:REITTIER_erhalten:rHD_rHF
# -----------------------------------------------------------------
# 1 : a531:Hh:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rHF_rZM
# -----------------------------------------------------------------
# 1:a531:f:NEUGIER_auslösen:rZM_fVB
# =================================================================
# 1:a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH_x
# -----------------------------------------------------------------
# 1 : a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH_x
# -----------------------------------------------------------------
# 1:a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH_x
# =================================================================
# 1:a531:Hh:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rHF_rZM
# -----------------------------------------------------------------
# 1 : a531:f:NEUGIER_auslösen:rZM_fVB
# -----------------------------------------------------------------
# 1:a531:f:Zu_Beauftragungen_anregen:rAN_fVB
# =================================================================
# 1:a531:HF:Die_SCHÖNE_erfassen:rHD_rZO
# 1:a531:H:Heiratszusage_erpressen:rHD_rZO
# 1:a302:H:EXTERNEN_SEELE_vernichten:rHD_fZM
# ...
# 3 : a531:f:Zu_Beauftragungen_anregen:rVB_rAN_x
# -----------------------------------------------------------------
# 1:a531:f:VOGEL_herbeiholen:rHD_rVB_rAN
# 1:a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN
# 1:a531:f:Mehrere_Aufgaben_in_Folge_erledigen:N
# =================================================================
# 1:a531:HF:Die_SCHÖNE_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a531:H:Die_SCHÖNE_erfassen:rHD_rHF_rBZ
# -----------------------------------------------------------------
# 1:a531:f:Abtretung_der_Schönen_stehet_bevor:rHD_rBZ
# =================================================================
# 1:a554:HF:Zuschnappendes_Hindernis_überwinden:rHD_rHF_rZO
# -----------------------------------------------------------------
# 1 : a531:H:HEILMITTEL_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1:a531:Hh:HEILMITTEL_besorgen:rHD_rAN
# =================================================================
# 1:a531:unklar:#:rHH_fHH
# -----------------------------------------------------------------
# 1 : a531:h:AUSSETZUNG:fHH
# -----------------------------------------------------------------
# 1:a531:F:Überrascht_werden:rHD_rHH
# =================================================================
# 1:a550:H:REITTIER_erfassen:rHD_rZO
# -----------------------------------------------------------------
# 1 : a531:Hh:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM_rZO
# -----------------------------------------------------------------
# 1:a531:f:NEUGIER_auslösen:rHD_rAN
# =================================================================
# 1:a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH_x
# -----------------------------------------------------------------
# 1 : a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH
# -----------------------------------------------------------------
# 1:a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rAN
# =================================================================
# 1:a531:F:JUWELEN_besorgen:rHD_rZO_rAN
# 1:a531:Hh:HEILMITTEL_besorgen:rHD_rAN
# 1:a531:f:#:rAN_fVB
# 1:a531:H:JUWELEN_erfassen:rHD_rHF_rZO
# 1:a531:f:Zu_Beauftragungen_anregen:rAN_fVB
# 1:a531:H:FEHLENDEN_Gegenstand_erfassen:rHD_rHF_rZO
# 1:a531:H:TIERKÖRPERTEIL_erfassen:rHD_rHF_x
# 1:a531:F:TIERKÖRPERTEIL_besorgen:rHD_rAN
# 1:a531:f:PFLANZE_besorgen:rHD_rZO_rAN
# -----------------------------------------------------------------
# 9 : a531:f:Zu_Beauftragungen_anregen:rAN_fVB_x
# -----------------------------------------------------------------
# 1:a531:f:HEILMITTEL_besorgen:rHD_rAN
# 3:a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN
# 1:a531:f:JUWELEN_besorgen:rHD_rZO_rAN
# 1:a531:f:FEHLENDEN_Gegenstand_besorgen:rHD_rAN
# 1:a531:f:Die_SCHÖNE_herbeiholen:rHD_rVB
# 1:a531:f:PFLANZE_besorgen:rHD_rAN
# 1:a531:f:BESITZER_DES_OBJEKTES_herbeiholen:rHD_rAN
# =================================================================
# 1:a531:H:Zweikampf:rHD_rHF_rAN
# -----------------------------------------------------------------
# 1 : a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_rAN_x
# -----------------------------------------------------------------
# 1:a531:F:Die_SCHÖNE_erfassen:rHD_rBZ
# =================================================================
# 1:a531:f:Zu_Beauftragungen_anregen:rAN_fVB_x
# -----------------------------------------------------------------
# 1 : a531:f:BESITZER_DES_OBJEKTES_herbeiholen:rHD_rAN
# -----------------------------------------------------------------
# 1:a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST_x
# =================================================================
# 1:a531:f:Zu_Beauftragungen_anregen:rVB_rAN
# -----------------------------------------------------------------
# 1 : a531:f:Mehrere_Aufgaben_in_Folge_erledigen:rHD_rVB
# -----------------------------------------------------------------
# 1:a531:H:Mitleidsgefühl_auslösen:rHD_rHF
# =================================================================
# 1:a531:H:Auf_Hilfsquelle_zurückgreifen:N
# -----------------------------------------------------------------
# 1 : a531:HF:VOGEL_erfassen:N
# -----------------------------------------------------------------
# 1:a531:H:VOGEL_erfassen:rHD_rZO_rAN
# =================================================================
# 1:a554:H:JUWELEN_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a531:F:JUWELEN_besorgen:rHD_rZO_rAN
# -----------------------------------------------------------------
# 1:a531:f:Zu_Beauftragungen_anregen:rAN_fVB_x
# =================================================================
# 1:a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rBZ_fHH
# -----------------------------------------------------------------
# 1 : a531:F:Bestrafung_erfolgt:rBZ_rAN
# -----------------------------------------------------------------
# 1:a707:F:MISSETAT_beheben:rBZ
# =================================================================
# 1:a531:HF:Sich_einem_magischen_Eingriff_unterziehen:rHD_rBZ
# -----------------------------------------------------------------
# 1 : a531:Hh:Die_SCHÖNE_herbeiholen:rHD_rBZ_rAN
# -----------------------------------------------------------------
# 1:a531:H:MILCH_besorgen:rHD_rHF_rZO
# =================================================================
# 1:a531:HF:SELTENEN_Gegenstand_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a531:F:SELTENEN_Gegenstand_erfassen:rHD_rZO
# -----------------------------------------------------------------
# 1:a531:H:SELTENEN_Gegenstand_besorgen:rVB_rAN
# =================================================================
# 1:a531:H:Mitleidsgefühl_auslösen:rHD_rHF_x
# -----------------------------------------------------------------
# 1 : a531:H:Hilfeversprechen_erhalten:rHD_rHF_x
# -----------------------------------------------------------------
# 1:a531:H:TIERKÖRPERTEIL_erfassen:rHD_rHF_x
# =================================================================
# 1:a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# -----------------------------------------------------------------
# 1 : a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# -----------------------------------------------------------------
# 1:a531:HF:REITTIER_erfassen:rHD_rHF
# =================================================================
# 1:a531:f:TABU_Tier_nicht_töten:rHD_rHH
# -----------------------------------------------------------------
# 1 : a531:h:TABU_nachgehen:rHD_rZM
# -----------------------------------------------------------------
# 1:a531:Ff:VOGEL_herbeiholen:rHD_rZM
# =================================================================
# 1:a531:f:NEUGIER_auslösen:rHD_rVB
# -----------------------------------------------------------------
# 1 : a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH
# -----------------------------------------------------------------
# 1:a531:f:TABU_Tier_nicht_töten:rHD_rHH_x
# =================================================================
# 1:a531:f:Zu_Beauftragungen_anregen:rAN_fVB_x
# -----------------------------------------------------------------
# 1 : a531:f:HEILMITTEL_besorgen:rHD_rAN
# -----------------------------------------------------------------
# 1:a554:F:Sorge_um_Schutzbedürftige:rHD_rHF_rZO
# =================================================================
# 1:a513A:F:VERTRAG_auflösen:rHF_rBZ
# -----------------------------------------------------------------
# 1 : a531:F:Auf_dem_Heimweg:rHD_rAN
# -----------------------------------------------------------------
# 1:a725:F:Ende:rHD_rHH
# =================================================================
# 1:a531:F:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# -----------------------------------------------------------------
# 1 : a531:F:Mitleidsgefühl_auslösen:rHD_rHF_x
# -----------------------------------------------------------------
# 1:a531:H:Komplikationsfreier_Flug:rHD_rHF
# =================================================================
# 1:a531:f:Abtretung_der_Schönen_stehet_bevor:rHD_rZO
# -----------------------------------------------------------------
# 1 : a531:Ff:Die_SCHÖNE_herbeiholen:rHD_rZO_rAN
# -----------------------------------------------------------------
# 1:a531:F:Tapferkeit_beweisen:rZO
# =================================================================
# 1:a531:Ff:VOGEL_herbeiholen:rHD_rZM
# 1:a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM
# -----------------------------------------------------------------
# 2 : a531:f:NEUGIER_auslösen:rHD_rVB
# -----------------------------------------------------------------
# 1:a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH
# 1:a531:h:Vermittlung_erhalten:rHD_rVB_rAN
# =================================================================
# 1:a531:H:Dem_STAUNEN_nachgehen:rHD_rST
# -----------------------------------------------------------------
# 1 : a531:H:Hilfeversprechen_erhalten:rHD_rST
# -----------------------------------------------------------------
# 1:a513A:F:Dem_STAUNEN_nachgehen:rHD_rHF
# =================================================================
# 1:a531:f:Sich_einem_magischen_Eingriff_unterziehen:rBZ_rAN
# -----------------------------------------------------------------
# 1 : a531:F:Heiraten:rHD_rBZ
# -----------------------------------------------------------------
# 1:a551:F:HEILMITTEL_besorgen:rHD_fHH
# =================================================================
# 1:a531:h:TABU_nachgehen:rHD_rHH
# 1:a531:H:Adoption_erfolgt:rHD_rST
# 1:a531:h:TABU_nachgehen:rHD
# -----------------------------------------------------------------
# 3 : a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM
# -----------------------------------------------------------------
# 1:a531:f:NEUGIER_auslösen:rHD_rVB
# 1:a531:f:NEUGIER_auslösen:rHD_rAN
# 1:a531:f:NEUGIER_auslösen:N
# =================================================================
# 1:a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rZO
# -----------------------------------------------------------------
# 1 : a531:HF:Die_SCHÖNE_erfassen:rHD_rZO
# -----------------------------------------------------------------
# 1:a531:H:Die_SCHÖNE_erfassen:rHD_rZO
# =================================================================
# 1:a531:H:Hilfeversprechen_erhalten:rHD_rHF_rZO
# -----------------------------------------------------------------
# 1 : a531:H:FEHLENDEN_Gegenstand_erfassen:rHD_rHF_rZO
# -----------------------------------------------------------------
# 1:a531:f:Zu_Beauftragungen_anregen:rAN_fVB_x
# =================================================================
# 1:a531:f:PFLANZE_besorgen:rHD_rAN
# 1:a531:f:BESITZER_DES_OBJEKTES_herbeiholen:rHD_rAN
# -----------------------------------------------------------------
# 2 : a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST_x
# -----------------------------------------------------------------
# 2:a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST_x
# =================================================================
# 1:a531:f:Zu_Beauftragungen_anregen:rAN_fVB
# -----------------------------------------------------------------
# 1 : a531:F:Vermittlung_erhalten:rAN_fVB
# -----------------------------------------------------------------
# 1:a531:f:#:rAN_fVB
# =================================================================
# 1:a531:H:Erträumen:rHD
# -----------------------------------------------------------------
# 1 : a531:HF:TIERKÖRPERTEIL_erfassen:rHD
# -----------------------------------------------------------------
# 1:a531:F:TIERKÖRPERTEIL_besorgen:rHD_rAN
# =================================================================
# 1:a551:H:BESITZER_DES_OBJEKTES_erfassen:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1 : a531:H:HEILMITTEL_besorgen:rHD_rHH_rBZ
# -----------------------------------------------------------------
# 1:a531:H:KRANKHEIT_beheben:rHD_rHH_rBZ
# =================================================================
# 1:a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST_x
# -----------------------------------------------------------------
# 1 : a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rAN_x
# -----------------------------------------------------------------
# 1:a531:F:BESITZER_DES_OBJEKTES_erfassen:rHD_rZO
# =================================================================
# 1:a531:f:KONTAKT_abbrechen:rHH_rHH
# -----------------------------------------------------------------
# 1 : a531:F:Mehrlingsgeburt_erfolgt:rHH_fHH
# -----------------------------------------------------------------
# 1:a531:unklar:#:rHH_fHH
# =================================================================
# 1:a531:Ff:Die_SCHÖNE_herbeiholen:rHD_rZO_rAN
# -----------------------------------------------------------------
# 1 : a531:F:Tapferkeit_beweisen:rZO
# -----------------------------------------------------------------
# 1:a531:h:Tapferkeit_beweisen:rAN
# =================================================================
# 1:Anf-a531:F:Wunderbare_EMPFÄNGNIS:rHH
# -----------------------------------------------------------------
# 1 : a531:F:Wunderbare_EMPFÄNGNIS:rHH
# -----------------------------------------------------------------
# 1:a531:f:KONTAKT_abbrechen:rHH_rHH
# =================================================================
# 1:a513A:F:Auf_dem_Heimweg:N
# -----------------------------------------------------------------
# 1 : a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rHD_rAN
# -----------------------------------------------------------------
# 1:a531:F:#:rHD_rAN
# =================================================================
# 3:a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rZO_rAN
# -----------------------------------------------------------------
# 3 : a531:F:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# -----------------------------------------------------------------
# 2:a531:f:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# 1:a531:F:Mitleidsgefühl_auslösen:rHD_rHF_x
# =================================================================
# 1:a707:H:MISSETAT_beheben:N
# -----------------------------------------------------------------
# 1 : a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rBZ_fHH
# -----------------------------------------------------------------
# 1:a531:F:Bestrafung_erfolgt:rBZ_rAN
# =================================================================
# 1:a531:F:Tapferkeit_beweisen:rZO
# -----------------------------------------------------------------
# 1 : a531:h:Tapferkeit_beweisen:rAN
# -----------------------------------------------------------------
# 1:a531:H:Tapferkeit_beweisen:rHD
# =================================================================
# 1:a531:f:Kälte_entkommen:rHD_rVB_rBZ
# -----------------------------------------------------------------
# 1 : a531:F:Kälte_entkommen:rHD_rHF
# -----------------------------------------------------------------
# 1:a531:F:VERTRAG_auflösen:rVB_rBZ
# =================================================================
# 2:a531:F:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# 1:a531:H:VERTRAG_auflösen:rVB_rAN
# -----------------------------------------------------------------
# 3 : a531:f:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# -----------------------------------------------------------------
# 2:a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# 1:a531:F:Sich_einem_magischen_Eingriff_unterziehen:rHD_rZO
# =================================================================
# 1:a531:H:Adoption_erfolgt:rHD_rHH
# -----------------------------------------------------------------
# 1 : a531:Hh:VERSPRECHEN_im_Austausch_für_Hilfe:rHH_rAN
# -----------------------------------------------------------------
# 1:a531:F:Ein_VERSPRECHEN_halten:rHD_rHH_fHD
# =================================================================
# 2:a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# -----------------------------------------------------------------
# 2 : a531:HF:Die_SCHÖNE_erfassen:rHD_rHF
# -----------------------------------------------------------------
# 1:a531:H:Die_SCHÖNE_erfassen:rHD_rHF_rBZ
# 1:a531:H:Die_SCHÖNE_erfassen:rHD_rBZ
# =================================================================
# 1:a531:H:Heiraten:rHD_rBZ
# -----------------------------------------------------------------
# 1 : a531:HF:Richtiges_erlangen:rHD_rBZ_rZO
# -----------------------------------------------------------------
# 1:a531:F:Universellen_ZAUBERMITTEL_erhalten:rHD_rBZ_rZO
# =================================================================

# %%
import matplotlib.pyplot as plt  #64 Importieren der matplotlib.pyplot-Bibliothek zur Visualisierung von Daten.
import networkx as nx  #65 Importieren der networkx-Bibliothek zur Erstellung und Analyse von Netzwerken.
#66 Eine Funktion zum Filtern von Daten für einen bestimmten Ast.
def cutoff_ast_data(wuerzel, graph, nachbar_liste, cutoff=0):
    vor = graph[wuerzel][0]  #67 Vorwärtsverbindungen des Astes.
    zurueck = graph[wuerzel][1]  #68 Rückwärtsverbindungen des Astes.
    nachbarn = vor.copy()  #69 Kopie der Vorwärtsverbindungen.
    nachbarn.update(zurueck)  #70 Hinzufügen der Rückwärtsverbindungen.
    for ast_name, ast_gewicht in sorted(nachbarn.items()):  #71 Iteration durch die Nachbarn des Astes.
        if (ast_gewicht >= cutoff):  #72 Wenn das Gewicht größer oder gleich dem Cutoff-Wert ist.
            nachbar_liste.append([ep_name_format(wuerzel),
                                   ep_name_format(ast_name), ast_gewicht])  #73 Die Verbindung wird der Nachbarliste hinzugefügt.
#74 Eine Funktion zum Filtern von Daten für den gesamten Graphen.
def cutoff_graph_data(graph, cutoff=0):
    nachbar_liste = []  #75 Eine leere Liste zur Speicherung der Nachbarn.
    for i, (k, v) in enumerate(sorted(graph.items())):  #76 Iteration durch die Elemente des Graphen.
        cutoff_ast_data(k, graph, nachbar_liste, cutoff)  #77 Filtern der Daten für jeden Ast.
    neue_nachbar_liste = [[i, nachbar] for i, nachbar in enumerate(nachbar_liste)]  #78 Indexierung der Nachbarn.
    return neue_nachbar_liste  #79 Rückgabe der gefilterten Nachbardaten.
#80 Eine Funktion zur Aktualisierung der interaktiven Daten des Graphen.
def interactive_graph_data(graph_data, loesch_index, gew_dict):
    for k, v in gew_dict.items():  #81 Iteration durch die Gewichts-Daten.
        graph_data[k][1][2] = v  #82 Aktualisieren der Gewichts-Daten.
    neue_nachbar_liste = [[i, nachbar[1]] for i,
                          nachbar in enumerate(graph_data) if i not in loesch_index]  #83 Filtern der Daten.
    return neue_nachbar_liste  #84 Rückgabe der aktualisierten Daten.

#85 Eine Funktion zum Aufbau des Graphen aus den Daten.
def graph_bauer(graph_data):
    G = nx.DiGraph()  #86 Initialisierung eines gerichteten Graphen.
    w_liste = []  #87 Eine leere Liste zur Speicherung der Gewichts-Daten.
    for el in graph_data:  #88 Iteration durch die Elemente der Graphendaten.
        n1 = el[1][0]  #89 Der Ausgangsknoten der Verbindung.
        n2 = el[1][1]  #90 Der Zielknoten der Verbindung.
        w = el[1][2]  #91 Das Gewicht der Verbindung.
        w_liste.append(w)  #92 Hinzufügen des Gewichts zur Liste.
        #93 Hinzufügen der Verbindung und der Knoten zum Graphen.
        G.add_edge(n1, n2, weight=w, title=w)
        #G.add_edge(n1, n2, weight=w, title=w)
        G.add_node(n1, title=n1, size=15)
        G.add_node(n2, title=n2, size=15)
    return G, w_liste  #94 Rückgabe des Graphen und der Gewichtsliste.

# %%
#95 Filtern der Graphendaten basierend auf der Häufigkeit.
auto_graph = cutoff_graph_data(graph, haeufigkeit)

# %%
from pyvis.network import Network 
#96 Erstellen des Graphen und der Gewichtsliste aus den Graphendaten.
G, W = graph_bauer(auto_graph)
#97 Erstellen einer Network-Instanz für die Visualisierung des Graphen.
nt = Network(notebook=True,  #98 Das Netzwerk wird im Jupyter Notebook angezeigt.
             height='900px',  #99 Höhe des Netzwerks.
             width='100%',  #100 Breite des Netzwerks.
             directed=False,  #101 Der Graph ist ungerichtet.
             bgcolor='#ffffff',  #102 Hintergrundfarbe des Netzwerks.
             font_color=False,  #103 Die Farbe der Schrift im Netzwerk wird automatisch festgelegt.
             layout=None,  #104 Die Layout-Eigenschaft wird nicht gesetzt (standardmäßig wird ein Fruchterman-Reingold-Layout verwendet).
             heading='',  #105 Ein leerer Titel für das Netzwerk.
             cdn_resources='local')  #106 Die Ressourcen werden lokal geladen (ohne Internetverbindung).
#107 Fügen Sie die Knoten und Kanten des Graphen zur Netzwerkinstanz hinzu.
nt.from_nx(G)
#108 Anzeigen des Netzwerks im Jupyter Notebook.
#nt.show('nx.html')  #109 Die Visualisierung wird in einer HTML-Datei gespeichert und im Notebook angezeigt.
# Out:
# Warning: When  cdn_resources is 'local' jupyter notebook has issues displaying graphics on chrome/safari. Use cdn_resources='in_line' or cdn_resources='remote' if you have issues viewing graphics in a notebook.

# %%
import csv  
import numpy as np 
#110 Eine Funktion zur Überprüfung, ob ein Nachbar in einen Knoten einbezogen werden kann.
def neighbour_is_includable(node, neighbour):
    designation = ":".join(node.split(":")[0:1])  #111 Extrahieren der Bezeichnung des Knotens.
    return neighbour.startswith(designation)  #112 Rückgabe, ob der Nachbar in den Knoten einbezogen werden kann.
#113 Eine Funktion zur Bereinigung der Kanten basierend auf der Einbeziehbarkeit.
def pruned_edges(node, neighbours):
    return [neighbor for neighbor in neighbours if neighbour_is_includable(node, neighbor)]
#114 Eine Funktion zur Erstellung eines bereinigten Graphen.
def make_pruned_graph(graph):
    pruned_graph = {}
    for node, (incoming, outgoing) in graph.items():
        pruned_incoming = pruned_edges(node, incoming)
        pruned_outgoing = pruned_edges(node, outgoing)
        pruned_graph[node] = (pruned_incoming, pruned_outgoing)
    return pruned_graph
#115 Eine Funktion zur Erstellung eines gerichteten Rückgrat-Graphen.
def make_backbone_di_graph(pruned_graph):
    new_DiGraph = nx.DiGraph()
    for node, (incoming, outgoing) in pruned_graph.items():
        for in_node in incoming:
            new_DiGraph.add_edge(in_node, node)
        for out_node in outgoing:
            new_DiGraph.add_edge(node, out_node)
    return new_DiGraph
#116 Eine Funktion zur Berechnung der kürzesten Pfade mit Vorzeichen.
def signed_shortest_path_length(G, source, target):
    try:
        pl = nx.dijkstra_path_length(G, source=source, target=target)
    except nx.NodeNotFound:
        pl = np.Inf
    except nx.NetworkXNoPath:
        try:
            pl = - nx.dijkstra_path_length(G, source=target, target=source)
        except nx.NodeNotFound:
            pl = np.Inf
        except nx.NetworkXNoPath:
            pl = np.Inf
    return pl
#     try:
#         pl = nx.dijkstra_path_length(G, source=source, target=target)
#     except nx.NetworkXNoPath:
#         try:
#             pl = - nx.dijkstra_path_length(G, source=target, target=source)
#         except nx.NetworkXNoPath:
#             pl = np.Inf     
#     return pl

#117 Eine Funktion zur Erstellung von Distanzdaten für Hauptknoten.
def create_main_node_distances(start_node, pruned_graph, graph, nx_graph):
    distances = { key:[] for key in graph}
    backbone_di_graph= make_backbone_di_graph(pruned_graph)
    for node in pruned_graph:
        distances[node] = {signed_shortest_path_length(backbone_di_graph, start_node, node)}
    return distances
#118 Eine Funktion zum Hinzufügen von Distanzdaten für Unter- bzw. Nebenknoten.
def add_sub_node_distances(node, sub_nodes, pruned_graph, distances, d):
    for sub_node in sub_nodes:
        if sub_node not in pruned_graph.keys():
            if sub_node not in distances:
                distances[sub_node] = set()
            new_dists = {dist + d for dist in distances[node]}
            distances[sub_node].update(new_dists)
#119 Eine Funktion zur Erstellung eines Distanz-Dictionarys.
def create_distance_dict(start_node, graph, G):
    pruned_graph = make_pruned_graph(graph)
    distances = create_main_node_distances(start_node, pruned_graph, graph, G)
    for node, (incoming, outgoing) in graph.items():
        add_sub_node_distances(node, incoming, pruned_graph, distances, -1)
        add_sub_node_distances(node, outgoing, pruned_graph, distances, 1)
    return distances
#120 Startknoten für die Berechnung der Distanzen.
start_node = mWert
#121 Erstellen der Distanzdaten.
distances = create_distance_dict(start_node, graph, G)
#122 Sortieren der Distanzdaten nach den minimalen Distanzen.
sorted_keys = sorted(distances, key=lambda x: min(distances[x]))
sorted_distances = {key: distances[key] for key in sorted_keys}
#123 Konvertierung der Distanzdaten in eine Zeichenfolge für den HTML-Output.
msia=""
tai = []
for k, v in sorted_distances.items():
    sia=(f"{k} {v}")
    msia+=sia+'<br>'
    tai.append(sia)
    print(sia)
# Out:
# Anf-a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH {-1}
# a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH {0}
# a550:F:Wache_halten:rHD_rHH_fHD {1}
# a550:F:Wache_halten:fHD {1}
# a550:f:Wache_halten:fHD {2}
# a550:F:Wache_halten:fHD_x {3}
# a550:f:Wache_halten:fHD_x {4}
# a550:F:Wache_halten:rHD_rZM {5}
# a550:H:Um_einen_Auftrag_werben:rHD_rHH {5}
# a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM {6}
# a550:f:NEUGIER_auslösen:rHD_fHD {7}
# a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rHH_fHD {7}
# a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rHH {7}
# a550:H:Um_einen_Auftrag_werben:rHH_fHD {8}
# a554:F:Sorge_um_Hungernde_oder_Durstige:rHD_rHF {8, inf}
# a554:F:Sorge_um_Hungernde_oder_Durstige:rHD_rST {8}
# a550:f:KONTAKT_abbrechen:fHD {9}
# a550:H:Um_einen_Auftrag_werben:rHH_fHD_x {10}
# a550:f:KONTAKT_abbrechen:fHD_x {11}
# a550:H:Um_einen_Auftrag_werben:rHD_rHH_x {12}
# a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD {13}
# a550:F:Schicksalsbestimmender_Weisung_folgen:rHD {14}
# a554:F:Den_Einbrecher_begnadigen:rHD_rHF {15}
# a550:h:FREIHEITSBERAUBUNG:rHD_rBZ {inf}
# a550:F:PARALYSIERUNG_beheben:rHD_rBZ_rZO {inf}
# a550:F:VOGEL_herbeiholen:fHD_x {inf}
# a550:HF:Die_SCHÖNE_erfassen:rHD_rHF {inf}
# a550:HF:VOGEL_erfassen:rHD_rHF {inf}
# a550:H:Handlungsanweisungen_aus_zweiter_Hand:rST_rVB {inf}
# a550:f:VOGEL_herbeiholen:fHD_x {inf}
# a550:h:MISSETAT_wie_Behinderung:rHD_fHD_fPP {inf}
# a550:HF:REITTIER_erfassen:rST_rVB {inf}
# a550:HF:REITTIER_besorgen:rHD_rST {inf}
# a550:F:REITTIER_erfassen:rHD_rBZ_rZO {inf}
# a550:f:REITTIER_besorgen:rHD_rBZ {inf}
# a550:H:Gutes_Benehmen:rHD_rST {inf}
# a550:F:ZWANGSEHE_Drohung_beheben:rHD_rVB {inf}
# a550:h:Zweikampf:rHD_rBZ_rZO {inf}
# a550:f:Held_erkennen:rHD_rZO_fHD {inf}
# a550:F:HOCHZEIT_verschieben:rHH_rZO_fHD {inf}
# a550:F:Held_erkennen:rHD_rZO_fHD {inf}
# a550:F:REITTIER_besorgen:rHH {inf}
# a550:F:REITTIER_besorgen:rHD_rHH_fHD {inf}
# a550:H:Dem_VERLUST_entgegentreten:rHD_rHH_fHD {inf}
# a550:H:NEUGIER_auslösen:rHD_rVB {inf}
# a550:F:Heiraten:rHD_rZO {inf}
# a550:f:TODESAUFTRAG:rBZ_fHF {inf}
# a550:F:REITTIER_besorgen:rHD_rHF_rBZ {inf}
# a550:h:Sandwich:fHD {inf}
# a550:H:Handlungsanweisungen_aus_zweiter_Hand:rHD_rVB {inf}
# a550:H:Zweikampf:rHD_rBZ_rZO {inf}
# a550:F:Krisenursachen_ergründen:rHD_rZO {inf}
# a550:H:Bestrafung_erfolgt:rHD_rHH_fHD {inf}
# a550:F:VOGEL_erfassen:rHD_rZO {inf}
# a550:H:ZWANGSEHE_Drohung_beheben:rHD_fHD {inf}
# a550:Hh:VOGEL_erfassen:rHD_rZO {inf}
# a550:F:Bestrafung_erfolgt:rHD_rBZ_fHD {inf}
# a550:Hh:Wache_halten:rHD_rAN {inf}
# a550:F:Die_SCHÖNE_herbeiholen:rHD_rHF_rBZ {inf}
# a550:h:MISSETAT_wie_Entmachtung:rHD_fHD {inf}
# a550:H:Held_erkennen:rHD_rHH_fHD {inf}
# a550:H:REITTIER_erfassen:rHD_rZO {inf}
# a550:F:VOGEL_herbeiholen:rHD_rHH_fHD {inf}
# a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ_x {inf}
# a550:h:TABU_nachgehen:rHD_rZO {inf}
# a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_x {inf}
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD {inf}
# a550:F:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB {inf}
# a550:h:MISSETAT_planen:fHD {inf}
# a550:H:Sorge_um_Freikaufsbedürftige:rHD_fHD_fPP {inf}
# a550:unklar:#:fHD_fST {inf}
# a550:F:PARALYSIERUNG_beheben:rBZ_rZO {inf}
# a550:F:Heiraten:rHD_rBZ_fHD {inf}
# a550:F:VOGEL_herbeiholen:fHD {inf}
# a550:h:MISSETAT_wie_Behinderung:fHD {inf}
# a550:HF:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rZO {inf}
# a550:h:TABU_nachgehen:rHD_rBZ_rZO_x {inf}
# a550:h:TABU_nachgehen:rHD_rBZ_rZO {inf}
# a550:F:Die_SCHÖNE_erfassen:rHD_rZO {inf}
# a550:f:VOGEL_herbeiholen:fHD {inf}
# a550:F:Wache_halten:rHH {inf}
# a550:F:IDENTITÄT_ändern:rHD_rVB {inf}
# a550:F:HOCHZEIT_verschieben:rHH_rBZ_fHD {inf}
# a550:h:Den_ALTERNATIVEN_nachgehen:rHD_fHD {inf}
# a550:F:PARALYSIERUNG_beheben:rZO_rZO {inf}
# a550:HF:REITTIER_erfassen:rHD_rHF {inf}
# a550:H:VOGEL_erfassen:rHD_rBZ_rZO {inf}
# a550:F:Ortswechsel_durchführen:rHD_rBZ {inf}
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_rVB {inf}
# a550:F:Ortswechsel_durchführen:rHD {inf}
# a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO {inf}
# a550:f:ZWANGSEHE_Drohung_beheben:rHD_fHD {inf}
# a550:F:IDENTITÄT_ändern:rHD_fHD {inf}
# a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF {inf}
# a550:h:KONTAKT_abbrechen:rHD_fHD {inf}
# a550:F:Heiraten:N {inf}
# a550:H:Wegweisung_erpressen:rHD_rAN {inf}
# a550:H:Einer_Einladung_folgen:rHD_rHF {inf}
# a550:f:Heldentat_VORTÄUSCHEN:rHH_rBZ_fHD {inf}
# a550:h:SCHWEIGEPFLICHT_verhängen:rHD_fHD_fPP {inf}
# a550:H:Ortswechsel_durchführen:rHD_rHF_x {inf}
# a550:F:VOGEL_herbeiholen:rHD_rHF_rBZ {inf}
# a550:F:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ {inf}
# a550:f:Abtretung_der_Schönen_stehet_bevor:rHD_rZO {inf}
# a550:f:Die_SCHÖNE_herbeiholen:rHD_rBZ {inf}
# a550:h:MISSETAT_planen:rHD_fHD {inf}
# a550:F:Eine_BEHINDERUNG_beheben:rHD_rHF {inf}
# a550:F:Auf_dem_Heimweg:rHD_rHF_rZO {inf}
# a550:H:Bestrafung_erfolgt:rHD_fHD {inf}
# a550:H:Heiraten:rHD_fPP {inf}
# a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rZO {inf}
# a550:H:Den_Vorgang_deuten:rHD_rHH_fHD {inf}
# a550:f:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD {inf}
# a550:F:REITTIER_erfassen:rHD_rZO {inf}
# a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD {inf}
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD_x {inf}
# a550:F:Heiraten:rHD_rPP {inf}
# a550:H:KONTAKT_wiederherstellen:rHD_fHD_fPP {inf}
# a550:H:Ende:rHD_fPP {inf}
# a550:F:Bestrafung_erfolgt:rHD_rZO_fHD {inf}
# a550:f:KRANKHEIT:rHH_rZO {inf}
# a550:F:REITTIER_erhalten:rHD_rHF {inf}
# a550:f:Die_SCHÖNE_herbeiholen:rHD_rZO {inf}
# a550:h:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH {inf}
# a550:F:Gutes_Benehmen:rHD_rST {inf}
# a550:Hh:REITTIER_erfassen:rHD_rBZ_rZO {inf}
# a550:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rBZ_rZO {inf}
# a550:f:REITTIER_besorgen:rHD_rHH_fHD {inf}
# a550:h:Wache_halten:fHD {inf}
# a550:h:MISSETAT_wie_Aneignung:rHD_fHD_fPP {inf}
# a550:H:Ortswechsel_durchführen:rHD_rHF {inf}
# a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO_x {inf}
# a550:f:TABU_Sonstiges:rHD_rHF {inf}
# a550:f:TABU_Sonstiges:rHD_rHF_x {inf}
# a550:F:ZWANGSEHE_Drohung_beheben:rHD_fHD {inf}
# a550:H:Auf_dem_Heimweg:rHD_rHF_fPP {inf}
# a550:F:Bestrafung_erfolgt:rHD_fHD {inf}
# a550:h:KONTAKT_abbrechen:rHD_rZO {inf}
# a550:F:PARALYSIERUNG_beheben:rHD_rZO {inf}
# a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD {inf}
# a531:H:Komplikationsfreier_Flug:rHD_rHF {inf}
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rAN {inf}
# a531:Hh:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rHF_rZM {inf}
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH_x {inf}
# a531:f:NEUGIER_auslösen:rZM_fVB {inf}
# a531:H:Die_SCHÖNE_erfassen:rHD_rZO {inf}
# a531:F:Dem_STAUNEN_nachgehen:rHD_rST {inf}
# a531:H:Um_einen_Auftrag_werben:rHD_rHH {inf}
# a531:HF:Sich_einem_magischen_Eingriff_unterziehen:rHD_rBZ {inf}
# a531:F:Heiraten:N {inf}
# a531:f:Kälte_entkommen:rHD_rVB_rBZ {inf}
# a531:f:Zu_Beauftragungen_anregen:rVB_rAN {inf}
# a531:HF:Stifter_oder_Helfer_gewinnen:rHD_rHH {inf}
# a531:f:Abtretung_der_Schönen_stehet_bevor:rBZ_rAN {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH_x {inf}
# a531:F:TIERKÖRPERTEIL_besorgen:rHD_rAN {inf}
# a531:H:KRANKHEIT_beheben:rHD_rHH_rBZ {inf}
# a531:H:VOGEL_herbeiholen:rHD_rZO_rAN {inf}
# a531:HF:FEHLENDEN_Gegenstand_erfassen:rHD_rZM_rZO {inf}
# a531:H:Die_SCHÖNE_erfassen:rHD_rBZ {inf}
# a531:f:NEUGIER_auslösen:rHD_rAN {inf}
# a531:F:Bestrafung_erfolgt:rHD_fHH {inf}
# a531:f:PFLANZE_besorgen:rHD_rZO_rAN {inf}
# a531:H:Adoption_erfolgt:rHD_rHH {inf}
# a531:F:Zur_Welt_kommen:rHH_rHH {inf}
# a531:f:Zu_Beauftragungen_anregen:fHD_fHH_x {inf}
# a531:f:Zu_Beauftragungen_anregen:fHD_fHH {inf}
# a531:F:Komplikationsfreier_Flug:rHD_rHF {inf}
# a531:F:Wunderbare_EMPFÄNGNIS:rHH_rHH {inf}
# a531:HF:NUTZTIER_erfassen:rHD_rHF {inf}
# a531:F:Ende:rHD_rZO {inf}
# a531:H:Adoption_erfolgt:rHD_rST {inf}
# a531:H:Heiraten:rHD_rBZ {inf}
# a531:Ff:VOGEL_herbeiholen:rHD_rZM {inf}
# a531:HF:MILCH_erfassen:rHD_rBZ {inf}
# a531:H:REITTIER_erhalten:rHD_rHF {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rZO {inf}
# a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rHF_rZM {inf}
# a531:F:Heiraten:rHD_rZO_rAN {inf}
# a531:HF:JUWELEN_erfassen:rHD_rHF_rZO {inf}
# a531:H:Um_einen_Auftrag_werben:rVB_rAN {inf}
# a531:F:VERTRAG_abschließen:rHD_rHP {inf}
# a531:H:Die_SCHÖNE_erfassen:rHD_rBZ_rZO {inf}
# a531:H:MILCH_besorgen:rHD_rHF_rZO {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_rZO {inf}
# a531:H:JUWELEN_erfassen:rHD_rHF_rZO {inf}
# a531:h:Vermittlung_erhalten:rHD_rVB_rAN {inf}
# a531:f:Sich_einem_magischen_Eingriff_unterziehen:rAN {inf}
# a531:H:TIERKÖRPERTEIL_erfassen:rHD {inf}
# a531:F:Heiraten:rHD_rBZ_rAN {inf}
# a531:f:PFLANZE_besorgen:rHD_rAN {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_rAN {inf}
# a531:H:Heiratszusage_erpressen:rHD_rBZ_rZO {inf}
# a531:f:JUWELEN_besorgen:rHD_rAN {inf}
# a531:h:TABU_nachgehen:rHD_rHH {inf}
# a531:HF:REITTIER_erfassen:rHD_rHF {inf}
# a531:H:TIERKÖRPERTEIL_erfassen:rHD_rHF_x {inf}
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB {inf}
# a531:Hh:HEILMITTEL_besorgen:rHD_rAN {inf}
# a531:f:KONTAKT_abbrechen:rHH_rHH {inf}
# a531:H:Hilfeversprechen_erhalten:rHD_rHF_rZO {inf}
# a531:F:Sich_einem_magischen_Eingriff_unterziehen:rHD_rZO {inf}
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST {inf}
# a531:H:Hilfeversprechen_erhalten:rHD_rHF {inf}
# a531:f:TABU_Land_nicht_betreten:rHD_rHH {inf}
# a531:H:Dem_STAUNEN_nachgehen:rHD_rST {inf}
# a531:F:Sich_einem_magischen_Eingriff_unterziehen:rBZ_rAN {inf}
# a531:f:VOGEL_herbeiholen:rVB_rAN {inf}
# a531:H:FEHLENDEN_Gegenstand_erfassen:rHD_rBZ_rZO {inf}
# a531:Hh:VOGEL_herbeiholen:rHD_rZO_rAN {inf}
# a531:Ff:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rZO {inf}
# a531:f:#:rAN_fVB {inf}
# a531:f:TABU_Haus_nicht_verlassen_dürfen:rHD_rHH {inf}
# a531:F:#:rHD_rAN {inf}
# a531:f:JUWELEN_besorgen:rHD_rZO_rAN {inf}
# a531:H:PFLANZE_erfassen:rHD_rZO {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:N {inf}
# a531:F:Bestrafung_erfolgt:rHD_rZO_rAN {inf}
# a531:F:VERTRAG_auflösen:rVB_rBZ {inf}
# a531:H:VERTRAG_auflösen:rVB_rAN {inf}
# a531:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rZO {inf}
# a531:F:Die_SCHÖNE_erfassen:rHD_rBZ {inf}
# a531:F:Heiraten:rHD_rZO {inf}
# a531:F:Universellen_ZAUBERMITTEL_erhalten:rHD_rBZ_rZO {inf}
# a531:Hh:FEHLENDEN_Gegenstand_erfassen:rHD_rBZ_rZO {inf}
# a531:unklar:#:rHH_fHH {inf}
# a531:F:Ein_VERSPRECHEN_halten:rHD_rHH_fHD {inf}
# a531:H:Zweikampf:rHD_rHF_rAN {inf}
# a531:f:TIERKÖRPERTEIL_besorgen:rHD_rAN {inf}
# a531:F:VERTRAG_auflösen:rHD_rBZ_rAN {inf}
# a531:f:VOGEL_herbeiholen:rHD_rVB_rAN {inf}
# a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN {inf}
# a531:f:NEUGIER_auslösen:rHD_fVB {inf}
# a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN_x {inf}
# a531:f:VERTRAG_abschließen:rHD_rAN {inf}
# a531:F:Überrascht_werden:rHD_rHH {inf}
# a531:f:FEHLENDEN_Gegenstand_besorgen:rHD_rAN {inf}
# a531:F:BESITZER_DES_OBJEKTES_erfassen:rHD_rZO {inf}
# a531:unklar:#:rHD_rZO_rAN {inf}
# a531:H:Sich_einem_magischen_Eingriff_unterziehen:rHD_rBZ_rAN {inf}
# a531:HF:SELTENEN_Gegenstand_erfassen:rHD_rHF {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF {inf}
# a531:H:Um_einen_Auftrag_werben:rVB_rAN_x {inf}
# a531:F:REITTIER_besorgen:rHD_fHH {inf}
# a531:H:Mitleidsgefühl_auslösen:rHD_rHF {inf}
# a531:H:Heiraten:rHD_rHH_rBZ {inf}
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST_x {inf}
# a531:H:Tapferkeit_beweisen:rHD {inf}
# a531:H:Heiratszusage_erpressen:rHD_rZO {inf}
# a531:H:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM {inf}
# a531:HF:FEHLENDEN_Gegenstand_erfassen:rHD_rZO {inf}
# a531:f:Abtretung_der_Schönen_stehet_bevor:rHD_rZO {inf}
# a531:H:NUTZTIER_erfassen:rHD_rZO {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST {inf}
# a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM_rZO {inf}
# a531:h:TABU_nachgehen:rHD {inf}
# a531:f:TABU_Tier_nicht_töten:rHD_rHH_x {inf}
# a531:H:Mitleidsgefühl_auslösen:rHD_rHF_x {inf}
# a531:H:PFÖRTNER_besänftigen:rHD_rZO {inf}
# a531:H:SELTENEN_Gegenstand_besorgen:rVB_rAN {inf}
# a531:f:Mehrere_Aufgaben_in_Folge_erledigen:N {inf}
# a531:H:Erträumen:rHD {inf}
# a531:f:TIERKÖRPERTEIL_besorgen:rHD_fVB {inf}
# a531:f:NEUGIER_auslösen:rZM_rAN {inf}
# a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rBZ_rAN {inf}
# a531:H:REITTIER_besorgen:rHD_rHF {inf}
# a531:f:Sich_einem_magischen_Eingriff_unterziehen:rBZ_rAN {inf}
# a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rZO_rAN {inf}
# a531:f:Abtretung_der_Schönen_stehet_bevor:rHD_rBZ {inf}
# a531:HF:Sich_einem_magischen_Eingriff_unterziehen:rBZ_rAN {inf}
# a531:H:TIERKÖRPERTEIL_erfassen:rHD_rHF {inf}
# a531:F:Mitleidsgefühl_auslösen:rHD_rHF {inf}
# a531:HF:PFÖRTNER_besänftigen:rHD_rHF {inf}
# a531:f:NUTZTIER_besorgen:N {inf}
# a531:f:Die_SCHÖNE_herbeiholen:rHD_rVB {inf}
# a531:f:NEUGIER_auslösen:N {inf}
# a531:HF:Heiratszusage_erpressen:rHD_rZO {inf}
# a531:H:VOGEL_erfassen:rHD_rZO_rAN {inf}
# a531:F:Um_eine_Frau_werben:rHD_rVB_rBZ {inf}
# a531:f:TABU_Tier_nicht_töten:rHD_rHH {inf}
# a531:f:Zu_Beauftragungen_anregen:rVB_rAN_x {inf}
# a531:H:Die_SCHÖNE_erfassen:rHD_rHF_rBZ {inf}
# a531:H:HEILMITTEL_erfassen:rHD_rHF {inf}
# a531:h:AUSSETZUNG:fHH {inf}
# a531:Hh:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM_rZO {inf}
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH {inf}
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB_x {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_rAN_x {inf}
# a531:f:BESITZER_DES_OBJEKTES_herbeiholen:rHD_rAN {inf}
# a531:f:Mehrere_Aufgaben_in_Folge_erledigen:rHD_rVB {inf}
# a531:HF:VOGEL_erfassen:N {inf}
# a531:F:JUWELEN_besorgen:rHD_rZO_rAN {inf}
# a531:F:Bestrafung_erfolgt:rBZ_rAN {inf}
# a531:Hh:Die_SCHÖNE_herbeiholen:rHD_rBZ_rAN {inf}
# a531:F:SELTENEN_Gegenstand_erfassen:rHD_rZO {inf}
# a531:H:Hilfeversprechen_erhalten:rHD_rHF_x {inf}
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF {inf}
# a531:h:TABU_nachgehen:rHD_rZM {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH {inf}
# a531:f:HEILMITTEL_besorgen:rHD_rAN {inf}
# a531:F:Auf_dem_Heimweg:rHD_rAN {inf}
# a531:F:Mitleidsgefühl_auslösen:rHD_rHF_x {inf}
# a531:Ff:Die_SCHÖNE_herbeiholen:rHD_rZO_rAN {inf}
# a531:f:NEUGIER_auslösen:rHD_rVB {inf}
# a531:H:Hilfeversprechen_erhalten:rHD_rST {inf}
# a531:F:Heiraten:rHD_rBZ {inf}
# a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM {inf}
# a531:HF:Die_SCHÖNE_erfassen:rHD_rZO {inf}
# a531:H:FEHLENDEN_Gegenstand_erfassen:rHD_rHF_rZO {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST_x {inf}
# a531:F:Vermittlung_erhalten:rAN_fVB {inf}
# a531:HF:TIERKÖRPERTEIL_erfassen:rHD {inf}
# a531:H:HEILMITTEL_besorgen:rHD_rHH_rBZ {inf}
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rAN_x {inf}
# a531:F:Mehrlingsgeburt_erfolgt:rHH_fHH {inf}
# a531:F:Tapferkeit_beweisen:rZO {inf}
# a531:F:Wunderbare_EMPFÄNGNIS:rHH {inf}
# a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rHD_rAN {inf}
# a531:F:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN {inf}
# a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rBZ_fHH {inf}
# a531:h:Tapferkeit_beweisen:rAN {inf}
# a531:F:Kälte_entkommen:rHD_rHF {inf}
# a531:f:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN {inf}
# a531:Hh:VERSPRECHEN_im_Austausch_für_Hilfe:rHH_rAN {inf}
# a531:HF:Die_SCHÖNE_erfassen:rHD_rHF {inf}
# a531:HF:Richtiges_erlangen:rHD_rBZ_rZO {inf}
# Anf-a550:F:REITTIER_besorgen:rHH {inf}
# Anf-a550:F:REITTIER_besorgen:rHD_rHH_fHD {inf}
# End-a550:F:Heiraten:rHD_rZO {inf}
# End-a550:F:VOGEL_erfassen:rHD_rZO {inf}
# a554:f:TABU_Sonstiges:rHD_rHF {inf}
# a530:H:Ende:N {inf}
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB {inf}
# End-a550:F:Heiraten:rHD_rBZ_fHD {inf}
# a554:H:TREUEN_HELFER_erhalten:rHD_rHF {inf}
# a300:F:Eine_BEHINDERUNG_beheben:rHD_rHF {inf}
# a300A:H:Ortswechsel_durchführen:rHD_fPP {inf}
# End-a550:F:Heiraten:N {inf}
# a519:H:Mit_einer_anderen_behinderten_Person_einen_Bund_schließen:rHD_rHF {inf}
# a530:H:Held_erkennen:rHD_fHD {inf}
# End-a550:H:Bestrafung_erfolgt:rHD_fHD {inf}
# End-a550:F:FEHLENDEN_Gegenstand_besorgen:rHD_rZO {inf}
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rPP {inf}
# End-a550:F:Heiraten:rHD_rPP {inf}
# a300A:H:Zweikampf:rHD_rAN_x {inf}
# End-a550:H:Ende:rHD_fPP {inf}
# End-a550:F:Bestrafung_erfolgt:rHD_rZO_fHD {inf}
# Anf-a550:f:KRANKHEIT:rHH_rZO {inf}
# a554:HF:REITTIER_besorgen:rHD_rST {inf}
# Anf-a550:h:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH {inf}
# Anf-a550:f:REITTIER_besorgen:rHD_rHH_fHD {inf}
# a554:F:Einen_Begleiter_gewinnen:rHD_rHF {inf}
# a519:H:Eine_BEHINDERUNG_beheben:rHD_rHF_rAN_x {inf}
# a551:F:REITTIER_erhalten:rHD_rHF {inf}
# a302:H:EXTERNEN_SEELE_vernichten:rHD_fZM {inf}
# a551:h:HEILMITTEL_besorgen:rHH_fHD_fZO_x {inf}
# a551:h:HEILMITTEL_besorgen:rHH_fHD_x {inf}
# End-a531:F:Heiraten:N {inf}
# a554:F:Sorge_um_Hilfsbedürftige:rHD_rHF {inf}
# a881A:F:MISSETAT_beheben:rHD_rBZ_fHH {inf}
# a471:f:Jenseitswanderung_unternehmen:rHD_fHH {inf}
# Anf-a531:F:Wunderbare_EMPFÄNGNIS:rHH_rHH {inf}
# a471:H:VERTRAG_auflösen:N {inf}
# End-a531:F:Ende:rHD_rZO {inf}
# a327:F:FLUCHT:rHD_rAN {inf}
# End-a531:F:Heiraten:rHD_rZO_rAN {inf}
# Anf-a531:H:Um_einen_Auftrag_werben:rVB_rAN {inf}
# a554:F:#:rHD_rHF {inf}
# a551:h:MISSETAT_planen:rBZ_fHH {inf}
# a554:F:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF_x {inf}
# a554:F:Sorge_um_Schutzbedürftige:rHD_rHF {inf}
# End-a531:F:Sich_einem_magischen_Eingriff_unterziehen:rHD_rZO {inf}
# Anf-a531:f:TABU_Land_nicht_betreten:rHD_rHH {inf}
# End-a531:F:#:rHD_rAN {inf}
# a513A:F:Dem_STAUNEN_nachgehen:rHD_rHF {inf}
# a725:unklar:#:rHD_rHH {inf}
# End-a531:H:Heiraten:rHD_rHH_rBZ {inf}
# a551:H:BESITZER_DES_OBJEKTES_erfassen:rHD_rBZ_rZO {inf}
# Anf-a531:f:TABU_Tier_nicht_töten:rHD_rHH {inf}
# a554:HF:Zuschnappendes_Hindernis_überwinden:rHD_rHF_rZO {inf}
# a554:H:JUWELEN_erfassen:rHD_rHF {inf}
# a707:F:MISSETAT_beheben:rBZ {inf}
# a554:F:Sorge_um_Schutzbedürftige:rHD_rHF_rZO {inf}
# a513A:F:VERTRAG_auflösen:rHF_rBZ {inf}
# a725:F:Ende:rHD_rHH {inf}
# a551:F:HEILMITTEL_besorgen:rHD_fHH {inf}
# Anf-a531:F:Wunderbare_EMPFÄNGNIS:rHH {inf}
# a513A:F:Auf_dem_Heimweg:N {inf}
# a707:H:MISSETAT_beheben:N {inf}

# %%
# import numpy as np
# def neighbour_is_includable(node, neighbour):
#     designation = ":".join(node.split(":")[0:1])
#     return neighbour.startswith(designation)

# def pruned_edges(node, neighbours):
#     return [neighbor for neighbor in neighbours if neighbour_is_includable(node, neighbor)]

# def make_pruned_graph(graph):
#     pruned_graph = {}
#     for node, (incoming, outgoing) in graph.items():
#         pruned_incoming = pruned_edges(node, incoming)
#         pruned_outgoing = pruned_edges(node, outgoing)
#         pruned_graph[node] = (pruned_incoming, pruned_outgoing)
#     return pruned_graph

# def make_backbone_di_graph(pruned_graph):
#     new_DiGraph = nx.DiGraph()
#     for node, (incoming, outgoing) in pruned_graph.items():
#         for in_node in incoming:
#             new_DiGraph.add_edge(in_node, node)
#         for out_node in outgoing:
#             new_DiGraph.add_edge(node, out_node)
#     return new_DiGraph

# def signed_shortest_path_length(G, source, target):
#     try:
#         pl = nx.dijkstra_path_length(G, source=source, target=target)
#     except nx.NetworkXNoPath:
#         try:
#             pl = - nx.dijkstra_path_length(G, source=target, target=source)
#         except nx.NetworkXNoPath:
#             pl = np.Inf
#     return pl

# def create_main_node_distances(start_node, pruned_graph, graph, nx_graph):
#     distances = { key:[] for key in graph}
#     backbone_di_graph= make_backbone_di_graph(pruned_graph)
#     for node in pruned_graph:
#         distances[node] = {signed_shortest_path_length(backbone_di_graph, start_node, node)}
#     return distances

# def add_sub_node_distances(node, sub_nodes, pruned_graph, distances, d):
#     for sub_node in sub_nodes:
#         if sub_node not in pruned_graph.keys():
#             if sub_node not in distances:
#                 distances[sub_node] = set()
#             new_dists = {dist + d for dist in distances[node]}
#             distances[sub_node].update(new_dists)

# def create_distance_dict(start_node, graph, G):
#     pruned_graph = make_pruned_graph(graph)
#     distances = create_main_node_distances(start_node, pruned_graph, graph, G)
#     for node, (incoming, outgoing) in graph.items():
#         add_sub_node_distances(node, incoming, pruned_graph, distances, -1)
#         add_sub_node_distances(node, outgoing, pruned_graph, distances, 1)
#     return distances


# start_node = mWert
# distances = create_distance_dict(start_node, graph, G)
# #print(distances)
# sorted_keys = sorted(distances, key=lambda x: min(distances[x]))
# sorted_distances = {key: distances[key] for key in sorted_keys}
# #print(sorted_distances)
# msia=""
# for k, v in sorted_distances.items():
#     sia=(f"{k} {v}")#.replace(':::::',':').replace(':::',':').replace('_',' ')
#     msia+=sia+'<br>'
#     print(sia)

# %%
#124 Pfad zur CSV-Datei
csv_file_path = 'output_1.csv'
#125 Schreibe die Daten in die CSV-Datei
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')  
    #126 Schreibe die Überschrift (Header) in die CSV-Datei
    writer.writerow([''])
    #127 Schreibe die Zeilen in die CSV-Datei
    for data in tai:
        writer.writerow([data])

# %%
# import csv
# from collections import defaultdict

# # Pfad zur CSV-Datei
# csv_datei = 'output_1.csv'

# # Datenstruktur zum Speichern der Häufigkeit der Kombinationen
# kombinationen = defaultdict(int)

# # Die CSV-Datei lesen und die Häufigkeit der Kombinationen zählen
# with open(csv_datei, mode='r', newline='', encoding='utf-8') as file:
#     reader = csv.DictReader(file)
#     rows = list(reader)

#     for row in rows:
#         kombination = (row['quelle'], row['index_string'])
#         kombinationen[kombination] += 1

# # Die Häufigkeit der Kombinationen erneut initialisieren, um Bearbeitungen durchzuführen
# kombinationen = defaultdict(int)

# # Die CSV-Datei bearbeiten, wobei nur wiederholte Kombinationen ein 'x' erhalten
# for row in rows:
#     kombination = (row['quelle'], row['index_string'])
#     kombinationen[kombination] += 1
#     if kombinationen[kombination] > 1:
#         row['index_string'] += '_x'

# # Die bearbeitete CSV-Datei unter demselben Namen speichern
# with open(csv_datei, mode='w', newline='', encoding='utf-8') as file:
#     writer = csv.DictWriter(file, fieldnames=rows[0].keys())
#     writer.writeheader()
#     writer.writerows(rows)

# print(f"Die Datei {csv_datei} wurde erfolgreich bearbeitet und gespeichert.")

# %%
#128 Diese Funktion erstellt eine Menge aus den ausgewählten Knoten basierend auf den Kanten im Graphen.
def make_set_of_chosen_vertices(graph_edge_data):
    chosen_vertices = set()  #129 Initialisierung einer leeren Menge für ausgewählte Knoten
    for sub_list in graph_edge_data:  #130 Iteration durch die Kanten im Graphen
        sub_sub_list = sub_list[1]  #131 Die Kanteninformationen befinden sich in der zweiten Unterliste
        chosen_vertices.add(sub_sub_list[0])  #132 Hinzufügen des ersten Knotens der Kante zur Menge ausgewählter Knoten
        chosen_vertices.add(sub_sub_list[1])  #133 Hinzufügen des zweiten Knotens der Kante zur Menge ausgewählter Knoten
    return chosen_vertices  #134 Rückgabe der Menge ausgewählter Knoten

dat = []  #135 Initialisierung einer leeren Liste 'dat' für Daten

#136 'graph_data' enthält die Informationen über die Kanten im Graphen, basierend auf einer bestimmten Häufigkeitsschwelle ('haeufigkeit')
graph_data = cutoff_graph_data(graph, haeufigkeit)

#137 Die ausgewählten Knoten werden aus der Menge ausgewählt und sortiert
chosen_vertices = list(make_set_of_chosen_vertices(graph_data))  
#chosen_vertices.sort()  

#138 Iteration durch die ausgewählten Knoten
for vertex_name in chosen_vertices:
    dat.append(vertex_name)  #134 Hinzufügen des Knotennamens zur Liste 'dat'
csv_file_path = 'output_2.csv'
#139 Schreibe die Daten in die CSV-Datei
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')    
    #140 Schreibe die Überschrift (Header) in die CSV-Datei
    writer.writerow([''])
    #141 Schreibe die Zeilen in die CSV-Datei
    for data in dat:
        writer.writerow([data])
        print(data)
# Out:
# a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH_x
# a550:f:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD
# End-a550:F:Heiraten:rHD_rBZ_fHD
# a531:H:Die_SCHÖNE_erfassen:rHD_rZO
# a550:F:PARALYSIERUNG_beheben:rZO_rZO
# a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD
# a550:h:Den_ALTERNATIVEN_nachgehen:rHD_fHD
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD_x
# a531:f:FEHLENDEN_Gegenstand_besorgen:rHD_rAN
# a550:H:Handlungsanweisungen_aus_zweiter_Hand:rHD_rVB
# a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH_x
# a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB_x
# a550:HF:VOGEL_erfassen:rHD_rHF
# a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD
# a550:H:Handlungsanweisungen_aus_zweiter_Hand:rST_rVB
# a531:f:NEUGIER_auslösen:rHD_rAN
# Anf-a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# a550:F:Wache_halten:rHD_rHH_fHD
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a550:F:Bestrafung_erfolgt:rHD_rBZ_fHD
# a550:f:Wache_halten:fHD
# End-a550:F:Heiraten:N
# a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO
# a550:HF:REITTIER_erfassen:rST_rVB
# a550:F:Wache_halten:rHD_rZM
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST_x
# a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# a550:H:REITTIER_erfassen:rHD_rZO
# a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a531:f:Abtretung_der_Schönen_stehet_bevor:rHD_rZO
# a550:F:Heiraten:N
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# a550:F:Wache_halten:fHD_x
# a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM_rZO
# a550:F:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB
# a550:f:REITTIER_besorgen:rHD_rHH_fHD
# a531:F:Bestrafung_erfolgt:rHD_rZO_rAN
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rZO
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST_x
# Anf-a550:F:REITTIER_besorgen:rHD_rHH_fHD
# a531:F:Heiraten:rHD_rZO_rAN
# a550:f:Wache_halten:fHD_x
# a550:h:MISSETAT_planen:rHD_fHD
# End-a531:F:Heiraten:rHD_rZO_rAN
# a550:F:PARALYSIERUNG_beheben:rBZ_rZO
# a550:F:Heiraten:rHD_rBZ_fHD
# a550:F:HOCHZEIT_verschieben:rHH_rZO_fHD
# a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rZO_rAN
# a550:F:REITTIER_besorgen:rHD_rHH_fHD
# Anf-a550:f:REITTIER_besorgen:rHD_rHH_fHD
# a531:F:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# End-a550:F:Heiraten:rHD_rZO
# a550:h:TABU_nachgehen:rHD_rBZ_rZO
# a531:f:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# a550:F:Bestrafung_erfolgt:rHD_fHD
# a550:F:Heiraten:rHD_rZO
# a550:F:Wache_halten:fHD
# a531:HF:Die_SCHÖNE_erfassen:rHD_rHF
# a531:HF:Heiratszusage_erpressen:rHD_rZO

# %%
def make_set_of_chosen_vertices(graph_edge_data):
    chosen_vertices = set()  # Initialisierung einer leeren Menge für ausgewählte Knoten
    for sub_list in graph_edge_data:  # Iteration durch die Kanten im Graphen
        sub_sub_list = sub_list[1]  # Die Kanteninformationen befinden sich in der zweiten Unterliste
        chosen_vertices.add(sub_sub_list[0])  # Hinzufügen des ersten Knotens der Kante zur Menge ausgewählter Knoten
        chosen_vertices.add(sub_sub_list[1])  # Hinzufügen des zweiten Knotens der Kante zur Menge ausgewählter Knoten
    return chosen_vertices  # Rückgabe der Menge ausgewählter Knoten

def find_connected_components(graph_edge_data):
    from collections import defaultdict

    # Ein Dictionary zur Speicherung der Nachbarn eines Knotens
    adjacency_list = defaultdict(set)
    
    for sub_list in graph_edge_data:
        sub_sub_list = sub_list[1]
        node1, node2 = sub_sub_list[0], sub_sub_list[1]
        adjacency_list[node1].add(node2)
        adjacency_list[node2].add(node1)

    visited = set()
    connected_components = []

    def dfs(node, component):
        visited.add(node)
        component.append(node)
        for neighbor in adjacency_list[node]:
            if neighbor not in visited:
                dfs(neighbor, component)

    for vertex in adjacency_list:
        if vertex not in visited:
            component = []
            dfs(vertex, component)
            connected_components.append(component)

    return connected_components

dat = []  # Initialisierung einer leeren Liste 'dat' für Daten

# 'graph_data' enthält die Informationen über die Kanten im Graphen, basierend auf einer bestimmten Häufigkeitsschwelle ('haeufigkeit')
graph_data = cutoff_graph_data(graph, haeufigkeit)

# Finden der verbundenen Komponenten im Graphen
connected_components = find_connected_components(graph_data)

# Iteration durch die verbundenen Komponenten
for component in connected_components:
    component.sort()  # Optional: Sortieren der Knoten innerhalb der Komponente
    for vertex_name in component:
        dat.append(vertex_name)  # Hinzufügen des Knotennamens zur Liste 'dat'
    dat.append("-------")  # Trennen der Komponenten durch "-------"

# Entfernen des letzten "-------", falls es existiert
if dat and dat[-1] == "-------":
    dat.pop()

csv_file_path = 'output_2.csv'

# Schreibe die Daten in die CSV-Datei
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csv_file:
    writer = csv.writer(csv_file, delimiter=',')
    # Schreibe die Zeilen in die CSV-Datei
    for data in dat:
        writer.writerow([data])
        print(data)
# Out:
# End-a531:F:Heiraten:rHD_rZO_rAN
# a531:F:Bestrafung_erfolgt:rHD_rZO_rAN
# a531:F:Heiraten:rHD_rZO_rAN
# -------
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH_x
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH_x
# -------
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST_x
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST_x
# -------
# End-a550:F:Heiraten:rHD_rBZ_fHD
# End-a550:F:Heiraten:rHD_rZO
# a531:F:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# a531:H:Die_SCHÖNE_erfassen:rHD_rZO
# a531:f:Abtretung_der_Schönen_stehet_bevor:rHD_rZO
# a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rZO_rAN
# a531:f:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN
# a550:F:Bestrafung_erfolgt:rHD_fHD
# a550:F:Bestrafung_erfolgt:rHD_rBZ_fHD
# a550:F:HOCHZEIT_verschieben:rHH_rZO_fHD
# a550:F:Heiraten:rHD_rBZ_fHD
# a550:F:Heiraten:rHD_rZO
# a550:F:PARALYSIERUNG_beheben:rBZ_rZO
# a550:F:PARALYSIERUNG_beheben:rZO_rZO
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD_x
# a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD
# a550:f:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD
# a550:h:MISSETAT_planen:rHD_fHD
# a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# -------
# Anf-a550:F:REITTIER_besorgen:rHD_rHH_fHD
# Anf-a550:f:REITTIER_besorgen:rHD_rHH_fHD
# a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM_rZO
# a550:F:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB
# a550:F:REITTIER_besorgen:rHD_rHH_fHD
# a550:H:Handlungsanweisungen_aus_zweiter_Hand:rHD_rVB
# a550:H:Handlungsanweisungen_aus_zweiter_Hand:rST_rVB
# a550:H:REITTIER_erfassen:rHD_rZO
# a550:HF:REITTIER_erfassen:rST_rVB
# a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD
# a550:f:REITTIER_besorgen:rHD_rHH_fHD
# a550:h:Den_ALTERNATIVEN_nachgehen:rHD_fHD
# -------
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a531:HF:Die_SCHÖNE_erfassen:rHD_rHF
# a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB_x
# -------
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rZO
# a531:HF:Heiratszusage_erpressen:rHD_rZO
# a531:f:FEHLENDEN_Gegenstand_besorgen:rHD_rAN
# a531:f:NEUGIER_auslösen:rHD_rAN
# -------
# End-a550:F:Heiraten:N
# a550:F:Heiraten:N
# -------
# Anf-a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# a550:F:Wache_halten:fHD
# a550:F:Wache_halten:fHD_x
# a550:F:Wache_halten:rHD_rHH_fHD
# a550:F:Wache_halten:rHD_rZM
# a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM
# a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# a550:f:Wache_halten:fHD
# a550:f:Wache_halten:fHD_x
# -------
# a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a550:HF:VOGEL_erfassen:rHD_rHF
# -------
# a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO
# a550:h:TABU_nachgehen:rHD_rBZ_rZO

# %%
# #142 Liste a
# sia_a=[]
# with open('output_1.csv', 'r', encoding='utf-8') as f:
#     reader = csv.reader(f) 
#     for line in reader:
#             sia_a.append(line)
# #143 Liste b
# sia_b=[]         
# with open('output_2.csv', 'r', encoding='utf-8') as f:
#     reader = csv.reader(f) 
#     for line in reader:
#             sia_b.append(line)
# #144 Liste c
# sia_c=[]
# #145 Iteriere durch Liste a
# for element_a in sia_a:
#     #146 Extrahiere den linken String aus dem ersten Element in Liste a
#     left_string_a = element_a[0].split(' ')[0]

#     #147 Überprüfe, ob der linke String aus Liste a in Liste b vorhanden ist
#     if any(left_string_a in element_b[0] for element_b in sia_b):
#         #148 Wenn ja, füge das aktuelle Element aus Liste a zu Liste c hinzu
#         sia_c.append(element_a[0])
# #149 Ausgabe der generierten Liste c
# print(f'Typ: {mZahl}\nMotiv: {mWert}\nHäufigkeit: {haeufigkeit}\nDistanz: {le_po}')
# for element_c in sia_c:
    
#     print(element_c)

# %%
import csv

#142 Liste a
sia_a = []
with open('output_1.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    for line in reader:
        sia_a.append(line)

#143 Liste b
sia_b = []
with open('output_2.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f)
    for line in reader:
        sia_b.append(line)

#144 Liste c
sia_c = []

#145 Erstelle ein Dictionary, das den Gruppenindex für jedes Element in sia_b speichert
group_indices = {}
current_group = 0

for element_b in sia_b:
    if element_b[0] == "-------":
        current_group += 1
    else:
        group_indices[element_b[0]] = current_group

# Iteriere durch Liste a
previous_group = None
for element_a in sia_a:
    #146 Extrahiere den linken String aus dem ersten Element in Liste a
    left_string_a = element_a[0].split(' ')[0]

    #147 Überprüfe, ob der linke String aus Liste a in Liste b vorhanden ist und zu welcher Gruppe es gehört
    for element_b in sia_b:
        if left_string_a in element_b[0]:
            current_group = group_indices.get(element_b[0])

            # Füge den Marker ein, wenn ein Gruppenwechsel erkannt wird
            if previous_group is not None and previous_group != current_group:
                sia_c.append("-------")

            sia_c.append(element_a[0])
            previous_group = current_group
            break

#149 Ausgabe der generierten Liste c
print(f'Typ: {mZahl}\nMotiv: {mWert}\nHäufigkeit: {haeufigkeit}')
for element_c in sia_c:
    print(element_c)
# Out:
# Typ: a550
# Motiv: a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# Häufigkeit: 2
#
# -------
# Anf-a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH {-1}
# a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH {0}
# a550:F:Wache_halten:rHD_rHH_fHD {1}
# a550:F:Wache_halten:fHD {1}
# a550:f:Wache_halten:fHD {2}
# a550:F:Wache_halten:fHD_x {3}
# a550:f:Wache_halten:fHD_x {4}
# a550:F:Wache_halten:rHD_rZM {5}
# a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM {6}
# -------
# a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD {13}
# -------
# a550:h:FREIHEITSBERAUBUNG:rHD_rBZ {inf}
# -------
# a550:HF:VOGEL_erfassen:rHD_rHF {inf}
# -------
# a550:H:Handlungsanweisungen_aus_zweiter_Hand:rST_rVB {inf}
# a550:HF:REITTIER_erfassen:rST_rVB {inf}
# -------
# a550:F:HOCHZEIT_verschieben:rHH_rZO_fHD {inf}
# -------
# a550:F:REITTIER_besorgen:rHD_rHH_fHD {inf}
# -------
# a550:F:Heiraten:rHD_rZO {inf}
# -------
# a550:H:Handlungsanweisungen_aus_zweiter_Hand:rHD_rVB {inf}
# -------
# a550:F:Bestrafung_erfolgt:rHD_rBZ_fHD {inf}
# a550:h:MISSETAT_wie_Entmachtung:rHD_fHD {inf}
# -------
# a550:H:REITTIER_erfassen:rHD_rZO {inf}
# -------
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD {inf}
# -------
# a550:F:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB {inf}
# -------
# a550:F:PARALYSIERUNG_beheben:rBZ_rZO {inf}
# a550:F:Heiraten:rHD_rBZ_fHD {inf}
# -------
# a550:h:TABU_nachgehen:rHD_rBZ_rZO {inf}
# -------
# a550:h:Den_ALTERNATIVEN_nachgehen:rHD_fHD {inf}
# -------
# a550:F:PARALYSIERUNG_beheben:rZO_rZO {inf}
# -------
# a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO {inf}
# -------
# a550:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF {inf}
# -------
# a550:F:Heiraten:N {inf}
# -------
# a550:h:MISSETAT_planen:rHD_fHD {inf}
# a550:f:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD {inf}
# a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD {inf}
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD_x {inf}
# -------
# a550:f:REITTIER_besorgen:rHD_rHH_fHD {inf}
# -------
# a550:F:Bestrafung_erfolgt:rHD_fHD {inf}
# -------
# a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD {inf}
# -------
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH_x {inf}
# -------
# a531:H:Die_SCHÖNE_erfassen:rHD_rZO {inf}
# -------
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH_x {inf}
# -------
# a531:f:NEUGIER_auslösen:rHD_rAN {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rZO {inf}
# -------
# a531:F:Heiraten:rHD_rZO_rAN {inf}
# -------
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB {inf}
# -------
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST {inf}
# -------
# a531:F:Bestrafung_erfolgt:rHD_rZO_rAN {inf}
# a531:F:Heiraten:rHD_rZO {inf}
# -------
# a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN {inf}
# -------
# a531:f:FEHLENDEN_Gegenstand_besorgen:rHD_rAN {inf}
# -------
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHF {inf}
# -------
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST_x {inf}
# -------
# a531:f:Abtretung_der_Schönen_stehet_bevor:rHD_rZO {inf}
# -------
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST {inf}
# -------
# a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM_rZO {inf}
# -------
# a531:f:Begehren_einer_Person_oder_eines_Gegenstandes:rZO_rAN {inf}
# -------
# a531:HF:Heiratszusage_erpressen:rHD_rZO {inf}
# -------
# a531:F:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHH {inf}
# -------
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB_x {inf}
# -------
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rHH {inf}
# -------
# a531:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM {inf}
# -------
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rST_x {inf}
# -------
# a531:F:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN {inf}
# a531:f:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN {inf}
# -------
# a531:HF:Die_SCHÖNE_erfassen:rHD_rHF {inf}
# -------
# Anf-a550:F:REITTIER_besorgen:rHD_rHH_fHD {inf}
# -------
# End-a550:F:Heiraten:rHD_rZO {inf}
# End-a550:F:Heiraten:rHD_rBZ_fHD {inf}
# -------
# End-a550:F:Heiraten:N {inf}
# -------
# Anf-a550:f:REITTIER_besorgen:rHD_rHH_fHD {inf}
# -------
# End-a531:F:Heiraten:rHD_rZO_rAN {inf}

# %%
# Neuen Code nach der Generierung von sia_c einsetzen

# 1. Gruppieren der Elemente in sia_c basierend auf dem Marker "-------"
filtered_sia_c = []
current_group = []

for element in sia_c:
    if element == "-------":
        # 2. Filtern: Behalte nur Gruppen mit mehr als einem Element
        if len(current_group) > 1:
            filtered_sia_c.extend(current_group)
            filtered_sia_c.append("-------")
        current_group = []
    else:
        current_group.append(element)

# Letzte Gruppe prüfen und hinzufügen, falls sie mehr als ein Element enthält
if len(current_group) > 1:
    filtered_sia_c.extend(current_group)

# 3. Die neue gefilterte Liste von sia_c
sia_c = filtered_sia_c

# Ausgabe der neuen gefilterten Liste sia_c
print("Gefilterte Liste sia_c:")
for element_c in sia_c:
    print(element_c)
# Out:
# Gefilterte Liste sia_c:
# Anf-a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH {-1}
# a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH {0}
# a550:F:Wache_halten:rHD_rHH_fHD {1}
# a550:F:Wache_halten:fHD {1}
# a550:f:Wache_halten:fHD {2}
# a550:F:Wache_halten:fHD_x {3}
# a550:f:Wache_halten:fHD_x {4}
# a550:F:Wache_halten:rHD_rZM {5}
# a550:Ff:Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden:rHD_rZM {6}
# -------
# a550:H:Handlungsanweisungen_aus_zweiter_Hand:rST_rVB {inf}
# a550:HF:REITTIER_erfassen:rST_rVB {inf}
# -------
# a550:F:Bestrafung_erfolgt:rHD_rBZ_fHD {inf}
# a550:h:MISSETAT_wie_Entmachtung:rHD_fHD {inf}
# -------
# a550:F:PARALYSIERUNG_beheben:rBZ_rZO {inf}
# a550:F:Heiraten:rHD_rBZ_fHD {inf}
# -------
# a550:h:MISSETAT_planen:rHD_fHD {inf}
# a550:f:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD {inf}
# a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD {inf}
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD_x {inf}
# -------
# a531:f:NEUGIER_auslösen:rHD_rAN {inf}
# a531:H:Auf_Hilfsquelle_zurückgreifen:rHD_rZO {inf}
# -------
# a531:F:Bestrafung_erfolgt:rHD_rZO_rAN {inf}
# a531:F:Heiraten:rHD_rZO {inf}
# -------
# a531:F:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN {inf}
# a531:f:Sich_einem_magischen_Eingriff_unterziehen:rZO_rAN {inf}
# -------
# End-a550:F:Heiraten:rHD_rZO {inf}
# End-a550:F:Heiraten:rHD_rBZ_fHD {inf}
# -------

# %%
nt.from_nx(G)  #150 Konvertiere den NetworkX-Graphen G in ein pyvis-Network-Objekt
print(f'Typ: {mZahl}\nMotiv: {mWert}\nHäufigkeit: {haeufigkeit}')  #148 Gib Informationen über den Graphen aus
nt.show('nx.html')  #149 Speichere die Visualisierung als HTML-Datei und zeige sie an
# Out:
# Typ: a550
# Motiv: a550:f:VERLUST_von_Tieren_Früchten_Ernte_usw_:rHH
# Häufigkeit: 2
# nx.html
#         <iframe
#             width="100%"
#             height="900px"
#             src="nx.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
