# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !git clone https://github.com/edadunashvili/KaFk.git

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# import os
# try:
#     os.chdir('/content/KaFk')
#     print("Verzeichnis erfolgreich gewechselt!")
# except FileNotFoundError:
#     print("Verzeichnis nicht gefunden.")
# except Exception as e:
#     print(f"Ein Fehler ist aufgetreten: {e}")

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# from IPython.display import HTML, display
# def set_css():
#   display(HTML('''
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   '''))
# get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# # Inhaltsannotation(en)

# %% [markdown]
# ### README
#
# ###### Tool zur Auswertung der annotierten Texte  in Form von Motivlisten
#
# ##### Anpassbare Variablen:
# if ("tg" in corp.attrib.get("n", "") or "xtk" in corp.attrib.get("n", "")):Sicherstellen, dass `n` den gesuchte Textkorpus z.B 'xtk', darf nicht leergelassen sein
#
#
# if "" in tn: Sicherstellen, dass `tn` das gesuchte Typ z.B 'a300' enthält, falls leergelassen greift die Suche das gesamte Repertoire zu.

# %%
import xml.etree.ElementTree as ET

# XML-Datei laden und Wurzel abrufen
root_node = ET.parse('gesamt_maerchen.xml').getroot()

Korpus = "xtk"
Typ ="a650A"
Sprache = "" 
Text_ID = ""

# Namespace definieren
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}

unique_schema_set = set()

# Durchlaufen des XML-Baums
for corp in root_node.findall(".//tei:teiCorpus", NS):
    if (Korpus in corp.attrib.get("n", "")):# or "xtk" in corp.attrib.get("n", "")):
        for ganze in corp.findall(".//tei:TEI", NS):
            language = ganze.find(".//tei:teiHeader//tei:langUsage/tei:language", NS)
            # Bedingung für Sprache: anwenden, wenn Sprache definiert ist, oder überspringen
            if language is not None and (not Sprache or language.attrib.get('ident') == Sprache):
                for text in ganze.findall(".//tei:text", NS):
                    if Text_ID in text.attrib['{http://www.w3.org/XML/1998/namespace}id']:  
                        for segm in text.findall(".//tei:seg", NS):
                            tn = segm.attrib.get('{www.dglab.uni-jena.de/vmf/a}ana', '')
                            if Typ in tn:  # Sicherstellen, dass `tn` das gesuchte Muster enthält
                                chisch = text.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                                if chisch:
                                    unique_schema_set.add(chisch)

# Ergebnisse in Datei schreiben
with open("TextClass.txt", 'w', encoding='utf-8') as f:
    f.write(str(sorted(unique_schema_set)))

# %%
import ast
import xml.etree.ElementTree as ET

def setze_variable_aus_datei(dateiname: str, variablenname: str):
    try:
        with open(dateiname, "r", encoding="utf-8") as datei:
            inhalt = datei.read().strip()
        wert = ast.literal_eval(inhalt)
        globals()[variablenname] = wert
        return wert
    except Exception as e:
        print(f"Fehler beim Einlesen und Setzen der Variable: {e}")
        return None

# 1. Mehrere `chisch`-Werte definieren
chisch = setze_variable_aus_datei("TextClass.txt", "chisch")

# Überprüfen, ob die Variable korrekt gesetzt wurde
print(chisch)
# Out:
# ['zyx_cr_nog_rus_30', 'zyx_cr_ttt_rus_31']

# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET

# Modul zur Speicherung in einer zentralen Textdatei
def speichere_gesamt_ergebnisse(dateiname, daten):
    """
    Speichert die Gesamtergebnisse in eine Textdatei.
    
    :param dateiname: Name der Textdatei
    :param daten: Ergebnisse in Form eines Dictionaries {chisch: [Daten]}
    """
    with open(dateiname, 'w', encoding='utf-8') as f:
        for ch, ergebnisse in daten.items():
            f.write(f"\n{ch}:\n")
            for zeile in ergebnisse:
                f.write(f"{zeile}\n")

# Mehrere `chisch`-Werte definieren
chisch = setze_variable_aus_datei("TextClass.txt", "chisch")
# chisch = ['zyx_cr_lbe_rus_43'] # 1.1. Alternativ: Einen chisch-Wert eingeben

root_node = ET.parse('gesamt_maerchen.xml').getroot()

# Speichern der Märchendaten für jedes `chisch`
maerchen_daten = {ch: "" for ch in chisch}

# 2. Schleife für jeden `chisch`-Wert in der Liste
for ch in chisch:
    for ganze in root_node.findall(".//{http://www.tei-c.org/ns/1.0}text"):
        if ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id') == ch:
            for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
                for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
                    for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}seg"):
                        try:
                            # Extrahieren der relevanten Attribute
                            labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
                            labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N')
                            labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N')
                            labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N')
                            labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N')
                            labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N')
                            labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N')
                            labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N')
                            labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N')
                            labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N')
                            labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N')
                            labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N')
                            quelle = ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']  
                            inhalt = (phrase.text.lower().strip()
                                      .replace('|','').replace(':','').replace("ä","ae").replace("ü","ue")
                                      .replace("ö","oe").replace("ß","ss").replace(",","" ).replace("«","")
                                      .replace("»","" ).replace(".","" ).replace(";","" ).replace('"',"")
                                      .replace("?","" ).replace("!","" ).replace("-"," " ).replace("'", "")
                                      .replace("(", "" ).replace(")", "" ).replace("\n","" ).replace("  ", " "))
                            if labela.startswith('a'):
                                # Speichern der Märchendaten in der entsprechenden `chisch`-Liste
                                maerchen_daten[ch] += f"{quelle},{labela},{labelb1},{labelc1},{labelb2},{labelc2},{labelb3},{labelc3},{labelb4},{labelc4},{labelb5},{labelc5},{labeld},{inhalt},0\n"
                        except KeyError as e:
                            print(f"Fehlendes Attribut: {e}")

# 3. Ausgabestruktur für jeden `chisch`-Wert erstellen
gesamt_ergebnisse = {}

# Erstellen der CSV-Dateien und Verarbeiten der Daten
unique_values_per_ch = {}
result_data_per_ch = {}
for ch in chisch:
    # CSV-Datei erstellen
    with open(f"text_{ch}.csv", 'w', encoding='utf-8') as f:
        f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar\n')
        f.write(maerchen_daten[ch])

    # Index-Strings erstellen
    abcd_data = []
    df = pd.read_csv(f"text_{ch}.csv", encoding='utf-8')

    for index, row in df.iterrows():
        quelle = row['quelle']
        labela = row['labela']
        for i in range(1, 6):
            labelb = row[f'labelb{i}']
            labelc = row[f'labelc{i}']
            labeld = row['labeld']
            inhalt = row['inhalt']
            abcd_data.append(f"{labela}:{labelb}:{labelc}:{labeld}")

    # Filterung der Daten
    filtered_data = [line for line in abcd_data if ':N:' not in line]

    # Extrahieren einzigartiger Werte vor dem ersten ':'
    unique_values = set(line.split(':')[0] for line in filtered_data)
    unique_values_per_ch[ch] = unique_values
    result_data_per_ch[ch] = filtered_data

    # Speichern der gefilterten Daten in der Gesamt-Ausgabeliste
    gesamt_ergebnisse[ch] = filtered_data

# Zählen der `chisch`-Werte mit und ohne Ergebnisse
chisch_mit_ergebnissen = [ch for ch, ergebnisse in gesamt_ergebnisse.items() if ergebnisse]
chisch_ohne_ergebnisse = [ch for ch, ergebnisse in gesamt_ergebnisse.items() if not ergebnisse]

print(f"Anzahl des ausgewerteten Typs mit Ergebnissen: {len(chisch_mit_ergebnissen)}")
print(f"Anzahl des ausgewerteten Typs ohne Ergebnisse: {len(chisch_ohne_ergebnisse)}")
print(f"Wenn:")
print(f"\tTyp={Typ}")
print(f"\tKorpus={Korpus}")
print(f"\tSprache={Sprache}")
print(f"\tText_ID={Text_ID}")

# Parsen der `fk/vmf_a.xsd`-Datei und Überprüfen von Werten mit Leerzeichen
fk_tree = ET.parse('kf/vmf_a.xsd').getroot()
enum_elements = fk_tree.findall(".//{http://www.w3.org/2001/XMLSchema}enumeration")
enum_values_with_spaces = {enum.attrib['value'] for enum in enum_elements if ' ' in enum.attrib['value']}
#-------------------------------------------------------------------------
# Ausgabe der Ergebnisse -1
for ch, unique_values in unique_values_per_ch.items():
    print(f"\n{ch}")
    print("-----------------")
    matching_values = [
    value for value in enum_values_with_spaces 
    if any(value.split(' ')[0] == uval for uval in unique_values)
]
    print(*matching_values, sep='\n')
    print("-----------------")

    # Ergebnisse mit Werten anzeigen
    if ch in result_data_per_ch:
        #print("Gefilterte Ergebnisse:")
        for result in result_data_per_ch[ch]:
            print(result)
            
# Löschen der erstellten CSV-Dateien
for ch in chisch:
    try:
        os.remove(f"text_{ch}.csv")  # Löschen der CSV-Datei
    except FileNotFoundError:
        print(f"Datei text_{ch}.csv wurde nicht gefunden und konnte nicht gelöscht werden.")
    except Exception as e:
        print(f"Fehler beim Löschen der Datei text_{ch}.csv: {e}")
# Out:
# Anzahl des ausgewerteten Typs mit Ergebnissen: 516
# Anzahl des ausgewerteten Typs ohne Ergebnisse: 591
# Wenn:
# 	Typ=
# 	Korpus=xtk
# 	Sprache=
# 	Text_ID=
#
# zyx_cc_agx_rus_35
# -----------------
# a1543 Keinen Pfennig weniger
# -----------------
# a1543:F:PROVOKATION:zs
# a1543:H:Auf_PROVOKATION_reagieren:zt
# a1543:H:Numinose_Einmischung_VORTÄUSCHEN:zt
# a1543:H:Auf_VORTÄUSCHEN_reagieren:zs_zt
# a1543:H:ABSURDITÄT_behaupten:zs_zt
# a1543:f:Vorgang_deuten:zs_zt
# a1543:h:VORTÄUSCHEN_eingestehen:zs_zt
# a1543:f:STREIT_schlichten:zs_zt
# a1543:H:Eine_löst_andere_ABSURDITÄT_aus:zs_zt
# a1543:F:STREIT_schlichten:zs_zt_zf
# a1543:h:Vorgang_deuten:zs_zt_zf
# a1543:H:VORTÄUSCHEN_ABSURDITÄT_zu_glauben:zs_zt_zf
# a1543:H:ABSURDITÄT_behaupten:zs_zt_zf
# a1543:H:ABSURDITÄT_beglaubigen:zs_zt_zf
#
# zyx_cc_agx_rus_36
# -----------------
# anh531 При дневном свете не знаешь дороги
# -----------------
# anh531:F:SONSTIGES_verkaufen:zs_zt
# anh531:h:Handeln_als_ABSURDITÄT:zs
# anh531:h:Sachschaden_anrichten:zs
# anh531:H:Schlußfolgerung_als_ABSURDITÄT:zs
# anh531:f:Vorgang_deuten:zs_zsa
# anh531:H:VORTÄUSCHEN_ABSURDITÄT_zu_glauben:zs_zsa
#
# zyx_cc_agx_rus_54
# -----------------
#
# -----------------
#
# zyx_cc_agx_rus_55
# -----------------
#
# -----------------
#
# zyx_cc_agx_rus_56
# -----------------
# a654 Die behenden Brüder
# -----------------
# a654:F:SELTENEN_Gegenstand_besorgen:rHP
# a654:H:Fernseher_als_ZAUBERMITTEL_erhalten:rHD
# a654:H:WAFFE_oder_ZAUBERMITTEL_erhalten:rHD
# a654:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD
# a654:F:Um_eine_Frau_WERBEN:rHD_rHP
# a654:F:ENTFÜHRUNG_beheben:N
# a654:F:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD
# a654:H:VORHERSAGE_des_Aufenthaltsortes:rHD
# a654:F:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:N
# a654:H:Komplikationsfreier_Flug:N
# a654:H:ENTFÜHRUNG_beheben:N
# a654:F:Dilemma_lösen:N
#
# zyx_cc_agx_rus_57
# -----------------
#
# -----------------
#
# zyx_cc_ani_rus_10
# -----------------
# anh248 Молла советуется с ослом
# -----------------
# anh248:#:#:#
# anh248:#:#:#
# anh248:#:#:#
# anh248:#:#:#
#
# zyx_cc_ani_rus_11
# -----------------
# anh384 Мупла Насреддин и дети
# -----------------
# anh384:#:#:#
# anh384:#:#:#
#
# zyx_cc_ani_rus_12
# -----------------
# a654 Die behenden Brüder
# -----------------
# a654:F:HEIRATSABSICHT_kundtun:rHD_rHH
# a654:Hh:Auf_HEIRATSABSICHT_reagieren:rHD_rHH
# a654:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rHH_rZM
# a654:H:Elixier_als_ZAUBERMITTEL_erhalten:rHD_rHH_rZM
# a654:H:Fernseher_als_ZAUBERMITTEL_erhalten:rHD_rHH_rZM
# a654:F:STREIT_schlichten:rHD_rST
# a654:H:STREIT_schlichten:rHD_rST
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM
# a654:F:WIEDERBELEBEN:rHD_rZM
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM
# a654:H:Komplikationsfreier_Flug:rHD_rZM
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rPP
# a654:H:WIEDERBELEBEN:rHD_rZM_rPP
# a654:F:Dilemma_lösen:rHD
# a654:F:Dilemma_lösen:rHD_fST
# a654:h:Dilemma_lösen:rHD_fST
#
# zyx_cc_ani_rus_13
# -----------------
#
# -----------------
#
# zyx_cc_ani_rus_14
# -----------------
#
# -----------------
#
# zyx_cc_ani_rus_15
# -----------------
#
# -----------------
#
# zyx_cc_ani_rus_16
# -----------------
# a1592B Topf hat ein Kind
# -----------------
# a1592B:f:#:zs_zt
# a1592B:h:#:zs_zt
# a1592B:f:#:zs_zt
# a1592B:h:#:zs_zt
# a1592B:f:#:zs_zt
# a1592B:h:#:zs_zt
#
# zyx_cc_ani_rus_17
# -----------------
#
# -----------------
#
# zyx_cc_ani_rus_8
# -----------------
# anh395 Эта мера — одна треть мана
# -----------------
# anh395:#:#:#
# anh395:#:#:#
# anh395:#:#:#
#
# zyx_cc_ani_rus_9
# -----------------
# anh313 Продаю лестницу
# -----------------
# anh313:#:#:#
# anh313:#:#:#
#
# zyx_cc_aqc_rus_19
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_20
# -----------------
# a1592B Topf hat ein Kind
# -----------------
# a1592B:#:#:#
# a1592B:#:#:#
#
# zyx_cc_aqc_rus_21
# -----------------
# anh577 Возьми и себе
# -----------------
# anh577:#:#:#
# anh577:#:#:#
# anh577:#:#:#
#
# zyx_cc_aqc_rus_22
# -----------------
# anh248 Молла советуется с ослом
# -----------------
# anh248:#:#:#
#
# zyx_cc_aqc_rus_23
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_24
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_25
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_26
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_27
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_28
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_29
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_30
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_31
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_32
# -----------------
#
# -----------------
#
# zyx_cc_aqc_rus_33
# -----------------
# aTMJ2672 Zwei Streitende stehlen seine Decke
# -----------------
# aTMJ2672:#:#:#
#
# zyx_cc_ava_ava_204
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_205
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_206
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_207
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_208
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_209
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_210
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_211
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_212
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_213
# -----------------
#
# -----------------
#
# zyx_cc_ava_ava_214
# -----------------
#
# -----------------
#
# zyx_cc_ava_deu_204
# -----------------
#
# -----------------
#
# zyx_cc_ava_deu_205
# -----------------
# a882 Die Wette auf die Treue der Ehefrau
# aU ATU Typ: unklar welcher
# -----------------
# aU:#:#:rHH_fHH
# a882:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP
# a882:H:TÖTUNG:rHD_fPP
# a882:H:Vorgang_deuten:rHD_rHH
# a882:F:TAT_ausschildern:rVB
# a882:H:Ausgeschilderte_TAT_zur_Kenntnis_nehmen:rPP
# a882:F:HEIRATSABSICHT_kundtun:rHP_rPP
# a882:H:Heiraten:rHD_rPP
# a882:F:Keuschheit:rHD_rPP
# a882:F:Tapferkeit_beweisen:rHD_rPP
# a882:h:KONTAKT_abbrechen:rHD_rPP
# a882:h:Sich_ZURÜCKZIEHEN:rHD
# a882:H:Unterkommen:rHD_rVB
# a882:F:Tapferkeit_beweisen:rHD_rVB
# a882:F:VEREINBARUNG:rHD_rVB
# a882:F:Reitkünste_zeigen:rVB_rPP_rAN
# a882:F:WETTBEWERB:rVB_rPP_rAN
# a882:F:VEREINBARUNG:rVB_rPP_rAN
# a882:F:WETTE_um_die_VERFÜHRUNG_der_Frau:rVB_rPP_rAN
# a882:F:VEREINBARUNG:rVB_rPP_rAN
# a882:H:Reitkünste_zeigen:rPP_rAN
# a882:H:WETTBEWERB_angehen:rPP_rAN
# a882:f:Auftrag_zur_VERFÜHRUNG:rAN_fPP
# a882:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP
# a882:F:Loyalität_VORTÄUSCHEN:rHD_fPP
# a882:F:Auftrag_zum_VORTÄUSCHEN:rHD_rHF
# a882:H:Geänderte_IDENTITÄT_VORTÄUSCHEN:rHF_fPP
# a882:H:Auf_VORTÄUSCHEN_reagieren:rHF_fPP
# a882:f:MARKIERUNGEN_anbringen:rHF_fPP
# a882:H:Auftrag_zum_VORTÄUSCHEN:rHD_rHF
# a882:H:Vorgang_deuten:rHD_rHF
# a882:H:Gespräche_belauschen:N
# a882:F:VERLEUMDUNG_beheben:N
# a882:H:IDENTITÄT_ändern:rHD
# a882:H:Geänderte_IDENTITÄT_VORTÄUSCHEN:rHD_fPP
# a882:F:WETTBEWERB:rHD_fPP
# a882:H:WETTBEWERB_angehen:rHD_fPP
# a882:F:MARKIERUNGEN_anbringen:rHD_fPP
# a882:H:Unterkommen:rHD_rVB
# a882:F:VERLEUMDUNG_beheben:rHD_rVB
# a882:F:Um_einen_Auftrag_WERBEN:rHD_fVB
# a882:F:Intensive_Erkundungsaktion:rHD_rAN
# a882:h:Intensive_Erkundungsaktion:rHD_rAN
# a882:H:Intensive_Erkundungsaktion:rHD_rAN_fPP
# a882:H:MARKIERUNGEN_erkennen:rHD_rAN_fPP
# a882:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rAN_fPP
# a882:H:VERLEUMDUNG_beheben:rHD_rAN_fPP
# a882:H:VEREINBARUNG_einhalten:rHD_rAN_fPP
# a882:H:Auf_dem_Heimweg:rHD_rPP
# a882:H:Tapferkeit_beweisen:rHD_rPP
#
# zyx_cc_ava_deu_206
# -----------------
# a303 Die zwei Brüder
# aU ATU Typ: unklar welcher
# -----------------
# aU:H:Auftrag_zum_Kochen:rHD_rHF
# a303:f:PROVOKATION:rHD_rHF_rAN
# a303:h:Auf_PROVOKATION_reagieren:rHD_rHF_rAN
# a303:f:PROVOKATION:rHD_rHF_rAN
# a303:H:Auf_PROVOKATION_reagieren:rHD_rHF_rAN
# a303:H:VERTREIBUNG:rHD_rHF_rAN
# aU:f:KANNIBALISMUS:rHD_rHF_rAN
# aU:H:Verstecken_als_Rettung:rHD_rHF_rAN
#
# zyx_cc_ava_deu_207
# -----------------
# aTMJ1545_4 The exiled wife's dearest possession
# a875 Die kluge Bauertochter
# a875E The Unjust Decision: The Oil Press Given Birth to a Foal
# -----------------
# a875:f:Auftrag_als_ABSURDITÄT:zf_zfa
# a875:hf:Information_aus_zweiter_Hand:zf_zfa
# a875:hf:Information_aus_zweiter_Hand:zs_zfa
# a875:f:Auftrag_als_ABSURDITÄT:zs_zfa
# a875:H:Auf_ABSURDITÄT_reagieren:zs
# a875:H:ABSURDITÄT_entgegentreten:zs_zfa
# a875:HF:Information_aus_zweiter_Hand:zs_zfa
# a875:HF:Information_aus_zweiter_Hand:zf_zfa
# a875:H:ABSURDITÄT_entgegentreten:zf_zfa
# a875:f:Auftrag_als_ABSURDITÄT:zf_zfa
# a875:hf:Information_aus_zweiter_Hand:zf_zfa
# a875:hf:Information_aus_zweiter_Hand:zs_zfa
# a875:f:Auftrag_als_ABSURDITÄT:zs_zfa
# a875:H:Auf_ABSURDITÄT_reagieren:N
# a875:H:ABSURDITÄT_entgegentreten:N
# a875:HF:Information_aus_zweiter_Hand:N
# a875:HF:Information_aus_zweiter_Hand:zf_zfa
# a875:H:ABSURDITÄT_entgegentreten:zf_zfa
# a875:H:Heiraten:zs_zf
# a875E:h:ABSURDITÄT_behaupten:zt_zt
# a875E:F:STREIT_schlichten:zs_zt
# a875E:H:STREIT_Schlichten_angehen:zs_zt
# a875E:f:Ungewünschtes_Wesen_beseitigen:zf_zfa
# aTMJ1545_4:f:Forderung_oder_Bitte_als_ABSURDITÄT:zs_zsa
# aTMJ1545_4:H:ABSURDITÄT_entgegentreten:zs_zsa
# a875E:H:Ende:N
#
# zyx_cc_ava_deu_208
# -----------------
# a1525E Diebswette
# -----------------
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
# a1525E:#:#:#
#
# zyx_cc_ava_deu_209
# -----------------
# a314A Hirt und die drei Riesen
# a530 Prinzessin auf dem Glasberg
# aU ATU Typ: unklar welcher
# -----------------
# a530:h:KRANKHEIT:rHD_rHH_fHD
# a530:F:Wache_halten:rHD_rHH_fHD
# a530:h:STERBEN:rHD_rHH_fHD
# a530:h:Wache_halten:fHD
# a530:h:Vorgang_deuten:rHD_fHD
# a530:h:RESPEKTLOSIGKEIT:rHD_fHD
# a530:h:Wache_halten:fHD
# a530:H:Heimlich_beobachten:rHD_fST
# a530:H:Zweikampf:rHD_fST
# a530:H:REITTIER_erfassen:rHD_fST
# a530:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_fST
# a530:h:Vorgang_deuten:rHD_fHD
# a530:h:RESPEKTLOSIGKEIT:rHD_fHD
# a530:F:VEREINBARUNG:rHP
# a530:f:Um_eine_Frau_WERBEN:fHD
# a530:H:IDENTITÄT_ändern:rHD
# a530:H:Reitkünste_zeigen:rHD
# a530:h:Vorgang_deuten:rHD_fHD
# a530:H:VEREINBARUNG_einhalten:rHD_rHP
# a530:H:SCHÖNE_erfassen:rHD_rHP
# a530:H:IDENTITÄT_ändern:rHD_fHD
# a530:h:Vorgang_deuten:rHD_fHD
# a530:h:RESPEKTLOSIGKEIT:rHD_fHD
# a530:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_fHD
# a530:H:RESPEKTLOSIGKEIT_entgegentreten:rHD_fHD
# a530:H:Heiraten:rHD_rPP
# a530:H:Geburt_des_NACHKOMMENs:rHD_rPP
# a314A:F:HEIRATSABSICHT_kundtun:rHD_fHH
# a314A:f:Beschaffung_der_AUSRÜSTUNG:rHD_fHH
# a314A:h:VERTREIBUNG:rHD_fHH
# a314A:H:Überrascht_werden_oder_geraten:rHD_rST_rST
# a314A:f:BEHINDERUNG_durch_Verstümmelung:rHD_rST_rST
# a314A:F:PROVOKATION:rHD_rST_rST
# a314A:H:Auf_PROVOKATION_reagieren:rHD_rST_rST
# a314A:H:Adoption:rHD_rST_rST
# a314A:F:Um_einen_Auftrag_WERBEN:N
# a314A:Hh:Auf_WERBEN_reagieren:N
# a314A:H:Zweikampf:rHD_rBZ
# a314A:H:Fremdes_Gut_beschlagnahmen:rHD_rBZ
# a314A:H:Zweikampf:rHD_rBZ
# a314A:H:UNGEHEUER_erfassen:rHD_rBZ
# a314A:H:UNGEHEUER_herbeiholen:rHD_rST
# a314A:h:ANGST_auslösen:rHD_rST
# a314A:F:TÖTUNG:rHD_rST
# a314A:H:Wiedergutmachung_erzielen:rHD_rST_rBZ
# a314A:H:BEHINDERUNG_beheben:rHD_rST_rBZ
# aU:hf:Information_aus_zweiter_Hand:rHD_rVB
# aU:f:Krieg_führen:rHD_rST
# aU:H:Beschaffung_der_AUSRÜSTUNG:rHD_rST
# aU:h:Krieg_führen:rHD
#
# zyx_cc_ava_deu_210
# -----------------
# a701 Riesenspielzeug
# aU ATU Typ: unklar welcher
# -----------------
# aU:#:#:#
# a701:#:#:#
# a701:#:#:#
# a701:#:#:#
# a701:#:#:#
# a701:#:#:#
#
# zyx_cc_ava_deu_211
# -----------------
# aU ATU Typ: unklar welcher
# -----------------
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
#
# zyx_cc_ava_deu_212
# -----------------
# a726 Die drei Alten
# -----------------
# a726:f:VERSUCHUNG:N
# a726:h:Auf_VERSUCHUNG_reagieren:N
# a726:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHH
# a726:F:Eigene_Misshandlung_nachforschen:rHD_rHH
# a726:H:Krisenursachen_ergründen:rHD_rHH
# a726:HF:Wiedergutmachung_erzielen:rHD_rHH
# a726:H:Begegnung:rST
# a726:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rST
# a726:H:Begegnung:rHD_rST
# a726:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST
# a726:F:Ursache_des_Altaussehens_deuten:rHD_rHP
# a726:H:Begegnung:rHD_rHP
# a726:F:Wiedergutmachung_erzielen:rHD_rHP
# a726:F:RÄTSELHAFTES_Gespräch_oder_Handlung:rHD_rHP
# a726:F:Heiraten:rHD_rHP
# a726:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHH
# a726:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:rHD_rHH
# a726:F:Bedingungslose_Gehorsamkeit:rHD_rHP_rHP
# a726:H:Heiraten:rHD_rPP
# a726:h:FLUCH:rHD_rPP
# a726:h:STERBEN:rHD_rPP
# a726:Hh:Ursache_des_Altaussehens_deuten:rHD_rHP
#
# zyx_cc_ava_deu_213
# -----------------
# a460A Reise zu Gott
# -----------------
# a460A:h:STERBEN:rHD
# a460A:F:Erträumen:rHD
# a460A:F:Jenseitswanderung_unternehmen:rHD
# a460A:F:Folge_von_Kriminalität_deuten:rHD_rVB
# a460A:F:Lösungsweg_für_leidendes_TIER_deuten:rHD_fVB
# a460A:F:Folge_von_Bigotterie_deuten:rHD_fVB
# a460A:F:Lösungsweg_für_sonstiges_LEID_deuten:rHD_rVB
# a460A:H:Begegnung:rHD_rHF
# a460A:H:Vermittlung:rHD_rHF
# a460A:HF:Information_aus_zweiter_Hand:rHD_rHF
# a460A:h:Lösungsweg_für_leidendes_TIER_deuten:rHD_rHF
# a460A:HF:Information_aus_zweiter_Hand:N
# a460A:h:Folge_von_Bigotterie_deuten:N
# a460A:HF:Information_aus_zweiter_Hand:rHD_rHF
# a460A:h:Lösungsweg_für_sonstiges_LEID_deuten:rHD_rHF
# a460A:HF:Information_aus_zweiter_Hand:rHD_rHF
# a460A:h:Lösungsweg_für_sonstiges_LEID_deuten:rHD_rHF
#
# zyx_cc_ava_rus_214
# -----------------
# anh789 Первый инжир
# -----------------
# anh789:#:#:#
# anh789:#:#:#
# anh789:#:#:#
#
# zyx_cc_ddo_ddo_95
# -----------------
#
# -----------------
#
# zyx_cc_ddo_ddo_96
# -----------------
#
# -----------------
#
# zyx_cc_ddo_ddo_97
# -----------------
#
# -----------------
#
# zyx_cc_ddo_ddo_98
# -----------------
#
# -----------------
#
# zyx_cc_ddo_ddo_99
# -----------------
#
# -----------------
#
# zyx_cc_ddo_kat_95
# -----------------
# a327 Die Kinder und der Unhold
# a313 Magische Flucht
# -----------------
# a327:h:KONTAKT_abbrechen:rHD_rHH
# a327:HF:KANNIBALISMUS_beheben:rHD_rST
# a327:H:FLUCHT_vorbereiten:rHD_rST
# a313:Hh:FLUCHT:rHD_rZM_rAN
# a313:h:VERFOLGUNG:rHD_rZM_rAN
# a313:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a313:H:VERFOLGUNG_entkommen:rHD_rZM_rAN
# a313:Hh:FLUCHT:rHD_rAN
# a313:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rAN
# a313:H:VERFOLGUNG_entkommen:rHD_rAN
# a313:H:Loyalität_VORTÄUSCHEN:rHD_rAN
# a313:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN
# a327:H:KONTAKT_wiederherstellen:rHD_rHH
#
# zyx_cc_ddo_kat_96
# -----------------
#
# -----------------
#
# zyx_cc_ddo_kat_97
# -----------------
#
# -----------------
#
# zyx_cc_ddo_kat_98
# -----------------
#
# -----------------
#
# zyx_cc_ddo_kat_99
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_13
# -----------------
# a516 Der treue Johannes
# aU ATU Typ: unklar welcher
# -----------------
# aU:h:VERTREIBUNG:rHH_fHH
# aU:H:Notwendiges_auf_wunderbare_Weise_besorgen:rHD_rHH
# aU:H:Goldhaariges_Kind_zur_Welt_bringen:rHD_rHH
# a516:h:FERNLIEBE_wird_ausgelöst:N
# a516:F:Auf_Hilfsquelle_zurückgreifen:rHF_rHP
# a516:F:Krisenursachen_ergründen:rHF_rHP
# a516:H:Gespräche_belauschen:rHF_rPP
# a516:H:Enthüllung_der_Wahrheit_durch_das_subtile_Mittel:rHF_rPP
# a516:H:Krisenursachen_ergründen:rHF_rPP
# a516:H:Vorgang_deuten:rHF_rHP
# aU:F:Um_eine_Frau_WERBEN:rHH_rHP
# aU:H:FERNLIEBE_beheben:rHH_rHP
# aU:H:Heiraten:N
#
# zyx_cc_ddo_rus_14
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_15
# -----------------
# a655 Die scharfsinnigen Brüder
# a976 Die vornehmste Handlung
# -----------------
# a655:F:Erbschaft_teilen:zs_zsa
# a655:h:STERBEN:zs_zsa
# a655:h:VERLUST_des_Schatzes:zs
# a655:F:VERLUSTursache_beheben:zs
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs
# a655:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:zs_zt
# a655:F:VORHERSAGE_erforderlich:zs_zt
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zt
# a655:h:Auf_VORHERSAGE_reagieren:zs_zt
# a655:F:VERLUSTursache_beheben:zs_zt
# a655:F:EINLADUNG_oder_Bestellung:zf_zfa
# a655:F:Gespräche_belauschen:zf_zfa
# a655:hf:VORHERSAGE_subtiles_Geschmak:zs_zfa
# a655:HF:VORHERSAGE_subtiler_Identität:zs_zfa
# a655:HF:Information_aus_zweiter_Hand:zf_zfa
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zf_zfa
# a655:HF:VORHERSAGE_subtiler_Identität:zf_zfa
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zf_zfa
# a655:HF:VORHERSAGE_subtiles_Geschmak:zf_zfa
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zf_zfa
# a655:HF:VORHERSAGE_subtiles_Geschmak:zf_zfa
# a655:F:STREIT_schlichten:zt_zf
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:H:STREIT_schlichten:zt_zf
# a655:H:VERLUSTursache_beheben:zt_zf
# a976:F:VORHERSAGE_erforderlich:zs_zf
# a976:F:VERLUSTursache_beheben:zs_zf
# a976:F:Rätsel_lösen:zs_zf
# a976:F:ERZÄHLEN_beginnen:zs_zf
# a655:H:ERZÄHLEN_beenden:zs_zf
# a655:Hh:Rätsel_lösen:zs_zf
# a655:H:VERLUSTursache_beheben:zs_zf
# a655:H:STREIT_schlichten:zs_zf
#
# zyx_cc_ddo_rus_16
# -----------------
# a654 Die behenden Brüder
# -----------------
# a654:F:Um_eine_Frau_WERBEN:rHD_rPP
# a654:F:SELTENEN_Gegenstand_besorgen:rHD_rPP
# a654:H:Elixier_als_ZAUBERMITTEL_erhalten:rHD_rST
# a654:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a654:H:Fernseher_als_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM
# a654:F:WIEDERBELEBEN:rHD_rZM
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM
# a654:H:Komplikationsfreier_Flug:rHD_rZM
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rPP
# a654:H:WIEDERBELEBEN:rHD_rZM_rPP
# a654:F:Dilemma_lösen:rHD_rPP
# a654:h:Dilemma_lösen:rHD_rPP
#
# zyx_cc_ddo_rus_17
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_18
# -----------------
# a545B Der gestiefelte Kater
# -----------------
# a545B:F:VEREINBARUNG:rHD_rHF
# a545B:H:Verlobung_arrangieren:rHF_rHP
# a545B:F:EINLADUNG_oder_Bestellung:rHF_rHP
# a545B:Hh:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rHF
# a545B:H:Verlust_VORTÄUSCHEN:rHD_rHF
# a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_rHP
# a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHF_rHP
# a545B:H:REITTIER_erhalten:rHF_rHP
# a545B:H:Heiraten:rHD_rHF
#
# zyx_cc_ddo_rus_19
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_20
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_21
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_22
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_23
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_25
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_26
# -----------------
# a982 Die vorgetäuschte Erbschaft
# a300A The Fight on the Bridge
# a300 Der Drachentöter
# -----------------
# a982:h:Reiche_Erbschaft_VORTÄUSCHEN:rHH
# a982:h:STERBEN:rHH
# a982:H:Auf_VORTÄUSCHEN_reagieren:rHD_fHD
# a982:F:Erträumen:rHD_rHH_fHD
# a982:F:Wache_halten:rHD_rHH_fHD
# a982:Hh:Wache_halten:fHD
# a982:H:Wache_halten:rHD_rST
# a982:H:Wegweisung_erpressen:rHD_rST
# a982:Hh:Wache_halten:rHD_rST
# a982:H:Wegweisung_erpressen:rHD_rST
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:H:Unterkommen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Zweikampf:rHD_rAN
# a300:h:Loyalität_VORTÄUSCHEN:rHD_rAN
# a300:f:VERGIFTUNG:rHD_rAN
# a300:H:Auf_VORTÄUSCHEN_reagieren:rHD_fZM
# a300:H:VERGIFTUNG_beheben:rHD_fZM
# a300:H:Menschliche_OPFERGABE_beheben:rHD_rPP
# a300:h:KONTAKT_abbrechen:rHD_rPP
# a300:H:NEUGIER_auslösen:rVB_rHP
# a300:HF:Information_aus_zweiter_Hand:rVB_rHP
# a300:H:Auf_ausgelöste_NEUGIER_reagieren:rVB_rHP
# a300:F:EINLADUNG_oder_Bestellung:rVB_rHP
# a300:h:Heldentat_VORTÄUSCHEN:rHD_rHP_fHD
# a300:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rHP_fHD
# a300:F:IDENTITÄT_beweisen:rHD_rHP_fHD
# a300:H:IDENTITÄT_beweisen:rHD_rHP_fHD
# a300:H:KONTAKT_wiederherstellen:rHD_rHP_fHD
# a300:F:Heiraten:rHD_rHP
# a300:h:Heiraten:rHD_rHP
# a300:H:Um_Gegenleistung_bitten:rHD_rHP
# a300:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rHP
# a300:h:Auf_ALTERNATIVEN_reagieren:rHD_rZM
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:H:Unterkommen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Sorge_um_Schutzbedürftige:rHD_rST
# a300:F:Angebot_KÖNIG_zu_werden:rHD_rHP
# a300:h:Auf_Angebot_KÖNIG_zu_werden_reagieren:rHD_rHP
# a300:H:Um_Gegenleistung_bitten:rHD_rHP
# a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP
# a300:H:Hilfeversprechen_erhalten:rHD_rHF
# a300:HF:Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a300:H:Beschaffung_der_AUSRÜSTUNG:rHD_rHP
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a300:H:Hilfsquelle_greift_zurück:rHD_rHF
# a300:H:BEHINDERUNG_beheben:rHD_rHF
# a300A:H:Krisenursachen_ergründen:rHD_rPP
# a300A:F:ENTFÜHRUNG_beheben:rHD_rPP
# a300A:HF:Abraten_von_der_MISSION:rHD_rPP
# a300A:Hh:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rPP
# a300A:H:Mut_zeigen:rHD_rAN
# a300A:HF:Zweikampf:rHD_rPP
# a300A:H:Zweikampf:rHD_rAN
# a300A:H:Auf_dem_Heimweg:N
# a300A:F:Angebot_KÖNIG_zu_werden:N
# a300A:h:Auf_Angebot_KÖNIG_zu_werden_reagieren:N
#
# zyx_cc_ddo_rus_27
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_28
# -----------------
# aTMJ1545_4 The exiled wife's dearest possession
# a875 Die kluge Bauertochter
# a875E The Unjust Decision: The Oil Press Given Birth to a Foal
# -----------------
# a875:F:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zt
# a875:HF:Information_aus_zweiter_Hand:zs_zf
# a875:F:EINLADUNG_oder_Bestellung:zs_zf
# a875:H:Auf_EINLADUNG_oder_Bestellung_reagieren:zs_zf
# a875:F:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zf
# a875:H:Heiraten:zs_zf
# a875E:h:ABSURDITÄT_behaupten:N
# a875E:F:STREIT_schlichten:N
# a875E:F:Auf_Hilfsquelle_zurückgreifen:zs_zt
# a875E:HF:ABSURDITÄT_entgegentreten:zs_zt
# a875E:H:ABSURDITÄT_entgegentreten:zt_zf
# a875E:H:STREIT_schlichten:zt_zf
# aTMJ1545_4:f:Forderung_oder_Bitte_als_ABSURDITÄT:zs_zf
# aTMJ1545_4:H:ABSURDITÄT_entgegentreten:zs_zf
# a875:H:Ende:zs_zf
#
# zyx_cc_ddo_rus_29
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_30
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_31
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_32
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_33
# -----------------
# a56A Fuchs und Vogeljunge
# -----------------
# a56A:#:#:#
# a56A:#:#:#
# a56A:#:#:#
# a56A:#:#:#
#
# zyx_cc_ddo_rus_34
# -----------------
# a327 Die Kinder und der Unhold
# a313 Magische Flucht
# -----------------
# a327:h:KONTAKT_abbrechen:rHD_rHH
# a327:H:AUSRÜSTUNG_als_ZAUBERMITTEL_erhalten:rHD_rHH
# a327:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD
# a327:Hh:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD
# a327:HF:KANNIBALISMUS_beheben:rHD_rST
# a327:HF:FLUCHT_vorbereiten:rHD_rST
# a313:H:FLUCHT:rHD_rAN
# a313:h:VERFOLGUNG:rHD_rAN
# a313:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rAN
# a313:H:VERFOLGUNG_entkommen:rHD_rAN
# a313:H:KANNIBALISMUS_beheben:rHD_rAN
# a327:H:KONTAKT_wiederherstellen:rHD_rHH
#
# zyx_cc_ddo_rus_35
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_36
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_37
# -----------------
# a1698 Schwerhörig Schwerhörigkeit
# a1528 Den Hut bewachen
# a1560 Wie das Essen so die Arbeit
# aU ATU Typ: unklar welcher
# -----------------
# a1560:#:#:#
# a1560:#:#:#
# a1560:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# a1698:#:#:#
# a1698:#:#:#
# a1698:#:#:#
# a1698:#:#:#
# a1698:#:#:#
# a1528:#:#:#
# aU:#:#:#
# aU:#:#:#
#
# zyx_cc_ddo_rus_39
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_4
# -----------------
# a301 Die drei geraubten Prinzessinnen
# -----------------
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rAN_fHD
# a301:h:Auf_PROVOKATION_reagieren:rAN_fHD
# a301:h:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Vorgang_deuten:rHD_fHD
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rAN_fHD
# a301:h:Auf_PROVOKATION_reagieren:rAN_fHD
# a301:h:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Vorgang_deuten:rHD_fHD
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:h:PROVOKATION:rHD_fVB
# a301:H:Auf_PROVOKATION_reagieren:rHD_fVB
# a301:H:Wegweisung_erpressen:rHD_rAN
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:HF:Abraten_von_der_MISSION:rHD_rPP
# a301:Hh:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:H:Heiraten:rHD_rAN
# a301:H:ENTFÜHRUNG_beheben:rHD_rAN
# a301:H:Heiraten:rHD_rAN
# a301:H:Ende:rHD_rAN
#
# zyx_cc_ddo_rus_40
# -----------------
# a930 Uriasbrief
# aU ATU Typ: unklar welcher
# -----------------
# aU:#:#:#
# a930:h:Aussetzung:rHD_rAN
# a930:H:Tier_als_Schutzgeist_erhalten:rHD_rST
# a930:H:Überrascht_werden_oder_geraten:rHD_rST
# a930:H:Adoption:rHD_rST
# aU:#:#:#
#
# zyx_cc_ddo_rus_41
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_44
# -----------------
# a402 Maus als Braut
# a471 Brücke zur anderen Welt
# -----------------
# a402:F:SCHÖNE_herbeiholen:N
# a402:F:Schicksalsbestimmender_Weisung_folgen:N
# a402:F:Ungewollte_Verlobung_akzeptieren:N
# a402:H:Überraschende_positive_Wendung:N
# a402:H:Änderung_der_EXISTENZFORM:N
# a402:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:N
# a402:f:FRUCHT_besorgen:N
# a402:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:N
# a402:H:Universellen_ZAUBERMITTEL_erhalten:N
# a402:F:Zauberkunstfertigkeit_gewährleisten:N
# a402:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:N
# a402:H:Universellen_ZAUBERMITTEL_erhalten:N
# a471:F:Jenseitswanderung_unternehmen:N
# a471:F:Auf_Hilfsquelle_zurückgreifen:N
# a471:F:Ursache_des_unstillbaren_Hungers_deuten:N
# a471:F:Ursache_des_unstillbaren_Dursts_deuten:N
# a471:H:Jenseitswanderung_unternehmen:N
# a471:H:Ursache_des_unstillbaren_Hungers_deuten:N
# a471:H:Ursache_des_unstillbaren_Dursts_deuten:N
# a471:H:VEREINBARUNG_auflösen:N
# a402:H:Ende:N
#
# zyx_cc_ddo_rus_45
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_47
# -----------------
# a327B Daeumling und Menschenfresser
# a328 Corvetto
# -----------------
# a327B:f:VEREINBARUNG:rHD_rAN
# a327B:h:Gastfreundlichkeit_VORTÄUSCHEN:rHD_rAN
# a327B:f:VEREINBARUNG:rHD_rAN
# a327B:F:Um_eine_Frau_WERBEN:rHD_rAN
# a327B:F:VEREINBARUNG_einhalten:rHD_rAN
# a327B:f:KANNIBALISMUS:N
# a327B:H:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:N
# a327B:f:KANNIBALISMUS:rHD_rAN
# a327B:H:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN
# a327B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN
# a327B:F:IDENTITÄT_ändern:rHD
# a327B:H:Schlaf_VORTÄUSCHEN:rHD_rAN
# a327B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN
# a327B:H:Personenschaden_anrichten:rHD_rAN
# a327B:f:Auftrag_zum_Kochen:rHD_rAN
# a327B:H:Auftrag_zum_Kochen:rHD_rAN
# a327B:H:Jemanden_in_Kannibalismus_verwickeln:rHD_rAN
# a327B:Hh:FLUCHT:rHD_fHD
# a328:F:Um_eine_Frau_WERBEN:rHD_rHP
# a328:h:VEREINBARUNG:rHD_rHP
# a328:f:SELTENEN_Gegenstand_besorgen:rHD_rHP
# a328:H:IDENTITÄT_ändern:rHD
# a328:H:Unruhe_VORTÄUSCHEN:rHD_rZO_rAN
# a328:H:Auf_VORTÄUSCHEN_reagieren:rHD_rZO_rAN
# a328:H:SELTENEN_Gegenstand_erfassen:rHD_rZO_rAN
# a328:H:SELTENEN_Gegenstand_besorgen:rHD_rHP
# a328:f:NUTZTIER_besorgen:rHD_rHP
# a328:H:Unruhe_VORTÄUSCHEN:rHD_rZO_rAN
# a328:H:Auf_VORTÄUSCHEN_reagieren:rHD_rZO_rAN
# a328:H:NUTZTIER_erfassen:rHD_rZO_rAN
# a328:H:NUTZTIER_besorgen:rHD_rHP
# a328:f:UNGEHEUER_herbeiholen:rHD_rHP
# a328:H:IDENTITÄT_ändern:rHD
# a328:H:Geänderte_IDENTITÄT_VORTÄUSCHEN:rHD_rBZ
# a328:F:Truhe_herstellen:rHD_rBZ
# a328:H:Testnotwendigkeit_VORTÄUSCHEN:rHD_rBZ
# a328:H:Auf_VORTÄUSCHEN_reagieren:rHD_rBZ
# a328:H:UNGEHEUER_erfassen:rHD_rBZ
# a328:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rBZ
# a328:H:UNGEHEUER_herbeiholen:rHD_rBZ_rHP
# a328:h:VERSCHLINGEN:rHD_rBZ_rHP
# a328:h:VERFOLGUNG:rHD_rBZ
# a328:H:TÖTUNG:rHD_rBZ
# a328:H:VERFOLGUNG_entkommen:rHD_rBZ
# a328:H:VERSCHLINGEN_beheben:rHD_rHP_rPP
# a328:H:Heiraten:rHD_rHP_rPP
#
# zyx_cc_ddo_rus_48
# -----------------
# a301 Die drei geraubten Prinzessinnen
# -----------------
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rAN_fHD
# a301:h:Auf_PROVOKATION_reagieren:rAN_fHD
# a301:h:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Vorgang_deuten:rHD_fHD
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rAN_fHD
# a301:h:Auf_PROVOKATION_reagieren:rAN_fHD
# a301:h:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Vorgang_deuten:rHD_fHD
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:f:PROVOKATION:rHD_rAN
# a301:H:Auf_PROVOKATION_reagieren:rHD_rAN
# a301:H:Vorgang_deuten:rHD_fVB
# a301:H:Wegweisung_erpressen:rHD_fVB
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:HF:Abraten_von_der_MISSION:rHD_rPP
# a301:Hh:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rPP
# a301:F:Krisenursachen_ergründen:rHD_rPP
# a301:F:VEREINBARUNG:rHD_rPP
# a301:H:TÖTUNG:rHD_rAN
# a301:H:VEREINBARUNG_einhalten:rHD_rAN
# a301:H:Heiraten:rHD_rAN
#
# zyx_cc_ddo_rus_49
# -----------------
# a327 Die Kinder und der Unhold
# a327B Daeumling und Menschenfresser
# -----------------
# a327B:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:rVB_rAN
# a327B:h:Gastfreundlichkeit_VORTÄUSCHEN:rHD_rAN_fHD
# a327B:Hh:Auf_VORTÄUSCHEN_reagieren:rHD_rAN_fHD
# a327B:f:KANNIBALISMUS:rHD_rAN_fHD
# a327B:H:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN
# a327B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN
# a327B:f:KANNIBALISMUS:rHD_rAN
# a327B:H:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN
# a327B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN
# a327B:F:IDENTITÄT_ändern:rHD_fHD
# a327B:H:Personenschaden_anrichten:rHD_rAN
# a327B:f:Auftrag_zum_Kochen:rHD
# a327B:H:Auftrag_zum_Kochen:rHD
# a327B:F:Jemanden_in_Kannibalismus_verwickeln:rHD_fHD
# a327B:H:FLUCHT:rHD_fHD
# a327B:h:VERFOLGUNG:rHD_fHD
# a327B:H:VERFOLGUNG_entkommen:rHD_fHD
# a327:F:SELTENEN_Gegenstand_besorgen:N
# a327:H:Unruhe_VORTÄUSCHEN:N
# a327:H:Auf_VORTÄUSCHEN_reagieren:N
# a327:H:SELTENEN_Gegenstand_erfassen:N
# a327:H:FLUCHT:rHD_rAN
# a327:f:VERFOLGUNG:rHD_rAN
# a327:H:VERFOLGUNG_entkommen:rHD_rAN
# a327:F:UNGEHEUER_herbeiholen:rHD
# a327:H:IDENTITÄT_ändern:rHD
# a327:H:Geänderte_IDENTITÄT_VORTÄUSCHEN:rHD_rAN
# a327:F:Truhe_herstellen:rHD_rAN
# a327:H:Testnotwendigkeit_VORTÄUSCHEN:rHD_rAN
# a327:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN
# a327:H:UNGEHEUER_erfassen:rHD_rAN
# a327:H:UNGEHEUER_herbeiholen:rHD
# a327:H:TÖTUNG:rHD
# a327:H:VERLUSTursache_beheben:rVB
#
# zyx_cc_ddo_rus_5
# -----------------
# a655 Die scharfsinnigen Brüder
# a976 Die vornehmste Handlung
# -----------------
# a655:F:Erbschaft_teilen:zs_zsa
# a655:h:STERBEN:zs_zsa
# a655:h:VERLUST_des_Schatzes:zs
# a655:F:VERLUSTursache_beheben:zs
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:N
# a655:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:zs_zt
# a655:F:VORHERSAGE_erforderlich:zs_zt
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zt
# a655:h:Auf_VORHERSAGE_reagieren:zs_zt
# a655:F:VERLUSTursache_beheben:zs_zt
# a655:F:EINLADUNG_oder_Bestellung:zfa
# a655:H:Auf_EINLADUNG_oder_Bestellung_reagieren:zfa
# a655:H:Gespräche_belauschen:zfa
# a655:HF:VORHERSAGE_subtiler_Identität:zs
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs
# a655:HF:VORHERSAGE_subtiles_Geschmak:N
# a655:HF:Information_aus_zweiter_Hand:zf_zfa
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zf_zfa
# a655:HF:VORHERSAGE_subtiler_Identität:zf_zfa
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zf_zfa
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zf_zfa
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zf_zfa
# a655:HF:VORHERSAGE_subtiles_Geschmak:zf_zfa
# a655:F:STREIT_schlichten:zt_zf
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:H:STREIT_schlichten:zt_zf
# a655:H:VERLUSTursache_beheben:zt_zf
# a976:F:VORHERSAGE_erforderlich:zs_zf
# a976:F:STREIT_schlichten:zs_zf
# a976:F:Rätsel_lösen:zs_zf
# a976:F:ERZÄHLEN_beginnen:zs_zf
# a655:H:ERZÄHLEN_beenden:zs_zf
# a655:Hh:Rätsel_lösen:zs_zf
# a655:H:STREIT_schlichten:zs_zf
# a655:H:VERLUSTursache_beheben:zs_zf
#
# zyx_cc_ddo_rus_50
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_51
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_54
# -----------------
# a537 Der Flug auf dem dankbaren Adler
# a222 Krieg der flugfähigen Tiere gegen die Vierbeiner
# -----------------
# a222:#:#:#
# a222:#:#:#
# a222:#:#:#
# a537:H:Sorge_um_Pflegebedürftige:rHD_rHF
# a537:Hh:ANGST_mit_ANGST_vergelten:N
# a537:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rHF
# a537:hf:TABU_Behälter_nicht_öffnen:rHD_rHF
# a537:h:Auf_TABU_reagieren:N
# a537:F:Folgen_eines_TABUbruches_rückgängig_machen:rHD_rHF
# a537:H:Folgen_eines_TABUbruches_rückgängig_machen:rHD_rHF
# a537:H:Ende:rHD_rHH
#
# zyx_cc_ddo_rus_55
# -----------------
# a650A Starker Hans
# a300 Der Drachentöter
# -----------------
# a650A:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHH_fHH
# a650A:h:ENTFÜHRUNG:rHH_fHH
# a650A:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHH
# a650A:H:Zur_Welt_kommen:rHD_rHH
# a300:h:WASSERMANGEL:rAN
# a300:h:OPFERGABE_verlangen:rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
#
# zyx_cc_ddo_rus_56
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_57
# -----------------
# a560 Zauberring
# -----------------
# a560:F:Sorge_um_Schutzbedürftige:N
# a560:H:Sorge_um_Schutzbedürftige:N
# a560:H:Universellen_ZAUBERMITTEL_erhalten:N
# a560:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:N
# a560:F:Um_eine_Frau_WERBEN:N
# a560:F:Bauwerk_errichten:N
# a560:H:Bauwerk_errichten:N
# a560:H:PFLANZE_besorgen:N
# a560:H:SONSTIGES_beheben:N
# a560:H:SONSTIGES_beheben:N
# a560:H:Heiraten:N
#
# zyx_cc_ddo_rus_58
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_59
# -----------------
# a537 Der Flug auf dem dankbaren Adler
# a327A Haensel und Gretel
# -----------------
# a537:F:Sorge_um_Pflegebedürftige:rHD_rHF
# a537:H:Sorge_um_Pflegebedürftige:rHD_rHF
# a537:F:Hilfeversprechen_erhalten:rHD_rHF
# a537:H:Sorge_um_Pflegebedürftige:rHD_rHF
# a537:Hh:ANGST_mit_ANGST_vergelten:rHD_rHF
# a537:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHF
# a537:HF:Richtiges_erlangen:rHD_rHF
# a537:H:Vermittlung:rHF_rST
# a537:F:Richtiges_erlangen:rHD_rST
# a537:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST
# a537:hf:TABU_Behälter_nicht_öffnen:rHD_rST
# a537:h:Auf_TABU_reagieren:rHD
# a537:F:Folgen_eines_TABUbruches_rückgängig_machen:rHD_fHF
# a537:Hh:VEREINBARUNG:rHD_fHF
# a537:H:Folgen_eines_TABUbruches_rückgängig_machen:rHD_fHF
# a327A:f:VEREINBARUNG_einhalten:rHD_fHF
# a327A:F:Um_einen_Auftrag_WERBEN:rHD_rHD
# a327A:h:KONTAKT_abbrechen:rHD_rHD
# a327A:HF:Unwissenheit_VORTÄUSCHEN:rHD_rST
# a327A:f:SONSTIGES_beheben:rHD_fHF
# a327A:H:Unwissenheit_VORTÄUSCHEN:rHD_fHF
# a327A:H:Auf_VORTÄUSCHEN_reagieren:rHD_fHF
# a327A:H:TÖTUNG:rHD_fHF
# a537:H:KONTAKT_wiederherstellen:rHD_rHD
#
# zyx_cc_ddo_rus_60
# -----------------
# a303 Die zwei Brüder
# a327A Haensel und Gretel
# -----------------
# a303:h:Kinderlosigkeit:rHH
# a303:Hh:VEREINBARUNG:rHH_rZM_fST
# a303:H:Wundermittel_zur_EMPFÄNGNIS_erhalten:rHH_rZM_fST
# a303:H:Zur_Welt_kommen:rHD
# a303:f:VEREINBARUNG_einhalten:rHH_fST
# a303:F:Um_einen_Auftrag_WERBEN:rHD_rHH
# a303:h:KONTAKT_abbrechen:rHD_rHH
# a303:F:Um_einen_Auftrag_WERBEN:rHD_rHH
# a303:h:KONTAKT_abbrechen:rHD_rHH
# a303:F:MARKIERUNGEN_anbringen:rHD_rHD
# a303:h:KONTAKT_abbrechen:rHD_rHD
# a327A:HF:Unwissenheit_VORTÄUSCHEN:rHD_rST
# a327A:Hh:Unterkommen:N
# a327A:H:Unwissenheit_VORTÄUSCHEN:N
# a327A:H:Auf_VORTÄUSCHEN_reagieren:N
# a327A:H:TÖTUNG:N
# a303:H:SCHÖNE_erfassen:rHD_rPP
# a303:H:Krisenursachen_ergründen:rHD_rPP
# a303:h:KONTAKT_abbrechen:rHD_rPP
# a303:F:MARKIERUNGEN_anbringen:rHD_rPP
# a303:f:WETTKAMPF:rHD_rAN
# a303:h:WETTKAMPF:rHD_rAN
# a303:h:VERSCHLINGEN:rHD_rAN
# a303:H:MARKIERUNGEN_erkennen:rHD_rHD
# a303:H:Wegweisung_erhalten:rHD_rPP
# a303:f:WETTKAMPF:rHD_rAN
# a303:H:WETTKAMPF:rHD_rAN
# a303:H:VERSCHLINGEN_beheben:rHD_rHD_rAN
# a303:H:Ende:N
#
# zyx_cc_ddo_rus_61
# -----------------
# a545B Der gestiefelte Kater
# -----------------
# a545B:H:Hilfeversprechen_erhalten:rHD_rHF
# a545B:H:Verlust_VORTÄUSCHEN:rHD_rHF
# a545B:F:Um_eine_Frau_WERBEN:rHD_rHF
# a545B:F:Auftrag_zum_VORTÄUSCHEN:rHF_fST
# a545B:H:TÖTUNG:rHF_fST
# a545B:H:Fremdes_Gut_beschlagnahmen:rHF_fST
# a545B:H:Heiraten:rHF_fST
# a545B:H:VEREINBARUNG:rHD_rHF
# a545B:f:Vertrauen_beweisen:rHD_rHF
# a545B:h:Tod_VORTÄUSCHEN:rHD_rHF
# a545B:h:Auf_VORTÄUSCHEN_reagieren:rHD_rHF
# a545B:h:Vertrauen_beweisen:rHD_rHF
# a545B:H:VORTÄUSCHEN_eingestehen:rHF_rPP
# a545B:h:Enttäuschung_ausgelöst:rHF_rPP
# a545B:H:Wiedergutmachung_erzielen:rHD_rHF
# a545B:f:Vertrauen_beweisen:rHD_rHF
# a545B:h:Tod_VORTÄUSCHEN:rHD_rHF
# a545B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHF
# a545B:H:VEREINBARUNG_einhalten:rHD_rHF
# a545B:H:Vertrauen_beweisen:rHD_rHF
#
# zyx_cc_ddo_rus_62
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_63
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_65
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_66
# -----------------
# a613 Die beiden Wanderer
# -----------------
# a613:h:Nahrungsvorrat_aufgebraucht:rHD_fHD
# a613:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_fHD
# a613:H:Gespräche_belauschen:rHD_rST
# a613:HF:Schatz_finden:rST
# a613:HF:KRANKHEIT_beheben:rST
# a613:HF:WASSERMANGEL_beheben:rST
# a613:H:Schatz_finden:rHD
# a613:F:Um_einen_Auftrag_WERBEN:rHD_rHP
# a613:H:KRANKHEIT_beheben:rHD_rPP
# a613:H:WASSERMANGEL_beheben:rHD_rVB
# a613:H:Vorgang_deuten:rHD_fHD
# a613:h:GIER_und_Neid_auslösen:rHD_fHD
# a613:h:Auf_Anreiz_zu_GIER_und_Neid_reagieren:fHD
# a613:h:Gespräche_belauschen:rST_fHD
#
# zyx_cc_ddo_rus_68
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_69
# -----------------
# a560 Zauberring
# -----------------
# a560:h:Nahrungsvorrat_aufgebraucht:N
# a560:F:Sorge_um_Freikaufsbedürftige:N
# a560:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:N
# a560:HF:Richtiges_erlangen:N
# a560:H:Universellen_ZAUBERMITTEL_erhalten:N
# a560:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:N
# a560:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:N
# a560:F:Um_eine_Frau_WERBEN:N
# a560:F:Bauwerk_errichten:N
# a560:H:VEREINBARUNG_auflösen:N
#
# zyx_cc_ddo_rus_70
# -----------------
# a1539 List und Leichtgläubigkeit
# -----------------
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
# a1539:#:#:#
#
# zyx_cc_ddo_rus_71
# -----------------
# a325 Zauberer und Schueler
# -----------------
# a325:f:VEREINBARUNG:rHD_rHH_rBZ
# a325:HF:Unwissenheit_VORTÄUSCHEN:rHD_rZO
# a325:H:Unwissenheit_VORTÄUSCHEN:rHD_rBZ
# a325:H:Zauberkunst_erlernen:rHD_rBZ
# a325:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH
# a325:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH
# a325:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH
# a325:hf:TABU_Gegenstand_nicht_weitergeben:rHD_rHH
# a325:H:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rHH_rBZ
# a325:h:Auf_TABU_reagieren:rHD_rHH_rBZ
# a325:H:FLUCHT_vorbereiten:rBZ_fZO
# a325:Hh:FLUCHT:rHD_rBZ_rZO
# a325:H:Änderung_der_EXISTENZFORM:rHD_rBZ_rZO
# a325:f:VERFOLGUNG:rHD_rBZ_rZO
# a325:H:VERFOLGUNG_entkommen:rHD_rBZ_rZO
# a325:H:KONTAKT_wiederherstellen:rHD_rHH_fZO
# a325:H:Heiraten:rHD_rHH_fZO
#
# zyx_cc_ddo_rus_72
# -----------------
# a550 Vogel Pferd und Königstochter
# a300 Der Drachentöter
# a530 Prinzessin auf dem Glasberg
# -----------------
# a530:F:Wache_halten:rHH
# a530:h:STERBEN:rHH
# a530:h:Wache_halten:fHD
# a530:H:Herbeirufendes_ZAUBERMITTEL_erhalten:rHD_rHF
# a530:F:Reitkünste_zeigen:rHP
# a530:h:Reitkünste_zeigen:fHD
# a530:h:RESPEKTLOSIGKEIT:rHD_fHD
# a530:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a530:H:REITTIER_erhalten:rHD_rHF
# a530:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Reitkünste_zeigen:rHD_rHF
# a530:H:SCHÖNE_erfassen:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:NEUGIER_auslösen:rHD_fHD
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Reitkünste_zeigen:rHD_rHF
# a530:H:SCHÖNE_erfassen:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:NEUGIER_auslösen:rHD_fHD
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Reitkünste_zeigen:rHD_rHF
# a530:H:SCHÖNE_erfassen:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Vorgang_deuten:rHD_fHD
# a530:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_fHD
# a530:Hh:Beuteteilen:rHD_fHD
# a550:f:ENTMACHTUNG:rHD_fHD
# a550:h:ENTMACHTUNG:rHD_fHD
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:H:Unterkommen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:h:Zweikampf:rHD_rAN
# a300:h:VERSCHLINGEN:rHD_rAN
# a300:H:VERSCHLINGEN_beheben:rHD_rAN
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
# a300:H:NEUGIER_auslösen:rVB
# a300:HF:Information_aus_zweiter_Hand:rVB
# a300:F:EINLADUNG_oder_Bestellung:rHD_rVB
# a300:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rVB
# a300:H:Um_Gegenleistung_bitten:rHD_rVB
# a300:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rHF
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a530:H:Ende:rHD_rVB
#
# zyx_cc_ddo_rus_73
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_74
# -----------------
# aTMJ1545_4 The exiled wife's dearest possession
# a875 Die kluge Bauertochter
# -----------------
# a875:f:Rätsel_lösen:zf_zsa
# a875:F:Auf_Hilfsquelle_zurückgreifen:zs_zsa
# a875:HF:Rätsel_lösen:zs_zsa
# a875:H:Rätsel_lösen:N
# a875:H:Wechsel_der_IDENTITÄT_eingestehen:N
# a875:f:Auftrag_als_ABSURDITÄT:zf_zsa
# a875:HF:ABSURDITÄT_entgegentreten:zf_zsa
# a875:F:Auf_Hilfsquelle_zurückgreifen:N
# a875:f:Auftrag_als_ABSURDITÄT:zf_zsa
# a875:F:Auf_Hilfsquelle_zurückgreifen:zs_zsa
# a875:H:ABSURDITÄT_entgegentreten:N
# a875:F:Um_eine_Frau_WERBEN:zf_zsa
# a875:f:Hochzeit_am_Tag_der_Scheidung_feiern:zf_zsa
# a875:H:Heiraten:zs_zf
# a875:f:Verbot_als_ABSURDITÄT:zs_zf
# a875:F:STREIT_schlichten:zs_zt
# a875:H:STREIT_Schlichten_angehen:zs_zt
# a875:H:STREIT_schlichten:zs_zt
# aTMJ1545_4:h:Hochzeit_am_Tag_der_Scheidung_feiern:zs_zf
# aTMJ1545_4:f:Forderung_oder_Bitte_als_ABSURDITÄT:zs_zf
# aTMJ1545_4:H:ABSURDITÄT_entgegentreten:zs_zf
#
# zyx_cc_ddo_rus_75
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_76
# -----------------
# a312D Erbsensohn
# a563 Tischleindeckdich
# a516 Der treue Johannes
# -----------------
# a312D:h:VERLOCKUNG:rRE_rAN
# a312D:h:Auf_VERLOCKUNG_reagieren:rRE_rAN
# a312D:h:FREIHEITSBERAUBUNG:rRE_rAN
# a312D:H:Zur_Welt_kommen:rHD
# a312D:F:PROVOKATION:rHD_rVB
# a312D:H:Auf_PROVOKATION_reagieren:rHD_rVB
# a312D:H:NEUGIER_auslösen:rHD_rVB
# a312D:H:Auf_ausgelöste_NEUGIER_reagieren:rHD_rHH
# a312D:H:Krisenursachen_ergründen:rHD_rHH
# a312D:F:FREIHEITSBERAUBUNG_beheben:rHD_rHH
# a563:h:SCHLAF:rHD_rST
# a563:H:SCHLAF_unterbrechen:rHD_rST
# a563:H:Proviantproduzierenden_ZAUBERMITTEL_erhalten:rHD_rST
# a312D:H:Hinuntersteigen:rHD_rST
# a312D:F:Ungewollte_Verlobung_akzeptieren:rHD_rST
# a312D:H:Ungewollte_Verlobung_akzeptieren:rHD_rST
# a312D:HF:Richtiges_erlangen:rHD_rHF
# a312D:hf:TABU_Türe_nicht_öffnen_dürfen:rHD_rST
# a516:HF:Richtiges_erlangen:rHD_rHF
# a516:F:Richtiges_erlangen:rHD_rST
# a516:h:Auf_TABU_reagieren:rHD_rST
# a516:h:FERNLIEBE_wird_ausgelöst:rHD_rPP
# a516:F:Richtiges_erlangen:rHD_rST
# a516:H:Treue_Helfer_erhalten:rHD_rHF
# a516:H:Änderung_der_EXISTENZFORM:rHD_rHF
# a516:H:REITTIER_erhalten:rHD_rHF
# a516:HF:SELTENEN_Gegenstand_erfassen:rHD_rHF
# a516:H:SELTENEN_Gegenstand_erfassen:rHD_rHF
# a516:F:Um_eine_Frau_WERBEN:rHD_rHP
# a516:F:VEREINBARUNG:rHD_rHP
# a516:F:Gegen_ein_Tier_kämpfen:rHD_rHP
# a516:HF:Gegen_ein_Tier_kämpfen:rHD_rHF
# a516:H:Gegen_ein_Tier_kämpfen:rHF_fHF
# a516:F:Tiere_gegeneinander_kämpfen_lassen:rHD_rHP
# a516:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a516:HF:Tiere_gegeneinander_kämpfen_lassen:rHD_rHF
# a516:H:Tiere_gegeneinander_kämpfen_lassen:rHF_fHF
# a516:F:WETTLAUF:rHD_rHP
# a516:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a516:HF:WETTKAMPF:rHD_rHF
# a516:H:WETTKAMPF:rHD_fHF
# a516:H:VEREINBARUNG_einhalten:rHD_rHP
# a516:H:Heiraten:rHD_rHP
#
# zyx_cc_ddo_rus_77
# -----------------
# a950 Rhampsinit
# -----------------
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
# a950:#:#:#
#
# zyx_cc_ddo_rus_78
# -----------------
# a707 Die drei goldenen Söhne
# -----------------
# a707:f:Ungewünschtes_Wesen_beseitigen:fHH_fHH
# a707:h:Aussetzung:rRE_fHH_fRE
# a707:H:Überrascht_werden_oder_geraten:rHH_rRE_fRE
# a707:F:Zauberkunstfertigkeit_gewährleisten:rHH_rRE_fRE
# a707:F:Zauberkunstfertigkeit_gewährleisten:rHH_rRE_fRE
# a707:F:Goldhaariges_Kind_zur_Welt_bringen:rHH_rRE_fRE
# a707:h:Zauberkunstfertigkeit_gewährleisten:rHH_fRE
# a707:h:Zauberkunstfertigkeit_gewährleisten:rHH_fRE
# a707:H:Heiraten:rHH_rRE
# a707:h:KONTAKT_abbrechen:rHH_rRE
# a707:f:Bösen_einstellen:rAN_fRE
# a707:f:Surrogat_unterschieben:rAN_fRE
# a707:f:Um_einen_Auftrag_WERBEN:rHH_rAN
# a707:h:Auf_WERBEN_reagieren:rHH_rAN
# a707:H:Goldhaariges_Kind_zur_Welt_bringen:rHD_rAN
# a707:h:Surrogat_unterschieben:rHD_rAN
# a707:h:ANEIGNUNG:rHD_rAN
# a707:h:VERLEUMDUNG_bei_Missgeburt:rHH_rRE
# a707:h:DEMÜTIGUNG:rHH_rRE
# a707:Hh:Heimlich_beobachten:rHH_rVB
# a707:Hh:Vorgang_deuten:rHH_rVB
# a707:h:Gespräche_belauschen:fRE_fVB
# a707:h:Information_aus_zweiter_Hand:fRE_fVB
# a707:f:Bösen_einstellen:rAN_fRE
# a707:h:Aussetzung:rHD_rAN
# a707:H:Überrascht_werden_oder_geraten:rHD_rST
# a707:H:Adoption:rHD_rST
# a707:F:PROVOKATION:rHD_rVB
# a707:H:Auf_PROVOKATION_reagieren:rHD_rVB
# a707:H:NEUGIER_auslösen:rHD_rVB
# a707:H:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST
# a707:F:Begegnung:rHD_rHH_rRE
# a707:H:Sich_niederlassen:rHD
# a707:F:Sorge_um_Schutzbedürftige:rHD_rHF
# a707:H:Sorge_um_Schutzbedürftige:rHD_rHF
# a707:H:Herbeirufendes_ZAUBERMITTEL_erhalten:rHD_rHF
# a707:H:REITTIER_erhalten:rHD_rHF
# a707:h:KRANKHEIT:rHH
# a707:F:HEILMITTEL_besorgen:rHH
# a707:F:Um_einen_Auftrag_WERBEN:fVB
# a707:h:HEILMITTEL_erfassen:fVB
# a707:H:HEILMITTEL_erfassen:rHD_fVB
# a707:Hh:HEILMITTEL_besorgen:rHH_fVB
# a707:H:NEUGIER_auslösen:rHH_fVB
# a707:h:Gespräche_belauschen:fRE_fVB
# a707:h:Information_aus_zweiter_Hand:fRE_fVB
# a707:f:Bösen_einstellen:rAN_fRE
# a707:f:Zu_Beauftragungen_anregen:rHD_rAN
# a707:hf:WASSERQUELLE_herbeiholen:rHD_rAN
# a707:F:WASSERQUELLE_herbeiholen:rHD_rHD
# a707:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF_rZO
# a707:Hh:Zuschnappendes_Hindernis_überwinden:rHD_rHF_rZO
# a707:h:BEHINDERUNG_durch_Verstümmelung:rHD_rHF_rZO
# a707:Hh:BEHINDERUNG_beheben:rHD_rHF_rZO
# a707:H:WASSERQUELLE_erfassen:rHD_rHF_rZO
# a707:H:Sorge_um_Mitleidsbedürftige:rHD_rHF
# a707:H:BEHINDERUNG_beheben:rHD_rHF
# a707:H:WASSERQUELLE_herbeiholen:rHD_rHD_rZO
# a707:h:KRANKHEIT:rHH_rVB
# a707:F:HEILMITTEL_besorgen:rHH_rVB
# a707:h:HEILMITTEL_besorgen:fVB
# a707:Hh:HEILMITTEL_erfassen:rHD_rVB
# a707:Hh:HEILMITTEL_erfassen:rHD_rVB
# a707:Hh:HEILMITTEL_besorgen:rHH_rVB
# a707:H:NEUGIER_auslösen:rHH_rVB
# a707:h:Gespräche_belauschen:fRE_fVB
# a707:h:Information_aus_zweiter_Hand:fRE_fVB
# a707:f:Bösen_einstellen:rAN_fRE
# a707:f:Zu_Beauftragungen_anregen:rHD_rAN
# a707:hf:WILD_besorgen:rHD_rAN
# a707:F:WILD_besorgen:rHD_rHD
# a707:HF:WILD_erfassen:rHD_rHF_rZO
# a707:H:WILD_erfassen:rHD_rZO
# a707:H:WILD_besorgen:rHD_rZO
# a707:f:Zu_Beauftragungen_anregen:rHD_rAN
# a707:hf:SCHÖNE_herbeiholen:rHD_rAN
# a707:F:SCHÖNE_herbeiholen:rHD_rHD
# a707:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a707:HF:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rHF
# a707:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rST
# a707:HF:SCHÖNE_erfassen:rHD_rST
# a707:H:SCHÖNE_erfassen:rHD_rZO
# a707:F:Liebe_wird_ausgelöst:rHD_rZO
# a707:H:Heiraten:rHD_rZO
# a707:Hh:Wiedergutmachung_erzielen:rHD_rZO_fHD
# a707:Hh:VERSTEINERUNG_beheben:rHD_rZO_fHD
# a707:h:VERFOLGUNG:rHD_rZO_fHD
# a707:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_fHD
# a707:H:Verstecken_als_Rettung:rHD_rST_fHD
# a707:H:Vermittlung:rHD_rST_fHD
# a707:H:Freundschaft_schließen:rHD_rST_fHD
# a707:H:Auf_dem_Heimweg:rHD_rRE
# a707:F:KRANKHEIT_beheben:rHH
# a707:F:EINLADUNG_oder_Bestellung:rHH
# a707:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHH
# a707:H:DEMÜTIGUNG_beheben:rHH_rHH_rZO
# a707:f:VERGIFTUNG:rHH_rZO
# a707:H:VERGIFTUNG_beheben:rHH_rZO
# a707:H:Sachverhalt_aus_der_Vergangenheit_aufklären:rHH_rZO
# a707:H:Bestrafung:rHH_rAN_fRE
# a707:H:Familienzusammenführung:rHH_rRE
# a707:H:Ende:rHH_rRE
#
# zyx_cc_ddo_rus_79
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_80
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_81
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_82
# -----------------
# a854 Der goldene Bock
# -----------------
# a854:F:WETTE_um_die_VERFÜHRUNG_der_Frau:N
# a854:F:#:N
# a854:H:Hohlen_Gegenstand_zum_Verstecken_erhalten:N
# a854:H:Sich_oder_andere_tragen_LASSEN:N
# a854:H:WETTE_um_die_VERFÜHRUNG_der_Frau:N
# a854:F:MARKIERUNGEN_anbringen:N
# a854:H:Sich_oder_andere_tragen_LASSEN:N
# a854:h:MARKIERUNGEN_erkennen:N
# a854:H:MARKIERUNGEN_erkennen:N
# a854:H:VEREINBARUNG_auflösen:N
#
# zyx_cc_ddo_rus_83
# -----------------
# a1313A Die Todesankündigung ernst nehmen
# -----------------
# a1313A:#:#:#
# a1313A:#:#:#
#
# zyx_cc_ddo_rus_84
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_85
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_86
# -----------------
#
# -----------------
#
# zyx_cc_ddo_rus_87
# -----------------
# a329 Versteckwette
# a531 Sohn des Jägers/Ferdinand der treue...
# -----------------
# a531:hf:TABU_Tier_nicht_töten:rHD_rHH
# a531:h:Auf_TABU_reagieren:rHD_rZM
# a531:Ff:VOGEL_erfassen:rHD_rZM
# ...
# a563:H:Gold_oder_geldproduzierenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_fVB
# a563:H:HUNGERSNOT_beheben:rHD_rZM_fVB
# a563:h:ANEIGNUNG:rHD_rZM_rAN
# a563:h:HUNGERSNOT:rHD_fVB
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM
# a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rZM
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a563:H:ANEIGNUNG_beheben:rHD_rZM_rAN
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN
# a563:H:ANEIGNUNG_beheben:rHD_rZM_rAN
# a563:H:HUNGERSNOT_beheben:rHD_rZM_fVB
# a563:H:Ende:rHD_rZM_fVB
#
# zyx_cr_ttt_rus_3
# -----------------
# a519 Heldenjungfrau
# -----------------
# a519:H:Personen_mit_der_BEHINDERUNG_gehen_einen_Bund_ein:rHD_rHF
# a519:H:Sich_niederlassen:rHD_rHF
# a519:H:Freundschaft_schließen:rHD_rHF_rPP
# a519:h:Auf_TABU_reagieren:rPP
# a519:F:Folgen_eines_TABUbruches_rückgängig_machen:rPP
# a519:f:MARKIERUNGEN_anbringen:rPP_rAN
# a519:h:MARKIERUNGEN_erkennen:rPP_rAN
# a519:h:Sich_auf_Eindringlinge_einlassen:rPP_rAN
# a519:h:VAMPIRISMUS:rPP_rAN
# a519:h:Vorgang_deuten:rHD_rHF_rPP
# a519:H:Krisenursachen_ergründen:rHD_rHF_rPP
# a519:F:Im_Verborgenen_lauern:rHD_rHF_rPP
# a519:h:Zweikampf:rHF_rAN
# a519:h:VAMPIRISMUS:rHF_rAN
# a519:h:Vorgang_deuten:rHF_rPP
# a519:F:Im_Verborgenen_lauern:rHF_rPP
# a519:h:Zweikampf:rHF_rAN
# a519:h:VAMPIRISMUS:rHF_rAN
# a519:h:Vorgang_deuten:rHD_rPP
# a519:F:Im_Verborgenen_lauern:rHD_rPP
# a519:H:Zweikampf:rHD_rAN
# a519:H:VERSCHLINGEN:rHD_rHF_rAN
# a519:H:VERSCHLINGEN_beheben:rHD_rHF_rAN
# a519:H:BEHINDERUNG_beheben:rHD_rHF_rAN
# a519:H:VERSCHLINGEN:rHD_rHF_rAN
# a519:H:VERSCHLINGEN_beheben:rHD_rHF_rAN
# a519:H:BEHINDERUNG_beheben:rHD_rHF_rAN
# a519:h:VERSCHLINGEN:rHD_rHF_rAN
# a519:H:VERSCHLINGEN_beheben:rHD_rHF_rAN
# a519:H:BEHINDERUNG_beheben:rHD_rHF_rAN
# a519:H:TÖTUNG:rHD_rHF_rAN
# a519:H:Ende:rHD_rHF_rAN
#
# zyx_cr_ttt_rus_30
# -----------------
# a750D God and the Three Brothers
# -----------------
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
# a750D:#:#:#
#
# zyx_cr_ttt_rus_31
# -----------------
# a725 Prophezeiung künftiger Hoheit
# aU ATU Typ: unklar welcher
# -----------------
# a725:h:HUNGERSNOT:rHD_rHH
# a725:F:HUNGERSNOT_beheben:rHD_rHH
# a725:F:VEREINBARUNG:rHD_fVB
# a725:H:Erträumen:rHD
# a725:F:TRAUM_vom_sozialen_Aufstieg:rHD
# a725:h:VEREINBARUNG_einhalten:rHD_fVB
# a725:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fVB
# a725:h:Zu_Beauftragungen_anregen:rHD_rHP_fVB
# a725:h:FREIHEITSBERAUBUNG:rHD_rHP_fVB
# a725:H:FREIHEITSBERAUBUNG_beheben:rHD
# a725:H:Sachschaden_anrichten:rHD_rPP
# a725:F:MARKIERUNGEN_anbringen:rHD_rPP
# a725:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:rPP
# a725:H:MARKIERUNGEN_erkennen:rPP
# a725:f:Wache_halten:rHP_fHF
# a725:h:Wache_halten:fHF
# a725:H:SCHLAF:fHF
# a725:H:Sachschaden_anrichten:rHD_rPP
# a725:H:Überrascht_werden_oder_geraten:rHD_rPP
# a725:F:Liebe_wird_ausgelöst:rHD_rPP
# a725:f:Rätsel_lösen:rHD_rPP
# a725:HF:Information_aus_zweiter_Hand:rHD_rPP
# a725:HF:Rätsel_lösen:rHD_rPP
# a725:F:EINLADUNG_oder_Bestellung:N
# a725:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rHP
# a725:F:VEREINBARUNG:rHD_rHP
# a725:F:Rätsel_lösen:rHD_rHP
# a725:F:Verlobung_arrangieren:rHD_rHP
# a725:H:VEREINBARUNG_einhalten:rHD_rHP
# a725:H:Rätsel_lösen:rHD_rHP
# a725:H:Verlobung_arrangieren:rHD_rHP
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# a725:H:Heiraten:rHD_rPP
# a725:H:TRAUM_wird_wahr:rHD_rHP_rPP
#
# zyx_cr_ttt_rus_32
# -----------------
# a706 Mädchen ohne Hände
# -----------------
# a706:h:Kinderlosigkeit:rHH
# a706:F:Wundermittel_zur_EMPFÄNGNIS_suchen:rHH
# a706:Hh:VEREINBARUNG:rHH_rZM_fST
# a706:H:Wundermittel_zur_EMPFÄNGNIS_erhalten:rHH_rZM_fST
# a706:H:Wunderbare_EMPFÄNGNIS:rHH_rZM
# a706:H:Zur_Welt_kommen:rHH
# a706:h:STERBEN:rHH
# a706:H:Zur_Welt_kommen:rHD
# a706:h:STERBEN:rHH
# a706:h:Sich_auf_Eindringlinge_einlassen:rHD_fHH
# a706:h:Verlobung_arrangieren:rHD_rHH_fHH
# a706:h:Heiraten:rHD_rHH_fHH
# a706:h:VERLEUMDUNG_bei_Schädigung:rHD_rHH_fHH
# a706:H:VERLEUMDUNG_beheben:rHD_rHH_fHH
# a706:h:VERLEUMDUNG_bei_Schädigung:rHD_rHH_fHH
# a706:H:VERLEUMDUNG_beheben:rHD_rHH_fHH
# a706:h:VERLEUMDUNG_bei_Schädigung:rHD_rHH_fHH
# a706:H:VERLEUMDUNG_beheben:rHD_rHH_fHH
# a706:h:Auf_Aufforderung_zu_KINDERMORD_reagieren:rHD_rHH_fHH
# a706:h:VERLEUMDUNG_bei_Kindstötung:rHD_rHH_fHH
# a706:h:BEHINDERUNG_durch_Verstümmelung:rHD_rHH
# a706:h:VERTREIBUNG:rHD_rHH
# a706:H:Überrascht_werden_oder_geraten:rHD_rPP
# a706:F:Liebe_wird_ausgelöst:rHD_rPP
# a706:F:Heiraten:rHD_rPP
# a706:Hh:KONTAKT_abbrechen:rHD_rPP
# a706:H:BOTSCHAFTEN_versenden:rVB_rHP
# a706:h:SCHLAF:rVB_fHH
# a706:h:BOTSCHAFTEN_verfälschen:rVB_fHH
# a706:H:BOTSCHAFTEN_versenden:rVB_rPP
# a706:h:SCHLAF:rVB_fHH
# a706:h:BOTSCHAFTEN_verfälschen:rVB_fHH
# a706:h:Auf_BOTSCHAFTEN_reagieren:rHD_rHP
# a706:h:VERTREIBUNG:rHD_rHP
# a706:F:Sorge_um_Hilfsbedürftige:N
# a706:H:Sorge_um_Hilfsbedürftige:N
# a706:H:BEHINDERUNG_beheben:N
# a706:H:Sich_niederlassen:rHD
# a706:H:Intensive_Erkundungsaktion:rHD_rST
# a706:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST
# a706:H:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST
# a706:H:Zusammenbringen_aller_Handlungsträger:rHD_rHH_rPP
# a706:H:Vorgang_deuten:rHD_rHH_rPP
# a706:H:VERLEUMDUNG_beheben:rHD_rHH_rPP
# a706:H:Bestrafung:rHH_fHH
# a706:H:Familienzusammenführung:rHD_rPP
#
# zyx_cr_ttt_rus_33
# -----------------
# aU ATU Typ: unklar welcher
# -----------------
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
#
# zyx_cr_ttt_rus_34
# -----------------
# aU ATU Typ: unklar welcher
# -----------------
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
#
# zyx_cr_ttt_rus_35
# -----------------
# a1626 Traumbrot
# -----------------
# a1626:#:#:#
# a1626:#:#:#
# a1626:#:#:#
# a1626:#:#:#
# a1626:#:#:#
# a1626:#:#:#
# a1626:#:#:#
# a1626:#:#:#
#
# zyx_cr_ttt_rus_36
# -----------------
# a890 Fleischpfand
# -----------------
# a890:#:#:#
# a890:#:#:#
# a890:#:#:#
# a890:#:#:#
# a890:#:#:#
# a890:#:#:#
# a890:#:#:#
# a890:#:#:#
# a890:#:#:#
#
# zyx_cr_ttt_rus_37
# -----------------
# aU ATU Typ: unklar welcher
# -----------------
# aU:#:#:#
# aU:#:#:#
#
# zyx_cr_ttt_rus_38
# -----------------
# a1654 Räuber in der Totenkammer
# -----------------
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:F:Tod_VORTÄUSCHEN:zs_zt_zsa
# a1654:H:Auf_VORTÄUSCHEN_reagieren:zs_zt
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:H:Numinose_Einmischung:zs_zt
# a1654:H:Auf_VORTÄUSCHEN_reagieren:zs_zt
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
# a1654:#:#:#
#
# zyx_cr_ttt_rus_39
# -----------------
# aEB144 Geschichtenerzähler
# -----------------
# aEB144:h:HUNGERSNOT:zs_zsa
# aEB144:h:SCHLAF:zs_zsa
# aEB144:F:Erträumen:zs_zsa
# aEB144:h:SCHLAF_unterbrechen:zs_zsa
# aEB144:h:Vorgang_deuten:zs_zsa
#
# zyx_cr_ttt_rus_4
# -----------------
# aU ATU Typ: unklar welcher
# -----------------
# aU:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rPP_rAN
# aU:f:Ungewünschtes_Wesen_beseitigen:rHD_rAN
# aU:h:SONSTIGES_beheben:rHD_rAN
# aU:#:#:#
# aU:H:Ende:rHD
#
# zyx_cr_ttt_rus_40
# -----------------
# aU ATU Typ: unklar welcher
# -----------------
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
# aU:#:#:#
#
# zyx_cr_ttt_rus_41
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_42
# -----------------
# a837 Brot des Bettlers
# -----------------
# a837:#:#:#
# a837:#:#:#
# a837:#:#:#
# a837:#:#:#
# a837:#:#:#
# a837:#:#:#
# a837:#:#:#
# a837:#:#:#
#
# zyx_cr_ttt_rus_43
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_44
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_45
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_46
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_47
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_48
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_49
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_5
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_50
# -----------------
# a922 Kaiser und Abt
# -----------------
# a922:f:VEREINBARUNG:zs_zf
# a922:f:Rätsel_lösen:zs_zf
# a922:H:Rätsel_lösen:zs_zf
# a922:H:VEREINBARUNG_einhalten:zs_zf
# a922:h:FREIHEITSBERAUBUNG:zs_zf_zfa
# a922:f:VEREINBARUNG:zt_zf
# a922:f:Rätsel_lösen:zt_zf
# a922:h:Rätsel_lösen:zt_zf
# a922:h:FREIHEITSBERAUBUNG:zt_zf
# a922:f:VEREINBARUNG:zt_zf
# a922:f:Rätsel_lösen:zt_zf
# a922:h:Rätsel_lösen:zt_zf
# a922:h:FREIHEITSBERAUBUNG:zt_zf
# a922:f:VEREINBARUNG:zt_zf
# a922:f:Rätsel_lösen:zt_zf
# a922:h:Rätsel_lösen:zt_zf
# a922:h:FREIHEITSBERAUBUNG:zt_zf
# a922:F:Auf_Hilfsquelle_zurückgreifen:zs_zt
# a922:F:BESTECHUNG:zs_zt
# a922:F:Auf_BESTECHUNG_reagieren:zs_zt_zta
# a922:HF:Rätsel_lösen:zs_zt_zta
# a922:H:Rätsel_lösen:zt_zf
# a922:H:Ende:zs_zf
#
# zyx_cr_ttt_rus_51
# -----------------
# a910 Kluge Raatschläge
# -----------------
# a910:H:Begegnung:rHD_rST
# a910:H:WEISHEITEN_erhalten:rHD_rST
# a910:#:#:#
# a910:#:#:#
# a910:#:#:#
# a910:#:#:#
# a910:#:#:N
# a910:#:#:#
# a910:#:#:#
# a910:#:#:#
# a910:#:#:#
# a910:#:#:#
# a910:#:#:#
# a910:#:#:#
#
# zyx_cr_ttt_rus_52
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_53
# -----------------
# a930 Uriasbrief
# -----------------
# a930:H:Unterkommen:rHH_rVB_fHP
# a930:H:Zur_Welt_kommen:rHD_rVB_fHP
# a930:f:VORHERSAGE_ungewünschter_Eheschliessung:rHD_rVB_fHP
# a930:h:Auf_VORHERSAGE_reagieren:rHD_rHH_fHP
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP
# a930:h:Adoption:rHD_rHH_fHP
# a930:h:Aussetzung:rHD_rVB_fHP
# a930:H:Überrascht_werden_oder_geraten:rHD_rST
# a930:H:Adoption:rHD_rST
# a930:H:Begegnung:rHD_rVB_fHP
# a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST_fHP
# a930:h:Auf_VORHERSAGE_reagieren:rHD_rST_fHP
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rST_fHP
# a930:h:Adoption:rHD_rST_fHP
# a930:h:Aussetzung:rHD_rVB_fHP
# a930:H:Überrascht_werden_oder_geraten:rHD_rST
# a930:H:Adoption:rHD_rST
# a930:F:Um_einen_Auftrag_WERBEN:rHD_rST
# a930:h:KONTAKT_abbrechen:rHD_rST
# a930:H:Begegnung:rHD_rVB_fHP
# a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rVB_fHP
# a930:h:Auf_VORHERSAGE_reagieren:rHD_rVB_fHP
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rVB_fHP
# a930:h:BOTSCHAFTEN_versenden:rHD_fHP
# a930:F:EINLADUNG_oder_Bestellung:rHD_fHP
# a930:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_fHP
# a930:h:BOTSCHAFTEN_versenden:rHD_fHP
# a930:H:SCHLAF:rHD
# a930:F:Liebe_wird_ausgelöst:rHD_rPP
# a930:H:BOTSCHAFTEN_verfälschen:rHD_rPP
# a930:H:Auf_BOTSCHAFTEN_reagieren:rHD_rHP_rPP
# a930:H:Heiraten:rHD_rHP_rPP
# a930:HF:VERFOLGUNG_entkommen:rHD_rPP
# a930:h:VERFOLGUNG:rVB_fHP
# a930:H:VERFOLGUNG_entkommen:rHD_fHP
# a930:H:VORHERSAGE_tritt_ein:rHD_fHP
#
# zyx_cr_ttt_rus_54
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_55
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_56
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_57
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_58
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_59
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_6
# -----------------
# a655 Die scharfsinnigen Brüder
# a976 Die vornehmste Handlung
# -----------------
# a655:Ff:Priorisierung_VORTÄUSCHEN:zs_zsa
# a655:Ff:Priorisierung_VORTÄUSCHEN:zs_zsa
# a655:Hh:Auf_VORTÄUSCHEN_reagieren:zs
# a655:h:STERBEN:zs_zsa
# a655:h:ANEIGNUNG:zs_zsa
# a655:h:VERLUST_des_Schatzes:zs
# a655:F:VERLUSTursache_beheben:zs
# a655:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:zs_zt
# a655:F:VORHERSAGE_erforderlich:zs_zt
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:h:Auf_VORHERSAGE_reagieren:zt_zf
# a655:F:STREIT_schlichten:zt_zf
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zs_zf
# a655:H:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zs_zf
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf
# a655:H:VERLUSTursache_beheben:zt_zf
# a655:H:STREIT_schlichten:zt_zf
# a655:F:EINLADUNG_oder_Bestellung:zs_zf
# a655:H:Auf_EINLADUNG_oder_Bestellung_reagieren:zs_zf
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zf
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zf
# a655:HF:VORHERSAGE_subtiler_Identität:zs_zf
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zf_zfa
# a655:HF:VORHERSAGE_subtiles_Geschmak:zf_zfa
# a655:H:Auf_VORHERSAGE_reagieren:zs_zsa
# a655:H:VORHERSAGE_tritt_ein:zs_zsa
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zsa
# a655:HF:Auf_VORHERSAGE_reagieren:zs_zf
# a655:H:VORHERSAGE_tritt_ein:zf_zfa
# a655:HF:VORHERSAGE_subtiler_Identität:zf_zfa
# a655:F:Auf_Hilfsquelle_zurückgreifen:zf_zfa
# a655:F:VERLUST_des_Schatzes:zs_zfa
# a655:F:VORHERSAGE_erforderlich:zs_zfa
# a976:F:Rätsel_lösen:zfa
# a976:F:ERZÄHLEN_beginnen:zfa
# a655:H:ERZÄHLEN_beenden:zs_zfa
# a655:Hh:Rätsel_lösen:zs_zfa
# a655:H:VERLUSTursache_beheben:zs_zfa
# a655:H:STREIT_schlichten:zs_zfa
#
# zyx_cr_ttt_rus_60
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_61
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_62
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_63
# -----------------
# a545B Der gestiefelte Kater
# -----------------
# a545B:F:Einbrecher_begnadigen:rHD_rHF
# a545B:H:Einbrecher_begnadigen:rHD_rHF
# a545B:H:Hilfeversprechen_erhalten:rHD_rHF
# a545B:H:NEUGIER_auslösen:rHF_rHP
# a545B:F:Verlobung_arrangieren:rHF_rHP
# a545B:F:EINLADUNG_oder_Bestellung:rHF_rHP
# a545B:H:Auf_ausgelöste_NEUGIER_reagieren:rHF_rHP
# a545B:HF:Reichtum_VORTÄUSCHEN:rHD_rHF
# a545B:F:SONSTIGES_beheben:rHD_rHF
# a545B:H:SONSTIGES_Beheben_angehen:rHD_rHH
# a545B:H:SONSTIGES_beheben:rHD_rHH
# a545B:H:Reichtum_VORTÄUSCHEN:rHD_rHH
# a545B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHH
# a545B:H:NEUGIER_auslösen:rHD_rHH
# a545B:H:Auf_ausgelöste_NEUGIER_reagieren:rHD_rHF_rHP
# a545B:F:EINLADUNG_oder_Bestellung:rHD_rHF_rHP
# a545B:Hh:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rHF
# a545B:H:Sonstiges_VORTÄUSCHEN:rHF_fST
# a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_fST
# a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHF_fST
# a545B:f:EINDRUCKSVOLLE_Handlung:rHF_rHP
# a545B:h:Auf_EINDRUCKSVOLLE_Handlung_reagieren:rHF_rHP
# a545B:H:Unzufriedenheit_VORTÄUSCHEN:rHF_rHP
# a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_rHP
# a545B:H:Bedrohung_VORTÄUSCHEN:rHF_fST
# a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_fST
# a545B:H:TÖTUNG:rHF_fST
# a545B:H:Fremdes_Gut_beschlagnahmen:rHD_rHF_rPP
# a545B:H:Heiraten:rHD_rHF_rPP
# a545B:H:Ende:N
#
# zyx_cr_ttt_rus_7
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_8
# -----------------
#
# -----------------
#
# zyx_cr_ttt_rus_9
# -----------------
#
# -----------------
#
# zyx_cs_ddo_rus_43
# -----------------
#
# -----------------
