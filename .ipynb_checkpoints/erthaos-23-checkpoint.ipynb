# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !git clone https://github.com/edadunashvili/KaFk.git

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# import os
# try:
#     os.chdir('/content/KaFk')
#     print("Verzeichnis erfolgreich gewechselt!")
# except FileNotFoundError:
#     print("Verzeichnis nicht gefunden.")
# except Exception as e:
#     print(f"Ein Fehler ist aufgetreten: {e}")

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !pip install mglearn

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !pip install --upgrade joblib==1.1.1

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# from IPython.display import HTML, display
# def set_css():
#   display(HTML('''
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   '''))
# get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# # erthaos-23

# %% [markdown]
# ### README
#
# #####  Assistent für die automatische Erkennung der gesuchten Motive
#
#
# ##### Anpassbare Variablen:
#
#
# filter_ident: Filter für die Sprache des Texte. Entspricht dem Attributwert des Elements //langUsage/anguage/@ident="" in der XML Datei.
#
# gesep_1 ="" , gesep_2 ="" usw.: Die Abfragewerte für das Zielmotiv mit entsprechende Label. Die Werte von 'gesep_1' bis 'gesep_n' können nach der in der Motivliste ausgewälte Zeilen, oder ihre Bestandteilen ausgefült werden und anschließend in der Anfragezeile als Anfrage mit 'or' und/oder 'and' Opperatoren bestimmen.
#
# Stoppwortliste für die bestimmte Sprache.

# %% [markdown]
# ### Trainingsdaten aufbereiten und transformieren

# %%
import xml.etree.ElementTree as ET  #1 Importieren der ElementTree-Bibliothek zum Parsen von XML

#2 XML-Daten laden
tree = ET.parse('gesamt_maerchen.xml')
root_node = tree.getroot()

#3 Namespace definieren
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}

#5 Filtereinstellung für das Attribut `@ident` (kann leer sein)
filter_ident = "rus"  # z. B. input("Bitte geben Sie das Attribut 'ident' an (z.B. 'kat'): ").strip()

#6 Variable für die gesammelten Märchendaten
maerchen = ""

#7 Iteration durch die XML-Daten
for corp in root_node.findall(".//tei:teiCorpus", NS):
    if "xtk" in corp.attrib.get("n", ""):# or "" in corp.attrib.get("n", ""):
        for tei in corp.findall("tei:TEI", NS):
            #8 Filter basierend auf `@ident` oder bei leerem `filter_ident`
            language = tei.find(".//tei:teiHeader//tei:langUsage/tei:language", NS)
            if language is not None:
                ident_value = language.attrib.get('ident', '')
                if filter_ident == "" or ident_value == filter_ident:
                    for ganze in tei.findall(".//tei:text", NS):
                        quelle = ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                        for body in ganze.findall(".//tei:body", NS):
                            for absatz in body.findall(".//tei:p", NS):
                                for phrase in absatz.findall(".//tei:seg", NS):
                                    #9 Labels extrahieren
                                    labela = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/a}ana', 'N/A')
                                    labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N/A')
                                    labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N/A')
                                    labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N/A')
                                    labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N/A')
                                    labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N/A')
                                    labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N/A')
                                    labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N/A')
                                    labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N/A')
                                    labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N/A')
                                    labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N/A')
                                    labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N/A')
                                    inhalt = (phrase.text.lower().strip()
                                              .replace('|', '').replace(':', '').replace("ä", "ae")
                                              .replace("ü", "ue").replace("ö", "oe").replace("ß", "ss")
                                              .replace(",", "").replace("\n", " ").replace("'", "")
                                              .replace("…", "").replace('"', "").replace("*", "")
                                              .replace("(", "").replace(")", "").replace("-", "")
                                              .replace("]", "").replace("[", "").replace(".", "")
                                              .replace("?", "").replace("!", "").replace("„", "")
                                              .replace("+", "").replace("=", "").replace("_", "")
                                              .replace("­", "").replace('“', "").replace('”', "")
                                              .replace(";", "").replace('~', "").replace('`', ""))
                                    #10 Bedingung: labela beginnt mit 'a' und labelb1 ist nicht 'N/A'
                                    if labela.startswith('a') and labelb1 != 'N':
                                        #11 Märchendaten sammeln
                                        maerchen += (quelle + ',' + labela + ',' + labelb1 + ',' + labelc1 + ',' +
                                                     labelb2 + ',' + labelc2 + ',' + labelb3 + ',' + labelc3 + ',' +
                                                     labelb4 + ',' + labelc4 + ',' + labelb5 + ',' + labelc5 + ',' +
                                                     labeld + ',' + inhalt + ',0' + '\n')

#12 Ergebnisse in eine CSV-Datei schreiben
with open("text.csv", 'w', encoding='utf-8') as f:
    #13 Kopfzeile schreiben
    f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar')
    f.write('\n')
    #14 Gesammelte Märchendaten schreiben
    f.write(maerchen)

print(f"Die Märchendaten mit 'ident'='{filter_ident}' wurden in 'text.csv' gespeichert.")
# Out:
# Die Märchendaten mit 'ident'='rus' wurden in 'text.csv' gespeichert.

# %%
#15 leere Zeichenfolge, die später mit den gewünschten Daten gefüllt werden
abcd1="" 
abcd2="" 
abcd3=""  
abcd4=""  
abcd5=""  

import pandas as pd  
from collections import Counter

#16 Lesen der CSV-Datei und Laden der Daten in ein Pandas DataFrame
df = pd.read_csv('text.csv',  encoding='utf-8')

#17.1 Hinzufügen von Daten zu den entsprechenden Variablen abcd1 bis abcd5
#17.2 Hier werden die Daten aus verschiedenen Spalten des DataFrame kombiniert
abcd1 += df.quelle+','+df.labela+':'+df.labelb1+':'+df.labelc1+':'+df.labeld+':'+','+df.inhalt+',0'
abcd2 += df.quelle+','+df.labela+':'+df.labelb2+':'+df.labelc2+':'+df.labeld+':'+','+df.inhalt+',0'
abcd3 += df.quelle+','+df.labela+':'+df.labelb3+':'+df.labelc3+':'+df.labeld+':'+','+df.inhalt+',0'
abcd4 += df.quelle+','+df.labela+':'+df.labelb4+':'+df.labelc4+':'+df.labeld+':'+','+df.inhalt+',0'
abcd5 += df.quelle+','+df.labela+':'+df.labelb5+':'+df.labelc5+':'+df.labeld+':'+','+df.inhalt+',0'

#18 Zusammenführen der Daten aus den Variablen abcd1 bis abcd5
recorded=(abcd1+'\n'+abcd2+'\n'+abcd3+'\n'+abcd4+'\n'+abcd5+'\n')

#19 Schreiben der kombinierten Daten in eine neue CSV-Datei
with open("text_aw.csv", 'w', encoding='utf-8') as w:
    #20 Schreiben der Kopfzeile
    w.write('quelle,index_string,inhalt,index_binar\n')
    #21 Schreiben der vordefinierten Zeile mit Dummy-Daten
    w.write('000:ballast,ballast,ballast,0\n')
    #22 Schreiben der kombinierten Daten
    w.write("".join(recorded))
    #23 Schließen der Datei
    w.close()

# %%
import csv  

mom=[]  #24 Eine leere Liste zum Speichern der Zeilen, die bestimmten Kriterien entsprechen

#25 Lesen der CSV-Datei 'text_aw.csv'
with open('text_aw.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f) 
    #26 Iteration über jede Zeile in der CSV-Datei
    for line in reader:
        #27 Überprüfen, ob die Zeile nicht das Muster ':N:' in der zweiten Spalte enthält
        if ':N:' not in line[1]:
            #28 Wenn das Muster nicht vorhanden ist, wird die Zeile der Liste 'mom' hinzugefügt
            mom.append(line)

#29 Kopieren der Datei text_ax.txt
import shutil, os
with open ('text_ax.txt', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(mom)

#30 Öffnen der Datei text_ax.txt zum Lesen
with open('text_ax.txt', 'r', encoding='utf-8') as file:
    #31 Lesen des gesamten Inhalts der Datei
    filedata = file.read()

#32 Bearbeiten des Dateiinhalts, um das gewünschte Format zu erzielen
filedata = (filedata.replace(']","[', "\n").replace('"[','').replace(']"','')
            .replace(" '","").replace("'",""))

#33 Schreiben des bearbeiteten Inhalts in eine neue CSV-Datei text_ay.csv
with open('text_ay.csv', 'w', encoding='utf-8') as file:
    file.write(filedata)

# %%
custom_stop_word_list=['шах', 'аббас', 'алейкум', 'молла', 'насреддин', 'асаламу',  'ва', 'ваалейкум', 'ассалам','насреддина','ходжа','эскендер']  #34 Eine leere Liste, um benutzerdefinierte Stoppwörter zu speichern

import nltk
nltk.download('stopwords')  #35 Herunterladen der Stoppwortliste aus der NLTK-Datenbank

from nltk.corpus import stopwords  #36 Importieren der Stoppwortliste aus NLTK
NLTK_stop_words_list=stopwords.words('russian')  #37 Laden der Stoppwortliste für die bestimmte Sprache
stpw = custom_stop_word_list + NLTK_stop_words_list
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\xe78diq\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#38 Funktion zur Filterung eines CSV-Datensatzes und Zusammenführung mehrfacher Inhalte in eine Zeile
def filter_csv(input_file, output_file):
    data_to_write = []  #39 Liste zum Speichern der zu schreibenden Daten
    with open(input_file, 'r', encoding="utf-8", newline='') as csvfile:  #40 Öffnen der Eingabedatei im Lesemodus
        reader = csv.reader(csvfile)  #41 Erstellen eines CSV-Lesers
        data = list(reader)  #42 Lesen aller Daten in eine Liste
        processed_values = {}  #43 Dictionary zur Nachverfolgung bereits verarbeiteter Inhalte und deren aggregierten Inhalte
        
        for row in data:  #44 Iteration über jede Zeile der Daten
            if len(row) < 4:  #45 Sicherstellen, dass die Zeile genügend Spalten hat
                continue  #46 Zeile überspringen, wenn sie nicht genügend Spalten hat
            content_key = row[2]  #47 Inhalt aus Spalte 3 als Schlüssel verwenden
            if content_key not in processed_values:  #48 Überprüfen, ob der Inhalt noch nicht verarbeitet wurde
                processed_values[content_key] = row  #49 Zeile als verarbeitet markieren und speichern
            else:
                #50 Ergänzen des Inhalts in Spalte 2 der bereits gespeicherten Zeile
                processed_values[content_key][1] += ' ' + row[1]
        
    data_to_write = list(processed_values.values())  #51 Alle verarbeiteten Zeilen in eine Liste umwandeln
    
    with open(output_file, 'w', encoding="utf-8", newline='') as csvfile:  #52 Öffnen der Ausgabedatei im Schreibmodus
        csvfile.write('\n')  #53 Neue Zeile nach der Header-Zeile
        writer = csv.writer(csvfile)  #54 Erstellen eines CSV-Schreibers
        writer.writerows(data_to_write)  #55 Schreiben der gefilterten Daten

#56 Beispielaufruf der Funktion:
filter_csv('text_ay.csv', 'text_az.csv')

# %%
import pandas as pd  
from collections import Counter

#57 Lesen der CSV-Datei 'text_ay.csv' und Laden der Daten in ein Pandas DataFrame
df_1 = pd.read_csv('text_ay.csv',  encoding='utf-8')
df_2 = pd.read_csv('text_az.csv',  encoding='utf-8')
#58 Zählen der Vorkommen jeder Zeichenfolge in der Spalte 'index_string'
indexliste_1 = Counter(df_1.index_string)
indexliste_2 = Counter(df_2.index_string)

#59 Ausgabe der einzigartigen Zeichenfolgen in der Spalte 'index_string'
print(*indexliste_2, sep='\n')
# Out:
# ballast
# a654:F:SELTENEN_Gegenstand_besorgen:rHP:
# a654:H:Fernseher_als_ZAUBERMITTEL_erhalten:rHD:
# a654:H:WAFFE_oder_ZAUBERMITTEL_erhalten:rHD:
# a654:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD:
# a654:F:Um_eine_Frau_WERBEN:rHD_rHP:
# a654:F:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD: a654:H:VORHERSAGE_des_Aufenthaltsortes:rHD:
# anh248:#:#:#:
# anh384:#:#:#:
# a654:F:HEIRATSABSICHT_kundtun:rHD_rHH: a654:Hh:Auf_HEIRATSABSICHT_reagieren:rHD_rHH:
# a654:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rHH_rZM: a654:H:Elixier_als_ZAUBERMITTEL_erhalten:rHD_rHH_rZM: a654:H:Fernseher_als_ZAUBERMITTEL_erhalten:rHD_rHH_rZM:
# a654:F:STREIT_schlichten:rHD_rST: a654:H:STREIT_schlichten:rHD_rST:
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a654:F:WIEDERBELEBEN:rHD_rZM:
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a654:H:Komplikationsfreier_Flug:rHD_rZM:
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rPP: a654:H:WIEDERBELEBEN:rHD_rZM_rPP:
# a654:F:Dilemma_lösen:rHD:
# a654:F:Dilemma_lösen:rHD_fST: a654:h:Dilemma_lösen:rHD_fST:
# a1592B:f:#:zs_zt:
# a1592B:h:#:zs_zt:
# a1592B:h:#:zs_zt: a1592B:f:#:zs_zt: a1592B:h:#:zs_zt:
# anh395:#:#:#:
# anh313:#:#:#:
# a1592B:#:#:#:
# anh577:#:#:#:
# aTMJ2672:#:#:#:
# anh789:#:#:#:
# aE2:H:Wunderbare_EMPFÄNGNIS:rHH:
# aE2:Hh:Kaiserschnitt:rHD_rHH_rHF: aE2:H:Zur_Welt_kommen:rHD_rHH_rHF:
# aE2:F:UNGEHEUER_herbeiholen:rHH_fAN:
# aE2:h:MASSENBEDROHUNG:rHD_rAN: aE2:H:Zweikampf:rHD_rAN:
# aE2:H:MASSENBEDROHUNG_beheben:rHD_rHH_rVB:
# aE2:F:Um_einen_Auftrag_WERBEN:rHD_rHH:
# aE2:F:PROVOKATION:rHD_rVB: aE2:H:Auf_PROVOKATION_reagieren:rHD_rVB:
# aE2:F:Krisenursachen_ergründen:rHD_rHH: aE2:F:Rache_nehmen:rHD_rHH: aE2:F:Um_einen_Auftrag_WERBEN:rHD_rHH:
# aE2:H:Beschaffung_der_AUSRÜSTUNG:rHH_rST:
# aE2:#:#:#:
# aE2:HF:PFÖRTNER_täuschen:rHD_rVB:
# aE2:H:PFÖRTNER_entkommen:rHD: aE2:H:ANGST_auslösen:rHD:
# aE2:F:MASSENBEDROHUNG_beheben:rHH_fAN:
# aE2:F:MASSENBEDROHUNG_beheben:rHD_rHH: aE2:HF:Information_aus_zweiter_Hand:rHD_rHH:
# aE2:H:Heimlich_beobachten:rHD: aE2:h:MASSENBEDROHUNG:rHD:
# aE2:H:Beschaffung_der_AUSRÜSTUNG:rHD_fAN: aE2:H:REITTIER_erfassen:rHD_fAN: aE2:H:REITTIER_besorgen:rHD_fAN:
# a1543:F:PROVOKATION:zs:
# a1543:H:Auf_PROVOKATION_reagieren:zt:
# a1543:h:Numinose_Einmischung_VORTÄUSCHEN:zs_zt: a1543:H:Auf_VORTÄUSCHEN_reagieren:zs_zt:
# a1543:H:VORTÄUSCHEN_ABSURDITÄT_zu_glauben:zs_zt:
# anh531:F:SONSTIGES_verkaufen:zs_zsa:
# anh531:h:Handeln_als_ABSURDITÄT:zs: anh531:h:Sachschaden_anrichten:zs: anh531:H:Schlußfolgerung_als_ABSURDITÄT:zs:
# anh531:f:Vorgang_deuten:zs_zsa: anh531:H:VORTÄUSCHEN_ABSURDITÄT_zu_glauben:zs_zsa:
# a56B:#:#:#:
# a8:#:#:#:
# a38:#:#:#:
# anh921:#:#:#:
# anh483:#:#:#:
# a1640:#:#:#:
# anh483:#:#:#: anh483:h:#:#:
# a301:F:Auftrag_zum_Kochen:fHD:
# a301:f:PROVOKATION:rST_fHD: a301:h:Auf_PROVOKATION_reagieren:rST_fHD:
# a301:h:Auftrag_zum_Kochen:fHD: a301:h:Vorgang_deuten:fHD:
# a301:F:Auftrag_zum_Kochen:fHD: a301:h:Auftrag_zum_Kochen:fHD: a301:h:Vorgang_deuten:fHD:
# a301:F:Auftrag_zum_Kochen:rHD:
# a301:f:PROVOKATION:rHD_rST: a301:H:Auf_PROVOKATION_reagieren:rHD_rST: a301:H:Hilfeversprechen_erhalten:rHD_rST:
# a300:F:WASSERMANGEL_beheben:rHD_rHF: a300:F:Menschliche_OPFERGABE_beheben:rHD_rHF: a300:H:WAFFE_oder_ZAUBERMITTEL_erhalten:rHD_rHF:
# a300:HF:Abraten_von_der_MISSION:rHD_rVB: a300:Hh:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rVB:
# a300:H:Mut_zeigen:rHD_rPP:
# a300:H:Zweikampf:rHD_rAN:
# a300:H:WASSERMANGEL_beheben:rHD_rVB:
# a300:F:MARKIERUNGEN_anbringen:rHD_rAN:
# a300:F:MARKIERUNGEN_anbringen:rHD_rPP: a300:h:KONTAKT_abbrechen:rHD_rPP:
# a300:H:Vorgang_deuten:rHD_fHD: a300:h:GIER_und_Neid_auslösen:rHD_fHD: a300:h:SCHLAF:rHD_fHD:
# a300:f:ANEIGNUNG:rHD_fHD: a300:h:ENTMACHTUNG:rHD_fHD: a300:h:ANEIGNUNG:rHD_fHD:
# a300:h:Heldentat_VORTÄUSCHEN:rVB_fHD:
# a300:H:Auf_VORTÄUSCHEN_reagieren:rPP_fHD:
# a300:F:ANEIGNUNG_beheben:rHD_rHF: a300:F:Krisenursachen_ergründen:rHD_rHF:
# a300:H:KONTAKT_wiederherstellen:rHD_rHP_rPP: a300:H:MARKIERUNGEN_vorlegen:rHD_rHP_rPP: a300:H:MARKIERUNGEN_erkennen:rHD_rHP_rPP:
# a300:H:Held_erkennen:rHF_rHP_fHD: a300:H:Bestrafung:rHF_rHP_fHD:
# a300:f:Heiraten:rHD_rPP:
# anh344:#:#:#:
# a922:f:PROVOKATION:zt_zf: a922:h:Auf_PROVOKATION_reagieren:zt_zf: a922:f:VEREINBARUNG:zt_zf:
# a922:F:Gutes_Benehmen:zs_zt: a922:H:Gutes_Benehmen:zs_zt: a922:H:Stifter_oder_Helfer_gewinnen:zs_zt:
# a922:f:RÄTSELHAFTES_Gespräch_oder_Handlung:zf_zfa:
# a922:H:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zt:
# a922:f:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zt_zf: a922:H:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zt_zf:
# a922:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:zs_zt_zf: a922:H:VEREINBARUNG_einhalten:zs_zt_zf:
# a930:f:VORHERSAGE_ungewünschter_Eheschliessung:rST_fHP:
# a930:h:Auf_VORHERSAGE_reagieren:rHD_rHH_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP: a930:h:TÖTUNG:rHD_rHH_fHP: a930:h:Aussetzung:rHD_rHH_fHP:
# a930:H:Adoption:rHD_rST:
# a930:H:Begegnung:rHD_rST_fHP: a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rST_fHP: a930:h:BOTSCHAFTEN_versenden:rHD_rST_fHP:
# a930:H:SCHLAF:rHD_rPP: a930:F:Liebe_wird_ausgelöst:rHD_rPP: a930:H:BOTSCHAFTEN_verfälschen:rHD_rPP:
# a930:H:Auf_BOTSCHAFTEN_reagieren:rHD_rHP_rPP: a930:H:Heiraten:rHD_rHP_rPP: a930:H:VORHERSAGE_tritt_ein:rHD_rHP_rPP:
# a545B:F:Sorge_um_Hungernde_oder_Durstige:rHD_rHF: a545B:H:Sorge_um_Hungernde_oder_Durstige:rHD_rHF:
# a545B:H:Hilfeversprechen_erhalten:rHD_rHF:
# a545B:H:Reichtum_VORTÄUSCHEN:rHF_rHP: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_rHP:
# a545B:H:Verlobung_arrangieren:rHF_rHP: a545B:F:EINLADUNG_oder_Bestellung:rHF_rHP:
# a545B:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rHF:
# a545B:H:Verlust_VORTÄUSCHEN:rHF_rHP: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_rHP:
# a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF: a545B:H:REITTIER_erhalten:rHD_rHF:
# a545B:H:Heiraten:rHD_rHF_rPP: a545B:H:Auf_dem_Heimweg:rHD_rHF_rPP:
# a545B:H:Bedrohung_VORTÄUSCHEN:rHF_fST: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_fST: a545B:H:VERTREIBUNG:rHF_fST:
# a545B:H:Fremdes_Gut_beschlagnahmen:rHD_rHF_rPP:
# a545B:h:Tod_VORTÄUSCHEN:rHD_rHF: a545B:Ff:Vertrauen_beweisen:rHD_rHF:
# a545B:h:Auf_VORTÄUSCHEN_reagieren:rHD_rPP: a545B:h:Vertrauen_beweisen:rHD_rPP:
# a545B:H:VORTÄUSCHEN_eingestehen:rHF_fST: a545B:hf:Wiedergutmachung_erzielen:rHF_fST:
# a545B:f:Wiedergutmachung_erzielen:rHD_rHF_fST: a545B:H:Bedrohung_VORTÄUSCHEN:rHD_rHF_fST: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHF_fST: a545B:H:Wiedergutmachung_erzielen:rHD_rHF_fST:
# a1164:h:Unerträgliche_Ungeheuerlichkeit:rHD_fHD: a1164:F:Ungewünschtes_Wesen_beseitigen:rHD_fHD:
# a1164:H:Jemanden_im_STICH_lassen:rHD_fHD:
# a1862B:Hh:Sorge_um_Hilfsbedürftige:rHD_fAN: a1862B:F:VEREINBARUNG:rHD_fAN: a1862B:HF:Heldentat_VORTÄUSCHEN:rHD_fAN: a1862B:hf:TABU_Limit_nicht_überziehen:rHD_fAN:
# a1862B:F:WASSERMANGEL_beheben:rHD_rHP: a1862B:F:Menschliche_OPFERGABE_beheben:rHD_rHP: a1862B:F:VEREINBARUNG:rHD_rHP:
# a1862B:F:Um_einen_Auftrag_WERBEN:rHD_rHP: a1862B:F:VEREINBARUNG:rHD_rHP:
# a1862B:H:Heldentat_VORTÄUSCHEN:rHD_fAN: a1862B:H:VEREINBARUNG_einhalten:rHD_fAN: a1862B:H:Bedrohung_VORTÄUSCHEN:rHD_fAN: a1862B:H:WASSERMANGEL_beheben:rHD_fAN: a1862B:H:Menschliche_OPFERGABE_beheben:rHD_fAN:
# a1862B:H:VEREINBARUNG_einhalten:rHD_rHP_rPP: a1862B:H:Heiraten:rHD_rHP_rPP:
# a1164:h:WASSERMANGEL:fAN: a1164:h:OPFERGABE_verlangen:fAN:
# a1164:F:WASSERMANGEL_beheben:rHD_rHP: a1164:F:Menschliche_OPFERGABE_beheben:rHD_rHP: a1164:F:Um_einen_Auftrag_WERBEN:rHD_rHP:
# a1164:F:PROVOKATION:rHD_fHF: a1164:H:Auf_PROVOKATION_reagieren:rHD_fHF:
# a1164:h:Auf_TABU_reagieren:rHD_fAN: a1164:f:VEREINBARUNG_einhalten:rHD_fAN: a1164:H:Gefahr_VORTÄUSCHEN:rHD_fAN: a1164:H:Auf_VORTÄUSCHEN_reagieren:rHD_fAN: a1164:H:Menschliche_OPFERGABE_beheben:rHD_fAN:
# a56A:#:#:#:
# a1543:H:Auf_PROVOKATION_reagieren:zt: a1543:H:Numinose_Einmischung_VORTÄUSCHEN:zt:
# a1543:H:Auf_VORTÄUSCHEN_reagieren:zs_zt: a1543:H:ABSURDITÄT_behaupten:zs_zt:
# a1543:f:Vorgang_deuten:zs_zt: a1543:h:VORTÄUSCHEN_eingestehen:zs_zt: a1543:f:STREIT_schlichten:zs_zt: a1543:H:Eine_löst_andere_ABSURDITÄT_aus:zs_zt:
# a1543:F:STREIT_schlichten:zs_zt_zf: a1543:h:Vorgang_deuten:zs_zt_zf: a1543:H:VORTÄUSCHEN_ABSURDITÄT_zu_glauben:zs_zt_zf: a1543:H:ABSURDITÄT_behaupten:zs_zt_zf: a1543:H:ABSURDITÄT_beglaubigen:zs_zt_zf:
# anh531:F:SONSTIGES_verkaufen:zs_zt:
# a329:h:STERBEN:rHD:
# a329:F:Potenzielle_Beute_begnadigen:rHD_rHF: a329:H:Potenzielle_Beute_begnadigen:rHD_rHF: a329:H:Herbeirufendes_ZAUBERMITTEL_erhalten:rHD_rHF:
# a329:F:VERSTECKWETTE:rHD_rVB:
# a329:f:VEREINBARUNG:rHD_rPP:
# a329:h:VERSTECKWETTE:rHD_rHF:
# a329:h:VERSTECKWETTE:rHD_rPP:
# a329:H:VERSTECKWETTE:rHD_rHF:
# a329:H:VERSTECKWETTE:rHD_rPP:
# a329:H:Heiraten:rHD_rPP:
# a922:F:Gutes_Benehmen:zs_zt: a922:h:Gutes_Benehmen:zs_zt: a922:h:KONTAKT_abbrechen:zs_zt:
# a922:H:KONTAKT_wiederherstellen:zs_zt: a922:H:Stifter_oder_Helfer_gewinnen:zs_zt:
# a922:H:RÄTSELHAFTES_Gespräch_oder_Handlung:zs:
# anh344:#:#:#: anh344:h:#:#:
# a545B:F:Sorge_um_Hungernde_oder_Durstige:rHD_rHF: a545B:H:Sorge_um_Hungernde_oder_Durstige:rHD_rHF: a545B:H:Hilfeversprechen_erhalten:rHD_rHF:
# a545B:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rHF: a545B:H:Verlust_VORTÄUSCHEN:rHD_rHF:
# a545B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHF_rHP: a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF_rHP: a545B:H:REITTIER_erhalten:rHD_rHF_rHP:
# a545B:H:Heiraten:rHD_rHF_rHP:
# a545B:H:Auf_dem_Heimweg:rHD_rHF_rPP:
# a545B:f:Vertrauen_beweisen:rHD_rHF_rPP: a545B:h:Vertrauen_beweisen:rHD_rHF_rPP:
# a325:F:Zauberkunst_erlernen:rHD_rBZ:
# a325:HF:Unwissenheit_VORTÄUSCHEN:rHD_rZO:
# a325:H:Unwissenheit_VORTÄUSCHEN:rHD_rBZ: a325:H:Zauberkunst_erlernen:rHD_rBZ:
# a325:hf:TABU_Gegenstand_nicht_weitergeben:rHD_rHH:
# a325:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHH_rBZ:
# a325:Hh:FLUCHT:rHD_rBZ: a325:h:VERFOLGUNG:rHD_rBZ: a325:H:Änderung_der_EXISTENZFORM:rHD_rBZ: a325:H:VERFOLGUNG_entkommen:rHD_rBZ:
# a930:h:Auf_VORHERSAGE_reagieren:rHH_fHP: a930:h:Heiraten:rHH_fHP:
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP: a930:h:TÖTUNG:rHD_rHH_fHP: a930:h:Aussetzung:rHD_rHH_fHP:
# a930:H:Begegnung:rHD_rST_fHP: a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST_fHP: a930:h:Adoption:rHD_rST_fHP:
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_fHP: a930:h:BOTSCHAFTEN_versenden:rHD_fHP:
# a930:F:Liebe_wird_ausgelöst:rHD_rHP_rPP: a930:H:BOTSCHAFTEN_verfälschen:rHD_rHP_rPP: a930:H:Heiraten:rHD_rHP_rPP:
# a910K:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rST_fHP:
# a910K:f:Ungewünschtes_Wesen_beseitigen:fHP_fAN: a910K:H:Bösen_einstellen:fHP_fAN: a910K:f:TODESAUFTRAG:fHP_fAN:
# a910K:f:FRUCHT_besorgen:rHD_fHP:
# a910K:H:FRUCHT_erfassen:rHD_rHP_fHP: a910K:H:FRUCHT_besorgen:rHD_rHP_fHP: a910K:H:TODESAUFTRAG_entkommen:rHD_rHP_fHP:
# a910K:H:Eigene_Misshandlung_nachforschen:fHP_fHP: a910K:H:TODESAUFTRAG:fHP_fHP:
# a910K:H:Ende:rHD_rPP:
# a314:h:RESPEKTLOSIGKEIT:rHD_fHH:
# a314:f:VEREINBARUNG:rST_fHH:
# a314:F:VEREINBARUNG_einhalten:fHD_fHH: a314:h:VEREINBARUNG_einhalten:fHD_fHH:
# a314:F:VEREINBARUNG_einhalten:rHD_fHH: a314:H:VEREINBARUNG_einhalten:rHD_fHH:
# a314:F:Liebe_wird_ausgelöst:rHD_rST_rPP: a314:H:Heiraten:rHD_rST_rPP:
# a314:F:Auf_dem_Heimweg:rHD_rHP: a314:H:SCHLAF:rHD_rHP:
# a314:H:SCHÖNE_erfassen:rHP_rHP:
# a314:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHP_rHP_fHP:
# a314:H:Bestrafung:rST_fHH:
# aTMJ1522_1:#:#:#:
# a950:#:#:#:
# a1525G:#:#:#:
# a563:F:HUNGERSNOT_beheben:rHD_rHH:
# a563:F:Sorge_um_Freikaufsbedürftige:rHD_rHF: a563:H:Sorge_um_Freikaufsbedürftige:rHD_rHF: a563:H:Begleiter_gewinnen:rHD_rHF:
# a563:h:HUNGERSNOT:rHD_rHH: a563:F:HUNGERSNOT_beheben:rHD_rHH:
# a563:F:Sorge_um_Freikaufsbedürftige:rHD_rST: a563:H:Sorge_um_Freikaufsbedürftige:rHD_rST: a563:H:Hilfeversprechen_erhalten:rHD_rST:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rVB: a563:HF:Richtiges_erlangen:rHD_rVB:
# a563:H:Richtiges_erlangen:rHD_rST: a563:H:Proviantproduzierenden_ZAUBERMITTEL_erhalten:rHD_rST:
# a563:HF:Richtiges_erlangen:rHD_rVB:
# a563:H:Richtiges_erlangen:rHD_rST: a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST: a563:HF:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rST:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH:
# a563:F:EINLADUNG_oder_Bestellung:rHD_rHH_rAN: a563:h:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rHH_rAN: a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHH_rAN: a563:h:GIER_und_Neid_auslösen:rHD_rHH_rAN: a563:h:ANEIGNUNG:rHD_rHH_rAN:
# a563:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHH_fZM:
# a563:F:EINLADUNG_oder_Bestellung:rHD_rZM_rAN: a563:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rZM_rAN: a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:H:ANEIGNUNG_beheben:rHD_rZM_rAN:
# a550:F:Erträumen:rHD_rHH_fHD: a550:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_rHH_fHD: a550:F:REITTIER_besorgen:rHD_rHH_fHD:
# a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD: a550:Hh:Auf_ALTERNATIVEN_reagieren:rHD_fHD:
# a550:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB:
# a550:HF:REITTIER_erfassen:rST_rVB:
# a550:HF:Information_aus_zweiter_Hand:rST_rVB:
# a550:H:REITTIER_erfassen:rHD_rZM_rZO:
# a531:Hh:Auffälliges_GEGENSTANDES_habhaft_werden:rHD_rZM_rZO: a531:HF:Heiratszusage_erpressen:rHD_rZM_rZO:
# a531:H:Heiratszusage_erpressen:rHD_rZO: a531:H:SCHÖNE_erfassen:rHD_rZO:
# a550:f:ENTMACHTUNG:rHD_fHD: a550:h:ENTMACHTUNG:rHD_fHD:
# a550:h:Vorgang_deuten:rHH_fHD: a550:h:Heldentat_VORTÄUSCHEN:rHH_fHD:
# a550:h:FREIHEITSBERAUBUNG:rPP_fHD:
# a550:H:FREIHEITSBERAUBUNG_beheben:rZO_rZO: a550:H:ENTMACHTUNG_beheben:rZO_rZO:
# a550:F:Bestrafung:rHD_rZO_fHD: a550:F:Heiraten:rHD_rZO_fHD:
# a563:F:Sorge_um_Freikaufsbedürftige:rHD_rST: a563:H:Sorge_um_Freikaufsbedürftige:rHD_rST:
# a563:H:Begleiter_gewinnen:rHD_rST:
# a563:H:Richtiges_erlangen:rHD_rST: a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST:
# a563:HF:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rVB:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH_rZM:
# a563:F:EINLADUNG_oder_Bestellung:rHD_rZM_rAN: a563:h:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rZM_rAN: a563:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:h:GIER_und_Neid_auslösen:rHD_rZM_rAN: a563:h:ANEIGNUNG:rHD_rZM_rAN:
# a563:F:EINLADUNG_oder_Bestellung:rHD_rZM_rAN: a563:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rZM_rAN: a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:H:ANEIGNUNG_beheben:rHD_rZM_rAN: a563:H:HUNGERSNOT_beheben:rHD_rZM_rAN:
# a550:HF:Information_aus_zweiter_Hand:rHD_rVB:
# a550:H:REITTIER_erfassen:rHD_rZO:
# a531:Hh:Auffälliges_GEGENSTANDES_habhaft_werden:rHD_rZM_rZO:
# a531:f:VOGEL_herbeiholen:rHD_fVB:
# a531:HF:Heiratszusage_erpressen:rHD_rZO:
# a550:hf:ENTMACHTUNG:rHD_fHD: a550:h:ENTMACHTUNG:rHD_fHD:
# a304:f:Ungewollte_Verlobung_akzeptieren:rHH_fHH: a304:h:Ungewollte_Verlobung_akzeptieren:rHH_fHH: a304:H:FLUCHT:rHH_fHH: a304:H:Sich_niederlassen:rHH_fHH:
# a304:H:Wunderbare_EMPFÄNGNIS:rHH:
# a304:H:Zur_Welt_kommen:rHD_rHH:
# a304:F:Tapferkeit_beweisen:rHP:
# a304:h:Stifter_oder_Helfer_gewinnen:fHD_fHF:
# a304:H:Mehrere_Gegner_nacheinander_besiegen:rHD_fHF:
# a304:F:MARKIERUNGEN_anbringen:rHD_fVB:
# a304:Hh:SCHÖNE_erfassen:rHD_rPP: a304:H:Beiwohnung_mit_der_Schönen:rHD_rPP: a304:F:MARKIERUNGEN_anbringen:rHD_rPP: a304:h:KONTAKT_abbrechen:rHD_rPP:
# a304:F:KONTAKT_wiederherstellen:rHP_fHD: a304:h:Heldentat_VORTÄUSCHEN:rHP_fHD: a304:h:MARKIERUNGEN_erkennen:rHP_fHD: a304:H:Auf_VORTÄUSCHEN_reagieren:rHP_fHD:
# a304:H:KONTAKT_wiederherstellen:rHD_rHP: a304:H:MARKIERUNGEN_erkennen:rHD_rHP: a304:H:Held_erkennen:rHD_rHP: a304:H:Heiraten:rHD_rHP:
# a1528:#:#:#:
# anh391:#:#:#:
# a1553:#:#:#:
# a303:h:Kinderlosigkeit:rHH:
# a303:Hh:VEREINBARUNG:rHH_rHP: a303:H:Wundermittel_zur_EMPFÄNGNIS_erhalten:rHH_rHP:
# a303:H:Zur_Welt_kommen:rHD_rHD: a303:H:Zur_Welt_kommen:rHD_rHD:
# a303:f:VEREINBARUNG_einhalten:rHD_rHH: a303:F:Um_einen_Auftrag_WERBEN:rHD_rHH:
# a303:F:MARKIERUNGEN_anbringen:rHD_rHD_rZM: a303:h:KONTAKT_abbrechen:rHD_rHD_rZM:
# a327A:F:Gutes_Benehmen:rHD_rST: a327A:H:Gutes_Benehmen:rHD_rST: a327A:HF:Unwissenheit_VORTÄUSCHEN:rHD_rST:
# a327A:h:Gastfreundlichkeit_VORTÄUSCHEN:rHD_fHP: a327A:H:Auf_VORTÄUSCHEN_reagieren:rHD_fHP:
# a327A:H:Unwissenheit_VORTÄUSCHEN:rHD_fHP: a327A:H:Auf_VORTÄUSCHEN_reagieren:rHD_fHP: a327A:H:TÖTUNG:rHD_fHP:
# a303:H:REITTIER_erfassen:rHD_rHF_rPP: a303:H:SCHÖNE_erfassen:rHD_rHF_rPP:
# a303:h:KONTAKT_abbrechen:rHD_rPP:
# a314:F:VEREINBARUNG:rHD_rVB:
# a314:F:Liebe_wird_ausgelöst:rHD_rPP:
# a314:F:RÄTSELHAFTES_Gespräch_oder_Handlung:rHD_rPP_fPP:
# a314:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:rHP_fVB:
# a314:H:Um_einen_Mann_WERBEN:fHD_fHP: a314:H:Heiraten:fHD_fHP:
# a314:Hh:Um_einen_Mann_WERBEN:fHD_fPP: a314:Hh:Heiraten:fHD_fPP:
# a314:h:RESPEKTLOSIGKEIT:rPP_fPP:
# a314:h:KRANKHEIT:rHP: a314:F:HEILMITTEL_besorgen:rHP:
# a314:H:TIERKÖRPERTEIL_erfassen:rHD_rZO:
# a314:Hh:HEILMITTEL_erfassen:rHD_fHD: a314:F:MARKIERUNGEN_anbringen:rHD_fHD:
# a314:h:HEILMITTEL_besorgen:fHD_fZO_fPP: a314:h:Heldentat_VORTÄUSCHEN:fHD_fZO_fPP:
# a314:h:KRANKHEIT_beheben:rHP_fZO_fPP:
# a314:H:HEILMITTEL_besorgen:rHD_rZO_rPP:
# a314:h:KRANKHEIT_beheben:rHP_rPP:
# a314:F:Krieg_führen:rHP_fHD:
# a314:F:Um_einen_Auftrag_WERBEN:rHD_fHD: a314:h:RESPEKTLOSIGKEIT:rHD_fHD:
# a314:h:Krieg_führen:rHP_fHD:
# a314:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rPP:
# a314:H:IDENTITÄT_ändern:rHD: a314:H:Krieg_führen:rHD:
# a314:F:Intensive_Erkundungsaktion:rHP:
# a314:h:NEUGIER_auslösen:fPP:
# a314:h:Auf_ausgelöste_NEUGIER_reagieren:fHD_fPP: a314:f:Ungewünschtes_Wesen_beseitigen:fHD_fPP:
# a314:h:TÖTUNG:rHD_fHD:
# a303:H:MARKIERUNGEN_erkennen:rHH_rZM:
# a303:F:Um_einen_Auftrag_WERBEN:rHD_rHH:
# a303:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rZM_rPP: a303:H:Wegweisung_erhalten:rHD_rZM_rPP: a303:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rZM_rPP:
# a303:H:Unterkommen:rHD_rPP: a303:F:RÄTSELHAFTES_Gespräch_oder_Handlung:rHD_rPP: a303:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:rHD_rPP: a303:H:Begleiter_gewinnen:rHD_rPP:
# a303:H:WIEDERBELEBEN:rHD_rHD_rPP:
# a314:H:Intensive_Erkundungsaktion:rHD_rHP_fHD: a314:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rHP_fHD: a314:H:MARKIERUNGEN_vorlegen:rHD_rHP_fHD: a314:H:MARKIERUNGEN_erkennen:rHD_rHP_fHD: a314:H:ANEIGNUNG_beheben:rHD_rHP_fHD:
# a314:H:Bestrafung:rHP_fHD:
# a314:H:Heiraten:rHD_rPP:
# a314:H:KONTAKT_wiederherstellen:rHD_rPP: a314:H:Heiraten:rHD_rPP:
# a303:H:KONTAKT_wiederherstellen:rHD_rHH:
# a1199:#:#:#:
# a551:h:KRANKHEIT:rHD_rHH_fHD: a551:F:FRUCHT_besorgen:rHD_rHH_fHD:
# a551:F:Gutes_Benehmen:rST_fHD: a551:h:Gutes_Benehmen:rST_fHD: a551:h:FLUCH:rST_fHD:
# a551:h:FRUCHT_erfassen:fHD_fZO:
# a551:h:FRUCHT_besorgen:rHH_fHD_fZO: a551:h:Vorgang_deuten:rHH_fHD_fZO:
# a551:h:FRUCHT_erfassen:rHH_fHD_fZO:
# a551:F:Gutes_Benehmen:rHD_rST: a551:H:Gutes_Benehmen:rHD_rST: a551:HF:PFÖRTNER_täuschen:rHD_rST: a551:HF:FRUCHT_erfassen:rHD_rST:
# a551:H:PFÖRTNER_täuschen:rHD_rBZ_fHF: a551:H:PFÖRTNER_entkommen:rHD_rBZ_fHF:
# a551:H:FRUCHT_erfassen:rHD_rBZ_rZO: a551:F:MARKIERUNGEN_anbringen:rHD_rBZ_rZO: a551:h:KONTAKT_abbrechen:rHD_rBZ_rZO:
# a551:H:FRUCHT_besorgen:rHD_rHH:
# a551:H:MARKIERUNGEN_erkennen:rBZ: a551:F:KONTAKT_wiederherstellen:rBZ: a551:F:Intensive_Erkundungsaktion:rBZ: a551:F:IDENTITÄT_beweisen:rBZ:
# a551:h:Intensive_Erkundungsaktion:rBZ_fHD: a551:h:IDENTITÄT_beweisen:rBZ_fHD:
# a551:H:Intensive_Erkundungsaktion:rHD_rBZ: a551:H:IDENTITÄT_beweisen:rHD_rBZ: a551:H:Held_erkennen:rHD_rBZ:
# a551:H:Heiraten:rHD_rBZ: a551:H:Ende:rHD_rBZ:
# a1354A*:#:#:#:
# a715:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:rHD_rAN: a715:F:VERLUSTursache_beheben:rHD_rAN:
# a715:H:Universellen_ZAUBERMITTEL_erfassen:rHD_rZM:
# a715:H:Mut_zeigen:rHD_rAN_fVB:
# a715:f:Gemenge_entkommen:rHD_rAN_fVB:
# a715:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a715:H:Gemenge_entkommen:rHD_rZM:
# a715:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a715:H:Gemenge_entkommen:rHD_rZM: a715:h:ANGST_auslösen:rHD_rZM:
# a715:f:Hitze_entkommen:rAN_fVB:
# a715:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a715:H:Hitze_entkommen:rHD_rZM:
# a715:H:NEUGIER_auslösen:rHD_rAN: a715:h:Auf_ausgelöste_NEUGIER_reagieren:rHD_rAN: a715:H:Bestrafung:rHD_rAN:
# a715:H:VERLUSTursache_beheben:rHD: a715:H:Ende:rHD:
# a910B:F:Um_einen_Auftrag_WERBEN:rHD_rHH: a910B:Hh:Auf_WERBEN_reagieren:rHD_rHH: a910B:HF:WEISHEITEN_erhalten:rHD_rHH: a910B:HF:Treuen_Helfer_finden:rHD_rHH:
# a910B:H:Auf_WEISHEITEN_reagieren:rHD:
# a505:F:Sorge_um_Freikaufsbedürftige:rHD_rHF: a505:H:Sorge_um_Freikaufsbedürftige:rHD_rHF:
# a910B:H:Begegnung:rHD_rHF: a910B:H:Begleiter_gewinnen:rHD_rHF:
# a910B:H:Auf_WEISHEITEN_reagieren:rHD_rHF: a910B:H:Treuen_Helfer_finden:rHD_rHF:
# a505:H:Unterkommen:rHD_rHF: a505:h:Auf_WEISHEITEN_reagieren:rHD_rHF: a505:F:Wache_halten:rHD_rHF:
# a505:H:Wache_halten:rHF_rAN: a505:HF:Schatz_finden:rHF_rAN: a505:H:TÖTUNG:rHF_rAN:
# a505:H:Wache_halten:rHD_rAN: a505:H:Wiedergutmachung_erzielen:rHD_rAN:
# a505:F:Verlobung_arrangieren:rHD_rHF:
# a505:f:EINLADUNG_oder_Bestellung:rHD_fHP: a505:f:TÖTUNG:rHD_fHP:
# a505:H:Zweikampf:rHF_rAN: a505:H:TÖTUNG_beheben:rHF_rAN:
# a505:H:Auf_dem_Heimweg:rHD_rHF: a505:H:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rHF:
# a505:H:Schatz_finden:rHD_rHF_rPP: a505:Ff:Beuteteilen:rHD_rHF_rPP: a505:Hh:Beuteteilen:rHD_rHF_rPP: a505:H:Erlösung:rHD_rHF_rPP:
# a505:H:Ende:rHD_rHH_rPP:
# a563:h:HUNGERSNOT:rHD_rHH:
# a563:F:Potenzielle_Beute_begnadigen:rHD_rST_rZM: a563:H:Potenzielle_Beute_begnadigen:rHD_rST_rZM: a563:H:Proviantproduzierenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH_rZM: a563:H:HUNGERSNOT_beheben:rHD_rHH_rZM:
# a563:F:EINLADUNG_oder_Bestellung:rHH_rHH:
# a563:HF:Information_aus_zweiter_Hand:rHH_rAN: a563:h:Auf_EINLADUNG_oder_Bestellung_reagieren:rHH_rAN:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:h:GIER_und_Neid_auslösen:rHD_rZM_rAN: a563:h:ANEIGNUNG:rHD_rZM_rAN:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a563:H:Hilfe_erpressen:rHD_rST_rZM: a563:H:Gold_oder_geldproduzierenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:Hh:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rZM_rAN: a563:hf:Verbot_als_ABSURDITÄT:rHD_rZM_rAN:
# a563:h:Auf_ABSURDITÄT_reagieren:rZM_rAN: a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rZM_rAN: a563:h:GIER_und_Neid_auslösen:rZM_rAN: a563:h:ANEIGNUNG:rZM_rAN:
# a563:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_fZM:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a563:H:Hilfe_erpressen:rHD_rST_rZM: a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rZM:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:H:ANEIGNUNG_beheben:rHD_rZM_rAN:
# a563:H:Ende:rHD_rHH:
# a650A:h:ENTFÜHRUNG:rHH_fHH:
# a650A:H:Zur_Welt_kommen:rHD:
# a650A:H:Krisenursachen_ergründen:rHD_rHH: a650A:F:ENTFÜHRUNG_beheben:rHD_rHH:
# a650A:H:Zweikampf:rHD_fHH: a650A:H:ENTFÜHRUNG_beheben:rHD_fHH:
# a650A:h:KONTAKT_abbrechen:rHD_rHH:
# a650A:f:VEREINBARUNG:rHD_rAN:
# a650A:f:HOLZ_besorgen:rHD_rAN:
# a650A:H:HOLZ_Besorgen_angehen:rHD_rZO:
# a650A:H:HOLZ_besorgen:rHD_rZO_rAN: a650A:h:ANGST_auslösen:rHD_rZO_rAN:
# a650A:f:ZOLLERHEBUNG_vollstrecken:rHD_rAN:
# a650A:H:ZOLLERHEBUNG_Vollstrecken_angehen:rHD_rBZ_rZO: a650A:H:UNGEHEUER_erfassen:rHD_rBZ_rZO:
# a650A:H:UNGEHEUER_herbeiholen:rHD_rBZ_rAN: a650A:h:ANGST_auslösen:rHD_rBZ_rAN:
# a650A:f:Tiere_MÄSTEN:rHD_rAN:
# a650A:H:Tiere_MÄSTEN_angehen:rHD_rAN_fHF: a650A:f:VERFOLGUNG:rHD_rAN_fHF: a650A:H:VERFOLGUNG_entkommen:rHD_rAN_fHF: a650A:H:VEREINBARUNG_auflösen:rHD_rAN_fHF:
# a301:F:EINDRUCKSVOLLE_Handlung:rHD_fHD: a301:H:Auf_EINDRUCKSVOLLE_Handlung_reagieren:rHD_fHD: a301:H:Begleiter_gewinnen:rHD_fHD:
# a301:f:PROVOKATION:rAN_fHD: a301:h:Auf_PROVOKATION_reagieren:rAN_fHD:
# a301:h:Auftrag_zum_Kochen:fHD:
# a301:f:PROVOKATION:rHD_rAN: a301:H:Auf_PROVOKATION_reagieren:rHD_rAN:
# a301:H:Wegweisung_erpressen:rHD_rAN:
# a301:H:Sich_abseilen_LASSEN:rHD_fHD:
# a301:HF:Abraten_von_der_MISSION:rHD_rPP: a301:Hh:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rPP:
# a301:H:Zweikampf:rHD_rAN:
# a301:F:Krisenursachen_ergründen:rHD_rPP: a301:HF:Im_STICH_gelassen_zu_werden_beheben:rHD_rPP: a301:Hh:Auf_Warnung_im_STICH_gelassen_zu_werden_reagieren:rHD_rPP: a301:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rPP:
# a301:h:Jemanden_im_STICH_lassen:rHD_fHD:
# a301:h:Auf_ALTERNATIVEN_reagieren:rHD_fZM:
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB: a300:H:Unterkommen:rHD_rVB: a300:F:WASSERMANGEL_beheben:rHD_rVB: a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB:
# a300:H:Mut_zeigen:rHD_rAN:
# a300:H:VEREINBARUNG:rHD_rHP:
# a300:F:Heiraten:rHD_rHP: a300:h:Heiraten:rHD_rHP: a300:H:Um_Gegenleistung_bitten:rHD_rHP: a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP:
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST: a300:H:Sorge_um_Schutzbedürftige:rHD_rST:
# a300:F:Hilfeversprechen_erhalten:rHD_rHF: a300:HF:Beschaffung_der_AUSRÜSTUNG:rHD_rHF:
# a300:H:Beschaffung_der_AUSRÜSTUNG:rHD_rHP:
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF: a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF: a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF:
# a300:H:Hilfsquelle_greift_zurück:rHD_rHF: a300:H:BEHINDERUNG_beheben:rHD_rHF:
# a301:f:ZWANGSEHE_Drohung:rHD_rPP_fHD: a301:H:ZWANGSEHE_Drohung_beheben:rHD_rPP_fHD: a301:H:Bestrafung:rHD_rPP_fHD:
# a301:F:Heiraten:rHD_rPP:
# a531:h:SCHLAF:rHD_fVB: a531:h:NEUGIER_auslösen:rHD_fVB: a531:h:Auf_ausgelöste_NEUGIER_reagieren:rHD_fVB:
# a531:h:Auf_ausgelöste_NEUGIER_reagieren:rHD_rAN: a531:h:SCHLAF_unterbrechen:rHD_rAN: a531:H:Vorgang_deuten:rHD_rAN:
# a531:f:FEHLENDEN_Gegenstand_besorgen:rHD_rAN:
# a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rZO: a531:HF:Heiratszusage_erpressen:rHD_rZO:
# a531:H:Heiratszusage_erpressen:rHD_rZO:
# a531:h:Abtretung_der_Schönen_stehet_bevor:rHD_rZO:
# a531:f:Begehren_einer_Person_oder_eines_GEGENSTANDES:rZO_rAN:
# a531:F:Sich_einem_magischen_EINGRIFF_unterziehen:rZO_rAN: a531:HF:Magischen_EINGRIFF_vorbereiten:rZO_rAN:
# a531:H:Magischen_EINGRIFF_vorbereiten:rZO_rAN:
# a531:H:Heilkunst_VORTÄUSCHEN:rZO_rAN: a531:H:Auf_VORTÄUSCHEN_reagieren:rZO_rAN: a531:H:Sich_einem_magischen_EINGRIFF_unterziehen:rZO_rAN:
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD: a550:H:Sorge_um_Freikaufsbedürftige:rHD_fHD:
# a550:h:Vorgang_deuten:rHH_rZO_fHD: a550:h:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD: a550:H:Hochzeit_verschieben:rHH_rZO_fHD:
# a550:F:ENTMACHTUNG_beheben:rZO_rZO:
# a550:F:Bestrafung:rHD_fHD:
# a550:F:Heiraten:rHD_rZO:
# a545B:F:Einbrecher_begnadigen:rHD_rHF: a545B:H:Einbrecher_begnadigen:rHD_rHF: a545B:H:Hilfeversprechen_erhalten:rHD_rHF:
# a545B:H:Reichtum_VORTÄUSCHEN:rHF_rHP: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_rHP: a545B:H:NEUGIER_auslösen:rHF_rHP:
# a545B:H:Verlobung_arrangieren:rHF_rHP: a545B:H:Auf_ausgelöste_NEUGIER_reagieren:rHF_rHP: a545B:H:EINLADUNG_oder_Bestellung:rHF_rHP:
# a545B:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHF_rHP: a545B:HF:Verlust_VORTÄUSCHEN:rHF_rHP:
# a545B:H:Verlust_VORTÄUSCHEN:rHD_rHF_fHF: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHF_fHF: a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF_fHF: a545B:f:EINDRUCKSVOLLE_Handlung:rHD_rHF_fHF: a545B:h:Auf_EINDRUCKSVOLLE_Handlung_reagieren:rHD_rHF_fHF:
# a545B:H:Unzufriedenheit_VORTÄUSCHEN:rHD_rHF_fHF: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHF_fHF: a545B:F:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF_fHF: a545B:H:REITTIER_erhalten:rHD_rHF_fHF:
# a545B:f:EINDRUCKSVOLLE_Handlung:rHD_rHF_rHP: a545B:h:Auf_EINDRUCKSVOLLE_Handlung_reagieren:rHD_rHF_rHP: a545B:H:Unzufriedenheit_VORTÄUSCHEN:rHD_rHF_rHP: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHF_rHP:
# a545B:F:Auftrag_zum_VORTÄUSCHEN:rHF_rVB: a545B:H:Reichtum_VORTÄUSCHEN:rHF_rVB:
# a545B:H:Auftrag_zum_VORTÄUSCHEN:rVB_fHF: a545B:H:Auf_VORTÄUSCHEN_reagieren:rVB_fHF:
# a545B:H:Bedrohung_VORTÄUSCHEN:rHF_fST: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_fST: a545B:H:TÖTUNG:rHF_fST:
# a545B:f:Vertrauen_beweisen:rHD_rHF: a545B:H:Tod_VORTÄUSCHEN:rHD_rHF: a545B:h:Auf_VORTÄUSCHEN_reagieren:rHD_rHF: a545B:h:Vertrauen_beweisen:rHD_rHF:
# a545B:h:VORTÄUSCHEN_eingestehen:rHD_rHF: a545B:h:Wiedergutmachung_erzielen:rHD_rHF:
# a315A:h:STERBEN:rHH_fHH: a315A:h:Heiraten:rHH_fHH:
# a315A:h:Missgeburt:fHD:
# a315A:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:rHD:
# a315A:F:VERLUSTursache_beheben:rHD_fHD: a315A:H:Krisenursachen_ergründen:rHD_fHD: a315A:h:KANNIBALISMUS:rHD_fHD:
# a315A:h:Vorgang_deuten:rHD_rHH_fHH: a315A:HF:KANNIBALISMUS_beheben:rHD_rHH_fHH: a315A:Hh:Auf_Warnung_vor_KANNIBALISMUS_reagieren:rHD_rHH_fHH: a315A:h:KONTAKT_abbrechen:rHD_rHH_fHH:
# a321:H:Krisenursachen_ergründen:rHD_rRE_rVB: a321:h:BEHINDERUNG_durch_Verstümmelung:rHD_rRE_rVB: a321:hf:TABU_Land_nicht_betreten:rHD_rRE_rVB:
# a321:h:Auf_TABU_reagieren:rHD_rAN: a321:H:Zweikampf:rHD_rAN:
# a321:H:Kaiserschnitt:rHD_rHF: a321:H:Adoption:rHD_rHF:
# a315A:Hh:KONTAKT_abbrechen:rHD_rVB: a315A:H:Beschaffung_der_AUSRÜSTUNG:rHD_rVB:
# a315A:h:KANNIBALISMUS:rHD_rHF_fHD: a315A:Hh:FLUCHT:rHD_rHF_fHD: a315A:h:VERFOLGUNG:rHD_rHF_fHD: a315A:H:VERFOLGUNG_entkommen:rHD_rHF_fHD:
# a321:H:Ende:rHD_rHF_rVB:
# a1164:h:Unerträgliche_Ungeheuerlichkeit:rHD_rAN:
# a1164:F:Ungewünschtes_Wesen_beseitigen:rHD_rAN: a1164:H:Jemanden_im_STICH_lassen:rHD_rAN:
# a1862B:Hh:Sorge_um_Hilfsbedürftige:rHD_fAN: a1862B:F:VEREINBARUNG:rHD_fAN: a1862B:HF:Heldentat_VORTÄUSCHEN:rHD_fAN:
# a1862B:F:WASSERMANGEL_beheben:rHD_rHP: a1862B:F:VEREINBARUNG:rHD_rHP:
# a1862B:H:Heldentat_VORTÄUSCHEN:rHD_fAN: a1862B:H:VEREINBARUNG_einhalten:rHD_fAN: a1862B:H:Auf_VORTÄUSCHEN_reagieren:rHD_fAN: a1862B:hf:TABU_Limit_nicht_überziehen:rHD_fAN:
# a1862B:H:WASSERMANGEL_beheben:rHD_rHP_rPP: a1862B:H:VEREINBARUNG_einhalten:rHD_rHP_rPP: a1862B:H:Heiraten:rHD_rHP_rPP:
# a1164:F:WASSERMANGEL_beheben:rHD_rHP:
# a1164:h:Auf_TABU_reagieren:rHD_fAN: a1164:H:Gefahr_VORTÄUSCHEN:rHD_fAN: a1164:H:Auf_VORTÄUSCHEN_reagieren:rHD_fAN: a1164:H:WASSERMANGEL_beheben:rHD_fAN: a1164:H:Ende:rHD_fAN:
# a1633:h:STERBEN:zsa:
# a1633:f:Wahl_als_ABSURDITÄT:zs_zsa:
# a1633:h:Auf_ABSURDITÄT_reagieren:zs_zsa:
# a1633:h:Auf_ABSURDITÄT_reagieren:zsa:
# a1633:H:Auf_ABSURDITÄT_reagieren:zs:
# a1633:Hh:ABSURDITÄT_entgegentreten:zs_zsa: a1633:h:KONTAKT_abbrechen:zs_zsa:
# a1920H:f:Auftrag_zum_Unterhalten:zt_zsa: a1920H:h:Auftrag_zum_Unterhalten:zt_zsa: a1920H:h:VERSCHLINGEN:zt_zsa:
# a1920H:Hh:ABSURDITÄT_entgegentreten:zsa: a1920H:h:KONTAKT_abbrechen:zsa:
# a1920H:h:VERSCHLINGEN:zsa:
# a1920H:f:Auftrag_zum_Unterhalten:zs_zt: a1920H:F:VEREINBARUNG:zs_zt:
# a1960:F:ERZÄHLEN_beginnen:zs_zt: a1960:F:PROVOKATION:zs_zt: a1960:h:Auf_PROVOKATION_reagieren:zs_zt:
# a1960:F:PROVOKATION:zs_zt: a1960:h:Auf_PROVOKATION_reagieren:zs_zt:
# a1960:F:PROVOKATION:zs_zt: a1960:H:Auf_PROVOKATION_reagieren:zs_zt: a1960:H:ERZÄHLEN_beenden:zs_zt: a1960:H:VEREINBARUNG_einhalten:zs_zt:
# a1920H:H:VEREINBARUNG_einhalten:zs_zt_zsa: a1920H:H:VERSCHLINGEN_beheben:zs_zt_zsa:
# a1633:H:Ende:zs_zsa:
# a552:F:Ungewollte_Verlobung_akzeptieren:rHD_rHH_fHD: a552:h:STERBEN:rHD_rHH_fHD:
# a552:F:Ungewollte_Verlobung_akzeptieren:rST_fHD: a552:h:Ungewollte_Verlobung_akzeptieren:rST_fHD:
# a552:H:Ungewollte_Verlobung_akzeptieren:rHD_rST:
# a552:H:Heiraten:rHD_fHD:
# a552:h:ENTFÜHRUNG:rPP_rAN:
# a552:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD: a552:Hh:Auf_ALTERNATIVEN_reagieren:rHD_fHD:
# a552:F:Auf_Hilfsquelle_zurückgreifen:rHD_rVB: a552:H:Verstecken_als_Rettung:rHD_rVB:
# a552:H:Vermittlung:rST_rVB:
# a552:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST_rZM: a552:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST_rZM: a552:H:REITTIER_erhalten:rHD_rST_rZM:
# a552:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST_rZM: a552:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a552:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a552:Hh:Abraten_von_der_MISSION:rHD_rPP: a552:h:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rPP:
# a552:h:Zweikampf:rHD_rAN:
# a552:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM:
# a552:H:Zweikampf:rHD_rAN:
# a552:HF:Abraten_von_der_MISSION:rHD_rPP: a552:h:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rPP:
# a552:HF:Abraten_von_der_MISSION:rHD_rPP: a552:Hh:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rPP:
# a552:h:Zweikampf:rHD_rPP_rAN:
# a552:F:Sorge_um_Freikaufsbedürftige:rHD_rPP: a552:H:Sorge_um_Freikaufsbedürftige:rHD_rPP: a552:h:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rPP:
# a552:H:Ende:rHD_rPP:
# aEB279:#:#:#:
# a329:H:Sorge_um_Schutzbedürftige:rHD_rHF:
# a329:H:Sorge_um_Hilfsbedürftige:rHD_rHF:
# a329:F:Sorge_um_Schutzbedürftige:rHD_rHF: a329:H:Sorge_um_Schutzbedürftige:rHD_rHF: a329:H:Herbeirufendes_ZAUBERMITTEL_erhalten:rHD_rHF:
# a329:f:VEREINBARUNG:rHD_rHP_rPP:
# a329:F:Letzte_Gelegenheit_nützen:rHD_rHP_rPP:
# a329:H:VERSTECKWETTE:rHD_rHF_rPP:
# a329:H:VERSTECKWETTE:rHD_rHP_rPP:
# a327B:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_fHD: a327B:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_fHD:
# a327B:Hh:Unterkommen:rHD_rAN_fHD: a327B:h:Gastfreundlichkeit_VORTÄUSCHEN:rHD_rAN_fHD: a327B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN_fHD:
# a327B:f:KANNIBALISMUS:rHD_rAN:
# a327B:H:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN: a327B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN:
# a327B:H:IDENTITÄT_ändern:rHD_rAN_fHD:
# a327B:H:Schlaf_VORTÄUSCHEN:rHD_rAN_rAN: a327B:H:Personenschaden_anrichten:rHD_rAN_rAN:
# a327B:f:Auftrag_zum_Kochen:rHD_rAN:
# a327B:H:Auftrag_zum_Kochen:rHD_rAN: a327B:Hh:Jemanden_in_Kannibalismus_verwickeln:rHD_rAN:
# a327B:H:FLUCH:rHD_rAN: a327B:h:VERFOLGUNG:rHD_rAN: a327B:H:VERFOLGUNG_entkommen:rHD_rAN:
# a328:f:VEREINBARUNG:rHD_rHP: a328:f:SELTENEN_Gegenstand_besorgen:rHD_rHP:
# a328:H:Unruhe_VORTÄUSCHEN:rHD_rBZ_rZO: a328:H:Auf_VORTÄUSCHEN_reagieren:rHD_rBZ_rZO: a328:H:SELTENEN_Gegenstand_erfassen:rHD_rBZ_rZO: a328:H:FLUCHT:rHD_rBZ_rZO:
# a328:h:VERFOLGUNG:rHD_rBZ: a328:H:VERFOLGUNG_entkommen:rHD_rBZ:
# a328:H:SELTENEN_Gegenstand_besorgen:rHD_rHP: a328:f:SELTENEN_Gegenstand_besorgen:rHD_rHP:
# a328:H:SELTENEN_Gegenstand_besorgen:rHD_rHP: a328:f:NUTZTIER_besorgen:rHD_rHP:
# a328:H:Unruhe_VORTÄUSCHEN:rHD_rBZ_rZO: a328:H:Auf_VORTÄUSCHEN_reagieren:rHD_rBZ_rZO: a328:H:NUTZTIER_erfassen:rHD_rBZ_rZO: a328:H:FLUCHT:rHD_rBZ_rZO:
# a328:H:NUTZTIER_besorgen:rHD_rHP: a328:f:UNGEHEUER_herbeiholen:rHD_rHP: a328:F:VEREINBARUNG:rHD_rHP:
# a328:H:IDENTITÄT_ändern:rHD:
# a328:H:Geänderte_IDENTITÄT_VORTÄUSCHEN:rHD_rBZ: a328:F:Truhe_herstellen:rHD_rBZ: a328:H:Testnotwendigkeit_VORTÄUSCHEN:rHD_rBZ: a328:H:Auf_VORTÄUSCHEN_reagieren:rHD_rBZ: a328:H:UNGEHEUER_erfassen:rHD_rBZ:
# a328:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rBZ:
# a328:h:Loyalität_VORTÄUSCHEN:rHD_rBZ: a328:H:Auf_VORTÄUSCHEN_reagieren:rHD_rBZ:
# a328:H:UNGEHEUER_herbeiholen:rHD_rBZ_rHP: a328:H:VERSCHLINGEN:rHD_rBZ_rHP:
# a328:F:VERFOLGUNG:rHD_rBZ: a328:H:TÖTUNG:rHD_rBZ:
# a328:H:VERSCHLINGEN_beheben:rHD_rHP_rPP: a328:H:VEREINBARUNG_einhalten:rHD_rHP_rPP: a328:H:Heiraten:rHD_rHP_rPP:
# a812:h:WASSERMANGEL:rAN:
# a812:F:Abraten_von_der_MISSION:rHD_rVB: a812:h:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rVB:
# a812:f:Rätsel_lösen:rHD_rAN:
# a812:H:Rätsel_lösen:rHD_rAN: a812:H:WASSERMANGEL_beheben:rHD_rAN:
# aU:#:#:rHD_rHH:
# a531:h:Überrascht_werden_oder_geraten:rHD_rAN: a531:f:VEREINBARUNG:rHD_rAN:
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB: a531:hf:JUWELEN_besorgen:rAN_fVB:
# a531:f:JUWELEN_besorgen:rHD_rAN:
# a531:F:Sorge_um_Schutzbedürftige:rHD_rHF: a531:H:Sorge_um_Schutzbedürftige:rHD_rHF: a531:H:JUWELEN_erfassen:rHD_rHF:
# a531:H:JUWELEN_besorgen:rHD_rZO_rAN:
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB: a531:hf:HEILMITTEL_besorgen:rAN_fVB:
# a531:f:HEILMITTEL_besorgen:rHD_rAN:
# a531:F:Sorge_um_Schutzbedürftige:rHD_rHF: a531:H:Sorge_um_Schutzbedürftige:rHD_rHF: a531:HF:Zuschnappendes_Hindernis_überwinden:rHD_rHF:
# a531:H:HEILMITTEL_erfassen:rHD_rHF_rZO:
# a531:H:HEILMITTEL_besorgen:rHD_rAN:
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB: a531:hf:SCHÖNE_herbeiholen:rAN_fVB:
# a531:f:SCHÖNE_herbeiholen:rHD_rAN:
# a513A:F:EINDRUCKSVOLLE_Handlung:rHD_rHF: a513A:H:Auf_EINDRUCKSVOLLE_Handlung_reagieren:rHD_rHF: a513A:H:Begleiter_gewinnen:rHD_rHF:
# a516:HF:Abraten_von_der_MISSION:rHD_fZO: a516:Hh:Auf_ABRATEN_von_der_Mission_reagieren:rHD_fZO: a516:HF:Hartes_Großes_Mächtiges_mit_Weichem_Kleinem_Schwachem_bewältigen:rHD_fZO: a516:HF:Baumersteigen:rHD_fZO: a516:H:Universellen_ZAUBERMITTEL_erhalten:rHD_fZO:
# a516:f:Um_eine_Frau_WERBEN:rHD_rBZ: a516:f:VEREINBARUNG:rHD_rBZ:
# a516:f:Baumersteigen:rHD_rBZ: a516:H:Baumersteigen:rHD_rBZ:
# a513A:f:Gegen_ein_Tier_kämpfen:rHD_rBZ: a513A:H:Gegen_ein_Tier_kämpfen:rHD_rBZ:
# a513A:f:WETTLAUF:rHF_rBZ:
# a513A:H:WETTLAUF_angehen:rHF_rBZ_fHF: a513A:H:WETTLAUF:rHF_rBZ_fHF:
# a513A:f:Hitze_entkommen:rHF_rBZ: a513A:F:Hitze_entkommen:rHF_rBZ:
# a513A:F:VEREINBARUNG_auflösen:rHF_rBZ:
# a531:H:Auf_dem_Heimweg:rHD_rAN:
# aU:H:Ende:rHD_rHH:
# a611:H:Verlobung_arrangieren:rHH_fHP:
# a611:h:STERBEN:rHH:
# a611:h:ZWANGSEHE_Drohung:rPP_fHD_fHP:
# a611:F:PROVOKATION:rHD_rVB: a611:H:Auf_PROVOKATION_reagieren:rHD_rVB: a611:H:NEUGIER_auslösen:rHD_rVB:
# a611:H:Auf_ausgelöste_NEUGIER_reagieren:rHD_rHH: a611:H:Krisenursachen_ergründen:rHD_rHH: a611:F:ZWANGSEHE_Drohung_beheben:rHD_rHH:
# a611:H:Wissen_VORTÄUSCHEN:rHD_rST_rZM: a611:H:Auf_VORTÄUSCHEN_reagieren:rHD_rST_rZM: a611:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a571:F:ZWANGSEHE_Drohung_beheben:rHD_rVB:
# a571:H:PARALYSIERUNG:rHD_rZM_fHD:
# a571:H:Loyalität_VORTÄUSCHEN:rHD_fHP:
# a571:H:PARALYSIERUNG:rHD_rZM_fHF:
# a571:Hh:VEREINBARUNG:rHD_rZM_fHP: a571:H:PARALYSIERUNG_beheben:rHD_rZM_fHP: a571:H:VEREINBARUNG_einhalten:rHD_rZM_fHP: a571:H:ZWANGSEHE_Drohung_beheben:rHD_rZM_fHP: a571:H:Bestrafung:rHD_rZM_fHP:
# a611:H:Heiraten:rHD_rPP:
# a2031C:#:#:#:
# a465:F:Schicksalsbestimmender_Weisung_folgen:rHD:
# a465:F:Ungewollte_Verlobung_akzeptieren:rHD_rPP:
# a465:H:Überraschende_positive_Wendung:rHD_rPP: a465:H:Änderung_der_EXISTENZFORM:rHD_rPP:
# a465:H:SONSTIGES_herstellen:rHD_rPP: a465:F:SONSTIGES_verkaufen:rHD_rPP:
# a465:H:SONSTIGES_verkaufen:rHD_fVB:
# a465:H:SONSTIGES_verkaufen:rHD_fAN:
# a465:h:NEUGIER_auslösen:rHD_fVB_fAN:
# a465:h:Auf_ausgelöste_NEUGIER_reagieren:rHD_fAN: a465:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fAN:
# a465:F:SELTENEN_Gegenstand_besorgen:rHD_fVB_fAN:
# a465:F:Auf_Hilfsquelle_zurückgreifen:rHD_rZM_rPP: a465:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rZM_rPP: a465:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rZM_rPP:
# a465:H:Begleiter_gewinnen:rHD_rHF_rHP:
# a465:H:Sich_oder_andere_tragen_LASSEN:rHD_rHF:
# a465:H:SELTENEN_Gegenstand_erfassen:rHF_rBZ_rZO:
# a465:H:TÖTUNG:rHD_rHF_rBZ:
# a465:H:MASSENBEDROHUNG_beheben:rHD_rHF_rVB:
# a465:H:Auf_dem_Heimweg:rHD_rHF:
# a465:H:SELTENEN_Gegenstand_besorgen:rHD_fAN: a465:H:VEREINBARUNG_auflösen:rHD_fAN:
# a1640:h:Unerträgliche_Faulheit:zs_zsa:
# a1640:f:VERLOCKUNG:zs_zsa: a1640:h:Auf_VERLOCKUNG_reagieren:zs_zsa: a1640:h:VERTREIBUNG:zs_zsa: a1640:H:Beschaffung_der_AUSRÜSTUNG:zs_zsa:
# a1640:H:Kraft_VORTÄUSCHEN:zs_zt: a1640:H:Auf_VORTÄUSCHEN_reagieren:zs_zt:
# a1640:H:Sich_oder_andere_tragen_LASSEN:zs_zt: a1640:H:Kraft_VORTÄUSCHEN:zs_zt: a1640:h:Auf_VORTÄUSCHEN_reagieren:zs_zt:
# a1640:H:Auf_EINLADUNG_oder_Bestellung_reagieren:zs_zt: a1640:F:SONSTIGES_beheben:zs_zt: a1640:Hh:SONSTIGES_Beheben_angehen:zs_zt: a1640:H:Krankheit_VORTÄUSCHEN:zs_zt: a1640:H:Auf_VORTÄUSCHEN_reagieren:zs_zt:
# a1640:F:SONSTIGES_beheben:zs_zt: a1640:Hh:SONSTIGES_Beheben_angehen:zs_zt: a1640:H:Kraft_VORTÄUSCHEN:zs_zt: a1640:H:Auf_VORTÄUSCHEN_reagieren:zs_zt:
# a1640:H:Bedrohung_VORTÄUSCHEN:zs_zt: a1640:H:Auf_VORTÄUSCHEN_reagieren:zs_zt: a1640:Hh:FLUCHT:zs_zt:
# a1640:H:ANEIGNUNG:zs:
# a1640:F:Überrascht_werden_oder_geraten:zt_zf: a1640:H:Vorgang_deuten:zt_zf: a1640:F:Auf_Hilfsquelle_zurückgreifen:zt_zf:
# a1640:H:Bedrohung_VORTÄUSCHEN:zs_zt_zf: a1640:H:Auf_VORTÄUSCHEN_reagieren:zs_zt_zf: a1640:H:Bestrafung:zs_zt_zf:
# a1640:H:Ende:zs:
# a313:h:Kinderlosigkeit:rHH:
# a313:Hh:VEREINBARUNG:rHH_rZM_fST: a313:H:Wundermittel_zur_EMPFÄNGNIS_erhalten:rHH_rZM_fST:
# a313:H:Wunderbare_EMPFÄNGNIS:rHH_rHH:
# a313:H:Zur_Welt_kommen:rHD:
# a313:H:VEREINBARUNG_einhalten:rHD_rHH:
# a400:HF:Heiratszusage_erpressen:rHD_rST:
# a400:H:Heiratszusage_erpressen:rHD_rPP:
# a313:f:VEREINBARUNG:rHD_fHP:
# a313:f:SONSTIGES_beheben:rHD_fHP:
# a313:F:Auf_Hilfsquelle_zurückgreifen:rHD_rPP: a313:H:SONSTIGES_beheben:rHD_rPP:
# a313:F:Bauwerk_errichten:rHD_fHP:
# a313:F:Auf_Hilfsquelle_zurückgreifen:rHD_rPP: a313:H:Bauwerk_errichten:rHD_rPP:
# a313:F:REITTIER_besorgen:rHD_fHP:
# a313:HF:Auf_Hilfsquelle_zurückgreifen:rHD_rPP: a313:H:Hilfeversprechen_erhalten:rHD_rPP: a313:HF:Richtiges_auswählen:rHD_rPP: a313:F:GEHEIMSPRACHE_beibringen:rHD_rPP:
# a313:H:REITTIER_besorgen:rHD_fHP: a313:F:VEREINBARUNG_einhalten:rHD_fHP: a313:F:Ungewollte_Verlobung_akzeptieren:rHD_fHP: a313:Hh:Ungewollte_Verlobung_akzeptieren:rHD_fHP: a313:f:Richtiges_auswählen:rHD_fHP:
# a313:H:Auf_GEHEIMSPRACHE_reagieren:rHD_rPP_fHP: a313:H:Richtiges_auswählen:rHD_rPP_fHP:
# a313:H:Gespräche_belauschen:rPP_fHP: a313:f:Ungewünschtes_Wesen_beseitigen:rPP_fHP:
# a313:H:FLUCHT_vorbereiten:rHD_rPP:
# a313:H:VERFOLGUNG_stören:fHP:
# a313:Hh:FLUCHT:rHD_rPP_fHP: a313:H:Änderung_der_EXISTENZFORM:rHD_rPP_fHP: a313:H:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rPP_fHP: a313:H:Auf_VORTÄUSCHEN_reagieren:rHD_rPP_fHP:
# a313:h:Vorgang_deuten:fHP_fHP: a313:h:VERFOLGUNG:fHP_fHP:
# a313:Hh:Änderung_der_EXISTENZFORM:rHD_rPP: a313:h:KONTAKT_abbrechen:rHD_rPP:
# a313:h:Änderung_der_EXISTENZFORM_stören:rPP_fHP:
# a313:h:Missachtung_der_LIEBE:rHD_fPP: a313:h:Heiraten:rHD_fPP:
# a313:H:Geänderte_EXISTENZFORM_beheben:rVB_rPP:
# a313:H:SONSTIGES_verkaufen:rVB_rPP: a313:H:NEUGIER_auslösen:rVB_rPP:
# a313:H:Auf_ausgelöste_NEUGIER_reagieren:rHD_rPP: a313:H:KONTAKT_wiederherstellen:rHD_rPP: a313:H:Missachtung_der_LIEBE_beheben:rHD_rPP: a313:H:Ende:rHD_rPP:
# a715:H:Mut_zeigen:rHD_fVB:
# a715:h:ANGST_auslösen:rHD_rAN_fVB: a715:f:Gemenge_entkommen:rHD_rAN_fVB:
# a715:h:ANGST_auslösen:rHD_rAN_fVB: a715:f:Hitze_entkommen:rHD_rAN_fVB:
# a715:H:Ende:rHD:
# a314:f:VEREINBARUNG:rHD_rHP:
# a314:f:Krieg_führen:rHD: a314:H:IDENTITÄT_ändern:rHD: a314:H:Krieg_führen:rHD:
# a314:Hh:KONTAKT_abbrechen:rHD_rHP: a314:H:NEUGIER_auslösen:rHD_rHP:
# a314:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rHP: a314:H:Held_erkennen:rHD_rHP: a314:F:Angebot_KÖNIG_zu_werden:rHD_rHP:
# a314:H:Heiraten:rHD_rHP_rPP:
# a449:F:Tapferkeit_beweisen:rHD_rPP:
# a321:h:Unterkommen:rHD_rVB: a321:F:WETTKAMPF:rHD_rVB:
# a321:H:WETTKAMPF:rHD_rAN:
# a321:H:Rache_nehmen:rHD_rVB: a321:H:Krisenursachen_ergründen:rHD_rVB:
# a321:Hh:WETTKAMPF:rHD_rAN:
# a321:F:WETTKAMPF:rHD_rAN: a321:Hh:WETTKAMPF:rHD_rAN: a321:HF:WAFFE_oder_ZAUBERMITTEL_erhalten:rHD_rAN:
# a321:H:WAFFE_oder_ZAUBERMITTEL_erhalten:rHD_rZM: a321:H:FEHLENDEN_Gegenstand_erfassen:rHD_rZM:
# a321:h:Loyalität_VORTÄUSCHEN:rHD_rAN: a321:f:VERGIFTUNG:rHD_rAN: a321:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rAN: a321:H:TÖTUNG:rHD_rAN:
# a321:HF:VERGIFTUNG_beheben:rHD_rPP:
# a321:H:Auf_VORTÄUSCHEN_reagieren:rHD: a321:H:VERGIFTUNG_beheben:rHD:
# a321:H:FEHLENDEN_Gegenstand_besorgen:rHD_rVB: a321:H:BEHINDERUNG_beheben:rHD_rVB:
# a327B:f:KANNIBALISMUS:rHD_rAN: a327B:H:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN: a327B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN:
# a327B:H:IDENTITÄT_ändern:rHD_rAN_rAN: a327B:H:Schlaf_VORTÄUSCHEN:rHD_rAN_rAN: a327B:H:Personenschaden_anrichten:rHD_rAN_rAN:
# a327B:f:Jemanden_in_Kannibalismus_verwickeln:rHD_rAN: a327B:H:FLUCHT:rHD_rAN: a327B:H:VERFOLGUNG:rHD_rAN: a327B:H:VERFOLGUNG_entkommen:rHD_rAN:
# a328:H:Unruhe_VORTÄUSCHEN:rHD_rBZ_rZO: a328:H:Auf_VORTÄUSCHEN_reagieren:rHD_rBZ_rZO: a328:H:SELTENEN_Gegenstand_erfassen:rHD_rBZ_rZO:
# a328:H:FLUCHT:rHD_rBZ: a328:h:VERFOLGUNG:rHD_rBZ: a328:H:VERFOLGUNG_entkommen:rHD_rBZ:
# a328:H:Unruhe_VORTÄUSCHEN:rHD_rBZ_rZO: a328:H:Auf_VORTÄUSCHEN_reagieren:rHD_rBZ_rZO: a328:H:NUTZTIER_erfassen:rHD_rBZ_rZO:
# a328:H:UNGEHEUER_herbeiholen:rHD_rBZ_rHP: a328:h:VERSCHLINGEN:rHD_rBZ_rHP:
# a328:f:VERFOLGUNG:rHD_rBZ: a328:H:TÖTUNG:rHD_rBZ:
# a1545A:h:STERBEN:rHD_fHD:
# a1545A:H:Erbschaft_teilen:rHD_fHD:
# a1545A:F:SONSTIGES_beheben:rHP:
# a1545A:F:Um_einen_Auftrag_WERBEN:fHD:
# a1545A:F:Rat_mit_ALTERNATIVEN:rHF_fHD: a1545A:h:Auf_ALTERNATIVEN_reagieren:rHF_fHD:
# a1545A:h:Surrogat_unterschieben:rHP_fHD_fPP: a1545A:Hh:SONSTIGES_Beheben_angehen:rHP_fHD_fPP:
# a1545A:Hh:Vorgang_deuten:rHD_fHD:
# a1545A:F:Um_einen_Auftrag_WERBEN:rHD:
# a1545A:F:Rat_mit_ALTERNATIVEN:rHD_rHF: a1545A:H:Auf_ALTERNATIVEN_reagieren:rHD_rHF: a1545A:H:Hilfeversprechen_erhalten:rHD_rHF:
# a1545A:H:SONSTIGES_Beheben_angehen:rHD_rHF: a1545A:H:Tiere_gegeneinander_kämpfen_lassen:rHD_rHF: a1545A:H:NEUGIER_auslösen:rHD_rHF:
# a1545A:H:Auf_ausgelöste_NEUGIER_reagieren:rHD_rHF_rPP:
# a1545A:H:Unterkommen:rHD_rHF:
# a1545A:H:SONSTIGES_Beheben_angehen:rHD_rHF: a1545A:H:Unwissenheit_VORTÄUSCHEN:rHD_rHF:
# a1545A:H:NEUGIER_auslösen:rHD_rHF_rPP: a1545A:H:Auf_ausgelöste_NEUGIER_reagieren:rHD_rHF_rPP: a1545A:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHF_rPP:
# a1545A:H:SONSTIGES_Beheben_angehen:rHD_rHD_rPP: a1545A:H:Unwissenheit_VORTÄUSCHEN:rHD_rHD_rPP: a1545A:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHD_rPP:
# a1545A:H:Beiwohnung_mit_der_Schönen:rHD_rPP: a1545A:H:SONSTIGES_beheben:rHD_rPP:
# a1545A:H:Sonstiges_VORTÄUSCHEN:rHD_rHF_rPP: a1545A:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHF_rPP:
# a1545A:H:Ende:rHD_rPP:
# a706:h:STERBEN:rHD_rHH:
# a706:h:Verlobung_arrangieren:rHH_fHH: a706:h:Heiraten:rHH_fHH:
# a706:h:VERLEUMDUNG_bei_Schädigung:rHD_rHH_fHH: a706:H:VERLEUMDUNG_beheben:rHD_rHH_fHH:
# a706:h:Auf_Aufforderung_zu_KINDERMORD_reagieren:rHD_rHH_fHH: a706:h:VERLEUMDUNG_bei_Kindstötung:rHD_rHH_fHH:
# a706:h:VERTREIBUNG:rHD_rHH:
# a706:H:Überrascht_werden_oder_geraten:rHD_rPP: a706:F:Liebe_wird_ausgelöst:rHD_rPP: a706:H:Heiraten:rHD_rPP:
# a706:Hh:KONTAKT_abbrechen:rHD_rPP:
# a706:F:BOTSCHAFTEN_versenden:rVB_rHP_rPP: a706:H:BOTSCHAFTEN_versenden:rVB_rHP_rPP:
# a706:h:BOTSCHAFTEN_verfälschen:rVB_fHH:
# a706:H:BOTSCHAFTEN_versenden:rVB_rPP:
# a706:h:Auf_BOTSCHAFTEN_reagieren:rHD_rHP: a706:h:VERTREIBUNG:rHD_rHP:
# a706:F:Zusammenbringen_aller_Handlungsträger:rHD_rHH_rPP:
# a706:F:ERZÄHLEN_beginnen:rHD: a706:H:Vorgang_deuten:rHD: a706:H:VERLEUMDUNG_beheben:rHD: a706:H:ERZÄHLEN_beenden:rHD:
# a706:H:Bestrafung:rHH_fHH:
# a706:H:Familienzusammenführung:rHD_rPP:
# a812:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:zs_zt: a812:f:Rätsel_lösen:zs_zt:
# a812:F:Auf_Hilfsquelle_zurückgreifen:zs_zsa:
# a812:H:Gutes_Benehmen:zs_zf_zsa: a812:H:Hilfeversprechen_erhalten:zs_zf_zsa:
# a812:H:Rätsel_lösen:zt_zsa: a812:H:Ende:zt_zsa:
# a1704:#:#:#:
# aTMJ1392_1:#:#:#:
# a1545A:h:STERBEN:rHD_fHD: a1545A:H:Erbschaft_teilen:rHD_fHD:
# a1545A:H:Beschaffung_der_AUSRÜSTUNG:rHD_rHF: a1545A:H:SONSTIGES_Beheben_angehen:rHD_rHF: a1545A:Hh:Tiere_gegeneinander_kämpfen_lassen:rHD_rHF: a1545A:H:NEUGIER_auslösen:rHD_rHF: a1545A:H:Auf_ausgelöste_NEUGIER_reagieren:rHD_rHF:
# a1545A:H:Unterkommen:rHD_rHF: a1545A:H:SONSTIGES_Beheben_angehen:rHD_rHF: a1545A:H:Unwissenheit_VORTÄUSCHEN:rHD_rHF:
# a1545A:H:SONSTIGES_Beheben_angehen:rHD_rHF_rPP: a1545A:H:Unwissenheit_VORTÄUSCHEN:rHD_rHF_rPP: a1545A:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHF_rPP: a1545A:H:Beiwohnung_mit_der_Schönen:rHD_rHF_rPP: a1545A:H:SONSTIGES_beheben:rHD_rHF_rPP:
# a1545A:H:Sonstiges_VORTÄUSCHEN:rHD_rPP: a1545A:H:Auf_VORTÄUSCHEN_reagieren:rHD_rPP: a1545A:H:Ende:rHD_rPP:
# a881:#:#:#:
# a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:fPP:
# a881:f:Bösen_einstellen:fVB_fPP:
# a881:h:Ausplaudern:rHH_fVB:
# a881:h:BEHINDERUNG_durch_Verstümmelung:rHD_fPP:
# a881:f:FLUCHT_vorbereiten:rHD_fPP: a881:h:FLUCHT:rHD_fPP:
# a881:H:BEHINDERUNG_beheben:rHD_fPP: a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP: a881:H:Loyalität_VORTÄUSCHEN:rHD_fPP: a881:H:Auf_VORTÄUSCHEN_reagieren:rHD_fPP: a881:H:FLUCHT:rHD_fPP:
# a881:f:Überrascht_werden_oder_geraten:rHD_fVB: a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fVB: a881:H:Loyalität_VORTÄUSCHEN:rHD_fVB: a881:H:Auf_VORTÄUSCHEN_reagieren:rHD_fVB: a881:H:FLUCHT:rHD_fVB:
# a881A:H:Unterkommen:rHD_rVB: a881A:F:An_Königswahl_teilnehmen:rHD_rVB: a881A:H:IDENTITÄT_ändern:rHD_rVB:
# a881A:H:Intensive_Erkundungsaktion:rHD:
# a881A:H:Intensive_Erkundungsaktion:rHD: a881A:H:Zusammenbringen_aller_Handlungsträger:rHD:
# a881A:F:Intensive_Erkundungsaktion:rHD_rPP: a881A:F:ERZÄHLEN_beginnen:rHD_rPP: a881A:H:ERZÄHLEN_beenden:rHD_rPP:
# a881A:F:Intensive_Erkundungsaktion:rHD_fPP: a881A:F:ERZÄHLEN_beginnen:rHD_fPP: a881A:H:ERZÄHLEN_beenden:rHD_fPP:
# a881A:F:Intensive_Erkundungsaktion:rHD_fVB: a881A:F:ERZÄHLEN_beginnen:rHD_fVB: a881A:H:ERZÄHLEN_beenden:rHD_fVB:
# a881A:H:Bestrafung:rHD_fPP:
# a881A:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP: a881A:H:Familienzusammenführung:rHD_rPP: a881A:H:Ende:rHD_rPP:
# a706:h:Heiraten:rHD_rHH_fHH:
# a706:h:KONTAKT_abbrechen:rHD_rPP:
# a706:F:Zusammenbringen_aller_Handlungsträger:rHD_rHH_rPP: a706:F:ERZÄHLEN_beginnen:rHD_rHH_rPP: a706:H:Vorgang_deuten:rHD_rHH_rPP: a706:H:VERLEUMDUNG_beheben:rHD_rHH_rPP: a706:H:ERZÄHLEN_beenden:rHD_rHH_rPP:
# a922:F:BESTECHUNG:zs_zsa: a922:H:Auf_BESTECHUNG_reagieren:zs_zsa:
# ...
# aE2:h:Begegnung:#: aE2:f:GIER_und_Neid_auslösen:#:
# aE2:f:SCHÖNE_herbeiholen:#:
# aE2:h:Heldentat_VORTÄUSCHEN:#: aE2:Hh:MARKIERUNGEN_vorlegen:#: aE2:h:Sich_ZURÜCKZIEHEN:#:
# aE2:H:Unterkommen:#: aE2:F:Tapferkeit_beweisen:#: aE2:HF:Abraten_von_der_MISSION:#: aE2:Hh:Auf_ABRATEN_von_der_Mission_reagieren:#:
# aE2:HF:Wegweisung_erhalten:rHD_rVB:
# aE2:H:Heiraten:#:
# aE2:f:FALLE_stellen:#:
# aE2:h:FALLE_stellen:#: aE2:h:In_die_FALLE_gehen:#: aE2:h:FREIHEITSBERAUBUNG:#:
# aE2:h:VERBANNUNG:#:
# a470B:h:KRANKHEIT:rHD: a470B:h:STERBEN:rHD:
# a470B:F:Krisenursachen_ergründen:rHD_rHH: a470B:f:STERBEN:rHD_rHH:
# a470B:F:STERBEN_beheben:rHD_rHF: a470B:Hh:STERBEN_Beheben_angehen:rHD_rHF: a470B:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHF:
# a470B:Hh:STERBEN_Beheben_angehen:rHD_rHF: a470B:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHF:
# a470B:H:STERBEN_beheben:rHD_rPP: a470B:H:Heiraten:rHD_rPP: a470B:H:Sich_niederlassen:rHD_rPP: a470B:H:Geburt_des_NACHKOMMENs:rHD_rPP:
# a470B:h:KONTAKT_abbrechen:rHD_rPP: a470B:hf:TABU_Sonstiges:rHD_rPP:
# a470B:f:Auf_Hilfsquelle_zurückgreifen:rHD_rHF: a470B:h:Auf_TABU_reagieren:rHD_rHF:
# a470B:h:KONTAKT_wiederherstellen:rHD_rST: a470B:f:Intensive_Erkundungsaktion:rHD_rST:
# a470B:h:Auf_TABU_reagieren:rHD: a470B:f:STERBEN:rHD:
# a470B:h:STERBEN_beheben:rHD:
# a519:H:Personen_mit_der_BEHINDERUNG_gehen_einen_Bund_ein:rHD_rHF: a519:H:Sich_niederlassen:rHD_rHF:
# a519:H:Freundschaft_schließen:rHD_rHF_rPP:
# a519:h:Auf_TABU_reagieren:rPP:
# a519:F:Folgen_eines_TABUbruches_rückgängig_machen:rPP_rAN: a519:f:MARKIERUNGEN_anbringen:rPP_rAN: a519:Hh:Folgen_eines_TABUbruches_rückgängig_machen:rPP_rAN: a519:h:MARKIERUNGEN_erkennen:rPP_rAN:
# a519:h:Sich_auf_Eindringlinge_einlassen:rPP_rAN: a519:h:VAMPIRISMUS:rPP_rAN:
# a519:H:Krisenursachen_ergründen:rHD_rHF_rPP: a519:F:Im_Verborgenen_lauern:rHD_rHF_rPP:
# a519:h:Zweikampf:rHF_rAN: a519:h:VAMPIRISMUS:rHF_rAN:
# a519:h:Vorgang_deuten:rHF_rPP: a519:F:Im_Verborgenen_lauern:rHF_rPP:
# a519:h:Vorgang_deuten:rHD_rPP: a519:F:Im_Verborgenen_lauern:rHD_rPP:
# a519:H:Zweikampf:rHD_rAN:
# a519:H:VERSCHLINGEN:rHD_rHF_rAN: a519:H:VERSCHLINGEN_beheben:rHD_rHF_rAN: a519:H:BEHINDERUNG_beheben:rHD_rHF_rAN:
# a519:h:VERSCHLINGEN:rHD_rHF_rAN: a519:H:VERSCHLINGEN_beheben:rHD_rHF_rAN: a519:H:BEHINDERUNG_beheben:rHD_rHF_rAN:
# a519:H:TÖTUNG:rHD_rHF_rAN:
# a519:H:Ende:rHD_rHF_rAN:
# a1960M:#:#:#:
# a881A:H:Verlobung_arrangieren:rHH_rHH:
# a881A:h:STERBEN:rHH: a881A:H:Hochzeit_verschieben:rHH:
# a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_rAN:
# a881A:f:Ungewollte_Verlobung_akzeptieren:rHH_rAN: a881A:h:Ungewollte_Verlobung_akzeptieren:rHH_rAN:
# a881A:h:Ungewollte_Verlobung_akzeptieren:rHD_rHH:
# a881A:H:FLUCHT_vorbereiten:rHD_rPP:
# a881A:H:Krankheit_VORTÄUSCHEN:rHD_rAN: a881A:H:Auf_VORTÄUSCHEN_reagieren:rHD_rAN:
# a881A:Hh:FLUCHT:rHD_rPP:
# a881A:H:IDENTITÄT_ändern:rHD_rPP:
# a881A:Hh:KONTAKT_abbrechen:rHD_rPP_fPP:
# a881A:h:ENTFÜHRUNG:rHD_fPP:
# a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP: a881A:H:Loyalität_VORTÄUSCHEN:rHD_fPP: a881A:H:Auf_VORTÄUSCHEN_reagieren:rHD_fPP:
# a881A:H:FLUCHT:rHD:
# a881A:h:SCHLAF:rHD:
# a881A:h:Überrascht_werden_oder_geraten:rHD_fPP: a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP: a881A:H:Loyalität_VORTÄUSCHEN:rHD_fPP: a881A:H:Auf_VORTÄUSCHEN_reagieren:rHD_fPP:
# a881A:Hh:FLUCHT:rHD_fHF:
# a881A:h:Überrascht_werden_oder_geraten:rHD_fPP:
# a881A:H:Loyalität_VORTÄUSCHEN:rHD_fPP: a881A:H:Zum_Schlafen_bringen:rHD_fPP: a881A:H:IDENTITÄT_ändern:rHD_fPP: a881A:F:MARKIERUNGEN_anbringen:rHD_fPP:
# a881A:F:An_Königswahl_teilnehmen:rHD:
# a881A:F:Intensive_Erkundungsaktion:rHD_fPP:
# a881A:#:#:#:
# a881A:H:Intensive_Erkundungsaktion:rAN: a881A:H:Zusammenbringen_aller_Handlungsträger:rAN:
# a881A:H:Intensive_Erkundungsaktion:rPP: a881A:H:Zusammenbringen_aller_Handlungsträger:rPP:
# a881A:H:Intensive_Erkundungsaktion:fPP: a881A:H:Zusammenbringen_aller_Handlungsträger:fPP:
# a881A:H:Intensive_Erkundungsaktion:rHD_rAN: a881A:F:ERZÄHLEN_beginnen:rHD_rAN: a881A:H:ERZÄHLEN_beenden:rHD_rAN:
# a881A:H:Intensive_Erkundungsaktion:rHD_rPP: a881A:F:ERZÄHLEN_beginnen:rHD_rPP: a881A:H:ERZÄHLEN_beenden:rHD_rPP:
# a881A:H:Intensive_Erkundungsaktion:rHD_fPP: a881A:F:ERZÄHLEN_beginnen:rHD_fPP: a881A:H:ERZÄHLEN_beenden:rHD_fPP:
# a881A:H:Bestrafung:rHD_rAN:
# a881A:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP: a881A:H:Familienzusammenführung:rHD_rPP:
# a945:F:WETTE_zwischen_Glück_und_Verstand:zv_zv:
# a507:H:Begegnung:rHD_rPP: a507:F:Liebe_wird_ausgelöst:rHD_rPP: a507:h:KONTAKT_abbrechen:rHD_rPP:
# a507:h:KRANKHEIT:rHD:
# a507:F:Krisenursachen_ergründen:rHD_rHH: a507:h:Krisenursachen_ergründen:rHD_rHH:
# a507:H:Hilfsquelle_greift_zurück:rHD_rHF: a507:H:Krisenursachen_ergründen:rHD_rHF: a507:F:FERNLIEBE_beheben:rHD_rHF:
# a507:F:Beschaffung_der_AUSRÜSTUNG:rHH_rHF: a507:H:Beschaffung_der_AUSRÜSTUNG:rHH_rHF:
# a507:Hh:Verlobung_arrangieren:rHH_rHP: a507:h:BEHINDERUNG_durch_einen_Fluch:rHH_rHP: a507:Ff:VEREINBARUNG:rHH_rHP:
# a507:H:FERNLIEBE_beheben:rHH_rHP: a507:H:KRANKHEIT_beheben:rHH_rHP: a507:Hh:Heiraten:rHH_rHP:
# a507:Hh:VEREINBARUNG_einhalten:rHD: a507:F:FLUCH_beheben:rHD: a507:F:GEHEIMNIS_aufklären:rHD:
# a507:F:Gutes_Benehmen:rHD_rST_rZM: a507:H:Gutes_Benehmen:rHD_rST_rZM: a507:H:Tarnung_gewährendes_ZAUBERMITTEL_erhalten:rHD_rST_rZM: a507:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rST_rZM:
# a507:H:GEHEIMNIS_Aufklären_angehen:rHD_rZM_rPP: a507:H:IDENTITÄT_ändern:rHD_rZM_rPP: a507:F:Heimlich_beobachten:rHD_rZM_rPP:
# a507:H:IDENTITÄT_ändern:rHD_rPP: a507:H:NEUGIER_auslösen:rHD_rPP:
# a507:Hh:Auf_ausgelöste_NEUGIER_reagieren:rHP_rPP:
# a507:H:IDENTITÄT_ändern:rHD_rZM_rPP: a507:H:Heimlich_beobachten:rHD_rZM_rPP: a507:H:Komplikationsfreier_Flug:rHD_rZM_rPP:
# a507:F:Heimlich_beobachten:rHD_rPP_rAN: a507:f:DEMÜTIGUNG:rHD_rPP_rAN:
# a507:H:Komplikationsfreier_Flug:rHD_rPP:
# a507:H:Heimlich_beobachten:rHD_rPP_rAN: a507:H:DEMÜTIGUNG_beheben:rHD_rPP_rAN:
# a507:H:Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP_rAN: a507:H:Um_eine_Frau_WERBEN:rHD_rPP_rAN: a507:f:Richtiges_auswählen:rHD_rPP_rAN: a507:H:Richtiges_auswählen:rHD_rPP_rAN: a507:H:FLUCH_beheben:rHD_rPP_rAN:
# a507:H:Ende:rHD_rPP:
# a471:h:STERBEN:rHH:
# a471:f:Jenseitswanderung_unternehmen:rZO_fHD: a471:f:FEHLENDEN_Gegenstand_besorgen:rZO_fHD:
# a471:h:Jenseitswanderung_unternehmen:fHD_fHH:
# a471:F:Um_einen_Auftrag_WERBEN:rHD_fHH:
# a471:F:Lösungsweg_für_FÄHRMANN_deuten:rHD_rZO_rAN:
# a471:F:Folge_von_Betrügerei_deuten:rHD_rZO:
# a471:F:Ursache_des_unstillbaren_Hungers_deuten:rHD_rZO:
# a471:F:Ursache_des_unstillbaren_Dursts_deuten:rHD_rZO:
# a471:F:Folge_von_Arbeitsscheu_deuten:rHD_rZO:
# a471:H:Jenseitswanderung_unternehmen:rHD_rHH:
# a471:H:Lösungsweg_für_FÄHRMANN_deuten:rHD_rHH_rZO:
# a471:H:Folge_von_Betrügerei_deuten:rHD_rHH_rZO:
# a471:H:Ursache_des_unstillbaren_Hungers_deuten:rHD_rHH_rZO:
# a471:H:Ursache_des_unstillbaren_Dursts_deuten:rHD_rHH_rZO:
# a471:H:Folge_von_Arbeitsscheu_deuten:rHD_rHH_rZO:
# a471:H:FEHLENDEN_Gegenstand_erfassen:rHD_rHH_rZO:
# a471:H:FEHLENDEN_Gegenstand_besorgen:rHD_fHD_fHH:
# a471:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rZM_fHD_fHH: a471:h:Bestrafung:rZM_fHD_fHH:
# a471:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a471:H:Notwendiges_auf_wunderbare_Weise_besorgen:rHD_rZM: a471:H:Heiraten:rHD_rZM: a471:H:Ende:rHD_rZM:
# a480:h:STERBEN:rHH:
# a480:h:Heiraten:rHH_fHH: a480:f:Ungewünschtes_Wesen_beseitigen:rHH_fHH:
# a471:H:Beschaffung_der_AUSRÜSTUNG:rHD_rHD:
# a471:H:Gutes_Benehmen:rHD_rST: a471:HF:Abraten_von_der_MISSION:rHD_rST: a471:h:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rST:
# a471:Hh:Sich_niederlassen:rHD:
# a480:h:VERMISSEN_der_Angehörige:rHD: a480:F:VERMISSEN_der_Angehörige_beheben:rHD:
# a480:HF:Universellen_ZAUBERMITTEL_erfassen:rHD:
# a480:H:Universellen_ZAUBERMITTEL_erfassen:rHD_rZM:
# a480:H:Gutes_Benehmen:rHD_rST: a480:HF:Abraten_von_der_MISSION:rHD_rST: a480:h:Auf_ABRATEN_von_der_Mission_reagieren:rHD_rST:
# a480:H:Unterkommen:rHD_rHD_rHH: a480:h:SCHLAF:rHD_rHD_rHH:
# a480:H:Sorge_um_Hungernde_oder_Durstige:rHF_rZM:
# a480:H:STERBEN_beheben:rHD_rHF_fHH: a480:H:Bestrafung:rHD_rHF_fHH:
# a563:F:HUNGERSNOT_beheben:rHD_rVB_fVB: a563:H:ANEIGNUNG:rHD_rVB_fVB:
# a563:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:rST_fHF:
# a563:h:Überrascht_werden_oder_geraten:rHD_rST: a563:f:Ungewollte_Verlobung_akzeptieren:rHD_rST:
# a563:HF:Information_aus_zweiter_Hand:rHD_fVB: a563:h:Ungewollte_Verlobung_akzeptieren:rHD_fVB:
# a563:HF:Information_aus_zweiter_Hand:rHD_rVB: a563:H:Ungewollte_Verlobung_akzeptieren:rHD_rVB:
# a563:h:HUNGERSNOT:rHD_fVB:
# a563:h:KONTAKT_abbrechen:rHD_fVB:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rVB:
# a563:H:Proviantproduzierenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:H:KONTAKT_wiederherstellen:rHD_fVB: a563:f:EINLADUNG_oder_Bestellung:rHD_fVB:
# a563:HF:Information_aus_zweiter_Hand:rAN_fVB: a563:h:Auf_EINLADUNG_oder_Bestellung_reagieren:rAN_fVB:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_fVB: a563:H:HUNGERSNOT_beheben:rHD_rZM_fVB:
# a563:h:ANEIGNUNG:rHD_rZM_rAN:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:H:HUNGERSNOT_beheben:rHD_rZM_fVB: a563:H:Ende:rHD_rZM_fVB:
# a519:h:Auf_TABU_reagieren:rPP: a519:F:Folgen_eines_TABUbruches_rückgängig_machen:rPP:
# a519:f:MARKIERUNGEN_anbringen:rPP_rAN:
# a519:h:MARKIERUNGEN_erkennen:rPP_rAN: a519:h:Sich_auf_Eindringlinge_einlassen:rPP_rAN: a519:h:VAMPIRISMUS:rPP_rAN:
# a519:h:Vorgang_deuten:rHD_rHF_rPP: a519:H:Krisenursachen_ergründen:rHD_rHF_rPP: a519:F:Im_Verborgenen_lauern:rHD_rHF_rPP:
# a519:h:VERSCHLINGEN:rHD_rHF_rAN: a519:H:VERSCHLINGEN_beheben:rHD_rHF_rAN: a519:H:BEHINDERUNG_beheben:rHD_rHF_rAN: a519:H:TÖTUNG:rHD_rHF_rAN:
# a750D:#:#:#:
# a725:h:HUNGERSNOT:rHD_rHH: a725:F:HUNGERSNOT_beheben:rHD_rHH:
# a725:F:VEREINBARUNG:rHD_fVB:
# a725:H:Erträumen:rHD: a725:F:TRAUM_vom_sozialen_Aufstieg:rHD:
# a725:h:VEREINBARUNG_einhalten:rHD_fVB: a725:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fVB:
# a725:h:Zu_Beauftragungen_anregen:rHD_rHP_fVB: a725:h:FREIHEITSBERAUBUNG:rHD_rHP_fVB:
# a725:H:FREIHEITSBERAUBUNG_beheben:rHD:
# a725:H:Sachschaden_anrichten:rHD_rPP: a725:F:MARKIERUNGEN_anbringen:rHD_rPP:
# a725:f:Wache_halten:rHP_fHF:
# a725:h:Wache_halten:fHF: a725:H:SCHLAF:fHF:
# a725:H:Sachschaden_anrichten:rHD_rPP: a725:H:Überrascht_werden_oder_geraten:rHD_rPP: a725:F:Liebe_wird_ausgelöst:rHD_rPP:
# a725:f:Rätsel_lösen:rHD_rPP: a725:HF:Information_aus_zweiter_Hand:rHD_rPP: a725:HF:Rätsel_lösen:rHD_rPP:
# a725:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rHP: a725:F:VEREINBARUNG:rHD_rHP: a725:F:Rätsel_lösen:rHD_rHP: a725:F:Verlobung_arrangieren:rHD_rHP:
# a725:H:VEREINBARUNG_einhalten:rHD_rHP: a725:H:Rätsel_lösen:rHD_rHP: a725:H:Verlobung_arrangieren:rHD_rHP:
# a725:H:Heiraten:rHD_rPP:
# a725:H:TRAUM_wird_wahr:rHD_rHP_rPP:
# a706:h:Kinderlosigkeit:rHH: a706:F:Wundermittel_zur_EMPFÄNGNIS_suchen:rHH:
# a706:Hh:VEREINBARUNG:rHH_rZM_fST: a706:H:Wundermittel_zur_EMPFÄNGNIS_erhalten:rHH_rZM_fST:
# a706:H:Wunderbare_EMPFÄNGNIS:rHH_rZM:
# a706:H:Zur_Welt_kommen:rHH:
# a706:h:STERBEN:rHH:
# a706:H:Zur_Welt_kommen:rHD:
# a706:h:Sich_auf_Eindringlinge_einlassen:rHD_fHH:
# a706:h:Verlobung_arrangieren:rHD_rHH_fHH: a706:h:Heiraten:rHD_rHH_fHH:
# a706:H:Überrascht_werden_oder_geraten:rHD_rPP: a706:F:Liebe_wird_ausgelöst:rHD_rPP:
# a706:F:Heiraten:rHD_rPP:
# a706:H:Sich_niederlassen:rHD:
# a706:H:Intensive_Erkundungsaktion:rHD_rST: a706:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST:
# a706:H:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST:
# a706:H:Zusammenbringen_aller_Handlungsträger:rHD_rHH_rPP: a706:H:Vorgang_deuten:rHD_rHH_rPP: a706:H:VERLEUMDUNG_beheben:rHD_rHH_rPP:
# aU:#:#:#: aU:#:#:#:
# a1654:F:Tod_VORTÄUSCHEN:zs_zt_zsa:
# a1654:H:Auf_VORTÄUSCHEN_reagieren:zs_zt:
# a1654:H:Numinose_Einmischung:zs_zt:
# aEB144:h:HUNGERSNOT:zs_zsa: aEB144:h:SCHLAF:zs_zsa:
# aEB144:F:Erträumen:zs_zsa:
# aEB144:h:SCHLAF_unterbrechen:zs_zsa:
# aEB144:h:Vorgang_deuten:zs_zsa:
# aU:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rPP_rAN:
# aU:f:Ungewünschtes_Wesen_beseitigen:rHD_rAN: aU:h:SONSTIGES_beheben:rHD_rAN:
# aU:H:Ende:rHD:
# a837:#:#:#:
# a922:f:VEREINBARUNG:zs_zf: a922:f:Rätsel_lösen:zs_zf: a922:H:Rätsel_lösen:zs_zf: a922:H:VEREINBARUNG_einhalten:zs_zf:
# a922:h:FREIHEITSBERAUBUNG:zs_zf_zfa:
# a922:f:VEREINBARUNG:zt_zf: a922:f:Rätsel_lösen:zt_zf: a922:h:Rätsel_lösen:zt_zf: a922:h:FREIHEITSBERAUBUNG:zt_zf:
# a922:F:Auf_Hilfsquelle_zurückgreifen:zs_zt: a922:F:BESTECHUNG:zs_zt:
# a922:F:Auf_BESTECHUNG_reagieren:zs_zt_zta: a922:HF:Rätsel_lösen:zs_zt_zta:
# a922:H:Rätsel_lösen:zt_zf:
# a922:H:Ende:zs_zf:
# a910:H:Begegnung:rHD_rST: a910:H:WEISHEITEN_erhalten:rHD_rST:
# a930:H:Unterkommen:rHH_rVB_fHP:
# a930:H:Zur_Welt_kommen:rHD_rVB_fHP: a930:f:VORHERSAGE_ungewünschter_Eheschliessung:rHD_rVB_fHP:
# a930:h:Auf_VORHERSAGE_reagieren:rHD_rHH_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP: a930:h:Adoption:rHD_rHH_fHP:
# a930:h:Aussetzung:rHD_rVB_fHP:
# a930:H:Überrascht_werden_oder_geraten:rHD_rST: a930:H:Adoption:rHD_rST:
# a930:H:Begegnung:rHD_rVB_fHP:
# a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST_fHP: a930:h:Auf_VORHERSAGE_reagieren:rHD_rST_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rST_fHP: a930:h:Adoption:rHD_rST_fHP:
# a930:F:Um_einen_Auftrag_WERBEN:rHD_rST: a930:h:KONTAKT_abbrechen:rHD_rST:
# a930:H:Begegnung:rHD_rVB_fHP: a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rVB_fHP: a930:h:Auf_VORHERSAGE_reagieren:rHD_rVB_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rVB_fHP:
# a930:h:BOTSCHAFTEN_versenden:rHD_fHP: a930:F:EINLADUNG_oder_Bestellung:rHD_fHP: a930:H:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_fHP:
# a930:h:BOTSCHAFTEN_versenden:rHD_fHP:
# a930:H:SCHLAF:rHD:
# a930:F:Liebe_wird_ausgelöst:rHD_rPP: a930:H:BOTSCHAFTEN_verfälschen:rHD_rPP:
# a930:H:Auf_BOTSCHAFTEN_reagieren:rHD_rHP_rPP: a930:H:Heiraten:rHD_rHP_rPP:
# a930:HF:VERFOLGUNG_entkommen:rHD_rPP:
# a930:h:VERFOLGUNG:rVB_fHP:
# a930:H:VERFOLGUNG_entkommen:rHD_fHP: a930:H:VORHERSAGE_tritt_ein:rHD_fHP:
# a655:Ff:Priorisierung_VORTÄUSCHEN:zs_zsa:
# a655:Hh:Auf_VORTÄUSCHEN_reagieren:zs:
# a655:h:STERBEN:zs_zsa: a655:h:ANEIGNUNG:zs_zsa:
# a655:h:VERLUST_von_Tieren_Früchten_Ernte_Essen_Futter_usw:zs_zt: a655:F:VORHERSAGE_erforderlich:zs_zt:
# a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf:
# a655:h:Auf_VORHERSAGE_reagieren:zt_zf: a655:F:STREIT_schlichten:zt_zf:
# a655:H:Auf_VORHERSAGE_reagieren:zs_zf: a655:H:VORHERSAGE_tritt_ein:zs_zf: a655:H:VORHERSAGE_subtiler_Eigenschaft:zs_zf:
# a655:H:VORHERSAGE_tritt_ein:zs_zf: a655:HF:VORHERSAGE_subtiler_Eigenschaft:zs_zf:
# a655:H:VERLUSTursache_beheben:zt_zf: a655:H:STREIT_schlichten:zt_zf:
# a655:F:EINLADUNG_oder_Bestellung:zs_zf: a655:H:Auf_EINLADUNG_oder_Bestellung_reagieren:zs_zf:
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zf:
# a655:HF:VORHERSAGE_subtiler_Identität:zs_zf:
# a655:H:Auf_VORHERSAGE_reagieren:zs_zsa: a655:H:VORHERSAGE_tritt_ein:zs_zsa: a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zsa:
# a655:HF:Auf_VORHERSAGE_reagieren:zs_zf:
# a655:F:Auf_Hilfsquelle_zurückgreifen:zf_zfa:
# a655:F:VERLUST_des_Schatzes:zs_zfa: a655:F:VORHERSAGE_erforderlich:zs_zfa:
# a976:F:Rätsel_lösen:zfa: a976:F:ERZÄHLEN_beginnen:zfa:
# a655:H:ERZÄHLEN_beenden:zs_zfa: a655:Hh:Rätsel_lösen:zs_zfa:
# a545B:H:NEUGIER_auslösen:rHF_rHP: a545B:F:Verlobung_arrangieren:rHF_rHP: a545B:F:EINLADUNG_oder_Bestellung:rHF_rHP: a545B:H:Auf_ausgelöste_NEUGIER_reagieren:rHF_rHP:
# a545B:HF:Reichtum_VORTÄUSCHEN:rHD_rHF: a545B:F:SONSTIGES_beheben:rHD_rHF:
# a545B:H:SONSTIGES_Beheben_angehen:rHD_rHH: a545B:H:SONSTIGES_beheben:rHD_rHH:
# a545B:H:Reichtum_VORTÄUSCHEN:rHD_rHH: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHD_rHH: a545B:H:NEUGIER_auslösen:rHD_rHH:
# a545B:H:Auf_ausgelöste_NEUGIER_reagieren:rHD_rHF_rHP: a545B:F:EINLADUNG_oder_Bestellung:rHD_rHF_rHP:
# a545B:Hh:Auf_EINLADUNG_oder_Bestellung_reagieren:rHD_rHF:
# a545B:H:Sonstiges_VORTÄUSCHEN:rHF_fST: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_fST: a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHF_fST:
# a545B:f:EINDRUCKSVOLLE_Handlung:rHF_rHP: a545B:h:Auf_EINDRUCKSVOLLE_Handlung_reagieren:rHF_rHP: a545B:H:Unzufriedenheit_VORTÄUSCHEN:rHF_rHP: a545B:H:Auf_VORTÄUSCHEN_reagieren:rHF_rHP:
# a545B:H:Fremdes_Gut_beschlagnahmen:rHD_rHF_rPP: a545B:H:Heiraten:rHD_rHF_rPP:

# %%
#60 Definieren der Variablen
gesep_1 ="a950"
gesep_2 =""
gesep_3 =""
gesep_4 =""

# %%
#61 Iteration über die Zeilen des DataFrames df_2
for i, gesuchte_label in enumerate(df_2.index_string):
    
    #62 Überprüfen, ob gesep_a-d in der aktuellen Zeile gesuchte_label vorhanden ist
    if gesep_1 in gesuchte_label:# and gesep_2 in gesuchte_label:# and gesep_3 in gesuchte_label:# or gesep_4 in gesuchte_label):
        print(i, gesuchte_label)
        #63 Wenn gesep_1-4 gefunden wurde, markiere die entsprechende Zeile in der Spalte 'index_binar' als '1'
        df_2.index_binar.iloc[i]='1'

#64 Speichern des aktualisierten DataFrames in einer CSV-Datei 'text_lab.csv'
df_2.to_csv('text_az.csv', encoding='utf-8', index=False)
# Out:
# 302 a950:#:#:#:
# 303 a950:#:#:#:
# 304 a950:#:#:#:
# 305 a950:#:#:#:
# 306 a950:#:#:#:
# 307 a950:#:#:#:
# 308 a950:#:#:#:
# 309 a950:#:#:#:
# 1937 a950:#:#:#:
# 1938 a950:#:#:#:
# 1939 a950:#:#:#:
# 1940 a950:#:#:#:
# 1941 a950:#:#:#:
# 1942 a950:#:#:#:
# 1943 a950:#:#:#:
# 1944 a950:#:#:#:
# 1945 a950:#:#:#:
# 1946 a950:#:#:#:
# 1947 a950:#:#:#:
# 1948 a950:#:#:#:
# 3416 a950:#:#:#:
# 3417 a950:#:#:#:
# 3418 a950:#:#:#:
# 3419 a950:#:#:#:
# 3420 a950:#:#:#:
# 3421 a950:#:#:#:
# 3422 a950:#:#:#:
# 3423 a950:#:#:#:
# 3424 a950:#:#:#:
# 3425 a950:#:#:#:
# 3426 a950:#:#:#:
# 3427 a950:#:#:#:
# 3428 a950:#:#:#:
# 4827 a950:#:#:#:
# 4828 a950:#:#:#:
# 4829 a950:#:#:#:
# 4830 a950:#:#:#:
# 4831 a950:#:#:#:
# 4832 a950:#:#:#:
# 4833 a950:#:#:#:
# 4834 a950:#:#:#:
# 4835 a950:#:#:#:
# 4836 a950:#:#:#:
# 4837 a950:#:#:#:
# 4838 a950:#:#:#:
# 4839 a950:#:#:#:
# 4840 a950:#:#:#:
# 4841 a950:#:#:#:
# 4842 a950:#:#:#:
# 4843 a950:#:#:#:
# 4844 a950:#:#:#:
# C:\Users\xe78diq\AppData\Local\Temp\ipykernel_19232\4090129089.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.index_binar.iloc[i]='1'

# %%
#65 Lesen der CSV-Datei 'text_lab.csv' und Laden der Daten in ein Pandas DataFrame
df = pd.read_csv('text_az.csv',  encoding='utf-8')

#66 Extrahieren der Trainingsdaten X_train und der Labels y_train
X_train = df['inhalt']  # Inhalt der Texte
y_train = df['index_binar']  # Binäre Indikatoren

#67 Zählen der Vorkommen jeder Binärklasse in der Spalte 'index_binar'
indexliste = Counter(df_2.index_binar)

#68 Ausgabe der Anzahl der Vorkommen jeder Binärklasse
print(indexliste)
# Out:
# Counter({0: 6609, '1': 51})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.linear_model import LogisticRegression  
from sklearn.model_selection import GridSearchCV  
from sklearn.pipeline import make_pipeline  

#69 Definieren der Pipeline mit einem TF-IDF-Vektorisierer und einem logistischen Regressionsmodell
pipe = make_pipeline(TfidfVectorizer(min_df=2, stop_words=stpw, ngram_range=(1,1), norm=None), 
                     LogisticRegression())

#70 Definieren des Rastersuchgitters für den Regularisierungsparameter C des logistischen Regressionsmodells
param_grid = {'logisticregression__C': [0.001, 0.01, 0.1, 1, 10]}     

#71 Erstellen eines Rastersuchobjekts mit der Pipeline und dem Rastersuchgitter, das auf 5-facher Kreuzvalidierung basiert
grid = GridSearchCV(pipe, param_grid, cv=5)

#72 Anpassen der Rastersuche an die Trainingsdaten
grid.fit(X_train, y_train)

#73 Drucken des besten Scores aus der Kreuzvalidierung
print("Bester Score aus der Kreuzvalidierung: {:.2f}".format(grid.best_score_))
# Out:
# Bester Score aus der Kreuzvalidierung: 0.99

# %%
import numpy as np

#74 Extrahieren des TF-IDF-Vektorisierers aus dem besten Schätzschritt des Gittersuchlaufs
vectorizer = grid.best_estimator_.named_steps["tfidfvectorizer"]

#75 Ermitteln des maximalen TF-IDF-Werts für jedes Merkmal
max_value = vectorizer.transform(X_train).max(axis=0).toarray().ravel()

#76 Sortieren der Merkmale nach ihren TF-IDF-Werten
sorted_by_tfidf = max_value.argsort()

#77 Extrahieren der Merkmalsnamen aus dem Vektorisierer
feature_names = np.array(vectorizer.get_feature_names_out())
print("Gesamte Anzahl der Wörter: {}".format(len(vectorizer.vocabulary_)))
# Out:
# Gesamte Anzahl der Wörter: 16722

# %%
s_zahl = 200  #78 Anzahl der Merkmale, die in der Visualisierung dargestellt werden sollen

import matplotlib.pyplot as plt  
import mglearn

#79 Visualisieren der Koeffizienten des logistischen Regressionsmodells
mglearn.tools.visualize_coefficients(
    grid.best_estimator_.named_steps["logisticregression"].coef_,  #80 Koeffizienten des Modells
    feature_names,  n_top_features=s_zahl  #81 Merkmalsnamen und Anzahl der Merkmale, die visualisiert werden sollen
)

#82 Anzeigen des Gitters in der Visualisierung
plt.grid()

#83 Anzeigen der Visualisierung
plt.show()
#plt.savefig(s_zahl+'.png', dpi=80)

# %%
#84 Extrahieren der Koeffizienten aus dem logistischen Regressionsmodell
gio = grid.best_estimator_.named_steps["logisticregression"].coef_[0]

#85 Sortieren der Indizes der Koeffizienten nach ihrer Größe
n_top = np.argsort(gio)

#86 Sortieren der Koeffizienten nach ihrer Größe
z_top = np.sort(gio)

#87 Extrahieren der Top-Merkmale mit den höchsten Koeffizienten
text_pos = feature_names[n_top[-s_zahl:]]
zahl_pos = gio[n_top[-s_zahl:]]

#88 Extrahieren der Top-Merkmale mit den niedrigsten Koeffizienten
text_neg = feature_names[n_top[0:s_zahl]]
zahl_neg = gio[n_top[0:s_zahl]]

#89 Ausgabe der positiven Merkmale und ihrer Koeffizienten
print("Positive Merkmale:\n{}".format(text_pos))

#90 Ausgabe der negativen Merkmale und ihrer Koeffizienten
# print("Negative Merkmale:\n{}".format(text_neg))

#91 Ausgabe der Koeffizienten der positiven Merkmale
# print("Positive coef:\n{}".format(zahl_pos))

#92 Ausgabe der Koeffizienten der negativen Merkmale
# print("Negative coef:\n{}".format(zahl_neg))
# Out:
# Positive Merkmale:
# ['покончить' 'спать' 'рублей' 'сокровищницы' 'дороге' 'ров' 'деньги'
#  'следующему' 'спустился' 'упала' 'обернется' 'хитрость' 'оплакивала'
#  'протяни' 'правым' 'пиалу' 'нагло' 'снова' 'спрятал' 'дам' 'хранить'
#  'подарок' 'навозом' 'дарует' 'бесстрашный' 'ножницами' 'вволю' 'пристали'
#  'стену' 'слезы' 'нога' 'вдова' 'ходила' 'мясом' 'увидишь' 'дала' 'слез'
#  'забрал' 'стражу' 'выбраться' 'безголовый' 'заплакала' 'оба' 'получил'
#  'возвращался' 'подарил' 'площадь' 'делал' 'плачь' 'попала' 'единственный'
#  'отрезал' 'ханства' 'выйдет' 'лекарства' 'молодости' 'выходила' 'шкуру'
#  'будешь' 'отрубят' 'бедная' 'предупредил' 'смерти' 'сколько' 'двенадцать'
#  'постоянно' 'зарезали' 'люди' 'завяз' 'ремеслу' 'человек' 'неизвестно'
#  'убитого' 'воров' 'лет' 'никто' 'попрошайка' 'отомстить' 'сын' 'выберусь'
#  'найти' 'отец' 'смоле' 'головой' 'отруби' 'собрал' 'ставил' 'малых'
#  'мертвеца' 'глиняный' 'ребенка' 'казны' 'мяса' 'мало' 'кумухскому' 'увяз'
#  'слезами' 'брат' 'утром' 'полным' 'произошло' 'повесили' 'чтонибудь'
#  'яму' 'моего' 'роднику' 'напоив' 'обнаружили' 'увидев' 'народ' 'отрежь'
#  'медный' 'сундук' 'государства' 'случившемся' 'меда' 'разбей' 'нижней'
#  'опознать' 'кувшина' 'пойдешь' 'рука' 'вдовы' 'охраняли' 'улицу'
#  'разбитого' 'крепостную' 'урони' 'навозе' 'белого' 'мужественный' 'водой'
#  'изза' 'ворами' 'вором' 'женщина' 'вином' 'схватили' 'дядя' 'домой'
#  'верблюжатины' 'золото' 'покинутый' 'соскользнулась' 'проверять' 'сестре'
#  'удалось' 'стражников' 'больного' 'базар' 'украдет' 'подсказала' 'глазах'
#  'половину' 'поймать' 'стража' 'сможешь' 'воровать' 'понял' 'приказал'
#  'украл' 'дереве' 'исцеления' 'зарезал' 'сдержать' 'разбила' 'отца'
#  'правый' 'отрезанной' 'ус' 'кувшином' 'ханские' 'доносчица' 'руку'
#  'голову' 'осла' 'воровали' 'верблюда' 'брата' 'сокровища' 'соседнего'
#  'родника' 'нукеров' 'сможет' 'падишах' 'вдову' 'хану' 'хана' 'плакать'
#  'украсть' 'нукеры' 'хан' 'стражники' 'тело' 'дяди' 'кувшин' 'племянник'
#  'вора' 'труп' 'вор']

# %%
kfz = range(s_zahl)  # Erstellen einer Sequenz von Zahlen von 0 bis s_zahl-1
folgenum = 0  # Initialisieren des Zählers für die Folgennummer
pop = None  # Initialisierung der "pop"-Variable

# Iteration über die Zahlen in der Sequenz kfz
for x in kfz:
    folgenum += 1  # Inkrementieren der Folgennummer
    # Berechnen der Summe der Koeffizienten für das aktuelle Element in der Liste
    vollliste = zahl_pos[s_zahl - folgenum] + zahl_neg[s_zahl - folgenum]
    # Runden der Summe auf drei Dezimalstellen
    rundliste = round(vollliste, 3)
    # Ausgabe der gerundeten Summe und der aktuellen Zahl in der Sequenz
    print(rundliste, '-', x)
    
    # Bedingung, um zu prüfen, ob rundliste weniger als 0.001 ist
    if rundliste < 0.001:
        pop = x  # Setzen der "pop"-Variable auf den aktuellen Wert von x
        break  # Schleife beenden, da wir den kleinsten Wert von x gefunden haben

# Ausgabe des Ergebnisses
if pop is not None:
    print(f"Die 'pop'-Variable ist {pop}, da rundliste kleiner als 0.001 ist.")
else:
    print("Kein Wert gefunden, bei dem rundliste kleiner als 0.001 ist.")
# Out:
# 0.087 - 0
# 0.08 - 1
# 0.067 - 2
# 0.051 - 3
# 0.039 - 4
# 0.038 - 5
# 0.037 - 6
# 0.036 - 7
# 0.036 - 8
# 0.035 - 9
# 0.033 - 10
# 0.03 - 11
# 0.03 - 12
# 0.03 - 13
# 0.029 - 14
# 0.029 - 15
# 0.026 - 16
# 0.025 - 17
# 0.024 - 18
# 0.024 - 19
# 0.023 - 20
# 0.022 - 21
# 0.022 - 22
# 0.021 - 23
# 0.021 - 24
# 0.021 - 25
# 0.02 - 26
# 0.02 - 27
# 0.019 - 28
# 0.019 - 29
# 0.018 - 30
# 0.018 - 31
# 0.018 - 32
# 0.018 - 33
# 0.016 - 34
# 0.016 - 35
# 0.016 - 36
# 0.016 - 37
# 0.016 - 38
# 0.015 - 39
# 0.014 - 40
# 0.014 - 41
# 0.014 - 42
# 0.014 - 43
# 0.014 - 44
# 0.014 - 45
# 0.014 - 46
# 0.013 - 47
# 0.013 - 48
# 0.013 - 49
# 0.013 - 50
# 0.012 - 51
# 0.012 - 52
# 0.012 - 53
# 0.012 - 54
# 0.012 - 55
# 0.012 - 56
# 0.012 - 57
# 0.011 - 58
# 0.011 - 59
# 0.011 - 60
# 0.011 - 61
# 0.011 - 62
# 0.011 - 63
# 0.011 - 64
# 0.011 - 65
# 0.011 - 66
# 0.011 - 67
# 0.011 - 68
# 0.011 - 69
# 0.011 - 70
# 0.01 - 71
# 0.01 - 72
# 0.01 - 73
# 0.01 - 74
# 0.01 - 75
# 0.01 - 76
# 0.01 - 77
# 0.01 - 78
# 0.01 - 79
# 0.01 - 80
# 0.01 - 81
# 0.01 - 82
# 0.009 - 83
# 0.009 - 84
# 0.009 - 85
# 0.009 - 86
# 0.009 - 87
# 0.009 - 88
# 0.009 - 89
# 0.009 - 90
# 0.009 - 91
# 0.009 - 92
# 0.009 - 93
# 0.009 - 94
# 0.009 - 95
# 0.008 - 96
# 0.008 - 97
# 0.008 - 98
# 0.008 - 99
# 0.008 - 100
# 0.008 - 101
# 0.008 - 102
# 0.008 - 103
# 0.008 - 104
# 0.008 - 105
# 0.008 - 106
# 0.008 - 107
# 0.008 - 108
# 0.008 - 109
# 0.007 - 110
# 0.007 - 111
# 0.007 - 112
# 0.007 - 113
# 0.007 - 114
# 0.007 - 115
# 0.007 - 116
# 0.007 - 117
# 0.007 - 118
# 0.007 - 119
# 0.007 - 120
# 0.007 - 121
# 0.007 - 122
# 0.006 - 123
# 0.006 - 124
# 0.006 - 125
# 0.006 - 126
# 0.006 - 127
# 0.006 - 128
# 0.006 - 129
# 0.006 - 130
# 0.006 - 131
# 0.006 - 132
# 0.006 - 133
# 0.006 - 134
# 0.005 - 135
# 0.005 - 136
# 0.005 - 137
# 0.005 - 138
# 0.005 - 139
# 0.005 - 140
# 0.005 - 141
# 0.005 - 142
# 0.005 - 143
# 0.005 - 144
# 0.005 - 145
# 0.005 - 146
# 0.004 - 147
# 0.004 - 148
# 0.004 - 149
# 0.004 - 150
# 0.004 - 151
# 0.004 - 152
# 0.004 - 153
# 0.004 - 154
# 0.003 - 155
# 0.003 - 156
# 0.003 - 157
# 0.003 - 158
# 0.003 - 159
# 0.003 - 160
# 0.003 - 161
# 0.003 - 162
# 0.003 - 163
# 0.003 - 164
# 0.003 - 165
# 0.003 - 166
# 0.002 - 167
# 0.002 - 168
# 0.002 - 169
# 0.002 - 170
# 0.002 - 171
# 0.002 - 172
# 0.001 - 173
# 0.001 - 174
# 0.001 - 175
# 0.001 - 176
# 0.001 - 177
# 0.001 - 178
# 0.001 - 179
# 0.001 - 180
# 0.001 - 181
# 0.001 - 182
# 0.001 - 183
# 0.001 - 184
# 0.0 - 185
# Die 'pop'-Variable ist 185, da rundliste kleiner als 0.001 ist.

# %%
#100 Schwelenwert bestimmen
sw = pop-1
print(sw)
# Out:
# 184

# %%
filename ='!_neu'  #101 Der Dateiname für die CSV-Datei (ohne Erweiterung)
tit = (text_pos[s_zahl-sw:s_zahl])  #102 Die Titelzeile, die geschrieben werden soll

#103 Öffnen der CSV-Datei zum Schreiben ('wt' für Schreiben im Textmodus)
with open (filename+'.csv', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f)  #85 Initialisieren des CSV-Schreibers
    writer.writerow(tit)  #86 Schreiben der Titelzeile in die CSV-Datei

# %% [markdown]
# ### Messdaten aufbereiten

# %%
import xml.etree.ElementTree as ET  # Importieren der ElementTree-Bibliothek zum Parsen von XML

# XML-Daten laden
tree = ET.parse('gesamt_maerchen.xml')
root_node = tree.getroot()

# Namespace definieren
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}

# Filtereinstellung für das Attribut `@ident` (kann leer sein)
filter_ident = "rus"  # z. B. input("Bitte geben Sie das Attribut 'ident' an (z.B. 'kat'): ").strip()

# Variable für die gesammelten Märchendaten
maerchen = ""

# Iteration durch die XML-Daten
for corp in root_node.findall(".//tei:teiCorpus", NS):
    if "tg" in corp.attrib.get("n", "") or "xtk" in corp.attrib.get("n", ""):
        for tei in corp.findall("tei:TEI", NS):
            # Filter basierend auf `@ident` oder bei leerem `filter_ident`
            language = tei.find(".//tei:teiHeader//tei:langUsage/tei:language", NS)
            if language is not None:
                ident_value = language.attrib.get('ident', '')
                if filter_ident == "" or ident_value == filter_ident:
                    for ganze in tei.findall(".//tei:text", NS):
                        quelle = ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                        for body in ganze.findall(".//tei:body", NS):
                            for absatz in body.findall(".//tei:p", NS):
                                for phrase in absatz.findall(".//tei:seg", NS):
                                    # Labels extrahieren
                                    labela = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/a}ana', 'N/A')
                                    labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N/A')
                                    labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N/A')
                                    labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N/A')
                                    labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N/A')
                                    labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N/A')
                                    labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N/A')
                                    labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N/A')
                                    labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N/A')
                                    labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N/A')
                                    labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N/A')
                                    labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N/A')
                                    inhalt = (phrase.text.lower().strip()
                                              .replace('|', '').replace(':', '').replace("ä", "ae")
                                              .replace("ü", "ue").replace("ö", "oe").replace("ß", "ss")
                                              .replace(",", "").replace("\n", " ").replace("'", "")
                                              .replace("…", "").replace('"', "").replace("*", "")
                                              .replace("(", "").replace(")", "").replace("-", "")
                                              .replace("]", "").replace("[", "").replace(".", "")
                                              .replace("?", "").replace("!", "").replace("„", "")
                                              .replace("+", "").replace("=", "").replace("_", "")
                                              .replace("­", "").replace('“', "").replace('”', "")
                                              .replace(";", "").replace('~', "").replace('`', ""))
                                    # Bedingung: labela beginnt mit 'a' und labelb1 ist nicht 'N/A'
                                    if labelb1.startswith('N'):
                                        # Märchendaten sammeln
                                        maerchen += (quelle + ',' + labela + ',' + labelb1 + ',' + labelc1 + ',' +
                                                     labelb2 + ',' + labelc2 + ',' + labelb3 + ',' + labelc3 + ',' +
                                                     labelb4 + ',' + labelc4 + ',' + labelb5 + ',' + labelc5 + ',' +
                                                     labeld + ',' + inhalt + ',0' + '\n')

# Ergebnisse in eine CSV-Datei schreiben
with open("text.csv", 'w', encoding='utf-8') as f:
    # Kopfzeile schreiben
    f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar')
    f.write('\n')
    # Gesammelte Märchendaten schreiben
    f.write(maerchen)

print(f"Die Märchendaten mit 'ident'='{filter_ident}' wurden in 'text.csv' gespeichert.")
# Out:
# Die Märchendaten mit 'ident'='rus' wurden in 'text.csv' gespeichert.

# %%
#118 Öffnen der CSV-Datei im Lesemodus und Lesen ihres Inhalts
with open(filename+'.csv', 'r', encoding='utf-8') as file:
    file_contents = file.read().replace(",", " ").replace("\n", "")  #119 Entfernen von Kommas und Zeilenumbrüchen

#120 Zusammenstellen des neuen Inhalts mit dem Dateinamen und zusätzlichen Metadaten
frt_contents = filename+',N,N,N,N,N,N,N,N,N,N,N,N'+','+file_contents+',0'

#121 Löschen der ursprünglichen CSV-Datei
import os 
os.remove(filename+'.csv')

# %%
row = [frt_contents]  #122 Erstellen einer neuen Zeile mit dem zusammengestellten Inhalt

#123 Öffnen der CSV-Datei im Lesemodus und Lesen der vorhandenen Zeilen
with open("text.csv", 'r', encoding='utf-8') as readFile:
    rd = csv.reader(readFile)  #124 Initialisieren des CSV-Lesers
    lines = list(rd)  #125 Lesen der Zeilen und Konvertieren in eine Liste

    #126 Einfügen der neuen Zeile an der zweiten Position in die Liste der Zeilen
    lines.insert(1, row)

#127 Öffnen der CSV-Datei im Schreibmodus und Schreiben der aktualisierten Zeilen
with open("text.csv", 'wt', newline='', encoding='utf-8') as writeFile:
    wt = csv.writer(writeFile)  #128 Initialisieren des CSV-Schreibers
    wt.writerows(lines)  #129 Schreiben der Zeilen in die Datei

#130 Öffnen der ursprünglichen und neuen CSV-Dateien zum Lesen bzw. Schreiben
fin = open('text.csv', 'r', encoding='utf-8')
fout = open('text_reich.csv', "wt", encoding='utf-8')

#131 Iteration über die Zeilen der ursprünglichen CSV-Datei
for kfz in fin:
    #132 Schreiben der Zeile in die neue Datei mit Entfernung bestimmter Zeichenfolgen
    fout.write(kfz.replace('"', ''))
#133 Schließen beider Dateien
fin.close()
fout.close()

# %%
#134 Funktion für die Beseitigung der leeren Datensätzen
def delete_records_with_empty_field(file_path, field_name):
    
    #135 Öffnen der CSV-Datei im Lese-Modus
    with open(file_path,  'r', encoding="utf-8") as file:
        #136 Lesen der Daten als Liste von Dictionaries
        reader = csv.DictReader(file)
        rows = list(reader)

    #137 Überprüfen, ob das Feld in den Daten leer ist
    filtered_rows = [row for row in rows if row[field_name]]

    #138 Öffnen der CSV-Datei im Schreibmodus und Schreiben der verbleibenden Datensätze
    with open(file_path, 'w', encoding="utf-8", newline='') as file:
        writer = csv.DictWriter(file, fieldnames=reader.fieldnames)
        writer.writeheader()
        writer.writerows(filtered_rows)

#139 Beispielaufruf der Funktion
file_path = 'text_reich.csv'  #140 Passe den Pfad zu deiner CSV-Datei an
field_name = 'inhalt'  #142 Passe den Namen des Feldes an, das überprüft werden soll
delete_records_with_empty_field(file_path, field_name)

# %%
t_corpus = []  #143 Eine leere Liste zum Speichern der Textdaten
df = pd.read_csv('text_reich.csv', encoding='utf-8')  #144 Einlesen der CSV-Datei in ein Pandas DataFrame
file = 'text_reich.csv'  #145 Der Dateiname der CSV-Datei

#146 Öffnen der CSV-Datei im Lesemodus und Extrahieren der Textdaten
with open(file, "rt", encoding='utf-8') as maerchen:
    maercho = df.inhalt  #147 Extrahieren der Spalte "inhalt" aus dem DataFrame
    reader = csv.reader(maercho)  #148 Initialisieren des CSV-Lesers
    for row in reader:
        lst = str(row)  #149 Konvertieren der gelesenen Zeile in eine Zeichenfolge
        t_corpus.append(lst)  #150 Hinzufügen der Zeichenfolge zur Liste der Textdaten

# %% [markdown]
# ### Vorhersage

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#162 Initialisieren des TF-IDF-Vektorisierers mit bestimmten Parametern
vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1,1), 
                             min_df=1, stop_words=stpw)

#163 Erstellen des Vokabulars aus den Textdaten mit dem TF-IDF-Vektorisierer
vocabulary = vectorizer.fit_transform(t_corpus)

#164 Funktion zur Suche nach ähnlichen Dokumenten basierend auf der Kosinusähnlichkeitsmetrik
def find_similar(vocabulary, index, top_n=-1):
    #165 Berechnen der Kosinusähnlichkeitswerte zwischen dem ausgewählten Dokument und allen anderen Dokumenten
    similarities = cosine_similarity(vocabulary[index:index+1], vocabulary).flatten()
    #166 Sortieren der Dokumente basierend auf den Kosinusähnlichkeitswerten in absteigender Reihenfolge
    related_docs_indices = [i for i in similarities.argsort()[::-1] if i != index]
    #167 Auswahl der Top-n ähnlichsten Dokumente und Rückgabe ihrer Indizes und Kosinusähnlichkeitswerte
    return [(index, similarities[index]) for index in related_docs_indices][:top_n]

#168 Die TF-IDF-Vektoren für die Textdaten können über `vocabulary` abgerufen werden
# print(vocabulary)

# %%
n_te = 0  #169 Index des ersten Dokuments
inhalt = df.inhalt[n_te]
print(inhalt)  #170 Ausgabe des Inhalts des ersten Dokuments

#with open(gesep_1.replace(':','')+'.txt','w', encoding="utf-8") as file:
    #file.write(inhalt)
# Out:
# нагло снова спрятал дам хранить подарок навозом дарует бесстрашный ножницами вволю пристали стену слезы нога вдова ходила мясом увидишь дала слез забрал стражу выбраться безголовый заплакала оба получил возвращался подарил площадь делал плачь попала единственный отрезал ханства выйдет лекарства молодости выходила шкуру будешь отрубят бедная предупредил смерти сколько двенадцать постоянно зарезали люди завяз ремеслу человек неизвестно убитого воров лет никто попрошайка отомстить сын выберусь найти отец смоле головой отруби собрал ставил малых мертвеца глиняный ребенка казны мяса мало кумухскому увяз слезами брат утром полным произошло повесили чтонибудь яму моего роднику напоив обнаружили увидев народ отрежь медный сундук государства случившемся меда разбей нижней опознать кувшина пойдешь рука вдовы охраняли улицу разбитого крепостную урони навозе белого мужественный водой изза ворами вором женщина вином схватили дядя домой верблюжатины золото покинутый соскользнулась проверять сестре удалось стражников больного базар украдет подсказала глазах половину поймать стража сможешь воровать понял приказал украл дереве исцеления зарезал сдержать разбила отца правый отрезанной ус кувшином ханские доносчица руку голову осла воровали верблюда брата сокровища соседнего родника нукеров сможет падишах вдову хану хана плакать украсть нукеры хан стражники тело дяди кувшин племянник вора труп вор

# %%
# 171 Iteration über die ähnlichen Dokumente zum ersten Dokument
similarities = list(find_similar(vocabulary, n_te))
max_score = max(score for _, score in similarities)

for index, score in similarities:
    if score > (2 / 3) * max_score:
        print(index, '-', round(score, 3), '-', df.quelle[index], '-', t_corpus[index], '\n')
# Out:
# 317 - 0.081 - zyx_cr_aqc_rus_2 - ['вор которого могли поймать хан нукеры хана всему народу кумуха всем людям хан объявил отдаст половину права царствовать тому поймает вора приведет нему арчинцы услышали этом']
#
# 4318 - 0.081 - zyx_cr_kum_rus_19 - ['посмотрю сможешь сказал хан слез коня']
#
# 5189 - 0.08 - zyx_cr_lbe_rus_19 - ['ножницами']
#
# 1286 - 0.08 - zyx_cr_dar_rus_10 - ['ходила мать спросил снова сын']
#
# 7932 - 0.074 - zyx_cr_rut_rus_7 - ['утром увидев отца слезами кинулась нему шею сказала']
#
# 1941 - 0.074 - zyx_cr_dar_rus_17 - ['нукеры пришли шаху ответами девушки шах понял эта девушка очень умна снова послал нукеров спросили ее выйдет замуж девушка ответила нукерам выйдет него обучится какомунибудь ремеслу которое както пригодиться жизни шах научился делать золотые цепочки девушка согласилась выйти него']
#
# 319 - 0.074 - zyx_cr_aqc_rus_2 - ['прошло дня арчинец поймал вора которого никто мог найти привел ха ну хан спросил вора почему занимался воровством вор сказал семеро детей бедная несчастная голодная семья посмотри то одет  сказал вор поэтому воровал ответил веришь отправь своих визиров посмотреть дом мое хозяйство']
#
# 3149 - 0.073 - zyx_cc_ddo_rus_93 - ['отец жаловался на боль в глазах он сказал «если поймать в реке рыбу и провести ею по глазам то они поправятся» ханские нукеры пошли на реку ловить рыбу никто не мог поймать но ханский сын потом поймал и вытащил ее потом тот сын сказал «наверное отец над нами издевается говоря что у него болят глаза» потом он выпустил рыбу обратно в воду говоря «я бы не хотел чтобы меня даже отец обманул»']
#
# 1242 - 0.072 - zyx_cr_ava_rus_6 - ['подойди отрежь голову']
#
# 17 - 0.071 - zyx_cc_ani_rus_13 - ['когда хан на следующий день увидел что случилось то собрал свой народ и сказал «люди вот что случилось моего гуся украли нукера убили узнайте кто это сделал» — «этого человека мы не знаем хан» ответили люди «и не можем знать но если он сам признается то прости его» вор признался и хан простил его «я это сделал» сказал вор «потому что мы с цыганом спорили изза этой девицы которая должна принадлежать более храброму из нас цыган так сделал как выше было рассказано я — так цыгана хан велел убить девица вышла за вора которого хан взял к себе»']
#
# 2617 - 0.069 - zyx_cr_dar_rus_90 - ['утром площадь снов^г вывели али весь народ ждал хана объявили ночью хан умер']
#
# 3619 - 0.068 - zyx_cr_khv_rus_44 - ['– быть отец родственники мои – ответил сын вдовы – сколько нужно платить отпустили отца']
#
# 7401 - 0.068 - zyx_cr_nog_rus_40 - ['джигит  хозяин трех гусей  получил жены дочь хана половину казны зажил довольстве счастье']
#
# 1814 - 0.067 - zyx_cr_dar_rus_151 - ['— делал']
#
# 6610 - 0.067 - zyx_cr_nog_rus_19 - [' делал']
#
# 6623 - 0.067 - zyx_cr_nog_rus_19 - [' делал']
#
# 5315 - 0.066 - zyx_cr_lbe_rus_25 - [' любезная зарезали верблюда']
#
# 5559 - 0.066 - zyx_cr_lbe_rus_4 - ['плачь дочь моя тебе скажу найти шерсть']
#
# 2888 - 0.066 - zyx_cc_ddo_rus_50 - ['сел на нее младший брат приехал в село и сказал «найдите моего старшего брата» и сразу же пришел старший брат и привел коня с тех пор никто не был на могиле отца оба брата построили хорошие дома и жили спокойной жизнью']
#
# 7845 - 0.066 - zyx_cr_rut_rus_3 - ['снова пошли искать дорогу брат вырвался рук сестры побежал какомуто роднику напился воды глазах превратился быка плачет бедная сестра заливается слезами сделать может погнала впереди быка пришла домой смотрит дома никого спросила соседей родители сказали родители переселились другую страну']
#
# 567 - 0.066 - zyx_cr_ava_rus_142 - ['первую ночь осок украл вел примерно утром вдова отправилась воду осок давай повсюду рыскать обшарикать попались куриные яйца привычке взял их спрятал шапку надел голову заметил осок мед кувигине очень узеньким горлышком жадности заколотилось сердце поспешил запустить туда правую руку но увы емот выталцить тут грех вернулась вдова осок — спрятал руку кувшином полу своего полушубка вдова поставила стол завтрак осок принялся левой рукой — почему ешь левой рукой — спросила женшина — правая болит — сказал осок — ах бедняга вечером болела такое приключилось — и заглянув полушубок увидела кувшине застряла рука — вот оказывается отчего болит рука голова отвалилась — крикнула женщина ударила осока шапке яйца осок кинулся бежать прочь оттаренный лицу текли яйца руке болтален кувшин осоком ругаясь м крича бежала вдова потрясая железными щипцами зрелище столь смешным люди покатывались смеху никто подумал остановить воришку скрылся сколько воровал осок наедался досыта остался голодным кувшин медом разбился']
#
# 16 - 0.066 - zyx_cc_ani_rus_13 - ['вор же прежде всего купил много ключей в городе селении где он жил был хан который имел 7 комнат одна приходилась внутри другой и крепкие решетки защищали их у первой двери этих комнат лежали храбрые собаки у второй были ямщики у третьей нукеры у четвертой семейство хана у пятой его визири у шестой он сам у седьмой гусь этого гуся именно вор хотел украсть ночью он отправился в путь взяв с собой ключи и тесто которое он смешал на водке прибыв к дому хана он бросил это тесто собакам которые конечно опьянели от него затем он открыл комнату ямщиков которых он нашел спящими как и нукеров и семейство хана и визирей потом он открыл комнату хана сам хан тоже спал но около него сидел нукер который чесал ему спину и жевал свою жвачку вор взял длинный волос и осторожно сунул его сбоку в рот нукера нукер все жевал и когда волос прилип к жвачке то вор вынул ее изо рта нукера который тотчас же заснул потом вор зарезал гуся и сварил его там же нукера он убил повесил его труп на дворе на столбе и лег спать немного около самого хана затем он пошёл домой и рассказал все любимой девушке «вот что я сделал» сказал он «ну кто из нас совершил самый большой подвиг» — «ей богу я подумаю немножко и потом скажу» ответила девушка']
#
# 1282 - 0.064 - zyx_cr_dar_rus_10 - ['ходила мать спросил сын']
#
# 20 - 0.064 - zyx_cc_ani_rus_14 - ['в это время возникла ссора между двумя ханами из которых один причинил другому вред вот один из них тот который повредил другому послал к разбойнику и велел ему сказать «я тебе дам много золота и серебра если ты мне будешь помогать причини вред моему противнику и убей его если ты его убьешь я тебе дам много казны» сын сапожника собрал своих товарищей и убил этого хана потом люди убитого хана узнали что это другой хан подстрекнул разбойника убить его «мы тебе дадим полмиллиона если ты убьешь этого хана» сказали они разбойнику «хорошо я его убью» ответил тот взял предложенные деньги и убил хана']
#
# 985 - 0.061 - zyx_cr_ava_rus_201 - ['— ито украл золото']
#
# 4516 - 0.06 - zyx_cr_kum_rus_26 - ['идем базар продавать половину меда сторожи оставшийся мед смотри пришел никому давай есть']
#
# 6151 - 0.06 - zyx_cr_lez_rus_34 - ['отдал золото хранение кадию теперь получил кувшин обратно оказалось золото превратилось н мед']
#
# 2199 - 0.059 - zyx_cr_dar_rus_24 - ['найдет человека который отрубил голову моего ребенка это узнает тому отдам половину своего богатства']
#
# 7395 - 0.059 - zyx_cr_nog_rus_40 - [' пощади меня ты оказывается умный глупый дам тебе жены дочь половину своей казны убивай меня']
#
# 5746 - 0.058 - zyx_cr_lbe_rus_5 - ['сын пачаха возвращался охоты увидев белого джейрана остановил коня унял собак спросил']
#
# 5938 - 0.058 - zyx_cr_lez_rus_12 - ['молодец сын мой сказал он нигде подвел моим сыном останешься им будешь падишахом моего государства']
#
# 5023 - 0.058 - zyx_cr_lbe_rus_11 - ['выйдет приказ хана никого пускали лес будешь делать']
#
# 3135 - 0.058 - zyx_cc_ddo_rus_93 - ['хан пригласил к себе одну хитрую вдову и спросил ее не сможет ли она узнать что случилось с его сыном «смогу»  уверяла она затем она сказала «в комнате где он живет на одной стороне двери на гвозде повесь худую утку а на другой стороне повесь жирную а там в комнате спрячьте меня» как сказала вдова ощипав уток с одной стороны жирную с другой  худую повесили с обеих сторон дверей комнаты где живет сын а в его комнате спрятали вдову']
#
# 8177 - 0.058 - zyx_cr_tab_rus_2 - ['падишах собрал народ города поведал своем горе народ начал искать девушку повсюду']
#
# 1726 - 0.057 - zyx_cr_dar_rus_140 - ['племянник сказал ому']
#
# 3142 - 0.057 - zyx_cc_ddo_rus_93 - ['ханский сын сел на ветряного коня которого дала та женщина и отправился искать яйрангази он пришел в дом вдовы которая живет в одном селе услышав звук зурны и барабана он спросил у вдовы «сегодня в селе что ли свадьба» «да сегодня выдают замуж яйрангази»  ответила вдова он оказался в безвыходном положении и сказал «любым способом я должен ее видеть» «ты не попадешь к ней если не переоденешься в женскую одежду»  сказала вдова ханский сын отдал вдове целую горсть золота и отправил на базар за женской одеждой вдова переодела ханского сына в женскую одежду и взяла его на свадьбу когда пришли на свадьбу та вдова сказала «это подруга яйрангази дайте ей пройти внутрь»']
#
# 5185 - 0.057 - zyx_cr_lbe_rus_19 - ['нет так поле пострижено ножницами большими ножницами возразила жена']
#
# 19 - 0.057 - zyx_cc_ani_rus_14 - ['народ скоро узнал об этом и так как они очень боялись хана то они пристали к сыну сапожника образовалась шайка из 100150 человек']
#
# 4993 - 0.056 - zyx_cr_lbe_rus_1 - ['иди к сестре спроси ее выйдет замуж унсука']
#
# 5903 - 0.056 - zyx_cr_lez_rus_12 - ['нет ответил юноша моего отца']
#
# 1785 - 0.056 - zyx_cr_dar_rus_15 - ['сын испугался задумался «ведь состарюсь также сбросят ли» понял самое могут сделать решил сбрасывать отца но боясь людских упреков сделал того обычно делает весь народ поместил отца большой сундук спрятал дальней комнате никому братьям сказал']
#
# 1121 - 0.055 - zyx_cr_ava_rus_31 - ['валлах спросил сказали сколько входит кувшин ответил муж вернулся базар']
#
# 2528 - 0.054 - zyx_cr_dar_rus_88 - ['второй день свадьбы хана табуна пропала одна кобылица доложили хану приказал стало разыскать вора пастухи обыскали все вора нашли следующую ночь пропала вторая кобылица хан приказал сыну караулить табун ночью']
