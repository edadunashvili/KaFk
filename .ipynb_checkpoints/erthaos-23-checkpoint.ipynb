# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !git clone https://github.com/edadunashvili/KaFk.git

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# import os
# try:
#     os.chdir('/content/KaFk')
#     print("Verzeichnis erfolgreich gewechselt!")
# except FileNotFoundError:
#     print("Verzeichnis nicht gefunden.")
# except Exception as e:
#     print(f"Ein Fehler ist aufgetreten: {e}")

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !pip install mglearn

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# !pip install --upgrade joblib==1.1.1

# %%
# # Nur bei der Ausführung des Codes in Google Colab verwenden!
# from IPython.display import HTML, display
# def set_css():
#   display(HTML('''
#   <style>
#     pre {
#         white-space: pre-wrap;
#     }
#   </style>
#   '''))
# get_ipython().events.register('pre_run_cell', set_css)

# %% [markdown]
# # erthaos-23

# %% [markdown]
# ### README
#
# #####  Assistent für die automatische Erkennung der gesuchten Motive
#
#
# ##### Anpassbare Variablen:
#
#
# filter_ident: Filter für die Sprache des Texte. Entspricht dem Attributwert des Elements //langUsage/anguage/@ident="" in der XML Datei.
#
# gesep_1 ="" , gesep_2 ="" usw.: Die Abfragewerte für das Zielmotiv mit entsprechende Label. Die Werte von 'gesep_1' bis 'gesep_n' können nach der in der Motivliste ausgewälte Zeilen, oder ihre Bestandteilen ausgefült werden und anschließend in der Anfragezeile als Anfrage mit 'or' und/oder 'and' Opperatoren bestimmen.
#
# Stoppwortliste für die bestimmte Sprache.

# %% [markdown]
# ### Trainingsdaten aufbereiten und transformieren

# %%
import xml.etree.ElementTree as ET  #1 Importieren der ElementTree-Bibliothek zum Parsen von XML

#2 XML-Daten laden
tree = ET.parse('gesamt_märchen.xml')
root_node = tree.getroot()

#3 Namespace definieren
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}

#5 Filtereinstellung für das Attribut `@ident` (kann leer sein)
filter_ident = "rus"  # z. B. input("Bitte geben Sie das Attribut 'ident' an (z.B. 'kat'): ").strip()

#6 Variable für die gesammelten Märchendaten
maerchen = ""

#7 Iteration durch die XML-Daten
for corp in root_node.findall(".//tei:teiCorpus", NS):
    if "tg" in corp.attrib.get("n", "") or "xtk" in corp.attrib.get("n", ""):
        for tei in corp.findall("tei:TEI", NS):
            #8 Filter basierend auf `@ident` oder bei leerem `filter_ident`
            language = tei.find(".//tei:teiHeader//tei:langUsage/tei:language", NS)
            if language is not None:
                ident_value = language.attrib.get('ident', '')
                if filter_ident == "" or ident_value == filter_ident:
                    for ganze in tei.findall(".//tei:text", NS):
                        quelle = ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                        for body in ganze.findall(".//tei:body", NS):
                            for absatz in body.findall(".//tei:p", NS):
                                for phrase in absatz.findall(".//tei:seg", NS):
                                    #9 Labels extrahieren
                                    labela = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/a}ana', 'N/A')
                                    labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N/A')
                                    labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N/A')
                                    labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N/A')
                                    labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N/A')
                                    labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N/A')
                                    labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N/A')
                                    labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N/A')
                                    labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N/A')
                                    labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N/A')
                                    labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N/A')
                                    labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N/A')
                                    inhalt = (phrase.text.lower().strip()
                                              .replace('|', '').replace(':', '').replace("ä", "ae")
                                              .replace("ü", "ue").replace("ö", "oe").replace("ß", "ss")
                                              .replace(",", "").replace("\n", " ").replace("'", "")
                                              .replace("…", "").replace('"', "").replace("*", "")
                                              .replace("(", "").replace(")", "").replace("-", "")
                                              .replace("]", "").replace("[", "").replace(".", "")
                                              .replace("?", "").replace("!", "").replace("„", "")
                                              .replace("+", "").replace("=", "").replace("_", "")
                                              .replace("­", "").replace('“', "").replace('”', "")
                                              .replace(";", "").replace('~', "").replace('`', ""))
                                    #10 Bedingung: labela beginnt mit 'a' und labelb1 ist nicht 'N/A'
                                    if labela.startswith('a') and labelb1 != 'N':
                                        #11 Märchendaten sammeln
                                        maerchen += (quelle + ',' + labela + ',' + labelb1 + ',' + labelc1 + ',' +
                                                     labelb2 + ',' + labelc2 + ',' + labelb3 + ',' + labelc3 + ',' +
                                                     labelb4 + ',' + labelc4 + ',' + labelb5 + ',' + labelc5 + ',' +
                                                     labeld + ',' + inhalt + ',0' + '\n')

#12 Ergebnisse in eine CSV-Datei schreiben
with open("text.csv", 'w', encoding='utf-8') as f:
    #13 Kopfzeile schreiben
    f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar')
    f.write('\n')
    #14 Gesammelte Märchendaten schreiben
    f.write(maerchen)

print(f"Die Märchendaten mit 'ident'='{filter_ident}' wurden in 'text.csv' gespeichert.")
# Out:
# Die Märchendaten mit 'ident'='rus' wurden in 'text.csv' gespeichert.

# %%
#15 leere Zeichenfolge, die später mit den gewünschten Daten gefüllt werden
abcd1="" 
abcd2="" 
abcd3=""  
abcd4=""  
abcd5=""  

import pandas as pd  
from collections import Counter

#16 Lesen der CSV-Datei und Laden der Daten in ein Pandas DataFrame
df = pd.read_csv('text.csv',  encoding='utf-8')

#17.1 Hinzufügen von Daten zu den entsprechenden Variablen abcd1 bis abcd5
#17.2 Hier werden die Daten aus verschiedenen Spalten des DataFrame kombiniert
abcd1 += df.quelle+','+df.labela+':'+df.labelb1+':'+df.labelc1+':'+df.labeld+':'+','+df.inhalt+',0'
abcd2 += df.quelle+','+df.labela+':'+df.labelb2+':'+df.labelc2+':'+df.labeld+':'+','+df.inhalt+',0'
abcd3 += df.quelle+','+df.labela+':'+df.labelb3+':'+df.labelc3+':'+df.labeld+':'+','+df.inhalt+',0'
abcd4 += df.quelle+','+df.labela+':'+df.labelb4+':'+df.labelc4+':'+df.labeld+':'+','+df.inhalt+',0'
abcd5 += df.quelle+','+df.labela+':'+df.labelb5+':'+df.labelc5+':'+df.labeld+':'+','+df.inhalt+',0'

#18 Zusammenführen der Daten aus den Variablen abcd1 bis abcd5
recorded=(abcd1+'\n'+abcd2+'\n'+abcd3+'\n'+abcd4+'\n'+abcd5+'\n')

#19 Schreiben der kombinierten Daten in eine neue CSV-Datei
with open("text_aw.csv", 'w', encoding='utf-8') as w:
    #20 Schreiben der Kopfzeile
    w.write('quelle,index_string,inhalt,index_binar\n')
    #21 Schreiben der vordefinierten Zeile mit Dummy-Daten
    w.write('000:ballast,ballast,ballast,0\n')
    #22 Schreiben der kombinierten Daten
    w.write("".join(recorded))
    #23 Schließen der Datei
    w.close()

# %%
import csv  

mom=[]  #24 Eine leere Liste zum Speichern der Zeilen, die bestimmten Kriterien entsprechen

#25 Lesen der CSV-Datei 'text_aw.csv'
with open('text_aw.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f) 
    #26 Iteration über jede Zeile in der CSV-Datei
    for line in reader:
        #27 Überprüfen, ob die Zeile nicht das Muster ':N:' in der zweiten Spalte enthält
        if ':N:' not in line[1]:
            #28 Wenn das Muster nicht vorhanden ist, wird die Zeile der Liste 'mom' hinzugefügt
            mom.append(line)

#29 Kopieren der Datei text_ax.txt
import shutil, os
with open ('text_ax.txt', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(mom)

#30 Öffnen der Datei text_ax.txt zum Lesen
with open('text_ax.txt', 'r', encoding='utf-8') as file:
    #31 Lesen des gesamten Inhalts der Datei
    filedata = file.read()

#32 Bearbeiten des Dateiinhalts, um das gewünschte Format zu erzielen
filedata = (filedata.replace(']","[', "\n").replace('"[','').replace(']"','')
            .replace(" '","").replace("'",""))

#33 Schreiben des bearbeiteten Inhalts in eine neue CSV-Datei text_ay.csv
with open('text_ay.csv', 'w', encoding='utf-8') as file:
    file.write(filedata)

# %%
custom_stop_word_list=['шах', 'аббас', 'алейкум', 'молла', 'насреддин', 'асаламу',  'ва', 'ваалейкум', 'ассалам','насреддина','ходжа','эскендер']  #34 Eine leere Liste, um benutzerdefinierte Stoppwörter zu speichern

import nltk
nltk.download('stopwords')  #35 Herunterladen der Stoppwortliste aus der NLTK-Datenbank

from nltk.corpus import stopwords  #36 Importieren der Stoppwortliste aus NLTK
NLTK_stop_words_list=stopwords.words('russian')  #37 Laden der Stoppwortliste für die bestimmte Sprache
stpw = custom_stop_word_list + NLTK_stop_words_list
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\xe78diq\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#38 Funktion zur Filterung eines CSV-Datensatzes und Zusammenführung mehrfacher Inhalte in eine Zeile
def filter_csv(input_file, output_file):
    data_to_write = []  #39 Liste zum Speichern der zu schreibenden Daten
    with open(input_file, 'r', encoding="utf-8", newline='') as csvfile:  #40 Öffnen der Eingabedatei im Lesemodus
        reader = csv.reader(csvfile)  #41 Erstellen eines CSV-Lesers
        data = list(reader)  #42 Lesen aller Daten in eine Liste
        processed_values = {}  #43 Dictionary zur Nachverfolgung bereits verarbeiteter Inhalte und deren aggregierten Inhalte
        
        for row in data:  #44 Iteration über jede Zeile der Daten
            if len(row) < 4:  #45 Sicherstellen, dass die Zeile genügend Spalten hat
                continue  #46 Zeile überspringen, wenn sie nicht genügend Spalten hat
            content_key = row[2]  #47 Inhalt aus Spalte 3 als Schlüssel verwenden
            if content_key not in processed_values:  #48 Überprüfen, ob der Inhalt noch nicht verarbeitet wurde
                processed_values[content_key] = row  #49 Zeile als verarbeitet markieren und speichern
            else:
                #50 Ergänzen des Inhalts in Spalte 2 der bereits gespeicherten Zeile
                processed_values[content_key][1] += ' ' + row[1]
        
    data_to_write = list(processed_values.values())  #51 Alle verarbeiteten Zeilen in eine Liste umwandeln
    
    with open(output_file, 'w', encoding="utf-8", newline='') as csvfile:  #52 Öffnen der Ausgabedatei im Schreibmodus
        csvfile.write('\n')  #53 Neue Zeile nach der Header-Zeile
        writer = csv.writer(csvfile)  #54 Erstellen eines CSV-Schreibers
        writer.writerows(data_to_write)  #55 Schreiben der gefilterten Daten

#56 Beispielaufruf der Funktion:
filter_csv('text_ay.csv', 'text_az.csv')

# %%
import pandas as pd  
from collections import Counter

#57 Lesen der CSV-Datei 'text_ay.csv' und Laden der Daten in ein Pandas DataFrame
df_1 = pd.read_csv('text_ay.csv',  encoding='utf-8')
df_2 = pd.read_csv('text_az.csv',  encoding='utf-8')
#58 Zählen der Vorkommen jeder Zeichenfolge in der Spalte 'index_string'
indexliste_1 = Counter(df_1.index_string)
indexliste_2 = Counter(df_2.index_string)

#59 Ausgabe der einzigartigen Zeichenfolgen in der Spalte 'index_string'
print(*indexliste_2, sep='\n')
# Out:
# ballast
# a654:F:SELTENEN_Gegenstand_besorgen:rHP:
# a654:H:Fernseher_als_ZAUBERMITTEL_erhalten:rHD:
# a654:H:WAFFE_ZAUBERMITTEL_erhalten:rHD:
# a654:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD:
# a654:F:Um_eine_Frau_werben:rHD_rHP:
# a654:F:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD: a654:H:VORHERSAGE_des_Aufenthaltsortes:rHD:
# anh248:#:#:#:
# anh384:#:#:#:
# a654:F:Eine_Heiratsabsicht_kundtun:rHD_rHH:
# a654:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rHH_rZM: a654:H:Elixier_als_ZAUBERMITTEL_erhalten:rHD_rHH_rZM: a654:H:Fernseher_als_ZAUBERMITTEL_erhalten:rHD_rHH_rZM:
# a654:F:STREIT_SCHLICHTEN:rHD_rST: a654:H:STREIT_SCHLICHTEN:rHD_rST:
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a654:F:WIEDERBELEBEN:rHD_rZM:
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a654:H:Komplikationsfreier_Flug:rHD_rZM:
# a654:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rPP: a654:H:WIEDERBELEBEN:rHD_rZM_rPP:
# a654:F:Dilemma_lösen:rHD:
# a654:F:Dilemma_lösen:rHD_fST: a654:h:Dilemma_lösen:rHD_fST:
# a1592B:f:#:zs_zt:
# a1592B:h:#:zs_zt:
# a1592B:h:#:zs_zt: a1592B:f:#:zs_zt: a1592B:h:#:zs_zt:
# anh395:f:#:zs:
# anh395:h:#:zsa:
# anh395:f:#:zs_zt: anh395:h:#:zs_zt:
# anh313:#:#:#:
# a1592B:#:#:#:
# anh577:#:#:#:
# anh789:f:#:zs_zt:
# anh789:h:#:zs:
# anh789:f:#:zs_zt: anh789:h:#:zs_zt:
# aE2:H:Wunderbare_EMPFÄNGNIS:rHH:
# aE2:Hh:Kaiserschnitt:rHD_rHH_rHF: aE2:H:Zur_Welt_kommen:rHD_rHH_rHF:
# aE2:F:UNGEHEUER_herbeiholen:rHH_fAN:
# aE2:h:MASSENBEDROHUNG:rHD_rAN: aE2:H:Zweikampf:rHD_rAN:
# aE2:H:MASSENBEDROHUNG_beheben:rHD_rHH_rVB:
# aE2:F:Um_einen_Auftrag_werben:rHD_rHH:
# aE2:F:PROVOKATION:rHD_rVB: aE2:H:Der_PROVOKATION_nachgehen:rHD_rVB:
# aE2:F:Krisenursachen_ergründen:rHD_rHH: aE2:F:Rache_nehmen:rHD_rHH: aE2:F:Um_einen_Auftrag_werben:rHD_rHH:
# aE2:H:Die_Beschaffung_der_AUSRÜSTUNG:rHH_rST:
# aE2:#:#:#:
# aE2:HF:PFÖRTNER_täuschen:rHD_rVB:
# aE2:H:PFÖRTNER_entkommen:rHD: aE2:H:Schrecken_ausgelöst:rHD:
# aE2:F:MASSENBEDROHUNG_beheben:rHH_fAN:
# aE2:F:MASSENBEDROHUNG_beheben:rHD_rHH: aE2:HF:Information_aus_zweiter_Hand:rHD_rHH:
# aE2:H:Heimlich_beobachten:rHD: aE2:h:MASSENBEDROHUNG:rHD:
# aE2:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_fAN: aE2:H:REITTIER_erfassen:rHD_fAN: aE2:H:REITTIER_besorgen:rHD_fAN:
# a1543:F:PROVOKATION:zs:
# a1543:H:Der_PROVOKATION_nachgehen:zt:
# a1543:h:Eine_numinose_Einmischung_VORTÄUSCHEN:zs_zt: a1543:H:Dem_VORTÄUSCHEN_nachgehen:zs_zt:
# a1543:H:ABSURDITÄT_glaubhaft_zu_halten_VORTÄUSCHEN:zs_zt:
# anh531:F:Sonstiges_verkaufen:zs_zsa:
# anh531:h:Handeln_als_ABSURDITÄT:zs: anh531:h:Sachschaden_anrichten:zs: anh531:H:Schlußfolgerung_als_ABSURDITÄT:zs:
# anh531:f:Den_Vorgang_deuten:zs_zsa: anh531:H:ABSURDITÄT_glaubhaft_zu_halten_VORTÄUSCHEN:zs_zsa:
# aTMJ2672:#:#:#:
# anh395:#:#:#:
# a56B:#:#:#:
# a8:#:#:#:
# a38:#:#:#:
# anh921:#:#:#:
# anh483:#:#:#:
# a1640:#:#:#:
# anh483:#:#:#: anh483:h:#:#:
# a301:F:Auftrag_zum_Kochen:fHD:
# a301:f:PROVOKATION:rST_fHD: a301:h:Der_PROVOKATION_nachgehen:rST_fHD:
# a301:h:Auftrag_zum_Kochen:fHD: a301:h:Den_Vorgang_deuten:fHD:
# a301:F:Auftrag_zum_Kochen:rHD:
# a301:f:PROVOKATION:rHD_rST: a301:H:Der_PROVOKATION_nachgehen:rHD_rST: a301:H:Hilfeversprechen_erhalten:rHD_rST:
# a300:F:WASSERMANGEL_beheben:rHD_rHF: a300:F:Menschliche_OPFERGABE_beheben:rHD_rHF: a300:H:WAFFE_ZAUBERMITTEL_erhalten:rHD_rHF:
# a300:HF:ABRATEN_von_der_Mission:rHD_rVB: a300:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rVB:
# a300:H:Mut_zeigen:rHD_rPP:
# a300:H:Zweikampf:rHD_rAN:
# a300:H:WASSERMANGEL_beheben:rHD_rVB:
# a300:F:MARKIERUNGEN_anbringen:rHD_rAN:
# a300:F:MARKIERUNGEN_anbringen:rHD_rPP: a300:h:KONTAKT_abbrechen:rHD_rPP:
# a300:H:Den_Vorgang_deuten:rHD_fHD: a300:h:GIER_und_NEID_ausgelöst:rHD_fHD: a300:h:SCHLAF:rHD_fHD:
# a300:f:MISSETAT_planen:rHD_fHD: a300:h:MISSETAT_wie_Entmachtung:rHD_fHD: a300:h:MISSETAT_wie_Aneignung:rHD_fHD:
# a300:f:Heldentat_VORTÄUSCHEN:rVB_fHD:
# a300:H:Dem_VORTÄUSCHEN_nachgehen:rPP_fHD:
# a300:F:MISSETAT_beheben:rHD_rHF: a300:F:Krisenursachen_ergründen:rHD_rHF:
# a300:H:KONTAKT_wiederherstellen:rHD_rHP_rPP: a300:H:MARKIERUNGEN_vorlegen:rHD_rHP_rPP: a300:H:MARKIERUNGEN_erkennen:rHD_rHP_rPP:
# a300:H:Held_erkennen:rHF_rHP_fHD: a300:H:Bestrafung:rHF_rHP_fHD:
# a300:f:Heiraten:rHD_rPP:
# anh344:#:#:#:
# a922:f:PROVOKATION:zt_zf: a922:h:Der_PROVOKATION_nachgehen:zt_zf: a922:f:VERTRAG_abschließen_oder_verkünden:zt_zf:
# a992:F:Gutes_Benehmen:zs_zt: a992:H:Gutes_Benehmen:zs_zt: a992:H:Stifter_oder_Helfer_gewinnen:zs_zt:
# a992:f:RÄTSELHAFTES_Gespräch_oder_Handlung:zf_zfa:
# a992:H:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zt:
# a992:f:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zt_zf: a992:H:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zt_zf:
# a992:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:zs_zt_zf: a992:H:VERTRAGsbedingungen_erfüllen:zs_zt_zf:
# a930:f:VORHERSAGE_ungewünschte_Heiraten:rST_fHP:
# a930:h:Der_VORHERSAGE_nachgehen:rHD_rHH_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP: a930:h:TÖTUNG:rHD_rHH_fHP: a930:h:Aussetzung:rHD_rHH_fHP:
# a930:H:Adoption:rHD_rST:
# a930:H:Begegnung:rHD_rST_fHP: a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rST_fHP: a930:f:BOTSCHAFTEN_versenden:rHD_rST_fHP:
# a930:H:SCHLAF:rHD_rPP: a930:F:Liebe_wird_ausgelöst:rHD_rPP: a930:H:BOTSCHAFTEN_verfälschen:rHD_rPP:
# a930:H:Heiraten:rHD_rHP_rPP: a930:H:Die_VORHERSAGE_tritt_ein:rHD_rHP_rPP:
# a545B:F:Sorge_um_Hungernde_oder_Durstige:rHD_rHF: a545B:H:Sorge_um_Hungernde_oder_Durstige:rHD_rHF:
# a545B:H:Hilfeversprechen_erhalten:rHD_rHF:
# a545B:F:Reichtum_VORTÄUSCHEN:rHF_rHP: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP:
# a545B:F:Um_eine_Frau_werben:rHF_rHP: a545B:HF:Information_aus_zweiter_Hand:rHF_rHP: a545B:F:EINLADUNG:rHF_rHP:
# a545B:H:Einer_EINLADUNG_nachgehen:rHD_rHF:
# a545B:F:Verlust_VORTÄUSCHEN:rHF_rHP: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP:
# a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF: a545B:H:REITTIER_erhalten:rHD_rHF:
# a545B:H:Heiraten:rHD_rHF_rPP: a545B:H:Auf_dem_Heimweg:rHD_rHF_rPP:
# a545B:F:Eine_Bedrohung_VORTÄUSCHEN:rHF_fST: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_fST: a545B:H:VERTREIBUNG:rHF_fST:
# a545B:H:Fremdes_Gut_einziehen:rHD_rHF_rPP:
# a545B:f:Tod_VORTÄUSCHEN:rHD_rHF: a545B:Ff:Vertrauen_beweisen:rHD_rHF:
# a545B:h:Dem_VORTÄUSCHEN_nachgehen:rHD_rPP: a545B:h:Vertrauen_beweisen:rHD_rPP:
# a545B:H:Das_VORTÄUSCHEN_eingestehen:rHF_fST: a545B:hf:Wiedergutmachung_erpressen:rHF_fST:
# a545B:f:Wiedergutmachung_erpressen:rHD_rHF_fST: a545B:F:Eine_Bedrohung_VORTÄUSCHEN:rHD_rHF_fST: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_fST: a545B:H:Wiedergutmachung_erpressen:rHD_rHF_fST:
# a1164:h:Unerträgliche_Ungeheuerlichkeit:rHD_fHD: a1164:F:Ungewünschtes_Wesen_beseitigen:rHD_fHD:
# a1164:H:MISSETAT_wie_Jemanden_im_Stich_lassen:rHD_fHD:
# a1862B:Hh:Sorge_um_Hilfsbedürftige:rHD_fAN: a1862B:F:VERSPRECHEN_im_Austausch_für_Hilfe:rHD_fAN: a1862B:HF:Heldentat_VORTÄUSCHEN:rHD_fAN: a1862B:hf:TABU_Limit_nicht_überziehen:rHD_fAN:
# a1862B:F:WASSERMANGEL_beheben:rHD_rHP: a1862B:F:Menschliche_OPFERGABE_beheben:rHD_rHP: a1862B:F:VERTRAG_abschließen_oder_verkünden:rHD_rHP:
# a1862B:F:Um_einen_Auftrag_werben:rHD_rHP: a1862B:F:VERTRAG_abschließen_oder_verkünden:rHD_rHP:
# a1862B:F:Heldentat_VORTÄUSCHEN:rHD_fAN: a1862B:H:Ein_VERSPRECHEN_halten:rHD_fAN: a1862B:H:Eine_Bedrohung_VORTÄUSCHEN:rHD_fAN: a1862B:H:WASSERMANGEL_beheben:rHD_fAN: a1862B:H:Menschliche_OPFERGABE_beheben:rHD_fAN:
# a1862B:H:VERTRAGsbedingungen_erfüllen:rHD_rHP_rPP: a1862B:H:Heiraten:rHD_rHP_rPP:
# a1164:h:WASSERMANGEL:fAN: a1164:h:Eine_OPFERGABE_verlangen:fAN:
# a1164:F:WASSERMANGEL_beheben:rHD_rHP: a1164:F:Menschliche_OPFERGABE_beheben:rHD_rHP: a1164:F:Um_einen_Auftrag_werben:rHD_rHP:
# a1164:F:PROVOKATION:rHD_fHF: a1164:H:Der_PROVOKATION_nachgehen:rHD_fHF:
# a1164:h:TABU_nachgehen:rHD_fAN: a1164:f:Ein_VERSPRECHEN_halten:rHD_fAN: a1164:H:Eine_Gefahr_VORTÄUSCHEN:rHD_fAN: a1164:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fAN: a1164:H:Menschliche_OPFERGABE_beheben:rHD_fAN:
# a56A:#:#:#:
# a1543:H:Der_PROVOKATION_nachgehen:zt: a1543:H:Eine_numinose_Einmischung_VORTÄUSCHEN:zt:
# a1543:H:Dem_VORTÄUSCHEN_nachgehen:zs_zt: a1543:H:Behauptung_der_ABSURDITÄT:zs_zt:
# a1543:f:Den_Vorgang_deuten:zs_zt: a1543:h:Das_VORTÄUSCHEN_eingestehen:zs_zt: a1543:f:Gerechte_Rückgabe_fordern:zs_zt: a1543:H:Eine_löst_andere_ABSURDITÄT_aus:zs_zt:
# a1543:F:STREIT_SCHLICHTEN:zs_zt_zf: a1543:h:Den_Vorgang_deuten:zs_zt_zf: a1543:H:ABSURDITÄT_glaubhaft_zu_halten_VORTÄUSCHEN:zs_zt_zf: a1543:H:Behauptung_der_ABSURDITÄT:zs_zt_zf: a1543:H:Beglaubigen_der_Behauptung_der_ABSURDITÄT:zs_zt_zf:
# anh531:F:Sonstiges_verkaufen:zs_zt:
# a329:h:Tod_von_Angehörigen:rHD:
# a329:F:Die_potenzielle_Beute_begnadigen:rHD_rHF: a329:H:Die_potenzielle_Beute_begnadigen:rHD_rHF: a329:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF:
# a329:F:VERSTECKWETTE:rHD_rVB:
# a329:f:VERTRAG_abschließen_oder_verkünden:rHD_rPP:
# a329:h:VERSTECKWETTE:rHD_rHF:
# a329:h:VERSTECKWETTE:rHD_rPP:
# a329:H:VERSTECKWETTE:rHD_rHF:
# a329:H:VERSTECKWETTE:rHD_rPP:
# a329:H:Heiraten:rHD_rPP:
# anh344:#:#:#: anh344:h:#:#:
# a545B:F:Sorge_um_Hungernde_oder_Durstige:rHD_rHF: a545B:H:Sorge_um_Hungernde_oder_Durstige:rHD_rHF: a545B:H:Hilfeversprechen_erhalten:rHD_rHF:
# a545B:H:Einer_EINLADUNG_nachgehen:rHD_rHF: a545B:F:Verlust_VORTÄUSCHEN:rHD_rHF:
# a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_rHP: a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF_rHP: a545B:H:REITTIER_erhalten:rHD_rHF_rHP:
# a545B:H:Heiraten:rHD_rHF_rHP:
# a545B:H:Auf_dem_Heimweg:rHD_rHF_rPP:
# a545B:f:Vertrauen_beweisen:rHD_rHF_rPP: a545B:h:Vertrauen_beweisen:rHD_rHF_rPP:
# a545B:f:Wiedergutmachung_erpressen:rHD_rHF_fST: a545B:H:Eine_Bedrohung_VORTÄUSCHEN:rHD_rHF_fST: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_fST: a545B:H:Wiedergutmachung_erpressen:rHD_rHF_fST:
# a325:F:Zauberkunst_erlernen:rHD_rBZ:
# a325:HF:Unwissenheit_VORTÄUSCHEN:rHD_rZO:
# a325:H:Unwissenheit_VORTÄUSCHEN:rHD_rBZ: a325:H:Zauberkunst_erlernen:rHD_rBZ:
# a325:hf:TABU_Gegenstand_nicht_weitergeben:rHD_rHH:
# a325:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHH_rBZ:
# a325:Hh:FLUCHT:rHD_rBZ: a325:h:VERFOLGUNG:rHD_rBZ: a325:H:Die_Änderung_der_EXISTENZFORM:rHD_rBZ: a325:H:VERFOLGUNG_entkommen:rHD_rBZ:
# a930:h:Der_VORHERSAGE_nachgehen:rHH_fHP: a930:h:Heiraten:rHH_fHP:
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP: a930:h:TÖTUNG:rHD_rHH_fHP: a930:h:Aussetzung:rHD_rHH_fHP:
# a930:H:Begegnung:rHD_rST_fHP: a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST_fHP: a930:h:Adoption:rHD_rST_fHP:
# a930:f:Ungewünschtes_Wesen_beseitigen:rHD_fHP: a930:f:BOTSCHAFTEN_versenden:rHD_fHP:
# a930:F:Liebe_wird_ausgelöst:rHD_rHP_rPP: a930:H:BOTSCHAFTEN_verfälschen:rHD_rHP_rPP: a930:H:Heiraten:rHD_rHP_rPP:
# a910K:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rST_fHP:
# a910K:f:Ungewünschtes_Wesen_beseitigen:fHP_fAN: a910K:H:Einen_Bösen_einstellen:fHP_fAN: a910K:f:TODESAUFTRAG:fHP_fAN:
# a910K:f:FRUCHT_besorgen:rHD_fHP:
# a910K:H:FRUCHT_erfassen:rHD_rHP_fHP: a910K:H:FRUCHT_besorgen:rHD_rHP_fHP: a910K:H:Einem_TODESAUFTRAG_entkommen:rHD_rHP_fHP:
# a910K:H:Eigene_Misshandlung_nachforschen:fHP_fHP: a910K:H:TODESAUFTRAG:fHP_fHP:
# a910K:H:Ende:rHD_rPP:
# a314:h:RESPEKTLOSIGKEIT:rHD_fHH:
# a314:f:VERSPRECHEN_im_Austausch_für_Hilfe:rST_fHH:
# a314:F:Ein_VERSPRECHEN_halten:fHD_fHH: a314:h:Ein_VERSPRECHEN_halten:fHD_fHH:
# a314:F:Ein_VERSPRECHEN_halten:rHD_fHH: a314:H:Ein_VERSPRECHEN_halten:rHD_fHH:
# a314:F:Liebe_wird_ausgelöst:rHD_rST_rPP: a314:H:Heiraten:rHD_rST_rPP:
# a314:F:Auf_dem_Heimweg:rHD_rHP: a314:H:SCHLAF:rHD_rHP:
# a314:H:Die_SCHÖNE_erfassen:rHP_rHP:
# a314:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHP_rHP_fHP:
# a314:H:Bestrafung:rST_fHH:
# aTMJ1522_1:#:#:#:
# a1525:#:#:#:
# a1525#:#:#:#:
# a563:F:HUNGERSNOT_beheben:rHD_rHH:
# a563:F:Sorge_um_Freikaufsbedürftige:rHD_rHF: a563:H:Sorge_um_Freikaufsbedürftige:rHD_rHF: a563:H:Einen_Begleiter_gewinnen:rHD_rHF:
# a563:h:HUNGERSNOT:rHD_rHH: a563:F:HUNGERSNOT_beheben:rHD_rHH:
# a563:F:Sorge_um_Freikaufsbedürftige:rHD_rST: a563:H:Sorge_um_Freikaufsbedürftige:rHD_rST: a563:H:Hilfeversprechen_erhalten:rHD_rST:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rVB: a563:HF:Richtiges_erlangen:rHD_rVB:
# a563:H:Richtiges_erlangen:rHD_rST: a563:H:PROVIANTPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST:
# a563:HF:Richtiges_erlangen:rHD_rVB:
# a563:H:Richtiges_erlangen:rHD_rST: a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST: a563:HF:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rST:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH:
# a563:F:EINLADUNG:rHD_rHH_rAN: a563:h:Einer_EINLADUNG_nachgehen:rHD_rHH_rAN: a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHH_rAN: a563:h:GIER_und_NEID_ausgelöst:rHD_rHH_rAN: a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_rHH_rAN:
# a563:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rHH_fZM:
# a563:F:EINLADUNG:rHD_rZM_rAN: a563:H:Einer_EINLADUNG_nachgehen:rHD_rZM_rAN: a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:H:ANEIGNEN_beheben:rHD_rZM_rAN:
# a550:F:Erträumen:rHD_rHH_fHD: a550:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_rHH_fHD: a550:F:REITTIER_besorgen:rHD_rHH_fHD:
# a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD: a550:Hh:Den_ALTERNATIVEN_nachgehen:rHD_fHD:
# a550:H:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rVB:
# a550:HF:REITTIER_erfassen:rST_rVB:
# a550:HF:Information_aus_zweiter_Hand:rST_rVB:
# a550:H:REITTIER_erfassen:rHD_rZO:
# a531:Hh:Eines_auffälligen_GEGENSTANDES_habhaft_werden:rHD_rZM: a531:HF:Heiratszusage_erpressen:rHD_rZM:
# a531:H:Heiratszusage_erpressen:rHD_rZO: a531:H:Die_SCHÖNE_erfassen:rHD_rZO:
# a550:f:MISSETAT_planen:rHD_fHD: a550:h:MISSETAT_wie_Entmachtung:rHD_fHD:
# a550:h:Den_Vorgang_deuten:rHH_fHD: a550:h:Heldentat_VORTÄUSCHEN:rHH_fHD:
# a550:h:FREIHEITSBERAUBUNG:rPP_fHD:
# a550:H:FREIHEITSBERAUBUNG_beheben:rZO_rZO: a550:H:MISSETAT_beheben:rZO_rZO:
# a550:F:Bestrafung:rHD_rZO_fHD: a550:F:Heiraten:rHD_rZO_fHD:
# a563:F:Sorge_um_Freikaufsbedürftige:rHD_rST: a563:H:Sorge_um_Freikaufsbedürftige:rHD_rST:
# a563:H:Einen_Begleiter_gewinnen:rHD_rST:
# a563:H:Richtiges_erlangen:rHD_rST: a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST:
# a563:HF:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rVB:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH_rZM:
# a563:F:EINLADUNG:rHD_rZM_rAN: a563:h:Einer_EINLADUNG_nachgehen:rHD_rZM_rAN: a563:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:h:GIER_und_NEID_ausgelöst:rHD_rZM_rAN: a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_rZM_rAN:
# a563:F:EINLADUNG:rHD_rZM_rAN: a563:H:Einer_EINLADUNG_nachgehen:rHD_rZM_rAN: a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:H:ANEIGNEN_beheben:rHD_rZM_rAN: a563:H:HUNGERSNOT_beheben:rHD_rZM_rAN:
# a550:HF:Information_aus_zweiter_Hand:rHD_rVB:
# a531:Hh:Eines_auffälligen_GEGENSTANDES_habhaft_werden:rHD_rZM_rZO:
# a531:f:VOGEL_herbeiholen:rHD_fVB:
# a531:HF:Heiratszusage_erpressen:rHD_rZO:
# a304:f:Ungewollte_Verlobung_akzeptieren:rHH_fHH: a304:h:Ungewollte_Verlobung_akzeptieren:rHH_fHH: a304:H:FLUCHT:rHH_fHH: a304:H:Sich_niederlassen:rHH_fHH:
# a304:H:Wunderbare_EMPFÄNGNIS:rHH:
# a304:H:Zur_Welt_kommen:rHD_rHH:
# a304:F:Tapferkeit_beweisen:rHP:
# a304:h:Stifter_oder_Helfer_gewinnen:fHD_fHF:
# a304:H:Mehrere_Gegner_nacheinander_besiegen:rHD_fHF:
# a304:F:MARKIERUNGEN_anbringen:rHD_fVB:
# a304:Hh:Die_SCHÖNE_erfassen:rHD_rPP: a304:H:Beiwohnung_mit_der_schlafenden_Schönen:rHD_rPP: a304:F:MARKIERUNGEN_anbringen:rHD_rPP: a304:h:KONTAKT_abbrechen:rHD_rPP:
# a304:F:KONTAKT_wiederherstellen:rHP_fHD: a304:f:Heldentat_VORTÄUSCHEN:rHP_fHD: a304:h:MARKIERUNGEN_erkennen:rHP_fHD: a304:H:Dem_VORTÄUSCHEN_nachgehen:rHP_fHD:
# a304:H:KONTAKT_wiederherstellen:rHD_rHP: a304:H:MARKIERUNGEN_erkennen:rHD_rHP: a304:H:Held_erkennen:rHD_rHP: a304:H:Heiraten:rHD_rHP:
# a1528:#:#:#:
# anh391:#:#:#:
# a1553:#:#:#:
# a303:h:Kinderlosigkeit:rHH:
# a303:Hh:VERSPRECHEN_im_Austausch_für_Hilfe:rHH_rHP: a303:H:Magische_EMPFÄNGNISmittel_erhalten:rHH_rHP:
# a303:H:Zur_Welt_kommen:rHD_rHD: a303:H:Zur_Welt_kommen:rHD_rHD:
# a303:f:Ein_VERSPRECHEN_halten:rHD_rHH: a303:F:Um_einen_Auftrag_werben:rHD_rHH:
# a303:F:MARKIERUNGEN_anbringen:rHD_rHD_rZM: a303:h:KONTAKT_abbrechen:rHD_rHD_rZM:
# a327A:F:Gutes_Benehmen:rHD_rST: a327A:H:Gutes_Benehmen:rHD_rST: a327A:HF:Unwissenheit_VORTÄUSCHEN:rHD_rST:
# a327A:f:Gastfreundlichkeit_VORTÄUSCHEN:rHD_fHP: a327A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fHP:
# a327A:F:Unwissenheit_VORTÄUSCHEN:rHD_fHP: a327A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fHP: a327A:H:TÖTUNG:rHD_fHP:
# a303:H:REITTIER_erfassen:rHD_rHF_rPP: a303:H:Die_SCHÖNE_erfassen:rHD_rHF_rPP:
# a303:h:KONTAKT_abbrechen:rHD_rPP:
# a314:F:VERTRAG_abschließen_oder_verkünden:rHD_rVB:
# a314:F:Liebe_wird_ausgelöst:rHD_rPP:
# a314:F:RÄTSELHAFTES_Gespräch_oder_Handlung:rHD_rPP_fPP:
# a314:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:rHP_fVB:
# a314:H:Um_einen_Mann_werben:fHD_fHP: a314:H:Heiraten:fHD_fHP:
# a314:Hh:Um_einen_Mann_werben:fHD_fPP: a314:Hh:Heiraten:fHD_fPP:
# a314:h:RESPEKTLOSIGKEIT:rPP_fPP:
# a314:h:KRANKHEIT:rHP: a314:F:HEILMITTEL_besorgen:rHP:
# a314:H:TIERKÖRPERTEIL_erfassen:rHD_rZO:
# a314:Hh:HEILMITTEL_erfassen:rHD_fHD: a314:F:MARKIERUNGEN_anbringen:rHD_fHD:
# a314:h:HEILMITTEL_besorgen:fHD_fZO_fPP: a314:h:Heldentat_VORTÄUSCHEN:fHD_fZO_fPP:
# a314:h:KRANKHEIT_beheben:rHP_fZO_fPP:
# a314:H:HEILMITTEL_besorgen:rHD_rZO_rPP:
# a314:h:KRANKHEIT_beheben:rHP_rPP:
# a314:F:Krieg_führen:rHP_fHD:
# a314:F:Um_einen_Auftrag_werben:rHD_fHD: a314:h:RESPEKTLOSIGKEIT:rHD_fHD:
# a314:h:Krieg_führen:rHP_fHD:
# a314:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rPP:
# a314:H:IDENTITÄT_ändern:rHD: a314:H:Krieg_führen:rHD:
# a314:F:Intensive_ERKUNDUNGSAKTION:rHP:
# a314:f:NEUGIER_ausgelöst:fPP:
# a314:h:Der_NEUGIER_nachgehen:fHD_fPP: a314:f:Ungewünschtes_Wesen_beseitigen:fHD_fPP:
# a314:h:TÖTUNG:rHD_fHD:
# a303:H:MARKIERUNGEN_erkennen:rHH_rZM:
# a303:F:Um_einen_Auftrag_werben:rHD_rHH:
# a303:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rZM_rPP: a303:H:Wegweisung_erhalten:rHD_rZM_rPP: a303:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rZM_rPP:
# a303:H:Unterkommen:rHD_rPP: a303:F:RÄTSELHAFTES_Gespräch_oder_Handlung:rHD_rPP: a303:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:rHD_rPP: a303:H:Einen_Begleiter_gewinnen:rHD_rPP:
# a303:H:WIEDERBELEBEN:rHD_rHD_rPP:
# a314:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rHP_fHD: a314:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rHP_fHD: a314:H:MARKIERUNGEN_vorlegen:rHD_rHP_fHD: a314:H:MARKIERUNGEN_erkennen:rHD_rHP_fHD: a314:H:ANEIGNEN_beheben:rHD_rHP_fHD:
# a314:H:Bestrafung:rHP_fHD:
# a314:H:Heiraten:rHD_rPP:
# a314:H:KONTAKT_wiederherstellen:rHD_rPP: a314:H:Heiraten:rHD_rPP:
# a303:H:KONTAKT_wiederherstellen:rHD_rHH:
# a1199:#:#:#:
# a551:h:KRANKHEIT:rHD_rHH_fHD: a551:F:FRUCHT_besorgen:rHD_rHH_fHD:
# a551:F:Gutes_Benehmen:rST_fHD: a551:h:Gutes_Benehmen:rST_fHD: a551:h:FLUCH:rST_fHD:
# a551:h:FRUCHT_erfassen:fHD_fZO:
# a551:h:FRUCHT_besorgen:rHH_fHD_fZO: a551:h:Den_Vorgang_deuten:rHH_fHD_fZO:
# a551:h:FRUCHT_erfassen:rHH_fHD_fZO:
# a551:F:Gutes_Benehmen:rHD_rST: a551:H:Gutes_Benehmen:rHD_rST: a551:HF:PFÖRTNER_täuschen:rHD_rST: a551:HF:FRUCHT_erfassen:rHD_rST:
# a551:H:PFÖRTNER_täuschen:rHD_rBZ_fHF: a551:H:PFÖRTNER_entkommen:rHD_rBZ_fHF:
# a551:H:FRUCHT_erfassen:rHD_rBZ_rZO: a551:F:MARKIERUNGEN_anbringen:rHD_rBZ_rZO: a551:h:KONTAKT_abbrechen:rHD_rBZ_rZO:
# a551:H:FRUCHT_besorgen:rHD_rHH:
# a551:H:MARKIERUNGEN_erkennen:rBZ: a551:F:KONTAKT_wiederherstellen:rBZ: a551:F:Intensive_ERKUNDUNGSAKTION:rBZ:
# a551:h:Intensive_ERKUNDUNGSAKTION_nachgehen:rBZ_fHD: a551:h:IDENTITÄT_beweisen:rBZ_fHD:
# a551:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rBZ: a551:H:IDENTITÄT_beweisen:rHD_rBZ: a551:H:Held_erkennen:rHD_rBZ:
# a551:H:Heiraten:rHD_rBZ: a551:H:Ende:rHD_rBZ:
# a715:h:VERLUST_von_Tieren_Früchten_Ernte_usw:rHD_rAN: a715:F:VERLUSTursache_beheben:rHD_rAN:
# a715:H:Universellen_ZAUBERMITTEL_erfassen:rHD_rZM:
# a715:H:Mut_zeigen:rHD_rAN_fVB:
# a715:f:Einem_Gemenge_entkommen:rHD_rAN_fVB:
# a715:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a715:H:Einem_Gemenge_entkommen:rHD_rZM:
# a715:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a715:H:Einem_Gemenge_entkommen:rHD_rZM: a715:f:Schrecken_ausgelöst:rHD_rZM:
# a715:f:Hitze_entkommen:rAN_fVB:
# a715:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM: a715:H:Hitze_entkommen:rHD_rZM:
# a715:F:NEUGIER_ausgelöst:rHD_rAN: a715:h:Der_NEUGIER_nachgehen:rHD_rAN: a715:H:Bestrafung:rHD_rAN:
# a715:H:VERLUSTursache_beheben:rHD: a715:H:Ende:rHD:
# a910B:HF:WEISHEITEN_erhalten:rHD_rHH:
# a910B:H:WEISHEITEN_nachgehen:rHD:
# a505:F:Sorge_um_Freikaufsbedürftige:rHD_rST: a505:H:Sorge_um_Freikaufsbedürftige:rHD_rST:
# a563:h:HUNGERSNOT:rHD_rHH:
# a563:F:Die_potenzielle_Beute_begnadigen:rHD_rST_rZM: a563:H:Die_potenzielle_Beute_begnadigen:rHD_rST_rZM: a563:H:PROVIANTPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rHH_rZM: a563:H:HUNGERSNOT_beheben:rHD_rHH_rZM:
# a563:F:EINLADUNG:rHH_rHH:
# a563:HF:Information_aus_zweiter_Hand:rHH_rAN: a563:h:Einer_EINLADUNG_nachgehen:rHH_rAN:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:h:GIER_und_NEID_ausgelöst:rHD_rZM_rAN: a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_rZM_rAN:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a563:H:Hilfe_erpressen:rHD_rST_rZM: a563:H:Einen_gold_oder_GELDPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:Hh:Potenziellen_Feind_zum_Gastgeber_gewinnen:rHD_rZM_rAN: a563:hf:Verbot_als_ABSURDITÄT:rHD_rZM_rAN:
# a563:h:ABSURDITÄT_nachgehen:rZM_rAN: a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rZM_rAN: a563:h:GIER_und_NEID_ausgelöst:rZM_rAN: a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rZM_rAN:
# a563:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_fZM:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a563:H:Hilfe_erpressen:rHD_rST_rZM: a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rZM:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_rAN: a563:H:ANEIGNEN_beheben:rHD_rZM_rAN:
# a563:H:Ende:rHD_rHH:
# a650A:h:Eine_ENTFÜHRUNG:rHH_fHH:
# a650A:H:Zur_Welt_kommen:rHD:
# a650A:F:Krisenursachen_ergründen:rHD_rHH: a650A:F:Eine_ENTFÜHRUNG_beheben:rHD_rHH:
# a650A:H:Zweikampf:rHD_fHH: a650A:H:Eine_ENTFÜHRUNG_beheben:rHD_fHH:
# a650A:H:KONTAKT_abbrechen:rHD_rHH:
# a650A:f:VERTRAG_abschließen_oder_verkünden:rHD_rAN:
# a650A:f:HOLZ_besorgen:rHD_rAN:
# a650A:H:HOLZ_Sammeln_in_Angriff_nehmen:rHD_rZO:
# a650A:H:HOLZ_besorgen:rHD_rZO_rAN: a650A:f:Schrecken_ausgelöst:rHD_rZO_rAN:
# a650A:f:ZOLLERHEBUNG_vollstrecken:rHD_rAN:
# a650A:H:ZOLLERHEBUNG_in_Angriff_nehmen:rHD_rBZ_rZO: a650A:H:UNGEHEUER_erfassen:rHD_rBZ_rZO:
# a650A:H:UNGEHEUER_herbeiholen:rHD_rBZ_rAN: a650A:f:Schrecken_ausgelöst:rHD_rBZ_rAN:
# a650A:f:Tiere_MÄSTEN:rHD_rAN:
# a650A:H:Tiere_MÄSTEN_in_Angriff_nehmen:rHD_rAN_fHF: a650A:f:VERFOLGUNG:rHD_rAN_fHF: a650A:H:VERFOLGUNG_entkommen:rHD_rAN_fHF: a650A:H:VERTRAG_auflösen:rHD_rAN_fHF:
# a301:F:Zum_STAUNEN_bringen:rHD_fHD: a301:H:Dem_STAUNEN_nachgehen:rHD_fHD: a301:H:Einen_Begleiter_gewinnen:rHD_fHD:
# a301:f:PROVOKATION:fHD_fAN: a301:h:Der_PROVOKATION_nachgehen:fHD_fAN:
# a301:h:Auftrag_zum_Kochen:fHD:
# a301:f:PROVOKATION:rHD_fAN: a301:H:Der_PROVOKATION_nachgehen:rHD_fAN:
# a301:H:Wegweisung_erpressen:rHD_fAN:
# a301:H:Sich_abseilen_LASSEN:rHD_fHD:
# a301:HF:ABRATEN_von_der_Mission:rHD_rPP: a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP:
# a301:H:Zweikampf:rHD_rAN:
# a301:F:Krisenursachen_ergründen:rHD_rPP: a301:HF:MISSETAT_beheben:rHD_rPP: a301:Hh:Der_MISSETATwarnung_nachgehen:rHD_rPP: a301:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rPP:
# a301:h:MISSETAT_wie_Jemanden_im_Stich_lassen:rHD_fHD:
# a301:h:Den_ALTERNATIVEN_nachgehen:rHD_fZM:
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB: a300:F:WASSERMANGEL_beheben:rHD_rVB: a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB:
# a300:H:Mut_zeigen:rHD_rAN:
# a300:F:GEGENLEISTUNG_für_die_LEISTUNG:rHD_rHP:
# a300:H:WASSERMANGEL_beheben:rVB:
# a300:F:Heiraten:rHD_rHP: a300:h:Heiraten:rHD_rHP: a300:H:Um_GEGENLEISTUNG_bitten:rHD_rHP: a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP:
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST: a300:H:Sorge_um_Schutzbedürftige:rHD_rST:
# a300:F:Hilfeversprechen_erhalten:rHD_rHF: a300:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF:
# a300:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHP:
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF: a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF: a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF:
# a300:H:Sorge_um_Mitleidsbedürftige:rHD_rHF: a300:H:Eine_BEHINDERUNG_beheben:rHD_rHF:
# a301:f:ZWANGSEHE_Drohung:rHD_rPP_fHD: a301:H:ZWANGSEHE_Drohung_beheben:rHD_rPP_fHD: a301:H:Bestrafung:rHD_rPP_fHD:
# a301:F:Heiraten:rHD_rPP:
# a531:h:SCHLAF:rHD_rVB: a531:f:NEUGIER_ausgelöst:rHD_rVB: a531:h:Der_NEUGIER_nachgehen:rHD_rVB:
# a531:h:Der_NEUGIER_nachgehen:rHD_rAN: a531:h:SCHLAF_unterbrechen:rHD_rAN: a531:H:Den_Vorgang_deuten:rHD_rAN:
# a531:f:FEHLENDEN_Gegenstand_besorgen:rHD_rAN:
# a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rZO: a531:HF:Heiratszusage_erpressen:rHD_rZO:
# a531:H:Heiratszusage_erpressen:rHD_rZO:
# a531:h:Abtretung_der_Schönen_stehet_bevor:rHD_rZO:
# a531:f:Begehren_einer_Person_oder_eines_GEGENSTANDES:rZO_rAN:
# a531:F:Sich_einem_magischen_EINGRIFF_unterziehen:rZO_rAN: a531:HF:Einen_magischen_EINGRIFF_vorbereiten:rZO_rAN:
# a531:H:Einen_magischen_EINGRIFF_vorbereiten:rZO_rAN:
# a531:F:Heilkunst_VORTÄUSCHEN:rZO_rAN: a531:H:Dem_VORTÄUSCHEN_nachgehen:rZO_rAN: a531:H:Sich_einem_magischen_EINGRIFF_unterziehen:rZO_rAN:
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD:
# a550:h:Den_Vorgang_deuten:rHH_rZO_fHD: a550:h:Heldentat_VORTÄUSCHEN:rHH_rZO_fHD: a550:H:Hochzeit_verschieben:rHH_rZO_fHD:
# a550:F:MISSETAT_beheben:rZO_rZO:
# a550:F:Bestrafung:rHD_fHD:
# a550:F:Heiraten:rHD_rZO:
# a545B:F:Den_Einbrecher_begnadigen:rHD_rHF: a545B:H:Den_Einbrecher_begnadigen:rHD_rHF: a545B:H:Hilfeversprechen_erhalten:rHD_rHF:
# a545B:F:Reichtum_VORTÄUSCHEN:rHF_rHP: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP: a545B:F:NEUGIER_ausgelöst:rHF_rHP:
# a545B:F:Um_eine_Frau_werben:rHF_rHP: a545B:HF:Information_aus_zweiter_Hand:rHF_rHP: a545B:H:Der_NEUGIER_nachgehen:rHF_rHP: a545B:F:EINLADUNG:rHF_rHP:
# a545B:H:Einer_EINLADUNG_nachgehen:rHF_rHP: a545B:HF:Verlust_VORTÄUSCHEN:rHF_rHP:
# a545B:F:Verlust_VORTÄUSCHEN:rHD_rHF_fHF: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_fHF: a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF_fHF: a545B:f:Zum_STAUNEN_bringen:rHD_rHF_fHF: a545B:h:Dem_STAUNEN_nachgehen:rHD_rHF_fHF:
# a545B:F:Unzufriedenheit_VORTÄUSCHEN:rHD_rHF_fHF: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_fHF: a545B:F:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF_fHF: a545B:H:REITTIER_erhalten:rHD_rHF_fHF:
# a545B:f:Zum_STAUNEN_bringen:rHD_rHF_rHP: a545B:h:Dem_STAUNEN_nachgehen:rHD_rHF_rHP: a545B:H:Unzufriedenheit_VORTÄUSCHEN:rHD_rHF_rHP: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_rHP:
# a545B:F:Auftrag_zum_VOTÄUSCHEN:rHF_rVB: a545B:F:Reichtum_VORTÄUSCHEN:rHF_rVB:
# a545B:H:Auftrag_zum_VOTÄUSCHEN:rVB_fHF: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rVB_fHF:
# a545B:F:Eine_Bedrohung_VORTÄUSCHEN:rHF_fST: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_fST: a545B:H:TÖTUNG:rHF_fST:
# a545B:f:Vertrauen_beweisen:rHD_rHF: a545B:F:Tod_VORTÄUSCHEN:rHD_rHF: a545B:h:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF: a545B:h:Vertrauen_beweisen:rHD_rHF:
# a545B:h:Das_VORTÄUSCHEN_eingestehen:rHD_rHF: a545B:h:Wiedergutmachung_erpressen:rHD_rHF:
# a315A:h:Tod_von_Angehörigen:rHH_fHH: a315A:h:Heiraten:rHH_fHH:
# a315A:h:Missgeburt:fHD:
# a315A:h:VERLUST_von_Tieren_Früchten_Ernte_usw:rHD:
# a315A:F:VERLUSTursache_beheben:rHD_fHD: a315A:H:Krisenursachen_ergründen:rHD_fHD: a315A:h:MISSETAT_wie_Kannibalismus:rHD_fHD:
# a315A:h:Den_Vorgang_deuten:rHD_rHH_fHH: a315A:HF:MISSETAT_beheben:rHD_rHH_fHH: a315A:Hh:Der_MISSETATwarnung_nachgehen:rHD_rHH_fHH: a315A:h:KONTAKT_abbrechen:rHD_rHH_fHH:
# a321:H:Krisenursachen_ergründen:rHD_rRE_rVB: a321:h:BEHINDERUNG_durch_Verstümmelung:rHD_rRE_rVB: a321:hf:TABU_Land_nicht_betreten:rHD_rRE_rVB:
# a321:h:TABU_nachgehen:rHD_rAN: a321:H:Zweikampf:rHD_rAN:
# a321:H:Kaiserschnitt:rHD_rHF: a321:H:Adoption:rHD_rHF:
# a315A:Hh:KONTAKT_abbrechen:rHD_rVB: a315A:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rVB:
# a315A:h:MISSETAT_wie_Kannibalismus:rHD_rHF_fHD: a315A:Hh:FLUCHT:rHD_rHF_fHD: a315A:h:VERFOLGUNG:rHD_rHF_fHD: a315A:H:VERFOLGUNG_entkommen:rHD_rHF_fHD:
# a321:H:Ende:rHD_rHF_rVB:
# a1164:h:Unerträgliche_Ungeheuerlichkeit:rHD_rAN:
# a1164:F:Ungewünschtes_Wesen_beseitigen:rHD_rAN: a1164:H:MISSETAT_wie_Jemanden_im_Stich_lassen:rHD_rAN:
# a1862B:Hh:Sorge_um_Hilfsbedürftige:rHD_fAN: a1862B:F:VERSPRECHEN_im_Austausch_für_Hilfe:rHD_fAN: a1862B:HF:Heldentat_VORTÄUSCHEN:rHD_fAN:
# a1862B:F:WASSERMANGEL_beheben:rHD_rHP: a1862B:F:VERSPRECHEN_im_Austausch_für_Hilfe:rHD_rHP:
# a1862B:F:Heldentat_VORTÄUSCHEN:rHD_fAN: a1862B:H:Ein_VERSPRECHEN_halten:rHD_fAN: a1862B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fAN: a1862B:hf:TABU_Limit_nicht_überziehen:rHD_fAN:
# a1862B:H:WASSERMANGEL_beheben:rHD_rHP_rPP: a1862B:H:Ein_VERSPRECHEN_halten:rHD_rHP_rPP: a1862B:H:Heiraten:rHD_rHP_rPP:
# a1164:F:WASSERMANGEL_beheben:rHD_rHP:
# a1164:h:TABU_nachgehen:rHD_fAN: a1164:H:Eine_Gefahr_VORTÄUSCHEN:rHD_fAN: a1164:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fAN: a1164:H:WASSERMANGEL_beheben:rHD_fAN: a1164:H:Ende:rHD_fAN:
# a1633:h:Tod_von_Angehörigen:zsa:
# a1633:f:Wahl_als_ABSURDITÄT:zs_zsa:
# a1633:h:ABSURDITÄT_nachgehen:zs_zsa:
# a1633:h:ABSURDITÄT_nachgehen:zsa:
# a1633:H:ABSURDITÄT_nachgehen:zs:
# a1633:Hh:Der_ABSURDITÄT_entgegentreten:zs_zsa: a1633:h:KONTAKT_abbrechen:zs_zsa:
# a1920H:f:Auftrag_zum_Unterhalten:zt_zsa: a1920H:h:Auftrag_zum_Unterhalten:zt_zsa: a1920H:h:VERSCHLINGEN:zt_zsa:
# a1920H:Hh:Der_ABSURDITÄT_entgegentreten:zsa: a1920H:h:KONTAKT_abbrechen:zsa:
# a1920H:h:VERSCHLINGEN:zsa:
# a1920H:f:Auftrag_zum_Unterhalten:zs_zt: a1920H:F:VERTRAG_abschließen_oder_verkünden:zs_zt:
# a1960:F:ERZÄHLEN_beginnen:zs_zt: a1960:F:PROVOKATION:zs_zt: a1960:h:Der_PROVOKATION_nachgehen:zs_zt:
# a1960:F:PROVOKATION:zs_zt: a1960:h:Der_PROVOKATION_nachgehen:zs_zt:
# a1960:F:PROVOKATION:zs_zt: a1960:H:Der_PROVOKATION_nachgehen:zs_zt: a1960:H:ERZÄHLEN_beenden:zs_zt: a1960:H:Auf_dem_VERTRAG_bestehen:zs_zt:
# a1920H:H:VERTRAGsbedingungen_erfüllen:zs_zt_zsa: a1920H:H:VERSCHLINGEN_beheben:zs_zt_zsa:
# a1633:H:Ende:zs_zsa:
# a552:F:Ungewollte_Verlobung_akzeptieren:rHD_rHH_fHD: a552:h:Tod_von_Angehörigen:rHD_rHH_fHD:
# a552:F:Ungewollte_Verlobung_akzeptieren:rST_fHD: a552:h:Ungewollte_Verlobung_akzeptieren:rST_fHD:
# a552:H:Ungewollte_Verlobung_akzeptieren:rHD_rST:
# a552:H:Heiraten:rHD_fHD:
# a552:h:Eine_ENTFÜHRUNG:rPP_rAN:
# a552:HF:Wegweisung_mit_ALTERNATIVEN:rHD_fHD: a552:Hh:Den_ALTERNATIVEN_nachgehen:rHD_fHD:
# a552:F:Auf_Hilfsquelle_zurückgreifen:rHD_rVB:
# a552:H:Vermittlung:rST_rVB:
# a552:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST_rZM: a552:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST_rZM: a552:H:REITTIER_erhalten:rHD_rST_rZM:
# a552:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST_rZM: a552:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a552:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a552:Hh:ABRATEN_von_der_Mission:rHD_rPP: a552:h:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP:
# a552:h:Zweikampf:rHD_rAN:
# a552:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM:
# a552:H:Zweikampf:rHD_rAN:
# a552:HF:ABRATEN_von_der_Mission:rHD_rPP: a552:h:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP:
# a552:HF:ABRATEN_von_der_Mission:rHD_rPP: a552:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP:
# a552:h:Zweikampf:rHD_rPP_rAN:
# a552:F:Sorge_um_Freikaufsbedürftige:rHD_rPP: a552:H:Sorge_um_Freikaufsbedürftige:rHD_rPP: a552:h:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP:
# a552:H:Ende:rHD_rPP:
# a329:H:Sorge_um_Schutzbedürftige:rHD_rHF:
# a329:H:Sorge_um_Hilfsbedürftige:rHD_rHF:
# a329:F:Sorge_um_Schutzbedürftige:rHD_rHF: a329:H:Sorge_um_Schutzbedürftige:rHD_rHF: a329:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF:
# a329:f:VERTRAG_abschließen_oder_verkünden:rHD_rHP_rPP:
# a329:F:Letzte_Gelegenheit_nützen:rHD_rHP_rPP:
# a329:H:VERSTECKWETTE:rHD_rHF_rPP:
# a329:H:VERSTECKWETTE:rHD_rHP_rPP:
# a327B:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_fHD: a327B:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_fHD:
# a327B:Hh:Unterkommen:rHD_rAN_fHD: a327B:f:Gastfreundlichkeit_VORTÄUSCHEN:rHD_rAN_fHD: a327B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN_fHD:
# a327B:f:KANNIBALISMUS:rHD_rAN:
# a327B:F:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN: a327B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN:
# a327B:H:IDENTITÄT_ändern:rHD_rAN_fHD:
# a327B:F:Schlaf_VORTÄUSCHEN:rHD_rAN_rAN: a327B:H:Personenschaden_anrichten:rHD_rAN_rAN:
# a327B:f:Auftrag_zum_Kochen:rHD_rAN:
# a327B:H:Auftrag_zum_Kochen:rHD_rAN: a327B:Hh:Jemanden_in_Kannibalismus_verwickeln:rHD_rAN:
# a327B:H:FLUCH:rHD_rAN: a327B:h:VERFOLGUNG:rHD_rAN: a327B:H:VERFOLGUNG_entkommen:rHD_rAN:
# a328:f:VERTRAG_abschließen_oder_verkünden:rHD_rHP: a328:f:SELTENEN_Gegenstand_besorgen:rHD_rHP:
# a328:F:Rebellion_des_Zielobjektes_VORTÄUSCHEN:rHD_rBZ_rZO: a328:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rBZ_rZO: a328:H:SELTENEN_Gegenstand_erfassen:rHD_rBZ_rZO: a328:H:FLUCHT:rHD_rBZ_rZO:
# a328:h:VERFOLGUNG:rHD_rBZ: a328:H:VERFOLGUNG_entkommen:rHD_rBZ:
# a328:H:SELTENEN_Gegenstand_besorgen:rHD_rHP: a328:f:SELTENEN_Gegenstand_besorgen:rHD_rHP:
# a328:H:SELTENEN_Gegenstand_besorgen:rHD_rHP: a328:f:NUTZTIER_besorgen:rHD_rHP:
# a328:F:Rebellion_des_Zielobjektes_VORTÄUSCHEN:rHD_rBZ_rZO: a328:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rBZ_rZO: a328:H:NUTZTIER_erfassen:rHD_rBZ_rZO: a328:H:FLUCHT:rHD_rBZ_rZO:
# a328:H:NUTZTIER_besorgen:rHD_rHP: a328:f:UNGEHEUER_herbeiholen:rHD_rHP: a328:F:VERTRAG_abschließen_oder_verkünden:rHD_rHP:
# a328:H:IDENTITÄT_ändern:rHD:
# a328:H:Geänderte_IDENTITÄT_VORTÄUSCHEN:rHD_rBZ: a328:F:Truhe_herstellen:rHD_rBZ: a328:F:Testnotwendigkeit_VORTÄUSCHEN:rHD_rBZ: a328:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rBZ: a328:H:UNGEHEUER_erfassen:rHD_rBZ:
# a328:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rBZ:
# a328:f:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_rBZ: a328:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rBZ:
# a328:H:UNGEHEUER_herbeiholen:rHD_rBZ_rHP: a328:H:VERSCHLINGEN:rHD_rBZ_rHP:
# a328:F:VERFOLGUNG:rHD_rBZ: a328:H:TÖTUNG:rHD_rBZ:
# a328:H:VERSCHLINGEN_beheben:rHD_rHP_rPP: a328:H:VERTRAGsbedingungen_erfüllen:rHD_rHP_rPP: a328:H:Heiraten:rHD_rHP_rPP:
# a812:h:WASSERMANGEL:rAN:
# a812:F:ABRATEN_von_der_Mission:rHD_rVB: a812:h:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rVB:
# a812:f:Rätsel_lösen:rHD_rAN:
# a812:H:Rätsel_lösen:rHD_rAN: a812:H:WASSERMANGEL_beheben:rHD_rAN:
# aU:#:#:rHD_rHH:
# a531:h:Überrascht_werden_oder_geraten:rHD_rAN: a531:f:VERTRAG_abschließen_oder_verkünden:rHD_rAN:
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB: a531:hf:JUWELEN_besorgen:rAN_fVB:
# a531:f:JUWELEN_besorgen:rHD_rAN:
# a531:F:Sorge_um_Schutzbedürftige:rHD_rHF: a531:H:Sorge_um_Schutzbedürftige:rHD_rHF: a531:H:JUWELEN_erfassen:rHD_rHF:
# a531:F:JUWELEN_besorgen:rHD_rZO_rAN:
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB: a531:hf:HEILMITTEL_besorgen:rAN_fVB:
# a531:f:HEILMITTEL_besorgen:rHD_rAN:
# a531:F:Sorge_um_Schutzbedürftige:rHD_rHF: a531:H:Sorge_um_Schutzbedürftige:rHD_rHF: a531:HF:Zuschnappendes_Hindernis_überwinden:rHD_rHF:
# a531:H:HEILMITTEL_erfassen:rHD_rHF_rZO:
# a531:H:HEILMITTEL_besorgen:rHD_rAN:
# a531:f:Zu_Beauftragungen_anregen:rAN_fVB: a531:hf:Die_SCHÖNE_herbeiholen:rAN_fVB:
# a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN:
# a513A:F:Zum_STAUNEN_bringen:rHD_rHF: a513A:H:Dem_STAUNEN_nachgehen:rHD_rHF: a513A:H:Einen_Begleiter_gewinnen:rHD_rHF:
# a516:HF:ABRATEN_von_der_Mission:rHD_fZO: a516:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_fZO: a516:HF:Hartes_Großes_Mächtiges_mit_Weichem_Kleinem_Schwachem_bewältigen:rHD_fZO: a516:HF:Baumersteigen:rHD_fZO: a516:H:Universellen_ZAUBERMITTEL_erhalten:rHD_fZO:
# a516:f:Um_eine_Frau_werben:rHD_rBZ: a516:f:VERTRAG_abschließen_oder_verkünden:rHD_rBZ:
# a516:f:Baumersteigen:rHD_rBZ: a516:H:Baumersteigen:rHD_rBZ:
# a513A:f:Gegen_ein_Tier_kämpfen:rHD_rBZ: a513A:H:Gegen_ein_Tier_kämpfen:rHD_rBZ:
# a513A:f:WETTLAUF:rHF_rBZ:
# a513A:H:WETTLAUF_in_Angriff_nehmen:rHF_rBZ_fHF: a513A:H:WETTLAUF:rHF_rBZ_fHF:
# a513A:f:Hitze_entkommen:rHF_rBZ: a513A:F:Hitze_entkommen:rHF_rBZ:
# a513A:F:VERTRAG_auflösen:rHF_rBZ:
# a531:H:Auf_dem_Heimweg:rHD_rAN:
# aU:H:Ende:rHD_rHH:
# a611:H:Verlobung_wird_arrangiert:rHH_fHP:
# a611:h:Tod_von_Angehörigen:rHH:
# a611:h:ZWANGSEHE_Drohung:rPP_fHD_fHP:
# a611:F:PROVOKATION:rHD_rVB: a611:H:Der_PROVOKATION_nachgehen:rHD_rVB: a611:F:NEUGIER_ausgelöst:rHD_rVB:
# a611:H:Der_NEUGIER_nachgehen:rHD_rHH: a611:H:Krisenursachen_ergründen:rHD_rHH: a611:F:ZWANGSEHE_Drohung_beheben:rHD_rHH:
# a611:F:Wissen_VORTÄUSCHEN:rHD_rST_rZM: a611:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rST_rZM: a611:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a571:F:ZWANGSEHE_Drohung_beheben:rHD_rVB:
# a571:H:PARALYSIERUNG:rHD_rZM_fHD:
# a571:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fHP:
# a571:H:PARALYSIERUNG:rHD_rZM_fHF:
# a571:Hh:VERSPRECHEN_im_Austausch_für_Hilfe:rHD_rZM_fHP: a571:H:PARALYSIERUNG_beheben:rHD_rZM_fHP: a571:H:Ein_VERSPRECHEN_halten:rHD_rZM_fHP: a571:H:ZWANGSEHE_Drohung_beheben:rHD_rZM_fHP: a571:H:Bestrafung:rHD_rZM_fHP:
# a611:H:Heiraten:rHD_rPP:
# a2031C:#:#:#:
# a465:F:Schicksalsbestimmender_Weisung_folgen:rHD:
# a465:F:Ungewollte_Verlobung_akzeptieren:rHD_rPP:
# a465:H:Überraschende_positive_Wendung:rHD_rPP: a465:H:Die_Änderung_der_EXISTENZFORM:rHD_rPP:
# a465:H:Sonstiges_herstellen:rHD_rPP: a465:F:Sonstiges_verkaufen:rHD_rPP:
# a465:H:Sonstiges_verkaufen:rHD_fVB:
# a465:H:Sonstiges_verkaufen:rHD_fAN:
# a465:f:NEUGIER_ausgelöst:rHD_fVB_fAN:
# a465:h:Der_NEUGIER_nachgehen:rHD_fAN: a465:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fAN:
# a465:F:SELTENEN_Gegenstand_besorgen:rHD_fVB_fAN:
# a465:F:Auf_Hilfsquelle_zurückgreifen:rHD_rZM_rPP: a465:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rZM_rPP: a465:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rZM_rPP:
# a465:H:Einen_Begleiter_gewinnen:rHD_rHF_rHP:
# a465:H:Sich_oder_andere_tragen_LASSEN:rHD_rHF:
# a465:H:SELTENEN_Gegenstand_erfassen:rHF_rBZ_rZO:
# a465:H:TÖTUNG:rHD_rHF_rBZ:
# a465:H:MASSENBEDROHUNG_beheben:rHD_rHF_rVB:
# a465:H:Auf_dem_Heimweg:rHD_rHF:
# a465:H:SELTENEN_Gegenstand_besorgen:rHD_fAN: a465:H:VERTRAG_auflösen:rHD_fAN:
# a1640:h:Unerträgliche_Faulheit:zs_zsa:
# a1640:f:VERLOCKUNG:zs_zsa: a1640:h:Der_VERLOCKUNG_nachgehen:zs_zsa: a1640:h:VERTREIBUNG:zs_zsa: a1640:H:Die_Beschaffung_der_AUSRÜSTUNG:zs_zsa:
# a1640:F:Kraft_VORTÄUSCHEN:zs_zt: a1640:H:Dem_VORTÄUSCHEN_nachgehen:zs_zt:
# a1640:H:Sich_oder_andere_tragen_LASSEN:zs_zt: a1640:F:Kraft_VORTÄUSCHEN:zs_zt: a1640:h:Dem_VORTÄUSCHEN_nachgehen:zs_zt:
# a1640:H:Einer_EINLADUNG_nachgehen:zs_zt: a1640:F:SONSTIGE_AUFGABE_erledigen:zs_zt: a1640:Hh:SONSTIGE_AUFGABE_in_Angriff_nehmen:zs_zt: a1640:F:Krankheit_VORTÄUSCHEN:zs_zt: a1640:H:Dem_VORTÄUSCHEN_nachgehen:zs_zt:
# a1640:F:SONSTIGE_AUFGABE_erledigen:zs_zt: a1640:Hh:SONSTIGE_AUFGABE_in_Angriff_nehmen:zs_zt: a1640:F:Kraft_VORTÄUSCHEN:zs_zt: a1640:H:Dem_VORTÄUSCHEN_nachgehen:zs_zt:
# a1640:F:Eine_Bedrohung_VORTÄUSCHEN:zs_zt: a1640:H:Dem_VORTÄUSCHEN_nachgehen:zs_zt: a1640:Hh:FLUCHT:zs_zt:
# a1640:H:Sich_sonstige_Dinge_ANEIGNEN:zs:
# a1640:F:Überrascht_werden_oder_geraten:zt_zf: a1640:H:Den_Vorgang_deuten:zt_zf: a1640:F:Auf_Hilfsquelle_zurückgreifen:zt_zf:
# a1640:F:Eine_Bedrohung_VORTÄUSCHEN:zs_zt_zf: a1640:H:Dem_VORTÄUSCHEN_nachgehen:zs_zt_zf: a1640:H:Bestrafung:zs_zt_zf:
# a1640:H:Ende:zs:
# a313:h:Kinderlosigkeit:rHH:
# a313:Hh:VERSPRECHEN_im_Austausch_für_Hilfe:rHH_rZM_fST: a313:H:Magische_EMPFÄNGNISmittel_erhalten:rHH_rZM_fST:
# a313:H:Wunderbare_EMPFÄNGNIS:rHH_rHH:
# a313:H:Zur_Welt_kommen:rHD:
# a313:H:Ein_VERSPRECHEN_halten:rHD_rHH:
# a400:HF:Heiratszusage_erpressen:rHD_rST:
# a400:H:Heiratszusage_erpressen:rHD_rPP:
# a313:f:VERTRAG_abschließen_oder_verkünden:rHD_fHP:
# a313:f:SONSTIGE_AUFGABE_erledigen:rHD_fHP:
# a313:F:Auf_Hilfsquelle_zurückgreifen:rHD_rPP: a313:H:SONSTIGE_AUFGABE_erledigen:rHD_rPP:
# a313:F:Bauwerk_errichten:rHD_fHP:
# a313:F:Auf_Hilfsquelle_zurückgreifen:rHD_rPP: a313:H:Bauwerk_errichten:rHD_rPP:
# a313:F:REITTIER_besorgen:rHD_fHP:
# a313:HF:Auf_Hilfsquelle_zurückgreifen:rHD_rPP: a313:H:Hilfeversprechen_erhalten:rHD_rPP: a313:HF:Richtiges_auswählen:rHD_rPP: a313:F:GEHEIMZEICHEN_vermitteln:rHD_rPP:
# a313:H:REITTIER_besorgen:rHD_fHP: a313:F:Auf_dem_VERTRAG_bestehen:rHD_fHP: a313:F:Ungewollte_Verlobung_akzeptieren:rHD_fHP: a313:Hh:Ungewollte_Verlobung_akzeptieren:rHD_fHP: a313:f:Richtiges_auswählen:rHD_fHP:
# a313:H:Dem_GEHEIMZEICHEN_nachgehen:rHD_rPP_fHP: a313:H:Richtiges_auswählen:rHD_rPP_fHP:
# a313:H:Gespräche_belauschen:rPP_fHP: a313:f:MISSETAT_planen:rPP_fHP:
# a313:H:FLUCHT_vorbereiten:rHD_rPP: a313:f:MISSETAT_planen:rHD_rPP:
# a313:H:VERFOLGUNG_stören:fHP:
# a313:Hh:FLUCHT:rHD_rPP_fHP: a313:H:Die_Änderung_der_EXISTENZFORM:rHD_rPP_fHP: a313:F:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rPP_fHP: a313:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rPP_fHP:
# a313:h:Den_Vorgang_deuten:fHP_fHP: a313:h:VERFOLGUNG:fHP_fHP:
# a313:Hh:Die_Änderung_der_EXISTENZFORM:rHD_rPP: a313:h:KONTAKT_abbrechen:rHD_rPP:
# a313:h:Die_Änderung_der_EXISTENZFORM_stören:rPP_fHP:
# a313:h:Missachtung_der_LIEBE:rHD_fPP: a313:h:Heiraten:rHD_fPP:
# a313:H:Änderung_der_EXISTENZFORM_beheben:rVB_rPP:
# a313:H:Sonstiges_verkaufen:rVB_rPP: a313:F:NEUGIER_ausgelöst:rVB_rPP:
# a313:H:Der_NEUGIER_nachgehen:rHD_rPP: a313:H:KONTAKT_wiederherstellen:rHD_rPP: a313:H:Missachtung_der_LIEBE_beheben:rHD_rPP: a313:H:Ende:rHD_rPP:
# a715:H:Mut_zeigen:rHD_fVB:
# a715:f:Schrecken_ausgelöst:rHD_rAN_fVB: a715:f:Einem_Gemenge_entkommen:rHD_rAN_fVB:
# a715:f:Schrecken_ausgelöst:rHD_rAN_fVB: a715:f:Hitze_entkommen:rHD_rAN_fVB:
# a715:H:Ende:rHD:
# a314:f:VERTRAG_abschließen_oder_verkünden:rHD_rHP:
# a314:f:Krieg_führen:rHD: a314:H:IDENTITÄT_ändern:rHD: a314:H:Krieg_führen:rHD:
# a314:Hh:KONTAKT_abbrechen:rHD_rHP: a314:F:NEUGIER_ausgelöst:rHD_rHP:
# a314:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rHP: a314:H:Held_erkennen:rHD_rHP: a314:F:Angebot_KÖNIG_ZU_WERDEN:rHD_rHP:
# a314:H:Heiraten:rHD_rHP_rPP:
# a449:F:Tapferkeit_beweisen:rHD_rPP:
# a321:h:Unterkommen:rHD_rVB: a321:F:WETTKAMPF:rHD_rVB:
# a321:H:WETTKAMPF:rHD_rAN:
# a321:H:Rache_nehmen:rHD_rVB: a321:H:Krisenursachen_ergründen:rHD_rVB:
# a321:Hh:WETTKAMPF:rHD_rAN:
# a321:F:WETTKAMPF:rHD_rAN: a321:Hh:WETTKAMPF:rHD_rAN: a321:HF:WAFFE_ZAUBERMITTEL_erhalten:rHD_rAN:
# a321:H:WAFFE_ZAUBERMITTEL_erhalten:rHD_rZM: a321:H:FEHLENDEN_Gegenstand_erfassen:rHD_rZM:
# a321:f:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_rAN: a321:f:VERGIFTUNG:rHD_rAN: a321:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rAN: a321:H:TÖTUNG:rHD_rAN:
# a321:HF:VERGIFTUNG_beheben:rHD_rPP:
# a321:H:Dem_VORTÄUSCHEN_nachgehen:rHD: a321:H:VERGIFTUNG_beheben:rHD:
# a327B:f:KANNIBALISMUS:rHD_rAN: a327B:F:Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN:rHD_rAN: a327B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN:
# a327B:H:IDENTITÄT_ändern:rHD_rAN_rAN: a327B:F:Schlaf_VORTÄUSCHEN:rHD_rAN_rAN: a327B:H:Personenschaden_anrichten:rHD_rAN_rAN:
# a327B:f:Jemanden_in_Kannibalismus_verwickeln:rHD_rAN: a327B:H:FLUCHT:rHD_rAN: a327B:H:VERFOLGUNG:rHD_rAN: a327B:H:VERFOLGUNG_entkommen:rHD_rAN:
# a328:F:Rebellion_des_Zielobjektes_VORTÄUSCHEN:rHD_rBZ_rZO: a328:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rBZ_rZO: a328:H:SELTENEN_Gegenstand_erfassen:rHD_rBZ_rZO:
# a328:H:FLUCHT:rHD_rBZ: a328:h:VERFOLGUNG:rHD_rBZ: a328:H:VERFOLGUNG_entkommen:rHD_rBZ:
# a328:F:Rebellion_des_Zielobjektes_VORTÄUSCHEN:rHD_rBZ_rZO: a328:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rBZ_rZO: a328:H:NUTZTIER_erfassen:rHD_rBZ_rZO:
# a328:H:UNGEHEUER_herbeiholen:rHD_rBZ_rHP: a328:h:VERSCHLINGEN:rHD_rBZ_rHP:
# a328:f:VERFOLGUNG:rHD_rBZ: a328:H:TÖTUNG:rHD_rBZ:
# a706:h:Tod_von_Angehörigen:rHD_rHH:
# a706:h:Verlobung_wird_arrangiert:rHH_fHH: a706:h:Heiraten:rHH_fHH:
# a706:h:VERLEUMDUNG_bei_Schädigung:rHD_rHH_fHH: a706:H:VERLEUMDUNG_beheben:rHD_rHH_fHH:
# a706:h:KINDERMORD_nachgehen:rHD_rHH_fHH: a706:h:VERLEUMDUNG_bei_Kindstötung:rHD_rHH_fHH:
# a706:h:VERTREIBUNG:rHD_rHH:
# a706:H:Überrascht_werden_oder_geraten:rHD_rPP: a706:F:Liebe_wird_ausgelöst:rHD_rPP: a706:H:Heiraten:rHD_rPP:
# a706:Hh:KONTAKT_abbrechen:rHD_rPP:
# a706:F:BOTSCHAFTEN_versenden:rVB_rHP_rPP: a706:H:BOTSCHAFTEN_versenden:rVB_rHP_rPP:
# a706:h:BOTSCHAFTEN_verfälschen:rVB_fHH:
# a706:H:BOTSCHAFTEN_versenden:rVB_rPP:
# a706:h:VERTREIBUNG:rHD_rHP:
# a706:F:Zusammenbringen_aller_Handlungsträger:rHD_rHH_rPP:
# a706:F:ERZÄHLEN_beginnen:rHD: a706:H:Den_Vorgang_deuten:rHD: a706:H:VERLEUMDUNG_beheben:rHD: a706:H:ERZÄHLEN_beenden:rHD:
# a706:H:Bestrafung:rHH_fHH:
# a706:H:Familienzusammenführung:rHD_rPP:
# a812:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:zs_zt: a812:f:Rätsel_lösen:zs_zt:
# a812:F:Auf_Hilfsquelle_zurückgreifen:zs_zsa:
# a812:H:Gutes_Benehmen:zs_zf_zsa: a812:H:Hilfeversprechen_erhalten:zs_zf_zsa:
# a812:H:Rätsel_lösen:zt_zsa: a812:H:Ende:zt_zsa:
# a1704:#:#:#:
# aTMJ1392_1:#:#:#:
# a881:#:#:#:
# a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:fPP:
# a881:f:Einen_Bösen_einstellen:fVB_fPP:
# a881:h:Ausplaudern:rHH_fVB:
# a881:h:BEHINDERUNG_durch_Verstümmelung:rHD_fPP:
# a881:f:FLUCHT_vorbereiten:rHD_fPP: a881:h:FLUCHT:rHD_fPP:
# a881:H:Eine_BEHINDERUNG_beheben:rHD_fPP: a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP: a881:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP: a881:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fPP: a881:H:FLUCHT:rHD_fPP:
# a881:f:Überrascht_werden_oder_geraten:rHD_fVB: a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fVB: a881:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fVB: a881:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fVB: a881:H:FLUCHT:rHD_fVB:
# a881A:H:Unterkommen:rHD_rVB: a881A:F:An_Königswahl_teilnehmen:rHD_rVB: a881A:H:IDENTITÄT_ändern:rHD_rVB:
# a881A:H:Intensive_ERKUNDUNGSAKTION:rHD:
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD: a881A:H:Zusammenbringen_aller_Handlungsträger:rHD:
# a881A:F:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rPP: a881A:F:ERZÄHLEN_beginnen:rHD_rPP: a881A:H:ERZÄHLEN_beenden:rHD_rPP:
# a881A:F:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fPP: a881A:F:ERZÄHLEN_beginnen:rHD_fPP: a881A:H:ERZÄHLEN_beenden:rHD_fPP:
# a881A:F:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fVB: a881A:F:ERZÄHLEN_beginnen:rHD_fVB: a881A:H:ERZÄHLEN_beenden:rHD_fVB:
# a881A:H:Bestrafung:rHD_fPP:
# a881A:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP: a881A:H:Familienzusammenführung:rHD_rPP: a881A:H:Ende:rHD_rPP:
# a706:h:Heiraten:rHD_rHH_fHH:
# a706:h:KONTAKT_abbrechen:rHD_rPP:
# a706:F:Zusammenbringen_aller_Handlungsträger:rHD_rHH_rPP: a706:F:ERZÄHLEN_beginnen:rHD_rHH_rPP: a706:H:Den_Vorgang_deuten:rHD_rHH_rPP: a706:H:VERLEUMDUNG_beheben:rHD_rHH_rPP: a706:H:ERZÄHLEN_beenden:rHD_rHH_rPP:
# a922:F:LEISTUNG_für_die_GEGENLEISTUNG:zs_zsa:
# a922:H:IDENTITÄT_ändern:zs_zt_zf: a922:F:Gutes_Benehmen:zs_zt_zf: a922:H:Gutes_Benehmen:zs_zt_zf:
# a922:H:GEGENLEISTUNG_für_die_LEISTUNG:zs_zf:
# a922:F:Um_einen_Auftrag_werben:zt_zf:
# a922:f:VERTRAG_abschließen_oder_verkünden:zs_zt: a922:f:Rätsel_lösen:zs_zt: a922:H:Rätsel_lösen:zs_zt: a922:F:Auf_dem_VERTRAG_bestehen:zs_zt: a922:H:VERTRAGsbedingungen_erfüllen:zs_zt:
# a922:H:Ende:zt_zf:
# a1920F:Ff:Auftrag_zum_Unterhalten:zs_zt: a1920F:Ff:VERTRAG_abschließen_oder_verkünden:zs_zt:
# a1960:F:Um_einen_Auftrag_werben:zs_zt: a1960:F:ERZÄHLEN_beginnen:zs_zt: a1960:F:PROVOKATION:zs_zt: a1960:h:Der_PROVOKATION_nachgehen:zs_zt:
# a1920F:H:ERZÄHLEN_beenden:zs_zt: a1920F:F:PROVOKATION:zs_zt: a1920F:H:Der_PROVOKATION_nachgehen:zs_zt: a1920F:H:VERTRAGsbedingungen_erfüllen:zs_zt:
# a1592:#:#:#:
# a875:f:Rätsel_lösen:zs:
# a875:F:Auf_Hilfsquelle_zurückgreifen:zs_zsa: a875:HF:Rätsel_lösen:zs_zsa:
# a875:H:Rätsel_lösen:zf_zsa: a875:H:Der_Wechsel_der_IDENTITÄT_eingestehen:zf_zsa:
# a875:f:Auftrag_als_ABSURDITÄT:zf_zsa:
# a875:F:Auf_Hilfsquelle_zurückgreifen:zs_zsa: a875:HF:Der_ABSURDITÄT_entgegentreten:zs_zsa:
# a875:H:Der_ABSURDITÄT_entgegentreten:zf_zsa:
# a875:F:Auf_Hilfsquelle_zurückgreifen:zf_zsa: a875:HF:Der_ABSURDITÄT_entgegentreten:zf_zsa:
# a875:H:Der_ABSURDITÄT_entgegentreten:zf:
# a875:H:Heiraten:zs_zf:
# a545B:HF:Verlust_VORTÄUSCHEN:rHF_rHP: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP:
# a545B:F:Unzufriedenheit_VORTÄUSCHEN:rHD_rHF_fHF: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_fHF: a545B:F:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF_fHF:
# a545B:H:Auftrag_zum_VOTÄUSCHEN:rVB_fHF: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rVB_fHF: a545B:H:VERTREIBUNG:rVB_fHF:
# a875:f:PROVOKATION:zt_zf: a875:h:Der_PROVOKATION_nachgehen:zt_zf: a875:f:VERTRAG_abschließen_oder_verkünden:zt_zf:
# a875:F:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zt: a875:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:zs_zt:
# a875:H:Stifter_oder_Helfer_gewinnen:zs_zt:
# a875:F:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zf: a875:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:zs_zf:
# a875:H:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zf: a875:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:zs_zf:
# a875:F:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zf: a875:H:RÄTSELHAFTES_Gespräch_oder_Handlung_aufklären:zs_zf: a875:H:RÄTSELHAFTES_Gespräch_oder_Handlung:zs_zf:
# a875:H:Angebot_KÖNIG_ZU_WERDEN:zs_zf:
# a61:#:#:#:
# a6:#:#:#:
# a1633:f:Wahl_als_ABSURDITÄT:zsa:
# ...
# a513A:f:Große_Mengen_ESSEN:rHF: a513A:H:Große_Mengen_ESSEN:rHF:
# a513A:f:WETTLAUF:rHD_rHF_rZO: a513A:H:WETTLAUF_in_Angriff_nehmen:rHD_rHF_rZO: a513A:H:WETTLAUF:rHD_rHF_rZO: a513A:H:VERTRAGsbedingungen_erfüllen:rHD_rHF_rZO:
# a531:f:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_rAN: a531:H:Bestrafung:rHD_rAN: a531:H:Heiraten:rHD_rAN:
# a441:H:Wunderbare_EMPFÄNGNIS:rHP:
# a441:Hh:Missgeburt:rPP:
# a441:H:Den_Vorgang_deuten:rHP_rHP:
# a441:F:Ungewollte_Verlobung_akzeptieren:rHP_rPP:
# a441:F:Ungewollte_Verlobung_akzeptieren:rHH_rHP: a441:HF:Information_aus_zweiter_Hand:rHH_rHP: a441:h:Ungewollte_Verlobung_akzeptieren:rHH_rHP:
# a441:F:Ungewollte_Verlobung_akzeptieren:rHH_rHP: a441:HF:Information_aus_zweiter_Hand:rHH_rHP: a441:h:Ungewollte_Verlobung_akzeptieren:rHH_rHP: a441:f:Mehrere_Aufgaben_in_Folge_erledigen:rHH_rHP:
# a441:H:Mehrere_Aufgaben_in_Folge_erledigen:rPP:
# a441:H:Ungewollte_Verlobung_akzeptieren:rHD_rHH:
# a425A:H:Heiraten:rHD_rPP: a425A:H:Die_Änderung_der_EXISTENZFORM:rHD_rPP: a425A:H:Überraschende_positive_Wendung:rHD_rPP: a425A:hf:TABU_Tierhaut_nicht_verbrennen:rHD_rPP:
# a425A:h:Sich_auf_Eindringlinge_einlassen:rHD_rAN: a425A:hf:Die_Änderung_der_EXISTENZFORM_stören:rHD_rAN:
# a425A:h:TABU_nachgehen:rHD_rAN: a425A:h:Die_Änderung_der_EXISTENZFORM_stören:rHD_rAN:
# a441:H:MARKIERUNGEN_erkennen:rVB_rPP:
# a425B:F:KONTAKT_wiederherstellen:rHD_rPP: a425B:h:Den_Vorgang_deuten:rHD_rPP: a425B:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rPP:
# a425B:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST:
# a425B:H:REITTIER_erhalten:rHD_rST: a425B:H:AUSRÜSTUNG_als_ZAUBERMITTEL_erhalten:rHD_rST: a425B:HF:FLUCHT_vorbereiten:rHD_rST:
# a313:H:FLUCHT:rHD_rPP_rAN: a313:h:VERFOLGUNG:rHD_rPP_rAN: a313:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rPP_rAN: a313:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_rPP_rAN: a313:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rPP_rAN:
# a313:h:VERFOLGUNG:rHD_rPP_rAN: a313:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rPP_rAN: a313:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rPP_rAN: a313:H:VERFOLGUNG_entkommen:rHD_rPP_rAN:
# a313:H:Heiraten:rHD_rPP_rAN: a313:H:Ende:rHD_rPP_rAN:
# a551:f:Zu_Beauftragungen_anregen:rHH_fVB: a551:h:Menschliches_Blut_als_HEILMITTEL_erforderlich:rHH_fVB:
# a551:f:HEILMITTEL_besorgen:rHH_fVB: a551:h:HEILMITTEL_besorgen:rHH_fVB:
# a551:F:Die_potenzielle_Beute_begnadigen:rHD_rST: a551:H:Die_potenzielle_Beute_begnadigen:rHD_rST: a551:H:Hilfeversprechen_erhalten:rHD_rST:
# a551:h:VERLEUMDUNG_bei_Untreue:rHD_rHH_fVB: a551:h:VERBANNUNG:rHD_rHH_fVB:
# a507:F:WEISHEITEN_erhalten:rHD_rST:
# a507:HF:Stifter_oder_Helfer_gewinnen:rHD_rHH:
# a507:F:TREUEN_HELFER_erhalten:rHD_rHF:
# a507:H:Unterkommen:rHD_rHP:
# a507:F:KRANKHEIT_beheben:rHP: a507:F:VERTRAG_abschließen_oder_verkünden:rHP:
# a507:F:Die_Hilfsquelle_greift_zurück:rHD_rHF:
# a507:F:Um_einen_Auftrag_werben:rHD_rVB:
# a507:F:Liebe_wird_ausgelöst:rHD_rPP: a507:F:ERZÄHLEN_beginnen:rHD_rPP: a507:H:ERZÄHLEN_beenden:rHD_rPP: a507:Hh:Enthüllung_der_Wahrheit_durch_das_subtile_Mittel:rHD_rPP:
# a507:F:ERZÄHLEN_beginnen:rHD_rPP: a507:H:ERZÄHLEN_beenden:rHD_rPP: a507:H:Enthüllung_der_Wahrheit_durch_das_subtile_Mittel:rHD_rPP:
# a507:F:ERZÄHLEN_beenden:rHD_rPP: a507:H:ERZÄHLEN_beenden:rHD_rPP: a507:H:Enthüllung_der_Wahrheit_durch_das_subtile_Mittel:rHD_rPP: a507:H:KRANKHEIT_beheben:rHD_rPP:
# a507:H:VERTRAGsbedingungen_erfüllen:rHD_rHP_rPP: a507:H:Heiraten:rHD_rHP_rPP:
# a507:H:Erlösung:rHF_rPP:
# a507:H:HEILMITTEL_erfassen:rHD_rHF_rZM:
# a551:H:VERBANNUNG_beheben:rHD_rHH: a551:H:HEILMITTEL_besorgen:rHD_rHH: a551:H:KRANKHEIT_beheben:rHD_rHH:
# a551:f:Erträumen:rHH: a551:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHH: a551:h:KRANKHEIT:rHH:
# a551:F:HEILMITTEL_besorgen:rHH_fHD: a551:h:HEILMITTEL_besorgen:rHH_fHD:
# a551:H:HEILMITTEL_erfassen:rHD_rZO_rZO: a551:H:Die_SCHÖNE_erfassen:rHD_rZO_rZO:
# a531:H:HEILMITTEL_besorgen:rHD_rHH_rZO: a531:H:KRANKHEIT_beheben:rHD_rHH_rZO: a531:H:Die_SCHÖNE_herbeiholen:rHD_rHH_rZO: a531:H:Heiraten:rHD_rHH_rZO:
# a650A:H:HOLZ_Sammeln_in_Angriff_nehmen:rHD_rZO: a650A:H:HOLZ_besorgen:rHD_rZO: a650A:f:Schrecken_ausgelöst:rHD_rZO:
# a650A:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST_rZM:
# a650A:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rVB_rZM:
# a545B:H:Einer_EINLADUNG_nachgehen:rHD_rHF_rPP: a545B:H:Heiraten:rHD_rHF_rPP: a545B:H:Auf_dem_Heimweg:rHD_rHF_rPP:
# a545B:F:Eine_Bedrohung_VORTÄUSCHEN:rHD_fST: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fST: a545B:H:VERTREIBUNG:rHD_fST:
# a545B:H:Fremdes_Gut_einziehen:rHD_fST: a545B:H:Ende:rHD_fST:
# a707:h:Tod_von_Angehörigen:rHH_fHH_fHH: a707:h:Heiraten:rHH_fHH_fHH:
# a707:h:Aussetzung:rHD_fHD_fHH: a707:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_fHD_fHH:
# a707:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_fHD:
# a707:h:VERLUST_von_Tieren_Früchten_Ernte_usw:rHP_rPP_fPP:
# a707:F:Wache_halten:rHP_fPP:
# a707:h:Wache_halten:rHP_fPP: a707:h:Den_Vorgang_deuten:rHP_fPP:
# a707:H:Wache_halten:rHD_rPP: a707:H:Überrascht_werden_oder_geraten:rHD_rPP:
# a707:H:Den_Vorgang_deuten:rHD_rHP_rPP: a707:F:Liebe_wird_ausgelöst:rHD_rHP_rPP:
# a707:H:Heiraten:rHD_rPP:
# a706:h:Goldhaariges_Kind_zur_Welt_bringen:rHD_fHH: a706:h:Sich_auf_Eindringlinge_einlassen:rHD_fHH:
# a706:h:KINDERMORD_nachgehen:fHH:
# a706:h:VERLEUMDUNG_bei_Kindstötung:rHD_rPP: a706:h:VERTREIBUNG:rHD_rPP:
# a706:H:Sorge_um_Mitleidsbedürftige:rHD_rST_rZM: a706:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a706:H:WIEDERBELEBEN:rHD_rZM:
# a706:h:Unterkommen:rHD_rAN_fVB: a706:h:MISSETAT_wie_Kannibalismus:rHD_rAN_fVB:
# a302:H:Das_Geheimnis_der_EXTERNEN_SEELE_AUSSPIONIEREN:rHD_fVB:
# a302:H:EXTERNEN_SEELE_erfassen:rHD_rAN_fZM: a302:H:EXTERNEN_SEELE_vernichten:rHD_rAN_fZM:
# a706:H:Begegnung:rHD_rPP_fPP: a706:H:IDENTITÄT_ändern:rHD_rPP_fPP: a706:H:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rPP_fPP: a706:H:Enthüllung_der_Wahrheit_durch_das_subtile_Mittel:rHD_rPP_fPP:
# a706:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP_fPP: a706:H:Den_Vorgang_deuten:rHD_rPP_fPP: a706:H:VERLEUMDUNG_beheben:rHD_rPP_fPP:
# a325:h:Die_FERNLIEBE_wird_ausgelöst:rHD:
# a325:F:Um_eine_Frau_werben:rHH_rHP:
# a325:HF:ABRATEN_von_der_Mission:rHD_fZO: a325:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_fZO:
# a325:H:Zauberkunst_erlernen:rHD_fZO:
# a325:H:FLUCHT_vorbereiten:rHD_rBZ_rZO:
# a325:Hh:FLUCHT:rHD_rBZ_rZO: a325:H:Die_Änderung_der_EXISTENZFORM:rHD_rBZ_rZO: a325:h:VERFOLGUNG:rHD_rBZ_rZO:
# a325:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rVB:
# a325:h:VERFOLGUNG:rHD_rVB_rBZ: a325:Hh:FLUCHT:rHD_rVB_rBZ: a325:H:Die_Änderung_der_EXISTENZFORM:rHD_rVB_rBZ: a325:H:VERFOLGUNG_entkommen:rHD_rVB_rBZ:
# a325:H:Ende:rHD_rPP_fZO:
# a922:f:VERTRAG_abschließen_oder_verkünden:zs_zt: a922:f:Rätsel_lösen:zs_zt: a922:H:Rätsel_lösen:zs_zt: a922:H:VERTRAGsbedingungen_erfüllen:zs_zt:
# a922:H:IDENTITÄT_ändern:zs_zt_zf: a922:H:Begegnung:zs_zt_zf: a922:F:Gutes_Benehmen:zs_zt_zf: a922:H:Gutes_Benehmen:zs_zt_zf: a922:Hh:KONTAKT_abbrechen:zs_zt_zf:
# a922:H:IDENTITÄT_ändern:zt_zf:
# a922:H:KONTAKT_wiederherstellen:zs_zt_zf: a922:F:Gutes_Benehmen:zs_zt_zf: a922:H:Gutes_Benehmen:zs_zt_zf:
# a922:H:GEGENLEISTUNG_für_die_LEISTUNG:zf:
# a922:F:Um_einen_Auftrag_werben:zt_zf: a922:F:VERTRAG_abschließen_oder_verkünden:zt_zf:
# a922:h:VERTRAGsbedingungen_erfüllen:zt_zf:
# a1534D*:#:#:#:
# a613:H:Heiraten:rHD_rPP:
# a613:F:Intensive_ERKUNDUNGSAKTION:rHD:
# a613:h:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fHD:
# aE2:h:KONTAKT_abbrechen:#:
# aE2:h:MASSENBEDROHUNG:#:
# aE2:F:MASSENBEDROHUNG_beheben:#: aE2:f:Um_einen_Auftrag_werben:#:
# aE2:F:MASSENBEDROHUNG_beheben:#: aE2:F:Um_einen_Auftrag_werben:#:
# aE2:f:WETTKAMPF:#:
# aE2:H:WETTKAMPF:#: aE2:H:MASSENBEDROHUNG_beheben:#:
# aE2:h:Begegnung:#: aE2:f:GIER_und_NEID_ausgelöst:#:
# aE2:f:Die_SCHÖNE_herbeiholen:#:
# aE2:h:Heldentat_VORTÄUSCHEN:#: aE2:Hh:MARKIERUNGEN_vorlegen:#: aE2:h:Sich_ZURÜCKZIEHEN:#:
# aE2:H:Unterkommen:#: aE2:F:Tapferkeit_beweisen:#: aE2:HF:ABRATEN_von_der_Mission:#: aE2:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:#:
# aE2:HF:Wegweisung_erhalten:rHD_rVB:
# aE2:H:Heiraten:#:
# aE2:f:MISSETAT_planen:#: aE2:h:MISSETAT_wie_Falle_stellen:#:
# aE2:h:FREIHEITSBERAUBUNG:#:
# aE2:h:VERBANNUNG:#:
# a881A:H:Verlobung_wird_arrangiert:rHH_rHH:
# a881A:h:Tod_von_Angehörigen:rHH: a881A:H:Hochzeit_verschieben:rHH:
# a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_rAN:
# a881A:f:Ungewollte_Verlobung_akzeptieren:rHH_rAN: a881A:h:Ungewollte_Verlobung_akzeptieren:rHH_rAN:
# a881A:h:Ungewollte_Verlobung_akzeptieren:rHD_rHH:
# a881A:H:FLUCHT_vorbereiten:rHD_rPP:
# a881A:F:Krankheit_VORTÄUSCHEN:rHD_rAN: a881A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN:
# a881A:Hh:FLUCHT:rHD_rPP:
# a881A:H:IDENTITÄT_ändern:rHD_rPP:
# a881A:Hh:KONTAKT_abbrechen:rHD_rPP_fPP:
# a881A:h:Eine_ENTFÜHRUNG:rHD_fPP:
# a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP: a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP: a881A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fPP:
# a881A:H:FLUCHT:rHD:
# a881A:h:SCHLAF:rHD:
# a881A:h:Überrascht_werden_oder_geraten:rHD_fPP: a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP: a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP: a881A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fPP:
# a881A:Hh:FLUCHT:rHD_fHF:
# a881A:h:Überrascht_werden_oder_geraten:rHD_fPP:
# a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP: a881A:H:Zum_Schlafen_bringen:rHD_fPP: a881A:H:IDENTITÄT_ändern:rHD_fPP: a881A:F:MARKIERUNGEN_anbringen:rHD_fPP:
# a881A:F:An_Königswahl_teilnehmen:rHD:
# a881A:F:Intensive_ERKUNDUNGSAKTION:rHD_fPP:
# a881A:#:#:#:
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rAN: a881A:H:Zusammenbringen_aller_Handlungsträger:rAN:
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rPP: a881A:H:Zusammenbringen_aller_Handlungsträger:rPP:
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:fPP: a881A:H:Zusammenbringen_aller_Handlungsträger:fPP:
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rAN: a881A:F:ERZÄHLEN_beginnen:rHD_rAN: a881A:H:ERZÄHLEN_beenden:rHD_rAN:
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rPP: a881A:F:ERZÄHLEN_beginnen:rHD_rPP: a881A:H:ERZÄHLEN_beenden:rHD_rPP:
# a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fPP: a881A:F:ERZÄHLEN_beginnen:rHD_fPP: a881A:H:ERZÄHLEN_beenden:rHD_fPP:
# a881A:H:Bestrafung:rHD_rAN:
# a881A:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP: a881A:H:Familienzusammenführung:rHD_rPP:
# a507:F:Krisenursachen_ergründen:rHD_rHF:
# a563:F:HUNGERSNOT_beheben:rHD_rVB_fVB: a563:H:Sich_sonstige_Dinge_ANEIGNEN:rHD_rVB_fVB:
# a563:h:VERLUST_von_Tieren_Früchten_Ernte_usw:rST_fHF:
# a563:h:Überrascht_werden_oder_geraten:rHD_rST: a563:f:Ungewollte_Verlobung_akzeptieren:rHD_rST:
# a563:HF:Information_aus_zweiter_Hand:rHD_fVB: a563:h:Ungewollte_Verlobung_akzeptieren:rHD_fVB:
# a563:HF:Information_aus_zweiter_Hand:rHD_rVB: a563:H:Ungewollte_Verlobung_akzeptieren:rHD_rVB:
# a563:h:HUNGERSNOT:rHD_fVB:
# a563:h:KONTAKT_abbrechen:rHD_fVB:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rVB:
# a563:H:PROVIANTPRODUZIERENDEN_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:H:KONTAKT_wiederherstellen:rHD_fVB: a563:f:EINLADUNG:rHD_fVB:
# a563:HF:Information_aus_zweiter_Hand:rAN_fVB: a563:h:Einer_EINLADUNG_nachgehen:rAN_fVB:
# a563:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen:rHD_rZM_fVB: a563:H:HUNGERSNOT_beheben:rHD_rZM_fVB:
# a563:h:Sich_ZAUBERMITTEL_ANEIGNEN:rHD_rZM_rAN:
# a563:F:Auf_Hilfsquelle_zurückgreifen:rHD_rST_rZM: a563:H:Strafvollstreckenden_ZAUBERMITTEL_erhalten:rHD_rST_rZM:
# a563:H:HUNGERSNOT_beheben:rHD_rZM_fVB: a563:H:Ende:rHD_rZM_fVB:
# a706:h:Kinderlosigkeit:rHH: a706:F:Magische_EMPFÄNGNISmittel_suchen:rHH:
# a706:Hh:VERSPRECHEN_im_Austausch_für_Hilfe:rHH_rZM_fST: a706:H:Magische_EMPFÄNGNISmittel_erhalten:rHH_rZM_fST:
# a706:H:Wunderbare_EMPFÄNGNIS:rHH_rZM:
# a706:H:Zur_Welt_kommen:rHH:
# a706:h:Tod_von_Angehörigen:rHH:
# a706:H:Zur_Welt_kommen:rHD:
# a706:h:Sich_auf_Eindringlinge_einlassen:rHD_fHH:
# a706:h:Verlobung_wird_arrangiert:rHD_rHH_fHH: a706:h:Heiraten:rHD_rHH_fHH:
# a706:H:Überrascht_werden_oder_geraten:rHD_rPP: a706:F:Liebe_wird_ausgelöst:rHD_rPP:
# a706:F:Heiraten:rHD_rPP:
# a706:H:Sich_niederlassen:rHD:
# a706:H:Intensive_ERKUNDUNGSAKTION:rHD_rST: a706:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rST:
# a706:H:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST:
# a706:H:Zusammenbringen_aller_Handlungsträger:rHD_rHH_rPP: a706:H:Den_Vorgang_deuten:rHD_rHH_rPP: a706:H:VERLEUMDUNG_beheben:rHD_rHH_rPP:
# a922:f:VERTRAG_abschließen_oder_verkünden:zs_zf: a922:f:Rätsel_lösen:zs_zf: a922:H:Rätsel_lösen:zs_zf: a922:H:VERTRAGsbedingungen_erfüllen:zs_zf:
# a922:h:FREIHEITSBERAUBUNG:zs_zf_zfa:
# a922:f:VERTRAG_abschließen_oder_verkünden:zt_zf: a922:f:Rätsel_lösen:zt_zf: a922:h:Rätsel_lösen:zt_zf: a922:h:FREIHEITSBERAUBUNG:zt_zf:
# a922:F:Auf_Hilfsquelle_zurückgreifen:zs_zt: a922:F:GEGENLEISTUNG_für_die_LEISTUNG:zs_zt:
# a922:F:LEISTUNG_für_die_GEGENLEISTUNG:zs_zt_zta: a922:HF:Rätsel_lösen:zs_zt_zta:
# a922:H:Rätsel_lösen:zt_zf:
# a922:H:Ende:zs_zf:
# a930:H:Unterkommen:rHH_rVB_fHP:
# a930:H:Zur_Welt_kommen:rHD_rVB_fHP: a930:f:VORHERSAGE_ungewünschte_Heiraten:rHD_rVB_fHP:
# a930:h:Der_VORHERSAGE_nachgehen:rHD_rHH_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rHH_fHP: a930:h:Adoption:rHD_rHH_fHP:
# a930:h:Aussetzung:rHD_rVB_fHP:
# a930:H:Überrascht_werden_oder_geraten:rHD_rST: a930:H:Adoption:rHD_rST:
# a930:H:Begegnung:rHD_rVB_fHP:
# a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rST_fHP: a930:h:Der_VORHERSAGE_nachgehen:rHD_rST_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rST_fHP: a930:h:Adoption:rHD_rST_fHP:
# a930:F:Um_einen_Auftrag_werben:rHD_rST: a930:h:KONTAKT_abbrechen:rHD_rST:
# a930:H:Begegnung:rHD_rVB_fHP: a930:h:Sachverhalt_aus_der_Vergangenheit_aufklären:rHD_rVB_fHP: a930:h:Der_VORHERSAGE_nachgehen:rHD_rVB_fHP: a930:f:Ungewünschtes_Wesen_beseitigen:rHD_rVB_fHP:
# a930:f:BOTSCHAFTEN_versenden:rHD_fHP:
# a930:H:SCHLAF:rHD:
# a930:F:Liebe_wird_ausgelöst:rHD_rPP: a930:H:BOTSCHAFTEN_verfälschen:rHD_rPP:
# a930:H:Heiraten:rHD_rHP_rPP:
# a930:HF:VERFOLGUNG_entkommen:rHD_rPP:
# a930:h:VERFOLGUNG:rVB_fHP:
# a930:H:VERFOLGUNG_entkommen:rHD_fHP: a930:H:Die_VORHERSAGE_tritt_ein:rHD_fHP:
# a655:Ff:Priorisierung_VORTÄUSCHEN:zs_zsa:
# a655:Hh:Dem_VORTÄUSCHEN_nachgehen:zs:
# a655:h:Tod_von_Angehörigen:zs_zsa: a655:h:MISSETAT_wie_Aneignung:zs_zsa:
# a655:h:VERLUST_von_Tieren_Früchten_Ernte_usw:zs_zt: a655:F:VORHERSAGE_erforderlich:zs_zt:
# a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zf:
# a655:h:Der_VORHERSAGE_nachgehen:zt_zf: a655:F:STREIT_SCHLICHTEN:zt_zf:
# a655:H:Der_VORHERSAGE_nachgehen:zs_zf: a655:H:Die_VORHERSAGE_tritt_ein:zs_zf: a655:H:VORHERSAGE_subtile_Eigenschaft:zs_zf:
# a655:H:Die_VORHERSAGE_tritt_ein:zs_zf: a655:HF:VORHERSAGE_subtile_Eigenschaft:zs_zf:
# a655:H:VERLUSTursache_beheben:zt_zf: a655:H:STREIT_SCHLICHTEN:zt_zf:
# a655:F:EINLADUNG:zs_zf: a655:H:Einer_EINLADUNG_nachgehen:zs_zf:
# a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zf:
# a655:HF:VORHERSAGE_subtile_Identität:zs_zf:
# a655:H:Der_VORHERSAGE_nachgehen:zs_zsa: a655:H:Die_VORHERSAGE_tritt_ein:zs_zsa: a655:HF:VORHERSAGE_subtiles_Geschmak:zs_zsa:
# a655:HF:Der_VORHERSAGE_nachgehen:zs_zf:
# a655:F:Auf_Hilfsquelle_zurückgreifen:zf_zfa:
# a655:F:VERLUST des Schatzes:zs_zfa: a655:F:VORHERSAGE_erforderlich:zs_zfa:
# a976:F:Rätsel_lösen:zfa: a976:F:ERZÄHLEN_beginnen:zfa:
# a655:H:ERZÄHLEN_beenden:zs_zfa: a655:Hh:Rätsel_lösen:zs_zfa:
# a545B:F:NEUGIER_ausgelöst:rHF_rHP: a545B:F:Um_eine_Frau_werben:rHF_rHP: a545B:HF:Information_aus_zweiter_Hand:rHF_rHP: a545B:H:Der_NEUGIER_nachgehen:rHF_rHP:
# a545B:HF:Reichtum_VORTÄUSCHEN:rHD_rHF: a545B:F:SONSTIGE_AUFGABE_erledigen:rHD_rHF:
# a545B:H:SONSTIGE_AUFGABE_in_Angriff_nehmen:rHD_rHH: a545B:H:SONSTIGE_AUFGABE_erledigen:rHD_rHH:
# a545B:F:Reichtum_VORTÄUSCHEN:rHD_rHH: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHH: a545B:F:NEUGIER_ausgelöst:rHD_rHH:
# a545B:H:Der_NEUGIER_nachgehen:rHD_rHF_rHP: a545B:F:EINLADUNG:rHD_rHF_rHP:
# a545B:Hh:Einer_EINLADUNG_nachgehen:rHD_rHF:
# a545B:F:LEISTUNG_für_die_GEGENLEISTUNG:rHF_fST: a545B:H:GEGENLEISTUNG_für_die_LEISTUNG:rHF_fST: a545B:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHF_fST:
# a545B:f:Zum_STAUNEN_bringen:rHF_rHP: a545B:h:Dem_STAUNEN_nachgehen:rHF_rHP: a545B:F:Unzufriedenheit_VORTÄUSCHEN:rHF_rHP: a545B:H:Dem_VORTÄUSCHEN_nachgehen:rHF_rHP:
# a545B:H:Fremdes_Gut_einziehen:rHD_rHF_rPP: a545B:H:Heiraten:rHD_rHF_rPP:

# %%
#60 Definieren der Variablen
gesep_1 ="a1525#"
gesep_2 ="#"
gesep_3 =""
gesep_4 =""

# %%
#61 Iteration über die Zeilen des DataFrames df_2
for i, gesuchte_label in enumerate(df_2.index_string):
    
    #62 Überprüfen, ob gesep_a-d in der aktuellen Zeile gesuchte_label vorhanden ist
    if gesep_1 in gesuchte_label:# and gesep_2 in gesuchte_label:# and gesep_3 in gesuchte_label:# or gesep_4 in gesuchte_label):
        print(i, gesuchte_label)
        #63 Wenn gesep_1-4 gefunden wurde, markiere die entsprechende Zeile in der Spalte 'index_binar' als '1'
        df_2.index_binar.iloc[i]='1'

#64 Speichern des aktualisierten DataFrames in einer CSV-Datei 'text_lab.csv'
df_2.to_csv('text_az.csv', encoding='utf-8', index=False)
# Out:
# 286 a1525#:#:#:#:
# 4114 a1525#:#:#:#:
# C:\Users\xe78diq\AppData\Local\Temp\ipykernel_19420\4090129089.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_2.index_binar.iloc[i]='1'

# %%
#65 Lesen der CSV-Datei 'text_lab.csv' und Laden der Daten in ein Pandas DataFrame
df = pd.read_csv('text_az.csv',  encoding='utf-8')

#66 Extrahieren der Trainingsdaten X_train und der Labels y_train
X_train = df['inhalt']  # Inhalt der Texte
y_train = df['index_binar']  # Binäre Indikatoren

#67 Zählen der Vorkommen jeder Binärklasse in der Spalte 'index_binar'
indexliste = Counter(df_2.index_binar)

#68 Ausgabe der Anzahl der Vorkommen jeder Binärklasse
print(indexliste)
# Out:
# Counter({0: 5232, '1': 2})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer  
from sklearn.linear_model import LogisticRegression  
from sklearn.model_selection import GridSearchCV  
from sklearn.pipeline import make_pipeline  

#69 Definieren der Pipeline mit einem TF-IDF-Vektorisierer und einem logistischen Regressionsmodell
pipe = make_pipeline(TfidfVectorizer(min_df=2, stop_words=stpw, ngram_range=(1,1), norm=None), 
                     LogisticRegression())

#70 Definieren des Rastersuchgitters für den Regularisierungsparameter C des logistischen Regressionsmodells
param_grid = {'logisticregression__C': [0.001, 0.01, 0.1, 1, 10]}     

#71 Erstellen eines Rastersuchobjekts mit der Pipeline und dem Rastersuchgitter, das auf 5-facher Kreuzvalidierung basiert
grid = GridSearchCV(pipe, param_grid, cv=5)

#72 Anpassen der Rastersuche an die Trainingsdaten
grid.fit(X_train, y_train)

#73 Drucken des besten Scores aus der Kreuzvalidierung
print("Bester Score aus der Kreuzvalidierung: {:.2f}".format(grid.best_score_))
# Out:
# C:\Users\xe78diq\AppData\Local\anaconda3\Lib\site-packages\sklearn\model_selection\_split.py:725: UserWarning: The least populated class in y has only 2 members, which is less than n_splits=5.
#   warnings.warn(
# Bester Score aus der Kreuzvalidierung: 1.00

# %%
import numpy as np

#74 Extrahieren des TF-IDF-Vektorisierers aus dem besten Schätzschritt des Gittersuchlaufs
vectorizer = grid.best_estimator_.named_steps["tfidfvectorizer"]

#75 Ermitteln des maximalen TF-IDF-Werts für jedes Merkmal
max_value = vectorizer.transform(X_train).max(axis=0).toarray().ravel()

#76 Sortieren der Merkmale nach ihren TF-IDF-Werten
sorted_by_tfidf = max_value.argsort()

#77 Extrahieren der Merkmalsnamen aus dem Vektorisierer
feature_names = np.array(vectorizer.get_feature_names_out())
print("Gesamte Anzahl der Wörter: {}".format(len(vectorizer.vocabulary_)))
# Out:
# Gesamte Anzahl der Wörter: 14202

# %%
s_zahl = 200  #78 Anzahl der Merkmale, die in der Visualisierung dargestellt werden sollen

import matplotlib.pyplot as plt  
import mglearn

#79 Visualisieren der Koeffizienten des logistischen Regressionsmodells
mglearn.tools.visualize_coefficients(
    grid.best_estimator_.named_steps["logisticregression"].coef_,  #80 Koeffizienten des Modells
    feature_names,  n_top_features=s_zahl  #81 Merkmalsnamen und Anzahl der Merkmale, die visualisiert werden sollen
)

#82 Anzeigen des Gitters in der Visualisierung
plt.grid()

#83 Anzeigen der Visualisierung
plt.show()
#plt.savefig(s_zahl+'.png', dpi=80)

# %%
#84 Extrahieren der Koeffizienten aus dem logistischen Regressionsmodell
gio = grid.best_estimator_.named_steps["logisticregression"].coef_[0]

#85 Sortieren der Indizes der Koeffizienten nach ihrer Größe
n_top = np.argsort(gio)

#86 Sortieren der Koeffizienten nach ihrer Größe
z_top = np.sort(gio)

#87 Extrahieren der Top-Merkmale mit den höchsten Koeffizienten
text_pos = feature_names[n_top[-s_zahl:]]
zahl_pos = gio[n_top[-s_zahl:]]

#88 Extrahieren der Top-Merkmale mit den niedrigsten Koeffizienten
text_neg = feature_names[n_top[0:s_zahl]]
zahl_neg = gio[n_top[0:s_zahl]]

#89 Ausgabe der positiven Merkmale und ihrer Koeffizienten
print("Positive Merkmale:\n{}".format(text_pos))

#90 Ausgabe der negativen Merkmale und ihrer Koeffizienten
# print("Negative Merkmale:\n{}".format(text_neg))

#91 Ausgabe der Koeffizienten der positiven Merkmale
# print("Positive coef:\n{}".format(zahl_pos))

#92 Ausgabe der Koeffizienten der negativen Merkmale
# print("Negative coef:\n{}".format(zahl_neg))
# Out:
# Positive Merkmale:
# ['езжу' 'покорился' 'смех' 'яблоках' 'прекраснее' 'загордилась'
#  'златокудрой' 'возвращай' 'запереть' 'усилия' 'питался' 'приказчиком'
#  'постелить' 'добежала' 'царей' 'искупались' 'магазина' 'прохожих'
#  'обойду' 'городским' 'повеление' 'улепетывает' 'морскому' 'замахала'
#  'бечедом' 'частокол' 'попавшийся' 'память' 'семиглавому' 'хрустальный'
#  'колья' 'окапывает' 'приветствую' 'вбитый' 'могильный' 'забросить'
#  'взлетал' 'попилипоели' 'приказчик' 'киркой' 'луг' 'вытянув' 'двоюродной'
#  'текли' 'слюнки' 'шитьем' 'отправляются' 'посредине' 'упираются'
#  'интересует' 'верхушками' 'изорвалась' 'всякая' 'кольями' 'неведомым'
#  'поднимал' 'булатный' 'прославившаяся' 'шагаду' 'разом' 'густым'
#  'бросилея' 'голень' 'диковинную' 'приподнявшись' 'челом' 'начеку'
#  'небесами' 'торчать' 'храбрецы' 'шороха' 'названия' 'отвернись'
#  'предстала' 'нырнули' 'коралловый' 'оденусь' 'лучезарных' 'голубом'
#  'расстаюсь' 'кружит' 'сброшен' 'воровку' 'устройте' 'оленьей' 'вторые'
#  'пучины' 'взрослой' 'повалявшись' 'нюхая' 'вершиной' 'серебряная'
#  'седьмые' 'взрослая' 'сын' 'время' 'жена' 'сказал' 'хана' 'отца' 'хану'
#  'рассказал' 'пошли' 'некоторое' 'собой' 'одну' 'пришли' 'которая' 'нам'
#  'жене' 'свое' 'поэтому' 'сколько' 'решили' 'никто' 'мою' 'завтра'
#  'говорит' 'понял' 'сыну' 'принес' 'золото' 'горе' 'крикнул' 'дорогой'
#  'тебе' 'оба' 'домой' 'твоего' 'ах' 'ямы' 'богатства' 'никому' 'сынок'
#  'отсюда' 'работу' 'сможет' 'ночей' 'золотом' 'поймать' 'тело' 'конец'
#  'отрубил' 'спустился' 'говори' 'тяжело' 'случившемся' 'крепость'
#  'просьбу' 'другим' 'оставить' 'стену' 'прыгнул' 'мешки' 'заплакал'
#  'отнес' 'силы' 'племянник' 'трудно' 'единственный' 'узнает' 'удалось'
#  'плачь' 'жаль' 'ох' 'украсть' 'принесу' 'выбраться' 'отнеси' 'прости'
#  'научил' 'молодости' 'народом' 'сокровищами' 'сиди' 'прихватив' 'снова'
#  'взобрались' 'воровали' 'кумухскому' 'повезло' 'дяде' 'ремеслу' 'выполни'
#  'крепостную' 'телу' 'плохому' 'навозе' 'спущусь' 'привычную' 'выберусь'
#  'яму' 'отец' 'дядя' 'отрубят' 'отруби' 'увяз' 'смоле' 'дяди' 'голову']

# %%
kfz = range(s_zahl)  # Erstellen einer Sequenz von Zahlen von 0 bis s_zahl-1
folgenum = 0  # Initialisieren des Zählers für die Folgennummer
pop = None  # Initialisierung der "pop"-Variable

# Iteration über die Zahlen in der Sequenz kfz
for x in kfz:
    folgenum += 1  # Inkrementieren der Folgennummer
    # Berechnen der Summe der Koeffizienten für das aktuelle Element in der Liste
    vollliste = zahl_pos[s_zahl - folgenum] + zahl_neg[s_zahl - folgenum]
    # Runden der Summe auf drei Dezimalstellen
    rundliste = round(vollliste, 3)
    # Ausgabe der gerundeten Summe und der aktuellen Zahl in der Sequenz
    print(rundliste, '-', x)
    
    # Bedingung, um zu prüfen, ob rundliste weniger als 0.001 ist
    if rundliste < 0.001:
        pop = x  # Setzen der "pop"-Variable auf den aktuellen Wert von x
        break  # Schleife beenden, da wir den kleinsten Wert von x gefunden haben

# Ausgabe des Ergebnisses
if pop is not None:
    print(f"Die 'pop'-Variable ist {pop}, da rundliste kleiner als 0.001 ist.")
else:
    print("Kein Wert gefunden, bei dem rundliste kleiner als 0.001 ist.")
# Out:
# 0.024 - 0
# 0.022 - 1
# 0.017 - 2
# 0.016 - 3
# 0.016 - 4
# 0.015 - 5
# 0.014 - 6
# 0.013 - 7
# 0.01 - 8
# 0.008 - 9
# 0.008 - 10
# 0.008 - 11
# 0.008 - 12
# 0.008 - 13
# 0.008 - 14
# 0.008 - 15
# 0.008 - 16
# 0.008 - 17
# 0.008 - 18
# 0.008 - 19
# 0.008 - 20
# 0.008 - 21
# 0.008 - 22
# 0.007 - 23
# 0.007 - 24
# 0.007 - 25
# 0.007 - 26
# 0.007 - 27
# 0.007 - 28
# 0.007 - 29
# 0.007 - 30
# 0.007 - 31
# 0.007 - 32
# 0.007 - 33
# 0.007 - 34
# 0.007 - 35
# 0.006 - 36
# 0.006 - 37
# 0.006 - 38
# 0.006 - 39
# 0.006 - 40
# 0.006 - 41
# 0.006 - 42
# 0.006 - 43
# 0.006 - 44
# 0.006 - 45
# 0.006 - 46
# 0.006 - 47
# 0.006 - 48
# 0.006 - 49
# 0.006 - 50
# 0.006 - 51
# 0.006 - 52
# 0.006 - 53
# 0.006 - 54
# 0.006 - 55
# 0.006 - 56
# 0.006 - 57
# 0.005 - 58
# 0.005 - 59
# 0.005 - 60
# 0.005 - 61
# 0.005 - 62
# 0.005 - 63
# 0.005 - 64
# 0.005 - 65
# 0.005 - 66
# 0.005 - 67
# 0.005 - 68
# 0.005 - 69
# 0.005 - 70
# 0.005 - 71
# 0.005 - 72
# 0.005 - 73
# 0.005 - 74
# 0.005 - 75
# 0.005 - 76
# 0.005 - 77
# 0.005 - 78
# 0.005 - 79
# 0.005 - 80
# 0.005 - 81
# 0.004 - 82
# 0.004 - 83
# 0.004 - 84
# 0.004 - 85
# 0.004 - 86
# 0.004 - 87
# 0.004 - 88
# 0.004 - 89
# 0.004 - 90
# 0.004 - 91
# 0.004 - 92
# 0.004 - 93
# 0.004 - 94
# 0.004 - 95
# 0.004 - 96
# 0.004 - 97
# 0.003 - 98
# 0.003 - 99
# 0.003 - 100
# 0.003 - 101
# 0.003 - 102
# 0.003 - 103
# 0.002 - 104
# 0.002 - 105
# -0.0 - 106
# Die 'pop'-Variable ist 106, da rundliste kleiner als 0.001 ist.

# %%
#100 Schwelenwert bestimmen
sw = pop-1
print(sw)
# Out:
# 105

# %%
filename ='!_neu'  #101 Der Dateiname für die CSV-Datei (ohne Erweiterung)
tit = (text_pos[s_zahl-sw:s_zahl])  #102 Die Titelzeile, die geschrieben werden soll

#103 Öffnen der CSV-Datei zum Schreiben ('wt' für Schreiben im Textmodus)
with open (filename+'.csv', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f)  #85 Initialisieren des CSV-Schreibers
    writer.writerow(tit)  #86 Schreiben der Titelzeile in die CSV-Datei

# %% [markdown]
# ### Messdaten aufbereiten

# %%
import xml.etree.ElementTree as ET  # Importieren der ElementTree-Bibliothek zum Parsen von XML

# XML-Daten laden
tree = ET.parse('gesamt_märchen.xml')
root_node = tree.getroot()

# Namespace definieren
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}

# Filtereinstellung für das Attribut `@ident` (kann leer sein)
filter_ident = "rus"  # z. B. input("Bitte geben Sie das Attribut 'ident' an (z.B. 'kat'): ").strip()

# Variable für die gesammelten Märchendaten
maerchen = ""

# Iteration durch die XML-Daten
for corp in root_node.findall(".//tei:teiCorpus", NS):
    if "tg" in corp.attrib.get("n", "") or "xtk" in corp.attrib.get("n", ""):
        for tei in corp.findall("tei:TEI", NS):
            # Filter basierend auf `@ident` oder bei leerem `filter_ident`
            language = tei.find(".//tei:teiHeader//tei:langUsage/tei:language", NS)
            if language is not None:
                ident_value = language.attrib.get('ident', '')
                if filter_ident == "" or ident_value == filter_ident:
                    for ganze in tei.findall(".//tei:text", NS):
                        quelle = ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                        for body in ganze.findall(".//tei:body", NS):
                            for absatz in body.findall(".//tei:p", NS):
                                for phrase in absatz.findall(".//tei:seg", NS):
                                    # Labels extrahieren
                                    labela = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/a}ana', 'N/A')
                                    labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N/A')
                                    labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N/A')
                                    labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N/A')
                                    labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N/A')
                                    labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N/A')
                                    labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N/A')
                                    labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N/A')
                                    labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N/A')
                                    labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N/A')
                                    labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N/A')
                                    labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N/A')
                                    inhalt = (phrase.text.lower().strip()
                                              .replace('|', '').replace(':', '').replace("ä", "ae")
                                              .replace("ü", "ue").replace("ö", "oe").replace("ß", "ss")
                                              .replace(",", "").replace("\n", " ").replace("'", "")
                                              .replace("…", "").replace('"', "").replace("*", "")
                                              .replace("(", "").replace(")", "").replace("-", "")
                                              .replace("]", "").replace("[", "").replace(".", "")
                                              .replace("?", "").replace("!", "").replace("„", "")
                                              .replace("+", "").replace("=", "").replace("_", "")
                                              .replace("­", "").replace('“', "").replace('”', "")
                                              .replace(";", "").replace('~', "").replace('`', ""))
                                    # Bedingung: labela beginnt mit 'a' und labelb1 ist nicht 'N/A'
                                    if labelb1.startswith('N'):
                                        # Märchendaten sammeln
                                        maerchen += (quelle + ',' + labela + ',' + labelb1 + ',' + labelc1 + ',' +
                                                     labelb2 + ',' + labelc2 + ',' + labelb3 + ',' + labelc3 + ',' +
                                                     labelb4 + ',' + labelc4 + ',' + labelb5 + ',' + labelc5 + ',' +
                                                     labeld + ',' + inhalt + ',0' + '\n')

# Ergebnisse in eine CSV-Datei schreiben
with open("text.csv", 'w', encoding='utf-8') as f:
    # Kopfzeile schreiben
    f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar')
    f.write('\n')
    # Gesammelte Märchendaten schreiben
    f.write(maerchen)

print(f"Die Märchendaten mit 'ident'='{filter_ident}' wurden in 'text.csv' gespeichert.")
# Out:
# Die Märchendaten mit 'ident'='rus' wurden in 'text.csv' gespeichert.

# %%
#118 Öffnen der CSV-Datei im Lesemodus und Lesen ihres Inhalts
with open(filename+'.csv', 'r', encoding='utf-8') as file:
    file_contents = file.read().replace(",", " ").replace("\n", "")  #119 Entfernen von Kommas und Zeilenumbrüchen

#120 Zusammenstellen des neuen Inhalts mit dem Dateinamen und zusätzlichen Metadaten
frt_contents = filename+',N,N,N,N,N,N,N,N,N,N,N,N'+','+file_contents+',0'

#121 Löschen der ursprünglichen CSV-Datei
import os 
os.remove(filename+'.csv')

# %%
row = [frt_contents]  #122 Erstellen einer neuen Zeile mit dem zusammengestellten Inhalt

#123 Öffnen der CSV-Datei im Lesemodus und Lesen der vorhandenen Zeilen
with open("text.csv", 'r', encoding='utf-8') as readFile:
    rd = csv.reader(readFile)  #124 Initialisieren des CSV-Lesers
    lines = list(rd)  #125 Lesen der Zeilen und Konvertieren in eine Liste

    #126 Einfügen der neuen Zeile an der zweiten Position in die Liste der Zeilen
    lines.insert(1, row)

#127 Öffnen der CSV-Datei im Schreibmodus und Schreiben der aktualisierten Zeilen
with open("text.csv", 'wt', newline='', encoding='utf-8') as writeFile:
    wt = csv.writer(writeFile)  #128 Initialisieren des CSV-Schreibers
    wt.writerows(lines)  #129 Schreiben der Zeilen in die Datei

#130 Öffnen der ursprünglichen und neuen CSV-Dateien zum Lesen bzw. Schreiben
fin = open('text.csv', 'r', encoding='utf-8')
fout = open('text_reich.csv', "wt", encoding='utf-8')

#131 Iteration über die Zeilen der ursprünglichen CSV-Datei
for kfz in fin:
    #132 Schreiben der Zeile in die neue Datei mit Entfernung bestimmter Zeichenfolgen
    fout.write(kfz.replace('"', ''))
#133 Schließen beider Dateien
fin.close()
fout.close()

# %%
#134 Funktion für die Beseitigung der leeren Datensätzen
def delete_records_with_empty_field(file_path, field_name):
    
    #135 Öffnen der CSV-Datei im Lese-Modus
    with open(file_path,  'r', encoding="utf-8") as file:
        #136 Lesen der Daten als Liste von Dictionaries
        reader = csv.DictReader(file)
        rows = list(reader)

    #137 Überprüfen, ob das Feld in den Daten leer ist
    filtered_rows = [row for row in rows if row[field_name]]

    #138 Öffnen der CSV-Datei im Schreibmodus und Schreiben der verbleibenden Datensätze
    with open(file_path, 'w', encoding="utf-8", newline='') as file:
        writer = csv.DictWriter(file, fieldnames=reader.fieldnames)
        writer.writeheader()
        writer.writerows(filtered_rows)

#139 Beispielaufruf der Funktion
file_path = 'text_reich.csv'  #140 Passe den Pfad zu deiner CSV-Datei an
field_name = 'inhalt'  #142 Passe den Namen des Feldes an, das überprüft werden soll
delete_records_with_empty_field(file_path, field_name)

# %%
t_corpus = []  #143 Eine leere Liste zum Speichern der Textdaten
df = pd.read_csv('text_reich.csv', encoding='utf-8')  #144 Einlesen der CSV-Datei in ein Pandas DataFrame
file = 'text_reich.csv'  #145 Der Dateiname der CSV-Datei

#146 Öffnen der CSV-Datei im Lesemodus und Extrahieren der Textdaten
with open(file, "rt", encoding='utf-8') as maerchen:
    maercho = df.inhalt  #147 Extrahieren der Spalte "inhalt" aus dem DataFrame
    reader = csv.reader(maercho)  #148 Initialisieren des CSV-Lesers
    for row in reader:
        lst = str(row)  #149 Konvertieren der gelesenen Zeile in eine Zeichenfolge
        t_corpus.append(lst)  #150 Hinzufügen der Zeichenfolge zur Liste der Textdaten

# %% [markdown]
# ### Vorhersage

# %%
# from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity

#162 Initialisieren des TF-IDF-Vektorisierers mit bestimmten Parametern
vectorizer = TfidfVectorizer(analyzer='word', ngram_range=(1,1), 
                             min_df=1, stop_words=stpw)

#163 Erstellen des Vokabulars aus den Textdaten mit dem TF-IDF-Vektorisierer
vocabulary = vectorizer.fit_transform(t_corpus)

#164 Funktion zur Suche nach ähnlichen Dokumenten basierend auf der Kosinusähnlichkeitsmetrik
def find_similar(vocabulary, index, top_n=-1):
    #165 Berechnen der Kosinusähnlichkeitswerte zwischen dem ausgewählten Dokument und allen anderen Dokumenten
    similarities = cosine_similarity(vocabulary[index:index+1], vocabulary).flatten()
    #166 Sortieren der Dokumente basierend auf den Kosinusähnlichkeitswerten in absteigender Reihenfolge
    related_docs_indices = [i for i in similarities.argsort()[::-1] if i != index]
    #167 Auswahl der Top-n ähnlichsten Dokumente und Rückgabe ihrer Indizes und Kosinusähnlichkeitswerte
    return [(index, similarities[index]) for index in related_docs_indices][:top_n]

#168 Die TF-IDF-Vektoren für die Textdaten können über `vocabulary` abgerufen werden
# print(vocabulary)

# %%
n_te = 0  #169 Index des ersten Dokuments
inhalt = df.inhalt[n_te]
print(inhalt)  #170 Ausgabe des Inhalts des ersten Dokuments

#with open(gesep_1.replace(':','')+'.txt','w', encoding="utf-8") as file:
    #file.write(inhalt)
# Out:
# время жена сказал хана отца хану рассказал пошли некоторое собой одну пришли которая нам жене свое поэтому сколько решили никто мою завтра говорит понял сыну принес золото горе крикнул дорогой тебе оба домой твоего ах ямы богатства никому сынок отсюда работу сможет ночей золотом поймать тело конец отрубил спустился говори тяжело случившемся крепость просьбу другим оставить стену прыгнул мешки заплакал отнес силы племянник трудно единственный узнает удалось плачь жаль ох украсть принесу выбраться отнеси прости научил молодости народом сокровищами сиди прихватив снова взобрались воровали кумухскому повезло дяде ремеслу выполни крепостную телу плохому навозе спущусь привычную выберусь яму отец дядя отрубят отруби увяз смоле дяди голову

# %%
# 171 Iteration über die ähnlichen Dokumente zum ersten Dokument
for index, score in (find_similar(vocabulary, n_te)):
    #172 Überprüfen, ob die Ähnlichkeit größer als 0.1 ist
    if score > 0.03:
        #173 Ausgabe des Index, der Ähnlichkeit, der Quelle und des Inhalts des ähnlichen Dokuments
        print(index, '-', score, '-', df.quelle[index], '-', t_corpus[index], '\n')
# Out:
# 12546 - 0.12881877060876862 - zyx_cr_ttt_rus_48 - ['рассказал отец сыну все как есть и говорит']
