# %% [markdown]
# # Lemmatizer

# %%
wortlaut = ["Abraten von der Mission",
"Abtretung steht bevor",
"Adoption",
"Aneignen",
"Aneignen beheben",
"Angebot von Heiratswilligen",
"Angebot von Heiratswilligen nachgehen",
"Angebot von Schatzhütern",
"Angebot von Schatzhütern nachgehen",
"Angebot zum König zu werden",
"Angebot zum König zu werden nachgehen",
"Anlocken",
"Anlocken nachgehen",
"Anregen zu Beauftragungen",
"Arrangierte Verlobung",
"Auf dem Weg nach Hause",
"Aufgabe anpacken",
"Auftrag Kochen",
"Ausgangslosen Ort entkommen",
"Ausgangslosen Ort gelangen",
"Ausrüsten",
"Ausrüsten nachgehen",
"Aussetzung",
"Ausspionieren beauftragen",
"Ausspionieren des Geheimnisses Zauberfohlen",
"Ausspionieren des Geheimnisses Zaubergegenstandes",
"Ausspionieren des Geheimnisses external soul",
"Baumersteigen",
"Bauwerk errichten",
"Begehren",
"Begleiter gewinnen",
"Begnadigen der potenziellen Beute",
"Begnadigen des Einbrechers",
"Behinderung beheben",
"Behinderung durch den Fluch",
"Behinderung durch die Verstümmelung",
"Belauschen",
"Belauschen misslingen",
"Besitzer des Objektes beschaffen",
"Besitzer des Objektes ergreifen",
"Bestrafung",
"Beute teilen",
"Beute teilen hat Wirkung",
"Beute teilen nachgehen",
"Botschaften verfälschen",
"Botschaften versenden",
"Demütigung beheben",
"Demütigung des verleumdeten Helden",
"Den Bösen Eigene Kinder fressen lassen",
"Den Bösen Eigene Kinder schlachten lassen",
"Den Bösen Schaden einrichten lassen",
"Einladung folgen",
"Empfängnismittel ergreifen",
"Empfängnismittel erhalten",
"Empfängnismittel suchen",
"Ende",
"Entführen",
"Entführen beheben",
"Entführten finden",
"Entmachten",
"Entmachten beheben",
"Erklärungsbedürftigem Verhalten von Betrügern",
"Erklärungsbedürftigem Verhalten von Bigotterie",
"Erklärungsbedürftigem Verhalten von Dieben",
"Erklärungsbedürftigem Verhalten von Geiz",
"Erklärungsbedürftigem Verhalten von Grobheit",
"Erklärungsbedürftigem Verhalten von Heiratswilligen",
"Erklärungsbedürftigem Verhalten von Klatschweibern",
"Erklärungsbedürftigem Verhalten von Rabenkindern",
"Erklärungsbedürftigem Verhalten von Schatzhütern",
"Erklärungsbedürftigem Verhalten von dem Alte",
"Erklärungsbedürftigem Verhalten von dem Ehemann",
"Erklärungsbedürftigem Verhalten von dem Fährmann",
"Erklärungsbedürftigem Verhalten von der Arbeitsscheu",
"Erklärungsbedürftigem Verhalten von leidendem Raubtier",
"Erklärungsbedürftigem Verhalten von leidendem Raubtier gefressen werden",
"Erklärungsbedürftigem Verhalten von unstillbarem Durst",
"Erklärungsbedürftigem Verhalten von unstillbarem Hunger",
"Erklärungsbedürftigem Verhalten von verweigerter Gastfreundschaft",
"Erklärungsbedürftigem Verhalten von vorehelichem Geschlechtsverkehr",
"Erlösung folgt",
"Erpressen Heiratszusage",
"Erpressen Hilfe",
"Erpressen Wegführung",
"Erpressen des Meineides",
"Erpressen des Meineides beheben",
"Erpressen für Wiedergutmachung",
"Erste Liebe ignorieren",
"Erste Liebe ignorieren beheben",
"Erzählen",
"Existenz sichern",
"Existenzforgewechselte verkaufen",
"Verwünschen",
"Verwünschen beheben",
"Viel Holz beschaffen",
"Viel essen",
"Viele Kinder werden auf einmal geboren",
"Vogel beschaffen",
"Vogel ergreifen",
"Vorhersagen treffen",
"Vortäuschen angeblicher Testnotwendigkeit",
"Vortäuschen angeblicher Unwissenheit Unsicherheit",
"Vortäuschen der Heldentat",
"Vortäuschen einer Abweisung",
"Vortäuschen einer Bedrohung",
"Vortäuschen einer Gastfreundlichkeit",
"Vortäuschen einer Heilkunst",
"Vortäuschen einer Kollaboration",
"Vortäuschen einer Krankheit",
"Vortäuschen einer Rebelion des Zielobjektes",
"Vortäuschen einer Reichen Erbschaft",
"Vortäuschen einer Treue",
"Vortäuschen einer Wachsamkeit Anwesenheit",
"Vortäuschen einer universalen Methode",
"Vortäuschen eines Reichtums",
"Vortäuschen eines Todes",
"Vortäuschen eines Verlustes",
"Vortäuschen nachgehen",
"Vortäuschen während der Niederkunft",
"Wache halten",
"Wahl zwischen materiellem und immateriellem Gut",
"Wassermangel auslösen",
"Wassermangel beheben",
"Wegweisung mit Optionen",
"Weihe vorschreiben",
"Weihen durchführen",
"Weisheiten erhalten",
"Werben um den Auftrag",
"Werben um den Mann",
"Werben um die Frau",
"Wetten Versteckwette",
"Wetten dass der Freier die Braut verführt",
"Wettkampf",
"Wettlauf",
"Wiederbelebung",
"Wild beschaffen",
"Wild ergreifen",
"Wunderbare Empfängnis",
"Wunsch erfüllen",
"Zauberkunst erlernen",
"Zauberkunstfertigkeit gewährleisten",
"Zaubermittel Ausrüstung oder die Waffe ausprobieren",
"Zaubermittel Ausrüstung oder die Waffe einstzen",
"Zaubermittel beschaffen",
"Zaubermittel erhalten",
"Zaubermühle beschaffen",
"Zollerhebung vollstrecken",
"Zug von Reisenden bzw Karavane folgen",
"Zum Schlafen bringen",
"Zum fremden Ort gelangen",
"Zurückgreifen",
"Zusammenbringen aller Beteiligten",
"Zuschnappendes Hindernis überwinden",
"Zwangsehe Drohung",
"Zwangsehe Drohung beheben",
"Zweikampf",
"Über die Brücke gehen",
"Überraschen",
"Überweisung an anderen Stifter oder Helfer",
"Überwinden von Unwegsamkeit"
]

# %%
custom_stop_word_list=[]
import spacy
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
NLTK_stop_words_list=stopwords.words('german')
de = custom_stop_word_list + NLTK_stop_words_list
nlp = spacy.load("fr_core_news_md")
#print(de)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\elguj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
###nicht lemmatisiert

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.pipeline import Pipeline
import numpy as np
vectorizerCount = CountVectorizer( min_df=1, stop_words=de)
vocabularyCount = vectorizerCount.fit_transform(wortlaut)
print (vectorizerCount.vocabulary_, sep='\n')
# Out:
# {'abraten': 1, 'mission': 281, 'abtretung': 4, 'steht': 358, 'bevor': 61, 'adoption': 6, 'aneignen': 8, 'beheben': 45, 'angebot': 11, 'heiratswilligen': 197, 'nachgehen': 290, 'schatzhütern': 330, 'könig': 248, 'anlocken': 13, 'anregen': 15, 'beauftragungen': 37, 'arrangierte': 19, 'verlobung': 425, 'hause': 191, 'aufgabe': 20, 'anpacken': 14, 'auftrag': 24, 'kochen': 237, 'ausgangslosen': 25, 'ort': 300, 'entkommen': 99, 'gelangen': 170, 'ausrüsten': 28, 'aussetzung': 30, 'ausspionieren': 31, 'beauftragen': 36, 'geheimnisses': 166, 'zauberfohlen': 485, 'zaubergegenstandes': 486, 'external': 130, 'soul': 354, 'baumersteigen': 34, 'bauwerk': 35, 'errichten': 118, 'begehren': 40, 'begleiter': 42, 'gewinnen': 178, 'begnadigen': 43, 'potenziellen': 310, 'beute': 60, 'einbrechers': 85, 'behinderung': 46, 'fluch': 141, 'verstümmelung': 441, 'belauschen': 48, 'misslingen': 282, 'besitzer': 54, 'objektes': 296, 'beschaffen': 52, 'ergreifen': 104, 'bestrafung': 55, 'teilen': 369, 'wirkung': 4
# ...

# %%
### lemmatisiert

# %%
from HanTa import HanoverTagger as ht
tagger = ht.HanoverTagger('morphmodel_ger.pgz')
wortlaut_lemma = []
for wort in wortlaut:
    lemma = [lemma for (word,lemma,pos) in tagger.tag_sent(wort.split())]
    wortlaut_lemma.append(' '.join(lemma))
print(wortlaut_lemma)
# Out:
# ['Abraten von der Mission', 'Abtretung stehen bevor', 'Adoption', 'Aneignen', 'Aneignen beheben', 'Angebot von Heiratswillige', 'Angebot von Heiratswillige nachgehen', 'Angebot von Schatzhüter', 'Angebot von Schatzhüter nachgehen', 'Angebot zu König zu werden', 'Angebot zu König zu werden nachgehen', 'Anlocken', 'Anlocken nachgehen', 'Anregen zu Beauftragung', 'arrangiert Verlobung', 'auf der Weg nach Haus', 'Aufgabe anpacken', 'Auftrag Kochen', 'ausgangslos Ort entkommen', 'ausgangslos Ort gelangen', 'Ausrüsten', 'Ausrüsten nachgehen', 'Aussetzung', 'Ausspionieren beauftragen', 'ausspionieren der Geheimnis Zauberfohle', 'ausspionieren der Geheimnis Zaubergegenstand', 'ausspionieren der Geheimnis External Soul', 'Baumersteige', 'Bauwerk errichten', 'Begehren', 'Begleiter gewinnen', 'begnadigen der potenziell Beute', 'begnadigen der Einbrecher', 'Behinderung beheben', 'Behinderung durch der Fluch', 'Behinderung durch der Verstümmelung', 'Belausche', 'Belausche misslingen', 'Besitzer d
# ...

# %%
vectorizerCount = CountVectorizer( min_df=1, stop_words=de)
vocabularyCount = vectorizerCount.fit_transform(wortlaut_lemma)
print (*vectorizerCount.vocabulary_, sep='\n')
# Out:
# abraten
# mission
# abtretung
# stehen
# bevor
# adoption
# aneignen
# beheben
# angebot
# heiratswillige
# nachgehen
# schatzhüter
# könig
# anlocken
# anregen
# beauftragung
# arrangiert
# verlobung
# haus
# aufgabe
# anpacken
# auftrag
# kochen
# ausgangslos
# ort
# entkommen
# gelangen
# ausrüsten
# aussetzung
# ausspionieren
# beauftragen
# geheimnis
# zauberfohle
# zaubergegenstand
# external
# soul
# baumersteige
# bauwerk
# errichten
# begehren
# begleiter
# gewinnen
# begnadigen
# potenziell
# beute
# einbrecher
# behinderung
# fluch
# verstümmelung
# belausche
# misslingen
# besitzer
# objekt
# beschaffen
# ergreifen
# bestrafung
# teilen
# wirkung
# botschaft
# verfälschen
# versenden
# demütigung
# verleumdet
# held
# böse
# eigen
# kind
# fressen
# lassen
# schlachten
# bös
# schaden
# einrichten
# einladung
# folgen
# empfängnismittel
# erhalten
# suchen
# ende
# entführen
# entführte
# finden
# entmachten
# erklärungsbedürftig
# verhalten
# betrüger
# bigotteri
# dieb
# ...
