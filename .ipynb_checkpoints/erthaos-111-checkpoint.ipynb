# %% [markdown]
# ## Google Colab Arbeitplatz vorbereiten

# %% [markdown]
# # erthaos-1

# %%
maerchen="" 
import xml.etree.ElementTree as ET
root_node = ET.parse('gesamt_märchen_1.xml').getroot()
never_saved = True
for ganze in root_node.findall(".//{http://www.tei-c.org/ns/1.0}text"):
    if ('deu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id'] 
        or 'uuu' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']):
        for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
            for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
                for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}*"):
                        labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
                        labelb1 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b1}ana']
                        labelb2 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b2}ana']
                        labelb3 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b3}ana']
                        labelb4 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b4}ana']
                        labelb5 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b5}ana']
                        labelc1 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c1}ana']
                        labelc2 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c2}ana']
                        labelc3 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c3}ana']
                        labelc4 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c4}ana']
                        labelc5 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c5}ana']
                        labeld = phrase.attrib['{www.dglab.uni-jena.de/vmf/d}ana']
                        quelle= ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
                        inhalt = (phrase.text.lower().strip().replace('|','').replace(':','').replace("ä","ae")
                                  .replace("ü","ue").replace("ö","oe").replace("ß","ss").replace(",","")
                                  .replace("«","").replace("»","").replace(".","").replace('=',' ').replace(";","")
                                  .replace('"',"").replace("?","").replace("!","").replace("á","a").replace(",","")
                                  .replace("\t"," ").replace("'","").replace("‹","").replace("›","").replace("-"," ")
                                  .replace("'('","").replace("')'","").replace('>','').replace("    "," ")
                                  .replace("   "," ").replace("  "," ").replace('–','').replace('—','').replace('<','')
                                  .replace("Â", "A").replace("ø", "oe").replace('“','').replace('„','').replace('(','')
                                  .replace(')','').replace('*','').replace("\n","\n")
                                  .replace("'''",""))
                        if labela.startswith('a') and labela!='N':
                            
                            maerchen += quelle+','+labela+','+labelb1+','+labelc1+','+labelb2+','+labelc2+','+labelb3+','+labelc3+','+labelb4+','+labelc4+','+labelb5+','+labelc5+','+labeld+','+inhalt+',0'+'\n'
                            #maerchen += quelle+','+labela+','+labelb1+','+labelc1+','+labelb2+','+labelc2+','+labelb3+','+labelc3+','+labelb4+','+labelc4+','+labelb5+','+labelc5+','+inhalt+',0'+'\n'

with open("text.csv", 'w', encoding='utf-8') as f:
    f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar')
    f.write('\n')
    f.write(maerchen)

# %%
abcd1=""
abcd2=""
abcd3=""
abcd4=""
abcd5=""
import pandas as pd
from collections import Counter
df = pd.read_csv('text.csv',  encoding='utf-8')
abcd1 += df.quelle+','+df.labela+':'+df.labelb1+':'+df.labelc1+':'+df.labeld+','+df.inhalt+',0'
abcd2 += df.quelle+','+df.labela+':'+df.labelb2+':'+df.labelc2+':'+df.labeld+','+df.inhalt+',0'
abcd3 += df.quelle+','+df.labela+':'+df.labelb3+':'+df.labelc3+':'+df.labeld+','+df.inhalt+',0'
abcd4 += df.quelle+','+df.labela+':'+df.labelb4+':'+df.labelc4+':'+df.labeld+','+df.inhalt+',0'
abcd5 += df.quelle+','+df.labela+':'+df.labelb5+':'+df.labelc5+':'+df.labeld+','+df.inhalt+',0'
# maca=':0:'
# for t in abcd3:
#     if maca not in t:
recorded=(abcd1+'\n'+abcd2+'\n'+abcd3+'\n'+abcd4+'\n'+abcd5+'\n')
with open("text_aw.csv", 'w', encoding='utf-8') as w:
    w.write('quelle,index_string,inhalt,index_binar\n')
    w.write('000:ballast,ballast,ballast,0\n')
    w.write("".join(recorded))
    w.close()

# %%
import csv
mom=[]
with open('text_aw.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f) 
    for line in reader:
        if ':N:' not in line[1]:
            mom.append(line)

# %%
import shutil, os
with open ('text_ax.txt', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(mom)

# %%
with open('text_ax.txt', 'r', encoding='utf-8') as file:
    filedata = file.read()
filedata = filedata.replace(']","[', "\n").replace('"[','').replace(']"','').replace(" '","").replace("'","")
with open('text_ay.csv', 'w', encoding='utf-8') as file:
    file.write(filedata)

# %%
custom_stop_word_list=[]
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
NLTK_stop_words_list=stopwords.words('russian')
ru = custom_stop_word_list + NLTK_stop_words_list
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\elguj\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import pandas as pd
from collections import Counter
df = pd.read_csv('text_ay.csv',  encoding='utf-8')
indexliste=Counter(df.index_string)
print(*indexliste, sep='\n')
# Out:
# ballast
# a590:h:Kinderlosigkeit:rHH
# a590:H:Empfängnismittel_erhalten:rHH_rAN
# a590:H:Wunderbare_Empfängnis:rHD_rHF
# a590:F:Geboren_werden:rHD_rHF
# a590:h:Kontakt_abbrechen:rHH_fHH
# a590:h:Heimliche_Liebesbeziehung:rAN_fHH
# a590:f:Ungewünschtes_Wesen_aus_dem_Weg_räumen:rAN_fHH
# a590:h:Lebensgefahr_Vergiftung:rAN_fHH
# a590:F:Zurückgreifen:rHD_rHF
# a590:H:Handlungsanweisung_Lebensgefahr_beheben:rHD_rHF
# a590:H:Lebensgefahr_beheben:rHD_fHH
# a590:h:Lebensgefahr_Vergiftung:fHH
# a590:h:Lebensgefahr_Verborgene_Waffe:fHH
# a590:f:Vortäuschen_einer_Krankheit:rAN_fHH
# a590:F:Krankheit_beheben:rHH_rST
# a590:h:Krankheit_beheben:rHH_rST
# a590:f:Anregen_zu_Beauftragungen:rAN_fHH
# a590:f:Todesauftrag:rAN_fHH
# a590:F:Ausrüsten:rHD_fHH
# a590:H:Zaubermittel_Ausrüstung_oder_die_Waffe_ausprobieren:rHD_rHF_fHH
# a590:F:Ausrüsten:rHD_rHF_fHH
# a590:H:Flucht:rHD_rHF_fHH
# a590:f:Identität_wechseln:rHD_rHF
# a314:F:Vertrag_abschließen:rHD_rHP
# a314:f:Liebe:rHD_rPP
# a314:F:Markieren:rHP_fPP
# a314:F:Markieren_erkennen:rHP_fPP
# a314:F:Markieren:rHP_rPP
# a314:F:Markieren_erkennen:rHP_rPP
# a314:f:Werben_um_den_Mann:rHP
# a314:f:Werben_um_den_Mann:fPP
# a314:Ff:Werben_um_den_Mann:rHP_rPP
# a314:f:Respektlosigkeit:rHP_rPP
# a551:h:Krankheit:rHH_rVB
# a551:F:Heilmittel_beschaffen:rHH_rVB
# a551:F:Ausrüsten:fHD
# a551:F:Werben_um_den_Auftrag:rHP_rPP
# a551:Hh:Ausrüsten:rHD_fHD_fZM
# a551:h:Respektlosigkeit:rHD_fHD_fZM
# a551:F:Kontakt_wiederherstellen:rHD_rHF_rZO
# a551:H:Identität_wechseln:rHD_rHF_rZO
# a551:H:Objekt_ergreifen:rHD_rHF_rZO
# a551:F:Markieren:rHD_fHD
# a551:f:Identität_wechseln:rHD_fHD
# a551:h:Krankheit_beheben:rHP_fHD
# a551:F:Heilmittel_beschaffen:rHD_rPP
# a551:F:Vermittlung:rHP_rPP
# a551:H:Krankheit_beheben:rHD_rHP
# a551:unklar:unklar:rHD_rHP
# a551:F:Zurückgreifen:rHD_rHF_rHP
# a551:F:Identität_wechseln:rHD_rHF_rHP
# a551:F:Held_erkennen:rHD_rHF_rHP
# a551:F:Markieren_erkennen:rHP_fHD
# a551:F:Bestrafung:rHP_fHD
# a551:h:Krankheit:rHH
# a551:F:Heilmittel_beschaffen:rHD_rHH_fHD
# a551:f:Vertrag_abschließen:rHD_rHH_fHD
# a551:F:Höfliches_Verhalten:rHD_rST
# a551:H:Höfliches_Verhalten:rHD_rST
# a551:Hh:Überweisung_an_anderen_Stifter_oder_Helfer:rHD_rST
# a551:F:Heilmittel_beschaffen:rHD_rST
# a551:H:Handlungsanweisung_Objekt_ergreifen:rHD_rST
# a551:f:Tabu_Sonstiges:rHD_rST
# a551:H:Objekt_ergreifen:rHD_rZO
# a551:h:Tabubruch_erfolgt:rHD_rZO
# a313:H:Flucht_mit_hinter_sich_geworfenen_Gegenständen:rHD_rBZ
# a551:H:Heilmittel_beschaffen:rHD_rST
# a551:h:Schweigenplicht_erhängen:rHD_rZO_fHD
# a551:h:Missetat_Aneignen:rHD_rZO_fHD
# a551:h:Identität_wechseln:rHD_rZO_fHD
# a551:Hh:Heilmittel_beschaffen:rHH_rZO_fHD
# a551:Hh:Krankheit_beheben:rHH_rZO_fHD
# a551:h:Vertrag_appelieren:rHH_rZO_fHD
# a551:h:Respektlosigkeit:rHD_fHD
# a551:F:Kontakt_wiederherstellen:rHH_rBZ
# a551:h:Identität_testen:rBZ_fHD
# a551:F:Wettkampf:rHH_rBZ
# a551:F:Werben_um_den_Auftrag:rHD_rHH
# a551:H:Identität_testen:rHD_rHH_rBZ
# a551:H:Kontakt_wiederherstellen:rHD_rHH_rBZ
# a551:H:Bestrafung:fHD
# a551:H:Heiraten:rHD_rHH_rBZ
# a551:F:Seltenen_Gegenstand_beschaffen:rHH_rVB
# a551:F:Werben_um_den_Auftrag:rHH_fHD
# a551:F:Ausrüsten:rHH_fHD
# a551:H:Ausrüsten:rZM_fHD
# a551:Ff:Wegweisung_mit_Optionen:rZM_fHD
# a551:Hh:Wegweisung_mit_Optionen:rZM_fHD
# a551:f:Zum_fremden_Ort_gelangen:rAN_fZO
# a551:Hh:Objekt_ergreifen:rAN_fZO
# a551:h:Seltenen_Gegenstand_beschaffen:rHH_fHD
# a551:h:Festnahme_bzw_Sperren:rHH_fHD
# a551:f:Zum_fremden_Ort_gelangen:rAN_fHD
# a551:f:Vortäuschen_einer_Gastfreundlichkeit:rAN_fHD
# a551:h:Vortäuschen_nachgehen:rAN_fHD
# a551:h:Festnahme_bzw_Sperren:rAN_fHD
# a551:F:Ausrüsten:rHD_rHH
# a551:Hh:Ausrüsten:N
# a551:H:Reittier_erhalten:rHD
# a551:Ff:Wegweisung_mit_Optionen:rHD_rZM
# a551:h:Wegweisung_mit_Optionen:rHD_rZM
# a551:F:Gastgeberschaft_sichern:rHD_rST
# a551:H:Reittier_erhalten:rHD_rST
# a551:H:Handlungsanweisung_Richtiges_auswählen:rHD_rST
# a551:H:Richtiges_auswählen:rHD_rBZ_rZO
# a551:F:Markieren:rHD_rBZ_rZO
# a551:H:Objekt_ergreifen:rHD_rBZ_rZO
# a551:H:Zaubermittel_erhalten:rHD_rBZ_rZO
# a551:h:Kontakt_abbrechen:rHD_rBZ_rZO
# a551:h:Pförtner_entkommen:rHD_rBZ_fHF
# a551:F:Flucht:rHD_rST
# a551:F:Verfolgung_hindern:rST_rBZ
# a551:H:Verfolgung_hindern:rST_rBZ
# a551:H:Verfolgung_entkommen:rHD_rBZ
# a551:F:Verschwinden_beheben:rHD_rAN
# a551:F:Zum_fremden_Ort_gelangen:rHD_rAN
# a551:f:Vortäuschen_einer_Gastfreundlichkeit:rHD_rAN
# a551:H:Vortäuschen_nachgehen:rHD_rAN
# a551:H:Bestrafung:rHD_rAN
# a551:H:Festnahme_bzw_Sperren_beheben:rHD_fHD
# a551:h:Schlaf:rHD
# a551:h:Missetat_Aneignen:fHD
# a551:F:Identität_wechseln:rHD
# a551:F:Kontakt_wiederherstellen:rHH_rVB_rBZ
# a551:h:Bestrafung:rBZ_fHD
# a551:H:Identitätswechsel_gestehen:rHD_rHH_rVB
# a551:F:Heilmittel_beschaffen:rHD_rVB_fHD
# a551:F:Höfliches_Verhalten:rST_fHD
# a551:h:Höfliches_Verhalten:rST_fHD
# a551:h:Festnahme_bzw_Sperren:rST_fHD
# a551:F:Handlungsanweisung_Pförtner_besänftigen:rHD_rST
# a551:h:Kontakt_abbrechen:rHD_rST
# a551:H:Pförtner_besänftigen:rHD_fHF
# a551:H:Pförtner_entkommen:rHD_fHF
# a551:H:Zaubermittel_erhalten:rHD_rZM
# a551:H:Handlungsanweisung_Objekt_ergreifen:rHD_fBZ
# a551:h:Kontakt_abbrechen:rHD_fBZ
# a551:F:Zurückgreifen:rHD_rST_fHD
# a551:F:Missetat_vermeiden:rHD_rST_fHD
# a551:Hh:Missetat_vermeiden:rHD_rST_fHD
# a551:Hh:Festnahme_bzw_Sperren:rHD_rST
# a551:F:Rettung_der_Hilfsbedürftigen:rHD_rHF_rZM
# a551:H:Rettung_der_Hilfsbedürftigen:rHD_rHF_rZM
# a551:h:Kontakt_abbrechen:rHD_rHF_rZM
# a551:f:Missetat_planen:rZO_fHD
# a551:h:Missetat_Aneignen:rZO_fHD
# a551:h:Heilmittel_beschaffen:rHD_rHH_fZO
# a551:h:Krankheit_beheben:rHD_rHH_fZO
# a551:h:Verleumdung_von_Untreue:rHH_rZO_fHD
# a551:h:Schweigenplicht_erhängen:rHD_fHD
# a551:f:Todesauftrag:rHH_rVB
# a551:H:Fassungslosigkeit_löst_Mitleidsgefühl_aus:rHD_rVB
# a551:H:Todesauftrag_entkommen:rHD_rVB
# a551:F:Zurückgreifen:rHH_rHF
# a551:H:Missetat_enthüllen:rHH_rHF
# a551:H:Verleumdung_beheben:rHH_rVB
# a551:F:Kontakt_wiederherstellen:fBZ
# a551:h:Identität_testen:fHD
# a551:H:Identität_testen:rHD_fBZ
# a551:H:Kontakt_wiederherstellen:rHD_fBZ
# a551:H:Schweigenplicht_beheben:rHD_rHH_fHD
# a551:H:Bestrafung:rHD_rHH_fHD
# a551:F:Heilmittel_beschaffen:rVB
# a551:f:Festnahme_bzw_Sperren:fHD_fVB
# a551:f:Anlocken:fHD_fVB
# a551:h:Anlocken_nachgehen:fHD_fVB
# a551:f:Anlocken:rHD_fVB
# a551:H:Anlocken_nachgehen:rHD_fVB
# a551:F:Rettung_der_Hilfsbedürftigen:rHD_fST
# a551:H:Rettung_der_Hilfsbedürftigen:rHD_fST
# a551:H:Handlungsanweisung_Pförtner_besänftigen:rHD_fST
# a551:H:Handlungsanweisung_Objekt_ergreifen:rHD_fST
# a551:F:Pförtner_besänftigen:rHD_fHF
# a551:f:Kontakt_abbrechen:rHD_rBZ_rZO
# a551:F:Rettung_der_Freikaufsbedürftigen:rHD_fHD
# a551:f:Respektlosigkeit:rHD
# a551:F:Kontakt_wiederherstellen:rHD_rBZ
# a551:F:Held_erkennen:rHD_rBZ
# a551:F:Heiraten:rHD_rBZ

# %%
gesep_a ="a551"
gesep_b = "F"
gesep_c = "Heilmittel_beschaffen"
gesep_d = ""

# %%
for i, gesuchte_label in enumerate(df.index_string):
    if gesep_a in gesuchte_label and gesep_b and gesuchte_label and gesep_c in gesuchte_label:# or gesep_d in gesuchte_label:
        print(i, gesuchte_label)
        df.index_binar.iloc[i]='1'
df.to_csv('text_lab.csv', encoding='utf-8', index=False)
# Out:
# 46 a551:F:Heilmittel_beschaffen:rHH_rVB
# 57 a551:F:Heilmittel_beschaffen:rHD_rPP
# 67 a551:F:Heilmittel_beschaffen:rHD_rHH_fHD
# 74 a551:F:Heilmittel_beschaffen:rHD_rST
# 76 a551:F:Heilmittel_beschaffen:rHD_rST
# 81 a551:F:Heilmittel_beschaffen:rHD_rST
# 86 a551:H:Heilmittel_beschaffen:rHD_rST
# 90 a551:Hh:Heilmittel_beschaffen:rHH_rZO_fHD
# 168 a551:F:Heilmittel_beschaffen:rHD_rVB_fHD
# 200 a551:h:Heilmittel_beschaffen:rHD_rHH_fZO
# 202 a551:Hh:Heilmittel_beschaffen:rHH_rZO_fHD
# 221 a551:F:Heilmittel_beschaffen:rVB
# C:\Users\elguj\AppData\Local\Temp\ipykernel_13380\682790586.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.index_binar.iloc[i]='1'

# %%
df = pd.read_csv('text_lab.csv',  encoding='utf-8')
X_train=(df['inhalt'])
y_train=(df['index_binar'])
indexliste=Counter(df.index_binar)
print(indexliste, sep='\n')
# Out:
# Counter({0: 235, 1: 12})

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import make_pipeline
pipe = make_pipeline(TfidfVectorizer(min_df=3, stop_words=ru, ngram_range=(1,1), norm=None), 
                     LogisticRegression())
param_grid = {'logisticregression__C': [0.001, 0.01, 0.1, 1, 10]}     
grid = GridSearchCV(pipe, param_grid, cv=5)
grid.fit(X_train, y_train)
print("Bester Score aus der Kreuzvalidierung: {:.2f}".format(grid.best_score_))
# Out:
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\elguj\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Bester Score aus der Kreuzvalidierung: 0.95

# %%
import numpy as np
vectorizer = grid.best_estimator_.named_steps["tfidfvectorizer"]
max_value = vectorizer.transform(X_train).max(axis=0).toarray().ravel()
sorted_by_tfidf = max_value.argsort()
feature_names = np.array(vectorizer.get_feature_names_out())
print("Gesamte Anzahl der Wörter: {}".format(len(vectorizer.vocabulary_)))
# Out:
# Gesamte Anzahl der Wörter: 1287

# %%
s_zahl = 200
import matplotlib.pyplot as plt
import mglearn
mglearn.tools.visualize_coefficients(
    grid.best_estimator_.named_steps["logisticregression"].coef_,
    feature_names,  n_top_features=s_zahl)
plt.grid()

# %%
gio=(grid.best_estimator_.named_steps["logisticregression"].coef_[0])
n_top=np.argsort(gio)
z_top=np.sort(gio)
text_pos=feature_names[n_top[-s_zahl:]]
text_neg=feature_names[n_top[0:s_zahl]]
zahl_pos=gio[n_top[-s_zahl:]]
zahl_neg=gio[n_top[0:s_zahl]]
print("Positive Merkmale:\n{}".format(text_pos))
#print ("Negative Merkmale:\n{}".format(text_neg))
#print ("Positive coef:\n{}".format(zahl_pos))
#print ("Negative coef:\n{}".format(zahl_neg))
# Out:
# Positive Merkmale:
# ['grusse' 'kuesse' 'uralte' 'milchstrasse' 'merken' 'maedchens2'
#  'aufgebunden' 'waers' 'gelingt' 'damals' 'reiss' 'fortziehst' 'entwenden'
#  'anfang' 'springe' 'heil' 'geboren' 'stammelte' 'findest' 'offen' 'axt'
#  'goldenen' 'hatte' 'euch' 'musste' 'rechte' 'schon' 'etwas' 'darin'
#  'ihrem' 'wohnt' 'seines' 'einer' 'haar' 'sprach' 'ihnen' 'bringe'
#  'nichts' 'gute' 'diesen' 'stimme' 'beiden' 'schloss' 'anderes' 'auch'
#  'sehen' 'weiblein' 'man' 'gezogen1' 'gruss' 'unterwegs' 'erwarte'
#  'schlechte' 'wohnte' 'zurueckkommst' 'weshalb' 'damit' 'todes' 'schweif'
#  'krank' 'solle' 'tagen' 'schickte' 'jungen' 'guten' 'gerade' 'sohn' 'ei'
#  'ein' 'viel' 'haette' 'jedoch' 'wollen' 'her' 'knecht' 'doch' 'gott'
#  'ganzes' 'vielleicht' 'alter' 'koennte' 'handtuch' 'buerste' 'sterben'
#  'gingen' 'gleich' 'freute' 'hinunter' 'holte' 'heilen' 'uebergab'
#  'kutscher' 'see' 'grossmutter' 'becher' 'juengsten' 'sondern' 'begegnete'
#  'sogleich' 'mein' 'daraus' 'traf' 'dieses' 'binde' 'deines' 'lieber'
#  'fuelle' 'ganzen' 'fand' 'soehnen' 'vergiften' 'finken' 'gebe' 'aerzte'
#  'altes' 'tages' 'dort' 'koenigstochter' 'wenn' 'herbei' 'trinken'
#  'wirklich' 'fuehrt' 'dank' 'gruesste' 'mache' 'finden' 'sache' 'wenig'
#  'maenner' 'krankheit' 'mann' 'kraenker' 'reichten' 'brachte' 'dass'
#  'graf' 'solch' 'meerwasser' 'zuvor' 'hier' 'seiner' 'pferde' 'alt'
#  'braechten' 'verschwinden' 'fuehlte' 'klagten' 'jammerte' 'stark'
#  'drittel' 'reiches' 'wackere' 'gekleidet' 'verstand' 'kranken'
#  'einstmals' 'von' 'schlafe' 'hand' 'betruebt' 'mittel' 'nach' 'aelter'
#  'helfen' 'vom' 'mitten' 'davon' 'welt' 'bald' 'kaum' 'weiss' 'darueber'
#  'jenseit' 'aeltesten' 'rat' 'lebens' 'weit' 'andere' 'drueckte' 'lahmen'
#  'huette' 'koenigssohn' 'waldes' 'alten' 'des' 'gehen' 'sagten' 'reihe'
#  'erzaehlte' 'wasser' 'jugend' 'getrunken' 'bekommen' 'wuerde' 'frau'
#  'soehne' 'krug' 'alte' 'gesund']

# %%
kfz=range(s_zahl)
folgenum=0
for x in kfz:
    folgenum+=1
    vollliste=(zahl_pos[s_zahl-folgenum])+(zahl_neg[s_zahl-folgenum])
    rundliste=(round(vollliste,3))
    print(rundliste, '-', x)
# Out:
# 0.013 - 0
# 0.012 - 1
# 0.01 - 2
# 0.009 - 3
# 0.009 - 4
# 0.007 - 5
# 0.007 - 6
# 0.006 - 7
# 0.006 - 8
# 0.006 - 9
# 0.005 - 10
# 0.005 - 11
# 0.005 - 12
# 0.005 - 13
# 0.004 - 14
# 0.004 - 15
# 0.004 - 16
# 0.004 - 17
# 0.004 - 18
# 0.004 - 19
# 0.004 - 20
# 0.004 - 21
# 0.004 - 22
# 0.004 - 23
# 0.004 - 24
# 0.004 - 25
# 0.003 - 26
# 0.003 - 27
# 0.003 - 28
# 0.003 - 29
# 0.003 - 30
# 0.003 - 31
# 0.003 - 32
# 0.003 - 33
# 0.003 - 34
# 0.003 - 35
# 0.003 - 36
# 0.003 - 37
# 0.003 - 38
# 0.003 - 39
# 0.003 - 40
# 0.003 - 41
# 0.003 - 42
# 0.002 - 43
# 0.002 - 44
# 0.002 - 45
# 0.002 - 46
# 0.002 - 47
# 0.002 - 48
# 0.002 - 49
# 0.002 - 50
# 0.002 - 51
# 0.002 - 52
# 0.002 - 53
# 0.002 - 54
# 0.002 - 55
# 0.002 - 56
# 0.002 - 57
# 0.002 - 58
# 0.002 - 59
# 0.002 - 60
# 0.002 - 61
# 0.002 - 62
# 0.002 - 63
# 0.002 - 64
# 0.002 - 65
# 0.002 - 66
# 0.002 - 67
# 0.002 - 68
# 0.001 - 69
# 0.001 - 70
# 0.001 - 71
# 0.001 - 72
# 0.001 - 73
# 0.001 - 74
# 0.001 - 75
# 0.001 - 76
# 0.001 - 77
# 0.001 - 78
# 0.001 - 79
# 0.001 - 80
# 0.001 - 81
# 0.001 - 82
# 0.001 - 83
# 0.001 - 84
# 0.001 - 85
# 0.001 - 86
# 0.001 - 87
# 0.001 - 88
# 0.001 - 89
# 0.001 - 90
# 0.001 - 91
# 0.001 - 92
# 0.001 - 93
# 0.001 - 94
# 0.001 - 95
# 0.001 - 96
# 0.001 - 97
# 0.001 - 98
# 0.001 - 99
# 0.001 - 100
# 0.001 - 101
# 0.001 - 102
# 0.001 - 103
# 0.001 - 104
# 0.001 - 105
# 0.001 - 106
# 0.001 - 107
# 0.0 - 108
# 0.0 - 109
# 0.0 - 110
# 0.0 - 111
# 0.0 - 112
# 0.0 - 113
# 0.0 - 114
# 0.0 - 115
# 0.0 - 116
# 0.0 - 117
# 0.0 - 118
# 0.0 - 119
# 0.0 - 120
# 0.0 - 121
# 0.0 - 122
# 0.0 - 123
# -0.0 - 124
# -0.0 - 125
# -0.0 - 126
# -0.0 - 127
# -0.0 - 128
# -0.0 - 129
# -0.0 - 130
# -0.0 - 131
# -0.0 - 132
# -0.0 - 133
# -0.0 - 134
# -0.0 - 135
# -0.0 - 136
# -0.0 - 137
# -0.0 - 138
# -0.0 - 139
# -0.001 - 140
# -0.001 - 141
# -0.001 - 142
# -0.001 - 143
# -0.001 - 144
# -0.001 - 145
# -0.001 - 146
# -0.001 - 147
# -0.001 - 148
# -0.001 - 149
# -0.001 - 150
# -0.001 - 151
# -0.001 - 152
# -0.001 - 153
# -0.001 - 154
# -0.001 - 155
# -0.001 - 156
# -0.001 - 157
# -0.001 - 158
# -0.001 - 159
# -0.001 - 160
# -0.002 - 161
# -0.002 - 162
# -0.002 - 163
# -0.002 - 164
# -0.002 - 165
# -0.002 - 166
# -0.002 - 167
# -0.002 - 168
# -0.002 - 169
# -0.002 - 170
# -0.002 - 171
# -0.002 - 172
# -0.002 - 173
# -0.002 - 174
# -0.002 - 175
# -0.002 - 176
# -0.002 - 177
# -0.003 - 178
# -0.003 - 179
# -0.003 - 180
# -0.003 - 181
# -0.004 - 182
# -0.004 - 183
# -0.004 - 184
# -0.004 - 185
# -0.004 - 186
# -0.005 - 187
# -0.005 - 188
# -0.005 - 189
# -0.005 - 190
# -0.005 - 191
# -0.005 - 192
# -0.005 - 193
# -0.005 - 194
# -0.005 - 195
# -0.007 - 196
# -0.007 - 197
# -0.008 - 198
# -0.024 - 199

# %%
sw=107

# %%
import csv 
import shutil, os
filename ='!_neu'#+gesep_1
tit=(text_pos[s_zahl-sw:s_zahl])
with open (filename+'.csv', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f)
    writer.writerow(tit)

# %% [markdown]
# # erthaos - Vorhersage -Episode

# %%
maerchen="" 
import xml.etree.ElementTree as ET
root_node = ET.parse('teiCorpus.xml').getroot()
never_saved = True
for ganze in root_node.findall(".//{http://www.tei-c.org/ns/1.0}text"):
    if ('deu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id'] 
        or 'uuu' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
        or 'uuu_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']):
        for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
            for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
                for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}*"):
                        labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
                        labelb1 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b1}ana']
                        labelb2 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b2}ana']
                        labelb3 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b3}ana']
                        labelb4 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b4}ana']
                        labelb5 = phrase.attrib['{www.dglab.uni-jena.de/vmf/b5}ana']
                        labelc1 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c1}ana']
                        labelc2 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c2}ana']
                        labelc3 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c3}ana']
                        labelc4 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c4}ana']
                        labelc5 = phrase.attrib['{www.dglab.uni-jena.de/vmf/c5}ana']
                        labeld = phrase.attrib['{www.dglab.uni-jena.de/vmf/d}ana']
                        quelle= ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
                        inhalt = (phrase.text.lower().strip().replace('|','').replace(':','').replace("ä","ae")
                                  .replace("ü","ue").replace("ö","oe").replace("ß","ss").replace(",","")
                                  .replace("«","").replace("»","").replace(".","").replace('=',' ').replace(";","")
                                  .replace('"',"").replace("?","").replace("!","").replace("á","a").replace(",","")
                                  .replace("\t"," ").replace("'","").replace("‹","").replace("›","").replace("-"," ")
                                  .replace("'('","").replace("')'","").replace('>','').replace("    "," ")
                                  .replace("   "," ").replace("  "," ").replace('–','').replace('—','').replace('<','')
                                  .replace("Â", "A").replace("ø", "oe").replace('“','').replace('„','').replace('(','')
                                  .replace(')','').replace('*','').replace("\n","\n")
                                  .replace("'''",""))
                        if labela.startswith('N'):
                            
                            maerchen += quelle+','+labela+','+labelb1+','+labelc1+','+labelb2+','+labelc2+','+labelb3+','+labelc3+','+labelb4+','+labelc4+','+labelb5+','+labelc5+','+labeld+','+inhalt+',0'+'\n'
                            #maerchen += quelle+','+labela+','+labelb1+','+labelc1+','+labelb2+','+labelc2+','+labelb3+','+labelc3+','+labelb4+','+labelc4+','+labelb5+','+labelc5+','+inhalt+',0'+'\n'

with open("text.csv", 'w', encoding='utf-8') as f:
    f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar')
    f.write('\n')
    f.write(maerchen)

# %%
abcd1=""
abcd2=""
abcd3=""
abcd4=""
abcd5=""
import pandas as pd
from collections import Counter
df = pd.read_csv('text.csv',  encoding='utf-8')
abcd1 += df.quelle+','+df.labela+':'+df.labelb1+':'+df.labelc1+':'+df.labeld+','+df.inhalt+',0'
abcd2 += df.quelle+','+df.labela+':'+df.labelb2+':'+df.labelc2+':'+df.labeld+','+df.inhalt+',0'
abcd3 += df.quelle+','+df.labela+':'+df.labelb3+':'+df.labelc3+':'+df.labeld+','+df.inhalt+',0'
abcd4 += df.quelle+','+df.labela+':'+df.labelb4+':'+df.labelc4+':'+df.labeld+','+df.inhalt+',0'
abcd5 += df.quelle+','+df.labela+':'+df.labelb5+':'+df.labelc5+':'+df.labeld+','+df.inhalt+',0'
# maca=':0:'
# for t in abcd3:
#     if maca not in t:
recorded=(abcd1+'\n'+abcd2+'\n'+abcd3+'\n'+abcd4+'\n'+abcd5+'\n')
with open("text_aw.csv", 'w', encoding='utf-8') as w:
    w.write('quelle,index_string,inhalt,index_binar\n')
    w.write('000:ballast,ballast,ballast,0\n')
    w.write("".join(recorded))
    w.close()

# %%
import csv
mom=[]
with open('text_aw.csv', 'r', encoding='utf-8') as f:
    reader = csv.reader(f) 
    for line in reader:
        if ':N:' not in line[1]:
            mom.append(line)

# %%
import shutil, os
with open ('text_ax.txt', 'wt', encoding='utf-8') as f:
    writer = csv.writer(f, delimiter=',')
    writer.writerow(mom)

# %%
with open('text_ax.txt', 'r', encoding='utf-8') as file:
    filedata = file.read()
filedata = filedata.replace(']","[', "\n").replace('"[','').replace(']"','').replace(" '","").replace("'","")
with open('text_ay.csv', 'w', encoding='utf-8') as file:
    file.write(filedata)

# %%
with open(filename+'.csv', 'r',encoding='utf-8') as file:
    file_contents = file.read().replace(",", " ").replace("\n", "")
    frt_contents = filename+',N,N,N,N,N,N,N,N,N,N,N,N'+','+file_contents+',0'
import os
os.remove(filename+'.csv')

# %%
row = [frt_contents]

with open("text_ay.csv", 'r',encoding='utf-8') as readFile:
    rd = csv.reader(readFile)
    lines = list(rd)
    lines.insert(1, row)

with open("text_ay.csv", 'wt',newline='',encoding='utf-8') as writeFile:
    wt = csv.writer(writeFile)
    wt.writerows(lines)

readFile.close()
writeFile.close()

fin = open('text_ay.csv','r', encoding ='utf-8')
fout = open('text_reich.csv', "wt", encoding ='utf-8')
for kfz in fin:
    fout.write(kfz.replace('"', ''))
fin.close()
fout.close()

# %%
import codecs
t_corpus = []
file = 'text_reich.csv'
with open (file, 'r', encoding='utf-8') as maerchen:
    maerchen = df.inhalt
    reader = csv.reader(maerchen, delimiter = ",") 
    for row in reader:       
        lst = str(row)
        t_corpus.append(lst)

# %% [markdown]
# ## Vorhersage durch LOGISTICREGRESSION

# %%
mod_pred=grid.predict(t_corpus)
for index in enumerate(mod_pred): 
    if 1 in (mod_pred) and index[1]>0:            
        print ('Positiv bewerteter Datensatz:{}'.format(index))

# %%
# all_pred=grid.predict_proba(t_corpus) 
# sort_index=np.flip(all_pred[:,1].argsort())
# for num_pos in sort_index:
#     pos=all_pred[num_pos][1]
#     for i,t_corpus_element in enumerate(t_corpus):
#         if i==num_pos  and num_pos>=0 and pos>=0.001:
#             print(num_pos,'-', pos,'-', df.quelle[num_pos],'-', df.inhalt[num_pos],
#                   '-',   df.index_binar[num_pos], '\n')

# %% [markdown]
# # CS

# %%
import csv 
t_corpus = []
file = 'text_reich.csv'
with open(file, "rt", encoding='utf-8') as maerchen:
    maerchen = df.inhalt
    reader = csv.reader(maerchen, delimiter = ",") 
    for row in reader:       
        lst = str(row)
        t_corpus.append(lst)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
vectorizer = TfidfVectorizer
vectorizers = vectorizer(analyzer='word', ngram_range=(1,1), 
                         min_df = 2, stop_words = ru)
vokabular =  vectorizers.fit_transform(t_corpus)
metrik = cosine_similarity
def find_similar(vokabular, index, top_n =-1):   
    metriks = metrik(vokabular[index:index+1], vokabular).flatten()
    related_docs_indices = [i for i in metriks.argsort()[::-1] 
                            if i != index]
    return [(index, metriks[index]) for index 
            in related_docs_indices][0:top_n]

# %%
n_te = 0
print(df.inhalt[n_te])
#entfernen('Messdaten/'+'0_'+gesep+'.txt')
# Out:
# es waren einmal zwei brueder die hatten beide das naemliche handwerk gelernt theilten ihr vaeterliches erbe und zogen mit einander in die weite welt als sie nun einmal sich unterwegs mit einander unterhielten sagte der aelteste undank ist der welt lohn der juengste aber sagte dank ist der welt lohn und weil sie sich nicht einigen konnten so wetteten sie setzten jeder sein erbtheil ein und machten aus wer mit seiner meinung auf ihrer wanderschaft recht behielte dem solle der andre sein erbtheil hingeben

# %%
for index, score in (find_similar(vokabular, n_te)):
    if (score>0.001):
        print(index,'-', score,'-', df.quelle[index],'-', 
           t_corpus[index],'\n')# '-'#,  df.index_binar[index],'-', df.index_binar[index],'\n' )
# Out:
# 2 - 0.429806676269442 - zyx_deu_111 - ['da gewaehrte ihm der aeltere bruder noch einen aufschub und sie zogen mit einander weiter in den wald hinein der spaziergang aber war nun zu ende und der wald wurde immer einsamer und wilder da rief ploetzlich wehklagend in der einsamkeit des waldes eine stimme jaemmerlich um huelfe zugleich eilte der juengste zur stelle und fand zwei koehler die sich mit einander schlugen er sprang dem schwaechern bei der um huelfe gerufen hatte als er sie aber von einander getrennt und den staerkeren tuechtig durchgepruegelt hatte sprangen beide koehler auf ihn los und schlugen gemeinsam auf ihn denn die koehler waren auch brueder endlich musste der aelteste von den beiden reisenden herbei kommen und ihn aus den haenden der koehler befreien da sprach der aelteste wieder undank ist der welt lohn der juengste aber sprach auch jetzt noch nein dank ist der welt lohn und bat seinen bruder um aufschub auf dass er ihn noch nicht seines erbtheils beraubte']
#
# 3 - 0.40997829075681536 - zyx_deu_111 - ['sie zogen also weiter mit einander und der wald in dem sie gingen wurde immer schauriger und wil der da kamen sie zu einem baeren und einer schlange die balgten sich mit einander der baer aber hatte die schlange schon bewaeltigt und zugleich sprang der juengste bruder hinzu ihr zu helfen das gelang ihm denn auch aber kaum war es geschehen als die schlange sich um ihren retter schlang und ihn erwuergen wollte da musste der aelteste bruder ihn auch von den thieren befreien nachdem dies aber geschehen war sprach er zu ihm es ist nicht anders undank ist der welt lohn dein erbtheil aber ist mir jetzt verfallen ich gebe dir keinen aufschub mehr da rief der juengste noch einmal nein bruder dank ist der welt lohn gewiss es muss sich bald zeigen schenke mir nur noch eine kurze frist allein der aeltere bruder hatte kein erbarmen mehr er stach dem juengeren die augen aus und beraubte ihn seines erbtheils an gelde zog ihn aus bis aufs hemd und ging fort']
#
#
# 39 - 0.11716078543315328 - zyx_deu_333 - ['im naechsten augenblick fuehlte ich mich mit dem kinde emporgehoben und wie im sturm durch die luft getragen ohne dass ich meine fluegel zu bewegen brauchte und da bin ich nun frau holle und ihr besitzet das kind das ihr euch so heiss gewuenscht das gute fromme kind dem die menschenkinder in allem guten nacheifern sollen das freundliche kind das ihnen freude spendet wenn sie brav sind aber auch das zuernende das die unartigen bestraft']
#
# 8 - 0.11458137116467965 - zyx_deu_111 - ['er richtete jetzt seinen weg nach dem koenigshofe darauf der koenigsbrunnen versiegt war da hatten auch schon viele leute versucht zu machen dass das wasser wieder hervorquelle und ob auch alles vergeblich gewesen war so war doch der koenig voll freude als sich abermals einer meldete der den brunnen wieder quellen machen wollte und gelobte ihm wenn ihm das gelaenge so solle er seine krone haben']
#
# 47 - 0.10863263082176529 - zyx_deu_444 - ['dann huepften und tanzten sie und sprangen ueber stuehle und baenke endlich tanzten sie zur tuer hinaus von nun an kamen sie nicht wieder dem schuster aber ging es wohl solang er lebte und es glueckte ihm alles was er unternahm']
#
# 17 - 0.09822903729410419 - zyx_deu_121 - ['da sprach einer der raethe des hasenkoenigs nicht also mein koenig lass uns nicht verzagen freylich vermoegen wir nichts gegen sie im kriege aber lass uns list brauchen vielleicht bringen wir sie dann wieder aus dem lande herr wenn du mich zum elefantenkoenig schickest so will ich das unheil wenden damit du aber erfaehrst was ich dort verhandle so schicke einen von deinen getreuesten dienern mit']
#
# 16 - 0.09471023294484421 - zyx_deu_121 - ['und der hasenkoenig berief alle seine raethe zusammen und sprach ich gestehe dass ich nicht die weisheit habe mein reich zu schuetzen gegen diese grossen feinde rathet ihr mir so gut ihr koennt sollen wir weg ziehen aus diesem schoenen lande das waere doch auch schade sollen wir foermlich krieg anfangen mit den starken elefanten was vermoegen wir gegen sie']
#
# 33 - 0.09352823119860004 - zyx_deu_333 - ['wenn ich nun ein kleines maedchen haette wuerde ich es so lieb und fromm machen dass alle kinder ihm gleichen und von ihm geliebt sein moechten lieber storch bringe mir von deiner naechsten reise ein kleines toechterchen mit']
#
# 23 - 0.09155448852970627 - zyx_deu_121 - ['aber die hasen freuten sich darueber und ruehmten den koenig denn er hatte doch auf klugen rath geachtet wenn er gleich selbst sie nicht retten konnte']
#
# 34 - 0.0872085155140098 - zyx_deu_333 - ['meine liebe frau holle sagte der storch das tue ich ja herzlich gern das schoenste beste und froemmste kind das ich auf erden finden kann will ich euch hierherbringen aber nur ein wenig geduld']
#
# 32 - 0.08119624325566535 - zyx_deu_333 - ['ganz gewiss frau holle das versteht sich von selbst klapperte der storch']
#
# 35 - 0.05966244791475969 - zyx_deu_333 - ['frau holle nickte und der storch flog fort']

# %%
# ziel = 'zyx_kum_rus_4'
# for index, score in (find_similar(vokabular, n_te)):  
#     if ziel in str(df.quelle[index]) or ziel in str(df.index_string[index]):
#         print([index], '-',score,'-', df.quelle[index],'-', t_corpus[index], '-', df.index_string[index],'-',df.index_binar[index],'\n')
