# %%
fin = open('gesamt_märchen.xml','r', encoding ='utf-8')
fout = open('g_m_23.xml', "wt", encoding ='utf-8')
for kfz in fin:
    fout.write(kfz.replace('"Abraten_von_der_Mission"','"ABRATEN_von_der_Mission"')
.replace('"Abraten_von_der_Mission_nachgehen"','"Dem_ABRATEN_von_der_Mission_nachgehen"')
.replace('"Abtretung_steht_bevor"','"Abtretung_der_Schönen_stehet_bevor"')
.replace('"Adoption"','"Adoption_erfolgt"')
.replace('"Amüsieren"','"AMUSEMENT"')
.replace('"Amüsieren_nachgehen"','"Dem_AMUSEMENT_nachgehen"')
.replace('"Aneignen_beheben"','"ANEIGNEN_beheben"')
.replace('"Angebot_von_Heiratswilligen"','"Lösung_für_HEIRATSWILLIGE_nachgehen"')
.replace('"Angebot_von_Heiratswilligen_nachgehen"','"Lösung_für_HEIRATSWILLIGE_nachgehen"')
.replace('"Angebot_von_Schatzhütern"','"Lösung_für_SCHATZHÜTERN_nachgehen"')
.replace('"Angebot_von_Schatzhütern_nachgehen"','"Lösung_für_SCHATZHÜTERN_nachgehen"')
.replace('"Angebot_zum_König_zu_werden"','"Angebot_KÖNIG_ZU_WERDEN"')
.replace('"Angebot_zum_König_zu_werden_nachgehen"','"Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen"')
.replace('"Anlocken"','"VERLOCKUNG"')
.replace('"Anlocken_nachgehen"','"Der_VERLOCKUNG_nachgehen"')
.replace('"Anregen_zu_Beauftragungen"','"Zu_Beauftragungen_anregen"')
.replace('"Arrangierte_Verlobung"','"Verlobung_wird_arrangiert"')
.replace('"Auf_dem_Weg_nach_Hause"','"Auf_dem_Heimweg"')
.replace('"Auftrag_Kochen"','"Auftrag_zum_Kochen"')
.replace('"Ausgangslosen_Ort_entkommen"','"Von_einem_AUSWEGLOSEN_Ort_entkommen"')
.replace('"Ausgangslosen_Ort_gelangen"','"An_einen_AUSWEGLOSEN_Ort_gelangen"')
.replace('"Ausrüsten"','"Die_Beschaffung_der_AUSRÜSTUNG"')
.replace('"Ausrüsten_nachgehen"','"Die_Beschaffung_der_AUSRÜSTUNG"')
.replace('"Aussetzung"','"AUSSETZUNG"')
.replace('"Ausspionieren_beauftragen"','"Auftrag_zum_AUSSPIONIEREN_erteilen"')
.replace('"Ausspionieren_des_Geheimnisses_external_soul"','"Das_Geheimnis_des_Erwerbs_der_EXTERNEN_SEELE_AUSSPIONIEREN"')
.replace('"Ausspionieren_des_Geheimnisses_Zauberfohlen"','"Das_Geheimnis_des_Erwerbs_des_REITTIERs_AUSSPIONIEREN"')
.replace('"Ausspionieren_des_Geheimnisses_Zaubergegenstandes"','"Das_Geheimnis_des_Erwerbs_des_BESONDEREN_Gegenstandes_AUSSPIONIEREN"')
.replace('"Baumersteigen"','"Baumersteigen"')
.replace('"Bauwerk_errichten"','"Bauwerk_errichten"')
.replace('"Begehren"','"Begehren_einer_Person_oder_eines_Gegenstandes"')
.replace('"Begleiter_gewinnen"','"Einen_Begleiter_gewinnen"')
.replace('"Begnadigen_der_potenziellen_Beute"','"Die_potenzielle_Beute_begnadigen"')
.replace('"Begnadigen_des_Einbrechers"','"Den_Einbrecher_begnadigen"')
.replace('"Behinderung_beheben"','"Eine_BEHINDERUNG_beheben"')
.replace('"Behinderung_durch_den_Fluch"','"BEHINDERUNG_durch_einen_Fluch"')
.replace('"Behinderung_durch_die_Verstümmelung"','"BEHINDERUNG_durch_Verstümmelung"')
.replace('"Belauschen"','"Gespräche_belauschen"')
.replace('"Besitzer_des_Objektes_beschaffen"','"BESITZER_DES_OBJEKTES_herbeiholen"')
.replace('"Besitzer_des_Objektes_ergreifen"','"BESITZER_DES_OBJEKTES_erfassen"')
.replace('"Bestrafung"','"Bestrafung_erfolgt"')
.replace('"Beute_teilen"','"BEUTETEILEN"')
.replace('"Beute_teilen_nachgehen"','"Dem_BEUTETEILEN_nachgehen"')
.replace('"Botschaften_verfälschen"','"BOTSCHAFTEN_verfälschen"')
.replace('"Botschaften_versenden"','"BOTSCHAFTEN_versenden"')
.replace('"Dem_Schicksal_entkommen"','"Dem_SCHICKSAL_entkommen"')
.replace('"Demütigung_beheben"','"Eine_DEMÜTIGUNG_beheben"')
.replace('"Demütigung_des_verleumdeten_Helden"','"DEMÜTIGUNG_des_verleumdeten_Helden"')
.replace('"Den_Bösen_Eigene_Kinder_fressen_lassen"','"Den_Bösen_die_eigenen_Kinder_fressen_lassen"')
.replace('"Den_Bösen_Eigene_Kinder_schlachten_lassen"','"Den_Bösen_die_eigenen_Kinder_schlachten_lassen"')
.replace('"Den_Bösen_Schaden_einrichten_lassen"','"Den_Bösen_Schaden_anrichten_lassen"')
.replace('"Einladung_folgen"','"Einer_Einladung_folgen"')
.replace('"Empfängnismittel_ergreifen"','"Magische_EMPFÄNGNISmittel_erfassen"')
.replace('"Empfängnismittel_erhalten"','"Magische_EMPFÄNGNISmittel_erhalten"')
.replace('"Empfängnismittel_suchen"','"Magische_EMPFÄNGNISmittel_suchen"')
.replace('"Entführen"','"Eine_ENTFÜHRUNG"')
.replace('"Entführen_beheben"','"Eine_ENTFÜHRUNG_beheben"')
.replace('"Entmachten"','"PARALYSIERUNG"')
.replace('"Entmachten_beheben"','"PARALYSIERUNG_beheben"')
.replace('"Enttäuschung_auslösen"','"Eine_Enttäuschung_auslösen"')
.replace('"Erklärungsbedürftigem_Verhalten_von_Betrügern"','"Folge_von_Betrügerei_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_Bigotterie"','"Folge_von_Bigotterie_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_dem_Alte"','"Ursache_des_Altaussehens_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_dem_Fährmann"','"Lösung_für_den_FÄHRMANN_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_der_Arbeitsscheu"','"Folge_von_Arbeitsscheu_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_Dieben"','"Folge_von_Kriminalität_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_Geiz"','"Folge_von_Geiz_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_Grobheit"','"Folge_von_Grobheit_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_Heiratswilligen"','"Lösung_für_HEIRATSWILLIGE_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_Klatschweibern"','"Folge_von_Klatsch_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_leidendem_Raubtier"','"Lösung_für_das_LEIDENDE_TIER_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_leidendem_Raubtier_gefressen_werden"','"Lösung_für_das_LEIDENDE_TIER_nachgehen"')
.replace('"Erklärungsbedürftigem_Verhalten_von_Rabenkindern"','"Folge_von_Vernachlässigung_der_Eltern_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_Schatzhütern"','"Lösung_für_SCHATZHÜTER_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_unstillbarem_Durst"','"Ursache_des_unstillbaren_Dursts_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_unstillbarem_Hunger"','"Ursache_des_unstillbaren_Hungers_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_verweigerter_Gastfreundschaft"','"Folge_von_verweigerter_Gastfreundschaft_deuten"')
.replace('"Erklärungsbedürftigem_Verhalten_von_vorehelichem_Geschlechtsverkehr"','"Folge_von_vorehelichem_Geschlechtsverkehr_deuten"')
.replace('"Erlösung"','"Erlösung"')
.replace('"Erpressen_des_Meineides"','"MEINEID_erpressen"')
.replace('"Erpressen_des_Meineides_beheben"','"MEINEID_erpressen_beheben"')
.replace('"Erpressen_für_Wiedergutmachung"','"Wiedergutmachung_erpressen"')
.replace('"Erpressen_Heiratszusage"','"Heiratszusage_erpressen"')
.replace('"Erpressen_Hilfe"','"Hilfe_erpressen"')
.replace('"Erpressen_Wegführung"','"Wegweisung_erpressen"')
.replace('"Erste_Liebe_ignorieren"','"Missachtung_der_LIEBE"')
.replace('"Erste_Liebe_ignorieren_beheben"','"Missachtung_der_LIEBE_beheben"')
.replace('"Erträumen"','"Erträumen"')
.replace('"Erzählen"','"Erzählen"')
.replace('"Existenz_sichern"','"Nahrungsvorrat_aufgebraucht"')
.replace('"Existenzform_wechseln"','"Die_Änderung_der_EXISTENZFORM"')
.replace('"Existenzform_wechseln_beheben"','"Änderung_der_EXISTENZFORM_beheben"')
.replace('"Existenzformgewechselte_verkaufen_unterschieben"','"Geänderte_EXISTENZFORM_VORTÄUSCHEN"')
.replace('"external_soul_vernichten"','"EXTERNEN_SEELE_vernichten"')
.replace('"Familienzusammenführung"','"Familienzusammenführung"')
.replace('"Fassungslosigkeit_löst_Mitleidsgefühl_aus"','"Mitleidsgefühl_auslösen"')
.replace('"Fehlen_männlicher_Nachkommenschaft"','"Fehlende_männliche_Nachkommen"')
.replace('"Fehlender_Gegenstand_beschaffen"','"FEHLENDEN_Gegenstand_besorgen"')
.replace('"Fehlender_Gegenstand_ergreifen"','"FEHLENDEN_Gegenstand_erfassen"')
.replace('"Felder_pflügen"','"FELDER_BESTELLEN"')
.replace('"Felder_pflügen_anpacken"','"FELDER_BESTELLEN_anpacken"')
.replace('"FERNLIEBE"','"Auslösen_von_FERNLIEBE"')
.replace('"FERNLIEBE_beheben"','"FERNLIEBE_beheben"')
.replace('"Festnahme_bzw_Sperren"','"FREIHEITSBERAUBUNG"')
.replace('"Festnahme_bzw_Sperren_beheben"','"FREIHEITSBERAUBUNG_beheben"')
.replace('"FLUCHT"','"FLUCHT"')
.replace('"Flucht_vorbereiten"','"FLUCHT_vorbereiten"')
.replace('"Flug_ohne_weitere_Komplikationen"','"Komplikationsfreier_Flug"')
.replace('"Flug_zeugendes_Transportmittel_erhalten"','"Flugfähiges_ZAUBERMITTEL_erhalten"')
.replace('"Frucht_beschaffen"','"FRUCHT_besorgen"')
.replace('"Frucht_ergreifen"','"FRUCHT_erfassen"')
.replace('"Gastgeberschaft_sichern"','"Potenziellen_Feind_zum_Gastgeber_gewinnen"')
.replace('"Geboren_werden"','"Zur_Welt_kommen"')
.replace('"Gegenstand_für_alle_Eventualitäten_erhalten"','"Universellen_ZAUBERMITTEL_erhalten"')
.replace('"Geheimnis_aufklären"','"Geheimnis_aufklären"')
.replace('"Gemenge_entkommen"','"Einem_Gemenge_entkommen"')
.replace('"Geschehen_deuten"','"Den_Vorgang_deuten"')
.replace('"Geschlechtswechsel_erzielen"','"Geschlechtsumwandlung_erzielen"')
.replace('"GIER"','"GIER"')
.replace('"Gier_nachgehen"','"Der_GIER_nachgehen"')
.replace('"Gold_oder_Geldproduzierenden_Gegenstand_oder_Wesen_aneignen"','"Sich_ZAUBERMITTEL_ANEIGNEN"')
.replace('"Gold_oder_Geldproduzierenden_Gegenstand_oder_Wesen_erhalten"','"Einen_gold_oder_GELDPRODUZIERENDEN_ZAUBERMITTEL_erhalten"')
.replace('"Goldhaariges_Kind_gebären"','"Goldhaariges_Kind_zur_Welt_bringen"')
.replace('"Handlungsanweisung_aus_zweiter_Hand"','"Handlungsanweisungen_aus_zweiter_Hand"')
.replace('"Handlungsanweisung_missachten"','"Handlungsanweisungen_missachten"')
.replace('"Hartes_mit_weichem_spalten"','"Hartes_Großes_Mächtiges_mit_Weichem_Kleinem_Schwachem_bewältigen"')
.replace('"Heilmittel_beschaffen"','"HEILMITTEL_besorgen"')
.replace('"Heilmittel_ergreifen"','"HEILMITTEL_erfassen"')
.replace('"Heimliche_Liebesbeziehung"','"Geheime_Liebesbeziehung"')
.replace('"Heiraten"','"Heiraten"')
.replace('"Held_erkennen"','"Held_erkennen"')
.replace('"Helfer_schlachten"','"ANGEBOT_geopfert_zu_werden"')
.replace('"Helfer_schlachten"','"ANGEBOT_nachgehen"')
.replace('"Hintergrund_aufklären"','"Sachverhalt_aus_der_Vergangenheit_aufklären"')
.replace('"Hitze_entkommen"','"Hitze_entkommen"')
.replace('"Hochzeit_verschieben"','"HOCHZEIT_verschieben"')
.replace('"Höfliches_Verhalten"','"Gutes_Benehmen"')
.replace('"Hohlen_Gegenstand_erhalten_um_sich_darin_zu_verstecken"','"Hohlen_Gegenstand_zum_Verstecken_erhalten"')
.replace('"Identität_testen"','"IDENTITÄT_beweisen"')
.replace('"Identität_wechseln"','"IDENTITÄT_ändern"')
.replace('"Identitätswechsel_gestehen"','"Der_Wechsel_der_IDENTITÄT_zugeben"')
.replace('"Todesauftrag"','"TODESAUFTRAG"')
.replace('"Im_Hinterhalt_liegen"','"Im_Verborgenen_lauern"')
.replace('"In_Besitz_eines_beleuchtenden_Gegenstandes_gelingen"','"Eines_BELEUCHTENDEN_Gegenstandes_habhaft_werden"')
.replace('"In_Krieg_ziehen"','"In_den_Krieg_ziehen"')
.replace('"Ins_Mausoleum_hinlegen"','"Im_Mausoleum_ruhen_lassen"')
.replace('"Jenseitswanderung_durchführen"','"Jenseitswanderung_unternehmen"')
.replace('"Juwelen_beschaffen"','"JUWELEN_besorgen"')
.replace('"Juwelen_ergreifen"','"JUWELEN_erfassen"')
.replace('"Kälte_entkommen"','"Kälte_entkommen"')
.replace('"Kampf_gegen_das_Tier"','"Gegen_ein_Tier_kämpfen"')
.replace('"Kinderlosigkeit"','"Kinderlosigkeit"')
.replace('"Königswahl_Teilnehmen"','"An_Königswahl_teilnehmen"')
.replace('"Kontakt_abbrechen"','"KONTAKT_abbrechen"')
.replace('"Kontakt_wiederherstellen"','"KONTAKT_wiederherstellen"')
.replace('"Körperteil_eines_Tieres_beschaffen"','"TIERKÖRPERTEIL_besorgen"')
.replace('"Körperteil_eines_Tieres_ergreifen"','"TIERKÖRPERTEIL_erfassen"')
.replace('"Körperteile_werden_zu_Edelmetall"','"Menschliche_Körperteile_in_Edelmetall_verwandeln"')
.replace('"Krankheit"','"KRANKHEIT"')
.replace('"Krankheit_beheben"','"KRANKHEIT_beheben"')
.replace('"Krisenursache_ergründen"','"Krisenursachen_ergründen"')
.replace('"Kühnheit_beweisen"','"Tapferkeit_beweisen"')
.replace('"Letzte_Chance_erhalten"','"Letzte_Gelegenheit_nützen"')
.replace('"Liebe"','"LIEBE_wird_ausgelöst"')
.replace('"Liebe_nachgehen"','"Der_LIEBE_nachgehen"')
.replace('"Lösung_für_den_FÄHRMANN_nachgehen"','"Lösung_für_den_FÄHRMANN_nachgehen"')
.replace('"Markieren"','"MARKIERUNGEN_anbringen"')
.replace('"Markieren_erkennen"','"MARKIERUNGEN_erkennen"')
.replace('"Massenbedrohung"','"MASSENBEDROHUNG"')
.replace('"Massenbedrohung_beheben"','"MASSENBEDROHUNG_beheben"')
.replace('"Mehrere_Aufgaben_nacheinander_erfüllen"','"Mehrere_Aufgaben_in_Folge_erledigen"')
.replace('"Mehrere_Gegner_nacheinander_köpfen"','"Mehrere_Gegner_nacheinander_besiegen"')
.replace('"Menschliche_Opfergabe_beheben"','"Menschliche_OPFERGABE_beheben"')
.replace('"Menschliches_Opfer_fordern"','"Eine_menschliche_OPFERGABE_verlangen"')
.replace('"Milch_beschaffen"','"MILCH_besorgen"')
.replace('"Milch_ergreifen"','"MILCH_erfassen"')
.replace('"Missetat_Aneignen"','"MISSETAT_wie_Aneignung"')
.replace('"Missetat_beheben"','"MISSETAT_beheben"')
.replace('"Missetat_Behinderung"','"MISSETAT_wie_Behinderung"')
.replace('"Missetat_Entmachten"','"MISSETAT_wie_Entmachtung"')
.replace('"Missetat_Hinterhalt"','"MISSETAT_wie_Hinterhalt"')
.replace('"Missetat_Im_Stich_lassen"','"MISSETAT_wie_Jemanden_im_Stich_lassen"')
.replace('"Missetat_Kanibalismus"','"MISSETAT_wie_Kannibalismus"')
.replace('"Missetat_planen"','"MISSETAT_planen"')
.replace('"Missetat_Tötung"','"MISSETAT_wie_Tötung"')
.replace('"Missetat_Unterschieben_des_Helden"','"MISSETAT_wie_ein_Surrogat_unterschieben"')
.replace('"Missetat_Verborgene_Waffe"','"MISSETAT_wie_Falle_stellen"')
.replace('"Missetat_Vergiftung"','"MISSETAT_wie_Vergiftung_versuchen"')
.replace('"Missgeburt"','"Missgeburt"')
.replace('"Mittel_zum_Herbeirufen_aneignen"','"Sich_ZAUBERMITTEL_ANEIGNEN"')
.replace('"Mittel_zum_Herbeirufen_erhalten"','"HERBEIRUFENDES_ZAUBERMITTEL_erhalten"')
.replace('"Musikinstrument_beschaffen"','"MUSIKINSTRUMENT_besorgen"')
.replace('"Musikinstrument_ergreifen"','"MUSIKINSTRUMENT_erfassen"')
.replace('"Mut_zeigen"','"Mut_zeigen"')
.replace('"Nahrung_geht_aus"','"Nahrungsvorrat_aufgebraucht"')
.replace('"Neugier_auslösen"','"NEUGIER_auslösen"')
.replace('"Neugier_nachgehen"','"Der_NEUGIER_nachgehen"')
.replace('"Notwendiges_wunderbarerweise_beschaffen"','"Notwendiges_auf_wunderbare_Weise_besorgen"')
.replace('"Nutztier_beschaffen"','"NUTZTIER_besorgen"')
.replace('"Nutztier_ergreifen"','"NUTZTIER_erfassen"')
.replace('"Ortswechsel_erfolgreich_durchführen"','"Ortswechsel_erfolgreich_durchführen"')
.replace('"Ortswechsel_gelingen"','"Ortswechsel_erfolgreich_durchführen"')
.replace('"Pferd_beschaffen"','"REITTIER_besorgen"')
.replace('"Pferd_ergreifen"','"REITTIER_erfassen"')
.replace('"Pflanze_beschaffen"','"PFLANZE_besorgen"')
.replace('"Pflanze_ergreifen"','"PFLANZE_erfassen"')
.replace('"Pförtner_besänftigen"','"Pförtner_besänftigen"')
.replace('"Pförtner_entkommen"','"PFÖRTNER_entkommen"')
.replace('"Pförtner_täuschen"','"PFÖRTNER_täuschen"')
.replace('"Prächtige_Kleidung_und_Schmuck_erhalten"','"Prächtige_Kleidung_und_Schmuck_erhalten"')
.replace('"Proviantproduzierenden_Gegenstand_aneignen"','"Sich_ZAUBERMITTEL_ANEIGNEN"')
.replace('"Proviantproduzierenden_Gegenstand_erhalten"','"PROVIANTPRODUZIERENDEN_ZAUBERMITTEL_erhalten"')
.replace('"Provozieren"','"PROVOKATION"')
.replace('"Provozieren_nachgehen"','"Der_PROVOKATION_nachgehen"')
.replace('"Reiterkünste_beweisen"','"Reitkünste_zeigen"')
.replace('"Reittier_ergreifen"','"REITTIER_besorgen"')
.replace('"Reittier_ergreifen"','"REITTIER_erfassen"')
.replace('"Reittier_erhalten"','"REITTIER_erhalten"')
.replace('"Respektlosigkeit"','"RESPEKTLOSIGKEIT"')
.replace('"Respektlosigkeit_beheben"','"Der_RESPEKTLOSIGKEIT_entgegentreten"')
.replace('"Richtiges_auswählen"','"Richtiges_auswählen"')
.replace('"Richtiges_erlangen"','"Richtiges_erlangen"')
.replace('"Schatz_finden"','"Schatz_entdecken"')
.replace('"Schicksal_ausweichen"','"SCHICKSAL_abwenden"')
.replace('"Schicksalsbestimmender_Weisung_folgen"','"Schicksalsbestimmender_Weisung_folgen"')
.replace('"Schlaf"','"SCHLAF"')
.replace('"Schlaf_beenden"','"SCHLAF_unterbrechen"')
.replace('"Schlagstock_erhalten"','"Strafvollstreckenden_ZAUBERMITTEL_erhalten"')
.replace('"Schlichtung_von_Streit"','"Streit_schlichten"')
.replace('"Schöne_beschaffen"','"Die_SCHÖNE_herbeiholen"')
.replace('"Schöne_ergreifen"','"Die_SCHÖNE_erfassen"')
.replace('"Schrecken_auslösen"','"Schrecken_auslösen"')
.replace('"Schweigenplicht_beheben"','"SCHWEIGEPFLICHT_beheben"')
.replace('"Schweigenplicht_erhängen"','"SCHWEIGEPFLICHT_verhängen"')
.replace('"Seltenen_Gegenstand_beschaffen"','"SELTENEN_Gegenstand_besorgen"')
.replace('"Seltenen_Gegenstand_ergreifen"','"SELTENEN_Gegenstand_erfassen"')
.replace('"Sich_abseilen_lassen"','"Sich_abseilen_LASSEN"')
.replace('"Sich_auf_Einschleuser_einlassen"','"Sich_auf_Eindringlinge_einlassen"')
.replace('"Sich_magischem_Eingriff_unterziehen"','"Sich_einem_magischen_Eingriff_unterziehen"')
.replace('"Sich_oder_andere_hochziehen_lassen"','"Sich_oder_Andere_hochziehen_LASSEN"')
.replace('"Sich_oder_Andere_tragen_lassen"','"Sich_oder_andere_tragen_LASSEN"')
.replace('"Sonstige_Aufgabe_anpacken"','"SONSTIGE_AUFGABE_anpacken"')
.replace('"Sonstige_Aufgabe_erfüllen"','"SONSTIGE_AUFGABE_erledigen"')
.replace('"Sonstiges_aneignen"','"Sich_sonstige_Dinge_ANEIGNEN"')
.replace('"Sorge_um_Freikaufsbedürftigen"','"Sorge_um_Freikaufsbedürftige"')
.replace('"Sorge_um_Hilfsbedürftigen"','"Sorge_um_Hilfsbedürftige"')
.replace('"Sorge_um_Hungrigen_oder_Durstigen"','"Sorge_um_Hungernde_oder_Durstige"')
.replace('"Sorge_um_Pflegebedürftigen"','"Sorge_um_Pflegebedürftige"')
.replace('"Sorge_um_Schutzbedürftigen"','"Sorge_um_Schutzbedürftige"')
.replace('"Staunen_lassen"','"Zum_STAUNEN_bringen"')
.replace('"Staunen_nachgehen"','"Dem_STAUNEN_nachgehen"')
.replace('"Sterben_von_Angehörigen"','"Tod_von_Angehörigen"')
.replace('"Sterbliche_Überreste_wie_etwa_Knochen_begraben"','"Knochen_begraben"')
.replace('"Stifter_oder_Helfer_gewinnen"','"Stifter_oder_Helfer_gewinnen"')
.replace('"Tabu_Behälter_nicht_öffnen"','"TABU_Behälter_nicht_öffnen"')
.replace('"Tabu_Feuer_darf_nicht_erlöschen"','"TABU_Feuer_darf_nicht_erlöschen"')
.replace('"Tabu_Fremde_nicht_einlassen"','"TABU_keine_Eindringlinge_einlassen"')
.replace('"Tabu_Gegenstand_nicht_weitergeben"','"TABU_Gegenstand_nicht_weitergeben"')
.replace('"Tabu_Haus_nicht_verlassen_dürfen"','"TABU_Haus_nicht_verlassen_dürfen"')
.replace('"Tabu_Land_nicht_betreten"','"TABU_Land_nicht_betreten"')
.replace('"Tabu_nicht_einschlafen_dürfen"','"TABU_nicht_einschlafen_dürfen"')
.replace('"Tabu_nicht_küssen"','"TABU_nicht_küssen"')
.replace('"Tabu_Schweigegebot"','"TABU_Schweigegebot"')
.replace('"Tabu_Sich_vom_Etwas_fernhalten"','"TABU_sich_von_Etwas_fernhalten"')
.replace('"Tabu_Sich_von_Jemandem_fernhalten"','"TABU_sich_von_Jemandem_fernhalten"')
.replace('"Tabu_Sonstiges"','"TABU_Sonstiges"')
.replace('"Tabu_Tier_nicht_erschießen"','"TABU_Tier_nicht_töten"')
.replace('"Tabu_Tierhaut_nicht_verbrennen"','"TABU_Tierhaut_nicht_verbrennen"')
.replace('"Tabu_Türe_nicht_öffnen_dürfen"','"TABU_Türe_nicht_öffnen_dürfen"')
.replace('"Tabu_wird_gebrochen"','"TABU_brechen"')
.replace('"Tabu_Zeit_nicht_überziehen"','"TABU_Frist_nicht_überziehen"')
.replace('"Tabu_Zielort_erreichen_ohne_Pause"','"TABU_keine_Pause_machen"')
.replace('"Tabubruchfolge_rückgängig_machen"','"Folgen_eines_TABUbruches_rückgängig_machen"')
.replace('"Tarnkappe_erhalten"','"Tarnung_gewährendes_ZAUBERMITTEL_erhalten"')
.replace('"Tier_als_Patron_erhalten"','"Tier_als_Schutzgeist_erhalten"')
.replace('"Tier_gegen_Tier_kämpfen_lassen"','"Tiere_gegeneinander_kämpfen_lassen"')
.replace('"Tiere_hüten"','"Tiere_HÜTEN"')
.replace('"Tiere_hüten"','"Tiere_HÜTEN_anpacken"')
.replace('"Tiere_mästen"','"Tiere_MÄSTEN"')
.replace('"Tiere_mästen_anpacken"','"Tiere_MÄSTEN_anpacken"')
.replace('"Tierjunges_erhalten"','"Tierjunges_erhalten"')
.replace('"Todesauftrag_entkommen"','"Einem_TODESAUFTRAG_entkommen"')
.replace('"Tötung"','"TÖTUNG"')
.replace('"Traum_vom_künftigen_Aufstieg"','"Traum_vom_sozialen_Aufstieg"')
.replace('"Treuen_Helfer_ergreifen"','"TREUEN_HELFER_finden"')
.replace('"Treuen_Helfer_erhalten"','"TREUEN_HELFER_erhalten"')
.replace('"Truhe_anfertigen"','"Truhe_herstellen"')
.replace('"Turm_Zaun_Berg_hinaufsteigen"','"Turm_Zaun_oder_Berg_hinaufsteigen"')
.replace('"Überraschen"','"Überrascht_werden"')
.replace('"Überweisung_an_anderen_Stifter_oder_Helfer"','"Weiterverweisung_an_anderen_Stifter_oder_Helfer"')
.replace('"Um_Gegenleistung_bitten"','"Um_Gegenleistung_bitten"')
.replace('"Unersättlichkeit"','"Unerträgliche_Unersättlichkeit"')
.replace('"Unerwartete_Wendung_zum_Guten"','"Überraschende_positive_Wendung"')
.replace('"Ungeheuer_beschaffen"','"UNGEHEUER_herbeiholen"')
.replace('"Ungeheuer_ergreifen"','"UNGEHEUER_erfassen"')
.replace('"Ungeheuerlichkeit_unerträglich"','"Unerträgliche_Ungeheuerlichkeit"')
.replace('"Ungewünschte_Verlobung"','"ungewollte_VERLOBUNG"')
.replace('"Ungewünschte_Verlobung_nachgehen"','"ungewollter_VERLOBUNG_nachgehen"')
.replace('"Ungewünschter_Heiratsantrag"','"Ungewollter_HEIRATSANTRAG"')
.replace('"Ungewünschter_Heiratsantrag_nachgehen"','"Ungewolltem_HEIRATSANTRAG_nachgehen"')
.replace('"Ungewünschtes_Wesen_aus_dem_Weg_räumen"','"Ungewünschtes_Wesen_beseitigen"')
.replace('"Unsichtbar_beobachten"','"Heimlich_beobachten"')
.replace('"Verbannung"','"VERBANNUNG"')
.replace('"Verbannung_beheben"','"VERBANNUNG_beheben"')
.replace('"Verfolgung"','"VERFOLGUNG"')
.replace('"Verfolgung_entkommen"','"VERFOLGUNG_entkommen"')
.replace('"Verfolgung_hindern"','"VERFOLGUNG_verzögern"')
.replace('"Vergeltung_Angst_um_Angst"','"Angst_mit_Angst_vergelten"')
.replace('"Vergütung_Gegenleistung_um_Hilfe"','"Gegenleistung_für_Hilfe_gewähren"')
.replace('"Verleumdung_beheben"','"VERLEUMDUNG_beheben"')
.replace('"Verleumdung_der_Tötung_des_Kindes"','"VERLEUMDUNG_bei_Kindstötung"')
.replace('"Verleumdung_von_Schädigung"','"VERLEUMDUNG_bei_Schädigung"')
.replace('"Verleumdung_von_Untreue"','"VERLEUMDUNG_bei_Untreue"')
.replace('"Verleumdung_von_Untreue"','"VERLEUMDUNG_beheben"')
.replace('"Verlust_entgegentreten"','"Dem_VERLUST_entgegentreten"')
.replace('"Verlust_von_Tieren_Früchten_Ernte_usw"','"VERLUST_von_Tieren_Früchten_Ernte_usw_"')
.replace('"Vermittlung_erhalten"','"Vermittlung_erhalten"')
.replace('"Verschlingen"','"VERSCHLINGEN"')
.replace('"Verschlingen_beheben"','"VERSCHLINGEN_beheben"')
.replace('"Versprechen_gegen_der_Hilfe"','"VERSPRECHEN_im_Austausch_für_Hilfe"')
.replace('"Versprechen_halten"','"Ein_VERSPRECHEN_halten"')
.replace('"Versprechen_von_Hilfe_erhalten"','"Hilfeversprechen_erhalten"')
.replace('"Verstecken_als_Rettungsmaßnahme"','"Verstecken_als_Rettung"')
.replace('"Versteinerung"','"VERSTEINERUNG"')
.replace('"Versteinerung_beheben"','"VERSTEINERUNG_beheben"')
.replace('"Vertrag_abschließen"','"VERTRAG_abschließen"')
.replace('"Vertrag_appellieren"','"Auf_dem_VERTRAG_bestehen"')
.replace('"Vertrag_erlösen"','"VERTRAG_auflösen"')
.replace('"Vertrauen_testen"','"VERTRAUEN_prüfen"')
.replace('"Vertrauensverlust_erfolgt"','"VERTRAUEN_beweisen"')
.replace('"Vertreibung"','"VERTREIBUNG"')
.replace('"Vertreibung_beheben"','"VERTREIBUNG_beheben"')
.replace('"Viel_essen"','"Große_Mengen_ESSEN"')
.replace('"Viel_Holz_beschaffen"','"HOLZ_besorgen"')
.replace('"Viel_Holz_beschaffen_anpacken"','"HOLZ_Sammeln_anpacken"')
.replace('"Viele_Kinder_werden_auf_einmal_geboren"','"Mehrlingsgeburt_erfolgt"')
.replace('"Vogel_beschaffen"','"VOGEL_herbeiholen"')
.replace('"Vogel_ergreifen"','"VOGEL_erfassen"')
.replace('"Vorhersagen_treffen"','"Vorhersagen_treffen"')
.replace('"Vortäuschen_angeblicher_Testnotwendigkeit"','"Angebliche_Testnotwendigkeit_VORTÄUSCHEN"')
.replace('"Vortäuschen_angeblicher_Unwissenheit_Unsicherheit"','"Unwissenheit_oder_Unsicherheit_VORTÄUSCHEN"')
.replace('"Vortäuschen_der_Heldentat"','"Heldentat_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Abweisung"','"Eine_Apathie_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Bedrohung"','"Eine_Bedrohung_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Gastfreundlichkeit"','"Gastfreundlichkeit_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Heilkunst"','"Heilkunst_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Kollaboration"','"Kollaborationsbereitschaft_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Krankheit"','"Krankheit_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Rebellion_des_Zielobjektes"','"Rebellion_des_Zielobjektes_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Reichen_Erbschaft"','"Reiche_Erbschaft_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Treue"','"Treue_VORTÄUSCHEN"')
.replace('"Vortäuschen_einer_Wachsamkeit_Anwesenheit"','"Wachsamkeit_oder_Anwesenheit_VORTÄUSCHEN"')
.replace('"Vortäuschen_eines_Reichtums"','"Reichtum_VORTÄUSCHEN"')
.replace('"Vortäuschen_eines_Todes"','"Tod_VORTÄUSCHEN"')
.replace('"Vortäuschen_eines_Verlustes"','"Verlust_VORTÄUSCHEN"')
.replace('"Vortäuschen_nachgehen"','"Dem_VORTÄUSCHEN_nachgehen"')
.replace('"Vortäuschen_richtiges_mitzuteilen"','"Kollaborationsbereitschaft_VORTÄUSCHEN"')
.replace('"Vortäuschen_während_der_Niederkunft"','"MISSETAT_ein_Surrogat_unterschieben"')
.replace('"Wache_halten"','"Wache_halten"')
.replace('"Wassermangel_auslösen"','"WASSERMANGEL"')
.replace('"Wassermangel_beheben"','"WASSERMANGEL_beheben"')
.replace('"Wegweisung_mit_Optionen"','"Wegweisung_mit_ALTERNATIVEN"')
.replace('"Wegweisung_mit_Optionen_nachgehen"','"Den_ALTERNATIVEN_nachgehen"')
.replace('"Weihe_vorschreiben"','"WEIHE_anordnen"')
.replace('"Weihen_durchführen"','"WEIHE_vollziehen"')
.replace('"Weisheiten_erhalten"','"WEISHEITEN_erhalten"')
.replace('"Weisheiten_erhalten"','"WEISHEITEN_nachgehen"')
.replace('"Werben_um_den_Auftrag"','"Um_einen_Auftrag_werben"')
.replace('"Werben_um_den_Mann"','"Um_einen_Mann_werben"')
.replace('"Werben_um_die_Frau"','"Um_eine_Frau_werben"')
.replace('"Wetten_dass_der_Freier_die_Braut_verführt"','"Wette_um_die_Verführung_der_Braut"')
.replace('"Wetten_Versteckwette"','"VERSTECKWETTE"')
.replace('"Wetten_Versteckwette"','"VERSTECKWETTE_anpacken"')
.replace('"Wettkampf"','"WETTKAMPF"')
.replace('"Wettkampf_anpacken"','"WETTKAMPF_anpacken"')
.replace('"WETTLAUF_anpacken"','"WETTLAUF_anpacken"')
.replace('"Wettlauf"','"WETTLAUF"')
.replace('"Wiederbelebung"','"TÖTUNG_beheben"')
.replace('"Wild_beschaffen"','"WILD_besorgen"')
.replace('"Wild_ergreifen"','"WILD_erfassen"')
.replace('"Wunderbare_Empfängnis"','"Wunderbare_EMPFÄNGNIS"')
.replace('"Zauberkunst_erlernen"','"Zauberkunst_erlernen"')
.replace('"Zauberkunstfertigkeit_gewährleisten"','"Zauberkunstfertigkeit_gewährleisten"')
.replace('"Zaubermittel_aneignen"','"Sich_ZAUBERMITTEL_ANEIGNEN"')
.replace('"Zaubermittel_Ausrüstung_oder_die_Waffe_ausprobieren"','"ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren"')
.replace('"Zaubermittel_Ausrüstung_oder_die_Waffe_einsetzen"','"ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_einsetzen"')
.replace('"Zaubermittel_erhalten"','"Universellen_ZAUBERMITTEL_erhalten"')
.replace('"Zollerhebung_vollstrecken"','"ZOLLERHEBUNG_vollstrecken"')
.replace('"Zollerhebung_vollstrecken_anpacken"','"ZOLLERHEBUNG_anpacken"')
.replace('"Zug_von_Reisenden_bzw_Karavane_folgen"','"Zug_von_Reisenden_oder_Karavane_folgen"')
.replace('"Zum_Schlafen_bringen"','"Zum_Schlafen_bringen"')
.replace('"Zurückgreifen"','"Auf_Hilfsquelle_zurückgreifen"')
.replace('"Zusammenbringen_aller_Beteiligten"','"Zusammenbringen_aller_Handlungsträger"')
.replace('"Zuschnappendes_Hindernis_überwinden"','"Zuschnappendes_Hindernis_überwinden"')
.replace('"Zwangsehe_Drohung"','"ZWANGSEHE_Drohung"')
.replace('"Zwangsehe_Drohung_beheben"','"ZWANGSEHE_Drohung_beheben"')
.replace('"Zweikampf"','"Zweikampf"')
.replace('"AUSRÜSTUNG_als_ZAUBERMITTEL_erhalten"','"AUSRÜSTUNG_als_ZAUBERMITTEL_erhalten"')
.replace('"WAFFE_ZAUBERMITTEL_erhalten"','"WAFFE_ZAUBERMITTEL_erhalten"')
.replace('"Wunsch_erfüllendes_ZAUBERMITTEL_erhalten"','"Wunsch_erfüllendes_ZAUBERMITTEL_erhalten"')
)
fin.close()
fout.close()
