# %% [markdown]
# # Modul für die Auswertund der Episoden

# %%
#neueste version
#das gilt für den Aggregation der gelabelte Episoden und Motive in Episoden
# maerchen="" 
# import xml.etree.ElementTree as ET
# root_node = ET.parse('gesamt_märchen.xml').getroot()
# inhalt_voll=""
# never_saved = True
# for ganze in root_node.findall(".//{http://www.tei-c.org/ns/1.0}text"):
#     if 'zyx_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']:
#         for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
#             for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
#                 for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}*"):
#                         labell = phrase.attrib['{www.dglab.uni-jena.de/vmf/l}ana']
#                         labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
#                         inhalt = (phrase.text.lower().strip().replace('|','').replace(':','').replace("ä","ae")
#                                   .replace("ü","ue").replace("ö","oe").replace("ß","ss").replace(",","")
#                                   .replace("«","").replace("»","").replace(".","").replace('=',' ').replace(";","")
#                                   .replace('"',"").replace("?","").replace("!","").replace("á","a").replace(",","")
#                                   .replace("\t"," ").replace("'","").replace("‹","").replace("›","").replace("-"," ")
#                                   .replace("'('","").replace("')'","").replace('>','').replace("    "," ")
#                                   .replace("   "," ").replace("  "," ").replace('–','').replace('—','').replace('<','')
#                                   .replace("Â", "A").replace("ø", "oe").replace('“','').replace('„','').replace('(','')
#                                   .replace(')','').replace("‚", "").replace ('|',',').replace('*','').replace("\n","\n")
#                                   .replace("'''",""))
#                         for n in absatz.findall(".//{http://www.tei-c.org/ns/1.0}unit"):
#                             quelle=n.attrib['n'] 
#                             if labela.startswith('m') and labela!='e0':
#                                 if never_saved:
#                                     never_saved = False
#                                 else:
#                                     maerchen += quelle_alt+','+labela_alt+':'+labell_alt+':'+','+inhalt_voll+',0'+'\n'
#                                 quelle_alt = quelle
#                                 inhalt_alt = inhalt
#                                 labela_alt = labela
#                                 labell_alt = labell
#                                 inhalt_voll = inhalt_alt
#                             if labela.startswith(('m')):
#                                 inhalt_voll+=' '+inhalt
# maerchen += quelle_alt+','+labela_alt+':'+labell_alt+':'+','+inhalt_voll+',0'+'\n'                                             
# with open("text.csv", 'w', encoding='utf-8') as f:
#     f.write('quelle,index_string,episode,index_binar\n')
#     f.write('000:ballast,ballast,ballast,0')
#     f.write('\n')
#     f.write(maerchen)

# %%
#das gilt für den Aggregation der gelabelte  Motiven
# maerchen="" 
# import xml.etree.ElementTree as ET
# root_node = ET.parse('gesamt_märchen.xml').getroot()
# inhalt_voll=""
# never_saved = True
# for ganze in root_node.findall(".//{http://www.tei-c.org/ns/1.0}text"):
#     if 'zyx_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']:
#         for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
#             for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
#                 for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}*"):
#                         labell = phrase.attrib['{www.dglab.uni-jena.de/vmf/l}ana']
#                         labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
#                         inhalt = (phrase.text.lower().strip().replace('|','').replace(':','').replace("ä","ae")
#                                   .replace("ü","ue").replace("ö","oe").replace("ß","ss").replace(",","")
#                                   .replace("«","").replace("»","").replace(".","").replace('=',' ').replace(";","")
#                                   .replace('"',"").replace("?","").replace("!","").replace("á","a").replace(",","")
#                                   .replace("\t"," ").replace("'","").replace("‹","").replace("›","").replace("-"," ")
#                                   .replace("'('","").replace("')'","").replace('>','').replace("    "," ")
#                                   .replace("   "," ").replace("  "," ").replace('–','').replace('—','').replace('<','')
#                                   .replace("Â", "A").replace("ø", "oe").replace('“','').replace('„','').replace('(','')
#                                   .replace(')','').replace('*','').replace("\n","\n")
#                                   .replace("'''",""))
#                         for n in absatz.findall(".//{http://www.tei-c.org/ns/1.0}unit"):
#                             quelle=n.attrib['n'] 
#                             if labela.startswith('m') and labela!='e0':
                                
#                                 maerchen += quelle+','+labela+':'+labell+':'+','+inhalt+',0'+'\n'                                             
# with open("text.csv", 'w', encoding='utf-8') as f:
#     f.write('quelle,index_string,episode,index_binar\n')
#     f.write('000:ballast,ballast,ballast,0')
#     f.write('\n')
#     f.write(maerchen)

# %%
maerchen="" 
import xml.etree.ElementTree as ET
root_node = ET.parse('gesamt_märchen.xml').getroot()
inhalt_voll=""
never_saved = True
for ganze in root_node.findall(".//{http://www.tei-c.org/ns/1.0}text"):
    if 'zyx_' in ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']:
        for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
            for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
                for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}*"):
                        labell = phrase.attrib['{www.dglab.uni-jena.de/vmf/l}ana']
                        labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
                        quelle= ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
                        inhalt = (phrase.text.lower().strip().replace('|','').replace(':','').replace("ä","ae")
                                  .replace("ü","ue").replace("ö","oe").replace("ß","ss").replace(",","")
                                  .replace("«","").replace("»","").replace(".","").replace('=',' ').replace(";","")
                                  .replace('"',"").replace("?","").replace("!","").replace("á","a").replace(",","")
                                  .replace("\t"," ").replace("'","").replace("‹","").replace("›","").replace("-"," ")
                                  .replace("'('","").replace("')'","").replace('>','').replace("    "," ")
                                  .replace("   "," ").replace("  "," ").replace('–','').replace('—','').replace('<','')
                                  .replace("Â", "A").replace("ø", "oe").replace('“','').replace('„','').replace('(','')
                                  .replace(')','').replace('*','').replace("\n","\n")
                                  .replace("'''",""))
                        if labela.startswith('m') and labela!='0':
                            maerchen += quelle+','+labela+':'+labell+','+inhalt+',0'+'\n'                                             
with open("text.csv", 'w', encoding='utf-8') as f:
    f.write('quelle,index_string,episode,index_binar\n')
    f.write('000:ballast,ballast,ballast,0')
    f.write('\n')
    f.write(maerchen)

# %%
import pandas as pd
df = pd.read_csv('text.csv', encoding='utf-8')
from collections import Counter
indexliste=Counter(df.index_string)
print(indexliste, sep='\n') # alternativ kann man vor dem 'indexliste' ein Sternchen (*) setzen
# Out:
# Counter({'m301:BG:probe:ob_der_HD_stark_ist': 22, 'm554:BV:erhalten:ein_signalisator_erhalten': 20, 'm301:BV-:durchfallen:bei_der_probe_durchfallen': 19, 'm554:BG:probe:ob_der_HD_unmundige_tierjunge_schutzt': 18, 'm300:KV:melden:als_ungewuenschte_besucher:sich_bei_dem_AN_melden_und_mut_zeigen': 16, 'm552:BV:sichern:respekt_sichern_ohne_dabei_etwas_zu_erhalten': 16, 'm552:KV:melden:als_verdienster_besucher:sich_bei_dem_HF_melden_um_hilfe_zu_holen': 14, 'm650A:KV:spannung:erfuellung_der_aufgabe': 13, 'm301:BV:erhalten:einen_gefaerten_erhalten': 13, 'm650A:KV:spannung:erfuellung_der_aufgabe_verursacht_schrecken': 12, 'm301:BG:faszination:der_HD_und_der_FH_aeussern_sich_gegenseitige_symphadie': 12, 'm301:KV:spannung:zweikampf_mit_sieg': 12, 'm554:BG:probe:ob_der_HD_auf_die_beute_verzichten_kann': 12, 'm300:KT:auskunft:über_maenschliche_opfergabe_mit_wassermangel_erfahren': 11, 'm300:KV:spannung:zweikampf_mit_sieg': 11, 'm545B:KV:melden:als_bertueger_HF:sich_beim_HO_melden_und_interesse_erwecken': 11, 'm545B:BV:erhalten:erhalten_eine_versprechen_geholfen_zu_werden': 9, 'm545B:KV:melden:verlobung:der_HF_meldet_den_HD_als_freier': 9, 'm545B:KV:unterstuetzung:manipulation_eigentum_entwenden': 9, 'm301:BV:erpressen:eine_spur_zum_zielort_erpressen': 8, 'm545B:KV:unterstuetzung:manipulation:die_kleidung_beschaffen': 8, 'm613:BG:gelegenheit:der_HD_hat_die_gelegenheit_zu_belauschen': 8, 'm613:BV:belauschen_wie_man_den_schatz_in_besitz_nehmen_kann': 8, 'm301:KF-:unterstuetzung::warnung_ratschlag_ablehnen': 7, 'm300:BG:gelegenheit:der_HD_hat_die_gelegenheit_zu_bitten': 7, 'm554:BV:erhalten:erhalten_eine_versprechen_geholfen_zu_werden': 7, 'm301:KV:spannung:bestrafung_des_FH': 7, 'm301:KV:raumverwaltung:absteigen': 7, 'm552:KV:unterstuetzung:wiederbelebung_des_HD': 7, 'm613:KV:spannung:kranke_heilen': 7, 'm613:KF:anregung:anregung_eines_geizes': 7, 'm613:KV-:spannung:erwischt_werden_bem_belauschen': 7, 'm301:KT:auskunft:es_wird_nachtraeglich_ueber_die_liguidierte_krise_auskunft_gegeben': 6, 'm301:KV:unterstuetzung:warnung:vor_dem_verrat': 6, 'm301:KV:unterstuetzung:anleitung:richtiges_transportmittel_vom_falschen_unterscheiden': 6, 'm301:KF:verrat:den_HD_wird_zurueckgelassen': 6, 'm301:BV-:verpassen:dem_richtigen_ZM_verpassen': 6, 'm300:KV:raumverwaltung:flug:der_HD_futtert_den_HF_mit_eigenem_fleisch': 6, 'm650A:KT:auftrag:de_HD_wird_beauftraglt_dem_schuldner_ruckzahlung_zu_erzwingen': 6, 'm552:BV-:ablehnen:anforderungen_des_testaments_ablehnen': 6, 'm552:KV-:spannung:zweikampf_mit_niederlage': 6, 'mTest:mTest': 6, 'm545B:BG:probe:ob_der_HD_zuverlaessig_ist': 6, 'm545B:BV-:durchfallen:bei_der_probe_durchfallen': 6, 'm613:KV:spannung:schatz_entwenden': 6, 'm554:BV:erhalten:einen_gefaerten_erhalten': 6, 'm650A:KT:auftrag:de_HD_wird_beauftraglt_holz_zu_beschaffen': 5, 'm300:BV-:ablehnen:bitte_ablehnen': 5, 'm300:KV:raumverwaltung:flug:beschaffung_des_proviants_folgt_vom_HO': 5, 'm300:KV:raumverwaltung:flug:Der_HF_heilt_die_wunde_ohne_dabei_das_heilmittel_auszuhaendigen': 5, 'm552:BG:probe:ob_der_HD_dem_testament_folgt:freier_willigen': 5, 'm552:KV:spannung:zweikampf_mit_sieg': 5, 'm613:BV:belauschen_wie_man_kranke_heilen_kann': 5, 'm613:KV:spannung:eigene_augenlicht_zurueckholen': 5, 'm650A:KF:leiden:die_ungeheuerlichkeit_des_HD_ist_unauftraeglich': 4, 'm650A:BG:test:der_HD_testet_die_tauglichkeit_des_ZM': 4, 'm301:KV:raumverwaltung:hochziehen:der_HD_laesst_den_FH_hochziehen': 4, 'm300:KV:markierung:der_HD_nimmt_die_zeichen_des_besiegten_AN': 4, 'm300:KV-:melden:der_HD_meldet_sich_vom_OB_oder_HO_ab': 4, 'm650A:KF:gewaltuebung:das_OB_wird_geraubt_oder_und_entfuehrt': 4, 'm613:KF:ausbeutung:den_HD_wird_ohne_essen_gelassen': 4, 'm613:BV:belauschen_wo_man_fehlendes_wasser_finden_kann': 4, 'm613:KV:spannung:wasserquelle_finden': 4, 'm545B:KV:unterstuetzung:manipulation:staunen_zum_spott_vorgeben': 4, 'm314:KF:anregung:anregung_einer_liebe': 4, 'm650A:KT:nachforschung:der_verhuelte_krise_nachforschen': 3, 'm650A:KV:spannung:zweikampf_mit_sieg': 3, 'm6 ...

# %% [markdown]
# 6 - Das Skript sorgt dafür die in den betrachteten Texten vorhandene Annotationen in eine Kette der vorherigen, der gesuchten und der folgenden Episode als Gliedern der gesamten Kette umzuwandeln.

# %%
import pandas as pd
df = pd.read_csv('text.csv', encoding='utf-8')
from collections import Counter
def ep_format(ep_full):
    return (ep_full.split(':'))[0]
def ep_name_format(ep_full):
    sublist = (ep_full)#.split(':')[0] #[0:1]
    name = ""
    for strg in sublist:
        name += strg#+'_'
    return name
def quellenvergleich (df, i1, i2):
    return df.quelle[i1]==df.quelle[i2]
def ast(gesep, df):
    ep_tree = {}
    a_liste = []
    z_liste = []  
    df_len = len(df.index_string)
    for i, ep in enumerate(df.index_string):
        if gesep == ep:
            if (i > 0)&(quellenvergleich(df, i, i-1)):
                a = df.index_string[i-1]
            else:
                a = 'Anf-'+ep_name_format(gesep)
            if (i < df_len - 1):
                if not (quellenvergleich(df, i, i+1)):
                    z = 'End-'+ep_name_format(gesep)
                else:        
                    z = df.index_string[i+1]
            else:
                z = 'End-'+ep_name_format(gesep)
            a_liste.append(a)
            z_liste.append(z)
    return {gesep: [Counter(a_liste), Counter(z_liste)]}

# %%
def alle_aeste(gesep, df):
    episoden_baeume = {} 
    ep_list = []
    for ep_full in df.index_string:         
        ep = ep_format(ep_full)      
        if gesep == ep:                      
            ep_list.append(ep_full)
    for ep in set(ep_list):
        episoden_baeume.update(ast(ep,df))
    return episoden_baeume

# %%
def key_val_printer(d):
    for k, v in d.items():
        print(v, k, sep=':')
def baum_printer(baeume: dict, baum: str):
    key_val_printer (baeume[baum][0])
    print(65*'-')
    print(sum(baeume[baum][0].values()),':', baum)
    print(65*'-')
    key_val_printer(baeume[baum][1]) 
def wald_printer(wald: dict):
    for baum in (wald.keys()): # for baum in sorted(wald.keys():
        baum_printer (wald, baum)
        print(65*'=')
def key_val_printer(d):
    for k, v in d.items():
        print(v, k, sep=':')

# %%
graph = alle_aeste("", df)
graph.update(alle_aeste("m554", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))
graph.update(alle_aeste("", df))

wald_printer(graph)
# Out:
# 1:m554:BV:erhalten:einen_gefaerten_erhalten
# -----------------------------------------------------------------
# 1 : m554:0
# -----------------------------------------------------------------
# 1:End-m554:0
# =================================================================
# 1:m300:KV:spannung:zweikampf_mit_sieg
# 4:m554:BV:erhalten:ein_signalisator_erhalten
# 1:m613:AS:sterben:ein_angehoerige_stirbt
# 2:Anf-m554:BG:probe:ob_der_HD_auf_die_beute_verzichten_kann
# 4:m554:BV:erhalten:einen_gefaerten_erhalten
# -----------------------------------------------------------------
# 12 : m554:BG:probe:ob_der_HD_auf_die_beute_verzichten_kann
# -----------------------------------------------------------------
# 6:m554:BV:erhalten:ein_signalisator_erhalten
# 6:m554:BV:erhalten:einen_gefaerten_erhalten
# =================================================================
# 6:m554:BG:probe:ob_der_HD_unmundige_tierjunge_schutzt
# 1:m554:BG:probe:ob_der_HD_zwischen_den_streitenden_schlichtet
# -----------------------------------------------------------------
# 7 : m554:BV:erhalten:erhalten_eine_versprechen_geholfen_zu_werden
# -----------------------------------------------------------------
# 5:m300:KV:raumverwaltung:flug:beschaffung_des_proviants_folgt_vom_HO
# 2:End-m554:BV:erhalten:erhalten_eine_versprechen_geholfen_zu_werden
# =================================================================
# 1:Anf-m554:BG:unklar:unklares_bedingung
# 1:m554:BV:erhalten:ein_signalisator_erhalten
# -----------------------------------------------------------------
# 2 : m554:BG:unklar:unklares_bedingung
# -----------------------------------------------------------------
# 2:m554:BV:erhalten:ein_signalisator_erhalten
# =================================================================
# 1:Anf-m554:BG:probe:ob_der_HD_zwischen_den_streitenden_schlichtet
# -----------------------------------------------------------------
# 1 : m554:BG:probe:ob_der_HD_zwischen_den_streitenden_schlichtet
# -----------------------------------------------------------------
# 1:m554:BV:erhalten:erhalten_eine_versprechen_geholfen_zu_werden
# =================================================================
# 6:m554:BG:probe:ob_der_HD_auf_die_beute_verzichten_kann
# -----------------------------------------------------------------
# 6 : m554:BV:erhalten:einen_gefaerten_erhalten
# -----------------------------------------------------------------
# 4:m554:BG:probe:ob_der_HD_auf_die_beute_verzichten_kann
# 1:m554:0
# 1:End-m554:BV:erhalten:einen_gefaerten_erhalten
# =================================================================
# 1:m554:BV:erhalten:ein_signalisator_erhalten
# -----------------------------------------------------------------
# 1 : m554:BG:probe:ob_der_HD_hungriges_tier_futtert
# -----------------------------------------------------------------
# 1:m554:BV:erhalten:ein_signalisator_erhalten
# =================================================================
# 1:m554:BG:probe:ob_der_HD_unmundige_tierjunge_schutzt
# -----------------------------------------------------------------
# 1 : m554:BV:erhalten:ein_tierjunge_erhalten
# -----------------------------------------------------------------
# 1:m314:KT:unklar:unklar_wie_vermittelt
# =================================================================
# 11:m554:BG:probe:ob_der_HD_unmundige_tierjunge_schutzt
# 1:m554:BG:probe:ob_der_HD_hungriges_tier_futtert
# 6:m554:BG:probe:ob_der_HD_auf_die_beute_verzichten_kann
# 2:m554:BG:unklar:unklares_bedingung
# -----------------------------------------------------------------
# 20 : m554:BV:erhalten:ein_signalisator_erhalten
# -----------------------------------------------------------------
# 1:m554:BG:probe:ob_der_HD_hungriges_tier_futtert
# 8:m554:BG:probe:ob_der_HD_unmundige_tierjunge_schutzt
# 1:m556F*:KF:melden:als_diener:der_HD_meldet_sich_beim_AN_als_diener
# 4:m554:BG:probe:ob_der_HD_auf_die_beute_verzichten_kann
# 2:End-m554:BV:erhalten:ein_signalisator_erhalten
# 1:m613:KV:melden:verlobung:der_HD_meldet_sich_als_freier
# 1:m554:BG:unklar:unklares_bedingung
# 2:m329:KV:melden:verlobung:der_HD_meldet_sich_als_freier
# =================================================================
# 5:m300:BV-:ablehnen:bitte_ablehnen
# 1:m302C*:BV:erpressen:eine_begehrte_information_erpressen
# 8:m554:BV:erhalten:ein_signalisator_erhalten
# 3:Anf-m554:BG:probe:ob_der_HD_unmundige_tierjunge_schutzt
# 1:m314:KV-:melden:der_HD_meldet_sich_vom_OB_oder_HO_ab
# -----------------------------------------------------------------
# 18 : m554:BG:probe:ob_der_HD_unmundige_tierjunge_schutzt
# -----------------------------------------------------------------
# 6:m554:BV:erhalten:erhalten_eine_versprechen_geholfen_zu_werden
# 11:m554:BV:erhalten:ein_signalisator_erhalten
# 1:m554:BV:erhalten:ein_tierjunge_erhalten
# =================================================================

# %%
import matplotlib.pyplot as plt
import networkx as nx
def cutoff_ast_data(wuerzel, graph, nachbar_liste, cutoff = 0):
    vor = graph[wuerzel][0]
    zurueck = graph[wuerzel][1]
    nachbarn = vor.copy()
    nachbarn.update(zurueck)
    for ast_name, ast_gewicht in sorted(nachbarn.items()):
        if (ast_gewicht >= cutoff):
             nachbar_liste.append([ep_name_format(wuerzel), 
                                   ep_name_format(ast_name), ast_gewicht])  
def cutoff_ast_volldata(wuerzel, graph, nachbar_liste, cutoff = 0):
    vor = graph[wuerzel][0]
    zurueck = graph[wuerzel][1]
    nachbarn = vor.copy()
    nachbarn.update(zurueck)
    for ast_name, ast_gewicht in sorted(nachbarn.items()):
        if (ast_gewicht >= cutoff):
             #nachbar_liste.append([ep_name_vollformat(wuerzel), ep_name_vollformat(ast_name), ast_gewicht])
            nachbar_liste.append([wuerzel, ast_name, ast_gewicht]) 
def cutoff_graph_data(graph, cutoff = 0):
    nachbar_liste = []
    for i, (k, v) in enumerate(sorted(graph.items())):
        cutoff_ast_data(k, graph, nachbar_liste, cutoff)
    neue_nachbar_liste = [[i, nachbar] for i, nachbar in enumerate(nachbar_liste)]
    return neue_nachbar_liste
def cutoff_graph_volldata(graph, cutoff = 0):
    nachbar_liste = []
    for i, (k, v) in enumerate(sorted(graph.items())):
        cutoff_ast_volldata(k, graph, nachbar_liste, cutoff)
    neue_nachbar_liste = [[i, nachbar] for i, nachbar in enumerate(nachbar_liste)]
    return neue_nachbar_liste
def interactive_graph_data(graph_data, loesch_index, gew_dict):
    for k, v in gew_dict.items():
        graph_data[k][1][2] = v
    neue_nachbar_liste = [[i, nachbar[1]] for i, 
                          nachbar in enumerate(graph_data) if i not in loesch_index]
    return neue_nachbar_liste
def graph_bauer(graph_data):
    G = nx.Graph()
    w_liste=[]
    for el in graph_data:
        n1 = el[1][0]
        n2 = el[1][1]
        w = el[1][2]
        w_liste.append(w)
        G.add_edge(n1, n2, weight=w)
    return G,w_liste
def show_graph(G,w):
    fh = open("edgelist.utf-8", "wb")
    nx.write_multiline_adjlist(G, fh, 
                               delimiter="\t", encoding="utf-8")
    fh = open("edgelist.utf-8", "rb")
    H = nx.read_multiline_adjlist(fh, 
                                  delimiter="\t", encoding="utf-8")
    for n in G.nodes():
        if n not in H:
            print(False)
    pos = nx.spring_layout(G)
#     for k, v in pos:
#         pos[k] = np.array([1, v[2]])
    q = max(w)
    klein = q //3
    gross = q //2  
    wenig = [(u, v) for (u, v, d) in G.edges(data=True) 
             if d["weight"] <klein]
    mehr = [(u, v) for (u, v, d) in G.edges(data=True) 
            if klein <= d["weight"] <=gross]
    viel = [(u, v) for (u, v, d) in G.edges(data=True) 
            if d["weight"] >gross]
    nx.draw(G, pos, edgelist=wenig, font_size=8, 
            edge_color="g", width=1, with_labels=False)
    nx.draw(G, pos, edgelist=mehr, font_size=8, 
            edge_color="b", width=1, with_labels=False)
    nx.draw(G, pos, edgelist=viel, font_size=8, 
            edge_color="r", width=1, with_labels=False)
    for p in pos:  # raise text positions
        pos[p][1] +=0.04

    nx.draw_networkx_labels(G, pos,  font_size=10)
    plt.show()

# %%
haeufigkeit=3
auto_graph=cutoff_graph_volldata(graph, haeufigkeit)
#auto_graph

# %%
G,W = graph_bauer(auto_graph)
show_graph(G,W)

# %%
def make_set_of_chosen_vertives(graph_edge_data):
    chosen_vertices=set()
    for sub_list in graph_edge_data:
        sub_sub_list = sub_list[1]
        chosen_vertices.add(sub_sub_list[0])
        chosen_vertices.add(sub_sub_list[1])
    return chosen_vertices

def write_nodes_code_in_js(chosen_vertices):
    nodes= "var nodes = ["
    #for k, v in graph.items():
    for k in chosen_vertices:
        id_ = ep_name_format(k)
        value = 0
        #for nn in v:
            #value += list(dict(nn).values())[0]
        title = k#f"{k} ({value})"
        did_ = (id_.split(':'))[0]+':'+(id_.split(':'))[1].replace('+','').replace('-','')+':'+(id_.split(':'))[-1].replace('_',' ')
        node_string = f"{{id:'{id_}',  label:'{did_}', title:'{title}'  }},"
        nodes+=node_string
    nodes+="];"
    return nodes

# %%
#print(write_nodes_code_in_js(chosen_vertices))

# %%
graph_data = cutoff_graph_volldata(graph, haeufigkeit)
chosen_vertices=list(make_set_of_chosen_vertives(graph_data))
chosen_vertices.sort()

# for vertex_name in chosen_vertices:
#     print(ep_name_format(vertex_name)) #,':',vertex_name)
    
# print(chosen_vertices, sep='\n')

# %%
#print(*chosen_vertices, sep='\n')

# %%
def write_edges_code_in_js(graph_data):
    edges = "var edges = ["
    edge_names = set()
    for els in graph_data:
        el = els[1]
        id1 = ep_name_format(el[0])
        id2 = ep_name_format(el[1])
        name_list = [id1, id2]
        name_list.sort()
        edge_name = "_".join(name_list)
        if edge_name not in edge_names:
            edge_names.add(edge_name)
            value = el[2]
            title = el[2]
            edge_string = f"{{from:'{id1}', to:'{id2}', value:{value}, title:'{title}' }},"
            edges+=edge_string
    edges+="];"    
    return edges
    print(edge_string)

# %%
def make_html_file_for_graphs(graph_data, destination):
    chosen_vertices=make_set_of_chosen_vertives(graph_data)
    nodes = write_nodes_code_in_js(chosen_vertices)
    edges = write_edges_code_in_js(graph_data)
    graph_html_string ="""<html>
    <head>
        <title>ATUDe1=40</title>

        <style type="text/css">
            #mynetwork {
                width: auto;
                height: auto;
                border: 1px solid lightgray;
            }</style>

        <script type="text/javascript" src="vis/dist/vis.js"></script>
        <link href="vis/dist/vis-network.min.css" rel="stylesheet" type="text/css" />

        <script type="text/javascript">
        function draw() {
    """ + nodes + """ 
    
    """+ edges + """
    var container = document.getElementById('mynetwork');
            var data = {
                nodes: nodes,
                edges: edges
            };
            var options = {
                nodes: {
                    shape: 'dot',
                    size: 16
                },
                physics: {
                    forceAtlas2Based: {
                        gravitationalConstant: -42,
                        centralGravity: 0.005,
                        springLength: 80,
                        springConstant: 0.23
                    },
                    maxVelocity: 146,
                    solver: 'forceAtlas2Based',
                    timestep: 0.21,
                    stabilization: {iterations: -1}
                }
            };
            var network = new vis.Network(container, data, options);

        }
    </script>

    </head>

    <body onload="draw()"> Graphenanalyse der ATU Typenaffinität des Repertoires der deutschsprachigen Zaubermärchen (1=40)
            <br /><a href="http://www.dglab.uni-jena.de/atu/kont/zeichenerklaerung.html"
            target="_blank"
            onclick="window.open(this.href,this.target,'width=640,height=720'); return false;"
            >Zeichenerklärung</a> | <a
            href="http://www.dglab.uni-jena.de/wiki/doku.php?id=visualisierung:graphen">Zurück zu
            Wiki</a>
        <div id="mynetwork"></div>
    </body>
</html>
    """
    with open(destination, "w") as save_file:
        print(graph_html_string, file=save_file)

# %%
graph_data = cutoff_graph_volldata(graph, haeufigkeit)
#graph_data = cutoff_graph_data(graph, haeufigkeit) #und [0:1] oben
make_html_file_for_graphs(graph_data, "graphen.html")
