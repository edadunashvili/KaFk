# %% [markdown]
# # TextClass (inkl. für mehrere Werte)

# %%
import xml.etree.ElementTree as ET

# 1. Die Wurzel des XML-Baums aus der Datei `gesamt_märchen.xml` wird gelesen
root_node = ET.parse('gesamt_märchen.xml').getroot()

# 2. Initialisierung eines Sets für eindeutige `chisch`-Werte
unique_schema_set = set()

# 3. Iteration über das `teiCorpus`-Element
for corp in root_node.findall(".//{http://www.tei-c.org/ns/1.0}teiCorpus"):
    if "xtk" in corp.attrib["n"]:
        # 4. Iteration über jedes `TEI`-Element
        for ganze in corp.findall(".//{http://www.tei-c.org/ns/1.0}TEI"):
            mance = ganze.attrib['n']
            # 5. Überprüfen, ob der Wert mit '100' beginnt
            if "" in mance:
                for text in ganze.findall(".//{http://www.tei-c.org/ns/1.0}text"):
                    for segm in text.findall(".//{http://www.tei-c.org/ns/1.0}seg"):
                        tn=segm.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
                        if "a881" in tn:
                            chisch = text.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                            if chisch:  # Überprüfen, ob der `chisch`-Wert nicht leer ist
                                unique_schema_set.add(chisch)  # Hinzufügen zur Menge

# 7. Schreiben der eindeutigen Werte in die Datei `TextClass.txt`
with open("TextClass.txt", 'w', encoding='utf-8') as f:
    # Erstellen der Liste im gewünschten Format
    chisch_list = sorted(unique_schema_set)  # Sortierte Liste der eindeutigen Werte
    formatted_list = str(chisch_list)  # In Python-Listenformat konvertieren
    f.write(formatted_list)

# %%
import ast
import xml.etree.ElementTree as ET

def setze_variable_aus_datei(dateiname: str, variablenname: str):
    try:
        with open(dateiname, "r", encoding="utf-8") as datei:
            inhalt = datei.read().strip()
        wert = ast.literal_eval(inhalt)
        globals()[variablenname] = wert
        return wert
    except Exception as e:
        print(f"Fehler beim Einlesen und Setzen der Variable: {e}")
        return None

# 1. Mehrere `chisch`-Werte definieren
chisch = setze_variable_aus_datei("TextClass.txt", "chisch")

# Überprüfen, ob die Variable korrekt gesetzt wurde
print(chisch)
# Out:
# ['zyx_cr_ava_rus_145ß', 'zyx_cr_ava_rus_27ß', 'zyx_cr_lez_rus_43ß', 'zyx_cr_lez_rus_4ß', 'zyx_cr_ttt_rus_23ß']

# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET

# Modul zur Speicherung in einer zentralen Textdatei
def speichere_gesamt_ergebnisse(dateiname, daten):
    """
    Speichert die Gesamtergebnisse in eine Textdatei.
    
    :param dateiname: Name der Textdatei
    :param daten: Ergebnisse in Form eines Dictionaries {chisch: [Daten]}
    """
    with open(dateiname, 'w', encoding='utf-8') as f:
        for ch, ergebnisse in daten.items():
            f.write(f"\n{ch}:\n")
            for zeile in ergebnisse:
                f.write(f"{zeile}\n")

# Mehrere `chisch`-Werte definieren
chisch = setze_variable_aus_datei("TextClass.txt", "chisch")
# chisch = ['zyx_cr_lbe_rus_43'] # 1.1. Alternativ: Einen chisch-Wert eingeben

root_node = ET.parse('gesamt_märchen.xml').getroot()

# Speichern der Märchendaten für jedes `chisch`
maerchen_daten = {ch: "" for ch in chisch}

# 2. Schleife für jeden `chisch`-Wert in der Liste
for ch in chisch:
    for ganze in root_node.findall(".//{http://www.tei-c.org/ns/1.0}text"):
        if ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id') == ch:
            for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
                for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
                    for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}seg"):
                        try:
                            # Extrahieren der relevanten Attribute
                            labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
                            labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N')
                            labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N')
                            labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N')
                            labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N')
                            labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N')
                            labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N')
                            labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N')
                            labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N')
                            labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N')
                            labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N')
                            labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N')
                            quelle = ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']
                            inhalt = (phrase.text.lower().strip()
                                      .replace('|','').replace(':','').replace("ä","ae").replace("ü","ue")
                                      .replace("ö","oe").replace("ß","ss").replace(",","" ).replace("«","")
                                      .replace("»","" ).replace(".","" ).replace(";","" ).replace('"',"")
                                      .replace("?","" ).replace("!","" ).replace("-"," " ).replace("'", "")
                                      .replace("(", "" ).replace(")", "" ).replace("\n","" ).replace("  ", " "))
                            
                            if labela.startswith('a'):
                                # Speichern der Märchendaten in der entsprechenden `chisch`-Liste
                                maerchen_daten[ch] += f"{quelle},{labela},{labelb1},{labelc1},{labelb2},{labelc2},{labelb3},{labelc3},{labelb4},{labelc4},{labelb5},{labelc5},{labeld},{inhalt},0\n"
                        except KeyError as e:
                            print(f"Fehlendes Attribut: {e}")

# 3. Ausgabestruktur für jeden `chisch`-Wert erstellen
gesamt_ergebnisse = {}

# Erstellen der CSV-Dateien und Verarbeiten der Daten
unique_values_per_ch = {}
result_data_per_ch = {}
for ch in chisch:
    # CSV-Datei erstellen
    with open(f"text_{ch}.csv", 'w', encoding='utf-8') as f:
        f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar\n')
        f.write(maerchen_daten[ch])

    # Index-Strings erstellen
    abcd_data = []
    df = pd.read_csv(f"text_{ch}.csv", encoding='utf-8')

    for index, row in df.iterrows():
        quelle = row['quelle']
        labela = row['labela']
        for i in range(1, 6):
            labelb = row[f'labelb{i}']
            labelc = row[f'labelc{i}']
            labeld = row['labeld']
            inhalt = row['inhalt']
            abcd_data.append(f"{labela}:{labelb}:{labelc}:{labeld}")

    # Filterung der Daten
    filtered_data = [line for line in abcd_data if ':N:' not in line]

    # Extrahieren einzigartiger Werte vor dem ersten ':'
    unique_values = set(line.split(':')[0] for line in filtered_data)
    unique_values_per_ch[ch] = unique_values
    result_data_per_ch[ch] = filtered_data

    # Speichern der gefilterten Daten in der Gesamt-Ausgabeliste
    gesamt_ergebnisse[ch] = filtered_data

# Zählen der `chisch`-Werte mit und ohne Ergebnisse
chisch_mit_ergebnissen = [ch for ch, ergebnisse in gesamt_ergebnisse.items() if ergebnisse]
chisch_ohne_ergebnisse = [ch for ch, ergebnisse in gesamt_ergebnisse.items() if not ergebnisse]

print(f"Anzahl der chisch-Werte mit Ergebnissen: {len(chisch_mit_ergebnissen)}")
print(f"Anzahl der chisch-Werte ohne Ergebnisse: {len(chisch_ohne_ergebnisse)}")

# Parsen der `fk/vmf_a.xsd`-Datei und Überprüfen von Werten mit Leerzeichen
fk_tree = ET.parse('kf/vmf_a.xsd').getroot()
enum_elements = fk_tree.findall(".//{http://www.w3.org/2001/XMLSchema}enumeration")
enum_values_with_spaces = {enum.attrib['value'] for enum in enum_elements if ' ' in enum.attrib['value']}

# Ausgabe der Ergebnisse
for ch, unique_values in unique_values_per_ch.items():
    print(f"\n\n<ul>{ch}</ul>")
    print("<p>-----------------</p>")
    matching_values = [
    value for value in enum_values_with_spaces 
    if any(value.split(' ')[0] == uval for uval in unique_values)
]
   
    print('<li>')
    print(*matching_values, sep='</li><li>')
    print('</li>')
    print("<p>-----------------</p>")

    # Ergebnisse mit Werten anzeigen
    if ch in result_data_per_ch:
        #print("Gefilterte Ergebnisse:")
        for result in result_data_per_ch[ch]:
            print(f"<li>{result}</li>")

# Speichern in einer Textdatei
speichere_gesamt_ergebnisse("TextClassaLaufende.txt", gesamt_ergebnisse)

# Löschen der erstellten CSV-Dateien
for ch in chisch:
    try:
        os.remove(f"text_{ch}.csv")  # Löschen der CSV-Datei
    except FileNotFoundError:
        print(f"Datei text_{ch}.csv wurde nicht gefunden und konnte nicht gelöscht werden.")
    except Exception as e:
        print(f"Fehler beim Löschen der Datei text_{ch}.csv: {e}")
# Out:
# Anzahl der chisch-Werte mit Ergebnissen: 5
# Anzahl der chisch-Werte ohne Ergebnisse: 0
#
#
# <ul>zyx_cr_ava_rus_145ß</ul>
# <p>-----------------</p>
# <li>
# a881 Vielgeprüfte Treue</li><li>a881A Frau in Männerkleidung
# </li>
# <p>-----------------</p>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:fPP</li>
# <li>a881:f:Einen_Bösen_einstellen:fVB_fPP</li>
# <li>a881:h:Ausplaudern:rHH_fVB</li>
# <li>a881:h:VERLEUMDUNG_bei_Untreue:N</li>
# <li>a881:f:Überrascht_werden_oder_geraten:rHD_fVB</li>
# <li>a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fVB</li>
# <li>a881:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fVB</li>
# <li>a881:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fVB</li>
# <li>a881:H:FLUCHT:rHD_fVB</li>
# <li>a881:f:Überrascht_werden_oder_geraten:rHD_fVB</li>
# <li>a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fVB</li>
# <li>a881:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fVB</li>
# <li>a881:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fVB</li>
# <li>a881:H:FLUCHT:rHD_fVB</li>
# <li>a881A:H:Unterkommen:rHD_rVB</li>
# <li>a881A:F:An_Königswahl_teilnehmen:rHD_rVB</li>
# <li>a881A:H:IDENTITÄT_ändern:rHD_rVB</li>
# <li>a881A:H:An_Königswahl_teilnehmen:N</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION:rHD</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD</li>
# <li>a881A:H:Zusammenbringen_aller_Handlungsträger:rHD</li>
# <li>a881A:F:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rPP</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_rPP</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_rPP</li>
# <li>a881A:F:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fPP</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_fPP</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_fPP</li>
# <li>a881A:F:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fVB</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_fVB</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_fVB</li>
# <li>a881A:H:Bestrafung:rHD_fPP</li>
# <li>a881A:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP</li>
# <li>a881A:H:Familienzusammenführung:rHD_rPP</li>
# <li>a881A:H:Ende:rHD_rPP</li>
#
#
# <ul>zyx_cr_ava_rus_27ß</ul>
# <p>-----------------</p>
# <li>
# a881 Vielgeprüfte Treue</li><li>a881A Frau in Männerkleidung
# </li>
# <p>-----------------</p>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:#:#:#</li>
# <li>a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:fPP</li>
# <li>a881:f:Einen_Bösen_einstellen:fVB_fPP</li>
# <li>a881:h:Ausplaudern:rHH_fVB</li>
# <li>a881:h:VERLEUMDUNG_bei_Untreue:fPP</li>
# <li>a881:h:BEHINDERUNG_durch_Verstümmelung:rHD_rPP</li>
# <li>a881:f:FLUCHT_vorbereiten:N</li>
# <li>a881:h:FLUCHT:N</li>
# <li>a881:H:Eine_BEHINDERUNG_beheben:rHD_fPP</li>
# <li>a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP</li>
# <li>a881:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP</li>
# <li>a881:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fPP</li>
# <li>a881:H:FLUCHT:rHD_fPP</li>
# <li>a881:f:Überrascht_werden_oder_geraten:rHD_fVB</li>
# <li>a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fVB</li>
# <li>a881:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fVB</li>
# <li>a881:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fVB</li>
# <li>a881:H:FLUCHT:rHD_fVB</li>
# <li>a881:f:Überrascht_werden_oder_geraten:rHD_fVB</li>
# <li>a881:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fVB</li>
# <li>a881:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fVB</li>
# <li>a881:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fVB</li>
# <li>a881:H:FLUCHT:rHD_fVB</li>
# <li>a881A:H:Unterkommen:rHD_rVB</li>
# <li>a881A:F:An_Königswahl_teilnehmen:rHD_rVB</li>
# <li>a881A:H:IDENTITÄT_ändern:rHD_rVB</li>
# <li>a881A:H:An_Königswahl_teilnehmen:rHD</li>
# <li>a881A:F:Intensive_ERKUNDUNGSAKTION:rHD</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD</li>
# <li>a881A:H:Zusammenbringen_aller_Handlungsträger:rHD</li>
# <li>a881A:F:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rPP</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_rPP</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_rPP</li>
# <li>a881A:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP</li>
# <li>a881A:H:Familienzusammenführung:rHD_rPP</li>
# <li>a881A:H:Bestrafung:rHD_fVB</li>
# <li>a881A:H:Ende:rHD_rPP</li>
#
#
# <ul>zyx_cr_lez_rus_43ß</ul>
# <p>-----------------</p>
# <li>
# a531 Sohn des Jaegers/Ferdinand der treue...</li><li>a551 Wasser des Lebens</li><li>a881A Frau in Männerkleidung
# </li>
# <p>-----------------</p>
# <li>a551:f:PROVOKATION:rBZ_fHH</li>
# <li>a551:h:Der_PROVOKATION_nachgehen:rBZ_fHH</li>
# <li>a551:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rBZ_fHH</li>
# <li>a551:h:KRANKHEIT:rBZ_fHH</li>
# <li>a551:F:HEILMITTEL_besorgen:rHH_fHD</li>
# <li>a551:F:Um_einen_Auftrag_werben:rHH_fHD</li>
# <li>a551:h:HEILMITTEL_erfassen:fHD_fZO</li>
# <li>a551:h:HEILMITTEL_besorgen:rHH_fHD_fZO</li>
# <li>a551:F:Um_einen_Auftrag_werben:rHH_fHD</li>
# <li>a551:h:HEILMITTEL_erfassen:fHD_fZO</li>
# <li>a551:h:HEILMITTEL_besorgen:fHD_fZO</li>
# <li>a551:h:HEILMITTEL_besorgen:rHH_fHD_fZO</li>
# <li>a531:F:Um_einen_Auftrag_werben:rHD_rHH</li>
# <li>a551:F:REITTIER_erhalten:rHD_rHF</li>
# <li>a551:HF:Wegweisung_erhalten:rHD_rHF</li>
# <li>a531:Hh:Eines_auffälligen_GEGENSTANDES_habhaft_werden:rHD_rHF_rZM</li>
# <li>a531:H:Unterkommen:rZM_fVB</li>
# <li>a531:f:NEUGIER_ausgelöst:rZM_fVB</li>
# <li>a531:h:Der_NEUGIER_nachgehen:rAN_fVB</li>
# <li>a531:f:Zu_Beauftragungen_anregen:rAN_fVB</li>
# <li>a531:f:EINLADUNG:rAN_fVB</li>
# <li>a531:HF:Information_aus_zweiter_Hand:rAN_fVB</li>
# <li>a531:H:Einer_EINLADUNG_nachgehen:rHD_rAN</li>
# <li>a531:f:Zu_Beauftragungen_anregen:rAN_fVB</li>
# <li>a531:hf:FEHLENDEN_Gegenstand_besorgen:rAN_fVB</li>
# <li>a531:f:FEHLENDEN_Gegenstand_besorgen:rHD_rAN</li>
# <li>a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF</li>
# <li>a531:HF:FEHLENDEN_Gegenstand_erfassen:rHD_rHF</li>
# <li>a531:H:FEHLENDEN_Gegenstand_besorgen:rHD_rHF</li>
# <li>a531:f:Zu_Beauftragungen_anregen:rAN_fVB</li>
# <li>a531:hf:Die_SCHÖNE_herbeiholen:rAN_fVB</li>
# <li>a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN</li>
# <li>a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF</li>
# <li>a531:HF:Die_SCHÖNE_erfassen:rHD_rHF</li>
# <li>a531:H:Die_SCHÖNE_erfassen:rHD_rBZ</li>
# <li>a531:h:Abtretung_der_Schönen_stehet_bevor:rBZ_rAN</li>
# <li>a531:HF:Einen_magischen_EINGRIFF_vorbereiten:rBZ_rAN</li>
# <li>a531:H:Einen_magischen_EINGRIFF_vorbereiten:rHD_rHF_rZM</li>
# <li>a531:F:Sich_einem_magischen_EINGRIFF_unterziehen:rHD_rBZ_rAN</li>
# <li>a531:H:Sich_einem_magischen_EINGRIFF_unterziehen:rHD_rBZ_rAN</li>
# <li>a531:H:FLUCH:rHD_rBZ_rAN</li>
# <li>a531:H:Bestrafung:rHD_rBZ_rAN</li>
# <li>a531:F:Heiraten:rHD_rBZ</li>
# <li>a551:F:HEILMITTEL_besorgen:rHD_fHH</li>
# <li>a551:H:KRANKHEIT_beheben:rHD_fHH</li>
# <li>a881A:f:GIER_und_NEID_ausgelöst:fHH</li>
# <li>a881A:h:Der_NEUGIER_nachgehen:fHH</li>
# <li>a881A:f:MISSETAT_planen:fHH</li>
# <li>a881A:F:MISSETAT_beheben:rHD_rHH</li>
# <li>a881A:Hh:KONTAKT_abbrechen:rHD_rBZ</li>
# <li>a881A:h:Eine_ENTFÜHRUNG:rBZ_fST</li>
# <li>a881A:H:Eine_ENTFÜHRUNG_beheben:rBZ_fST</li>
# <li>a881A:H:FLUCHT:rBZ_fST</li>
# <li>a881A:h:Überrascht_werden_oder_geraten:rBZ_fST</li>
# <li>a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rBZ_fST</li>
# <li>a881A:H:Dem_VORTÄUSCHEN_nachgehen:rBZ_fST</li>
# <li>a881A:H:Zum_Schlafen_bringen:rBZ_fST</li>
# <li>a881A:H:IDENTITÄT_ändern:rBZ</li>
# <li>a881A:H:FLUCHT:rBZ</li>
# <li>a881A:H:Unterkommen:rVB_rBZ</li>
# <li>a881A:F:An_Königswahl_teilnehmen:rVB_rBZ</li>
# <li>a881A:H:An_Königswahl_teilnehmen:rBZ</li>
# <li>a881A:F:Intensive_ERKUNDUNGSAKTION:rBZ</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rBZ</li>
# <li>a881A:H:Zusammenbringen_aller_Handlungsträger:rBZ</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rBZ_fST</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rBZ_fST</li>
# <li>a881A:H:ERZÄHLEN_beenden:rBZ_fST</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rBZ_fHH</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rBZ_fHH</li>
# <li>a881A:H:ERZÄHLEN_beenden:rBZ_fHH</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rBZ_fST</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rBZ_fST</li>
# <li>a881A:H:ERZÄHLEN_beenden:rBZ_fST</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rBZ</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_rBZ</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_rBZ</li>
# <li>a881A:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rBZ</li>
# <li>a881A:H:KONTAKT_wiederherstellen:rHD_rBZ</li>
# <li>a881A:H:Bestrafung:rHD_fHH</li>
#
#
# <ul>zyx_cr_lez_rus_4ß</ul>
# <p>-----------------</p>
# <li>
# a531 Sohn des Jaegers/Ferdinand der treue...</li><li>a551 Wasser des Lebens</li><li>a881A Frau in Männerkleidung
# </li>
# <p>-----------------</p>
# <li>a551:f:PROVOKATION:rBZ_fHH</li>
# <li>a551:h:Der_PROVOKATION_nachgehen:rBZ_fHH</li>
# <li>a551:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rBZ_fHH</li>
# <li>a551:h:KRANKHEIT:rBZ_fHH</li>
# <li>a551:F:HEILMITTEL_besorgen:fHD_fHH</li>
# <li>a551:h:HEILMITTEL_erfassen:fHD_fZO</li>
# <li>a551:h:HEILMITTEL_besorgen:fHD_fHH_fZO</li>
# <li>a551:F:Um_einen_Auftrag_werben:fHD_fHH</li>
# <li>a551:h:HEILMITTEL_erfassen:fHD_fZO</li>
# <li>a551:h:HEILMITTEL_besorgen:fHD_fHH_fZO</li>
# <li>a551:F:Um_einen_Auftrag_werben:rHD_fHH</li>
# <li>a551:F:REITTIER_erhalten:rHD_rHF</li>
# <li>a551:HF:Wegweisung_erhalten:rHD_rHF</li>
# <li>a531:Hh:Eines_auffälligen_GEGENSTANDES_habhaft_werden:rHD_rHF_rZM</li>
# <li>a531:H:Unterkommen:rHD_fVB</li>
# <li>a531:f:NEUGIER_ausgelöst:rHD_fVB</li>
# <li>a531:h:Der_NEUGIER_nachgehen:rAN_fVB</li>
# <li>a531:f:Information_aus_zweiter_Hand:rAN_fVB</li>
# <li>a531:f:EINLADUNG:rAN_fVB</li>
# <li>a531:hf:Information_aus_zweiter_Hand:rAN_fVB</li>
# <li>a531:H:Einer_EINLADUNG_nachgehen:rHD_rAN</li>
# <li>a531:f:Zu_Beauftragungen_anregen:rAN_fVB</li>
# <li>a531:hf:FEHLENDEN_Gegenstand_besorgen:rAN_fVB</li>
# <li>a531:f:FEHLENDEN_Gegenstand_besorgen:rHD_rAN</li>
# <li>a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF</li>
# <li>a531:HF:FEHLENDEN_Gegenstand_besorgen:rHD_rHF</li>
# <li>a531:H:FEHLENDEN_Gegenstand_erfassen:rHD_rHF_rZO</li>
# <li>a531:H:FEHLENDEN_Gegenstand_besorgen:rHD_rZO_rAN</li>
# <li>a531:f:Zu_Beauftragungen_anregen:rAN_fVB</li>
# <li>a531:hf:Die_SCHÖNE_herbeiholen:rAN_fVB</li>
# <li>a531:f:Die_SCHÖNE_herbeiholen:rHD_rAN</li>
# <li>a531:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF</li>
# <li>a531:HF:Die_SCHÖNE_erfassen:rHD_rHF</li>
# <li>a531:H:Die_SCHÖNE_erfassen:rHD_rHF_rBZ</li>
# <li>a531:h:Abtretung_der_Schönen_stehet_bevor:rHD_rBZ</li>
# <li>a531:HF:Einen_magischen_EINGRIFF_vorbereiten:rHD_rBZ</li>
# <li>a531:Hh:Die_SCHÖNE_herbeiholen:rHD_rBZ_rAN</li>
# <li>a531:H:Einen_magischen_EINGRIFF_vorbereiten:rHD_rHF_rZO</li>
# <li>a531:f:Sich_einem_magischen_EINGRIFF_unterziehen:rHD_rBZ_rAN</li>
# <li>a531:H:Sich_einem_magischen_EINGRIFF_unterziehen:rHD_rBZ_rAN</li>
# <li>a531:H:FLUCH:rHD_rBZ_rAN</li>
# <li>a531:H:Bestrafung:rHD_rBZ_rAN</li>
# <li>a531:H:Heiraten:rHD_rBZ</li>
# <li>a551:H:HEILMITTEL_besorgen:rBZ_fHH</li>
# <li>a551:H:KRANKHEIT_beheben:rBZ_fHH</li>
# <li>a551:f:GIER_und_NEID_ausgelöst:fHH</li>
# <li>a551:h:Der_NEUGIER_nachgehen:fHH</li>
# <li>a551:f:MISSETAT_planen:fHH</li>
# <li>a551:F:MISSETAT_beheben:rHD_rHH</li>
# <li>a551:H:Der_MISSETATwarnung_nachgehen:rHD_rBZ</li>
# <li>a551:H:FLUCHT:rHD_rBZ</li>
# <li>a881A:f:KONTAKT_abbrechen:rHD_rBZ</li>
# <li>a881A:h:Eine_ENTFÜHRUNG:rBZ_fST</li>
# <li>a881A:H:Eine_ENTFÜHRUNG_beheben:rBZ_fST</li>
# <li>a881A:H:FLUCHT:rBZ_fST</li>
# <li>a881A:h:Überrascht_werden_oder_geraten:rBZ_fST</li>
# <li>a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rBZ_fST</li>
# <li>a881A:H:Dem_VORTÄUSCHEN_nachgehen:rBZ_fST</li>
# <li>a881A:H:Zum_Schlafen_bringen:rBZ_fST</li>
# <li>a881A:H:IDENTITÄT_ändern:rBZ</li>
# <li>a881A:H:FLUCHT:rBZ</li>
# <li>a881A:H:Unterkommen:rVB_rBZ</li>
# <li>a881A:F:An_Königswahl_teilnehmen:rVB_rBZ</li>
# <li>a881A:H:An_Königswahl_teilnehmen:rBZ</li>
# <li>a881A:F:Intensive_ERKUNDUNGSAKTION:rVB_rBZ</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rBZ</li>
# <li>a881A:H:Zusammenbringen_aller_Handlungsträger:rBZ</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rBZ_fHH</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rBZ_fHH</li>
# <li>a881A:H:ERZÄHLEN_beenden:rBZ_fHH</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rBZ_fST</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rBZ_fST</li>
# <li>a881A:H:ERZÄHLEN_beenden:rBZ_fST</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rBZ_fST</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rBZ_fST</li>
# <li>a881A:H:ERZÄHLEN_beenden:rBZ_fST</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rBZ</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_rBZ</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_rBZ</li>
# <li>a881A:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rBZ</li>
# <li>a881A:H:KONTAKT_wiederherstellen:rHD_rBZ</li>
# <li>a531:F:Bestrafung:rHD_fHH</li>
# <li>a531:F:Heiraten:N</li>
#
#
# <ul>zyx_cr_ttt_rus_23ß</ul>
# <p>-----------------</p>
# <li>
# a881A Frau in Männerkleidung
# </li>
# <p>-----------------</p>
# <li>a881A:H:Verlobung_wird_arrangiert:rHH_rHH</li>
# <li>a881A:h:Tod_von_Angehörigen:rHH</li>
# <li>a881A:H:Hochzeit_verschieben:rHH</li>
# <li>a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_rAN</li>
# <li>a881A:f:Ungewollte_Verlobung_akzeptieren:rHH_rAN</li>
# <li>a881A:h:Ungewollte_Verlobung_akzeptieren:rHH_rAN</li>
# <li>a881A:f:Ungewollte_Verlobung_akzeptieren:rHH_rAN</li>
# <li>a881A:h:Ungewollte_Verlobung_akzeptieren:rHH_rAN</li>
# <li>a881A:h:Ungewollte_Verlobung_akzeptieren:rHD_rHH</li>
# <li>a881A:H:FLUCHT_vorbereiten:rHD_rPP</li>
# <li>a881A:F:Krankheit_VORTÄUSCHEN:rHD_rAN</li>
# <li>a881A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rAN</li>
# <li>a881A:Hh:FLUCHT:rHD_rPP</li>
# <li>a881A:H:IDENTITÄT_ändern:rHD_rPP</li>
# <li>a881A:Hh:KONTAKT_abbrechen:rHD_rPP_fPP</li>
# <li>a881A:h:Eine_ENTFÜHRUNG:rHD_fPP</li>
# <li>a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP</li>
# <li>a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP</li>
# <li>a881A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fPP</li>
# <li>a881A:H:FLUCHT:rHD</li>
# <li>a881A:h:SCHLAF:rHD</li>
# <li>a881A:h:Überrascht_werden_oder_geraten:rHD_fPP</li>
# <li>a881A:h:Begehren_einer_Person_oder_eines_GEGENSTANDES:rHD_fPP</li>
# <li>a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP</li>
# <li>a881A:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fPP</li>
# <li>a881A:Hh:FLUCHT:rHD_fHF</li>
# <li>a881A:h:Überrascht_werden_oder_geraten:rHD_fPP</li>
# <li>a881A:F:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_fPP</li>
# <li>a881A:H:Zum_Schlafen_bringen:rHD_fPP</li>
# <li>a881A:H:IDENTITÄT_ändern:rHD_fPP</li>
# <li>a881A:F:MARKIERUNGEN_anbringen:rHD_fPP</li>
# <li>a881A:F:An_Königswahl_teilnehmen:rHD</li>
# <li>a881A:H:An_Königswahl_teilnehmen:rHD</li>
# <li>a881A:F:Intensive_ERKUNDUNGSAKTION:rHD_fPP</li>
# <li>a881A:#:#:#</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rAN</li>
# <li>a881A:H:Zusammenbringen_aller_Handlungsträger:rAN</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rPP</li>
# <li>a881A:H:Zusammenbringen_aller_Handlungsträger:rPP</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:fPP</li>
# <li>a881A:H:Zusammenbringen_aller_Handlungsträger:fPP</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:fPP</li>
# <li>a881A:H:Zusammenbringen_aller_Handlungsträger:fPP</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:fPP</li>
# <li>a881A:H:Zusammenbringen_aller_Handlungsträger:fPP</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rAN</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_rAN</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_rAN</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_rPP</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_rPP</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_rPP</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fPP</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_fPP</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_fPP</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fPP</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_fPP</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_fPP</li>
# <li>a881A:H:Intensive_ERKUNDUNGSAKTION_nachgehen:rHD_fPP</li>
# <li>a881A:F:ERZÄHLEN_beginnen:rHD_fPP</li>
# <li>a881A:H:ERZÄHLEN_beenden:rHD_fPP</li>
# <li>a881A:H:Bestrafung:rHD_rAN</li>
# <li>a881A:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_rPP</li>
# <li>a881A:H:Familienzusammenführung:rHD_rPP</li>
# <li>a881A:F:Angebot_KÖNIG_ZU_WERDEN:N</li>
# <li>a881A:H:Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen:N</li>
# <li>a881A:H:Ende:N</li>
