# %%
# XML-Datei laden
DTN="vmf_c1.xsd"
with open(DTN, 'r', encoding='utf-8') as file:
    data = file.read()

# Änderungen durchführen
data = data.replace('"ABRATEN_von_der_Mission"', '"Abraten_von_der_MISSION"')
data = data.replace('"Beglaubigen_der_Behauptung_der_ABSURDITÄT"', '"ABSURDITÄT_beglaubigen"')
data = data.replace('"Behauptung_der_ABSURDITÄT"', '"ABSURDITÄT_behaupten"')
data = data.replace('"Der_ABSURDITÄT_entgegentreten"', '"ABSURDITÄT_entgegentreten"')
data = data.replace('"AMUSEMENT"', '"AMÜSEMENT"')
data = data.replace('"Sich_ANEIGNEN"', '"ANEIGNUNG"')
data = data.replace('"ANEIGNEN_beheben"', '"ANEIGNUNG_beheben"')
data = data.replace('"ANEIGNEN_beheben_in_Angriff_nehmen"', '"ANEIGNUNG_Beheben_angehen"')
data = data.replace('"Angebot_GEOPFERT_ZU_WERDEN"', '"Angebot_GEOPFERT_zu_werden"')
data = data.replace('"Angebot_KÖNIG_ZU_WERDEN"', '"Angebot_KÖNIG_zu_werden"')
data = data.replace('"Schrecken_ausgelöst"', '"ANGST_auslösen"')
data = data.replace('"Angst_mit_Angst_vergelten"', '"ANGST_mit_ANGST_vergelten"')
data = data.replace('"Verdreht_interpretieren"', '"Anweisung_wörtlich_nehmen"')
data = data.replace('"Dem_ABRATEN_von_der_Mission_nachgehen"', '"Auf_ABRATEN_von_der_Mission_reagieren"')
data = data.replace('"ABSURDITÄT_nachgehen"', '"Auf_ABSURDITÄT_reagieren"')
data = data.replace('"Den_ALTERNATIVEN_nachgehen"', '"Auf_ALTERNATIVEN_reagieren"')
data = data.replace('"Angebot_GEOPFERT_ZU_WERDEN_nachgehen"', '"Auf_Angebot_GEOPFERT_zu_werden_reagieren"')
data = data.replace('"Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen"', '"Auf_Angebot_KÖNIG_zu_werden_reagieren"')
data = data.replace('"Den_GIER_und_NEID_nachgehen"', '"Auf_Anreiz_zu_GIER_und_Neid_reagieren"')
data = data.replace('"Dem_AMUSEMENT_nachgehen"', '"Auf_Anreiz_zum_AMÜSEMENT_reagieren"')
data = data.replace('"KINDERMORD_nachgehen"', '"Auf_Aufforderung_zu_KINDERMORD_reagieren"')
data = data.replace('"Der_NEUGIER_nachgehen"', '"Auf_ausgelöste_NEUGIER_reagieren"')
data = data.replace('"BESTECHUND_nachgehen"', '"Auf_BESTECHUNG_reagieren"')
data = data.replace('"Dem_STAUNEN_nachgehen"', '"Auf_EINDRUCKSVOLLE_Handlung_reagieren"')
data = data.replace('"Einer_EINLADUNG_oder_BESTELLUNG_nachgehen"', '"Auf_EINLADUNG_oder_Bestellung_reagieren"')
data = data.replace('"Dem_GEHEIMZEICHEN_nachgehen"', '"Auf_GEHEIMSPRACHE_reagieren"')
data = data.replace('"Der_HEIRATSABSICHT_nachgehen"', '"Auf_HEIRATSABSICHT_reagieren"')
data = data.replace('"Lösung_für_den_FÄHRMANN_nachgehen"', '"Auf_Lösungsweg_für_FÄHRMANN_reagieren"')
data = data.replace('"Lösung_für_HEIRATSWILLIGE_nachgehen"', '"Auf_Lösungsweg_für_HEIRATSWILLIGE_reagieren"')
data = data.replace('"Lösung_für_das_LEIDENDE_TIER_nachgehen"', '"Auf_Lösungsweg_für_leidendes_TIER_reagieren"')
data = data.replace('"Lösung_für_SCHATZHÜTERN_nachgehen"', '"Auf_Lösungsweg_für_SCHATZHÜTERN_reagieren"')
data = data.replace('"Lösung_für_SONSTIGES_LEID_nachgehen"', '"Auf_Lösungsweg_für_sonstiges_LEID_reagieren"')
data = data.replace('"Der_PROVOKATION_nachgehen"', '"Auf_PROVOKATION_reagieren"')
data = data.replace('"TABU_nachgehen"', '"Auf_TABU_reagieren"')
data = data.replace('"RENDEZVOUS_nachgehen"', '"Auf_verabredetes_RENDEZVOUS_reagieren"')
data = data.replace('"Der_VERLOCKUNG_nachgehen"', '"Auf_VERLOCKUNG_reagieren"')
data = data.replace('"SÜNDERFALL_nachgehen"', '"Auf_VERSUCHUNG_reagieren"')
data = data.replace('"Der_VORHERSAGE_nachgehen"', '"Auf_VORHERSAGE_reagieren"')
data = data.replace('"Dem_VORTÄUSCHEN_nachgehen"', '"Auf_VORTÄUSCHEN_reagieren"')
data = data.replace('"Einer_Warnung_im_STICH_gelassen_zu_werden_nachgehen"', '"Auf_Warnung_im_STICH_gelassen_zu_werden_reagieren"')
data = data.replace('"Einer_Warnung_vor_KANNIBALISMUS_nachgehen"', '"Auf_Warnung_vor_KANNIBALISMUS_reagieren"')
data = data.replace('"Einer_Warnung_vor_VERGIFTUNG_nachgehen"', '"Auf_Warnung_vor_VERGIFTUNG_reagieren"')
data = data.replace('"WEISHEITEN_nachgehen"', '"Auf_WEISHEITEN_reagieren"')
data = data.replace('"Dem_WERBEN_nachgehen"', '"Auf_WERBEN_reagieren"')
data = data.replace('"Eines_auffälligen_GEGENSTANDES_habhaft_werden"', '"Auffälliges_GEGENSTANDES_habhaft_werden"')
data = data.replace('"AUSSPIONIEREN_in_Angriff_nehmen"', '"AUSSPIONIEREN_angehen"')
data = data.replace('"Eine_Bedrohung_VORTÄUSCHEN"', '"Bedrohung_VORTÄUSCHEN"')
data = data.replace('"Einen_Begleiter_gewinnen"', '"Begleiter_gewinnen"')
data = data.replace('"Eine_BEHINDERUNG_beheben"', '"BEHINDERUNG_beheben"')
data = data.replace('"BESTECHUND"', '"BESTECHUNG"')
data = data.replace('"Eine_BLAMAGE_gelingt"', '"BLAMAGE_gelingt"')
data = data.replace('"Einen_Bösen_befreien"', '"Bösen_befreien"')
data = data.replace('"Einen_Bösen_einstellen"', '"Bösen_einstellen"')
data = data.replace('"Eine_DEMÜTIGUNG_beheben"', '"DEMÜTIGUNG_beheben"')
data = data.replace('"Den_Einbrecher_begnadigen"', '"Einbrecher_begnadigen"')
data = data.replace('"Den_prächtigen_Palast_erhalten"', '"Prächtigen_Palast_erhalten"')
data = data.replace('"Den_Vorgang_deuten"', '"Vorgang_deuten"')
data = data.replace('"Der_RESPEKTLOSIGKEIT_entgegentreten"', '"RESPEKTLOSIGKEIT_entgegentreten"')
data = data.replace('"Der_Wechsel_der_IDENTITÄT_eingestehen"', '"Wechsel_der_IDENTITÄT_eingestehen"')
data = data.replace('"Die_Änderung_der_EXISTENZFORM"', '"Änderung_der_EXISTENZFORM"')
data = data.replace('"Die_Änderung_der_EXISTENZFORM_stören"', '"Änderung_der_EXISTENZFORM_stören"')
data = data.replace('"Die_Beschaffung_der_AUSRÜSTUNG"', '"Beschaffung_der_AUSRÜSTUNG"')
data = data.replace('"Die_Erbschaft_teilen"', '"Erbschaft_teilen"')
data = data.replace('"Die_FERNLIEBE_wird_ausgelöst"', '"FERNLIEBE_wird_ausgelöst"')
data = data.replace('"Die_Hilfsquelle_greift_zurück"', '"Hilfsquelle_greift_zurück"')
data = data.replace('"Die_potenzielle_Beute_begnadigen"', '"Potenzielle_Beute_begnadigen"')
data = data.replace('"Die_SCHÖNE_erfassen"', '"SCHÖNE_erfassen"')
data = data.replace('"Die_SCHÖNE_herbeiholen"', '"SCHÖNE_herbeiholen"')
data = data.replace('"Zum_STAUNEN_bringen"', '"EINDRUCKSVOLLE_Handlung"')
data = data.replace('"EINLADUNG_oder_BESTELLUNG"', '"EINLADUNG_oder_Bestellung"')
data = data.replace('"Magische_EMPFÄNGNISmittel_erfassen"', '"Wundermittel_zur_EMPFÄNGNIS_erfassen"')
data = data.replace('"Magische_EMPFÄNGNISmittel_erhalten"', '"Wundermittel_zur_EMPFÄNGNIS_erhalten"')
data = data.replace('"Magische_EMPFÄNGNISmittel_suchen"', '"Wundermittel_zur_EMPFÄNGNIS_suchen"')
data = data.replace('"Eine_ENTFÜHRUNG"', '"ENTFÜHRUNG"')
data = data.replace('"Eine_ENTFÜHRUNG_beheben"', '"ENTFÜHRUNG_beheben"')
data = data.replace('"ENTFÜHRUNG_beheben_in_Angriff_nehmen"', '"ENTFÜHRUNG_Beheben_angehen"')
data = data.replace('"ENTLARVEN"', '"ENTLARVUNG"')
data = data.replace('"ENTLARVEN_in_Angriff_nehmen"', '"ENTLARVUNG_angehen"')
data = data.replace('"Eine_Enttäuschung_ausgelöst"', '"Enttäuschung_ausgelöst"')
data = data.replace('"Die_ERNTE_verarbeiten"', '"ERNTE_verarbeiten"')
data = data.replace('"Die_ERNTE_verarbeiten_in_Angriff_nehmen"', '"ERNTE_Verarbeiten_angehen"')
data = data.replace('"Das_Geheimnis_der_EXTERNEN_SEELE_AUSSPIONIEREN"', '"EXTERNE_SEELE_Geheimnis_AUSSPIONIEREN"')
data = data.replace('"FALLE_stellen_beheben"', '"FALLE_Stellen_beheben"')
data = data.replace('"FELDER_BESTELLEN"', '"FELDER_bestellen"')
data = data.replace('"FELDER_BESTELLEN_in_Angriff_nehmen"', '"FELDER_Bestellen_angehen"')
data = data.replace('"Änderung_der_EXISTENZFORM_beheben"', '"Geänderte_EXISTENZFORM_beheben"')
data = data.replace('"Eine_Gefahr_VORTÄUSCHEN"', '"Gefahr_VORTÄUSCHEN"')
data = data.replace('"GEHEIMNIS_AUFKLÄREN"', '"GEHEIMNIS_aufklären"')
data = data.replace('"GEHEIMNIS_AUFKLÄREN_in_Angriff_nehmen"', '"GEHEIMNIS_Aufklären_angehen"')
data = data.replace('"GEHEIMZEICHEN_vermitteln"', '"GEHEIMSPRACHE_beibringen"')
data = data.replace('"Einem_Gemenge_entkommen"', '"Gemenge_entkommen"')
data = data.replace('"GIER_und_NEID_ausgelöst"', '"GIER_und_Neid_auslösen"')
data = data.replace('"Einen_gold_oder_geldproduzierenden_ZAUBERMITTEL_erhalten"', '"Gold_oder_geldproduzierenden_ZAUBERMITTEL_erhalten"')
data = data.replace('"Eine_HEIRATSABSICHT_kundtun"', '"HEIRATSABSICHT_kundtun"')
data = data.replace('"HOLZ_Sammeln_in_Angriff_nehmen"', '"HOLZ_Besorgen_angehen"')
data = data.replace('"Eine_BLAMAGE_bereiten"', '"LAMAGE_bereiten"')
data = data.replace('"Lösung_für_den_FÄHRMANN_deuten"', '"Lösungsweg_für_FÄHRMANN_deuten"')
data = data.replace('"Lösung_für_HEIRATSWILLIGE_deuten"', '"Lösungsweg_für_HEIRATSWILLIGE_deuten"')
data = data.replace('"Lösung_für_das_LEIDENDE_TIER_deuten"', '"Lösungsweg_für_leidendes_TIER_deuten"')
data = data.replace('"Lösung_für_SCHATZHÜTER_deuten"', '"Lösungsweg_für_SCHATZHÜTER_deuten"')
data = data.replace('"Lösung_für_SONSTIGES_LEID_deuten"', '"Lösungsweg_für_sonstiges_LEID_deuten"')
data = data.replace('"Kollaborationsbereitschaft_VORTÄUSCHEN"', '"Loyalität_VORTÄUSCHEN"')
data = data.replace('"Einen_magischen_EINGRIFF_vorbereiten"', '"Magischen_EINGRIFF_vorbereiten"')
data = data.replace('"Eine_numinose_Einmischung"', '"Numinose_Einmischung"')
data = data.replace('"Eine_numinose_Einmischung_VORTÄUSCHEN"', '"Numinose_Einmischung_VORTÄUSCHEN"')
data = data.replace('"Eine_OPFERGABE_verlangen"', '"OPFERGABE_verlangen"')
data = data.replace('"Das_Geheimnis_des_REITTIERs_AUSSPIONIEREN"', '"REITTIER_Geheimnis_AUSSPIONIEREN"')
data = data.replace('"RENDEZVOUS"', '"RENDEZVOUS_verabreden"')
data = data.replace('"SONSTIGE_AUFGABE_erledigen"', '"SONSTIGES_beheben"')
data = data.replace('"SONSTIGE_AUFGABE_in_Angriff_nehmen"', '"SONSTIGES_Beheben_angehen"')
data = data.replace('"Sonstiges_herstellen"', '"SONSTIGES_herstellen"')
data = data.replace('"Sonstiges_kaufen"', '"SONSTIGES_kaufen"')
data = data.replace('"Sonstiges_verkaufen"', '"SONSTIGES_verkaufen"')
data = data.replace('"Den_STALL_ausmisten"', '"STALL_ausmisten"')
data = data.replace('"Den_STALL_ausmisten_in_Angriff_nehmen"', '"STALL_Ausmisten_angehen"')
data = data.replace('"STERBEN_unabwendbar"', '"STERBEN"')
data = data.replace('"STERBEN_beheben_in_Angriff_nehmen"', '"STERBEN_Beheben_angehen"')
data = data.replace('"STREIT_SCHLICHTEN"', '"STREIT_schlichten"')
data = data.replace('"STREIT_SCHLICHTEN_in_Angriff_nehmen"', '"STREIT_Schlichten_angehen"')
data = data.replace('"Tiere_HÜTEN_in_Angriff_nehmen"', '"Tiere_HÜTEN_angehen"')
data = data.replace('"Tiere_MÄSTEN_in_Angriff_nehmen"', '"Tiere_MÄSTEN_angehen"')
data = data.replace('"Einem_TODESAUFTRAG_entkommen"', '"TODESAUFTRAG_entkommen"')
data = data.replace('"Töte_zu_lebenden_VORTÄUSCHEN"', '"Toten_als_lebend_VORTÄUSCHEN"')
data = data.replace('"TREUEN_HELFER_finden"', '"Treuen_Helfer_finden"')
data = data.replace('"Eine_VEREINBARUNG_einhalten"', '"VEREINBARUNG_einhalten"')
data = data.replace('"SÜNDERFALL"', '"VERSUCHUNG"')
data = data.replace('"VORHERSAGE_Fluch"', '"VORHERSAGE_als_Fluch"')
data = data.replace('"VORHERSAGE_Unglück_vom_Anziehen"', '"VORHERSAGE_Gefahr_vom_Anziehen"')
data = data.replace('"VORHERSAGE_Unglück_vom_Juwelier"', '"VORHERSAGE_Gefahr_vom_Juwelier"')
data = data.replace('"VORHERSAGE_Unglück_vom_Haustier"', '"VORHERSAGE_Gefahr_vom_Tier"')
data = data.replace('"VORHERSAGE_Unglück_vom_Wild"', '"VORHERSAGE_Gefahr_vom_Wild"')
data = data.replace('"VORHERSAGE_Unglück_von_der_Angehörigen"', '"VORHERSAGE_Gefahr_von_Angehörigen"')
data = data.replace('"VORHERSAGE_Unglück_vom_Essen_und_Trinken"', '"VORHERSAGE_Gefahr_von_Essen_und_Trinken"')
data = data.replace('"VORHERSAGE_subtile_Eigenschaft"', '"VORHERSAGE_subtiler_Eigenschaft"')
data = data.replace('"VORHERSAGE_subtile_Identität"', '"VORHERSAGE_subtiler_Identität"')
data = data.replace('"Die_VORHERSAGE_tritt_ein"', '"VORHERSAGE_tritt_ein"')
data = data.replace('"VORHERSAGE_ungewünschte_Heiraten"', '"VORHERSAGE_ungewünschter_Eheschliessung"')
data = data.replace('"ABSURDITÄT_glaubhaft_zu_halten_VORTÄUSCHEN"', '"VORTÄUSCHEN_ABSURDITÄT_zu_glauben"')
data = data.replace('"Das_VORTÄUSCHEN_eingestehen"', '"VORTÄUSCHEN_eingestehen"')
data = data.replace('"WAFFE_ZAUBERMITTEL_erfassen"', '"WAFFE_oder_ZAUBERMITTEL_erfassen"')
data = data.replace('"WAFFE_ZAUBERMITTEL_erhalten"', '"WAFFE_oder_ZAUBERMITTEL_erhalten"')
data = data.replace('"WETTBEWERB_in_Angriff_nehmen"', '"WETTBEWERB_angehen"')
data = data.replace('"WETTE_in_Angriff_nehmen"', '"WETTE_angehen"')
data = data.replace('"WETTE_Glück_oder_Verstand"', '"WETTE_zwischen_Glück_und_Verstand"')
data = data.replace('"WETTKAMPF_in_Angriff_nehmen"', '"WETTKAMPF_angehen"')
data = data.replace('"WETTLAUF_in_Angriff_nehmen"', '"WETTLAUF_angehen"')
data = data.replace('"WIEDERBELEBEN_in_Angriff_nehmen"', '"WIEDERBELEBEN_angehen"')
data = data.replace('"Das_Geheimnis_des_ZAUBERMITTELs_AUSSPIONIEREN"', '"ZAUBERMITTEL_Geheimnis_AUSSPIONIEREN"')
data = data.replace('"ZOLLERHEBUNG_in_Angriff_nehmen"', '"ZOLLERHEBUNG_Vollstrecken_angehen"')


# Geänderte Inhalte in derselben Datei speichern
with open(DTN, 'w', encoding='utf-8') as file:
    file.write(data)
