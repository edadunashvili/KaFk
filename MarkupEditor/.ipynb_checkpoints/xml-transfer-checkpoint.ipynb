# %%
#Dieser Editor kann fürs Ersetzen (replace) der Markupwerte sowohl in XML als auch XSD Dateien eingesetzt werden. 
#Entsprechend der Aufgabe sollen auch die Namen von input und output Dateien definiert werden
#Die entsprechend benannte Dateien sollen in jeweiligen Ordner eingefügt und eingesetzt werden
fin = open('input.xml','r', encoding ='utf-8') #Statt Sternchen tragen Sie den Name ihrer XML Inputdatei ein
fout = open('output.xml', "wt", encoding ='utf-8') #Statt Sternchen tragen Sie den Name ihrer XML Outputdatei ein
for kfz in fin:
    fout.write(kfz.replace('"ABRATEN_von_der_Mission"', '"Abraten_von_der_MISSION"')
.replace('"Beglaubigen_der_Behauptung_der_ABSURDITÄT"', '"ABSURDITÄT_beglaubigen"')
.replace('"Behauptung_der_ABSURDITÄT"', '"ABSURDITÄT_behaupten"')
.replace('"Der_ABSURDITÄT_entgegentreten"', '"ABSURDITÄT_entgegentreten"')
.replace('"AMUSEMENT"', '"AMÜSEMENT"')
.replace('"Sich_ANEIGNEN"', '"ANEIGNUNG"')
.replace('"ANEIGNEN_beheben"', '"ANEIGNUNG_beheben"')
.replace('"ANEIGNEN_beheben_in_Angriff_nehmen"', '"ANEIGNUNG_Beheben_angehen"')
.replace('"Angebot_GEOPFERT_ZU_WERDEN"', '"Angebot_GEOPFERT_zu_werden"')
.replace('"Angebot_KÖNIG_ZU_WERDEN"', '"Angebot_KÖNIG_zu_werden"')
.replace('"Schrecken_ausgelöst"', '"ANGST_auslösen"')
.replace('"Angst_mit_Angst_vergelten"', '"ANGST_mit_ANGST_vergelten"')
.replace('"Verdreht_interpretieren"', '"Anweisung_wörtlich_nehmen"')
.replace('"Dem_ABRATEN_von_der_Mission_nachgehen"', '"Auf_ABRATEN_von_der_Mission_reagieren"')
.replace('"ABSURDITÄT_nachgehen"', '"Auf_ABSURDITÄT_reagieren"')
.replace('"Den_ALTERNATIVEN_nachgehen"', '"Auf_ALTERNATIVEN_reagieren"')
.replace('"Angebot_GEOPFERT_ZU_WERDEN_nachgehen"', '"Auf_Angebot_GEOPFERT_zu_werden_reagieren"')
.replace('"Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen"', '"Auf_Angebot_KÖNIG_zu_werden_reagieren"')
.replace('"Den_GIER_und_NEID_nachgehen"', '"Auf_Anreiz_zu_GIER_und_Neid_reagieren"')
.replace('"Dem_AMUSEMENT_nachgehen"', '"Auf_Anreiz_zum_AMÜSEMENT_reagieren"')
.replace('"KINDERMORD_nachgehen"', '"Auf_Aufforderung_zu_KINDERMORD_reagieren"')
.replace('"Der_NEUGIER_nachgehen"', '"Auf_ausgelöste_NEUGIER_reagieren"')
.replace('"BESTECHUND_nachgehen"', '"Auf_BESTECHUNG_reagieren"')
.replace('"Dem_STAUNEN_nachgehen"', '"Auf_EINDRUCKSVOLLE_Handlung_reagieren"')
.replace('"Einer_EINLADUNG_oder_BESTELLUNG_nachgehen"', '"Auf_EINLADUNG_oder_Bestellung_reagieren"')
.replace('"Dem_GEHEIMZEICHEN_nachgehen"', '"Auf_GEHEIMSPRACHE_reagieren"')
.replace('"Der_HEIRATSABSICHT_nachgehen"', '"Auf_HEIRATSABSICHT_reagieren"')
.replace('"Lösung_für_den_FÄHRMANN_nachgehen"', '"Auf_Lösungsweg_für_FÄHRMANN_reagieren"')
.replace('"Lösung_für_HEIRATSWILLIGE_nachgehen"', '"Auf_Lösungsweg_für_HEIRATSWILLIGE_reagieren"')
.replace('"Lösung_für_das_LEIDENDE_TIER_nachgehen"', '"Auf_Lösungsweg_für_leidendes_TIER_reagieren"')
.replace('"Lösung_für_SCHATZHÜTERN_nachgehen"', '"Auf_Lösungsweg_für_SCHATZHÜTERN_reagieren"')
.replace('"Lösung_für_SONSTIGES_LEID_nachgehen"', '"Auf_Lösungsweg_für_sonstiges_LEID_reagieren"')
.replace('"Der_PROVOKATION_nachgehen"', '"Auf_PROVOKATION_reagieren"')
.replace('"TABU_nachgehen"', '"Auf_TABU_reagieren"')
.replace('"RENDEZVOUS_nachgehen"', '"Auf_verabredetes_RENDEZVOUS_reagieren"')
.replace('"Der_VERLOCKUNG_nachgehen"', '"Auf_VERLOCKUNG_reagieren"')
.replace('"SÜNDERFALL_nachgehen"', '"Auf_VERSUCHUNG_reagieren"')
.replace('"Der_VORHERSAGE_nachgehen"', '"Auf_VORHERSAGE_reagieren"')
.replace('"Dem_VORTÄUSCHEN_nachgehen"', '"Auf_VORTÄUSCHEN_reagieren"')
.replace('"Einer_Warnung_im_STICH_gelassen_zu_werden_nachgehen"', '"Auf_Warnung_im_STICH_gelassen_zu_werden_reagieren"')
.replace('"Einer_Warnung_vor_KANNIBALISMUS_nachgehen"', '"Auf_Warnung_vor_KANNIBALISMUS_reagieren"')
.replace('"Einer_Warnung_vor_VERGIFTUNG_nachgehen"', '"Auf_Warnung_vor_VERGIFTUNG_reagieren"')
.replace('"WEISHEITEN_nachgehen"', '"Auf_WEISHEITEN_reagieren"')
.replace('"Dem_WERBEN_nachgehen"', '"Auf_WERBEN_reagieren"')
.replace('"Eines_auffälligen_GEGENSTANDES_habhaft_werden"', '"Auffälliges_GEGENSTANDES_habhaft_werden"')
.replace('"AUSSPIONIEREN_in_Angriff_nehmen"', '"AUSSPIONIEREN_angehen"')
.replace('"Eine_Bedrohung_VORTÄUSCHEN"', '"Bedrohung_VORTÄUSCHEN"')
.replace('"Einen_Begleiter_gewinnen"', '"Begleiter_gewinnen"')
.replace('"Eine_BEHINDERUNG_beheben"', '"BEHINDERUNG_beheben"')
.replace('"BESTECHUND"', '"BESTECHUNG"')
.replace('"Eine_BLAMAGE_gelingt"', '"BLAMAGE_gelingt"')
.replace('"Einen_Bösen_befreien"', '"Bösen_befreien"')
.replace('"Einen_Bösen_einstellen"', '"Bösen_einstellen"')
.replace('"Eine_DEMÜTIGUNG_beheben"', '"DEMÜTIGUNG_beheben"')
.replace('"Den_Einbrecher_begnadigen"', '"Einbrecher_begnadigen"')
.replace('"Den_prächtigen_Palast_erhalten"', '"Prächtigen_Palast_erhalten"')
.replace('"Den_Vorgang_deuten"', '"Vorgang_deuten"')
.replace('"Der_RESPEKTLOSIGKEIT_entgegentreten"', '"RESPEKTLOSIGKEIT_entgegentreten"')
.replace('"Der_Wechsel_der_IDENTITÄT_eingestehen"', '"Wechsel_der_IDENTITÄT_eingestehen"')
.replace('"Die_Änderung_der_EXISTENZFORM"', '"Änderung_der_EXISTENZFORM"')
.replace('"Die_Änderung_der_EXISTENZFORM_stören"', '"Änderung_der_EXISTENZFORM_stören"')
.replace('"Die_Beschaffung_der_AUSRÜSTUNG"', '"Beschaffung_der_AUSRÜSTUNG"')
.replace('"Die_Erbschaft_teilen"', '"Erbschaft_teilen"')
.replace('"Die_FERNLIEBE_wird_ausgelöst"', '"FERNLIEBE_wird_ausgelöst"')
.replace('"Die_Hilfsquelle_greift_zurück"', '"Hilfsquelle_greift_zurück"')
.replace('"Die_potenzielle_Beute_begnadigen"', '"Potenzielle_Beute_begnadigen"')
.replace('"Die_SCHÖNE_erfassen"', '"SCHÖNE_erfassen"')
.replace('"Die_SCHÖNE_herbeiholen"', '"SCHÖNE_herbeiholen"')
.replace('"Zum_STAUNEN_bringen"', '"EINDRUCKSVOLLE_Handlung"')
.replace('"EINLADUNG_oder_BESTELLUNG"', '"EINLADUNG_oder_Bestellung"')
.replace('"Magische_EMPFÄNGNISmittel_erfassen"', '"Wundermittel_zur_EMPFÄNGNIS_erfassen"')
.replace('"Magische_EMPFÄNGNISmittel_erhalten"', '"Wundermittel_zur_EMPFÄNGNIS_erhalten"')
.replace('"Magische_EMPFÄNGNISmittel_suchen"', '"Wundermittel_zur_EMPFÄNGNIS_suchen"')
.replace('"Eine_ENTFÜHRUNG"', '"ENTFÜHRUNG"')
.replace('"Eine_ENTFÜHRUNG_beheben"', '"ENTFÜHRUNG_beheben"')
.replace('"ENTFÜHRUNG_beheben_in_Angriff_nehmen"', '"ENTFÜHRUNG_Beheben_angehen"')
.replace('"ENTLARVEN"', '"ENTLARVUNG"')
.replace('"ENTLARVEN_in_Angriff_nehmen"', '"ENTLARVUNG_angehen"')
.replace('"Eine_Enttäuschung_ausgelöst"', '"Enttäuschung_ausgelöst"')
.replace('"Die_ERNTE_verarbeiten"', '"ERNTE_verarbeiten"')
.replace('"Die_ERNTE_verarbeiten_in_Angriff_nehmen"', '"ERNTE_Verarbeiten_angehen"')
.replace('"Das_Geheimnis_der_EXTERNEN_SEELE_AUSSPIONIEREN"', '"EXTERNE_SEELE_Geheimnis_AUSSPIONIEREN"')
.replace('"FALLE_stellen_beheben"', '"FALLE_Stellen_beheben"')
.replace('"FELDER_BESTELLEN"', '"FELDER_bestellen"')
.replace('"FELDER_BESTELLEN_in_Angriff_nehmen"', '"FELDER_Bestellen_angehen"')
.replace('"Änderung_der_EXISTENZFORM_beheben"', '"Geänderte_EXISTENZFORM_beheben"')
.replace('"Eine_Gefahr_VORTÄUSCHEN"', '"Gefahr_VORTÄUSCHEN"')
.replace('"GEHEIMNIS_AUFKLÄREN"', '"GEHEIMNIS_aufklären"')
.replace('"GEHEIMNIS_AUFKLÄREN_in_Angriff_nehmen"', '"GEHEIMNIS_Aufklären_angehen"')
.replace('"GEHEIMZEICHEN_vermitteln"', '"GEHEIMSPRACHE_beibringen"')
.replace('"Einem_Gemenge_entkommen"', '"Gemenge_entkommen"')
.replace('"GIER_und_NEID_ausgelöst"', '"GIER_und_Neid_auslösen"')
.replace('"Einen_gold_oder_geldproduzierenden_ZAUBERMITTEL_erhalten"', '"Gold_oder_geldproduzierenden_ZAUBERMITTEL_erhalten"')
.replace('"Eine_HEIRATSABSICHT_kundtun"', '"HEIRATSABSICHT_kundtun"')
.replace('"HOLZ_Sammeln_in_Angriff_nehmen"', '"HOLZ_Besorgen_angehen"')
.replace('"Eine_BLAMAGE_bereiten"', '"LAMAGE_bereiten"')
.replace('"Lösung_für_den_FÄHRMANN_deuten"', '"Lösungsweg_für_FÄHRMANN_deuten"')
.replace('"Lösung_für_HEIRATSWILLIGE_deuten"', '"Lösungsweg_für_HEIRATSWILLIGE_deuten"')
.replace('"Lösung_für_das_LEIDENDE_TIER_deuten"', '"Lösungsweg_für_leidendes_TIER_deuten"')
.replace('"Lösung_für_SCHATZHÜTER_deuten"', '"Lösungsweg_für_SCHATZHÜTER_deuten"')
.replace('"Lösung_für_SONSTIGES_LEID_deuten"', '"Lösungsweg_für_sonstiges_LEID_deuten"')
.replace('"Kollaborationsbereitschaft_VORTÄUSCHEN"', '"Loyalität_VORTÄUSCHEN"')
.replace('"Einen_magischen_EINGRIFF_vorbereiten"', '"Magischen_EINGRIFF_vorbereiten"')
.replace('"Eine_numinose_Einmischung"', '"Numinose_Einmischung"')
.replace('"Eine_numinose_Einmischung_VORTÄUSCHEN"', '"Numinose_Einmischung_VORTÄUSCHEN"')
.replace('"Eine_OPFERGABE_verlangen"', '"OPFERGABE_verlangen"')
.replace('"Das_Geheimnis_des_REITTIERs_AUSSPIONIEREN"', '"REITTIER_Geheimnis_AUSSPIONIEREN"')
.replace('"RENDEZVOUS"', '"RENDEZVOUS_verabreden"')
.replace('"SONSTIGE_AUFGABE_erledigen"', '"SONSTIGES_beheben"')
.replace('"SONSTIGE_AUFGABE_in_Angriff_nehmen"', '"SONSTIGES_Beheben_angehen"')
.replace('"Sonstiges_herstellen"', '"SONSTIGES_herstellen"')
.replace('"Sonstiges_kaufen"', '"SONSTIGES_kaufen"')
.replace('"Sonstiges_verkaufen"', '"SONSTIGES_verkaufen"')
.replace('"Den_STALL_ausmisten"', '"STALL_ausmisten"')
.replace('"Den_STALL_ausmisten_in_Angriff_nehmen"', '"STALL_Ausmisten_angehen"')
.replace('"STERBEN_unabwendbar"', '"STERBEN"')
.replace('"STERBEN_beheben_in_Angriff_nehmen"', '"STERBEN_Beheben_angehen"')
.replace('"STREIT_SCHLICHTEN"', '"STREIT_schlichten"')
.replace('"STREIT_SCHLICHTEN_in_Angriff_nehmen"', '"STREIT_Schlichten_angehen"')
.replace('"Tiere_HÜTEN_in_Angriff_nehmen"', '"Tiere_HÜTEN_angehen"')
.replace('"Tiere_MÄSTEN_in_Angriff_nehmen"', '"Tiere_MÄSTEN_angehen"')
.replace('"Einem_TODESAUFTRAG_entkommen"', '"TODESAUFTRAG_entkommen"')
.replace('"Töte_zu_lebenden_VORTÄUSCHEN"', '"Toten_als_lebend_VORTÄUSCHEN"')
.replace('"TREUEN_HELFER_finden"', '"Treuen_Helfer_finden"')
.replace('"Eine_VEREINBARUNG_einhalten"', '"VEREINBARUNG_einhalten"')
.replace('"SÜNDERFALL"', '"VERSUCHUNG"')
.replace('"VORHERSAGE_Fluch"', '"VORHERSAGE_als_Fluch"')
.replace('"VORHERSAGE_Unglück_vom_Anziehen"', '"VORHERSAGE_Gefahr_vom_Anziehen"')
.replace('"VORHERSAGE_Unglück_vom_Juwelier"', '"VORHERSAGE_Gefahr_vom_Juwelier"')
.replace('"VORHERSAGE_Unglück_vom_Haustier"', '"VORHERSAGE_Gefahr_vom_Tier"')
.replace('"VORHERSAGE_Unglück_vom_Wild"', '"VORHERSAGE_Gefahr_vom_Wild"')
.replace('"VORHERSAGE_Unglück_von_der_Angehörigen"', '"VORHERSAGE_Gefahr_von_Angehörigen"')
.replace('"VORHERSAGE_Unglück_vom_Essen_und_Trinken"', '"VORHERSAGE_Gefahr_von_Essen_und_Trinken"')
.replace('"VORHERSAGE_subtile_Eigenschaft"', '"VORHERSAGE_subtiler_Eigenschaft"')
.replace('"VORHERSAGE_subtile_Identität"', '"VORHERSAGE_subtiler_Identität"')
.replace('"Die_VORHERSAGE_tritt_ein"', '"VORHERSAGE_tritt_ein"')
.replace('"VORHERSAGE_ungewünschte_Heiraten"', '"VORHERSAGE_ungewünschter_Eheschliessung"')
.replace('"ABSURDITÄT_glaubhaft_zu_halten_VORTÄUSCHEN"', '"VORTÄUSCHEN_ABSURDITÄT_zu_glauben"')
.replace('"Das_VORTÄUSCHEN_eingestehen"', '"VORTÄUSCHEN_eingestehen"')
.replace('"WAFFE_ZAUBERMITTEL_erfassen"', '"WAFFE_oder_ZAUBERMITTEL_erfassen"')
.replace('"WAFFE_ZAUBERMITTEL_erhalten"', '"WAFFE_oder_ZAUBERMITTEL_erhalten"')
.replace('"WETTBEWERB_in_Angriff_nehmen"', '"WETTBEWERB_angehen"')
.replace('"WETTE_in_Angriff_nehmen"', '"WETTE_angehen"')
.replace('"WETTE_Glück_oder_Verstand"', '"WETTE_zwischen_Glück_und_Verstand"')
.replace('"WETTKAMPF_in_Angriff_nehmen"', '"WETTKAMPF_angehen"')
.replace('"WETTLAUF_in_Angriff_nehmen"', '"WETTLAUF_angehen"')
.replace('"WIEDERBELEBEN_in_Angriff_nehmen"', '"WIEDERBELEBEN_angehen"')
.replace('"Das_Geheimnis_des_ZAUBERMITTELs_AUSSPIONIEREN"', '"ZAUBERMITTEL_Geheimnis_AUSSPIONIEREN"')
.replace('"ZOLLERHEBUNG_in_Angriff_nehmen"', '"ZOLLERHEBUNG_Vollstrecken_angehen"')

    )
fin.close()
fout.close()
