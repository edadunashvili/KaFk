# %% [markdown]
# # TextClass (inkl. für mehrere Werte)

# %%
import xml.etree.ElementTree as ET

# XML-Datei laden und Wurzel abrufen
root_node = ET.parse('gesamt_märchen.xml').getroot()

# Namespace definieren
NS = {'tei': 'http://www.tei-c.org/ns/1.0'}
filter_ident = "rus"  # Kann auf "" gesetzt werden, um keinen Filter anzuwenden
unique_schema_set = set()

# Durchlaufen des XML-Baums
for corp in root_node.findall(".//tei:teiCorpus", NS):
    if ("tg" in corp.attrib.get("n", "") or "xtk" in corp.attrib.get("n", "")):
        for ganze in corp.findall(".//tei:TEI", NS):
            language = ganze.find(".//tei:teiHeader//tei:langUsage/tei:language", NS)
            # Bedingung für Sprache: anwenden, wenn filter_ident definiert ist, oder überspringen
            if language is not None and (not filter_ident or language.attrib.get('ident') == filter_ident):
                for text in ganze.findall(".//tei:text", NS):
                    if "" in text.attrib['{http://www.w3.org/XML/1998/namespace}id']:  
                        for segm in text.findall(".//tei:seg", NS):
                            tn = segm.attrib.get('{www.dglab.uni-jena.de/vmf/a}ana', '')
                            if "a300" in tn:  # Sicherstellen, dass `tn` das gesuchte Muster enthält
                                chisch = text.attrib.get('{http://www.w3.org/XML/1998/namespace}id', '')
                                if chisch:
                                    unique_schema_set.add(chisch)

# Ergebnisse in Datei schreiben
with open("TextClass.txt", 'w', encoding='utf-8') as f:
    f.write(str(sorted(unique_schema_set)))

# %%
import ast
import xml.etree.ElementTree as ET

def setze_variable_aus_datei(dateiname: str, variablenname: str):
    try:
        with open(dateiname, "r", encoding="utf-8") as datei:
            inhalt = datei.read().strip()
        wert = ast.literal_eval(inhalt)
        globals()[variablenname] = wert
        return wert
    except Exception as e:
        print(f"Fehler beim Einlesen und Setzen der Variable: {e}")
        return None

# 1. Mehrere `chisch`-Werte definieren
chisch = setze_variable_aus_datei("TextClass.txt", "chisch")

# Überprüfen, ob die Variable korrekt gesetzt wurde
print(chisch)
# Out:
# ['zyx_cc_ddo_rus_26ß', 'zyx_cc_ddo_rus_55ß', 'zyx_cc_ddo_rus_72ß', 'zyx_cr_agx_rus_2ß', 'zyx_cr_ava_rus_110ß', 'zyx_cr_ava_rus_176ß', 'zyx_cr_ava_rus_2ß', 'zyx_cr_ava_rus_8ß', 'zyx_cr_dar_rus_5ß', 'zyx_cr_dar_rus_89ß', 'zyx_cr_dar_rus_8ß', 'zyx_cr_khv_rus_17ß', 'zyx_cr_lez_rus_1ß', 'zyx_cr_lez_rus_29ß', 'zyx_cr_nog_rus_17ß']

# %%
import os
import pandas as pd
import xml.etree.ElementTree as ET

# Modul zur Speicherung in einer zentralen Textdatei
def speichere_gesamt_ergebnisse(dateiname, daten):
    """
    Speichert die Gesamtergebnisse in eine Textdatei.
    
    :param dateiname: Name der Textdatei
    :param daten: Ergebnisse in Form eines Dictionaries {chisch: [Daten]}
    """
    with open(dateiname, 'w', encoding='utf-8') as f:
        for ch, ergebnisse in daten.items():
            f.write(f"\n{ch}:\n")
            for zeile in ergebnisse:
                f.write(f"{zeile}\n")

# Mehrere `chisch`-Werte definieren
chisch = setze_variable_aus_datei("TextClass.txt", "chisch")
# chisch = ['zyx_cr_lbe_rus_43'] # 1.1. Alternativ: Einen chisch-Wert eingeben

root_node = ET.parse('gesamt_märchen.xml').getroot()

# Speichern der Märchendaten für jedes `chisch`
maerchen_daten = {ch: "" for ch in chisch}

# 2. Schleife für jeden `chisch`-Wert in der Liste
for ch in chisch:
    for ganze in root_node.findall(".//{http://www.tei-c.org/ns/1.0}text"):
        if ganze.attrib.get('{http://www.w3.org/XML/1998/namespace}id') == ch:
            for body in ganze.findall(".//{http://www.tei-c.org/ns/1.0}body"):
                for absatz in body.findall(".//{http://www.tei-c.org/ns/1.0}p"):
                    for phrase in absatz.findall(".//{http://www.tei-c.org/ns/1.0}seg"):
                        try:
                            # Extrahieren der relevanten Attribute
                            labela = phrase.attrib['{www.dglab.uni-jena.de/vmf/a}ana']
                            labelb1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b1}ana', 'N')
                            labelb2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b2}ana', 'N')
                            labelb3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b3}ana', 'N')
                            labelb4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b4}ana', 'N')
                            labelb5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/b5}ana', 'N')
                            labelc1 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c1}ana', 'N')
                            labelc2 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c2}ana', 'N')
                            labelc3 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c3}ana', 'N')
                            labelc4 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c4}ana', 'N')
                            labelc5 = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/c5}ana', 'N')
                            labeld = phrase.attrib.get('{www.dglab.uni-jena.de/vmf/d}ana', 'N')
                            quelle = ganze.attrib['{http://www.w3.org/XML/1998/namespace}id']  
                            inhalt = (phrase.text.lower().strip()
                                      .replace('|','').replace(':','').replace("ä","ae").replace("ü","ue")
                                      .replace("ö","oe").replace("ß","ss").replace(",","" ).replace("«","")
                                      .replace("»","" ).replace(".","" ).replace(";","" ).replace('"',"")
                                      .replace("?","" ).replace("!","" ).replace("-"," " ).replace("'", "")
                                      .replace("(", "" ).replace(")", "" ).replace("\n","" ).replace("  ", " "))
                            if labela.startswith('a'):
                                # Speichern der Märchendaten in der entsprechenden `chisch`-Liste
                                maerchen_daten[ch] += f"{quelle},{labela},{labelb1},{labelc1},{labelb2},{labelc2},{labelb3},{labelc3},{labelb4},{labelc4},{labelb5},{labelc5},{labeld},{inhalt},0\n"
                        except KeyError as e:
                            print(f"Fehlendes Attribut: {e}")

# 3. Ausgabestruktur für jeden `chisch`-Wert erstellen
gesamt_ergebnisse = {}

# Erstellen der CSV-Dateien und Verarbeiten der Daten
unique_values_per_ch = {}
result_data_per_ch = {}
for ch in chisch:
    # CSV-Datei erstellen
    with open(f"text_{ch}.csv", 'w', encoding='utf-8') as f:
        f.write('quelle,labela,labelb1,labelc1,labelb2,labelc2,labelb3,labelc3,labelb4,labelc4,labelb5,labelc5,labeld,inhalt,index_binar\n')
        f.write(maerchen_daten[ch])

    # Index-Strings erstellen
    abcd_data = []
    df = pd.read_csv(f"text_{ch}.csv", encoding='utf-8')

    for index, row in df.iterrows():
        quelle = row['quelle']
        labela = row['labela']
        for i in range(1, 6):
            labelb = row[f'labelb{i}']
            labelc = row[f'labelc{i}']
            labeld = row['labeld']
            inhalt = row['inhalt']
            abcd_data.append(f"{labela}:{labelb}:{labelc}:{labeld}")

    # Filterung der Daten
    filtered_data = [line for line in abcd_data if ':N:' not in line]

    # Extrahieren einzigartiger Werte vor dem ersten ':'
    unique_values = set(line.split(':')[0] for line in filtered_data)
    unique_values_per_ch[ch] = unique_values
    result_data_per_ch[ch] = filtered_data

    # Speichern der gefilterten Daten in der Gesamt-Ausgabeliste
    gesamt_ergebnisse[ch] = filtered_data

# Zählen der `chisch`-Werte mit und ohne Ergebnisse
chisch_mit_ergebnissen = [ch for ch, ergebnisse in gesamt_ergebnisse.items() if ergebnisse]
chisch_ohne_ergebnisse = [ch for ch, ergebnisse in gesamt_ergebnisse.items() if not ergebnisse]

print(f"Anzahl der chisch-Werte mit Ergebnissen: {len(chisch_mit_ergebnissen)}")
print(f"Anzahl der chisch-Werte ohne Ergebnisse: {len(chisch_ohne_ergebnisse)}")

# Parsen der `fk/vmf_a.xsd`-Datei und Überprüfen von Werten mit Leerzeichen
fk_tree = ET.parse('kf/vmf_a.xsd').getroot()
enum_elements = fk_tree.findall(".//{http://www.w3.org/2001/XMLSchema}enumeration")
enum_values_with_spaces = {enum.attrib['value'] for enum in enum_elements if ' ' in enum.attrib['value']}

# Ausgabe der Ergebnisse
for ch, unique_values in unique_values_per_ch.items():
    print(f"\n\n{ch}")
    print("-----------------")
    matching_values = [
    value for value in enum_values_with_spaces 
    if any(value.split(' ')[0] == uval for uval in unique_values)
]
    print(*matching_values, sep='\n')
    print("-----------------")

    # Ergebnisse mit Werten anzeigen
    if ch in result_data_per_ch:
        #print("Gefilterte Ergebnisse:")
        for result in result_data_per_ch[ch]:
            print(result)

# Speichern in einer Textdatei
speichere_gesamt_ergebnisse("TextClassaLaufende.txt", gesamt_ergebnisse)

# Löschen der erstellten CSV-Dateien
for ch in chisch:
    try:
        os.remove(f"text_{ch}.csv")  # Löschen der CSV-Datei
    except FileNotFoundError:
        print(f"Datei text_{ch}.csv wurde nicht gefunden und konnte nicht gelöscht werden.")
    except Exception as e:
        print(f"Fehler beim Löschen der Datei text_{ch}.csv: {e}")
# Out:
# Anzahl der chisch-Werte mit Ergebnissen: 15
# Anzahl der chisch-Werte ohne Ergebnisse: 0
#
#
# zyx_cc_ddo_rus_26ß
# -----------------
# a300 Der Drachentöter
# a982 Die vorgetäuschte Erbschaft
# a301 Die drei geraubten Prinzesinnen
# -----------------
# a982:f:Reiche_Erbschaft_VORTÄUSCHEN:rHH
# a982:h:Tod_von_Angehörigen:rHH
# a982:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fHD
# a982:F:Erträumen:rHD_rHH_fHD
# a982:F:Wache_halten:rHD_rHH_fHD
# a982:Hh:Wache_halten:fHD
# a982:H:Wache_halten:rHD_rST
# a982:H:Wegweisung_erpressen:rHD_rST
# a982:Hh:Wache_halten:rHD_rST
# a982:H:Wegweisung_erpressen:rHD_rST
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Zweikampf:rHD_rAN
# a300:f:Kollaborationsbereitschaft_VORTÄUSCHEN:rHD_rAN
# a300:f:VERGIFTUNG:rHD_rAN
# a300:H:Dem_VORTÄUSCHEN_nachgehen:rHD_fZM
# a300:H:VERGIFTUNG_beheben:rHD_fZM
# a300:H:Menschliche_OPFERGABE_beheben:rHD_rPP
# a300:h:KONTAKT_abbrechen:rHD_rPP
# a300:F:NEUGIER_ausgelöst:rVB_rHP
# a300:HF:Information_aus_zweiter_Hand:rVB_rHP
# a300:H:Der_NEUGIER_nachgehen:rVB_rHP
# a300:F:EINLADUNG:rVB_rHP
# a300:f:Heldentat_VORTÄUSCHEN:rHD_rHP_fHD
# a300:H:Einer_EINLADUNG_nachgehen:rHD_rHP_fHD
# a300:F:IDENTITÄT_beweisen:rHD_rHP_fHD
# a300:H:IDENTITÄT_beweisen:rHD_rHP_fHD
# a300:H:KONTAKT_wiederherstellen:rHD_rHP_fHD
# a300:F:Heiraten:rHD_rHP
# a300:h:Heiraten:rHD_rHP
# a300:H:Um_GEGENLEISTUNG_bitten:rHD_rHP
# a300:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rHP
# a300:h:Den_ALTERNATIVEN_nachgehen:rHD_rZM
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:MASSENBEDROHUNG_beheben:rHD_rVB
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Sorge_um_Schutzbedürftige:rHD_rST
# a300:F:Angebot_KÖNIG_ZU_WERDEN:rHD_rHP
# a300:h:Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen:rHD_rHP
# a300:F:Um_GEGENLEISTUNG_bitten:rHD_rHP
# a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP
# a300:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a300:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHP
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a300:H:Sorge_um_Mitleidsbedürftige:rHD_rHF
# a300:H:Eine_BEHINDERUNG_beheben:rHD_rHF
# a301:H:Krisenursachen_ergründen:rHD_rPP
# a301:F:Eine_ENTFÜHRUNG_beheben:rHD_rPP
# a301:HF:ABRATEN_von_der_Mission:rHD_rPP
# a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a301:H:Mut_zeigen:rHD_rAN
# a301:HF:Zweikampf:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:H:Auf_dem_Heimweg:N
# a301:F:Angebot_KÖNIG_ZU_WERDEN:N
# a301:h:Dem_Angebot_KÖNIG_ZU_WERDEN_nachgehen:N
#
#
# zyx_cc_ddo_rus_55ß
# -----------------
# a300 Der Drachentöter
# a650A Starker Hans
# -----------------
# a650A:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHH_fHH
# a650A:h:Eine_ENTFÜHRUNG:rHH_fHH
# a650A:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHH
# a650A:H:Zur_Welt_kommen:rHD_rHH
# a300:h:WASSERMANGEL:rAN
# a300:h:Eine_OPFERGABE_verlangen:rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
#
#
# zyx_cc_ddo_rus_72ß
# -----------------
# a300 Der Drachentöter
# a530 Prinzessin auf dem Glasberg
# a550 Vogel Pferd und Koenigstochter
# -----------------
# a530:F:Wache_halten:rHH
# a530:h:Tod_von_Angehörigen:rHH
# a530:h:Wache_halten:fHD
# a530:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a530:F:Reitkünste_zeigen:rHP
# a530:h:Reitkünste_zeigen:fHD
# a530:h:RESPEKTLOSIGKEIT:rHD_fHD
# a530:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a530:H:REITTIER_erhalten:rHD_rHF
# a530:H:Prächtige_Kleidung_und_Schmuck_erhalten:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Reitkünste_zeigen:rHD_rHF
# a530:H:Die_SCHÖNE_erfassen:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:F:NEUGIER_ausgelöst:rHD_fHD
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Reitkünste_zeigen:rHD_rHF
# a530:H:Die_SCHÖNE_erfassen:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:F:NEUGIER_ausgelöst:rHD_fHD
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Reitkünste_zeigen:rHD_rHF
# a530:H:Die_SCHÖNE_erfassen:rHD_rHF
# a530:H:IDENTITÄT_ändern:rHD_rHF
# a530:H:Den_Vorgang_deuten:rHD_fHD
# a530:H:Der_Wechsel_der_IDENTITÄT_eingestehen:rHD_fHD
# a530:Hh:Beuteteilen:rHD_fHD
# a550:f:MISSETAT_planen:rHD_fHD
# a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:h:Zweikampf:rHD_rAN
# a300:h:VERSCHLINGEN:rHD_rAN
# a300:H:VERSCHLINGEN_beheben:rHD_rAN
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
# a300:H:NEUGIER_ausgelöst:rVB
# a300:HF:Information_aus_zweiter_Hand:rVB
# a300:F:EINLADUNG:rHD_rVB
# a300:H:Einer_EINLADUNG_nachgehen:rHD_rVB
# a300:F:Um_GEGENLEISTUNG_bitten:rHD_rVB
# a300:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rHF
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a530:H:Ende:rHD_rVB
#
#
# zyx_cr_agx_rus_2ß
# -----------------
# a300 Der Drachentöter
# a301 Die drei geraubten Prinzesinnen
# -----------------
# a301:F:Auftrag_zum_Kochen:fHD
# a301:f:PROVOKATION:rST_fHD
# a301:h:Der_PROVOKATION_nachgehen:rST_fHD
# a301:h:Auftrag_zum_Kochen:fHD
# a301:h:Den_Vorgang_deuten:fHD
# a301:F:Auftrag_zum_Kochen:rHD
# a301:f:PROVOKATION:rHD_rST
# a301:H:Der_PROVOKATION_nachgehen:rHD_rST
# a301:H:Hilfeversprechen_erhalten:rHD_rST
# a300:F:WASSERMANGEL_beheben:rHD_rHF
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rHF
# a300:H:WAFFE_ZAUBERMITTEL_erhalten:rHD_rHF
# a300:HF:ABRATEN_von_der_Mission:rHD_rVB
# a300:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rVB
# a300:H:Mut_zeigen:rHD_rPP
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rHD_rVB
# a300:F:MARKIERUNGEN_anbringen:rHD_rAN
# a300:F:MARKIERUNGEN_anbringen:rHD_rPP
# a300:h:KONTAKT_abbrechen:rHD_rPP
# a300:H:Den_Vorgang_deuten:rHD_fHD
# a300:h:GIER_und_NEID_ausgelöst:rHD_fHD
# a300:h:SCHLAF:rHD_fHD
# a300:f:MISSETAT_planen:rHD_fHD
# a300:h:MISSETAT_wie_Entmachtung:rHD_fHD
# a300:h:MISSETAT_wie_Aneignung:rHD_fHD
# a300:f:Heldentat_VORTÄUSCHEN:rVB_fHD
# a300:H:Dem_VORTÄUSCHEN_nachgehen:rPP_fHD
# a300:F:MISSETAT_beheben:rHD_rHF
# a300:F:Krisenursachen_ergründen:rHD_rHF
# a300:H:KONTAKT_wiederherstellen:rHD_rHP_rPP
# a300:H:MARKIERUNGEN_vorlegen:rHD_rHP_rPP
# a300:H:MARKIERUNGEN_erkennen:rHD_rHP_rPP
# a300:H:Held_erkennen:rHF_rHP_fHD
# a300:H:Bestrafung:rHF_rHP_fHD
# a300:f:Heiraten:rHD_rPP
#
#
# zyx_cr_ava_rus_110ß
# -----------------
# a300 Der Drachentöter
# a301 Die drei geraubten Prinzesinnen
# a650A Starker Hans
# -----------------
# a650A:h:Eine_ENTFÜHRUNG:rHH_fHH
# a650A:H:Zur_Welt_kommen:rHD
# a650A:F:Krisenursachen_ergründen:rHD_rHH
# a650A:F:Eine_ENTFÜHRUNG_beheben:rHD_rHH
# a650A:H:Zweikampf:rHD_fHH
# a650A:H:Eine_ENTFÜHRUNG_beheben:rHD_fHH
# a650A:H:KONTAKT_abbrechen:rHD_rHH
# a650A:f:VERTRAG_abschließen_oder_verkünden:rHD_rAN
# a650A:f:HOLZ_besorgen:rHD_rAN
# a650A:H:HOLZ_Sammeln_in_Angriff_nehmen:rHD_rZO
# a650A:H:HOLZ_besorgen:rHD_rZO_rAN
# a650A:f:Schrecken_ausgelöst:rHD_rZO_rAN
# a650A:f:ZOLLERHEBUNG_vollstrecken:rHD_rAN
# a650A:H:ZOLLERHEBUNG_in_Angriff_nehmen:rHD_rBZ_rZO
# a650A:H:UNGEHEUER_erfassen:rHD_rBZ_rZO
# a650A:H:UNGEHEUER_herbeiholen:rHD_rBZ_rAN
# a650A:f:Schrecken_ausgelöst:rHD_rBZ_rAN
# a650A:f:ZOLLERHEBUNG_vollstrecken:rHD_rAN
# a650A:H:ZOLLERHEBUNG_in_Angriff_nehmen:rHD_rBZ_rZO
# a650A:H:UNGEHEUER_erfassen:rHD_rBZ_rZO
# a650A:H:UNGEHEUER_herbeiholen:rHD_rBZ_rAN
# a650A:f:Schrecken_ausgelöst:rHD_rBZ_rAN
# a650A:f:Tiere_MÄSTEN:rHD_rAN
# a650A:H:Tiere_MÄSTEN_in_Angriff_nehmen:rHD_rAN_fHF
# a650A:f:VERFOLGUNG:rHD_rAN_fHF
# a650A:H:VERFOLGUNG_entkommen:rHD_rAN_fHF
# a650A:H:VERTRAG_auflösen:rHD_rAN_fHF
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Auftrag_zum_Kochen:fHD
# a301:f:PROVOKATION:fHD_fAN
# a301:h:Der_PROVOKATION_nachgehen:fHD_fAN
# a301:h:Auftrag_zum_Kochen:fHD
# a301:F:Auftrag_zum_Kochen:fHD
# a301:f:PROVOKATION:fHD_fAN
# a301:h:Der_PROVOKATION_nachgehen:fHD_fAN
# a301:F:Auftrag_zum_Kochen:rHD
# a301:f:PROVOKATION:rHD_fAN
# a301:H:Der_PROVOKATION_nachgehen:rHD_fAN
# a301:H:Wegweisung_erpressen:rHD_fAN
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:HF:ABRATEN_von_der_Mission:rHD_rPP
# a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:F:Krisenursachen_ergründen:rHD_rPP
# a301:HF:MISSETAT_beheben:rHD_rPP
# a301:Hh:Der_MISSETATwarnung_nachgehen:rHD_rPP
# a301:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rPP
# a301:h:MISSETAT_wie_Jemanden_im_Stich_lassen:rHD_fHD
# a301:h:Den_ALTERNATIVEN_nachgehen:rHD_fZM
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:F:GEGENLEISTUNG_für_die_LEISTUNG:rHD_rHP
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
# a300:F:Heiraten:rHD_rHP
# a300:h:Heiraten:rHD_rHP
# a300:H:Um_GEGENLEISTUNG_bitten:rHD_rHP
# a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Sorge_um_Schutzbedürftige:rHD_rST
# a300:F:Hilfeversprechen_erhalten:rHD_rHF
# a300:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a300:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHP
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a300:H:Sorge_um_Mitleidsbedürftige:rHD_rHF
# a300:H:Eine_BEHINDERUNG_beheben:rHD_rHF
# a301:f:ZWANGSEHE_Drohung:rHD_rPP_fHD
# a301:H:ZWANGSEHE_Drohung_beheben:rHD_rPP_fHD
# a301:H:Bestrafung:rHD_rPP_fHD
# a301:F:Heiraten:rHD_rPP
#
#
# zyx_cr_ava_rus_176ß
# -----------------
# a300 Der Drachentöter
# a301 Die drei geraubten Prinzesinnen
# a650A Starker Hans
# -----------------
# a650A:F:Bauwerk_errichten:rHD_rZO
# a650A:F:FEHLENDEN_Gegenstand_besorgen:rHD_rZO
# a650A:H:FEHLENDEN_Gegenstand_erfassen:rHD_rZO
# a650A:H:UNGEHEUER_erfassen:rHD_rZO
# a650A:H:UNGEHEUER_herbeiholen:rHD_rZO
# a650A:f:Schrecken_ausgelöst:rHD_rAN
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Auftrag_zum_Kochen:fHD
# a301:f:PROVOKATION:fHD_fAN
# a301:h:Der_PROVOKATION_nachgehen:fHD_fAN
# a301:h:Auftrag_zum_Kochen:fHD
# a301:h:Den_Vorgang_deuten:fHD
# a301:F:Auftrag_zum_Kochen:fHD
# a301:f:PROVOKATION:fHD_fAN
# a301:h:Der_PROVOKATION_nachgehen:fHD_fAN
# a301:F:Auftrag_zum_Kochen:rHD
# a301:f:PROVOKATION:rHD_fAN
# a301:H:Der_PROVOKATION_nachgehen:rHD_fAN
# a301:H:Wegweisung_erpressen:rHD_fVB
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:HF:ABRATEN_von_der_Mission:rHD_rAN
# a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rAN
# a301:H:Zweikampf:rHD_rAN
# a301:F:Krisenursachen_ergründen:rHD_rPP
# a301:H:Sich_oder_Andere_hochziehen_LASSEN:rHD_rPP
# a301:HF:MISSETAT_beheben:rHD_rPP
# a301:Hh:Der_MISSETATwarnung_nachgehen:rHD_rPP
# a301:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rPP
# a301:h:MISSETAT_wie_Jemanden_im_Stich_lassen:rHD_fHD
# a301:h:Den_ALTERNATIVEN_nachgehen:rHD_fZM
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
# a300:H:Um_GEGENLEISTUNG_bitten:rHD_rVB
# a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rVB
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Vermittlung:rHF_rST
# a300:H:Hilfeversprechen_erhalten:rHD_rHF
# a300:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a300:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rVB
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a300:H:Sorge_um_Mitleidsbedürftige:rHD_rHF
# a300:H:Eine_BEHINDERUNG_beheben:rHD_rHF
# a301:f:ZWANGSEHE_Drohung:rHD_rHP_fHD
# a301:H:ZWANGSEHE_Drohung_beheben:rHD_rHP_fHD
# a301:H:Bestrafung:rHD_rHP_fHD
# a301:H:Heiraten:N
#
#
# zyx_cr_ava_rus_2ß
# -----------------
# a300 Der Drachentöter
# a301 Die drei geraubten Prinzesinnen
# a650A Starker Hans
# -----------------
# a650A:h:Eine_ENTFÜHRUNG:rHH_fHH
# a650A:H:Zur_Welt_kommen:rHD
# a650A:H:Krisenursachen_ergründen:rHD_rHH
# a650A:F:Eine_ENTFÜHRUNG_beheben:rHD_rHH
# a650A:H:Zweikampf:rHD_fHH
# a650A:H:Eine_ENTFÜHRUNG_beheben:rHD_fHH
# a650A:h:KONTAKT_abbrechen:rHD_rHH
# a650A:f:VERTRAG_abschließen_oder_verkünden:rHD_rAN
# a650A:f:HOLZ_besorgen:rHD_rAN
# a650A:H:HOLZ_Sammeln_in_Angriff_nehmen:rHD_rZO
# a650A:H:HOLZ_besorgen:rHD_rAN
# a650A:h:Schrecken_ausgelöst:rHD_rAN
# a650A:f:ZOLLERHEBUNG_vollstrecken:rHD_rAN
# a650A:H:ZOLLERHEBUNG_in_Angriff_nehmen:rHD_rZO
# a650A:H:UNGEHEUER_erfassen:rHD_rZO
# a650A:H:UNGEHEUER_herbeiholen:rHD_rAN
# a650A:f:Schrecken_ausgelöst:rHD_rAN
# a650A:f:ZOLLERHEBUNG_vollstrecken:rHD_rAN
# a650A:H:ZOLLERHEBUNG_in_Angriff_nehmen:rHD_rZO
# a650A:H:UNGEHEUER_erfassen:rHD_rZO
# a650A:H:UNGEHEUER_herbeiholen:rHD_rAN
# a650A:f:Schrecken_ausgelöst:rHD_rAN
# a650A:f:Tiere_MÄSTEN:rHD_rAN
# a650A:H:Tiere_MÄSTEN_in_Angriff_nehmen:rHD_rAN_fHF
# a650A:h:VERFOLGUNG:rHD_rAN_fHF
# a650A:H:VERFOLGUNG_entkommen:rHD_rAN_fHF
# a650A:H:VERTRAG_auflösen:rHD_rAN_fHF
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Auftrag_zum_Kochen:fHD
# a301:f:PROVOKATION:fHD_fAN
# a301:h:Der_PROVOKATION_nachgehen:fHD_fAN
# a301:h:Auftrag_zum_Kochen:fHD
# a301:h:Den_Vorgang_deuten:fHD
# a301:F:Auftrag_zum_Kochen:fHD_fAN
# a301:f:PROVOKATION:fHD_fAN
# a301:h:Der_PROVOKATION_nachgehen:fHD_fAN
# a301:F:Auftrag_zum_Kochen:rHD
# a301:f:PROVOKATION:rHD_fAN
# a301:H:Der_PROVOKATION_nachgehen:rHD_fAN
# a301:H:Wegweisung_erpressen:rHD_fAN
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:HF:ABRATEN_von_der_Mission:rHD_rPP
# a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:H:Krisenursachen_ergründen:rHD_rPP
# a301:F:Liebe_wird_ausgelöst:rHD_rPP
# a301:H:Sich_oder_Andere_hochziehen_LASSEN:rHD_rPP
# a301:HF:MISSETAT_beheben:rHD_rPP
# a301:Hh:Der_MISSETATwarnung_nachgehen:rHD_rPP
# a301:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rPP
# a301:h:MISSETAT_wie_Jemanden_im_Stich_lassen:rHD_rPP_fHD
# a300:h:Den_ALTERNATIVEN_nachgehen:rHD_fZM
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_fZM
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:HF:ABRATEN_von_der_Mission:rHD_rVB
# a300:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:F:GEGENLEISTUNG_für_die_LEISTUNG:rHD_rHP
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
# a300:F:Heiraten:rHD_rHP
# a300:h:Heiraten:rHD_rHP
# a300:F:Um_GEGENLEISTUNG_bitten:rHD_rHP
# a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Vermittlung:rHF_rST
# a300:H:Hilfeversprechen_erhalten:rHD_rHF
# a300:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a300:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHP
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a300:H:Sorge_um_Mitleidsbedürftige:rHD_rHF
# a300:H:Eine_BEHINDERUNG_beheben:rHD_rHF
# a301:f:ZWANGSEHE_Drohung:rHD_rPP_fHD
# a301:H:ZWANGSEHE_Drohung_beheben:rHD_rPP_fHD
# a301:H:Bestrafung:rHD_rPP_fHD
# a301:H:Heiraten:rHD_rHH_rHP
#
#
# zyx_cr_ava_rus_8ß
# -----------------
# a550 Vogel Pferd und Koenigstochter
# a300A The Fight on the Bridge
# a519 Heldenjungfrau
# -----------------
# a300A:h:VERLUST_von_Tieren_Früchten_Ernte_usw:rHH
# a300A:F:Wache_halten:rHH
# a300A:h:Wache_halten:fHD
# a300A:h:Wache_halten:fHD
# a300A:Hh:Wache_halten:rHD_rAN
# a300A:H:Wegweisung_erpressen:rHD_rAN
# a300A:H:Den_Vorgang_deuten:rHD_rHH_fHD
# a300A:F:VERLUSTursache_beheben:rHD_rHH_fHD
# a300A:h:KONTAKT_abbrechen:rHD_fHD
# a300A:HF:Im_Verborgenen_lauern:rHD_fPP
# a300A:F:Im_Verborgenen_lauern:rHD_rAN
# a300A:H:Zweikampf:rHD_rAN
# a300A:HF:Im_Verborgenen_lauern:rHD_fPP
# a300A:F:Im_Verborgenen_lauern:rHD_rAN
# a300A:H:Zweikampf:rHD_rAN
# a300A:HF:Im_Verborgenen_lauern:rHD_fPP
# a300A:F:Liebe_wird_ausgelöst:rHD_fPP
# a300A:F:Im_Verborgenen_lauern:rHD_rAN
# a300A:H:Zweikampf:rHD_rAN
# a550:H:Auf_dem_Heimweg:rHD_fPP
# a550:H:KONTAKT_wiederherstellen:rHD_fHD
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# a550:H:Sorge_um_Freikaufsbedürftige:rHD_fHD
# a550:h:GIER_und_NEID_ausgelöst:fHD
# a550:h:Der_NEUGIER_nachgehen:fHD
# a550:f:MISSETAT_planen:fHD
# a550:h:MISSETAT_wie_Behinderung:rHD_fHD_fPP
# a550:h:MISSETAT_wie_Aneignung:rHD_fHD_fPP
# a550:h:SCHWEIGEPFLICHT_verhängen:rHD_fHD_fPP
# a519:H:Mit_einer_anderen_Behinderten_einen_Bund_schließen:rHD_rHF
# a519:H:Mit_einer_anderen_Behinderten_einen_Bund_schließen:rHD_rHF
# a519:HF:FEHLENDEN_Gegenstand_besorgen:rHD_rHF
# a519:H:FEHLENDEN_Gegenstand_erfassen:rHD_rHF
# a519:HF:Die_SCHÖNE_herbeiholen:rHD_rHF
# a519:H:Die_SCHÖNE_erfassen:rHD_rHF_rZO
# a519:H:Die_SCHÖNE_herbeiholen:rHD_rHF_rZO
# a519:h:TABU_nachgehen:rZO_rAN
# a519:Hh:Folgen_eines_TABUbruches_rückgängig_machen:rZO_rAN
# a519:h:Sich_auf_Eindringlinge_einlassen:rZO_rAN
# a519:h:VAMPIRISMUS:rZO_rAN
# a519:F:NEUGIER_ausgelöst:rHD_rHF
# a519:H:Der_NEUGIER_nachgehen:rHD_rHF
# a519:F:Heimlich_beobachten:rHD_rHF
# a519:h:Heimlich_beobachten:rHF
# a519:h:Den_Vorgang_deuten:rHF
# a519:F:Heimlich_beobachten:rHF
# a519:h:Den_Vorgang_deuten:rHF
# a519:F:Im_Verborgenen_lauern:rHD_rAN
# a519:H:Wiedergutmachung_erpressen:rHD_rAN
# a519:F:Eine_BEHINDERUNG_beheben:rHD_rHF_rAN
# a519:H:VERSCHLINGEN:rHD_rHF_rAN
# a519:H:VERSCHLINGEN_beheben:rHD_rHF_rAN
# a519:F:Eine_BEHINDERUNG_beheben:rHD_rHF_rAN
# a519:H:VERSCHLINGEN:rHD_rHF_rAN
# a519:H:VERSCHLINGEN_beheben:rHD_rHF_rAN
# a519:HF:VERSCHLINGEN_beheben:rHD_rHF
# a519:F:Eine_BEHINDERUNG_beheben:rHD_rAN
# a519:h:VERSCHLINGEN:rHD_rAN
# a519:h:VERSCHLINGEN_beheben:rHD_rAN
# a519:H:TÖTUNG:rHD_rHF_rAN
# a519:H:VERSCHLINGEN_beheben:rHD_rHF_rAN
# a519:H:Eine_BEHINDERUNG_beheben:rHD_rHF_rAN
# a550:H:Auf_dem_Heimweg:rHD_rHF_fPP
# a550:F:ZWANGSEHE_Drohung_beheben:rHD_rVB
# a550:F:Sonstiges_VORTÄUSCHEN:rHD_rVB
# a550:HF:Information_aus_zweiter_Hand:rHD_rVB
# a550:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF
# a550:f:EINLADUNG:rHD_rHF
# a550:H:Einer_EINLADUNG_nachgehen:rHD_rHF
# a550:F:WETTKAMPF:rHD_fHD
# a550:H:WETTKAMPF_in_Angriff_nehmen:rHD_fHD
# a550:H:Bestrafung:rHD_rHH_fHD
# a550:H:Held_erkennen:rHD_rHH_fHD
# a550:H:Heiraten:rHD_fPP
# a550:H:Ende:rHD_fPP
#
#
# zyx_cr_dar_rus_5ß
# -----------------
# a315 Die treulose Schwester
# a303 Die zwei Brueder
# a300 Der Drachentöter
# a519 Heldenjungfrau
# -----------------
# a315:f:Geburt_des_NACHKOMMENs:rHD_rHH
# a315:f:TODESAUFTRAG:rHD_rHH
# a315:h:Geburt_des_NACHKOMMENs:rHD_fHD
# a315:H:Sorge_um_Mitleidsbedürftige:rHD_fHD
# a315:H:Einem_TODESAUFTRAG_entkommen:rHD_fHD
# a315:F:Im_Verborgenen_lauern:rHD_fHD
# a315:Hh:Mehrere_Gegner_nacheinander_besiegen:rHD_rAN
# a315:h:Sich_auf_Eindringlinge_einlassen:rAN_fHD
# a315:h:GEHEIME_LIEBESBEZIEHUNG:rAN_fHD
# a315:F:Geburt_des_NACHKOMMENs:rHD_rHD_fHD
# a315:H:Geburt_des_NACHKOMMENs:rHD_rHD_fHD
# a315:h:Aussetzung:rHD_rHD_fHD
# a315:H:Adoption:rHD_rHD
# a315:f:VERGIFTUNG:rHD_fHD
# a315:HF:VERGIFTUNG_beheben:rHD_rHD
# a315:H:VERGIFTUNG_beheben:rHD_fHD
# a315:f:VERGIFTUNG:rHD_fHD
# a315:HF:VERGIFTUNG_beheben:rHD_rHD
# a315:H:MISSETAT_beheben:rHD_fHD
# a315:f:VERGIFTUNG:rHD_fHD
# a315:HF:VERGIFTUNG_beheben:rHD_rHD
# a315:H:VERGIFTUNG_beheben:rHD_fHD
# a315:h:MISSETAT_wie_Entmachtung:rHD_fHD
# a315:H:MISSETAT_beheben:rHD_rHD_rZM
# a315:H:Bestrafung:rHD_rAN_fHD
# a303:F:MARKIERUNGEN_anbringen:rHD_rHF
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rPP
# a300:F:WASSERMANGEL_beheben:rHD_rPP
# a300:HF:ABRATEN_von_der_Mission:rHD_rPP
# a300:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a300:h:SCHLAF:rHD_rPP
# a300:H:SCHLAF_unterbrechen:rHD_rPP_rAN
# a300:F:MARKIERUNGEN_anbringen:rHD_rPP
# a300:h:KONTAKT_abbrechen:rHD_rPP
# a300:H:WASSERMANGEL_beheben:rVB_rPP
# a300:H:Menschliche_OPFERGABE_beheben:rVB_rPP
# a300:H:KONTAKT_wiederherstellen:rHD_rPP
# a300:H:MARKIERUNGEN_vorlegen:rHD_rPP
# a300:H:MARKIERUNGEN_erkennen:rHD_rPP
# a300:H:Heiraten:rHD_rPP
# a303:f:NEUGIER_ausgelöst:rHD_rPP
# a303:F:Die_SCHÖNE_herbeiholen:rHD_rPP
# a519:H:Die_SCHÖNE_erfassen:rHD_rZO
# a519:H:Zweikampf:rHD_rZO
# a519:H:Heiratszusage_erpressen:rHD_rZO
# a519:H:Auf_dem_Heimweg:rHD_rBZ_rZO
# a519:H:Heiraten:rHD_rZO
#
#
# zyx_cr_dar_rus_89ß
# -----------------
# a300 Der Drachentöter
# a312D Erbsensohn
# -----------------
# a312D:F:MARKIERUNGEN_anbringen:rHH_rRE
# a312D:h:FREIHEITSBERAUBUNG:rRE
# a312D:F:FREIHEITSBERAUBUNG_beheben:rHH_rRE
# a312D:f:Krisenursachen_ergründen:rRE_rAN
# a312D:f:VERLOCKUNG:rRE_rAN
# a312D:h:Der_VERLOCKUNG_nachgehen:rRE_rAN
# a312D:h:FREIHEITSBERAUBUNG:rRE_rAN
# a312D:F:FREIHEITSBERAUBUNG_beheben:rHH_fRE
# a312D:h:FREIHEITSBERAUBUNG:rAN_fRE
# a312D:H:Magische_EMPFÄNGNISmittel_erhalten:rHD_rHH_rZM
# a312D:H:Wunderbare_EMPFÄNGNIS:rHD_rHH_rZM
# a312D:H:Zur_Welt_kommen:rHD_rHH_rZM
# a312D:F:PROVOKATION:rHD_rVB
# a312D:H:Der_PROVOKATION_nachgehen:rHD_rVB
# a312D:F:NEUGIER_ausgelöst:rHD_rVB
# a312D:F:Der_NEUGIER_nachgehen:rHD_rHH
# a312D:F:Krisenursachen_ergründen:rHD_rHH
# a312D:F:FREIHEITSBERAUBUNG_beheben:rHD_rHH
# a312D:HF:ABRATEN_von_der_Mission:rHD_rVB
# a312D:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rVB
# a312D:H:Zweikampf:rHD_rAN
# a312D:H:Wiedergutmachung_erpressen:rHD_rAN
# a312D:H:TÖTUNG:rHD_rAN
# a312D:H:FREIHEITSBERAUBUNG_beheben:N
# a312D:f:MISSETAT_planen:rHD_fRE
# a312D:h:MISSETAT_wie_Entmachtung:rHD_fRE
# a312D:h:Den_Vorgang_deuten:rHH_rRE_fRE
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rVB
# a312D:H:IDENTITÄT_ändern:N
# a312D:f:ZWANGSEHE_Drohung:rHD_fRE
# a312D:F:WETTKAMPF:rHD_fRE
# a312D:H:WETTKAMPF_in_Angriff_nehmen:rHD_fRE
# a312D:H:Bestrafung:rHD_fRE
# a312D:H:ZWANGSEHE_Drohung_beheben:rHD_fRE
# a312D:H:Den_Vorgang_deuten:rHD_rRE_rPP
# a312D:H:Heiraten:rHD_rRE_rPP
#
#
# zyx_cr_dar_rus_8ß
# -----------------
# a300 Der Drachentöter
# aU ATU Typ: unklar welcher
# -----------------
# aU:h:RESPEKTLOSIGKEIT:N
# aU:F:KONTAKT_abbrechen:N
# aU:HF:Wegweisung_mit_ALTERNATIVEN:N
# aU:Hh:Den_ALTERNATIVEN_nachgehen:N
# aU:F:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:H:Zweikampf:rHD_rAN
# a300:h:KONTAKT_abbrechen:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
# aU:F:MASSENBEDROHUNG:rHD_rVB
# a300:F:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a300:H:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a300:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a300:F:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a300:H:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a300:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# a300:F:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a300:H:Die_potenzielle_Beute_begnadigen:rHD_rHF
# a300:H:HERBEIRUFENDES_ZAUBERMITTEL_erhalten:rHD_rHF
# aU:F:Auf_Hilfsquelle_zurückgreifen:N
# aU:H:Zweikampf:N
# aU:H:Wiedergutmachung_erpressen:N
# aU:F:Auf_Hilfsquelle_zurückgreifen:N
# aU:H:Wiedergutmachung_erpressen:N
# aU:H:MASSENBEDROHUNG_beheben:N
# aU:H:Heiraten:N
# aU:H:KONTAKT_wiederherstellen:N
# aU:H:Der_RESPEKTLOSIGKEIT_entgegentreten:N
#
#
# zyx_cr_khv_rus_17ß
# -----------------
# a300 Der Drachentöter
# a301 Die drei geraubten Prinzesinnen
# a650A Starker Hans
# -----------------
# a650A:h:Eine_ENTFÜHRUNG:rHH_fHH
# a650A:H:Krisenursachen_ergründen:N
# a650A:F:Eine_ENTFÜHRUNG_beheben:N
# a650A:H:FLUCHT_vorbereiten:N
# a650A:H:Zur_Welt_kommen:rHD
# a650A:H:FLUCHT:rHD
# a650A:h:Unerträgliche_Ungeheuerlichkeit:rHD
# a650A:h:KONTAKT_abbrechen:rHD_rHH
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Auftrag_zum_Kochen:fHD
# a301:h:Den_Vorgang_deuten:fHD_fVB
# a301:f:PROVOKATION:fHD_fVB
# a301:h:Der_PROVOKATION_nachgehen:fHD_fVB
# a301:F:Auftrag_zum_Kochen:fHD
# a301:h:Auftrag_zum_Kochen:fHD
# a301:h:Den_Vorgang_deuten:fHD_fVB
# a301:f:PROVOKATION:fHD_fVB
# a301:h:Der_PROVOKATION_nachgehen:fHD_fVB
# a301:F:Auftrag_zum_Kochen:fHD
# a301:h:Auftrag_zum_Kochen:fHD
# a301:h:Den_Vorgang_deuten:fHD_fVB
# a301:f:PROVOKATION:fHD_fVB
# a301:h:Der_PROVOKATION_nachgehen:fHD_fVB
# a301:F:Auftrag_zum_Kochen:rHD
# a301:f:PROVOKATION:rHD_fVB
# a301:H:Der_PROVOKATION_nachgehen:rHD_fVB
# a301:h:SCHLAF:rHD_fVB
# a301:H:SCHLAF_unterbrechen:rHD_fVB
# a301:H:Auftrag_zum_Kochen:rHD_fVB
# a301:H:Den_Vorgang_deuten:rHD_fVB
# a301:H:Wegweisung_erpressen:rHD_fVB
# a301:h:Sich_abseilen_LASSEN:rHD_fHD
# a301:h:Sich_abseilen_LASSEN:rHD_fHD
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:H:Zweikampf:rHD_rAN
# a301:H:Eine_ENTFÜHRUNG_beheben:rHD_rPP
# a301:F:Krisenursachen_ergründen:rHD_rPP
# a301:HF:MISSETAT_beheben:rHD_rPP
# a301:Hh:Der_MISSETATwarnung_nachgehen:rHD_rPP
# a301:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rPP
# a301:F:MARKIERUNGEN_anbringen:rHD_rPP
# a301:h:KONTAKT_abbrechen:rHD_rPP
# a301:H:Sich_oder_Andere_hochziehen_LASSEN:rHD_rPP_fHD
# a301:h:MISSETAT_wie_Jemanden_im_Stich_lassen:rHD_rPP_fHD
# a301:h:Den_ALTERNATIVEN_nachgehen:rHD_fZM
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rPP_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rAN
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rAN
# a300:H:Zweikampf:rHD_rAN
# a300:F:MARKIERUNGEN_anbringen:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rVB
# a300:H:Menschliche_OPFERGABE_beheben:rHP_fHD
# a300:F:GEGENLEISTUNG_für_die_LEISTUNG:rHP_fHD
# a300:f:Heldentat_VORTÄUSCHEN:rHP_fHD
# a300:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHP
# a300:H:MARKIERUNGEN_vorlegen:rHD_rHP
# a300:H:MARKIERUNGEN_erkennen:rHD_rHP
# a300:H:Held_erkennen:rHD_rHP
# a300:F:Heiraten:rHD_rZM_rHP
# a300:h:Heiraten:rHD_rZM_rHP
# a300:H:Um_GEGENLEISTUNG_bitten:rHD_rZM_rHP
# a300:H:Flugzeugendes_ZAUBERMITTEL_erhalten:rHD_rZM_rHP
# a300:F:Sich_oder_andere_tragen_LASSEN:rHD_rZM
# a301:f:ZWANGSEHE_Drohung:rHD_rPP_fHD
# a301:Ff:MARKIERUNGEN_vorlegen:rHD_rPP_fHD
# a301:h:MARKIERUNGEN_vorlegen:rHD_rPP_fHD
# a301:f:ZWANGSEHE_Drohung:rHD_rPP_fHD
# a301:Ff:MARKIERUNGEN_vorlegen:rHD_rPP_fHD
# a301:h:MARKIERUNGEN_vorlegen:rHD_rPP_fHD
# a301:H:KONTAKT_wiederherstellen:rHD_rPP_fHD
# a301:H:MARKIERUNGEN_vorlegen:rHD_rPP_fHD
# a301:H:MARKIERUNGEN_erkennen:rHD_rPP_fHD
# a301:H:Held_erkennen:rHD_rPP_fHD
# a301:H:Bestrafung:rHD_rPP_fHD
# a301:H:Heiraten:rHD_rPP
#
#
# zyx_cr_lez_rus_1ß
# -----------------
# a300 Der Drachentöter
# a590 Die treulose Mutter
# a301 Die drei geraubten Prinzesinnen
# a650A Starker Hans
# -----------------
# a650A:h:Unerträgliche_Unersättlichkeit:rHD_fHH
# a650A:f:Schrecken_ausgelöst:rHD_fHH
# a650A:h:Unerträgliche_Unersättlichkeit:rHD_rVB
# a650A:f:HOLZ_besorgen:rHD_fVB
# a650A:H:HOLZ_Sammeln_in_Angriff_nehmen:rHD_rZO
# a650A:H:UNGEHEUER_erfassen:rHD_rZO
# a650A:H:HOLZ_besorgen:rHD_rZO_fHH
# a650A:f:Schrecken_ausgelöst:rHD_rZO_fHH
# a590:f:Zu_Beauftragungen_anregen:fHH_fVB
# a590:hf:TIERKÖRPERTEIL_besorgen:fHH_fVB
# a590:f:Krankheit_VORTÄUSCHEN:rHD_fHH
# a590:f:TIERKÖRPERTEIL_besorgen:rHD_fHH
# a590:h:Dem_VORTÄUSCHEN_nachgehen:rHD_rZO
# a590:H:TIERKÖRPERTEIL_erfassen:rHD_rZO
# a590:Hh:TIERKÖRPERTEIL_besorgen:rHD_rZO_fHH
# a650A:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST
# a650A:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rVB_fZM
# a650A:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST
# a650A:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rZM
# a650A:h:KONTAKT_abbrechen:rHD_fHH_fVB
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Auftrag_zum_Kochen:fHD
# a301:f:PROVOKATION:fHD_fVB
# a301:h:Der_PROVOKATION_nachgehen:fHD_fVB
# a301:h:Auftrag_zum_Kochen:rHD_fHD
# a301:h:Den_Vorgang_deuten:rHD_fHD
# a301:F:Auftrag_zum_Kochen:fHD
# a301:f:PROVOKATION:fHD_fVB
# a301:h:Der_PROVOKATION_nachgehen:fHD_fVB
# a301:h:Auftrag_zum_Kochen:fHD
# a301:F:Auftrag_zum_Kochen:rHD
# a301:f:GIER_und_NEID_ausgelöst:fHD
# a301:f:PROVOKATION:rHD_fVB
# a301:H:Der_PROVOKATION_nachgehen:rHD_fVB
# a301:H:Auftrag_zum_Kochen:rHD
# a301:H:Wegweisung_erpressen:rHD_fVB
# a301:h:Sich_abseilen_LASSEN:rHD_fHD
# a301:h:Sich_abseilen_LASSEN:rHD_fHD
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:F:Eine_ENTFÜHRUNG_beheben:rHD_rPP
# a301:Hh:ABRATEN_von_der_Mission:rHD_rPP
# a301:h:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:H:Eine_ENTFÜHRUNG_beheben:rHD_rPP
# a301:F:Eine_ENTFÜHRUNG_beheben:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:H:Eine_ENTFÜHRUNG_beheben:rHD_rPP
# a301:HF:ABRATEN_von_der_Mission:rHD_rPP
# a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:F:Krisenursachen_ergründen:rHD_rPP
# a301:HF:MISSETAT_beheben:rHD_rPP
# a301:Hh:Der_MISSETATwarnung_nachgehen:rHD_rPP
# a301:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rPP
# a301:H:Sich_oder_Andere_hochziehen_LASSEN:rHD_rPP_fHD
# a301:h:MISSETAT_wie_Jemanden_im_Stich_lassen:rHD_rPP_fHD
# a301:h:Den_ALTERNATIVEN_nachgehen:rHD_fZM
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rPP_rAN
# a300:H:Zweikampf:rHD_rPP_rAN
# a300:F:MARKIERUNGEN_anbringen:rHD_rPP_rAN
# a300:h:KONTAKT_abbrechen:rHD_rPP_rAN
# a300:H:WASSERMANGEL_beheben:rVB
# a300:F:Intensive_ERKUNDUNGSAKTION:rVB_rHP_rPP
# a300:Hh:Intensive_ERKUNDUNGSAKTION_nachgehen:rVB_rHP_rPP
# a300:F:EINLADUNG:rVB_rHP_rPP
# a300:H:Einer_EINLADUNG_nachgehen:rHD_rHP_rPP
# a300:H:KONTAKT_wiederherstellen:rHD_rHP_rPP
# a300:H:MARKIERUNGEN_vorlegen:rHD_rHP_rPP
# a300:H:MARKIERUNGEN_erkennen:rHD_rHP_rPP
# a300:H:Um_GEGENLEISTUNG_bitten:rHD_rHP
# a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Sorge_um_Schutzbedürftige:rHD_rST
# a300:h:SCHLAF:rHD_rST
# a300:H:Vermittlung:rHF_rST
# a300:H:SCHLAF_unterbrechen:rHD_rHF
# a300:F:Hilfeversprechen_erhalten:rHD_rHF
# a300:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a300:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHP
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a300:H:Sorge_um_Mitleidsbedürftige:rHD_rHF
# a300:H:Eine_BEHINDERUNG_beheben:rHD_rHF
# a301:F:ZWANGSEHE_Drohung:rHD_rVB
# a301:H:ZWANGSEHE_Drohung_beheben:rHD_rPP_fHD
# a301:H:Bestrafung:rHD_rPP_fHD
# a301:H:Heiraten:rHD_rPP
#
#
# zyx_cr_lez_rus_29ß
# -----------------
# a300 Der Drachentöter
# a590 Die treulose Mutter
# a301 Die drei geraubten Prinzesinnen
# a650A Starker Hans
# -----------------
# a650A:h:Unerträgliche_Unersättlichkeit:rHD_fHH
# a650A:h:Unerträgliche_Unersättlichkeit:rHD_rAN
# a650A:f:HOLZ_besorgen:rHD_rAN
# a650A:H:HOLZ_Sammeln_in_Angriff_nehmen:rHD_rZO
# a650A:H:UNGEHEUER_erfassen:rHD_rZO
# a650A:H:HOLZ_besorgen:rHD_rZO_fHH
# a650A:f:Schrecken_ausgelöst:rHD_rZO_fHH
# a590:f:Zu_Beauftragungen_anregen:rAN_fHH
# a590:hf:TIERKÖRPERTEIL_besorgen:rAN_fHH
# a590:f:Krankheit_VORTÄUSCHEN:rHD_fHH
# a590:f:TIERKÖRPERTEIL_besorgen:rHD_fHH
# a590:h:Dem_VORTÄUSCHEN_nachgehen:rHD_rZO
# a590:H:TIERKÖRPERTEIL_erfassen:rHD_rZO
# a650A:Ff:TIERKÖRPERTEIL_besorgen:rHD_fHH
# a650A:h:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rVB_fZM
# a650A:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST
# a650A:H:ZAUBERMITTEL_AUSRÜSTUNG_oder_WAFFE_ausprobieren:rHD_rST_rZM
# a650A:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rST_rZM
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Zum_STAUNEN_bringen:rHD_fHD
# a301:H:Dem_STAUNEN_nachgehen:rHD_fHD
# a301:H:Einen_Begleiter_gewinnen:rHD_fHD
# a301:F:Auftrag_zum_Kochen:fHD_fVB
# a301:f:PROVOKATION:fHD
# a301:h:Der_PROVOKATION_nachgehen:fHD
# a301:h:Auftrag_zum_Kochen:fHD
# a301:h:Den_Vorgang_deuten:fHD
# a301:F:Auftrag_zum_Kochen:fHD
# a301:h:Auftrag_zum_Kochen:fHD
# a301:F:Auftrag_zum_Kochen:rHD
# a301:f:GIER_und_NEID_ausgelöst:fHD
# a301:f:PROVOKATION:rHD_fVB
# a301:H:Der_PROVOKATION_nachgehen:rHD_fVB
# a301:H:Auftrag_zum_Kochen:rHD_fHD
# a301:H:Den_Vorgang_deuten:rHD_fHD
# a301:h:GIER_und_NEID_ausgelöst:rHD_fHD
# a301:H:Wegweisung_erpressen:rHD_fVB
# a301:h:Sich_abseilen_LASSEN:rHD_fHD
# a301:h:Sich_abseilen_LASSEN:rHD_fHD
# a301:H:Sich_abseilen_LASSEN:rHD_fHD
# a301:F:Eine_ENTFÜHRUNG_beheben:rHD_rPP
# a301:HF:ABRATEN_von_der_Mission:rHD_rPP
# a301:Hh:Dem_ABRATEN_von_der_Mission_nachgehen:rHD_rPP
# a301:H:Zweikampf:rHD_rAN
# a301:H:Eine_ENTFÜHRUNG_beheben:rHD_rAN
# a301:F:Eine_ENTFÜHRUNG_beheben:rHD_rAN
# a301:H:Zweikampf:rHD_rAN
# a301:H:Eine_ENTFÜHRUNG_beheben:rHD_rAN
# a301:F:Eine_ENTFÜHRUNG_beheben:rHD_rAN
# a301:H:Zweikampf:rHD_rAN
# a301:H:Eine_ENTFÜHRUNG_beheben:rHD_rPP
# a301:F:Krisenursachen_ergründen:rHD_rPP
# a301:H:Sich_oder_Andere_hochziehen_LASSEN:rHD_rPP
# a301:HF:MISSETAT_beheben:rHD_rPP
# a301:Hh:Der_MISSETATwarnung_nachgehen:rHD_rPP
# a301:HF:Wegweisung_mit_ALTERNATIVEN:rHD_rPP
# a301:H:Sich_oder_Andere_hochziehen_LASSEN:rHD_rPP_fHD
# a301:h:MISSETAT_wie_Jemanden_im_Stich_lassen:rHD_rPP_fHD
# a301:h:Den_ALTERNATIVEN_nachgehen:rHD_fZM
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rVB
# a300:F:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rVB_rAN
# a300:Hh:WASSERMANGEL_beheben:rHD_rVB
# a300:H:Mut_zeigen:rHD_rAN
# a300:H:Zweikampf:rHD_rAN
# a300:F:MARKIERUNGEN_anbringen:rHD_rAN
# a300:H:Menschliche_OPFERGABE_beheben:rHD_rPP
# a300:h:KONTAKT_abbrechen:rHD_rPP
# a300:F:WASSERMANGEL_beheben:rVB
# a300:F:Intensive_ERKUNDUNGSAKTION:rHP
# a300:Hh:Intensive_ERKUNDUNGSAKTION_nachgehen:rHP
# a300:F:EINLADUNG:rHP
# a300:H:Einer_EINLADUNG_nachgehen:rHD_rHP
# a300:H:MARKIERUNGEN_vorlegen:rHD_rHP
# a300:H:MARKIERUNGEN_erkennen:rHD_rHP
# a300:H:Held_erkennen:rHD_rHP
# a300:H:KONTAKT_wiederherstellen:rHD_rHP
# a300:H:Um_GEGENLEISTUNG_bitten:rHD_rHP
# a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP
# a300:F:Sorge_um_Schutzbedürftige:rHD_rST
# a300:H:Sorge_um_Schutzbedürftige:rHD_rST
# a300:h:SCHLAF:rHD_rST
# a300:H:Vermittlung:rHD_rHF
# a300:H:SCHLAF_unterbrechen:rHD_rHF
# a300:H:Hilfeversprechen_erhalten:rHD_rHF
# a300:HF:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF
# a300:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHP
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a300:H:Sorge_um_Mitleidsbedürftige:rHD_rHF
# a300:H:Eine_BEHINDERUNG_beheben:rHD_rHF
# a301:F:ZWANGSEHE_Drohung:rHD_rVB
# a301:H:ZWANGSEHE_Drohung_beheben:rHD_fHD
# a301:H:Bestrafung:rHD_fHD
#
#
# zyx_cr_nog_rus_17ß
# -----------------
# a300 Der Drachentöter
# a550 Vogel Pferd und Koenigstochter
# -----------------
# a550:h:VERLUST_von_Tieren_Früchten_Ernte_usw:rHH
# a550:F:Wache_halten:rHD_rHH_fHD
# a550:h:Wache_halten:fHD
# a550:h:Wache_halten:fHD
# a550:F:Um_einen_Auftrag_werben:rHD_rHH
# a550:H:Wache_halten:rHD_rZM
# a550:Hh:Eines_auffälligen_GEGENSTANDES_habhaft_werden:rHD_rZM
# a550:f:NEUGIER_ausgelöst:rHD_fHD
# a550:H:Den_Vorgang_deuten:rHD_fHD
# a550:F:Um_einen_Auftrag_werben:rHH_fHD
# a550:F:VOGEL_herbeiholen:rHH_fHD
# a550:h:VERMISSEN_der_Angehörige:rHH_fHD
# a550:F:Um_einen_Auftrag_werben:rHH_fHD
# a550:F:VOGEL_herbeiholen:rHH_fHD
# a550:h:VERMISSEN_der_Angehörige:rHH_fHD
# a550:F:Um_einen_Auftrag_werben:rHD_rHH
# a550:F:VOGEL_herbeiholen:rHD_rHH
# a550:F:VERMISSEN_der_Angehörige_beheben:rHD_rHH
# a550:HF:Wegweisung_mit_ALTERNATIVEN:rHD
# a550:F:Schicksalsbestimmender_Weisung_folgen:rHD
# a550:h:SCHLAF:rHD_rHF
# a550:H:SCHLAF_unterbrechen:rHD_rHF
# a550:F:Den_Einbrecher_begnadigen:rHD_rHF
# a550:H:Den_Einbrecher_begnadigen:rHD_rHF
# a550:H:Einen_Begleiter_gewinnen:rHD_rHF
# a550:HF:VOGEL_erfassen:rHD_rHF
# a550:hf:TABU_Sonstiges:rHD_rHF
# a550:H:VOGEL_erfassen:rHD_rBZ_rZO
# a550:h:TABU_nachgehen:rHD_rBZ_rZO
# a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO
# a550:f:REITTIER_besorgen:rHD_rBZ
# a550:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a550:HF:REITTIER_erfassen:rHD_rHF
# a550:hf:TABU_Sonstiges:rHD_rHF
# a550:H:REITTIER_erfassen:rHD_rBZ_rZO
# a550:h:TABU_nachgehen:rHD_rBZ_rZO
# a550:h:FREIHEITSBERAUBUNG:rHD_rBZ_rZO
# a550:f:Die_SCHÖNE_herbeiholen:rHD_rBZ
# a550:F:Auf_Hilfsquelle_zurückgreifen:rHD_rHF
# a550:HF:Die_SCHÖNE_erfassen:rHD_rHF
# a550:H:Turm_Zaun_oder_Berg_hinaufsteigen:rHD_rBZ_rZO
# a550:H:Mehrere_Gegner_nacheinander_besiegen:rHD_rBZ_rZO
# a550:H:Universellen_ZAUBERMITTEL_erhalten:rHD_rBZ_rZO
# a550:F:Krisenursachen_ergründen:rHD_rZO
# a550:h:Abtretung_der_Schönen_stehet_bevor:rHD_rZO
# a550:F:Auf_Hilfsquelle_zurückgreifen:rHD_rZO
# a550:HF:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rZO
# a550:H:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rBZ
# a550:F:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rHF_rBZ
# a550:H:Dem_VORTÄUSCHEN_nachgehen:rHD_rHF_rBZ
# a550:H:Die_SCHÖNE_herbeiholen:rHD_rHF_rBZ
# a550:H:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rZO
# a550:F:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rHF_rZO
# a550:H:VOGEL_herbeiholen:rHD_rHF_rZO
# a550:H:Die_Änderung_der_EXISTENZFORM:rHD_rHF_rZO
# a550:F:Geänderte_EXISTENZFORM_VORTÄUSCHEN:rHD_rHF_rZO
# a550:H:REITTIER_besorgen:rHD_rHF_rZO
# a550:H:Auf_dem_Heimweg:rHD_rHF_rZO
# a550:F:Sorge_um_Freikaufsbedürftige:rHD_fHD
# a550:H:Sorge_um_Freikaufsbedürftige:rHD_fHD
# a550:H:VERMISSEN_der_Angehörige_beheben:rHD_fHD
# a550:H:Auf_dem_Heimweg:rHD_fHD
# a550:h:SCHLAF:rHD_fHD
# a550:f:MISSETAT_planen:rHD_fHD
# a550:h:MISSETAT_wie_Entmachtung:rHD_fHD
# a550:h:MISSETAT_wie_Aneignung:rHD_fHD
# a550:f:Heldentat_VORTÄUSCHEN:rHH_fHD
# a300:h:An_einen_AUSWEGLOSEN_Ort_gelangen:rHD_rPP
# a300:F:WASSERMANGEL_beheben:rHD_rPP
# a300:F:Menschliche_OPFERGABE_beheben:rHD_rPP
# a300:F:LEISTUNG_für_die_GEGENLEISTUNG:rHD_rHP_rPP
# a300:H:Zweikampf:rHD_rAN
# a300:H:WASSERMANGEL_beheben:rHD_rAN
# a300:F:Heiraten:rHD_rHP
# a300:h:Heiraten:rHD_rHP
# a300:H:Um_GEGENLEISTUNG_bitten:rHD_rHP
# a300:HF:Weiterverweisung_an_anderen_Stifter_oder_Helfer:rHD_rHP
# a300:H:Die_Beschaffung_der_AUSRÜSTUNG:rHD_rHF_rPP
# a300:h:Nahrungsvorrat_aufgebraucht:rHD_rHF
# a300:Hh:BEHINDERUNG_durch_Verstümmelung:rHD_rHF
# a300:H:Von_einem_AUSWEGLOSEN_Ort_entkommen:rHD_rHF
# a300:H:Sorge_um_Mitleidsbedürftige:rHD_rHF
# a300:F:Eine_BEHINDERUNG_beheben:rHD_rHF
# a550:H:IDENTITÄT_ändern:rHD_rHH_fHD
# a550:h:ZWANGSEHE_Drohung:rHD_rHH_fHD
# a550:H:Bestrafung:rHD_rHH_fHD
# a550:H:ZWANGSEHE_Drohung_beheben:rHD_rHH_fHD
